# %% [markdown]
# # Changing Ambient Temperature for Low C-rate Simulations

# %%
import pybamm
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import math
from scipy.integrate import solve_ivp
from scipy.fft import fft, fftfreq, fftshift
from scipy.signal import savgol_filter
from scipy.signal import find_peaks
from scipy import interpolate
plt.rcParams['figure.dpi'] = 150
plt.rcParams['savefig.dpi'] = 300
plt.style.use('seaborn-white')

eSOH_DIR = "./data/esoh/"
oCV_DIR = "./data/ocv/"
fig_DIR = "./figures/"

# %matplotlib widget

# %%
def nmc_volume_change_mohtat(sto):
    t_change = -1.10/100*(1-sto)
    return t_change

def graphite_volume_change_mohtat(sto):
    stoichpoints = np.array([0,0.12,0.18,0.24,0.50,1])
    thicknesspoints = np.array([0,2.406/100,3.3568/100,4.3668/100,5.583/100,13.0635/100])
    x = [sto]
    t_change = pybamm.Interpolant(stoichpoints, thicknesspoints, x, name=None, interpolator='linear', extrapolate=True, entries_string=None)
    return t_change

def get_parameter_values():
    parameter_values = pybamm.ParameterValues(chemistry=pybamm.parameter_sets.Mohtat2020)
    parameter_values.update(
        {
            # mechanical properties
            "Positive electrode Poisson's ratio": 0.3,
            "Positive electrode Young's modulus [Pa]": 375e9,
            "Positive electrode reference concentration for free of deformation [mol.m-3]": 0,
            "Positive electrode partial molar volume [m3.mol-1]": -7.28e-7,
            "Positive electrode volume change": nmc_volume_change_mohtat,
            # Loss of active materials (LAM) model
            "Positive electrode LAM constant exponential term": 2,
            "Positive electrode critical stress [Pa]": 375e6,
            # mechanical properties
            "Negative electrode Poisson's ratio": 0.2,
            "Negative electrode Young's modulus [Pa]": 15e9,
            "Negative electrode reference concentration for free of deformation [mol.m-3]": 0,
            "Negative electrode partial molar volume [m3.mol-1]": 3.1e-6,
            "Negative electrode volume change": graphite_volume_change_mohtat,
            # Loss of active materials (LAM) model
            "Negative electrode LAM constant exponential term": 2,
            "Negative electrode critical stress [Pa]": 60e6,
            # Other
            "Cell thermal expansion coefficient [m.K-1]": 1.48E-6,
            "Lower voltage cut-off [V]": 3.0
        },
        check_already_exists=False,
    )
    return parameter_values
parameter_values = get_parameter_values()

# %%
parameter_values.search("SEI")
# Out:
# Initial inner SEI thickness [m]	2.5e-09
# Initial outer SEI thickness [m]	2.5e-09
# Inner SEI electron conductivity [S.m-1]	8.95e-14
# Inner SEI lithium interstitial diffusivity [m2.s-1]	1e-20
# Inner SEI open-circuit potential [V]	0.1
# Inner SEI partial molar volume [m3.mol-1]	9.585e-05
# Inner SEI reaction proportion	0.5
# Outer SEI open-circuit potential [V]	0.8
# Outer SEI partial molar volume [m3.mol-1]	9.585e-05
# Outer SEI solvent diffusivity [m2.s-1]	2.5000000000000002e-22
# Ratio of inner and outer SEI exchange current densities	1.0
# SEI kinetic rate constant [m.s-1]	1e-12
# SEI open-circuit potential [V]	0.4
# SEI reaction exchange current density [A.m-2]	1.5e-07
# SEI resistivity [Ohm.m]	200000.0

# %%
def split_long_string(title, max_words=None):
    """Get title in a nice format"""
    max_words = max_words or pybamm.settings.max_words_in_line
    words = title.split()
    # Don't split if fits on one line, don't split just for units
    if len(words) <= max_words or words[max_words].startswith("["):
        return title
    else:
        first_line = (" ").join(words[:max_words])
        second_line = (" ").join(words[max_words:])
        return first_line + "\n" + second_line

# %%
def cycle_adaptive_simulation(model, parameter_values, experiment,SOC_0=1, save_at_cycles=None):
    experiment_one_cycle = pybamm.Experiment(
        experiment.operating_conditions_cycles[:1],
        termination=experiment.termination_string,
        cccv_handling=experiment.cccv_handling,
    )
    Vmin = 3.0
    Vmax = 4.2
    esoh_model = pybamm.lithium_ion.ElectrodeSOH()
    esoh_sim = pybamm.Simulation(esoh_model, parameter_values=parameter_values)
    param = model.param
    Cn = parameter_values.evaluate(param.C_n_init)
    Cp = parameter_values.evaluate(param.C_p_init)
    eps_n = parameter_values["Negative electrode active material volume fraction"]
    eps_p = parameter_values["Positive electrode active material volume fraction"]
    C_over_eps_n = Cn / eps_n
    C_over_eps_p = Cp / eps_p
    c_n_max = parameter_values.evaluate(param.c_n_max)
    c_p_max = parameter_values.evaluate(param.c_p_max)
    n_Li_init = parameter_values.evaluate(param.n_Li_particles_init)
    
    esoh_sol = esoh_sim.solve(
        [0],
        inputs={"V_min": Vmin, "V_max": Vmax, "C_n": Cn, "C_p": Cp, "n_Li": n_Li_init},
        solver=pybamm.AlgebraicSolver(),
    )

    parameter_values.update(
        {
            "Initial concentration in negative electrode [mol.m-3]": esoh_sol[
                "x_100"
            ].data[0]
            * c_n_max,
            "Initial concentration in positive electrode [mol.m-3]": esoh_sol[
                "y_100"
            ].data[0]
            * c_p_max,
            
        }
    )

    sim_ode = pybamm.Simulation(
        model, experiment=experiment_one_cycle, parameter_values=parameter_values,
        solver=pybamm.CasadiSolver("safe")
    )
    sol0 = sim_ode.solve(initial_soc=SOC_0)
    model = sim_ode.solution.all_models[0]
    cap0 = sol0.summary_variables["Capacity [A.h]"]

    def sol_to_y(sol, loc="end"):
        if loc == "start":
            pos = 0
        elif loc == "end":
            pos = -1
        model = sol.all_models[0]
        n_Li = sol["Total lithium in particles [mol]"].data[pos].flatten()
        Cn = sol["Negative electrode capacity [A.h]"].data[pos].flatten()
        Cp = sol["Positive electrode capacity [A.h]"].data[pos].flatten()
        # y = np.concatenate([n_Li, Cn, Cp])
        y = n_Li
        for var in model.initial_conditions:
            if var.name not in [
                "X-averaged negative particle concentration",
                "X-averaged positive particle concentration",
                "Discharge capacity [A.h]",
            ]:
                value = sol[var.name].data
                if value.ndim == 1:
                    value = value[pos]
                elif value.ndim == 2:
                    value = value[:, pos]
                elif value.ndim == 3:
                    value = value[:, :, pos]
                y = np.concatenate([y, value.flatten()])
        return y

    def y_to_sol(y, esoh_sim, model):
        n_Li = y[0]
        Cn = C_over_eps_n * y[1]
        Cp = C_over_eps_p * y[2]

        esoh_sol = esoh_sim.solve(
            [0],
            inputs={"V_min": Vmin, "V_max": Vmax, "C_n": Cn, "C_p": Cp, "n_Li": n_Li},
        )
        esoh_sim.built_model.set_initial_conditions_from(esoh_sol)
        ics = {}
        x_100 = esoh_sol["x_100"].data[0]
        y_100 = esoh_sol["y_100"].data[0]
        x_0 = esoh_sol["x_0"].data[0]
        y_0 = esoh_sol["y_0"].data[0]
        start = 1
        for var in model.initial_conditions:
            if var.name == "X-averaged negative particle concentration":
                ics[var.name] = ((x_100-x_0)*SOC_0+x_0) * np.ones((model.variables[var.name].size, 2))
            elif var.name == "X-averaged positive particle concentration":
                ics[var.name] = ((y_100-y_0)*SOC_0+y_0) * np.ones((model.variables[var.name].size, 2))
            elif var.name == "Discharge capacity [A.h]":
                ics[var.name] = np.zeros(1)
            else:
                end = start + model.variables[var.name].size
                ics[var.name] = y[start:end, np.newaxis]
                start = end
        model.set_initial_conditions_from(ics)
        return pybamm.Solution(
            [np.array([0])],
            model.concatenated_initial_conditions.evaluate()[:, np.newaxis],
            model,
            {},
        )

    def dydt(t, y):
        if y[0] < 0 or y[1] < 0 or y[2] < 0:
            return 0 * y

        print(t)
        # Set up based on current value of y
        y_to_sol(
            y,
            esoh_sim,
            sim_ode.op_conds_to_built_models[
                experiment_one_cycle.operating_conditions[0]["electric"]
            ],
        )

        # Simulate one cycle
        sol = sim_ode.solve()

        dy = sol_to_y(sol) - y

        return dy

    if experiment.termination == {}:
        event = None
    else:

        def capacity_cutoff(t, y):
            sol = y_to_sol(y, esoh_sim, model)
            cap = pybamm.make_cycle_solution([sol], esoh_sim, True)[1]["Capacity [A.h]"]
            return cap / cap0 - experiment_one_cycle.termination["capacity"][0] / 100

        capacity_cutoff.terminal = True

    num_cycles = len(experiment.operating_conditions_cycles)
    if save_at_cycles is None:
        t_eval = np.arange(1, num_cycles + 1)
    elif save_at_cycles == -1:
        t_eval = None
    else:
        t_eval = np.arange(1, num_cycles + 1, save_at_cycles)
    y0 = sol_to_y(sol0, loc="start")
    timer = pybamm.Timer()
    sol = solve_ivp(
        dydt,
        [1, num_cycles],
        y0,
        t_eval=t_eval,
        events=capacity_cutoff,
        first_step=10,
        method="RK23",
        atol=1e-2,
        rtol=1e-2,
    )
    time = timer.time()

    all_sumvars = []
    for idx in range(sol.y.shape[1]):
        fullsol = y_to_sol(sol.y[:, idx], esoh_sim, model)
        sumvars = pybamm.make_cycle_solution([fullsol], esoh_sim, True)[1]
        all_sumvars.append(sumvars)

    all_sumvars_dict = {
        key: np.array([sumvars[key] for sumvars in all_sumvars])
        for key in all_sumvars[0].keys()
    }
    all_sumvars_dict["Cycle number"] = sol.t
    
    all_sumvars_dict["cycles evaluated"] = sol.nfev
    all_sumvars_dict["solution time"] = time
    
    return all_sumvars_dict

# %%
def plot(all_sumvars_dict,esoh_data):
    esoh_vars = ["x_0", "y_0", "x_100", "y_100", "C_n", "C_p"]
    # esoh_vars = ["Capacity [A.h]", "Loss of lithium inventory [%]",
    #              "Loss of active material in negative electrode [%]",
    #              "Loss of active material in positive electrode [%]"]
    fig, axes = plt.subplots(3,2,figsize=(7,9))
    for k, name in enumerate(esoh_vars):
        ax = axes.flat[k]
        ax.plot(all_sumvars_dict["Cycle number"],all_sumvars_dict[name],"ro")
        ax.plot(esoh_data["N"],esoh_data[name],"kx")
#         ax.scatter(all_sumvars_dict["Cycle number"],all_sumvars_dict[name],color="r")
    #     ax.plot(long_sol.summary_variables[name],"b-")
        ax.set_title(split_long_string(name))
        if k>3:
            ax.set_xlabel("Cycle number")
    # fig.subplots_adjust(bottom=0.4)
    fig.legend(["Acc Sim"] + ["Reported"], 
           loc="lower center", ncol=1, fontsize=11)
    fig.tight_layout()
    return fig

def plot1(all_sumvars_dict,esoh_data):
    esoh_vars = ["Capacity [A.h]","n_Li"]
    esoh_data["Capacity [A.h]"]=esoh_data["Cap"]
    param = pybamm.LithiumIonParameters()
    esoh_data["n_Li"]= 3600/param.F.value*(esoh_data["y_100"]*esoh_data["C_p"]+esoh_data["x_100"]*esoh_data["C_n"])
    fig, axes = plt.subplots(2,1,figsize=(7,9))
    for k, name in enumerate(esoh_vars):
        ax = axes.flat[k]
        ax.plot(all_sumvars_dict["Cycle number"],all_sumvars_dict[name],"ro")
        ax.plot(esoh_data["N"],esoh_data[name],"kx")
        ax.set_title(split_long_string(name))
        ax.set_xlabel("Cycle number")
    fig.legend(["Acc Sim"] + ["Reported"], 
           loc="upper right", ncol=1, fontsize=11)
    fig.tight_layout()
    return fig

# %%
cell = 2

# %%
cell_no = f'{cell:02d}'
dfe=pd.read_csv(eSOH_DIR+"aging_param_cell_"+cell_no+".csv")
N =dfe.N.unique()
dfo_0=pd.read_csv(oCV_DIR+"ocv_data_cell_"+cell_no+".csv")
print("Cycle Numbers:")
print(*N, sep = ", ")
# Out:
# Cycle Numbers:
# 0, 20, 47, 57, 76, 97, 113, 135, 162, 184, 206, 228, 250, 273, 294

# %%
sei_data = []
for i in range(len(N)):
    dfo = dfo_0[dfo_0['N']==N[i]]
    # print(min(dfo['E']))
    sei_data.append(min(dfo['E']))

# %%
dfo = dfo_0[dfo_0['N']==N[0]]
# dfe_0 = dfe[dfe['N']==N[0]]
C_n_init = dfe['C_n'][0]
C_p_init = dfe['C_p'][0]
y_0_init = dfe['y_0'][0] 
c_rate_c = 'C/5'
c_rate_d = 'C/5'
dis_set = " until 3V"

# %%
dfe.N.iloc[-1]
# Out:
# 294

# %%
pybamm.set_logging_level("WARNING")
# pybamm.set_logging_level("NOTICE")
experiment = pybamm.Experiment(
    [
        ("Discharge at "+c_rate_d+dis_set,
         "Rest for 5 min",
         "Charge at "+c_rate_c+" until 4.2V", 
         "Hold at 4.2V until C/50")
    ] *dfe.N.iloc[-1],
    termination="50% capacity",
#     cccv_handling="ode",
)
spm = pybamm.lithium_ion.SPM(
    {
        "SEI": "ec reaction limited",
        # "loss of active material": ("stress-driven","none"),
        "loss of active material": "stress-driven",
        "stress-induced diffusion": "true",
        # "lithium plating": "reversible",
        # "thermal": "lumped",
        # "cell geometry": "arbitrary",
    }
)
# spm.print_parameter_info()

# %%
param = spm.param
eps_n_data = parameter_values.evaluate(C_n_init*3600/(param.L_n * param.c_n_max * param.F* param.A_cc))
eps_p_data = parameter_values.evaluate(C_p_init*3600/(param.L_p * param.c_p_max * param.F* param.A_cc))
cs_p_init = parameter_values.evaluate(y_0_init* param.c_p_max)

# %%
parameter_values = get_parameter_values()
sim_des = '_lowc'
parameter_values.update(
    {
        "SEI kinetic rate constant [m.s-1]": 1.6827e-16,
        "Positive electrode LAM constant proportional term [s-1]": 8.3569e-6,
        "Negative electrode LAM constant proportional term [s-1]": 5.8032e-5,
        "EC diffusivity [m2.s-1]": 2e-18,
        "Positive electrode LAM constant exponential term": 2,
        "Negative electrode LAM constant exponential term": 2,
        "Negative electrode active material volume fraction": eps_n_data,
        "Positive electrode active material volume fraction": eps_p_data,
        "Ambient temperature [K]": 273+25
    },
    check_already_exists=False,
)
all_sumvars_dict = cycle_adaptive_simulation(spm, parameter_values, experiment, save_at_cycles=2)
# Out:
# 1.0
# 6.0
# 8.5
# 11.0
# 61.0
# 86.0
# 111.0
# 202.5
# 248.25
# 294.0

# %%
print(all_sumvars_dict["cycles evaluated"])
print(all_sumvars_dict["solution time"])
# Out:
# 10
# 10.083 s

# %%
fig = plot(all_sumvars_dict,dfe);
fig.savefig(fig_DIR +'fast_sim_'+cell_no+'_new.png')

# %%
fig = plot1(all_sumvars_dict,dfe);
fig.savefig(fig_DIR +'fast_sim_'+cell_no+'_cap_new.png')

# %%
pybamm.set_logging_level("NOTICE")
parameter_values.update(
    {
        "SEI kinetic rate constant [m.s-1]": 1.6827e-16,
        "Positive electrode LAM constant proportional term [s-1]": 8.3569e-6,
        "Negative electrode LAM constant proportional term [s-1]": 5.8032e-5,
        "EC diffusivity [m2.s-1]": 2e-18,
        "Positive electrode LAM constant exponential term": 2,
        "Negative electrode LAM constant exponential term": 2,
        "Negative electrode active material volume fraction": eps_n_data,
        "Positive electrode active material volume fraction": eps_p_data,
        "Ambient temperature [K]": 273+25
    },
    check_already_exists=False,
)

# %%
sim_long = pybamm.Simulation(spm, experiment=experiment, parameter_values=parameter_values, 
                            solver=pybamm.CasadiSolver("safe"))
sol_long = sim_long.solve(initial_soc=1)
# Out:
# 2022-02-24 15:28:01,690 - [NOTICE] simulation.solve(855): Cycle 1/294 (60.530 ms elapsed) --------------------
# 2022-02-24 15:28:01,691 - [NOTICE] simulation.solve(889): Cycle 1/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:28:02,137 - [NOTICE] simulation.solve(889): Cycle 1/294, step 2/4: Rest for 5 min
# 2022-02-24 15:28:02,220 - [NOTICE] simulation.solve(889): Cycle 1/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:28:02,784 - [NOTICE] simulation.solve(889): Cycle 1/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:28:03,620 - [NOTICE] simulation.solve(977): Capacity is now 5.050 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:28:03,621 - [NOTICE] simulation.solve(855): Cycle 2/294 (1.991 s elapsed) --------------------
# 2022-02-24 15:28:03,621 - [NOTICE] simulation.solve(889): Cycle 2/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:28:04,090 - [NOTICE] simulation.solve(889): Cycle 2/294, step 2/4: Rest for 5 min
# 2022-02-24 15:28:04,108 - [NOTICE] simulation.solve(889): Cycle 2/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:28:04,520 - [NOTICE] simulation.solve(889): Cycle 2/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:28:04,639 - [NOTICE] simulation.solve(977): Capacity is now 5.047 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:28:04,640 - [NOTICE] simulation.solve(855): Cycle 3/294 (3.012 s elapsed) --------------------
# 2022-02-24 15:28:04,641 - [NOTICE] simulation.solve(889): Cycle 3/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:28:05,025 - [NOTICE] simulation.solve(889): Cycle 3/294, step 2/4: Rest for 5 min
# 2022-02-24 15:28:05,039 - [NOTICE] simulation.solve(889): Cycle 3/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:28:05,377 - [NOTICE] simulation.solve(889): Cycle 3/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:28:05,553 - [NOTICE] simulation.solve(977): Capacity is now 5.043 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:28:05,554 - [NOTICE] simulation.solve(855): Cycle 4/294 (3.925 s elapsed) --------------------
# 2022-02-24 15:28:05,555 - [NOTICE] simulation.solve(889): Cycle 4/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:28:06,024 - [NOTICE] simulation.solve(889): Cycle 4/294, step 2/4: Rest for 5 min
# 2022-02-24 15:28:06,038 - [NOTICE] simulation.solve(889): Cycle 4/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:28:06,491 - [NOTICE] simulation.solve(889): Cycle 4/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:28:06,595 - [NOTICE] simulation.solve(977): Capacity is now 5.040 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:28:06,597 - [NOTICE] simulation.solve(855): Cycle 5/294 (4.967 s elapsed) --------------------
# 2022-02-24 15:28:06,601 - [NOTICE] simulation.solve(889): Cycle 5/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:28:07,026 - [NOTICE] simulation.solve(889): Cycle 5/294, step 2/4: Rest for 5 min
# 2022-02-24 15:28:07,050 - [NOTICE] simulation.solve(889): Cycle 5/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:28:07,525 - [NOTICE] simulation.solve(889): Cycle 5/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:28:07,714 - [NOTICE] simulation.solve(977): Capacity is now 5.036 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:28:07,717 - [NOTICE] simulation.solve(855): Cycle 6/294 (6.088 s elapsed) --------------------
# 2022-02-24 15:28:07,720 - [NOTICE] simulation.solve(889): Cycle 6/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:28:08,345 - [NOTICE] simulation.solve(889): Cycle 6/294, step 2/4: Rest for 5 min
# 2022-02-24 15:28:08,359 - [NOTICE] simulation.solve(889): Cycle 6/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:28:08,664 - [NOTICE] simulation.solve(889): Cycle 6/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:28:08,769 - [NOTICE] simulation.solve(977): Capacity is now 5.032 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:28:08,770 - [NOTICE] simulation.solve(855): Cycle 7/294 (7.140 s elapsed) --------------------
# 2022-02-24 15:28:08,770 - [NOTICE] simulation.solve(889): Cycle 7/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:28:09,048 - [NOTICE] simulation.solve(889): Cycle 7/294, step 2/4: Rest for 5 min
# 2022-02-24 15:28:09,057 - [NOTICE] simulation.solve(889): Cycle 7/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:28:09,320 - [NOTICE] simulation.solve(889): Cycle 7/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:28:09,631 - [NOTICE] simulation.solve(977): Capacity is now 5.029 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:28:09,632 - [NOTICE] simulation.solve(855): Cycle 8/294 (8.002 s elapsed) --------------------
# 2022-02-24 15:28:09,633 - [NOTICE] simulation.solve(889): Cycle 8/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:28:10,023 - [NOTICE] simulation.solve(889): Cycle 8/294, step 2/4: Rest for 5 min
# 2022-02-24 15:28:10,033 - [NOTICE] simulation.solve(889): Cycle 8/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:28:10,334 - [NOTICE] simulation.solve(889): Cycle 8/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:28:10,424 - [NOTICE] simulation.solve(977): Capacity is now 5.025 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:28:10,425 - [NOTICE] simulation.solve(855): Cycle 9/294 (8.797 s elapsed) --------------------
# 2022-02-24 15:28:10,426 - [NOTICE] simulation.solve(889): Cycle 9/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:28:10,705 - [NOTICE] simulation.solve(889): Cycle 9/294, step 2/4: Rest for 5 min
# 2022-02-24 15:28:10,715 - [NOTICE] simulation.solve(889): Cycle 9/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:28:10,970 - [NOTICE] simulation.solve(889): Cycle 9/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:28:11,071 - [NOTICE] simulation.solve(977): Capacity is now 5.021 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:28:11,073 - [NOTICE] simulation.solve(855): Cycle 10/294 (9.444 s elapsed) --------------------
# 2022-02-24 15:28:11,073 - [NOTICE] simulation.solve(889): Cycle 10/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:28:11,351 - [NOTICE] simulation.solve(889): Cycle 10/294, step 2/4: Rest for 5 min
# 2022-02-24 15:28:11,360 - [NOTICE] simulation.solve(889): Cycle 10/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:28:11,597 - [NOTICE] simulation.solve(889): Cycle 10/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:28:11,699 - [NOTICE] simulation.solve(977): Capacity is now 5.018 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:28:11,700 - [NOTICE] simulation.solve(855): Cycle 11/294 (10.071 s elapsed) --------------------
# 2022-02-24 15:28:11,701 - [NOTICE] simulation.solve(889): Cycle 11/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:28:11,947 - [NOTICE] simulation.solve(889): Cycle 11/294, step 2/4: Rest for 5 min
# 2022-02-24 15:28:11,955 - [NOTICE] simulation.solve(889): Cycle 11/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:28:12,186 - [NOTICE] simulation.solve(889): Cycle 11/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:28:12,257 - [NOTICE] simulation.solve(977): Capacity is now 5.014 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:28:12,258 - [NOTICE] simulation.solve(855): Cycle 12/294 (10.628 s elapsed) --------------------
# 2022-02-24 15:28:12,258 - [NOTICE] simulation.solve(889): Cycle 12/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:28:12,541 - [NOTICE] simulation.solve(889): Cycle 12/294, step 2/4: Rest for 5 min
# 2022-02-24 15:28:12,551 - [NOTICE] simulation.solve(889): Cycle 12/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:28:12,801 - [NOTICE] simulation.solve(889): Cycle 12/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:28:12,910 - [NOTICE] simulation.solve(977): Capacity is now 5.010 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:28:12,911 - [NOTICE] simulation.solve(855): Cycle 13/294 (11.281 s elapsed) --------------------
# 2022-02-24 15:28:12,911 - [NOTICE] simulation.solve(889): Cycle 13/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:28:13,222 - [NOTICE] simulation.solve(889): Cycle 13/294, step 2/4: Rest for 5 min
# 2022-02-24 15:28:13,232 - [NOTICE] simulation.solve(889): Cycle 13/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:28:13,547 - [NOTICE] simulation.solve(889): Cycle 13/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:28:13,641 - [NOTICE] simulation.solve(977): Capacity is now 5.007 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:28:13,642 - [NOTICE] simulation.solve(855): Cycle 14/294 (12.013 s elapsed) --------------------
# 2022-02-24 15:28:13,642 - [NOTICE] simulation.solve(889): Cycle 14/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:28:13,927 - [NOTICE] simulation.solve(889): Cycle 14/294, step 2/4: Rest for 5 min
# 2022-02-24 15:28:13,936 - [NOTICE] simulation.solve(889): Cycle 14/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:28:14,169 - [NOTICE] simulation.solve(889): Cycle 14/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:28:14,266 - [NOTICE] simulation.solve(977): Capacity is now 5.003 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:28:14,267 - [NOTICE] simulation.solve(855): Cycle 15/294 (12.638 s elapsed) --------------------
# 2022-02-24 15:28:14,267 - [NOTICE] simulation.solve(889): Cycle 15/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:28:14,496 - [NOTICE] simulation.solve(889): Cycle 15/294, step 2/4: Rest for 5 min
# 2022-02-24 15:28:14,504 - [NOTICE] simulation.solve(889): Cycle 15/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:28:14,819 - [NOTICE] simulation.solve(889): Cycle 15/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:28:14,907 - [NOTICE] simulation.solve(977): Capacity is now 4.999 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:28:14,908 - [NOTICE] simulation.solve(855): Cycle 16/294 (13.278 s elapsed) --------------------
# 2022-02-24 15:28:14,908 - [NOTICE] simulation.solve(889): Cycle 16/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:28:15,154 - [NOTICE] simulation.solve(889): Cycle 16/294, step 2/4: Rest for 5 min
# 2022-02-24 15:28:15,163 - [NOTICE] simulation.solve(889): Cycle 16/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:28:15,372 - [NOTICE] simulation.solve(889): Cycle 16/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:28:15,468 - [NOTICE] simulation.solve(977): Capacity is now 4.995 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:28:15,469 - [NOTICE] simulation.solve(855): Cycle 17/294 (13.840 s elapsed) --------------------
# 2022-02-24 15:28:15,469 - [NOTICE] simulation.solve(889): Cycle 17/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:28:15,690 - [NOTICE] simulation.solve(889): Cycle 17/294, step 2/4: Rest for 5 min
# 2022-02-24 15:28:15,699 - [NOTICE] simulation.solve(889): Cycle 17/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:28:15,927 - [NOTICE] simulation.solve(889): Cycle 17/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:28:16,018 - [NOTICE] simulation.solve(977): Capacity is now 4.992 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:28:16,018 - [NOTICE] simulation.solve(855): Cycle 18/294 (14.389 s elapsed) --------------------
# 2022-02-24 15:28:16,019 - [NOTICE] simulation.solve(889): Cycle 18/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:28:16,277 - [NOTICE] simulation.solve(889): Cycle 18/294, step 2/4: Rest for 5 min
# 2022-02-24 15:28:16,286 - [NOTICE] simulation.solve(889): Cycle 18/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:28:16,527 - [NOTICE] simulation.solve(889): Cycle 18/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:28:16,635 - [NOTICE] simulation.solve(977): Capacity is now 4.988 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:28:16,636 - [NOTICE] simulation.solve(855): Cycle 19/294 (15.008 s elapsed) --------------------
# 2022-02-24 15:28:16,637 - [NOTICE] simulation.solve(889): Cycle 19/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:28:16,893 - [NOTICE] simulation.solve(889): Cycle 19/294, step 2/4: Rest for 5 min
# 2022-02-24 15:28:16,903 - [NOTICE] simulation.solve(889): Cycle 19/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:28:17,149 - [NOTICE] simulation.solve(889): Cycle 19/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:28:17,233 - [NOTICE] simulation.solve(977): Capacity is now 4.984 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:28:17,234 - [NOTICE] simulation.solve(855): Cycle 20/294 (15.604 s elapsed) --------------------
# 2022-02-24 15:28:17,234 - [NOTICE] simulation.solve(889): Cycle 20/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:28:17,521 - [NOTICE] simulation.solve(889): Cycle 20/294, step 2/4: Rest for 5 min
# 2022-02-24 15:28:17,533 - [NOTICE] simulation.solve(889): Cycle 20/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:28:17,790 - [NOTICE] simulation.solve(889): Cycle 20/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:28:17,884 - [NOTICE] simulation.solve(977): Capacity is now 4.980 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:28:17,885 - [NOTICE] simulation.solve(855): Cycle 21/294 (16.256 s elapsed) --------------------
# 2022-02-24 15:28:17,886 - [NOTICE] simulation.solve(889): Cycle 21/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:28:18,179 - [NOTICE] simulation.solve(889): Cycle 21/294, step 2/4: Rest for 5 min
# 2022-02-24 15:28:18,190 - [NOTICE] simulation.solve(889): Cycle 21/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:28:18,453 - [NOTICE] simulation.solve(889): Cycle 21/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:28:18,542 - [NOTICE] simulation.solve(977): Capacity is now 4.977 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:28:18,542 - [NOTICE] simulation.solve(855): Cycle 22/294 (16.913 s elapsed) --------------------
# 2022-02-24 15:28:18,543 - [NOTICE] simulation.solve(889): Cycle 22/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:28:18,802 - [NOTICE] simulation.solve(889): Cycle 22/294, step 2/4: Rest for 5 min
# 2022-02-24 15:28:18,811 - [NOTICE] simulation.solve(889): Cycle 22/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:28:19,075 - [NOTICE] simulation.solve(889): Cycle 22/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:28:19,170 - [NOTICE] simulation.solve(977): Capacity is now 4.973 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:28:19,171 - [NOTICE] simulation.solve(855): Cycle 23/294 (17.542 s elapsed) --------------------
# 2022-02-24 15:28:19,171 - [NOTICE] simulation.solve(889): Cycle 23/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:28:19,411 - [NOTICE] simulation.solve(889): Cycle 23/294, step 2/4: Rest for 5 min
# 2022-02-24 15:28:19,420 - [NOTICE] simulation.solve(889): Cycle 23/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:28:19,673 - [NOTICE] simulation.solve(889): Cycle 23/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:28:19,755 - [NOTICE] simulation.solve(977): Capacity is now 4.969 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:28:19,756 - [NOTICE] simulation.solve(855): Cycle 24/294 (18.127 s elapsed) --------------------
# 2022-02-24 15:28:19,757 - [NOTICE] simulation.solve(889): Cycle 24/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:28:20,003 - [NOTICE] simulation.solve(889): Cycle 24/294, step 2/4: Rest for 5 min
# 2022-02-24 15:28:20,011 - [NOTICE] simulation.solve(889): Cycle 24/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:28:20,267 - [NOTICE] simulation.solve(889): Cycle 24/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:28:20,343 - [NOTICE] simulation.solve(977): Capacity is now 4.965 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:28:20,344 - [NOTICE] simulation.solve(855): Cycle 25/294 (18.714 s elapsed) --------------------
# 2022-02-24 15:28:20,344 - [NOTICE] simulation.solve(889): Cycle 25/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:28:20,563 - [NOTICE] simulation.solve(889): Cycle 25/294, step 2/4: Rest for 5 min
# 2022-02-24 15:28:20,574 - [NOTICE] simulation.solve(889): Cycle 25/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:28:20,809 - [NOTICE] simulation.solve(889): Cycle 25/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:28:20,953 - [NOTICE] simulation.solve(977): Capacity is now 4.962 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:28:20,958 - [NOTICE] simulation.solve(855): Cycle 26/294 (19.329 s elapsed) --------------------
# 2022-02-24 15:28:20,959 - [NOTICE] simulation.solve(889): Cycle 26/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:28:21,332 - [NOTICE] simulation.solve(889): Cycle 26/294, step 2/4: Rest for 5 min
# 2022-02-24 15:28:21,341 - [NOTICE] simulation.solve(889): Cycle 26/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:28:21,619 - [NOTICE] simulation.solve(889): Cycle 26/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:28:21,707 - [NOTICE] simulation.solve(977): Capacity is now 4.961 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:28:21,709 - [NOTICE] simulation.solve(855): Cycle 27/294 (20.081 s elapsed) --------------------
# 2022-02-24 15:28:21,712 - [NOTICE] simulation.solve(889): Cycle 27/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:28:21,944 - [NOTICE] simulation.solve(889): Cycle 27/294, step 2/4: Rest for 5 min
# 2022-02-24 15:28:21,955 - [NOTICE] simulation.solve(889): Cycle 27/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:28:22,205 - [NOTICE] simulation.solve(889): Cycle 27/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:28:22,285 - [NOTICE] simulation.solve(977): Capacity is now 4.954 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:28:22,285 - [NOTICE] simulation.solve(855): Cycle 28/294 (20.656 s elapsed) --------------------
# 2022-02-24 15:28:22,286 - [NOTICE] simulation.solve(889): Cycle 28/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:28:22,537 - [NOTICE] simulation.solve(889): Cycle 28/294, step 2/4: Rest for 5 min
# 2022-02-24 15:28:22,546 - [NOTICE] simulation.solve(889): Cycle 28/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:28:22,851 - [NOTICE] simulation.solve(889): Cycle 28/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:28:22,939 - [NOTICE] simulation.solve(977): Capacity is now 4.953 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:28:22,940 - [NOTICE] simulation.solve(855): Cycle 29/294 (21.311 s elapsed) --------------------
# 2022-02-24 15:28:22,941 - [NOTICE] simulation.solve(889): Cycle 29/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:28:23,251 - [NOTICE] simulation.solve(889): Cycle 29/294, step 2/4: Rest for 5 min
# 2022-02-24 15:28:23,262 - [NOTICE] simulation.solve(889): Cycle 29/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:28:23,766 - [NOTICE] simulation.solve(889): Cycle 29/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:28:23,844 - [NOTICE] simulation.solve(977): Capacity is now 4.946 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:28:23,845 - [NOTICE] simulation.solve(855): Cycle 30/294 (22.216 s elapsed) --------------------
# 2022-02-24 15:28:23,846 - [NOTICE] simulation.solve(889): Cycle 30/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:28:24,073 - [NOTICE] simulation.solve(889): Cycle 30/294, step 2/4: Rest for 5 min
# 2022-02-24 15:28:24,081 - [NOTICE] simulation.solve(889): Cycle 30/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:28:24,339 - [NOTICE] simulation.solve(889): Cycle 30/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:28:24,423 - [NOTICE] simulation.solve(977): Capacity is now 4.946 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:28:24,424 - [NOTICE] simulation.solve(855): Cycle 31/294 (22.795 s elapsed) --------------------
# 2022-02-24 15:28:24,425 - [NOTICE] simulation.solve(889): Cycle 31/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:28:24,681 - [NOTICE] simulation.solve(889): Cycle 31/294, step 2/4: Rest for 5 min
# 2022-02-24 15:28:24,689 - [NOTICE] simulation.solve(889): Cycle 31/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:28:24,908 - [NOTICE] simulation.solve(889): Cycle 31/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:28:24,998 - [NOTICE] simulation.solve(977): Capacity is now 4.939 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:28:24,998 - [NOTICE] simulation.solve(855): Cycle 32/294 (23.369 s elapsed) --------------------
# 2022-02-24 15:28:24,999 - [NOTICE] simulation.solve(889): Cycle 32/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:28:25,221 - [NOTICE] simulation.solve(889): Cycle 32/294, step 2/4: Rest for 5 min
# 2022-02-24 15:28:25,231 - [NOTICE] simulation.solve(889): Cycle 32/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:28:25,495 - [NOTICE] simulation.solve(889): Cycle 32/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:28:25,598 - [NOTICE] simulation.solve(977): Capacity is now 4.938 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:28:25,599 - [NOTICE] simulation.solve(855): Cycle 33/294 (23.970 s elapsed) --------------------
# 2022-02-24 15:28:25,599 - [NOTICE] simulation.solve(889): Cycle 33/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:28:25,825 - [NOTICE] simulation.solve(889): Cycle 33/294, step 2/4: Rest for 5 min
# 2022-02-24 15:28:25,835 - [NOTICE] simulation.solve(889): Cycle 33/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:28:26,086 - [NOTICE] simulation.solve(889): Cycle 33/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:28:26,182 - [NOTICE] simulation.solve(977): Capacity is now 4.931 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:28:26,183 - [NOTICE] simulation.solve(855): Cycle 34/294 (24.553 s elapsed) --------------------
# 2022-02-24 15:28:26,184 - [NOTICE] simulation.solve(889): Cycle 34/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:28:26,419 - [NOTICE] simulation.solve(889): Cycle 34/294, step 2/4: Rest for 5 min
# 2022-02-24 15:28:26,427 - [NOTICE] simulation.solve(889): Cycle 34/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:28:26,659 - [NOTICE] simulation.solve(889): Cycle 34/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:28:26,749 - [NOTICE] simulation.solve(977): Capacity is now 4.930 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:28:26,749 - [NOTICE] simulation.solve(855): Cycle 35/294 (25.120 s elapsed) --------------------
# 2022-02-24 15:28:26,750 - [NOTICE] simulation.solve(889): Cycle 35/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:28:26,994 - [NOTICE] simulation.solve(889): Cycle 35/294, step 2/4: Rest for 5 min
# 2022-02-24 15:28:27,003 - [NOTICE] simulation.solve(889): Cycle 35/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:28:27,222 - [NOTICE] simulation.solve(889): Cycle 35/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:28:27,305 - [NOTICE] simulation.solve(977): Capacity is now 4.924 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:28:27,306 - [NOTICE] simulation.solve(855): Cycle 36/294 (25.677 s elapsed) --------------------
# 2022-02-24 15:28:27,307 - [NOTICE] simulation.solve(889): Cycle 36/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:28:27,563 - [NOTICE] simulation.solve(889): Cycle 36/294, step 2/4: Rest for 5 min
# 2022-02-24 15:28:27,578 - [NOTICE] simulation.solve(889): Cycle 36/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:28:27,864 - [NOTICE] simulation.solve(889): Cycle 36/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:28:27,958 - [NOTICE] simulation.solve(977): Capacity is now 4.922 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:28:27,959 - [NOTICE] simulation.solve(855): Cycle 37/294 (26.330 s elapsed) --------------------
# 2022-02-24 15:28:27,959 - [NOTICE] simulation.solve(889): Cycle 37/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:28:28,206 - [NOTICE] simulation.solve(889): Cycle 37/294, step 2/4: Rest for 5 min
# 2022-02-24 15:28:28,218 - [NOTICE] simulation.solve(889): Cycle 37/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:28:28,553 - [NOTICE] simulation.solve(889): Cycle 37/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:28:28,653 - [NOTICE] simulation.solve(977): Capacity is now 4.916 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:28:28,653 - [NOTICE] simulation.solve(855): Cycle 38/294 (27.024 s elapsed) --------------------
# 2022-02-24 15:28:28,656 - [NOTICE] simulation.solve(889): Cycle 38/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:28:28,890 - [NOTICE] simulation.solve(889): Cycle 38/294, step 2/4: Rest for 5 min
# 2022-02-24 15:28:28,899 - [NOTICE] simulation.solve(889): Cycle 38/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:28:29,148 - [NOTICE] simulation.solve(889): Cycle 38/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:28:29,240 - [NOTICE] simulation.solve(977): Capacity is now 4.914 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:28:29,240 - [NOTICE] simulation.solve(855): Cycle 39/294 (27.611 s elapsed) --------------------
# 2022-02-24 15:28:29,241 - [NOTICE] simulation.solve(889): Cycle 39/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:28:29,477 - [NOTICE] simulation.solve(889): Cycle 39/294, step 2/4: Rest for 5 min
# 2022-02-24 15:28:29,488 - [NOTICE] simulation.solve(889): Cycle 39/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:28:29,784 - [NOTICE] simulation.solve(889): Cycle 39/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:28:29,878 - [NOTICE] simulation.solve(977): Capacity is now 4.908 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:28:29,879 - [NOTICE] simulation.solve(855): Cycle 40/294 (28.249 s elapsed) --------------------
# 2022-02-24 15:28:29,880 - [NOTICE] simulation.solve(889): Cycle 40/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:28:30,160 - [NOTICE] simulation.solve(889): Cycle 40/294, step 2/4: Rest for 5 min
# 2022-02-24 15:28:30,174 - [NOTICE] simulation.solve(889): Cycle 40/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:28:30,389 - [NOTICE] simulation.solve(889): Cycle 40/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:28:30,459 - [NOTICE] simulation.solve(977): Capacity is now 4.907 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:28:30,460 - [NOTICE] simulation.solve(855): Cycle 41/294 (28.831 s elapsed) --------------------
# 2022-02-24 15:28:30,461 - [NOTICE] simulation.solve(889): Cycle 41/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:28:30,755 - [NOTICE] simulation.solve(889): Cycle 41/294, step 2/4: Rest for 5 min
# 2022-02-24 15:28:30,767 - [NOTICE] simulation.solve(889): Cycle 41/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:28:30,981 - [NOTICE] simulation.solve(889): Cycle 41/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:28:31,057 - [NOTICE] simulation.solve(977): Capacity is now 4.901 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:28:31,058 - [NOTICE] simulation.solve(855): Cycle 42/294 (29.429 s elapsed) --------------------
# 2022-02-24 15:28:31,059 - [NOTICE] simulation.solve(889): Cycle 42/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:28:31,346 - [NOTICE] simulation.solve(889): Cycle 42/294, step 2/4: Rest for 5 min
# 2022-02-24 15:28:31,356 - [NOTICE] simulation.solve(889): Cycle 42/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:28:31,588 - [NOTICE] simulation.solve(889): Cycle 42/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:28:31,675 - [NOTICE] simulation.solve(977): Capacity is now 4.899 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:28:31,679 - [NOTICE] simulation.solve(855): Cycle 43/294 (30.050 s elapsed) --------------------
# 2022-02-24 15:28:31,681 - [NOTICE] simulation.solve(889): Cycle 43/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:28:31,960 - [NOTICE] simulation.solve(889): Cycle 43/294, step 2/4: Rest for 5 min
# 2022-02-24 15:28:31,969 - [NOTICE] simulation.solve(889): Cycle 43/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:28:32,195 - [NOTICE] simulation.solve(889): Cycle 43/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:28:32,284 - [NOTICE] simulation.solve(977): Capacity is now 4.895 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:28:32,286 - [NOTICE] simulation.solve(855): Cycle 44/294 (30.657 s elapsed) --------------------
# 2022-02-24 15:28:32,288 - [NOTICE] simulation.solve(889): Cycle 44/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:28:32,516 - [NOTICE] simulation.solve(889): Cycle 44/294, step 2/4: Rest for 5 min
# 2022-02-24 15:28:32,526 - [NOTICE] simulation.solve(889): Cycle 44/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:28:32,818 - [NOTICE] simulation.solve(889): Cycle 44/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:28:32,909 - [NOTICE] simulation.solve(977): Capacity is now 4.891 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:28:32,910 - [NOTICE] simulation.solve(855): Cycle 45/294 (31.281 s elapsed) --------------------
# 2022-02-24 15:28:32,915 - [NOTICE] simulation.solve(889): Cycle 45/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:28:33,155 - [NOTICE] simulation.solve(889): Cycle 45/294, step 2/4: Rest for 5 min
# 2022-02-24 15:28:33,166 - [NOTICE] simulation.solve(889): Cycle 45/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:28:33,439 - [NOTICE] simulation.solve(889): Cycle 45/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:28:33,567 - [NOTICE] simulation.solve(977): Capacity is now 4.887 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:28:33,571 - [NOTICE] simulation.solve(855): Cycle 46/294 (31.941 s elapsed) --------------------
# 2022-02-24 15:28:33,572 - [NOTICE] simulation.solve(889): Cycle 46/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:28:33,834 - [NOTICE] simulation.solve(889): Cycle 46/294, step 2/4: Rest for 5 min
# 2022-02-24 15:28:33,843 - [NOTICE] simulation.solve(889): Cycle 46/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:28:34,077 - [NOTICE] simulation.solve(889): Cycle 46/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:28:34,164 - [NOTICE] simulation.solve(977): Capacity is now 4.883 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:28:34,164 - [NOTICE] simulation.solve(855): Cycle 47/294 (32.536 s elapsed) --------------------
# 2022-02-24 15:28:34,165 - [NOTICE] simulation.solve(889): Cycle 47/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:28:34,443 - [NOTICE] simulation.solve(889): Cycle 47/294, step 2/4: Rest for 5 min
# 2022-02-24 15:28:34,453 - [NOTICE] simulation.solve(889): Cycle 47/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:28:34,732 - [NOTICE] simulation.solve(889): Cycle 47/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:28:34,828 - [NOTICE] simulation.solve(977): Capacity is now 4.880 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:28:34,830 - [NOTICE] simulation.solve(855): Cycle 48/294 (33.201 s elapsed) --------------------
# 2022-02-24 15:28:34,832 - [NOTICE] simulation.solve(889): Cycle 48/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:28:35,103 - [NOTICE] simulation.solve(889): Cycle 48/294, step 2/4: Rest for 5 min
# 2022-02-24 15:28:35,112 - [NOTICE] simulation.solve(889): Cycle 48/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:28:35,401 - [NOTICE] simulation.solve(889): Cycle 48/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:28:35,518 - [NOTICE] simulation.solve(977): Capacity is now 4.876 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:28:35,518 - [NOTICE] simulation.solve(855): Cycle 49/294 (33.889 s elapsed) --------------------
# 2022-02-24 15:28:35,519 - [NOTICE] simulation.solve(889): Cycle 49/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:28:35,742 - [NOTICE] simulation.solve(889): Cycle 49/294, step 2/4: Rest for 5 min
# 2022-02-24 15:28:35,751 - [NOTICE] simulation.solve(889): Cycle 49/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:28:36,012 - [NOTICE] simulation.solve(889): Cycle 49/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:28:36,112 - [NOTICE] simulation.solve(977): Capacity is now 4.872 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:28:36,113 - [NOTICE] simulation.solve(855): Cycle 50/294 (34.483 s elapsed) --------------------
# 2022-02-24 15:28:36,114 - [NOTICE] simulation.solve(889): Cycle 50/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:28:36,355 - [NOTICE] simulation.solve(889): Cycle 50/294, step 2/4: Rest for 5 min
# 2022-02-24 15:28:36,365 - [NOTICE] simulation.solve(889): Cycle 50/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:28:36,596 - [NOTICE] simulation.solve(889): Cycle 50/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:28:36,712 - [NOTICE] simulation.solve(977): Capacity is now 4.868 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:28:36,713 - [NOTICE] simulation.solve(855): Cycle 51/294 (35.084 s elapsed) --------------------
# 2022-02-24 15:28:36,720 - [NOTICE] simulation.solve(889): Cycle 51/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:28:37,159 - [NOTICE] simulation.solve(889): Cycle 51/294, step 2/4: Rest for 5 min
# 2022-02-24 15:28:37,171 - [NOTICE] simulation.solve(889): Cycle 51/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:28:37,482 - [NOTICE] simulation.solve(889): Cycle 51/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:28:37,588 - [NOTICE] simulation.solve(977): Capacity is now 4.864 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:28:37,589 - [NOTICE] simulation.solve(855): Cycle 52/294 (35.960 s elapsed) --------------------
# 2022-02-24 15:28:37,589 - [NOTICE] simulation.solve(889): Cycle 52/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:28:37,830 - [NOTICE] simulation.solve(889): Cycle 52/294, step 2/4: Rest for 5 min
# 2022-02-24 15:28:37,838 - [NOTICE] simulation.solve(889): Cycle 52/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:28:38,067 - [NOTICE] simulation.solve(889): Cycle 52/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:28:38,199 - [NOTICE] simulation.solve(977): Capacity is now 4.860 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:28:38,200 - [NOTICE] simulation.solve(855): Cycle 53/294 (36.571 s elapsed) --------------------
# 2022-02-24 15:28:38,200 - [NOTICE] simulation.solve(889): Cycle 53/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:28:38,480 - [NOTICE] simulation.solve(889): Cycle 53/294, step 2/4: Rest for 5 min
# 2022-02-24 15:28:38,490 - [NOTICE] simulation.solve(889): Cycle 53/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:28:38,767 - [NOTICE] simulation.solve(889): Cycle 53/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:28:38,860 - [NOTICE] simulation.solve(977): Capacity is now 4.856 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:28:38,861 - [NOTICE] simulation.solve(855): Cycle 54/294 (37.232 s elapsed) --------------------
# 2022-02-24 15:28:38,863 - [NOTICE] simulation.solve(889): Cycle 54/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:28:39,145 - [NOTICE] simulation.solve(889): Cycle 54/294, step 2/4: Rest for 5 min
# 2022-02-24 15:28:39,154 - [NOTICE] simulation.solve(889): Cycle 54/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:28:39,380 - [NOTICE] simulation.solve(889): Cycle 54/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:28:39,469 - [NOTICE] simulation.solve(977): Capacity is now 4.853 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:28:39,470 - [NOTICE] simulation.solve(855): Cycle 55/294 (37.840 s elapsed) --------------------
# 2022-02-24 15:28:39,470 - [NOTICE] simulation.solve(889): Cycle 55/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:28:39,750 - [NOTICE] simulation.solve(889): Cycle 55/294, step 2/4: Rest for 5 min
# 2022-02-24 15:28:39,763 - [NOTICE] simulation.solve(889): Cycle 55/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:28:40,032 - [NOTICE] simulation.solve(889): Cycle 55/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:28:40,158 - [NOTICE] simulation.solve(977): Capacity is now 4.849 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:28:40,158 - [NOTICE] simulation.solve(855): Cycle 56/294 (38.529 s elapsed) --------------------
# 2022-02-24 15:28:40,159 - [NOTICE] simulation.solve(889): Cycle 56/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:28:40,423 - [NOTICE] simulation.solve(889): Cycle 56/294, step 2/4: Rest for 5 min
# 2022-02-24 15:28:40,434 - [NOTICE] simulation.solve(889): Cycle 56/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:28:40,673 - [NOTICE] simulation.solve(889): Cycle 56/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:28:40,748 - [NOTICE] simulation.solve(977): Capacity is now 4.845 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:28:40,748 - [NOTICE] simulation.solve(855): Cycle 57/294 (39.119 s elapsed) --------------------
# 2022-02-24 15:28:40,749 - [NOTICE] simulation.solve(889): Cycle 57/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:28:41,292 - [NOTICE] simulation.solve(889): Cycle 57/294, step 2/4: Rest for 5 min
# 2022-02-24 15:28:41,304 - [NOTICE] simulation.solve(889): Cycle 57/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:28:41,540 - [NOTICE] simulation.solve(889): Cycle 57/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:28:41,620 - [NOTICE] simulation.solve(977): Capacity is now 4.841 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:28:41,621 - [NOTICE] simulation.solve(855): Cycle 58/294 (39.992 s elapsed) --------------------
# 2022-02-24 15:28:41,622 - [NOTICE] simulation.solve(889): Cycle 58/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:28:41,849 - [NOTICE] simulation.solve(889): Cycle 58/294, step 2/4: Rest for 5 min
# 2022-02-24 15:28:41,862 - [NOTICE] simulation.solve(889): Cycle 58/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:28:42,122 - [NOTICE] simulation.solve(889): Cycle 58/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:28:42,208 - [NOTICE] simulation.solve(977): Capacity is now 4.837 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:28:42,209 - [NOTICE] simulation.solve(855): Cycle 59/294 (40.580 s elapsed) --------------------
# 2022-02-24 15:28:42,210 - [NOTICE] simulation.solve(889): Cycle 59/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:28:42,456 - [NOTICE] simulation.solve(889): Cycle 59/294, step 2/4: Rest for 5 min
# 2022-02-24 15:28:42,465 - [NOTICE] simulation.solve(889): Cycle 59/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:28:42,730 - [NOTICE] simulation.solve(889): Cycle 59/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:28:42,824 - [NOTICE] simulation.solve(977): Capacity is now 4.833 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:28:42,825 - [NOTICE] simulation.solve(855): Cycle 60/294 (41.196 s elapsed) --------------------
# 2022-02-24 15:28:42,826 - [NOTICE] simulation.solve(889): Cycle 60/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:28:43,069 - [NOTICE] simulation.solve(889): Cycle 60/294, step 2/4: Rest for 5 min
# 2022-02-24 15:28:43,079 - [NOTICE] simulation.solve(889): Cycle 60/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:28:43,309 - [NOTICE] simulation.solve(889): Cycle 60/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:28:43,449 - [NOTICE] simulation.solve(977): Capacity is now 4.830 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:28:43,450 - [NOTICE] simulation.solve(855): Cycle 61/294 (41.821 s elapsed) --------------------
# 2022-02-24 15:28:43,451 - [NOTICE] simulation.solve(889): Cycle 61/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:28:43,784 - [NOTICE] simulation.solve(889): Cycle 61/294, step 2/4: Rest for 5 min
# 2022-02-24 15:28:43,796 - [NOTICE] simulation.solve(889): Cycle 61/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:28:44,045 - [NOTICE] simulation.solve(889): Cycle 61/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:28:44,156 - [NOTICE] simulation.solve(977): Capacity is now 4.826 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:28:44,157 - [NOTICE] simulation.solve(855): Cycle 62/294 (42.528 s elapsed) --------------------
# 2022-02-24 15:28:44,158 - [NOTICE] simulation.solve(889): Cycle 62/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:28:44,458 - [NOTICE] simulation.solve(889): Cycle 62/294, step 2/4: Rest for 5 min
# 2022-02-24 15:28:44,470 - [NOTICE] simulation.solve(889): Cycle 62/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:28:44,761 - [NOTICE] simulation.solve(889): Cycle 62/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:28:44,884 - [NOTICE] simulation.solve(977): Capacity is now 4.822 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:28:44,885 - [NOTICE] simulation.solve(855): Cycle 63/294 (43.256 s elapsed) --------------------
# 2022-02-24 15:28:44,885 - [NOTICE] simulation.solve(889): Cycle 63/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:28:45,157 - [NOTICE] simulation.solve(889): Cycle 63/294, step 2/4: Rest for 5 min
# 2022-02-24 15:28:45,169 - [NOTICE] simulation.solve(889): Cycle 63/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:28:45,431 - [NOTICE] simulation.solve(889): Cycle 63/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:28:45,517 - [NOTICE] simulation.solve(977): Capacity is now 4.818 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:28:45,518 - [NOTICE] simulation.solve(855): Cycle 64/294 (43.889 s elapsed) --------------------
# 2022-02-24 15:28:45,520 - [NOTICE] simulation.solve(889): Cycle 64/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:28:45,772 - [NOTICE] simulation.solve(889): Cycle 64/294, step 2/4: Rest for 5 min
# 2022-02-24 15:28:45,783 - [NOTICE] simulation.solve(889): Cycle 64/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:28:45,995 - [NOTICE] simulation.solve(889): Cycle 64/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:28:46,087 - [NOTICE] simulation.solve(977): Capacity is now 4.814 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:28:46,088 - [NOTICE] simulation.solve(855): Cycle 65/294 (44.459 s elapsed) --------------------
# 2022-02-24 15:28:46,092 - [NOTICE] simulation.solve(889): Cycle 65/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:28:46,363 - [NOTICE] simulation.solve(889): Cycle 65/294, step 2/4: Rest for 5 min
# 2022-02-24 15:28:46,373 - [NOTICE] simulation.solve(889): Cycle 65/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:28:46,635 - [NOTICE] simulation.solve(889): Cycle 65/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:28:46,717 - [NOTICE] simulation.solve(977): Capacity is now 4.810 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:28:46,719 - [NOTICE] simulation.solve(855): Cycle 66/294 (45.090 s elapsed) --------------------
# 2022-02-24 15:28:46,720 - [NOTICE] simulation.solve(889): Cycle 66/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:28:46,988 - [NOTICE] simulation.solve(889): Cycle 66/294, step 2/4: Rest for 5 min
# 2022-02-24 15:28:47,000 - [NOTICE] simulation.solve(889): Cycle 66/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:28:47,210 - [NOTICE] simulation.solve(889): Cycle 66/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:28:47,291 - [NOTICE] simulation.solve(977): Capacity is now 4.807 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:28:47,291 - [NOTICE] simulation.solve(855): Cycle 67/294 (45.663 s elapsed) --------------------
# 2022-02-24 15:28:47,292 - [NOTICE] simulation.solve(889): Cycle 67/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:28:47,537 - [NOTICE] simulation.solve(889): Cycle 67/294, step 2/4: Rest for 5 min
# 2022-02-24 15:28:47,546 - [NOTICE] simulation.solve(889): Cycle 67/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:28:47,791 - [NOTICE] simulation.solve(889): Cycle 67/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:28:47,899 - [NOTICE] simulation.solve(977): Capacity is now 4.803 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:28:47,900 - [NOTICE] simulation.solve(855): Cycle 68/294 (46.272 s elapsed) --------------------
# 2022-02-24 15:28:47,901 - [NOTICE] simulation.solve(889): Cycle 68/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:28:48,120 - [NOTICE] simulation.solve(889): Cycle 68/294, step 2/4: Rest for 5 min
# 2022-02-24 15:28:48,130 - [NOTICE] simulation.solve(889): Cycle 68/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:28:48,338 - [NOTICE] simulation.solve(889): Cycle 68/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:28:48,423 - [NOTICE] simulation.solve(977): Capacity is now 4.799 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:28:48,424 - [NOTICE] simulation.solve(855): Cycle 69/294 (46.795 s elapsed) --------------------
# 2022-02-24 15:28:48,425 - [NOTICE] simulation.solve(889): Cycle 69/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:28:48,685 - [NOTICE] simulation.solve(889): Cycle 69/294, step 2/4: Rest for 5 min
# 2022-02-24 15:28:48,697 - [NOTICE] simulation.solve(889): Cycle 69/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:28:48,961 - [NOTICE] simulation.solve(889): Cycle 69/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:28:49,074 - [NOTICE] simulation.solve(977): Capacity is now 4.795 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:28:49,075 - [NOTICE] simulation.solve(855): Cycle 70/294 (47.445 s elapsed) --------------------
# 2022-02-24 15:28:49,075 - [NOTICE] simulation.solve(889): Cycle 70/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:28:49,358 - [NOTICE] simulation.solve(889): Cycle 70/294, step 2/4: Rest for 5 min
# 2022-02-24 15:28:49,376 - [NOTICE] simulation.solve(889): Cycle 70/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:28:49,638 - [NOTICE] simulation.solve(889): Cycle 70/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:28:49,754 - [NOTICE] simulation.solve(977): Capacity is now 4.791 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:28:49,755 - [NOTICE] simulation.solve(855): Cycle 71/294 (48.126 s elapsed) --------------------
# 2022-02-24 15:28:49,756 - [NOTICE] simulation.solve(889): Cycle 71/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:28:50,058 - [NOTICE] simulation.solve(889): Cycle 71/294, step 2/4: Rest for 5 min
# 2022-02-24 15:28:50,074 - [NOTICE] simulation.solve(889): Cycle 71/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:28:50,339 - [NOTICE] simulation.solve(889): Cycle 71/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:28:50,421 - [NOTICE] simulation.solve(977): Capacity is now 4.788 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:28:50,422 - [NOTICE] simulation.solve(855): Cycle 72/294 (48.794 s elapsed) --------------------
# 2022-02-24 15:28:50,423 - [NOTICE] simulation.solve(889): Cycle 72/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:28:50,702 - [NOTICE] simulation.solve(889): Cycle 72/294, step 2/4: Rest for 5 min
# 2022-02-24 15:28:50,710 - [NOTICE] simulation.solve(889): Cycle 72/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:28:50,964 - [NOTICE] simulation.solve(889): Cycle 72/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:28:51,086 - [NOTICE] simulation.solve(977): Capacity is now 4.784 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:28:51,087 - [NOTICE] simulation.solve(855): Cycle 73/294 (49.458 s elapsed) --------------------
# 2022-02-24 15:28:51,087 - [NOTICE] simulation.solve(889): Cycle 73/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:28:51,359 - [NOTICE] simulation.solve(889): Cycle 73/294, step 2/4: Rest for 5 min
# 2022-02-24 15:28:51,369 - [NOTICE] simulation.solve(889): Cycle 73/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:28:51,685 - [NOTICE] simulation.solve(889): Cycle 73/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:28:51,786 - [NOTICE] simulation.solve(977): Capacity is now 4.780 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# ...
# 2022-02-24 15:31:01,452 - [NOTICE] simulation.solve(889): Cycle 271/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:31:01,709 - [NOTICE] simulation.solve(889): Cycle 271/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:31:01,842 - [NOTICE] simulation.solve(977): Capacity is now 4.049 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:31:01,843 - [NOTICE] simulation.solve(855): Cycle 272/294 (3 minutes, 0 seconds elapsed) --------------------
# 2022-02-24 15:31:01,843 - [NOTICE] simulation.solve(889): Cycle 272/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:31:02,081 - [NOTICE] simulation.solve(889): Cycle 272/294, step 2/4: Rest for 5 min
# 2022-02-24 15:31:02,091 - [NOTICE] simulation.solve(889): Cycle 272/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:31:02,329 - [NOTICE] simulation.solve(889): Cycle 272/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:31:02,449 - [NOTICE] simulation.solve(977): Capacity is now 4.045 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:31:02,450 - [NOTICE] simulation.solve(855): Cycle 273/294 (3 minutes, 1 second elapsed) --------------------
# 2022-02-24 15:31:02,450 - [NOTICE] simulation.solve(889): Cycle 273/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:31:02,781 - [NOTICE] simulation.solve(889): Cycle 273/294, step 2/4: Rest for 5 min
# 2022-02-24 15:31:02,793 - [NOTICE] simulation.solve(889): Cycle 273/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:31:03,068 - [NOTICE] simulation.solve(889): Cycle 273/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:31:03,198 - [NOTICE] simulation.solve(977): Capacity is now 4.042 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:31:03,199 - [NOTICE] simulation.solve(855): Cycle 274/294 (3 minutes, 2 seconds elapsed) --------------------
# 2022-02-24 15:31:03,199 - [NOTICE] simulation.solve(889): Cycle 274/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:31:03,399 - [NOTICE] simulation.solve(889): Cycle 274/294, step 2/4: Rest for 5 min
# 2022-02-24 15:31:03,408 - [NOTICE] simulation.solve(889): Cycle 274/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:31:03,606 - [NOTICE] simulation.solve(889): Cycle 274/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:31:03,726 - [NOTICE] simulation.solve(977): Capacity is now 4.038 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:31:03,738 - [NOTICE] simulation.solve(855): Cycle 275/294 (3 minutes, 2 seconds elapsed) --------------------
# 2022-02-24 15:31:03,739 - [NOTICE] simulation.solve(889): Cycle 275/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:31:03,998 - [NOTICE] simulation.solve(889): Cycle 275/294, step 2/4: Rest for 5 min
# 2022-02-24 15:31:04,008 - [NOTICE] simulation.solve(889): Cycle 275/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:31:04,204 - [NOTICE] simulation.solve(889): Cycle 275/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:31:04,299 - [NOTICE] simulation.solve(977): Capacity is now 4.034 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:31:04,300 - [NOTICE] simulation.solve(855): Cycle 276/294 (3 minutes, 3 seconds elapsed) --------------------
# 2022-02-24 15:31:04,301 - [NOTICE] simulation.solve(889): Cycle 276/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:31:04,592 - [NOTICE] simulation.solve(889): Cycle 276/294, step 2/4: Rest for 5 min
# 2022-02-24 15:31:04,601 - [NOTICE] simulation.solve(889): Cycle 276/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:31:04,827 - [NOTICE] simulation.solve(889): Cycle 276/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:31:04,919 - [NOTICE] simulation.solve(977): Capacity is now 4.031 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:31:04,920 - [NOTICE] simulation.solve(855): Cycle 277/294 (3 minutes, 3 seconds elapsed) --------------------
# 2022-02-24 15:31:04,922 - [NOTICE] simulation.solve(889): Cycle 277/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:31:05,226 - [NOTICE] simulation.solve(889): Cycle 277/294, step 2/4: Rest for 5 min
# 2022-02-24 15:31:05,236 - [NOTICE] simulation.solve(889): Cycle 277/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:31:05,462 - [NOTICE] simulation.solve(889): Cycle 277/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:31:05,650 - [NOTICE] simulation.solve(977): Capacity is now 4.027 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:31:05,651 - [NOTICE] simulation.solve(855): Cycle 278/294 (3 minutes, 4 seconds elapsed) --------------------
# 2022-02-24 15:31:05,652 - [NOTICE] simulation.solve(889): Cycle 278/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:31:05,872 - [NOTICE] simulation.solve(889): Cycle 278/294, step 2/4: Rest for 5 min
# 2022-02-24 15:31:05,883 - [NOTICE] simulation.solve(889): Cycle 278/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:31:06,342 - [NOTICE] simulation.solve(889): Cycle 278/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:31:06,530 - [NOTICE] simulation.solve(977): Capacity is now 4.023 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:31:06,530 - [NOTICE] simulation.solve(855): Cycle 279/294 (3 minutes, 5 seconds elapsed) --------------------
# 2022-02-24 15:31:06,531 - [NOTICE] simulation.solve(889): Cycle 279/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:31:06,825 - [NOTICE] simulation.solve(889): Cycle 279/294, step 2/4: Rest for 5 min
# 2022-02-24 15:31:06,837 - [NOTICE] simulation.solve(889): Cycle 279/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:31:07,097 - [NOTICE] simulation.solve(889): Cycle 279/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:31:07,225 - [NOTICE] simulation.solve(977): Capacity is now 4.020 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:31:07,226 - [NOTICE] simulation.solve(855): Cycle 280/294 (3 minutes, 6 seconds elapsed) --------------------
# 2022-02-24 15:31:07,227 - [NOTICE] simulation.solve(889): Cycle 280/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:31:07,465 - [NOTICE] simulation.solve(889): Cycle 280/294, step 2/4: Rest for 5 min
# 2022-02-24 15:31:07,476 - [NOTICE] simulation.solve(889): Cycle 280/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:31:07,732 - [NOTICE] simulation.solve(889): Cycle 280/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:31:07,848 - [NOTICE] simulation.solve(977): Capacity is now 4.016 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:31:07,861 - [NOTICE] simulation.solve(855): Cycle 281/294 (3 minutes, 6 seconds elapsed) --------------------
# 2022-02-24 15:31:07,861 - [NOTICE] simulation.solve(889): Cycle 281/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:31:08,075 - [NOTICE] simulation.solve(889): Cycle 281/294, step 2/4: Rest for 5 min
# 2022-02-24 15:31:08,085 - [NOTICE] simulation.solve(889): Cycle 281/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:31:08,281 - [NOTICE] simulation.solve(889): Cycle 281/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:31:08,388 - [NOTICE] simulation.solve(977): Capacity is now 4.012 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:31:08,389 - [NOTICE] simulation.solve(855): Cycle 282/294 (3 minutes, 7 seconds elapsed) --------------------
# 2022-02-24 15:31:08,390 - [NOTICE] simulation.solve(889): Cycle 282/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:31:08,614 - [NOTICE] simulation.solve(889): Cycle 282/294, step 2/4: Rest for 5 min
# 2022-02-24 15:31:08,628 - [NOTICE] simulation.solve(889): Cycle 282/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:31:08,800 - [NOTICE] simulation.solve(889): Cycle 282/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:31:08,904 - [NOTICE] simulation.solve(977): Capacity is now 4.009 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:31:08,906 - [NOTICE] simulation.solve(855): Cycle 283/294 (3 minutes, 7 seconds elapsed) --------------------
# 2022-02-24 15:31:08,907 - [NOTICE] simulation.solve(889): Cycle 283/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:31:09,111 - [NOTICE] simulation.solve(889): Cycle 283/294, step 2/4: Rest for 5 min
# 2022-02-24 15:31:09,120 - [NOTICE] simulation.solve(889): Cycle 283/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:31:09,335 - [NOTICE] simulation.solve(889): Cycle 283/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:31:09,459 - [NOTICE] simulation.solve(977): Capacity is now 4.005 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:31:09,460 - [NOTICE] simulation.solve(855): Cycle 284/294 (3 minutes, 8 seconds elapsed) --------------------
# 2022-02-24 15:31:09,460 - [NOTICE] simulation.solve(889): Cycle 284/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:31:09,676 - [NOTICE] simulation.solve(889): Cycle 284/294, step 2/4: Rest for 5 min
# 2022-02-24 15:31:09,686 - [NOTICE] simulation.solve(889): Cycle 284/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:31:09,929 - [NOTICE] simulation.solve(889): Cycle 284/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:31:10,060 - [NOTICE] simulation.solve(977): Capacity is now 4.002 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:31:10,061 - [NOTICE] simulation.solve(855): Cycle 285/294 (3 minutes, 8 seconds elapsed) --------------------
# 2022-02-24 15:31:10,061 - [NOTICE] simulation.solve(889): Cycle 285/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:31:10,317 - [NOTICE] simulation.solve(889): Cycle 285/294, step 2/4: Rest for 5 min
# 2022-02-24 15:31:10,329 - [NOTICE] simulation.solve(889): Cycle 285/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:31:10,579 - [NOTICE] simulation.solve(889): Cycle 285/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:31:10,698 - [NOTICE] simulation.solve(977): Capacity is now 3.998 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:31:10,699 - [NOTICE] simulation.solve(855): Cycle 286/294 (3 minutes, 9 seconds elapsed) --------------------
# 2022-02-24 15:31:10,700 - [NOTICE] simulation.solve(889): Cycle 286/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:31:10,969 - [NOTICE] simulation.solve(889): Cycle 286/294, step 2/4: Rest for 5 min
# 2022-02-24 15:31:10,983 - [NOTICE] simulation.solve(889): Cycle 286/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:31:11,299 - [NOTICE] simulation.solve(889): Cycle 286/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:31:11,422 - [NOTICE] simulation.solve(977): Capacity is now 3.994 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:31:11,423 - [NOTICE] simulation.solve(855): Cycle 287/294 (3 minutes, 10 seconds elapsed) --------------------
# 2022-02-24 15:31:11,424 - [NOTICE] simulation.solve(889): Cycle 287/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:31:11,827 - [NOTICE] simulation.solve(889): Cycle 287/294, step 2/4: Rest for 5 min
# 2022-02-24 15:31:11,839 - [NOTICE] simulation.solve(889): Cycle 287/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:31:12,113 - [NOTICE] simulation.solve(889): Cycle 287/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:31:12,277 - [NOTICE] simulation.solve(977): Capacity is now 3.991 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:31:12,278 - [NOTICE] simulation.solve(855): Cycle 288/294 (3 minutes, 11 seconds elapsed) --------------------
# 2022-02-24 15:31:12,279 - [NOTICE] simulation.solve(889): Cycle 288/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:31:12,521 - [NOTICE] simulation.solve(889): Cycle 288/294, step 2/4: Rest for 5 min
# 2022-02-24 15:31:12,530 - [NOTICE] simulation.solve(889): Cycle 288/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:31:12,784 - [NOTICE] simulation.solve(889): Cycle 288/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:31:12,927 - [NOTICE] simulation.solve(977): Capacity is now 3.987 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:31:12,928 - [NOTICE] simulation.solve(855): Cycle 289/294 (3 minutes, 11 seconds elapsed) --------------------
# 2022-02-24 15:31:12,928 - [NOTICE] simulation.solve(889): Cycle 289/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:31:13,121 - [NOTICE] simulation.solve(889): Cycle 289/294, step 2/4: Rest for 5 min
# 2022-02-24 15:31:13,135 - [NOTICE] simulation.solve(889): Cycle 289/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:31:13,387 - [NOTICE] simulation.solve(889): Cycle 289/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:31:13,499 - [NOTICE] simulation.solve(977): Capacity is now 3.983 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:31:13,500 - [NOTICE] simulation.solve(855): Cycle 290/294 (3 minutes, 12 seconds elapsed) --------------------
# 2022-02-24 15:31:13,502 - [NOTICE] simulation.solve(889): Cycle 290/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:31:13,700 - [NOTICE] simulation.solve(889): Cycle 290/294, step 2/4: Rest for 5 min
# 2022-02-24 15:31:13,709 - [NOTICE] simulation.solve(889): Cycle 290/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:31:13,916 - [NOTICE] simulation.solve(889): Cycle 290/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:31:14,019 - [NOTICE] simulation.solve(977): Capacity is now 3.980 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:31:14,021 - [NOTICE] simulation.solve(855): Cycle 291/294 (3 minutes, 12 seconds elapsed) --------------------
# 2022-02-24 15:31:14,022 - [NOTICE] simulation.solve(889): Cycle 291/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:31:14,296 - [NOTICE] simulation.solve(889): Cycle 291/294, step 2/4: Rest for 5 min
# 2022-02-24 15:31:14,306 - [NOTICE] simulation.solve(889): Cycle 291/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:31:14,508 - [NOTICE] simulation.solve(889): Cycle 291/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:31:14,663 - [NOTICE] simulation.solve(977): Capacity is now 3.976 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:31:14,664 - [NOTICE] simulation.solve(855): Cycle 292/294 (3 minutes, 13 seconds elapsed) --------------------
# 2022-02-24 15:31:14,664 - [NOTICE] simulation.solve(889): Cycle 292/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:31:14,870 - [NOTICE] simulation.solve(889): Cycle 292/294, step 2/4: Rest for 5 min
# 2022-02-24 15:31:14,882 - [NOTICE] simulation.solve(889): Cycle 292/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:31:15,111 - [NOTICE] simulation.solve(889): Cycle 292/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:31:15,255 - [NOTICE] simulation.solve(977): Capacity is now 3.972 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:31:15,255 - [NOTICE] simulation.solve(855): Cycle 293/294 (3 minutes, 14 seconds elapsed) --------------------
# 2022-02-24 15:31:15,256 - [NOTICE] simulation.solve(889): Cycle 293/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:31:15,534 - [NOTICE] simulation.solve(889): Cycle 293/294, step 2/4: Rest for 5 min
# 2022-02-24 15:31:15,546 - [NOTICE] simulation.solve(889): Cycle 293/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:31:15,807 - [NOTICE] simulation.solve(889): Cycle 293/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:31:15,943 - [NOTICE] simulation.solve(977): Capacity is now 3.969 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:31:15,944 - [NOTICE] simulation.solve(855): Cycle 294/294 (3 minutes, 14 seconds elapsed) --------------------
# 2022-02-24 15:31:15,945 - [NOTICE] simulation.solve(889): Cycle 294/294, step 1/4: Discharge at C/5 until 3V
# 2022-02-24 15:31:16,240 - [NOTICE] simulation.solve(889): Cycle 294/294, step 2/4: Rest for 5 min
# 2022-02-24 15:31:16,252 - [NOTICE] simulation.solve(889): Cycle 294/294, step 3/4: Charge at C/5 until 4.2V
# 2022-02-24 15:31:16,616 - [NOTICE] simulation.solve(889): Cycle 294/294, step 4/4: Hold at 4.2V until C/50
# 2022-02-24 15:31:16,778 - [NOTICE] simulation.solve(977): Capacity is now 3.965 Ah (originally 5.050 Ah, will stop at 2.525 Ah)
# 2022-02-24 15:31:16,785 - [NOTICE] simulation.solve(1011): Finish experiment simulation, took 3 minutes, 15 seconds

# %%
long_sol_output =sol_long.summary_variables

# %%
fig = plot(long_sol_output,dfe);

# %%
fig = plot1(long_sol_output,dfe);
