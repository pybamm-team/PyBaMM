# %%
import pybamm
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.arange(-10,10,0.001)
y = -1*np.exp(-x)
plt.figure()
plt.plot(x,y)

# %%
x = np.arange(-0.1,0.2,0.001)
y = -1*np.exp(-x)
plt.figure()
plt.plot(x,y)
