# %% [markdown]
# # Low c-rate aging simulation ORIGINAL Code from ACC Paper

# %%
import pybamm
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import math
from scipy.integrate import solve_ivp

DATA_DIR  = "./data/esoh_V/"
fig_DIR = "./figures/"

# %% [markdown]
# # Set Parameters and Expansion Functions

# %%
def nmc_volume_change_mohtat(sto):
    t_change = -1.10/100*(1-sto)
    return t_change

def graphite_volume_change_mohtat(sto):
    stoichpoints = np.array([0,0.12,0.18,0.24,0.50,1])
    thicknesspoints = np.array([0,2.406/100,3.3568/100,4.3668/100,5.583/100,13.0635/100])
    x = [sto]
    t_change = pybamm.Interpolant(stoichpoints, thicknesspoints, x, name=None, interpolator='linear', extrapolate=True, entries_string=None)
    return t_change

def get_parameter_values():
    parameter_values = pybamm.ParameterValues(chemistry=pybamm.parameter_sets.Mohtat2020)
    parameter_values.update(
        {
            # mechanical properties
            "Positive electrode Poisson's ratio": 0.3,
            "Positive electrode Young's modulus [Pa]": 375e9,
            "Positive electrode reference concentration for free of deformation [mol.m-3]": 0,
            "Positive electrode partial molar volume [m3.mol-1]": -7.28e-7,
            "Positive electrode volume change": nmc_volume_change_mohtat,
            # Loss of active materials (LAM) model
            "Positive electrode LAM constant exponential term": 2,
            "Positive electrode critical stress [Pa]": 375e6,
            # mechanical properties
            "Negative electrode Poisson's ratio": 0.2,
            "Negative electrode Young's modulus [Pa]": 15e9,
            "Negative electrode reference concentration for free of deformation [mol.m-3]": 0,
            "Negative electrode partial molar volume [m3.mol-1]": 3.1e-6,
            "Negative electrode volume change": graphite_volume_change_mohtat,
            # Loss of active materials (LAM) model
            "Negative electrode LAM constant exponential term": 2,
            "Negative electrode critical stress [Pa]": 60e6,
            # Other
            "Cell thermal expansion coefficient [m.K-1]": 1.48E-6,
            "Lower voltage cut-off [V]": 3.0
        },
        check_already_exists=False,
    )
    return parameter_values
parameter_values = get_parameter_values()

# %%
parameter_values.search("Li")
# Out:
# Cell cooling surface area [m2]	0.41
# Initial plated lithium concentration [mol.m-3]	0.0
# Inner SEI lithium interstitial diffusivity [m2.s-1]	1e-20
# Lithium interstitial reference concentration [mol.m-3]	15.0
# Lithium metal partial molar volume [m3.mol-1]	1.3e-05
# Typical lithium ion diffusivity [m2.s-1]	5.34e-10
# Typical plated lithium concentration [mol.m-3]	1000.0

# %%
def split_long_string(title, max_words=None):
    """Get title in a nice format"""
    max_words = max_words or pybamm.settings.max_words_in_line
    words = title.split()
    # Don't split if fits on one line, don't split just for units
    if len(words) <= max_words or words[max_words].startswith("["):
        return title
    else:
        first_line = (" ").join(words[:max_words])
        second_line = (" ").join(words[max_words:])
        return first_line + "\n" + second_line

# %% [markdown]
# # Accelerated Simulations Function

# %%
def cycle_adaptive_simulation(model, parameter_values, experiment,SOC_0=1, save_at_cycles=None):
    experiment_one_cycle = pybamm.Experiment(
        experiment.operating_conditions_cycles[:1],
        termination=experiment.termination_string,
        cccv_handling=experiment.cccv_handling,
    )
    Vmin = 3.0
    Vmax = 4.2
    esoh_model = pybamm.lithium_ion.ElectrodeSOH()
    esoh_sim = pybamm.Simulation(esoh_model, parameter_values=parameter_values)
    param = model.param
    Cn = parameter_values.evaluate(param.C_n_init)
    Cp = parameter_values.evaluate(param.C_p_init)
    eps_n = parameter_values["Negative electrode active material volume fraction"]
    eps_p = parameter_values["Positive electrode active material volume fraction"]
    C_over_eps_n = Cn / eps_n
    C_over_eps_p = Cp / eps_p
    c_n_max = parameter_values.evaluate(param.c_n_max)
    c_p_max = parameter_values.evaluate(param.c_p_max)
    n_Li_init = parameter_values.evaluate(param.n_Li_particles_init)
    
    esoh_sol = esoh_sim.solve(
        [0],
        inputs={"V_min": Vmin, "V_max": Vmax, "C_n": Cn, "C_p": Cp, "n_Li": n_Li_init},
        solver=pybamm.AlgebraicSolver(),
    )

    parameter_values.update(
        {
            "Initial concentration in negative electrode [mol.m-3]": esoh_sol[
                "x_100"
            ].data[0]
            * c_n_max,
            "Initial concentration in positive electrode [mol.m-3]": esoh_sol[
                "y_100"
            ].data[0]
            * c_p_max,
            
        }
    )

    sim_ode = pybamm.Simulation(
        model, experiment=experiment_one_cycle, parameter_values=parameter_values,
        solver=pybamm.CasadiSolver("safe")
    )
    sol0 = sim_ode.solve(initial_soc=SOC_0)
    model = sim_ode.solution.all_models[0]
    cap0 = sol0.summary_variables["Capacity [A.h]"]

    def sol_to_y(sol, loc="end"):
        if loc == "start":
            pos = 0
        elif loc == "end":
            pos = -1
        model = sol.all_models[0]
        n_Li = sol["Total lithium in particles [mol]"].data[pos].flatten()
        Cn = sol["Negative electrode capacity [A.h]"].data[pos].flatten()
        Cp = sol["Positive electrode capacity [A.h]"].data[pos].flatten()
        # y = np.concatenate([n_Li, Cn, Cp])
        y = n_Li
        for var in model.initial_conditions:
            if var.name not in [
                "X-averaged negative particle concentration",
                "X-averaged positive particle concentration",
                "Discharge capacity [A.h]",
            ]:
                value = sol[var.name].data
                if value.ndim == 1:
                    value = value[pos]
                elif value.ndim == 2:
                    value = value[:, pos]
                elif value.ndim == 3:
                    value = value[:, :, pos]
                y = np.concatenate([y, value.flatten()])
        return y

    def y_to_sol(y, esoh_sim, model):
        n_Li = y[0]
        Cn = C_over_eps_n * y[1]
        Cp = C_over_eps_p * y[2]

        esoh_sol = esoh_sim.solve(
            [0],
            inputs={"V_min": Vmin, "V_max": Vmax, "C_n": Cn, "C_p": Cp, "n_Li": n_Li},
        )
        esoh_sim.built_model.set_initial_conditions_from(esoh_sol)
        ics = {}
        x_100 = esoh_sol["x_100"].data[0]
        y_100 = esoh_sol["y_100"].data[0]
        x_0 = esoh_sol["x_0"].data[0]
        y_0 = esoh_sol["y_0"].data[0]
        start = 1
        for var in model.initial_conditions:
            if var.name == "X-averaged negative particle concentration":
                ics[var.name] = ((x_100-x_0)*SOC_0+x_0) * np.ones((model.variables[var.name].size, 2))
            elif var.name == "X-averaged positive particle concentration":
                ics[var.name] = y_100 * np.ones((model.variables[var.name].size, 2))
            elif var.name == "Discharge capacity [A.h]":
                ics[var.name] = np.zeros(1)
            else:
                end = start + model.variables[var.name].size
                ics[var.name] = y[start:end, np.newaxis]
                start = end
        model.set_initial_conditions_from(ics)
        return pybamm.Solution(
            [np.array([0])],
            model.concatenated_initial_conditions.evaluate()[:, np.newaxis],
            model,
            {},
        )

    def dydt(t, y):
        if y[0] < 0 or y[1] < 0 or y[2] < 0:
            return 0 * y

        print(t)
        # Set up based on current value of y
        y_to_sol(
            y,
            esoh_sim,
            sim_ode.op_conds_to_built_models[
                experiment_one_cycle.operating_conditions[0]["electric"]
            ],
        )

        # Simulate one cycle
        sol = sim_ode.solve()

        dy = sol_to_y(sol) - y

        return dy

    if experiment.termination == {}:
        event = None
    else:

        def capacity_cutoff(t, y):
            sol = y_to_sol(y, esoh_sim, model)
            cap = pybamm.make_cycle_solution([sol], esoh_sim, True)[1]["Capacity [A.h]"]
            return cap / cap0 - experiment_one_cycle.termination["capacity"][0] / 100

        capacity_cutoff.terminal = True

    num_cycles = len(experiment.operating_conditions_cycles)
    if save_at_cycles is None:
        t_eval = np.arange(1, num_cycles + 1)
    elif save_at_cycles == -1:
        t_eval = None
    else:
        t_eval = np.arange(1, num_cycles + 1, save_at_cycles)
    y0 = sol_to_y(sol0, loc="start")
    timer = pybamm.Timer()
    sol = solve_ivp(
        dydt,
        [1, num_cycles],
        y0,
        t_eval=t_eval,
        events=capacity_cutoff,
        first_step=10,
        method="RK23",
        atol=1e-2,
        rtol=1e-2,
    )
    time = timer.time()

    all_sumvars = []
    for idx in range(sol.y.shape[1]):
        fullsol = y_to_sol(sol.y[:, idx], esoh_sim, model)
        sumvars = pybamm.make_cycle_solution([fullsol], esoh_sim, True)[1]
        all_sumvars.append(sumvars)

    all_sumvars_dict = {
        key: np.array([sumvars[key] for sumvars in all_sumvars])
        for key in all_sumvars[0].keys()
    }
    all_sumvars_dict["Cycle number"] = sol.t
    
    all_sumvars_dict["cycles evaluated"] = sol.nfev
    all_sumvars_dict["solution time"] = time
    
    return all_sumvars_dict

# %% [markdown]
# # Plot Functions

# %%
def plot(all_sumvars_dict,esoh_data):
    esoh_vars = ["x_0", "y_0", "x_100", "y_100", "C_n", "C_p"]
    # esoh_vars = ["Capacity [A.h]", "Loss of lithium inventory [%]",
    #              "Loss of active material in negative electrode [%]",
    #              "Loss of active material in positive electrode [%]"]
    fig, axes = plt.subplots(3,2,figsize=(7,9))
    for k, name in enumerate(esoh_vars):
        ax = axes.flat[k]
        ax.plot(all_sumvars_dict["Cycle number"],all_sumvars_dict[name],"ro")
        ax.plot(esoh_data["N"],esoh_data[name],"kx")
#         ax.scatter(all_sumvars_dict["Cycle number"],all_sumvars_dict[name],color="r")
    #     ax.plot(long_sol.summary_variables[name],"b-")
        ax.set_title(split_long_string(name))
        if k>3:
            ax.set_xlabel("Cycle number")
    # fig.subplots_adjust(bottom=0.4)
    fig.legend(["Acc Sim"] + ["Reported"], 
           loc="lower center", ncol=1, fontsize=11)
    fig.tight_layout()
    return fig

def plot1(all_sumvars_dict,esoh_data):
    esoh_vars = ["Capacity [A.h]","n_Li"]
    esoh_data["Capacity [A.h]"]=esoh_data["Cap"]
    param = pybamm.LithiumIonParameters()
    esoh_data["n_Li"]= 3600/param.F.value*(esoh_data["y_100"]*esoh_data["C_p"]+esoh_data["x_100"]*esoh_data["C_n"])
    fig, axes = plt.subplots(2,1,figsize=(7,9))
    for k, name in enumerate(esoh_vars):
        ax = axes.flat[k]
        ax.plot(all_sumvars_dict["Cycle number"],all_sumvars_dict[name],"ro")
        ax.plot(esoh_data["N"],esoh_data[name],"kx")
        ax.set_title(split_long_string(name))
        ax.set_xlabel("Cycle number")
    fig.legend(["Acc Sim"] + ["Reported"], 
           loc="upper right", ncol=1, fontsize=11)
    fig.tight_layout()
    return fig
    
def plotc(all_sumvars_dict,esoh_data):
    esoh_vars = ["x_100", "y_0", "C_n", "C_p", "Capacity [A.h]", "Loss of lithium inventory [%]"]
    esoh_data["Capacity [A.h]"]=esoh_data["Cap"]
    param = pybamm.LithiumIonParameters()
    esoh_data["n_Li"]= 3600/param.F.value*(esoh_data["y_100"]*esoh_data["C_p"]+esoh_data["x_100"]*esoh_data["C_n"])
    esoh_data["Loss of lithium inventory [%]"]=(1-esoh_data["n_Li"]/esoh_data["n_Li"][0])*100
    fig, axes = plt.subplots(3,2,figsize=(7,7))
    for k, name in enumerate(esoh_vars):
        ax = axes.flat[k]
        ax.plot(all_sumvars_dict["Cycle number"],all_sumvars_dict[name],"ro")
        # ax.plot(esoh_data["N"],esoh_data[name],"kx")
        ax.set_title(split_long_string(name))
        if k>3:
            ax.set_xlabel("Cycle number")
    # fig.legend(["Acc Sim"] + ["Reported"], 
    #        loc="lower center",bbox_to_anchor=[0.5,-0.02], ncol=1, fontsize=11)
    fig.tight_layout()
    return fig

# %% [markdown]
# # Choose Cell

# %%
cell = 4

# %% [markdown]
# ## Set cell eSOH and cycling parameters

# %%
cell_no = f'{cell:02d}'
if cell_no=='01':
    c_rate_c = 'C/5'
    c_rate_d = 'C/5'
    dis_set = " until 3V"
    eps_n_data = 0.6234
    eps_p_data = 0.4542
elif cell_no=='04':
    c_rate_c = '1.5C'
    c_rate_d = '1.5C'
    dis_set = " until 3V"
    eps_n_data = 0.6247
    eps_p_data = 0.4512
elif cell_no=='07':
    c_rate_c = '2C'
    c_rate_d = '2C'
    dis_set = " until 3V"
    eps_n_data = 0.6166
    eps_p_data = 0.4529
elif cell_no=='10':
    c_rate_c = 'C/5'
    c_rate_d = '1.5C'
    dis_set = " until 3V"
    eps_n_data = 0.6250
    eps_p_data = 0.4493
elif cell_no=='13':
    c_rate_c = 'C/5'
    c_rate_d = 'C/5'
    dis_set = " for 150 min"
    eps_n_data = 0.6247
    eps_p_data = 0.4544
elif cell_no=='16':
    c_rate_c = 'C/5'
    c_rate_d = '1.5C'
    dis_set = " for 20 min"
    eps_n_data = 0.6243
    eps_p_data = 0.4501
esoh_data =  pd.read_csv(DATA_DIR +'aging_param_cell_'+cell_no+'.csv')  
esoh_data.N.iloc[-1]
# Out:
# 328

# %% [markdown]
# # Define Experiment and Model

# %%
pybamm.set_logging_level("WARNING")
pybamm.set_logging_level("NOTICE")
experiment = pybamm.Experiment(
    [
        ("Discharge at "+c_rate_d+dis_set,
         "Rest for 5 min",
         "Charge at "+c_rate_c+" until 4.2V", 
         "Hold at 4.2V until C/50")
    ] *esoh_data.N.iloc[-1],
    termination="50% capacity",
#     cccv_handling="ode",
)
spm = pybamm.lithium_ion.SPMe(
    {
        "SEI": "ec reaction limited",
        # "loss of active material": ("stress-driven","none"),
        "loss of active material": "stress-driven",
        "stress-induced diffusion": "true",
        # "lithium plating": "reversible",
    }
)
# spm.print_parameter_info()

# %% [markdown]
# # Set Additional Parameter Value and Simulate

# %%
parameter_values = get_parameter_values()
parameter_values.update(
    {

        "Positive electrode LAM constant proportional term [s-1]": 8.7864e-07,
        "Negative electrode LAM constant proportional term [s-1]": 1.08031e-05,
        "SEI kinetic rate constant [m.s-1]": 1.6297e-15,
        "EC diffusivity [m2.s-1]": 2e-18,
        "Positive electrode LAM constant exponential term": 2,
        "Negative electrode LAM constant exponential term": 2,
        "Negative electrode active material volume fraction": eps_n_data,
        "Positive electrode active material volume fraction": eps_p_data,
        "Negative electrode porosity": 0.3,
        "Positive electrode porosity": 0.3,
        "Separator porosity": 0.4,
        # "Negative electrode porosity": 0.28,
        # "Positive electrode porosity": 0.28,
        # "Separator porosity": 0.38,
        # "Negative electrode porosity": 0.15,
        # "Positive electrode porosity": 0.15,
        # "Separator porosity": 0.2,
    },
    check_already_exists=False,
)
# all_sumvars_dict = cycle_adaptive_simulation(spm, parameter_values, experiment, save_at_cycles=2)

# %%
# fig = plotc(all_sumvars_dict,esoh_data);
# fig.savefig(fig_DIR +'fast_sim_'+cell_no+'_esoh.png')

# %%
# afsdfsd

# %% [markdown]
# # Normal Simulations

# %%
sim_long = pybamm.Simulation(spm, experiment=experiment, parameter_values=parameter_values, 
                            solver=pybamm.CasadiSolver("safe"))
sol_long_0 = sim_long.solve(initial_soc=1)
long_sol_output_0 =sol_long_0.summary_variables
# Out:
# 2022-05-11 13:08:33,860 - [NOTICE] simulation.solve(855): Cycle 1/328 (58.967 ms elapsed) --------------------
# 2022-05-11 13:08:33,861 - [NOTICE] simulation.solve(889): Cycle 1/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:08:34,186 - [NOTICE] simulation.solve(889): Cycle 1/328, step 2/4: Rest for 5 min
# 2022-05-11 13:08:34,335 - [NOTICE] simulation.solve(889): Cycle 1/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:08:34,599 - [NOTICE] simulation.solve(889): Cycle 1/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:08:35,441 - [NOTICE] simulation.solve(977): Capacity is now 5.032 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:08:35,441 - [NOTICE] simulation.solve(855): Cycle 2/328 (1.640 s elapsed) --------------------
# 2022-05-11 13:08:35,442 - [NOTICE] simulation.solve(889): Cycle 2/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:08:35,648 - [NOTICE] simulation.solve(889): Cycle 2/328, step 2/4: Rest for 5 min
# 2022-05-11 13:08:35,690 - [NOTICE] simulation.solve(889): Cycle 2/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:08:35,877 - [NOTICE] simulation.solve(889): Cycle 2/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:08:36,211 - [NOTICE] simulation.solve(977): Capacity is now 5.026 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:08:36,212 - [NOTICE] simulation.solve(855): Cycle 3/328 (2.410 s elapsed) --------------------
# 2022-05-11 13:08:36,213 - [NOTICE] simulation.solve(889): Cycle 3/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:08:36,402 - [NOTICE] simulation.solve(889): Cycle 3/328, step 2/4: Rest for 5 min
# 2022-05-11 13:08:36,443 - [NOTICE] simulation.solve(889): Cycle 3/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:08:36,669 - [NOTICE] simulation.solve(889): Cycle 3/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:08:36,992 - [NOTICE] simulation.solve(977): Capacity is now 5.020 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:08:36,992 - [NOTICE] simulation.solve(855): Cycle 4/328 (3.191 s elapsed) --------------------
# 2022-05-11 13:08:36,993 - [NOTICE] simulation.solve(889): Cycle 4/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:08:37,229 - [NOTICE] simulation.solve(889): Cycle 4/328, step 2/4: Rest for 5 min
# 2022-05-11 13:08:37,266 - [NOTICE] simulation.solve(889): Cycle 4/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:08:37,418 - [NOTICE] simulation.solve(889): Cycle 4/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:08:37,688 - [NOTICE] simulation.solve(977): Capacity is now 5.014 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:08:37,688 - [NOTICE] simulation.solve(855): Cycle 5/328 (3.887 s elapsed) --------------------
# 2022-05-11 13:08:37,689 - [NOTICE] simulation.solve(889): Cycle 5/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:08:37,921 - [NOTICE] simulation.solve(889): Cycle 5/328, step 2/4: Rest for 5 min
# 2022-05-11 13:08:37,969 - [NOTICE] simulation.solve(889): Cycle 5/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:08:38,173 - [NOTICE] simulation.solve(889): Cycle 5/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:08:38,548 - [NOTICE] simulation.solve(977): Capacity is now 5.008 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:08:38,549 - [NOTICE] simulation.solve(855): Cycle 6/328 (4.747 s elapsed) --------------------
# 2022-05-11 13:08:38,549 - [NOTICE] simulation.solve(889): Cycle 6/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:08:38,742 - [NOTICE] simulation.solve(889): Cycle 6/328, step 2/4: Rest for 5 min
# 2022-05-11 13:08:38,789 - [NOTICE] simulation.solve(889): Cycle 6/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:08:39,003 - [NOTICE] simulation.solve(889): Cycle 6/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:08:39,360 - [NOTICE] simulation.solve(977): Capacity is now 5.002 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:08:39,361 - [NOTICE] simulation.solve(855): Cycle 7/328 (5.560 s elapsed) --------------------
# 2022-05-11 13:08:39,362 - [NOTICE] simulation.solve(889): Cycle 7/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:08:39,539 - [NOTICE] simulation.solve(889): Cycle 7/328, step 2/4: Rest for 5 min
# 2022-05-11 13:08:39,579 - [NOTICE] simulation.solve(889): Cycle 7/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:08:39,736 - [NOTICE] simulation.solve(889): Cycle 7/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:08:40,050 - [NOTICE] simulation.solve(977): Capacity is now 4.997 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:08:40,050 - [NOTICE] simulation.solve(855): Cycle 8/328 (6.249 s elapsed) --------------------
# 2022-05-11 13:08:40,052 - [NOTICE] simulation.solve(889): Cycle 8/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:08:40,239 - [NOTICE] simulation.solve(889): Cycle 8/328, step 2/4: Rest for 5 min
# 2022-05-11 13:08:40,272 - [NOTICE] simulation.solve(889): Cycle 8/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:08:40,443 - [NOTICE] simulation.solve(889): Cycle 8/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:08:40,724 - [NOTICE] simulation.solve(977): Capacity is now 4.991 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:08:40,725 - [NOTICE] simulation.solve(855): Cycle 9/328 (6.924 s elapsed) --------------------
# 2022-05-11 13:08:40,726 - [NOTICE] simulation.solve(889): Cycle 9/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:08:40,890 - [NOTICE] simulation.solve(889): Cycle 9/328, step 2/4: Rest for 5 min
# 2022-05-11 13:08:40,940 - [NOTICE] simulation.solve(889): Cycle 9/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:08:41,146 - [NOTICE] simulation.solve(889): Cycle 9/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:08:41,503 - [NOTICE] simulation.solve(977): Capacity is now 4.985 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:08:41,504 - [NOTICE] simulation.solve(855): Cycle 10/328 (7.702 s elapsed) --------------------
# 2022-05-11 13:08:41,504 - [NOTICE] simulation.solve(889): Cycle 10/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:08:41,670 - [NOTICE] simulation.solve(889): Cycle 10/328, step 2/4: Rest for 5 min
# 2022-05-11 13:08:41,701 - [NOTICE] simulation.solve(889): Cycle 10/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:08:41,851 - [NOTICE] simulation.solve(889): Cycle 10/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:08:42,168 - [NOTICE] simulation.solve(977): Capacity is now 4.978 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:08:42,169 - [NOTICE] simulation.solve(855): Cycle 11/328 (8.368 s elapsed) --------------------
# 2022-05-11 13:08:42,170 - [NOTICE] simulation.solve(889): Cycle 11/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:08:42,350 - [NOTICE] simulation.solve(889): Cycle 11/328, step 2/4: Rest for 5 min
# 2022-05-11 13:08:42,390 - [NOTICE] simulation.solve(889): Cycle 11/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:08:42,559 - [NOTICE] simulation.solve(889): Cycle 11/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:08:42,857 - [NOTICE] simulation.solve(977): Capacity is now 4.976 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:08:42,858 - [NOTICE] simulation.solve(855): Cycle 12/328 (9.056 s elapsed) --------------------
# 2022-05-11 13:08:42,859 - [NOTICE] simulation.solve(889): Cycle 12/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:08:43,059 - [NOTICE] simulation.solve(889): Cycle 12/328, step 2/4: Rest for 5 min
# 2022-05-11 13:08:43,100 - [NOTICE] simulation.solve(889): Cycle 12/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:08:43,312 - [NOTICE] simulation.solve(889): Cycle 12/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:08:43,625 - [NOTICE] simulation.solve(977): Capacity is now 4.966 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:08:43,626 - [NOTICE] simulation.solve(855): Cycle 13/328 (9.824 s elapsed) --------------------
# 2022-05-11 13:08:43,627 - [NOTICE] simulation.solve(889): Cycle 13/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:08:43,786 - [NOTICE] simulation.solve(889): Cycle 13/328, step 2/4: Rest for 5 min
# 2022-05-11 13:08:43,819 - [NOTICE] simulation.solve(889): Cycle 13/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:08:43,956 - [NOTICE] simulation.solve(889): Cycle 13/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:08:44,312 - [NOTICE] simulation.solve(977): Capacity is now 4.964 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:08:44,313 - [NOTICE] simulation.solve(855): Cycle 14/328 (10.511 s elapsed) --------------------
# 2022-05-11 13:08:44,313 - [NOTICE] simulation.solve(889): Cycle 14/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:08:44,477 - [NOTICE] simulation.solve(889): Cycle 14/328, step 2/4: Rest for 5 min
# 2022-05-11 13:08:44,513 - [NOTICE] simulation.solve(889): Cycle 14/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:08:44,658 - [NOTICE] simulation.solve(889): Cycle 14/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:08:44,931 - [NOTICE] simulation.solve(977): Capacity is now 4.954 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:08:44,931 - [NOTICE] simulation.solve(855): Cycle 15/328 (11.129 s elapsed) --------------------
# 2022-05-11 13:08:44,932 - [NOTICE] simulation.solve(889): Cycle 15/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:08:45,095 - [NOTICE] simulation.solve(889): Cycle 15/328, step 2/4: Rest for 5 min
# 2022-05-11 13:08:45,129 - [NOTICE] simulation.solve(889): Cycle 15/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:08:45,293 - [NOTICE] simulation.solve(889): Cycle 15/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:08:45,737 - [NOTICE] simulation.solve(977): Capacity is now 4.948 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:08:45,738 - [NOTICE] simulation.solve(855): Cycle 16/328 (11.937 s elapsed) --------------------
# 2022-05-11 13:08:45,739 - [NOTICE] simulation.solve(889): Cycle 16/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:08:45,884 - [NOTICE] simulation.solve(889): Cycle 16/328, step 2/4: Rest for 5 min
# 2022-05-11 13:08:45,922 - [NOTICE] simulation.solve(889): Cycle 16/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:08:46,062 - [NOTICE] simulation.solve(889): Cycle 16/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:08:46,366 - [NOTICE] simulation.solve(977): Capacity is now 4.942 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:08:46,367 - [NOTICE] simulation.solve(855): Cycle 17/328 (12.566 s elapsed) --------------------
# 2022-05-11 13:08:46,368 - [NOTICE] simulation.solve(889): Cycle 17/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:08:46,532 - [NOTICE] simulation.solve(889): Cycle 17/328, step 2/4: Rest for 5 min
# 2022-05-11 13:08:46,571 - [NOTICE] simulation.solve(889): Cycle 17/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:08:46,738 - [NOTICE] simulation.solve(889): Cycle 17/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:08:47,031 - [NOTICE] simulation.solve(977): Capacity is now 4.936 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:08:47,031 - [NOTICE] simulation.solve(855): Cycle 18/328 (13.230 s elapsed) --------------------
# 2022-05-11 13:08:47,032 - [NOTICE] simulation.solve(889): Cycle 18/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:08:47,195 - [NOTICE] simulation.solve(889): Cycle 18/328, step 2/4: Rest for 5 min
# 2022-05-11 13:08:47,233 - [NOTICE] simulation.solve(889): Cycle 18/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:08:47,405 - [NOTICE] simulation.solve(889): Cycle 18/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:08:47,747 - [NOTICE] simulation.solve(977): Capacity is now 4.932 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:08:47,748 - [NOTICE] simulation.solve(855): Cycle 19/328 (13.947 s elapsed) --------------------
# 2022-05-11 13:08:47,749 - [NOTICE] simulation.solve(889): Cycle 19/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:08:47,902 - [NOTICE] simulation.solve(889): Cycle 19/328, step 2/4: Rest for 5 min
# 2022-05-11 13:08:47,934 - [NOTICE] simulation.solve(889): Cycle 19/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:08:48,074 - [NOTICE] simulation.solve(889): Cycle 19/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:08:48,389 - [NOTICE] simulation.solve(977): Capacity is now 4.923 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:08:48,390 - [NOTICE] simulation.solve(855): Cycle 20/328 (14.589 s elapsed) --------------------
# 2022-05-11 13:08:48,391 - [NOTICE] simulation.solve(889): Cycle 20/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:08:48,553 - [NOTICE] simulation.solve(889): Cycle 20/328, step 2/4: Rest for 5 min
# 2022-05-11 13:08:48,588 - [NOTICE] simulation.solve(889): Cycle 20/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:08:48,732 - [NOTICE] simulation.solve(889): Cycle 20/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:08:49,019 - [NOTICE] simulation.solve(977): Capacity is now 4.919 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:08:49,019 - [NOTICE] simulation.solve(855): Cycle 21/328 (15.218 s elapsed) --------------------
# 2022-05-11 13:08:49,021 - [NOTICE] simulation.solve(889): Cycle 21/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:08:49,161 - [NOTICE] simulation.solve(889): Cycle 21/328, step 2/4: Rest for 5 min
# 2022-05-11 13:08:49,203 - [NOTICE] simulation.solve(889): Cycle 21/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:08:49,375 - [NOTICE] simulation.solve(889): Cycle 21/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:08:49,698 - [NOTICE] simulation.solve(977): Capacity is now 4.913 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:08:49,699 - [NOTICE] simulation.solve(855): Cycle 22/328 (15.898 s elapsed) --------------------
# 2022-05-11 13:08:49,700 - [NOTICE] simulation.solve(889): Cycle 22/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:08:49,855 - [NOTICE] simulation.solve(889): Cycle 22/328, step 2/4: Rest for 5 min
# 2022-05-11 13:08:49,888 - [NOTICE] simulation.solve(889): Cycle 22/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:08:50,027 - [NOTICE] simulation.solve(889): Cycle 22/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:08:50,338 - [NOTICE] simulation.solve(977): Capacity is now 4.907 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:08:50,339 - [NOTICE] simulation.solve(855): Cycle 23/328 (16.537 s elapsed) --------------------
# 2022-05-11 13:08:50,339 - [NOTICE] simulation.solve(889): Cycle 23/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:08:50,523 - [NOTICE] simulation.solve(889): Cycle 23/328, step 2/4: Rest for 5 min
# 2022-05-11 13:08:50,559 - [NOTICE] simulation.solve(889): Cycle 23/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:08:50,718 - [NOTICE] simulation.solve(889): Cycle 23/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:08:50,992 - [NOTICE] simulation.solve(977): Capacity is now 4.900 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:08:50,993 - [NOTICE] simulation.solve(855): Cycle 24/328 (17.192 s elapsed) --------------------
# 2022-05-11 13:08:50,994 - [NOTICE] simulation.solve(889): Cycle 24/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:08:51,140 - [NOTICE] simulation.solve(889): Cycle 24/328, step 2/4: Rest for 5 min
# 2022-05-11 13:08:51,176 - [NOTICE] simulation.solve(889): Cycle 24/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:08:51,309 - [NOTICE] simulation.solve(889): Cycle 24/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:08:51,630 - [NOTICE] simulation.solve(977): Capacity is now 4.894 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:08:51,631 - [NOTICE] simulation.solve(855): Cycle 25/328 (17.830 s elapsed) --------------------
# 2022-05-11 13:08:51,631 - [NOTICE] simulation.solve(889): Cycle 25/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:08:51,805 - [NOTICE] simulation.solve(889): Cycle 25/328, step 2/4: Rest for 5 min
# 2022-05-11 13:08:51,841 - [NOTICE] simulation.solve(889): Cycle 25/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:08:51,980 - [NOTICE] simulation.solve(889): Cycle 25/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:08:52,273 - [NOTICE] simulation.solve(977): Capacity is now 4.888 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:08:52,274 - [NOTICE] simulation.solve(855): Cycle 26/328 (18.472 s elapsed) --------------------
# 2022-05-11 13:08:52,274 - [NOTICE] simulation.solve(889): Cycle 26/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:08:52,455 - [NOTICE] simulation.solve(889): Cycle 26/328, step 2/4: Rest for 5 min
# 2022-05-11 13:08:52,489 - [NOTICE] simulation.solve(889): Cycle 26/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:08:52,636 - [NOTICE] simulation.solve(889): Cycle 26/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:08:52,950 - [NOTICE] simulation.solve(977): Capacity is now 4.882 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:08:52,950 - [NOTICE] simulation.solve(855): Cycle 27/328 (19.149 s elapsed) --------------------
# 2022-05-11 13:08:52,951 - [NOTICE] simulation.solve(889): Cycle 27/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:08:53,092 - [NOTICE] simulation.solve(889): Cycle 27/328, step 2/4: Rest for 5 min
# 2022-05-11 13:08:53,123 - [NOTICE] simulation.solve(889): Cycle 27/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:08:53,264 - [NOTICE] simulation.solve(889): Cycle 27/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:08:53,618 - [NOTICE] simulation.solve(977): Capacity is now 4.875 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:08:53,619 - [NOTICE] simulation.solve(855): Cycle 28/328 (19.817 s elapsed) --------------------
# 2022-05-11 13:08:53,620 - [NOTICE] simulation.solve(889): Cycle 28/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:08:53,802 - [NOTICE] simulation.solve(889): Cycle 28/328, step 2/4: Rest for 5 min
# 2022-05-11 13:08:53,862 - [NOTICE] simulation.solve(889): Cycle 28/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:08:54,060 - [NOTICE] simulation.solve(889): Cycle 28/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:08:54,346 - [NOTICE] simulation.solve(977): Capacity is now 4.869 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:08:54,347 - [NOTICE] simulation.solve(855): Cycle 29/328 (20.545 s elapsed) --------------------
# 2022-05-11 13:08:54,348 - [NOTICE] simulation.solve(889): Cycle 29/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:08:54,575 - [NOTICE] simulation.solve(889): Cycle 29/328, step 2/4: Rest for 5 min
# 2022-05-11 13:08:54,612 - [NOTICE] simulation.solve(889): Cycle 29/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:08:54,832 - [NOTICE] simulation.solve(889): Cycle 29/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:08:55,139 - [NOTICE] simulation.solve(977): Capacity is now 4.863 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:08:55,140 - [NOTICE] simulation.solve(855): Cycle 30/328 (21.338 s elapsed) --------------------
# 2022-05-11 13:08:55,140 - [NOTICE] simulation.solve(889): Cycle 30/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:08:55,293 - [NOTICE] simulation.solve(889): Cycle 30/328, step 2/4: Rest for 5 min
# 2022-05-11 13:08:55,330 - [NOTICE] simulation.solve(889): Cycle 30/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:08:55,523 - [NOTICE] simulation.solve(889): Cycle 30/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:08:55,914 - [NOTICE] simulation.solve(977): Capacity is now 4.857 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:08:55,915 - [NOTICE] simulation.solve(855): Cycle 31/328 (22.114 s elapsed) --------------------
# 2022-05-11 13:08:55,915 - [NOTICE] simulation.solve(889): Cycle 31/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:08:56,126 - [NOTICE] simulation.solve(889): Cycle 31/328, step 2/4: Rest for 5 min
# 2022-05-11 13:08:56,171 - [NOTICE] simulation.solve(889): Cycle 31/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:08:56,387 - [NOTICE] simulation.solve(889): Cycle 31/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:08:56,845 - [NOTICE] simulation.solve(977): Capacity is now 4.851 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:08:56,845 - [NOTICE] simulation.solve(855): Cycle 32/328 (23.044 s elapsed) --------------------
# 2022-05-11 13:08:56,846 - [NOTICE] simulation.solve(889): Cycle 32/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:08:57,059 - [NOTICE] simulation.solve(889): Cycle 32/328, step 2/4: Rest for 5 min
# 2022-05-11 13:08:57,122 - [NOTICE] simulation.solve(889): Cycle 32/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:08:57,308 - [NOTICE] simulation.solve(889): Cycle 32/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:08:57,753 - [NOTICE] simulation.solve(977): Capacity is now 4.844 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:08:57,754 - [NOTICE] simulation.solve(855): Cycle 33/328 (23.952 s elapsed) --------------------
# 2022-05-11 13:08:57,755 - [NOTICE] simulation.solve(889): Cycle 33/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:08:57,995 - [NOTICE] simulation.solve(889): Cycle 33/328, step 2/4: Rest for 5 min
# 2022-05-11 13:08:58,047 - [NOTICE] simulation.solve(889): Cycle 33/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:08:58,217 - [NOTICE] simulation.solve(889): Cycle 33/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:08:58,640 - [NOTICE] simulation.solve(977): Capacity is now 4.838 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:08:58,641 - [NOTICE] simulation.solve(855): Cycle 34/328 (24.839 s elapsed) --------------------
# 2022-05-11 13:08:58,642 - [NOTICE] simulation.solve(889): Cycle 34/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:08:58,870 - [NOTICE] simulation.solve(889): Cycle 34/328, step 2/4: Rest for 5 min
# 2022-05-11 13:08:58,916 - [NOTICE] simulation.solve(889): Cycle 34/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:08:59,101 - [NOTICE] simulation.solve(889): Cycle 34/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:08:59,538 - [NOTICE] simulation.solve(977): Capacity is now 4.832 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:08:59,539 - [NOTICE] simulation.solve(855): Cycle 35/328 (25.737 s elapsed) --------------------
# 2022-05-11 13:08:59,539 - [NOTICE] simulation.solve(889): Cycle 35/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:08:59,777 - [NOTICE] simulation.solve(889): Cycle 35/328, step 2/4: Rest for 5 min
# 2022-05-11 13:08:59,844 - [NOTICE] simulation.solve(889): Cycle 35/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:09:00,060 - [NOTICE] simulation.solve(889): Cycle 35/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:09:00,475 - [NOTICE] simulation.solve(977): Capacity is now 4.826 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:09:00,476 - [NOTICE] simulation.solve(855): Cycle 36/328 (26.675 s elapsed) --------------------
# 2022-05-11 13:09:00,477 - [NOTICE] simulation.solve(889): Cycle 36/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:09:00,712 - [NOTICE] simulation.solve(889): Cycle 36/328, step 2/4: Rest for 5 min
# 2022-05-11 13:09:00,755 - [NOTICE] simulation.solve(889): Cycle 36/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:09:00,975 - [NOTICE] simulation.solve(889): Cycle 36/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:09:01,365 - [NOTICE] simulation.solve(977): Capacity is now 4.820 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:09:01,367 - [NOTICE] simulation.solve(855): Cycle 37/328 (27.565 s elapsed) --------------------
# 2022-05-11 13:09:01,367 - [NOTICE] simulation.solve(889): Cycle 37/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:09:01,619 - [NOTICE] simulation.solve(889): Cycle 37/328, step 2/4: Rest for 5 min
# 2022-05-11 13:09:01,678 - [NOTICE] simulation.solve(889): Cycle 37/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:09:01,904 - [NOTICE] simulation.solve(889): Cycle 37/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:09:02,230 - [NOTICE] simulation.solve(977): Capacity is now 4.814 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:09:02,231 - [NOTICE] simulation.solve(855): Cycle 38/328 (28.429 s elapsed) --------------------
# 2022-05-11 13:09:02,232 - [NOTICE] simulation.solve(889): Cycle 38/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:09:02,417 - [NOTICE] simulation.solve(889): Cycle 38/328, step 2/4: Rest for 5 min
# 2022-05-11 13:09:02,470 - [NOTICE] simulation.solve(889): Cycle 38/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:09:02,642 - [NOTICE] simulation.solve(889): Cycle 38/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:09:02,991 - [NOTICE] simulation.solve(977): Capacity is now 4.807 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:09:02,992 - [NOTICE] simulation.solve(855): Cycle 39/328 (29.190 s elapsed) --------------------
# 2022-05-11 13:09:02,992 - [NOTICE] simulation.solve(889): Cycle 39/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:09:03,152 - [NOTICE] simulation.solve(889): Cycle 39/328, step 2/4: Rest for 5 min
# 2022-05-11 13:09:03,199 - [NOTICE] simulation.solve(889): Cycle 39/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:09:03,351 - [NOTICE] simulation.solve(889): Cycle 39/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:09:03,675 - [NOTICE] simulation.solve(977): Capacity is now 4.801 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:09:03,676 - [NOTICE] simulation.solve(855): Cycle 40/328 (29.874 s elapsed) --------------------
# 2022-05-11 13:09:03,676 - [NOTICE] simulation.solve(889): Cycle 40/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:09:03,865 - [NOTICE] simulation.solve(889): Cycle 40/328, step 2/4: Rest for 5 min
# 2022-05-11 13:09:03,907 - [NOTICE] simulation.solve(889): Cycle 40/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:09:04,060 - [NOTICE] simulation.solve(889): Cycle 40/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:09:04,334 - [NOTICE] simulation.solve(977): Capacity is now 4.795 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:09:04,334 - [NOTICE] simulation.solve(855): Cycle 41/328 (30.533 s elapsed) --------------------
# 2022-05-11 13:09:04,335 - [NOTICE] simulation.solve(889): Cycle 41/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:09:04,546 - [NOTICE] simulation.solve(889): Cycle 41/328, step 2/4: Rest for 5 min
# 2022-05-11 13:09:04,586 - [NOTICE] simulation.solve(889): Cycle 41/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:09:04,750 - [NOTICE] simulation.solve(889): Cycle 41/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:09:05,066 - [NOTICE] simulation.solve(977): Capacity is now 4.789 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:09:05,066 - [NOTICE] simulation.solve(855): Cycle 42/328 (31.265 s elapsed) --------------------
# 2022-05-11 13:09:05,067 - [NOTICE] simulation.solve(889): Cycle 42/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:09:05,214 - [NOTICE] simulation.solve(889): Cycle 42/328, step 2/4: Rest for 5 min
# 2022-05-11 13:09:05,246 - [NOTICE] simulation.solve(889): Cycle 42/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:09:05,390 - [NOTICE] simulation.solve(889): Cycle 42/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:09:05,728 - [NOTICE] simulation.solve(977): Capacity is now 4.783 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:09:05,729 - [NOTICE] simulation.solve(855): Cycle 43/328 (31.928 s elapsed) --------------------
# 2022-05-11 13:09:05,730 - [NOTICE] simulation.solve(889): Cycle 43/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:09:05,918 - [NOTICE] simulation.solve(889): Cycle 43/328, step 2/4: Rest for 5 min
# 2022-05-11 13:09:05,956 - [NOTICE] simulation.solve(889): Cycle 43/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:09:06,090 - [NOTICE] simulation.solve(889): Cycle 43/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:09:06,366 - [NOTICE] simulation.solve(977): Capacity is now 4.777 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:09:06,367 - [NOTICE] simulation.solve(855): Cycle 44/328 (32.566 s elapsed) --------------------
# 2022-05-11 13:09:06,368 - [NOTICE] simulation.solve(889): Cycle 44/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:09:06,544 - [NOTICE] simulation.solve(889): Cycle 44/328, step 2/4: Rest for 5 min
# 2022-05-11 13:09:06,583 - [NOTICE] simulation.solve(889): Cycle 44/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:09:06,731 - [NOTICE] simulation.solve(889): Cycle 44/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:09:07,045 - [NOTICE] simulation.solve(977): Capacity is now 4.771 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:09:07,046 - [NOTICE] simulation.solve(855): Cycle 45/328 (33.245 s elapsed) --------------------
# 2022-05-11 13:09:07,046 - [NOTICE] simulation.solve(889): Cycle 45/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:09:07,229 - [NOTICE] simulation.solve(889): Cycle 45/328, step 2/4: Rest for 5 min
# 2022-05-11 13:09:07,263 - [NOTICE] simulation.solve(889): Cycle 45/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:09:07,426 - [NOTICE] simulation.solve(889): Cycle 45/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:09:07,743 - [NOTICE] simulation.solve(977): Capacity is now 4.765 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:09:07,744 - [NOTICE] simulation.solve(855): Cycle 46/328 (33.942 s elapsed) --------------------
# 2022-05-11 13:09:07,745 - [NOTICE] simulation.solve(889): Cycle 46/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:09:07,914 - [NOTICE] simulation.solve(889): Cycle 46/328, step 2/4: Rest for 5 min
# 2022-05-11 13:09:07,947 - [NOTICE] simulation.solve(889): Cycle 46/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:09:08,107 - [NOTICE] simulation.solve(889): Cycle 46/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:09:08,411 - [NOTICE] simulation.solve(977): Capacity is now 4.758 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:09:08,412 - [NOTICE] simulation.solve(855): Cycle 47/328 (34.611 s elapsed) --------------------
# 2022-05-11 13:09:08,412 - [NOTICE] simulation.solve(889): Cycle 47/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:09:08,609 - [NOTICE] simulation.solve(889): Cycle 47/328, step 2/4: Rest for 5 min
# 2022-05-11 13:09:08,649 - [NOTICE] simulation.solve(889): Cycle 47/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:09:08,843 - [NOTICE] simulation.solve(889): Cycle 47/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:09:09,142 - [NOTICE] simulation.solve(977): Capacity is now 4.752 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:09:09,143 - [NOTICE] simulation.solve(855): Cycle 48/328 (35.341 s elapsed) --------------------
# 2022-05-11 13:09:09,143 - [NOTICE] simulation.solve(889): Cycle 48/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:09:09,290 - [NOTICE] simulation.solve(889): Cycle 48/328, step 2/4: Rest for 5 min
# 2022-05-11 13:09:09,324 - [NOTICE] simulation.solve(889): Cycle 48/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:09:09,497 - [NOTICE] simulation.solve(889): Cycle 48/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:09:09,844 - [NOTICE] simulation.solve(977): Capacity is now 4.746 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:09:09,845 - [NOTICE] simulation.solve(855): Cycle 49/328 (36.044 s elapsed) --------------------
# 2022-05-11 13:09:09,846 - [NOTICE] simulation.solve(889): Cycle 49/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:09:10,026 - [NOTICE] simulation.solve(889): Cycle 49/328, step 2/4: Rest for 5 min
# 2022-05-11 13:09:10,057 - [NOTICE] simulation.solve(889): Cycle 49/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:09:10,204 - [NOTICE] simulation.solve(889): Cycle 49/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:09:10,506 - [NOTICE] simulation.solve(977): Capacity is now 4.740 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:09:10,507 - [NOTICE] simulation.solve(855): Cycle 50/328 (36.705 s elapsed) --------------------
# 2022-05-11 13:09:10,507 - [NOTICE] simulation.solve(889): Cycle 50/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:09:10,692 - [NOTICE] simulation.solve(889): Cycle 50/328, step 2/4: Rest for 5 min
# 2022-05-11 13:09:10,728 - [NOTICE] simulation.solve(889): Cycle 50/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:09:10,891 - [NOTICE] simulation.solve(889): Cycle 50/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:09:11,200 - [NOTICE] simulation.solve(977): Capacity is now 4.734 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:09:11,201 - [NOTICE] simulation.solve(855): Cycle 51/328 (37.400 s elapsed) --------------------
# 2022-05-11 13:09:11,202 - [NOTICE] simulation.solve(889): Cycle 51/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:09:11,349 - [NOTICE] simulation.solve(889): Cycle 51/328, step 2/4: Rest for 5 min
# 2022-05-11 13:09:11,384 - [NOTICE] simulation.solve(889): Cycle 51/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:09:11,548 - [NOTICE] simulation.solve(889): Cycle 51/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:09:11,961 - [NOTICE] simulation.solve(977): Capacity is now 4.728 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:09:11,962 - [NOTICE] simulation.solve(855): Cycle 52/328 (38.160 s elapsed) --------------------
# 2022-05-11 13:09:11,962 - [NOTICE] simulation.solve(889): Cycle 52/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:09:12,116 - [NOTICE] simulation.solve(889): Cycle 52/328, step 2/4: Rest for 5 min
# 2022-05-11 13:09:12,149 - [NOTICE] simulation.solve(889): Cycle 52/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:09:12,281 - [NOTICE] simulation.solve(889): Cycle 52/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:09:12,595 - [NOTICE] simulation.solve(977): Capacity is now 4.722 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:09:12,596 - [NOTICE] simulation.solve(855): Cycle 53/328 (38.794 s elapsed) --------------------
# 2022-05-11 13:09:12,596 - [NOTICE] simulation.solve(889): Cycle 53/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:09:12,767 - [NOTICE] simulation.solve(889): Cycle 53/328, step 2/4: Rest for 5 min
# 2022-05-11 13:09:12,808 - [NOTICE] simulation.solve(889): Cycle 53/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:09:12,958 - [NOTICE] simulation.solve(889): Cycle 53/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:09:13,232 - [NOTICE] simulation.solve(977): Capacity is now 4.716 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:09:13,234 - [NOTICE] simulation.solve(855): Cycle 54/328 (39.432 s elapsed) --------------------
# 2022-05-11 13:09:13,234 - [NOTICE] simulation.solve(889): Cycle 54/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:09:13,381 - [NOTICE] simulation.solve(889): Cycle 54/328, step 2/4: Rest for 5 min
# 2022-05-11 13:09:13,430 - [NOTICE] simulation.solve(889): Cycle 54/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:09:13,574 - [NOTICE] simulation.solve(889): Cycle 54/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:09:13,904 - [NOTICE] simulation.solve(977): Capacity is now 4.710 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:09:13,904 - [NOTICE] simulation.solve(855): Cycle 55/328 (40.103 s elapsed) --------------------
# 2022-05-11 13:09:13,905 - [NOTICE] simulation.solve(889): Cycle 55/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:09:14,076 - [NOTICE] simulation.solve(889): Cycle 55/328, step 2/4: Rest for 5 min
# 2022-05-11 13:09:14,108 - [NOTICE] simulation.solve(889): Cycle 55/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:09:14,230 - [NOTICE] simulation.solve(889): Cycle 55/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:09:14,540 - [NOTICE] simulation.solve(977): Capacity is now 4.704 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:09:14,541 - [NOTICE] simulation.solve(855): Cycle 56/328 (40.739 s elapsed) --------------------
# 2022-05-11 13:09:14,542 - [NOTICE] simulation.solve(889): Cycle 56/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:09:14,722 - [NOTICE] simulation.solve(889): Cycle 56/328, step 2/4: Rest for 5 min
# 2022-05-11 13:09:14,763 - [NOTICE] simulation.solve(889): Cycle 56/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:09:14,923 - [NOTICE] simulation.solve(889): Cycle 56/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:09:15,272 - [NOTICE] simulation.solve(977): Capacity is now 4.698 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:09:15,273 - [NOTICE] simulation.solve(855): Cycle 57/328 (41.471 s elapsed) --------------------
# 2022-05-11 13:09:15,274 - [NOTICE] simulation.solve(889): Cycle 57/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:09:15,450 - [NOTICE] simulation.solve(889): Cycle 57/328, step 2/4: Rest for 5 min
# 2022-05-11 13:09:15,480 - [NOTICE] simulation.solve(889): Cycle 57/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:09:15,632 - [NOTICE] simulation.solve(889): Cycle 57/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:09:15,916 - [NOTICE] simulation.solve(977): Capacity is now 4.692 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:09:15,917 - [NOTICE] simulation.solve(855): Cycle 58/328 (42.116 s elapsed) --------------------
# 2022-05-11 13:09:15,918 - [NOTICE] simulation.solve(889): Cycle 58/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:09:16,064 - [NOTICE] simulation.solve(889): Cycle 58/328, step 2/4: Rest for 5 min
# 2022-05-11 13:09:16,096 - [NOTICE] simulation.solve(889): Cycle 58/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:09:16,246 - [NOTICE] simulation.solve(889): Cycle 58/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:09:16,544 - [NOTICE] simulation.solve(977): Capacity is now 4.686 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:09:16,545 - [NOTICE] simulation.solve(855): Cycle 59/328 (42.743 s elapsed) --------------------
# 2022-05-11 13:09:16,546 - [NOTICE] simulation.solve(889): Cycle 59/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:09:16,710 - [NOTICE] simulation.solve(889): Cycle 59/328, step 2/4: Rest for 5 min
# 2022-05-11 13:09:16,743 - [NOTICE] simulation.solve(889): Cycle 59/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:09:16,882 - [NOTICE] simulation.solve(889): Cycle 59/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:09:17,159 - [NOTICE] simulation.solve(977): Capacity is now 4.680 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:09:17,160 - [NOTICE] simulation.solve(855): Cycle 60/328 (43.358 s elapsed) --------------------
# 2022-05-11 13:09:17,160 - [NOTICE] simulation.solve(889): Cycle 60/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:09:17,321 - [NOTICE] simulation.solve(889): Cycle 60/328, step 2/4: Rest for 5 min
# 2022-05-11 13:09:17,366 - [NOTICE] simulation.solve(889): Cycle 60/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:09:17,539 - [NOTICE] simulation.solve(889): Cycle 60/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:09:17,817 - [NOTICE] simulation.solve(977): Capacity is now 4.674 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:09:17,818 - [NOTICE] simulation.solve(855): Cycle 61/328 (44.016 s elapsed) --------------------
# 2022-05-11 13:09:17,818 - [NOTICE] simulation.solve(889): Cycle 61/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:09:17,957 - [NOTICE] simulation.solve(889): Cycle 61/328, step 2/4: Rest for 5 min
# 2022-05-11 13:09:17,989 - [NOTICE] simulation.solve(889): Cycle 61/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:09:18,126 - [NOTICE] simulation.solve(889): Cycle 61/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:09:18,454 - [NOTICE] simulation.solve(977): Capacity is now 4.668 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:09:18,454 - [NOTICE] simulation.solve(855): Cycle 62/328 (44.653 s elapsed) --------------------
# 2022-05-11 13:09:18,455 - [NOTICE] simulation.solve(889): Cycle 62/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:09:18,618 - [NOTICE] simulation.solve(889): Cycle 62/328, step 2/4: Rest for 5 min
# 2022-05-11 13:09:18,655 - [NOTICE] simulation.solve(889): Cycle 62/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:09:18,800 - [NOTICE] simulation.solve(889): Cycle 62/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:09:19,070 - [NOTICE] simulation.solve(977): Capacity is now 4.662 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:09:19,070 - [NOTICE] simulation.solve(855): Cycle 63/328 (45.269 s elapsed) --------------------
# 2022-05-11 13:09:19,071 - [NOTICE] simulation.solve(889): Cycle 63/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:09:19,227 - [NOTICE] simulation.solve(889): Cycle 63/328, step 2/4: Rest for 5 min
# 2022-05-11 13:09:19,265 - [NOTICE] simulation.solve(889): Cycle 63/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:09:19,425 - [NOTICE] simulation.solve(889): Cycle 63/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:09:19,761 - [NOTICE] simulation.solve(977): Capacity is now 4.656 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:09:19,762 - [NOTICE] simulation.solve(855): Cycle 64/328 (45.961 s elapsed) --------------------
# 2022-05-11 13:09:19,763 - [NOTICE] simulation.solve(889): Cycle 64/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:09:19,915 - [NOTICE] simulation.solve(889): Cycle 64/328, step 2/4: Rest for 5 min
# 2022-05-11 13:09:19,948 - [NOTICE] simulation.solve(889): Cycle 64/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:09:20,101 - [NOTICE] simulation.solve(889): Cycle 64/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:09:20,392 - [NOTICE] simulation.solve(977): Capacity is now 4.650 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:09:20,393 - [NOTICE] simulation.solve(855): Cycle 65/328 (46.592 s elapsed) --------------------
# 2022-05-11 13:09:20,394 - [NOTICE] simulation.solve(889): Cycle 65/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:09:20,565 - [NOTICE] simulation.solve(889): Cycle 65/328, step 2/4: Rest for 5 min
# 2022-05-11 13:09:20,611 - [NOTICE] simulation.solve(889): Cycle 65/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:09:20,772 - [NOTICE] simulation.solve(889): Cycle 65/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:09:21,043 - [NOTICE] simulation.solve(977): Capacity is now 4.644 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:09:21,043 - [NOTICE] simulation.solve(855): Cycle 66/328 (47.241 s elapsed) --------------------
# 2022-05-11 13:09:21,044 - [NOTICE] simulation.solve(889): Cycle 66/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:09:21,229 - [NOTICE] simulation.solve(889): Cycle 66/328, step 2/4: Rest for 5 min
# 2022-05-11 13:09:21,274 - [NOTICE] simulation.solve(889): Cycle 66/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:09:21,447 - [NOTICE] simulation.solve(889): Cycle 66/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:09:21,797 - [NOTICE] simulation.solve(977): Capacity is now 4.638 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:09:21,798 - [NOTICE] simulation.solve(855): Cycle 67/328 (47.997 s elapsed) --------------------
# 2022-05-11 13:09:21,799 - [NOTICE] simulation.solve(889): Cycle 67/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:09:21,939 - [NOTICE] simulation.solve(889): Cycle 67/328, step 2/4: Rest for 5 min
# 2022-05-11 13:09:21,970 - [NOTICE] simulation.solve(889): Cycle 67/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:09:22,112 - [NOTICE] simulation.solve(889): Cycle 67/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:09:22,408 - [NOTICE] simulation.solve(977): Capacity is now 4.632 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:09:22,409 - [NOTICE] simulation.solve(855): Cycle 68/328 (48.607 s elapsed) --------------------
# 2022-05-11 13:09:22,410 - [NOTICE] simulation.solve(889): Cycle 68/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:09:22,573 - [NOTICE] simulation.solve(889): Cycle 68/328, step 2/4: Rest for 5 min
# 2022-05-11 13:09:22,614 - [NOTICE] simulation.solve(889): Cycle 68/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:09:22,774 - [NOTICE] simulation.solve(889): Cycle 68/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:09:23,062 - [NOTICE] simulation.solve(977): Capacity is now 4.626 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:09:23,063 - [NOTICE] simulation.solve(855): Cycle 69/328 (49.261 s elapsed) --------------------
# 2022-05-11 13:09:23,063 - [NOTICE] simulation.solve(889): Cycle 69/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:09:23,208 - [NOTICE] simulation.solve(889): Cycle 69/328, step 2/4: Rest for 5 min
# 2022-05-11 13:09:23,246 - [NOTICE] simulation.solve(889): Cycle 69/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:09:23,393 - [NOTICE] simulation.solve(889): Cycle 69/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:09:23,688 - [NOTICE] simulation.solve(977): Capacity is now 4.620 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:09:23,689 - [NOTICE] simulation.solve(855): Cycle 70/328 (49.887 s elapsed) --------------------
# 2022-05-11 13:09:23,690 - [NOTICE] simulation.solve(889): Cycle 70/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:09:23,870 - [NOTICE] simulation.solve(889): Cycle 70/328, step 2/4: Rest for 5 min
# 2022-05-11 13:09:23,909 - [NOTICE] simulation.solve(889): Cycle 70/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:09:24,065 - [NOTICE] simulation.solve(889): Cycle 70/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:09:24,343 - [NOTICE] simulation.solve(977): Capacity is now 4.614 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:09:24,344 - [NOTICE] simulation.solve(855): Cycle 71/328 (50.542 s elapsed) --------------------
# 2022-05-11 13:09:24,344 - [NOTICE] simulation.solve(889): Cycle 71/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:09:24,515 - [NOTICE] simulation.solve(889): Cycle 71/328, step 2/4: Rest for 5 min
# 2022-05-11 13:09:24,548 - [NOTICE] simulation.solve(889): Cycle 71/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:09:24,703 - [NOTICE] simulation.solve(889): Cycle 71/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:09:25,025 - [NOTICE] simulation.solve(977): Capacity is now 4.608 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:09:25,026 - [NOTICE] simulation.solve(855): Cycle 72/328 (51.224 s elapsed) --------------------
# 2022-05-11 13:09:25,027 - [NOTICE] simulation.solve(889): Cycle 72/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:09:25,189 - [NOTICE] simulation.solve(889): Cycle 72/328, step 2/4: Rest for 5 min
# 2022-05-11 13:09:25,219 - [NOTICE] simulation.solve(889): Cycle 72/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:09:25,348 - [NOTICE] simulation.solve(889): Cycle 72/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:09:25,637 - [NOTICE] simulation.solve(977): Capacity is now 4.602 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:09:25,638 - [NOTICE] simulation.solve(855): Cycle 73/328 (51.836 s elapsed) --------------------
# 2022-05-11 13:09:25,639 - [NOTICE] simulation.solve(889): Cycle 73/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:09:25,806 - [NOTICE] simulation.solve(889): Cycle 73/328, step 2/4: Rest for 5 min
# 2022-05-11 13:09:25,843 - [NOTICE] simulation.solve(889): Cycle 73/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:09:25,995 - [NOTICE] simulation.solve(889): Cycle 73/328, step 4/4: Hold at 4.2V until C/50
# ...
# 2022-05-11 13:12:04,444 - [NOTICE] simulation.solve(889): Cycle 305/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:12:04,844 - [NOTICE] simulation.solve(977): Capacity is now 3.346 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:12:04,844 - [NOTICE] simulation.solve(855): Cycle 306/328 (3 minutes, 31 seconds elapsed) --------------------
# 2022-05-11 13:12:04,845 - [NOTICE] simulation.solve(889): Cycle 306/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:12:04,947 - [NOTICE] simulation.solve(889): Cycle 306/328, step 2/4: Rest for 5 min
# 2022-05-11 13:12:04,980 - [NOTICE] simulation.solve(889): Cycle 306/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:12:05,089 - [NOTICE] simulation.solve(889): Cycle 306/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:12:05,525 - [NOTICE] simulation.solve(977): Capacity is now 3.341 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:12:05,526 - [NOTICE] simulation.solve(855): Cycle 307/328 (3 minutes, 32 seconds elapsed) --------------------
# 2022-05-11 13:12:05,526 - [NOTICE] simulation.solve(889): Cycle 307/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:12:05,647 - [NOTICE] simulation.solve(889): Cycle 307/328, step 2/4: Rest for 5 min
# 2022-05-11 13:12:05,678 - [NOTICE] simulation.solve(889): Cycle 307/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:12:05,769 - [NOTICE] simulation.solve(889): Cycle 307/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:12:06,111 - [NOTICE] simulation.solve(977): Capacity is now 3.336 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:12:06,112 - [NOTICE] simulation.solve(855): Cycle 308/328 (3 minutes, 32 seconds elapsed) --------------------
# 2022-05-11 13:12:06,113 - [NOTICE] simulation.solve(889): Cycle 308/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:12:06,233 - [NOTICE] simulation.solve(889): Cycle 308/328, step 2/4: Rest for 5 min
# 2022-05-11 13:12:06,267 - [NOTICE] simulation.solve(889): Cycle 308/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:12:06,395 - [NOTICE] simulation.solve(889): Cycle 308/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:12:06,771 - [NOTICE] simulation.solve(977): Capacity is now 3.331 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:12:06,773 - [NOTICE] simulation.solve(855): Cycle 309/328 (3 minutes, 33 seconds elapsed) --------------------
# 2022-05-11 13:12:06,773 - [NOTICE] simulation.solve(889): Cycle 309/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:12:06,901 - [NOTICE] simulation.solve(889): Cycle 309/328, step 2/4: Rest for 5 min
# 2022-05-11 13:12:06,933 - [NOTICE] simulation.solve(889): Cycle 309/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:12:07,029 - [NOTICE] simulation.solve(889): Cycle 309/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:12:07,373 - [NOTICE] simulation.solve(977): Capacity is now 3.326 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:12:07,374 - [NOTICE] simulation.solve(855): Cycle 310/328 (3 minutes, 34 seconds elapsed) --------------------
# 2022-05-11 13:12:07,375 - [NOTICE] simulation.solve(889): Cycle 310/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:12:07,531 - [NOTICE] simulation.solve(889): Cycle 310/328, step 2/4: Rest for 5 min
# 2022-05-11 13:12:07,573 - [NOTICE] simulation.solve(889): Cycle 310/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:12:07,714 - [NOTICE] simulation.solve(889): Cycle 310/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:12:08,093 - [NOTICE] simulation.solve(977): Capacity is now 3.321 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:12:08,093 - [NOTICE] simulation.solve(855): Cycle 311/328 (3 minutes, 34 seconds elapsed) --------------------
# 2022-05-11 13:12:08,094 - [NOTICE] simulation.solve(889): Cycle 311/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:12:08,203 - [NOTICE] simulation.solve(889): Cycle 311/328, step 2/4: Rest for 5 min
# 2022-05-11 13:12:08,235 - [NOTICE] simulation.solve(889): Cycle 311/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:12:08,330 - [NOTICE] simulation.solve(889): Cycle 311/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:12:08,702 - [NOTICE] simulation.solve(977): Capacity is now 3.316 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:12:08,703 - [NOTICE] simulation.solve(855): Cycle 312/328 (3 minutes, 35 seconds elapsed) --------------------
# 2022-05-11 13:12:08,703 - [NOTICE] simulation.solve(889): Cycle 312/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:12:08,832 - [NOTICE] simulation.solve(889): Cycle 312/328, step 2/4: Rest for 5 min
# 2022-05-11 13:12:08,870 - [NOTICE] simulation.solve(889): Cycle 312/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:12:08,974 - [NOTICE] simulation.solve(889): Cycle 312/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:12:09,304 - [NOTICE] simulation.solve(977): Capacity is now 3.311 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:12:09,304 - [NOTICE] simulation.solve(855): Cycle 313/328 (3 minutes, 36 seconds elapsed) --------------------
# 2022-05-11 13:12:09,305 - [NOTICE] simulation.solve(889): Cycle 313/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:12:09,424 - [NOTICE] simulation.solve(889): Cycle 313/328, step 2/4: Rest for 5 min
# 2022-05-11 13:12:09,463 - [NOTICE] simulation.solve(889): Cycle 313/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:12:09,570 - [NOTICE] simulation.solve(889): Cycle 313/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:12:09,963 - [NOTICE] simulation.solve(977): Capacity is now 3.306 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:12:09,963 - [NOTICE] simulation.solve(855): Cycle 314/328 (3 minutes, 36 seconds elapsed) --------------------
# 2022-05-11 13:12:09,964 - [NOTICE] simulation.solve(889): Cycle 314/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:12:10,104 - [NOTICE] simulation.solve(889): Cycle 314/328, step 2/4: Rest for 5 min
# 2022-05-11 13:12:10,135 - [NOTICE] simulation.solve(889): Cycle 314/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:12:10,232 - [NOTICE] simulation.solve(889): Cycle 314/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:12:10,563 - [NOTICE] simulation.solve(977): Capacity is now 3.301 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:12:10,563 - [NOTICE] simulation.solve(855): Cycle 315/328 (3 minutes, 37 seconds elapsed) --------------------
# 2022-05-11 13:12:10,564 - [NOTICE] simulation.solve(889): Cycle 315/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:12:10,699 - [NOTICE] simulation.solve(889): Cycle 315/328, step 2/4: Rest for 5 min
# 2022-05-11 13:12:10,734 - [NOTICE] simulation.solve(889): Cycle 315/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:12:10,850 - [NOTICE] simulation.solve(889): Cycle 315/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:12:11,294 - [NOTICE] simulation.solve(977): Capacity is now 3.296 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:12:11,295 - [NOTICE] simulation.solve(855): Cycle 316/328 (3 minutes, 37 seconds elapsed) --------------------
# 2022-05-11 13:12:11,296 - [NOTICE] simulation.solve(889): Cycle 316/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:12:11,443 - [NOTICE] simulation.solve(889): Cycle 316/328, step 2/4: Rest for 5 min
# 2022-05-11 13:12:11,475 - [NOTICE] simulation.solve(889): Cycle 316/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:12:11,583 - [NOTICE] simulation.solve(889): Cycle 316/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:12:12,000 - [NOTICE] simulation.solve(977): Capacity is now 3.290 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:12:12,001 - [NOTICE] simulation.solve(855): Cycle 317/328 (3 minutes, 38 seconds elapsed) --------------------
# 2022-05-11 13:12:12,002 - [NOTICE] simulation.solve(889): Cycle 317/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:12:12,133 - [NOTICE] simulation.solve(889): Cycle 317/328, step 2/4: Rest for 5 min
# 2022-05-11 13:12:12,166 - [NOTICE] simulation.solve(889): Cycle 317/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:12:12,257 - [NOTICE] simulation.solve(889): Cycle 317/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:12:12,862 - [NOTICE] simulation.solve(977): Capacity is now 3.285 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:12:12,863 - [NOTICE] simulation.solve(855): Cycle 318/328 (3 minutes, 39 seconds elapsed) --------------------
# 2022-05-11 13:12:12,864 - [NOTICE] simulation.solve(889): Cycle 318/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:12:12,986 - [NOTICE] simulation.solve(889): Cycle 318/328, step 2/4: Rest for 5 min
# 2022-05-11 13:12:13,026 - [NOTICE] simulation.solve(889): Cycle 318/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:12:13,138 - [NOTICE] simulation.solve(889): Cycle 318/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:12:13,508 - [NOTICE] simulation.solve(977): Capacity is now 3.280 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:12:13,508 - [NOTICE] simulation.solve(855): Cycle 319/328 (3 minutes, 40 seconds elapsed) --------------------
# 2022-05-11 13:12:13,509 - [NOTICE] simulation.solve(889): Cycle 319/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:12:13,632 - [NOTICE] simulation.solve(889): Cycle 319/328, step 2/4: Rest for 5 min
# 2022-05-11 13:12:13,666 - [NOTICE] simulation.solve(889): Cycle 319/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:12:13,775 - [NOTICE] simulation.solve(889): Cycle 319/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:12:14,166 - [NOTICE] simulation.solve(977): Capacity is now 3.275 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:12:14,167 - [NOTICE] simulation.solve(855): Cycle 320/328 (3 minutes, 40 seconds elapsed) --------------------
# 2022-05-11 13:12:14,168 - [NOTICE] simulation.solve(889): Cycle 320/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:12:14,279 - [NOTICE] simulation.solve(889): Cycle 320/328, step 2/4: Rest for 5 min
# 2022-05-11 13:12:14,314 - [NOTICE] simulation.solve(889): Cycle 320/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:12:14,432 - [NOTICE] simulation.solve(889): Cycle 320/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:12:14,983 - [NOTICE] simulation.solve(977): Capacity is now 3.270 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:12:14,984 - [NOTICE] simulation.solve(855): Cycle 321/328 (3 minutes, 41 seconds elapsed) --------------------
# 2022-05-11 13:12:14,985 - [NOTICE] simulation.solve(889): Cycle 321/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:12:15,153 - [NOTICE] simulation.solve(889): Cycle 321/328, step 2/4: Rest for 5 min
# 2022-05-11 13:12:15,197 - [NOTICE] simulation.solve(889): Cycle 321/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:12:15,351 - [NOTICE] simulation.solve(889): Cycle 321/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:12:15,888 - [NOTICE] simulation.solve(977): Capacity is now 3.265 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:12:15,889 - [NOTICE] simulation.solve(855): Cycle 322/328 (3 minutes, 42 seconds elapsed) --------------------
# 2022-05-11 13:12:15,889 - [NOTICE] simulation.solve(889): Cycle 322/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:12:16,049 - [NOTICE] simulation.solve(889): Cycle 322/328, step 2/4: Rest for 5 min
# 2022-05-11 13:12:16,096 - [NOTICE] simulation.solve(889): Cycle 322/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:12:16,234 - [NOTICE] simulation.solve(889): Cycle 322/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:12:16,732 - [NOTICE] simulation.solve(977): Capacity is now 3.260 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:12:16,733 - [NOTICE] simulation.solve(855): Cycle 323/328 (3 minutes, 43 seconds elapsed) --------------------
# 2022-05-11 13:12:16,733 - [NOTICE] simulation.solve(889): Cycle 323/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:12:16,915 - [NOTICE] simulation.solve(889): Cycle 323/328, step 2/4: Rest for 5 min
# 2022-05-11 13:12:16,962 - [NOTICE] simulation.solve(889): Cycle 323/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:12:17,129 - [NOTICE] simulation.solve(889): Cycle 323/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:12:17,579 - [NOTICE] simulation.solve(977): Capacity is now 3.255 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:12:17,580 - [NOTICE] simulation.solve(855): Cycle 324/328 (3 minutes, 44 seconds elapsed) --------------------
# 2022-05-11 13:12:17,581 - [NOTICE] simulation.solve(889): Cycle 324/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:12:17,752 - [NOTICE] simulation.solve(889): Cycle 324/328, step 2/4: Rest for 5 min
# 2022-05-11 13:12:17,795 - [NOTICE] simulation.solve(889): Cycle 324/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:12:17,966 - [NOTICE] simulation.solve(889): Cycle 324/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:12:18,436 - [NOTICE] simulation.solve(977): Capacity is now 3.250 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:12:18,438 - [NOTICE] simulation.solve(855): Cycle 325/328 (3 minutes, 45 seconds elapsed) --------------------
# 2022-05-11 13:12:18,439 - [NOTICE] simulation.solve(889): Cycle 325/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:12:18,597 - [NOTICE] simulation.solve(889): Cycle 325/328, step 2/4: Rest for 5 min
# 2022-05-11 13:12:18,645 - [NOTICE] simulation.solve(889): Cycle 325/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:12:18,808 - [NOTICE] simulation.solve(889): Cycle 325/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:12:19,322 - [NOTICE] simulation.solve(977): Capacity is now 3.245 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:12:19,322 - [NOTICE] simulation.solve(855): Cycle 326/328 (3 minutes, 46 seconds elapsed) --------------------
# 2022-05-11 13:12:19,323 - [NOTICE] simulation.solve(889): Cycle 326/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:12:19,468 - [NOTICE] simulation.solve(889): Cycle 326/328, step 2/4: Rest for 5 min
# 2022-05-11 13:12:19,509 - [NOTICE] simulation.solve(889): Cycle 326/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:12:19,685 - [NOTICE] simulation.solve(889): Cycle 326/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:12:20,246 - [NOTICE] simulation.solve(977): Capacity is now 3.240 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:12:20,247 - [NOTICE] simulation.solve(855): Cycle 327/328 (3 minutes, 46 seconds elapsed) --------------------
# 2022-05-11 13:12:20,248 - [NOTICE] simulation.solve(889): Cycle 327/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:12:20,383 - [NOTICE] simulation.solve(889): Cycle 327/328, step 2/4: Rest for 5 min
# 2022-05-11 13:12:20,424 - [NOTICE] simulation.solve(889): Cycle 327/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:12:20,614 - [NOTICE] simulation.solve(889): Cycle 327/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:12:21,040 - [NOTICE] simulation.solve(977): Capacity is now 3.235 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:12:21,041 - [NOTICE] simulation.solve(855): Cycle 328/328 (3 minutes, 47 seconds elapsed) --------------------
# 2022-05-11 13:12:21,041 - [NOTICE] simulation.solve(889): Cycle 328/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:12:21,170 - [NOTICE] simulation.solve(889): Cycle 328/328, step 2/4: Rest for 5 min
# 2022-05-11 13:12:21,206 - [NOTICE] simulation.solve(889): Cycle 328/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:12:21,305 - [NOTICE] simulation.solve(889): Cycle 328/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:12:21,682 - [NOTICE] simulation.solve(977): Capacity is now 3.230 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:12:21,688 - [NOTICE] simulation.solve(1011): Finish experiment simulation, took 3 minutes, 48 seconds

# %%
parameter_values = get_parameter_values()
parameter_values.update(
    {

        "Positive electrode LAM constant proportional term [s-1]": 8.7864e-07,
        "Negative electrode LAM constant proportional term [s-1]": 1.08031e-05,
        "SEI kinetic rate constant [m.s-1]": 1.6297e-15,
        "EC diffusivity [m2.s-1]": 2e-18,
        "Positive electrode LAM constant exponential term": 2,
        "Negative electrode LAM constant exponential term": 2,
        "Negative electrode active material volume fraction": eps_n_data,
        "Positive electrode active material volume fraction": eps_p_data,
        # "Negative electrode porosity": 0.3,
        # "Positive electrode porosity": 0.3,
        # "Separator porosity": 0.4,
        "Negative electrode porosity": 0.28,
        "Positive electrode porosity": 0.28,
        "Separator porosity": 0.38,
        # "Negative electrode porosity": 0.15,
        # "Positive electrode porosity": 0.15,
        # "Separator porosity": 0.2,
    },
    check_already_exists=False,
)
# all_sumvars_dict = cycle_adaptive_simulation(spm, parameter_values, experiment, save_at_cycles=2)

# %%
sim_long = pybamm.Simulation(spm, experiment=experiment, parameter_values=parameter_values, 
                            solver=pybamm.CasadiSolver("safe"))
sol_long_1 = sim_long.solve(initial_soc=1)
long_sol_output_1 =sol_long_1.summary_variables
# Out:
# 2022-05-11 13:12:25,529 - [NOTICE] simulation.solve(855): Cycle 1/328 (34.660 ms elapsed) --------------------
# 2022-05-11 13:12:25,529 - [NOTICE] simulation.solve(889): Cycle 1/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:12:25,809 - [NOTICE] simulation.solve(889): Cycle 1/328, step 2/4: Rest for 5 min
# 2022-05-11 13:12:25,950 - [NOTICE] simulation.solve(889): Cycle 1/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:12:26,239 - [NOTICE] simulation.solve(889): Cycle 1/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:12:26,910 - [NOTICE] simulation.solve(977): Capacity is now 5.032 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:12:26,912 - [NOTICE] simulation.solve(855): Cycle 2/328 (1.417 s elapsed) --------------------
# 2022-05-11 13:12:26,912 - [NOTICE] simulation.solve(889): Cycle 2/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:12:27,095 - [NOTICE] simulation.solve(889): Cycle 2/328, step 2/4: Rest for 5 min
# 2022-05-11 13:12:27,128 - [NOTICE] simulation.solve(889): Cycle 2/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:12:27,281 - [NOTICE] simulation.solve(889): Cycle 2/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:12:27,555 - [NOTICE] simulation.solve(977): Capacity is now 5.026 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:12:27,555 - [NOTICE] simulation.solve(855): Cycle 3/328 (2.061 s elapsed) --------------------
# 2022-05-11 13:12:27,556 - [NOTICE] simulation.solve(889): Cycle 3/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:12:27,717 - [NOTICE] simulation.solve(889): Cycle 3/328, step 2/4: Rest for 5 min
# 2022-05-11 13:12:27,757 - [NOTICE] simulation.solve(889): Cycle 3/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:12:27,907 - [NOTICE] simulation.solve(889): Cycle 3/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:12:28,236 - [NOTICE] simulation.solve(977): Capacity is now 5.020 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:12:28,237 - [NOTICE] simulation.solve(855): Cycle 4/328 (2.743 s elapsed) --------------------
# 2022-05-11 13:12:28,237 - [NOTICE] simulation.solve(889): Cycle 4/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:12:28,401 - [NOTICE] simulation.solve(889): Cycle 4/328, step 2/4: Rest for 5 min
# 2022-05-11 13:12:28,434 - [NOTICE] simulation.solve(889): Cycle 4/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:12:28,574 - [NOTICE] simulation.solve(889): Cycle 4/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:12:28,887 - [NOTICE] simulation.solve(977): Capacity is now 5.014 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:12:28,888 - [NOTICE] simulation.solve(855): Cycle 5/328 (3.394 s elapsed) --------------------
# 2022-05-11 13:12:28,889 - [NOTICE] simulation.solve(889): Cycle 5/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:12:29,061 - [NOTICE] simulation.solve(889): Cycle 5/328, step 2/4: Rest for 5 min
# 2022-05-11 13:12:29,103 - [NOTICE] simulation.solve(889): Cycle 5/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:12:29,270 - [NOTICE] simulation.solve(889): Cycle 5/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:12:29,547 - [NOTICE] simulation.solve(977): Capacity is now 5.008 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:12:29,548 - [NOTICE] simulation.solve(855): Cycle 6/328 (4.054 s elapsed) --------------------
# 2022-05-11 13:12:29,550 - [NOTICE] simulation.solve(889): Cycle 6/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:12:29,712 - [NOTICE] simulation.solve(889): Cycle 6/328, step 2/4: Rest for 5 min
# 2022-05-11 13:12:29,750 - [NOTICE] simulation.solve(889): Cycle 6/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:12:29,919 - [NOTICE] simulation.solve(889): Cycle 6/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:12:30,255 - [NOTICE] simulation.solve(977): Capacity is now 5.002 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:12:30,256 - [NOTICE] simulation.solve(855): Cycle 7/328 (4.762 s elapsed) --------------------
# 2022-05-11 13:12:30,256 - [NOTICE] simulation.solve(889): Cycle 7/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:12:30,414 - [NOTICE] simulation.solve(889): Cycle 7/328, step 2/4: Rest for 5 min
# 2022-05-11 13:12:30,445 - [NOTICE] simulation.solve(889): Cycle 7/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:12:30,587 - [NOTICE] simulation.solve(889): Cycle 7/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:12:30,928 - [NOTICE] simulation.solve(977): Capacity is now 4.996 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:12:30,928 - [NOTICE] simulation.solve(855): Cycle 8/328 (5.434 s elapsed) --------------------
# 2022-05-11 13:12:30,929 - [NOTICE] simulation.solve(889): Cycle 8/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:12:31,117 - [NOTICE] simulation.solve(889): Cycle 8/328, step 2/4: Rest for 5 min
# 2022-05-11 13:12:31,157 - [NOTICE] simulation.solve(889): Cycle 8/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:12:31,310 - [NOTICE] simulation.solve(889): Cycle 8/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:12:31,586 - [NOTICE] simulation.solve(977): Capacity is now 4.990 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:12:31,587 - [NOTICE] simulation.solve(855): Cycle 9/328 (6.092 s elapsed) --------------------
# 2022-05-11 13:12:31,587 - [NOTICE] simulation.solve(889): Cycle 9/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:12:31,776 - [NOTICE] simulation.solve(889): Cycle 9/328, step 2/4: Rest for 5 min
# 2022-05-11 13:12:31,815 - [NOTICE] simulation.solve(889): Cycle 9/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:12:31,991 - [NOTICE] simulation.solve(889): Cycle 9/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:12:32,335 - [NOTICE] simulation.solve(977): Capacity is now 4.984 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:12:32,336 - [NOTICE] simulation.solve(855): Cycle 10/328 (6.842 s elapsed) --------------------
# 2022-05-11 13:12:32,337 - [NOTICE] simulation.solve(889): Cycle 10/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:12:32,484 - [NOTICE] simulation.solve(889): Cycle 10/328, step 2/4: Rest for 5 min
# 2022-05-11 13:12:32,517 - [NOTICE] simulation.solve(889): Cycle 10/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:12:32,668 - [NOTICE] simulation.solve(889): Cycle 10/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:12:32,992 - [NOTICE] simulation.solve(977): Capacity is now 4.978 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:12:32,993 - [NOTICE] simulation.solve(855): Cycle 11/328 (7.498 s elapsed) --------------------
# 2022-05-11 13:12:32,994 - [NOTICE] simulation.solve(889): Cycle 11/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:12:33,202 - [NOTICE] simulation.solve(889): Cycle 11/328, step 2/4: Rest for 5 min
# 2022-05-11 13:12:33,242 - [NOTICE] simulation.solve(889): Cycle 11/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:12:33,431 - [NOTICE] simulation.solve(889): Cycle 11/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:12:33,700 - [NOTICE] simulation.solve(977): Capacity is now 4.976 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:12:33,701 - [NOTICE] simulation.solve(855): Cycle 12/328 (8.207 s elapsed) --------------------
# 2022-05-11 13:12:33,702 - [NOTICE] simulation.solve(889): Cycle 12/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:12:33,898 - [NOTICE] simulation.solve(889): Cycle 12/328, step 2/4: Rest for 5 min
# 2022-05-11 13:12:33,938 - [NOTICE] simulation.solve(889): Cycle 12/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:12:34,093 - [NOTICE] simulation.solve(889): Cycle 12/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:12:34,406 - [NOTICE] simulation.solve(977): Capacity is now 4.966 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:12:34,407 - [NOTICE] simulation.solve(855): Cycle 13/328 (8.912 s elapsed) --------------------
# 2022-05-11 13:12:34,407 - [NOTICE] simulation.solve(889): Cycle 13/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:12:34,589 - [NOTICE] simulation.solve(889): Cycle 13/328, step 2/4: Rest for 5 min
# 2022-05-11 13:12:34,621 - [NOTICE] simulation.solve(889): Cycle 13/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:12:34,750 - [NOTICE] simulation.solve(889): Cycle 13/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:12:35,029 - [NOTICE] simulation.solve(977): Capacity is now 4.963 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:12:35,030 - [NOTICE] simulation.solve(855): Cycle 14/328 (9.535 s elapsed) --------------------
# 2022-05-11 13:12:35,031 - [NOTICE] simulation.solve(889): Cycle 14/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:12:35,224 - [NOTICE] simulation.solve(889): Cycle 14/328, step 2/4: Rest for 5 min
# 2022-05-11 13:12:35,271 - [NOTICE] simulation.solve(889): Cycle 14/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:12:35,434 - [NOTICE] simulation.solve(889): Cycle 14/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:12:35,733 - [NOTICE] simulation.solve(977): Capacity is now 4.954 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:12:35,734 - [NOTICE] simulation.solve(855): Cycle 15/328 (10.239 s elapsed) --------------------
# 2022-05-11 13:12:35,734 - [NOTICE] simulation.solve(889): Cycle 15/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:12:35,891 - [NOTICE] simulation.solve(889): Cycle 15/328, step 2/4: Rest for 5 min
# 2022-05-11 13:12:35,922 - [NOTICE] simulation.solve(889): Cycle 15/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:12:36,054 - [NOTICE] simulation.solve(889): Cycle 15/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:12:36,373 - [NOTICE] simulation.solve(977): Capacity is now 4.948 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:12:36,373 - [NOTICE] simulation.solve(855): Cycle 16/328 (10.879 s elapsed) --------------------
# 2022-05-11 13:12:36,374 - [NOTICE] simulation.solve(889): Cycle 16/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:12:36,543 - [NOTICE] simulation.solve(889): Cycle 16/328, step 2/4: Rest for 5 min
# 2022-05-11 13:12:36,580 - [NOTICE] simulation.solve(889): Cycle 16/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:12:36,719 - [NOTICE] simulation.solve(889): Cycle 16/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:12:36,988 - [NOTICE] simulation.solve(977): Capacity is now 4.942 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:12:36,989 - [NOTICE] simulation.solve(855): Cycle 17/328 (11.495 s elapsed) --------------------
# 2022-05-11 13:12:36,990 - [NOTICE] simulation.solve(889): Cycle 17/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:12:37,156 - [NOTICE] simulation.solve(889): Cycle 17/328, step 2/4: Rest for 5 min
# 2022-05-11 13:12:37,189 - [NOTICE] simulation.solve(889): Cycle 17/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:12:37,335 - [NOTICE] simulation.solve(889): Cycle 17/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:12:37,712 - [NOTICE] simulation.solve(977): Capacity is now 4.935 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:12:37,713 - [NOTICE] simulation.solve(855): Cycle 18/328 (12.219 s elapsed) --------------------
# 2022-05-11 13:12:37,713 - [NOTICE] simulation.solve(889): Cycle 18/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:12:37,861 - [NOTICE] simulation.solve(889): Cycle 18/328, step 2/4: Rest for 5 min
# 2022-05-11 13:12:37,892 - [NOTICE] simulation.solve(889): Cycle 18/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:12:38,027 - [NOTICE] simulation.solve(889): Cycle 18/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:12:38,319 - [NOTICE] simulation.solve(977): Capacity is now 4.932 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:12:38,321 - [NOTICE] simulation.solve(855): Cycle 19/328 (12.826 s elapsed) --------------------
# 2022-05-11 13:12:38,321 - [NOTICE] simulation.solve(889): Cycle 19/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:12:38,495 - [NOTICE] simulation.solve(889): Cycle 19/328, step 2/4: Rest for 5 min
# 2022-05-11 13:12:38,527 - [NOTICE] simulation.solve(889): Cycle 19/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:12:38,660 - [NOTICE] simulation.solve(889): Cycle 19/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:12:38,964 - [NOTICE] simulation.solve(977): Capacity is now 4.923 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:12:38,965 - [NOTICE] simulation.solve(855): Cycle 20/328 (13.470 s elapsed) --------------------
# 2022-05-11 13:12:38,965 - [NOTICE] simulation.solve(889): Cycle 20/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:12:39,121 - [NOTICE] simulation.solve(889): Cycle 20/328, step 2/4: Rest for 5 min
# 2022-05-11 13:12:39,156 - [NOTICE] simulation.solve(889): Cycle 20/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:12:39,290 - [NOTICE] simulation.solve(889): Cycle 20/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:12:39,544 - [NOTICE] simulation.solve(977): Capacity is now 4.919 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:12:39,545 - [NOTICE] simulation.solve(855): Cycle 21/328 (14.050 s elapsed) --------------------
# 2022-05-11 13:12:39,545 - [NOTICE] simulation.solve(889): Cycle 21/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:12:39,714 - [NOTICE] simulation.solve(889): Cycle 21/328, step 2/4: Rest for 5 min
# 2022-05-11 13:12:39,750 - [NOTICE] simulation.solve(889): Cycle 21/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:12:39,894 - [NOTICE] simulation.solve(889): Cycle 21/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:12:40,225 - [NOTICE] simulation.solve(977): Capacity is now 4.913 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:12:40,225 - [NOTICE] simulation.solve(855): Cycle 22/328 (14.732 s elapsed) --------------------
# 2022-05-11 13:12:40,226 - [NOTICE] simulation.solve(889): Cycle 22/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:12:40,383 - [NOTICE] simulation.solve(889): Cycle 22/328, step 2/4: Rest for 5 min
# 2022-05-11 13:12:40,415 - [NOTICE] simulation.solve(889): Cycle 22/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:12:40,554 - [NOTICE] simulation.solve(889): Cycle 22/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:12:40,851 - [NOTICE] simulation.solve(977): Capacity is now 4.906 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:12:40,851 - [NOTICE] simulation.solve(855): Cycle 23/328 (15.358 s elapsed) --------------------
# 2022-05-11 13:12:40,852 - [NOTICE] simulation.solve(889): Cycle 23/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:12:41,026 - [NOTICE] simulation.solve(889): Cycle 23/328, step 2/4: Rest for 5 min
# 2022-05-11 13:12:41,068 - [NOTICE] simulation.solve(889): Cycle 23/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:12:41,207 - [NOTICE] simulation.solve(889): Cycle 23/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:12:41,478 - [NOTICE] simulation.solve(977): Capacity is now 4.900 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:12:41,478 - [NOTICE] simulation.solve(855): Cycle 24/328 (15.984 s elapsed) --------------------
# 2022-05-11 13:12:41,479 - [NOTICE] simulation.solve(889): Cycle 24/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:12:41,616 - [NOTICE] simulation.solve(889): Cycle 24/328, step 2/4: Rest for 5 min
# 2022-05-11 13:12:41,647 - [NOTICE] simulation.solve(889): Cycle 24/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:12:41,797 - [NOTICE] simulation.solve(889): Cycle 24/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:12:42,110 - [NOTICE] simulation.solve(977): Capacity is now 4.894 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:12:42,110 - [NOTICE] simulation.solve(855): Cycle 25/328 (16.616 s elapsed) --------------------
# 2022-05-11 13:12:42,111 - [NOTICE] simulation.solve(889): Cycle 25/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:12:42,267 - [NOTICE] simulation.solve(889): Cycle 25/328, step 2/4: Rest for 5 min
# 2022-05-11 13:12:42,301 - [NOTICE] simulation.solve(889): Cycle 25/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:12:42,446 - [NOTICE] simulation.solve(889): Cycle 25/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:12:42,720 - [NOTICE] simulation.solve(977): Capacity is now 4.887 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:12:42,721 - [NOTICE] simulation.solve(855): Cycle 26/328 (17.227 s elapsed) --------------------
# 2022-05-11 13:12:42,721 - [NOTICE] simulation.solve(889): Cycle 26/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:12:42,881 - [NOTICE] simulation.solve(889): Cycle 26/328, step 2/4: Rest for 5 min
# 2022-05-11 13:12:42,925 - [NOTICE] simulation.solve(889): Cycle 26/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:12:43,062 - [NOTICE] simulation.solve(889): Cycle 26/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:12:43,358 - [NOTICE] simulation.solve(977): Capacity is now 4.881 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:12:43,359 - [NOTICE] simulation.solve(855): Cycle 27/328 (17.865 s elapsed) --------------------
# 2022-05-11 13:12:43,360 - [NOTICE] simulation.solve(889): Cycle 27/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:12:43,521 - [NOTICE] simulation.solve(889): Cycle 27/328, step 2/4: Rest for 5 min
# 2022-05-11 13:12:43,554 - [NOTICE] simulation.solve(889): Cycle 27/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:12:43,682 - [NOTICE] simulation.solve(889): Cycle 27/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:12:43,950 - [NOTICE] simulation.solve(977): Capacity is now 4.875 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:12:43,951 - [NOTICE] simulation.solve(855): Cycle 28/328 (18.456 s elapsed) --------------------
# 2022-05-11 13:12:43,951 - [NOTICE] simulation.solve(889): Cycle 28/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:12:44,123 - [NOTICE] simulation.solve(889): Cycle 28/328, step 2/4: Rest for 5 min
# 2022-05-11 13:12:44,157 - [NOTICE] simulation.solve(889): Cycle 28/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:12:44,297 - [NOTICE] simulation.solve(889): Cycle 28/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:12:44,589 - [NOTICE] simulation.solve(977): Capacity is now 4.869 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:12:44,590 - [NOTICE] simulation.solve(855): Cycle 29/328 (19.096 s elapsed) --------------------
# 2022-05-11 13:12:44,591 - [NOTICE] simulation.solve(889): Cycle 29/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:12:44,752 - [NOTICE] simulation.solve(889): Cycle 29/328, step 2/4: Rest for 5 min
# 2022-05-11 13:12:44,790 - [NOTICE] simulation.solve(889): Cycle 29/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:12:44,918 - [NOTICE] simulation.solve(889): Cycle 29/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:12:45,197 - [NOTICE] simulation.solve(977): Capacity is now 4.863 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:12:45,198 - [NOTICE] simulation.solve(855): Cycle 30/328 (19.704 s elapsed) --------------------
# 2022-05-11 13:12:45,199 - [NOTICE] simulation.solve(889): Cycle 30/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:12:45,350 - [NOTICE] simulation.solve(889): Cycle 30/328, step 2/4: Rest for 5 min
# 2022-05-11 13:12:45,382 - [NOTICE] simulation.solve(889): Cycle 30/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:12:45,530 - [NOTICE] simulation.solve(889): Cycle 30/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:12:45,849 - [NOTICE] simulation.solve(977): Capacity is now 4.856 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:12:45,850 - [NOTICE] simulation.solve(855): Cycle 31/328 (20.356 s elapsed) --------------------
# 2022-05-11 13:12:45,850 - [NOTICE] simulation.solve(889): Cycle 31/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:12:46,022 - [NOTICE] simulation.solve(889): Cycle 31/328, step 2/4: Rest for 5 min
# 2022-05-11 13:12:46,058 - [NOTICE] simulation.solve(889): Cycle 31/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:12:46,228 - [NOTICE] simulation.solve(889): Cycle 31/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:12:46,513 - [NOTICE] simulation.solve(977): Capacity is now 4.850 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:12:46,514 - [NOTICE] simulation.solve(855): Cycle 32/328 (21.019 s elapsed) --------------------
# 2022-05-11 13:12:46,515 - [NOTICE] simulation.solve(889): Cycle 32/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:12:46,678 - [NOTICE] simulation.solve(889): Cycle 32/328, step 2/4: Rest for 5 min
# 2022-05-11 13:12:46,713 - [NOTICE] simulation.solve(889): Cycle 32/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:12:46,869 - [NOTICE] simulation.solve(889): Cycle 32/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:12:47,141 - [NOTICE] simulation.solve(977): Capacity is now 4.844 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:12:47,142 - [NOTICE] simulation.solve(855): Cycle 33/328 (21.648 s elapsed) --------------------
# 2022-05-11 13:12:47,142 - [NOTICE] simulation.solve(889): Cycle 33/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:12:47,297 - [NOTICE] simulation.solve(889): Cycle 33/328, step 2/4: Rest for 5 min
# 2022-05-11 13:12:47,329 - [NOTICE] simulation.solve(889): Cycle 33/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:12:47,480 - [NOTICE] simulation.solve(889): Cycle 33/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:12:47,781 - [NOTICE] simulation.solve(977): Capacity is now 4.838 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:12:47,782 - [NOTICE] simulation.solve(855): Cycle 34/328 (22.288 s elapsed) --------------------
# 2022-05-11 13:12:47,783 - [NOTICE] simulation.solve(889): Cycle 34/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:12:47,937 - [NOTICE] simulation.solve(889): Cycle 34/328, step 2/4: Rest for 5 min
# 2022-05-11 13:12:47,970 - [NOTICE] simulation.solve(889): Cycle 34/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:12:48,099 - [NOTICE] simulation.solve(889): Cycle 34/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:12:48,366 - [NOTICE] simulation.solve(977): Capacity is now 4.832 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:12:48,366 - [NOTICE] simulation.solve(855): Cycle 35/328 (22.872 s elapsed) --------------------
# 2022-05-11 13:12:48,367 - [NOTICE] simulation.solve(889): Cycle 35/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:12:48,526 - [NOTICE] simulation.solve(889): Cycle 35/328, step 2/4: Rest for 5 min
# 2022-05-11 13:12:48,566 - [NOTICE] simulation.solve(889): Cycle 35/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:12:48,727 - [NOTICE] simulation.solve(889): Cycle 35/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:12:49,031 - [NOTICE] simulation.solve(977): Capacity is now 4.825 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:12:49,031 - [NOTICE] simulation.solve(855): Cycle 36/328 (23.537 s elapsed) --------------------
# 2022-05-11 13:12:49,032 - [NOTICE] simulation.solve(889): Cycle 36/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:12:49,191 - [NOTICE] simulation.solve(889): Cycle 36/328, step 2/4: Rest for 5 min
# 2022-05-11 13:12:49,224 - [NOTICE] simulation.solve(889): Cycle 36/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:12:49,351 - [NOTICE] simulation.solve(889): Cycle 36/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:12:49,650 - [NOTICE] simulation.solve(977): Capacity is now 4.819 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:12:49,651 - [NOTICE] simulation.solve(855): Cycle 37/328 (24.157 s elapsed) --------------------
# 2022-05-11 13:12:49,652 - [NOTICE] simulation.solve(889): Cycle 37/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:12:49,815 - [NOTICE] simulation.solve(889): Cycle 37/328, step 2/4: Rest for 5 min
# 2022-05-11 13:12:49,852 - [NOTICE] simulation.solve(889): Cycle 37/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:12:50,013 - [NOTICE] simulation.solve(889): Cycle 37/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:12:50,328 - [NOTICE] simulation.solve(977): Capacity is now 4.813 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:12:50,328 - [NOTICE] simulation.solve(855): Cycle 38/328 (24.834 s elapsed) --------------------
# 2022-05-11 13:12:50,329 - [NOTICE] simulation.solve(889): Cycle 38/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:12:50,493 - [NOTICE] simulation.solve(889): Cycle 38/328, step 2/4: Rest for 5 min
# 2022-05-11 13:12:50,527 - [NOTICE] simulation.solve(889): Cycle 38/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:12:50,661 - [NOTICE] simulation.solve(889): Cycle 38/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:12:50,959 - [NOTICE] simulation.solve(977): Capacity is now 4.807 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:12:50,959 - [NOTICE] simulation.solve(855): Cycle 39/328 (25.465 s elapsed) --------------------
# 2022-05-11 13:12:50,960 - [NOTICE] simulation.solve(889): Cycle 39/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:12:51,139 - [NOTICE] simulation.solve(889): Cycle 39/328, step 2/4: Rest for 5 min
# 2022-05-11 13:12:51,173 - [NOTICE] simulation.solve(889): Cycle 39/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:12:51,337 - [NOTICE] simulation.solve(889): Cycle 39/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:12:51,597 - [NOTICE] simulation.solve(977): Capacity is now 4.801 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:12:51,598 - [NOTICE] simulation.solve(855): Cycle 40/328 (26.104 s elapsed) --------------------
# 2022-05-11 13:12:51,598 - [NOTICE] simulation.solve(889): Cycle 40/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:12:51,758 - [NOTICE] simulation.solve(889): Cycle 40/328, step 2/4: Rest for 5 min
# 2022-05-11 13:12:51,795 - [NOTICE] simulation.solve(889): Cycle 40/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:12:51,950 - [NOTICE] simulation.solve(889): Cycle 40/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:12:52,288 - [NOTICE] simulation.solve(977): Capacity is now 4.795 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:12:52,289 - [NOTICE] simulation.solve(855): Cycle 41/328 (26.794 s elapsed) --------------------
# 2022-05-11 13:12:52,289 - [NOTICE] simulation.solve(889): Cycle 41/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:12:52,440 - [NOTICE] simulation.solve(889): Cycle 41/328, step 2/4: Rest for 5 min
# 2022-05-11 13:12:52,474 - [NOTICE] simulation.solve(889): Cycle 41/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:12:52,606 - [NOTICE] simulation.solve(889): Cycle 41/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:12:52,882 - [NOTICE] simulation.solve(977): Capacity is now 4.788 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:12:52,883 - [NOTICE] simulation.solve(855): Cycle 42/328 (27.389 s elapsed) --------------------
# 2022-05-11 13:12:52,884 - [NOTICE] simulation.solve(889): Cycle 42/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:12:53,038 - [NOTICE] simulation.solve(889): Cycle 42/328, step 2/4: Rest for 5 min
# 2022-05-11 13:12:53,072 - [NOTICE] simulation.solve(889): Cycle 42/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:12:53,224 - [NOTICE] simulation.solve(889): Cycle 42/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:12:53,554 - [NOTICE] simulation.solve(977): Capacity is now 4.782 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:12:53,554 - [NOTICE] simulation.solve(855): Cycle 43/328 (28.060 s elapsed) --------------------
# 2022-05-11 13:12:53,555 - [NOTICE] simulation.solve(889): Cycle 43/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:12:53,703 - [NOTICE] simulation.solve(889): Cycle 43/328, step 2/4: Rest for 5 min
# 2022-05-11 13:12:53,734 - [NOTICE] simulation.solve(889): Cycle 43/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:12:53,881 - [NOTICE] simulation.solve(889): Cycle 43/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:12:54,278 - [NOTICE] simulation.solve(977): Capacity is now 4.776 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:12:54,278 - [NOTICE] simulation.solve(855): Cycle 44/328 (28.784 s elapsed) --------------------
# 2022-05-11 13:12:54,279 - [NOTICE] simulation.solve(889): Cycle 44/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:12:54,511 - [NOTICE] simulation.solve(889): Cycle 44/328, step 2/4: Rest for 5 min
# 2022-05-11 13:12:54,618 - [NOTICE] simulation.solve(889): Cycle 44/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:12:54,762 - [NOTICE] simulation.solve(889): Cycle 44/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:12:55,069 - [NOTICE] simulation.solve(977): Capacity is now 4.770 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:12:55,070 - [NOTICE] simulation.solve(855): Cycle 45/328 (29.575 s elapsed) --------------------
# 2022-05-11 13:12:55,070 - [NOTICE] simulation.solve(889): Cycle 45/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:12:55,258 - [NOTICE] simulation.solve(889): Cycle 45/328, step 2/4: Rest for 5 min
# 2022-05-11 13:12:55,295 - [NOTICE] simulation.solve(889): Cycle 45/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:12:55,431 - [NOTICE] simulation.solve(889): Cycle 45/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:12:55,713 - [NOTICE] simulation.solve(977): Capacity is now 4.764 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:12:55,714 - [NOTICE] simulation.solve(855): Cycle 46/328 (30.219 s elapsed) --------------------
# 2022-05-11 13:12:55,714 - [NOTICE] simulation.solve(889): Cycle 46/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:12:55,869 - [NOTICE] simulation.solve(889): Cycle 46/328, step 2/4: Rest for 5 min
# 2022-05-11 13:12:55,900 - [NOTICE] simulation.solve(889): Cycle 46/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:12:56,043 - [NOTICE] simulation.solve(889): Cycle 46/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:12:56,339 - [NOTICE] simulation.solve(977): Capacity is now 4.758 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:12:56,340 - [NOTICE] simulation.solve(855): Cycle 47/328 (30.845 s elapsed) --------------------
# 2022-05-11 13:12:56,340 - [NOTICE] simulation.solve(889): Cycle 47/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:12:56,505 - [NOTICE] simulation.solve(889): Cycle 47/328, step 2/4: Rest for 5 min
# 2022-05-11 13:12:56,538 - [NOTICE] simulation.solve(889): Cycle 47/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:12:56,680 - [NOTICE] simulation.solve(889): Cycle 47/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:12:56,933 - [NOTICE] simulation.solve(977): Capacity is now 4.752 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:12:56,934 - [NOTICE] simulation.solve(855): Cycle 48/328 (31.439 s elapsed) --------------------
# 2022-05-11 13:12:56,934 - [NOTICE] simulation.solve(889): Cycle 48/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:12:57,111 - [NOTICE] simulation.solve(889): Cycle 48/328, step 2/4: Rest for 5 min
# 2022-05-11 13:12:57,143 - [NOTICE] simulation.solve(889): Cycle 48/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:12:57,308 - [NOTICE] simulation.solve(889): Cycle 48/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:12:57,630 - [NOTICE] simulation.solve(977): Capacity is now 4.746 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:12:57,631 - [NOTICE] simulation.solve(855): Cycle 49/328 (32.137 s elapsed) --------------------
# 2022-05-11 13:12:57,631 - [NOTICE] simulation.solve(889): Cycle 49/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:12:57,784 - [NOTICE] simulation.solve(889): Cycle 49/328, step 2/4: Rest for 5 min
# 2022-05-11 13:12:57,816 - [NOTICE] simulation.solve(889): Cycle 49/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:12:57,949 - [NOTICE] simulation.solve(889): Cycle 49/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:12:58,227 - [NOTICE] simulation.solve(977): Capacity is now 4.740 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:12:58,227 - [NOTICE] simulation.solve(855): Cycle 50/328 (32.733 s elapsed) --------------------
# 2022-05-11 13:12:58,228 - [NOTICE] simulation.solve(889): Cycle 50/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:12:58,386 - [NOTICE] simulation.solve(889): Cycle 50/328, step 2/4: Rest for 5 min
# 2022-05-11 13:12:58,421 - [NOTICE] simulation.solve(889): Cycle 50/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:12:58,581 - [NOTICE] simulation.solve(889): Cycle 50/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:12:58,931 - [NOTICE] simulation.solve(977): Capacity is now 4.734 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:12:58,932 - [NOTICE] simulation.solve(855): Cycle 51/328 (33.437 s elapsed) --------------------
# 2022-05-11 13:12:58,933 - [NOTICE] simulation.solve(889): Cycle 51/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:12:59,093 - [NOTICE] simulation.solve(889): Cycle 51/328, step 2/4: Rest for 5 min
# 2022-05-11 13:12:59,128 - [NOTICE] simulation.solve(889): Cycle 51/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:12:59,266 - [NOTICE] simulation.solve(889): Cycle 51/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:12:59,571 - [NOTICE] simulation.solve(977): Capacity is now 4.727 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:12:59,572 - [NOTICE] simulation.solve(855): Cycle 52/328 (34.078 s elapsed) --------------------
# 2022-05-11 13:12:59,573 - [NOTICE] simulation.solve(889): Cycle 52/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:12:59,746 - [NOTICE] simulation.solve(889): Cycle 52/328, step 2/4: Rest for 5 min
# 2022-05-11 13:12:59,780 - [NOTICE] simulation.solve(889): Cycle 52/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:12:59,912 - [NOTICE] simulation.solve(889): Cycle 52/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:13:00,208 - [NOTICE] simulation.solve(977): Capacity is now 4.721 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:13:00,209 - [NOTICE] simulation.solve(855): Cycle 53/328 (34.715 s elapsed) --------------------
# 2022-05-11 13:13:00,209 - [NOTICE] simulation.solve(889): Cycle 53/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:13:00,391 - [NOTICE] simulation.solve(889): Cycle 53/328, step 2/4: Rest for 5 min
# 2022-05-11 13:13:00,424 - [NOTICE] simulation.solve(889): Cycle 53/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:13:00,559 - [NOTICE] simulation.solve(889): Cycle 53/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:13:00,849 - [NOTICE] simulation.solve(977): Capacity is now 4.715 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:13:00,849 - [NOTICE] simulation.solve(855): Cycle 54/328 (35.355 s elapsed) --------------------
# 2022-05-11 13:13:00,850 - [NOTICE] simulation.solve(889): Cycle 54/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:13:01,002 - [NOTICE] simulation.solve(889): Cycle 54/328, step 2/4: Rest for 5 min
# 2022-05-11 13:13:01,037 - [NOTICE] simulation.solve(889): Cycle 54/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:13:01,153 - [NOTICE] simulation.solve(889): Cycle 54/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:13:01,433 - [NOTICE] simulation.solve(977): Capacity is now 4.709 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:13:01,434 - [NOTICE] simulation.solve(855): Cycle 55/328 (35.940 s elapsed) --------------------
# 2022-05-11 13:13:01,436 - [NOTICE] simulation.solve(889): Cycle 55/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:13:01,605 - [NOTICE] simulation.solve(889): Cycle 55/328, step 2/4: Rest for 5 min
# 2022-05-11 13:13:01,637 - [NOTICE] simulation.solve(889): Cycle 55/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:13:01,766 - [NOTICE] simulation.solve(889): Cycle 55/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:13:02,051 - [NOTICE] simulation.solve(977): Capacity is now 4.703 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:13:02,052 - [NOTICE] simulation.solve(855): Cycle 56/328 (36.558 s elapsed) --------------------
# 2022-05-11 13:13:02,053 - [NOTICE] simulation.solve(889): Cycle 56/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:13:02,193 - [NOTICE] simulation.solve(889): Cycle 56/328, step 2/4: Rest for 5 min
# 2022-05-11 13:13:02,223 - [NOTICE] simulation.solve(889): Cycle 56/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:13:02,354 - [NOTICE] simulation.solve(889): Cycle 56/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:13:02,650 - [NOTICE] simulation.solve(977): Capacity is now 4.697 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:13:02,650 - [NOTICE] simulation.solve(855): Cycle 57/328 (37.156 s elapsed) --------------------
# 2022-05-11 13:13:02,651 - [NOTICE] simulation.solve(889): Cycle 57/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:13:02,811 - [NOTICE] simulation.solve(889): Cycle 57/328, step 2/4: Rest for 5 min
# 2022-05-11 13:13:02,846 - [NOTICE] simulation.solve(889): Cycle 57/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:13:03,004 - [NOTICE] simulation.solve(889): Cycle 57/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:13:03,264 - [NOTICE] simulation.solve(977): Capacity is now 4.691 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:13:03,266 - [NOTICE] simulation.solve(855): Cycle 58/328 (37.772 s elapsed) --------------------
# 2022-05-11 13:13:03,267 - [NOTICE] simulation.solve(889): Cycle 58/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:13:03,398 - [NOTICE] simulation.solve(889): Cycle 58/328, step 2/4: Rest for 5 min
# 2022-05-11 13:13:03,428 - [NOTICE] simulation.solve(889): Cycle 58/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:13:03,572 - [NOTICE] simulation.solve(889): Cycle 58/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:13:03,889 - [NOTICE] simulation.solve(977): Capacity is now 4.685 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:13:03,890 - [NOTICE] simulation.solve(855): Cycle 59/328 (38.396 s elapsed) --------------------
# 2022-05-11 13:13:03,891 - [NOTICE] simulation.solve(889): Cycle 59/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:13:04,050 - [NOTICE] simulation.solve(889): Cycle 59/328, step 2/4: Rest for 5 min
# 2022-05-11 13:13:04,081 - [NOTICE] simulation.solve(889): Cycle 59/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:13:04,205 - [NOTICE] simulation.solve(889): Cycle 59/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:13:04,464 - [NOTICE] simulation.solve(977): Capacity is now 4.679 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:13:04,464 - [NOTICE] simulation.solve(855): Cycle 60/328 (38.970 s elapsed) --------------------
# 2022-05-11 13:13:04,465 - [NOTICE] simulation.solve(889): Cycle 60/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:13:04,628 - [NOTICE] simulation.solve(889): Cycle 60/328, step 2/4: Rest for 5 min
# 2022-05-11 13:13:04,661 - [NOTICE] simulation.solve(889): Cycle 60/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:13:04,805 - [NOTICE] simulation.solve(889): Cycle 60/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:13:05,093 - [NOTICE] simulation.solve(977): Capacity is now 4.673 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:13:05,094 - [NOTICE] simulation.solve(855): Cycle 61/328 (39.600 s elapsed) --------------------
# 2022-05-11 13:13:05,095 - [NOTICE] simulation.solve(889): Cycle 61/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:13:05,267 - [NOTICE] simulation.solve(889): Cycle 61/328, step 2/4: Rest for 5 min
# 2022-05-11 13:13:05,299 - [NOTICE] simulation.solve(889): Cycle 61/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:13:05,420 - [NOTICE] simulation.solve(889): Cycle 61/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:13:05,733 - [NOTICE] simulation.solve(977): Capacity is now 4.667 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:13:05,734 - [NOTICE] simulation.solve(855): Cycle 62/328 (40.240 s elapsed) --------------------
# 2022-05-11 13:13:05,734 - [NOTICE] simulation.solve(889): Cycle 62/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:13:05,885 - [NOTICE] simulation.solve(889): Cycle 62/328, step 2/4: Rest for 5 min
# 2022-05-11 13:13:05,926 - [NOTICE] simulation.solve(889): Cycle 62/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:13:06,084 - [NOTICE] simulation.solve(889): Cycle 62/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:13:06,396 - [NOTICE] simulation.solve(977): Capacity is now 4.661 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:13:06,397 - [NOTICE] simulation.solve(855): Cycle 63/328 (40.902 s elapsed) --------------------
# 2022-05-11 13:13:06,398 - [NOTICE] simulation.solve(889): Cycle 63/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:13:06,574 - [NOTICE] simulation.solve(889): Cycle 63/328, step 2/4: Rest for 5 min
# 2022-05-11 13:13:06,621 - [NOTICE] simulation.solve(889): Cycle 63/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:13:06,801 - [NOTICE] simulation.solve(889): Cycle 63/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:13:07,108 - [NOTICE] simulation.solve(977): Capacity is now 4.655 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:13:07,109 - [NOTICE] simulation.solve(855): Cycle 64/328 (41.615 s elapsed) --------------------
# 2022-05-11 13:13:07,109 - [NOTICE] simulation.solve(889): Cycle 64/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:13:07,245 - [NOTICE] simulation.solve(889): Cycle 64/328, step 2/4: Rest for 5 min
# 2022-05-11 13:13:07,274 - [NOTICE] simulation.solve(889): Cycle 64/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:13:07,392 - [NOTICE] simulation.solve(889): Cycle 64/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:13:07,692 - [NOTICE] simulation.solve(977): Capacity is now 4.649 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:13:07,692 - [NOTICE] simulation.solve(855): Cycle 65/328 (42.198 s elapsed) --------------------
# 2022-05-11 13:13:07,693 - [NOTICE] simulation.solve(889): Cycle 65/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:13:07,867 - [NOTICE] simulation.solve(889): Cycle 65/328, step 2/4: Rest for 5 min
# 2022-05-11 13:13:07,900 - [NOTICE] simulation.solve(889): Cycle 65/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:13:08,058 - [NOTICE] simulation.solve(889): Cycle 65/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:13:08,351 - [NOTICE] simulation.solve(977): Capacity is now 4.643 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:13:08,352 - [NOTICE] simulation.solve(855): Cycle 66/328 (42.858 s elapsed) --------------------
# 2022-05-11 13:13:08,353 - [NOTICE] simulation.solve(889): Cycle 66/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:13:08,487 - [NOTICE] simulation.solve(889): Cycle 66/328, step 2/4: Rest for 5 min
# 2022-05-11 13:13:08,517 - [NOTICE] simulation.solve(889): Cycle 66/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:13:08,645 - [NOTICE] simulation.solve(889): Cycle 66/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:13:08,978 - [NOTICE] simulation.solve(977): Capacity is now 4.637 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:13:08,979 - [NOTICE] simulation.solve(855): Cycle 67/328 (43.485 s elapsed) --------------------
# 2022-05-11 13:13:08,980 - [NOTICE] simulation.solve(889): Cycle 67/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:13:09,153 - [NOTICE] simulation.solve(889): Cycle 67/328, step 2/4: Rest for 5 min
# 2022-05-11 13:13:09,198 - [NOTICE] simulation.solve(889): Cycle 67/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:13:09,355 - [NOTICE] simulation.solve(889): Cycle 67/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:13:09,667 - [NOTICE] simulation.solve(977): Capacity is now 4.631 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:13:09,668 - [NOTICE] simulation.solve(855): Cycle 68/328 (44.174 s elapsed) --------------------
# 2022-05-11 13:13:09,669 - [NOTICE] simulation.solve(889): Cycle 68/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:13:09,852 - [NOTICE] simulation.solve(889): Cycle 68/328, step 2/4: Rest for 5 min
# 2022-05-11 13:13:09,890 - [NOTICE] simulation.solve(889): Cycle 68/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:13:10,043 - [NOTICE] simulation.solve(889): Cycle 68/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:13:10,343 - [NOTICE] simulation.solve(977): Capacity is now 4.625 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:13:10,343 - [NOTICE] simulation.solve(855): Cycle 69/328 (44.849 s elapsed) --------------------
# 2022-05-11 13:13:10,344 - [NOTICE] simulation.solve(889): Cycle 69/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:13:10,477 - [NOTICE] simulation.solve(889): Cycle 69/328, step 2/4: Rest for 5 min
# 2022-05-11 13:13:10,512 - [NOTICE] simulation.solve(889): Cycle 69/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:13:10,672 - [NOTICE] simulation.solve(889): Cycle 69/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:13:11,040 - [NOTICE] simulation.solve(977): Capacity is now 4.619 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:13:11,041 - [NOTICE] simulation.solve(855): Cycle 70/328 (45.546 s elapsed) --------------------
# 2022-05-11 13:13:11,041 - [NOTICE] simulation.solve(889): Cycle 70/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:13:11,233 - [NOTICE] simulation.solve(889): Cycle 70/328, step 2/4: Rest for 5 min
# 2022-05-11 13:13:11,281 - [NOTICE] simulation.solve(889): Cycle 70/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:13:11,469 - [NOTICE] simulation.solve(889): Cycle 70/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:13:11,840 - [NOTICE] simulation.solve(977): Capacity is now 4.613 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:13:11,841 - [NOTICE] simulation.solve(855): Cycle 71/328 (46.346 s elapsed) --------------------
# 2022-05-11 13:13:11,841 - [NOTICE] simulation.solve(889): Cycle 71/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:13:12,014 - [NOTICE] simulation.solve(889): Cycle 71/328, step 2/4: Rest for 5 min
# 2022-05-11 13:13:12,053 - [NOTICE] simulation.solve(889): Cycle 71/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:13:12,205 - [NOTICE] simulation.solve(889): Cycle 71/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:13:12,502 - [NOTICE] simulation.solve(977): Capacity is now 4.607 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:13:12,502 - [NOTICE] simulation.solve(855): Cycle 72/328 (47.008 s elapsed) --------------------
# 2022-05-11 13:13:12,503 - [NOTICE] simulation.solve(889): Cycle 72/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:13:12,654 - [NOTICE] simulation.solve(889): Cycle 72/328, step 2/4: Rest for 5 min
# 2022-05-11 13:13:12,690 - [NOTICE] simulation.solve(889): Cycle 72/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:13:12,842 - [NOTICE] simulation.solve(889): Cycle 72/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:13:13,215 - [NOTICE] simulation.solve(977): Capacity is now 4.601 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:13:13,217 - [NOTICE] simulation.solve(855): Cycle 73/328 (47.722 s elapsed) --------------------
# 2022-05-11 13:13:13,217 - [NOTICE] simulation.solve(889): Cycle 73/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:13:13,368 - [NOTICE] simulation.solve(889): Cycle 73/328, step 2/4: Rest for 5 min
# 2022-05-11 13:13:13,402 - [NOTICE] simulation.solve(889): Cycle 73/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:13:13,536 - [NOTICE] simulation.solve(889): Cycle 73/328, step 4/4: Hold at 4.2V until C/50
# ...
# 2022-05-11 13:15:59,801 - [NOTICE] simulation.solve(889): Cycle 305/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:16:00,209 - [NOTICE] simulation.solve(977): Capacity is now 3.344 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:16:00,210 - [NOTICE] simulation.solve(855): Cycle 306/328 (3 minutes, 35 seconds elapsed) --------------------
# 2022-05-11 13:16:00,211 - [NOTICE] simulation.solve(889): Cycle 306/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:16:00,355 - [NOTICE] simulation.solve(889): Cycle 306/328, step 2/4: Rest for 5 min
# 2022-05-11 13:16:00,391 - [NOTICE] simulation.solve(889): Cycle 306/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:16:00,520 - [NOTICE] simulation.solve(889): Cycle 306/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:16:01,023 - [NOTICE] simulation.solve(977): Capacity is now 3.339 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:16:01,024 - [NOTICE] simulation.solve(855): Cycle 307/328 (3 minutes, 36 seconds elapsed) --------------------
# 2022-05-11 13:16:01,024 - [NOTICE] simulation.solve(889): Cycle 307/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:16:01,219 - [NOTICE] simulation.solve(889): Cycle 307/328, step 2/4: Rest for 5 min
# 2022-05-11 13:16:01,278 - [NOTICE] simulation.solve(889): Cycle 307/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:16:01,404 - [NOTICE] simulation.solve(889): Cycle 307/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:16:01,943 - [NOTICE] simulation.solve(977): Capacity is now 3.334 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:16:01,943 - [NOTICE] simulation.solve(855): Cycle 308/328 (3 minutes, 36 seconds elapsed) --------------------
# 2022-05-11 13:16:01,944 - [NOTICE] simulation.solve(889): Cycle 308/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:16:02,118 - [NOTICE] simulation.solve(889): Cycle 308/328, step 2/4: Rest for 5 min
# 2022-05-11 13:16:02,152 - [NOTICE] simulation.solve(889): Cycle 308/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:16:02,256 - [NOTICE] simulation.solve(889): Cycle 308/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:16:02,682 - [NOTICE] simulation.solve(977): Capacity is now 3.329 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:16:02,683 - [NOTICE] simulation.solve(855): Cycle 309/328 (3 minutes, 37 seconds elapsed) --------------------
# 2022-05-11 13:16:02,683 - [NOTICE] simulation.solve(889): Cycle 309/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:16:02,845 - [NOTICE] simulation.solve(889): Cycle 309/328, step 2/4: Rest for 5 min
# 2022-05-11 13:16:02,881 - [NOTICE] simulation.solve(889): Cycle 309/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:16:02,993 - [NOTICE] simulation.solve(889): Cycle 309/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:16:03,382 - [NOTICE] simulation.solve(977): Capacity is now 3.324 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:16:03,383 - [NOTICE] simulation.solve(855): Cycle 310/328 (3 minutes, 38 seconds elapsed) --------------------
# 2022-05-11 13:16:03,384 - [NOTICE] simulation.solve(889): Cycle 310/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:16:03,532 - [NOTICE] simulation.solve(889): Cycle 310/328, step 2/4: Rest for 5 min
# 2022-05-11 13:16:03,570 - [NOTICE] simulation.solve(889): Cycle 310/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:16:03,695 - [NOTICE] simulation.solve(889): Cycle 310/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:16:04,093 - [NOTICE] simulation.solve(977): Capacity is now 3.319 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:16:04,093 - [NOTICE] simulation.solve(855): Cycle 311/328 (3 minutes, 39 seconds elapsed) --------------------
# 2022-05-11 13:16:04,094 - [NOTICE] simulation.solve(889): Cycle 311/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:16:04,236 - [NOTICE] simulation.solve(889): Cycle 311/328, step 2/4: Rest for 5 min
# 2022-05-11 13:16:04,268 - [NOTICE] simulation.solve(889): Cycle 311/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:16:04,366 - [NOTICE] simulation.solve(889): Cycle 311/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:16:04,773 - [NOTICE] simulation.solve(977): Capacity is now 3.314 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:16:04,774 - [NOTICE] simulation.solve(855): Cycle 312/328 (3 minutes, 39 seconds elapsed) --------------------
# 2022-05-11 13:16:04,775 - [NOTICE] simulation.solve(889): Cycle 312/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:16:04,938 - [NOTICE] simulation.solve(889): Cycle 312/328, step 2/4: Rest for 5 min
# 2022-05-11 13:16:04,973 - [NOTICE] simulation.solve(889): Cycle 312/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:16:05,092 - [NOTICE] simulation.solve(889): Cycle 312/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:16:05,502 - [NOTICE] simulation.solve(977): Capacity is now 3.309 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:16:05,503 - [NOTICE] simulation.solve(855): Cycle 313/328 (3 minutes, 40 seconds elapsed) --------------------
# 2022-05-11 13:16:05,503 - [NOTICE] simulation.solve(889): Cycle 313/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:16:05,683 - [NOTICE] simulation.solve(889): Cycle 313/328, step 2/4: Rest for 5 min
# 2022-05-11 13:16:05,722 - [NOTICE] simulation.solve(889): Cycle 313/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:16:05,838 - [NOTICE] simulation.solve(889): Cycle 313/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:16:06,293 - [NOTICE] simulation.solve(977): Capacity is now 3.304 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:16:06,294 - [NOTICE] simulation.solve(855): Cycle 314/328 (3 minutes, 41 seconds elapsed) --------------------
# 2022-05-11 13:16:06,294 - [NOTICE] simulation.solve(889): Cycle 314/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:16:06,449 - [NOTICE] simulation.solve(889): Cycle 314/328, step 2/4: Rest for 5 min
# 2022-05-11 13:16:06,487 - [NOTICE] simulation.solve(889): Cycle 314/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:16:06,587 - [NOTICE] simulation.solve(889): Cycle 314/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:16:07,053 - [NOTICE] simulation.solve(977): Capacity is now 3.298 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:16:07,053 - [NOTICE] simulation.solve(855): Cycle 315/328 (3 minutes, 42 seconds elapsed) --------------------
# 2022-05-11 13:16:07,054 - [NOTICE] simulation.solve(889): Cycle 315/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:16:07,225 - [NOTICE] simulation.solve(889): Cycle 315/328, step 2/4: Rest for 5 min
# 2022-05-11 13:16:07,261 - [NOTICE] simulation.solve(889): Cycle 315/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:16:07,376 - [NOTICE] simulation.solve(889): Cycle 315/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:16:07,797 - [NOTICE] simulation.solve(977): Capacity is now 3.293 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:16:07,798 - [NOTICE] simulation.solve(855): Cycle 316/328 (3 minutes, 42 seconds elapsed) --------------------
# 2022-05-11 13:16:07,799 - [NOTICE] simulation.solve(889): Cycle 316/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:16:07,950 - [NOTICE] simulation.solve(889): Cycle 316/328, step 2/4: Rest for 5 min
# 2022-05-11 13:16:08,008 - [NOTICE] simulation.solve(889): Cycle 316/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:16:08,149 - [NOTICE] simulation.solve(889): Cycle 316/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:16:08,523 - [NOTICE] simulation.solve(977): Capacity is now 3.288 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:16:08,523 - [NOTICE] simulation.solve(855): Cycle 317/328 (3 minutes, 43 seconds elapsed) --------------------
# 2022-05-11 13:16:08,524 - [NOTICE] simulation.solve(889): Cycle 317/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:16:08,657 - [NOTICE] simulation.solve(889): Cycle 317/328, step 2/4: Rest for 5 min
# 2022-05-11 13:16:08,696 - [NOTICE] simulation.solve(889): Cycle 317/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:16:08,832 - [NOTICE] simulation.solve(889): Cycle 317/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:16:09,855 - [NOTICE] simulation.solve(977): Capacity is now 3.283 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:16:09,856 - [NOTICE] simulation.solve(855): Cycle 318/328 (3 minutes, 44 seconds elapsed) --------------------
# 2022-05-11 13:16:09,857 - [NOTICE] simulation.solve(889): Cycle 318/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:16:10,046 - [NOTICE] simulation.solve(889): Cycle 318/328, step 2/4: Rest for 5 min
# 2022-05-11 13:16:10,113 - [NOTICE] simulation.solve(889): Cycle 318/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:16:10,222 - [NOTICE] simulation.solve(889): Cycle 318/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:16:10,582 - [NOTICE] simulation.solve(977): Capacity is now 3.278 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:16:10,584 - [NOTICE] simulation.solve(855): Cycle 319/328 (3 minutes, 45 seconds elapsed) --------------------
# 2022-05-11 13:16:10,584 - [NOTICE] simulation.solve(889): Cycle 319/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:16:10,716 - [NOTICE] simulation.solve(889): Cycle 319/328, step 2/4: Rest for 5 min
# 2022-05-11 13:16:10,747 - [NOTICE] simulation.solve(889): Cycle 319/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:16:10,857 - [NOTICE] simulation.solve(889): Cycle 319/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:16:11,259 - [NOTICE] simulation.solve(977): Capacity is now 3.273 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:16:11,261 - [NOTICE] simulation.solve(855): Cycle 320/328 (3 minutes, 46 seconds elapsed) --------------------
# 2022-05-11 13:16:11,261 - [NOTICE] simulation.solve(889): Cycle 320/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:16:11,398 - [NOTICE] simulation.solve(889): Cycle 320/328, step 2/4: Rest for 5 min
# 2022-05-11 13:16:11,434 - [NOTICE] simulation.solve(889): Cycle 320/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:16:11,544 - [NOTICE] simulation.solve(889): Cycle 320/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:16:11,897 - [NOTICE] simulation.solve(977): Capacity is now 3.268 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:16:11,898 - [NOTICE] simulation.solve(855): Cycle 321/328 (3 minutes, 46 seconds elapsed) --------------------
# 2022-05-11 13:16:11,899 - [NOTICE] simulation.solve(889): Cycle 321/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:16:12,061 - [NOTICE] simulation.solve(889): Cycle 321/328, step 2/4: Rest for 5 min
# 2022-05-11 13:16:12,101 - [NOTICE] simulation.solve(889): Cycle 321/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:16:12,221 - [NOTICE] simulation.solve(889): Cycle 321/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:16:12,613 - [NOTICE] simulation.solve(977): Capacity is now 3.263 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:16:12,614 - [NOTICE] simulation.solve(855): Cycle 322/328 (3 minutes, 47 seconds elapsed) --------------------
# 2022-05-11 13:16:12,614 - [NOTICE] simulation.solve(889): Cycle 322/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:16:12,731 - [NOTICE] simulation.solve(889): Cycle 322/328, step 2/4: Rest for 5 min
# 2022-05-11 13:16:12,763 - [NOTICE] simulation.solve(889): Cycle 322/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:16:12,869 - [NOTICE] simulation.solve(889): Cycle 322/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:16:13,266 - [NOTICE] simulation.solve(977): Capacity is now 3.258 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:16:13,266 - [NOTICE] simulation.solve(855): Cycle 323/328 (3 minutes, 48 seconds elapsed) --------------------
# 2022-05-11 13:16:13,267 - [NOTICE] simulation.solve(889): Cycle 323/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:16:13,401 - [NOTICE] simulation.solve(889): Cycle 323/328, step 2/4: Rest for 5 min
# 2022-05-11 13:16:13,442 - [NOTICE] simulation.solve(889): Cycle 323/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:16:13,560 - [NOTICE] simulation.solve(889): Cycle 323/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:16:13,977 - [NOTICE] simulation.solve(977): Capacity is now 3.253 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:16:13,977 - [NOTICE] simulation.solve(855): Cycle 324/328 (3 minutes, 48 seconds elapsed) --------------------
# 2022-05-11 13:16:13,978 - [NOTICE] simulation.solve(889): Cycle 324/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:16:14,101 - [NOTICE] simulation.solve(889): Cycle 324/328, step 2/4: Rest for 5 min
# 2022-05-11 13:16:14,131 - [NOTICE] simulation.solve(889): Cycle 324/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:16:14,234 - [NOTICE] simulation.solve(889): Cycle 324/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:16:14,585 - [NOTICE] simulation.solve(977): Capacity is now 3.248 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:16:14,586 - [NOTICE] simulation.solve(855): Cycle 325/328 (3 minutes, 49 seconds elapsed) --------------------
# 2022-05-11 13:16:14,587 - [NOTICE] simulation.solve(889): Cycle 325/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:16:14,717 - [NOTICE] simulation.solve(889): Cycle 325/328, step 2/4: Rest for 5 min
# 2022-05-11 13:16:14,748 - [NOTICE] simulation.solve(889): Cycle 325/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:16:14,870 - [NOTICE] simulation.solve(889): Cycle 325/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:16:15,238 - [NOTICE] simulation.solve(977): Capacity is now 3.243 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:16:15,239 - [NOTICE] simulation.solve(855): Cycle 326/328 (3 minutes, 50 seconds elapsed) --------------------
# 2022-05-11 13:16:15,239 - [NOTICE] simulation.solve(889): Cycle 326/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:16:15,356 - [NOTICE] simulation.solve(889): Cycle 326/328, step 2/4: Rest for 5 min
# 2022-05-11 13:16:15,388 - [NOTICE] simulation.solve(889): Cycle 326/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:16:15,482 - [NOTICE] simulation.solve(889): Cycle 326/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:16:15,899 - [NOTICE] simulation.solve(977): Capacity is now 3.238 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:16:15,899 - [NOTICE] simulation.solve(855): Cycle 327/328 (3 minutes, 50 seconds elapsed) --------------------
# 2022-05-11 13:16:15,900 - [NOTICE] simulation.solve(889): Cycle 327/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:16:16,056 - [NOTICE] simulation.solve(889): Cycle 327/328, step 2/4: Rest for 5 min
# 2022-05-11 13:16:16,093 - [NOTICE] simulation.solve(889): Cycle 327/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:16:16,193 - [NOTICE] simulation.solve(889): Cycle 327/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:16:16,636 - [NOTICE] simulation.solve(977): Capacity is now 3.232 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:16:16,637 - [NOTICE] simulation.solve(855): Cycle 328/328 (3 minutes, 51 seconds elapsed) --------------------
# 2022-05-11 13:16:16,637 - [NOTICE] simulation.solve(889): Cycle 328/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:16:16,785 - [NOTICE] simulation.solve(889): Cycle 328/328, step 2/4: Rest for 5 min
# 2022-05-11 13:16:16,818 - [NOTICE] simulation.solve(889): Cycle 328/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:16:16,955 - [NOTICE] simulation.solve(889): Cycle 328/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:16:17,324 - [NOTICE] simulation.solve(977): Capacity is now 3.227 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:16:17,330 - [NOTICE] simulation.solve(1011): Finish experiment simulation, took 3 minutes, 52 seconds

# %%
parameter_values = get_parameter_values()
parameter_values.update(
    {

        "Positive electrode LAM constant proportional term [s-1]": 8.7864e-07,
        "Negative electrode LAM constant proportional term [s-1]": 1.08031e-05,
        "SEI kinetic rate constant [m.s-1]": 1.6297e-15,
        "EC diffusivity [m2.s-1]": 2e-18,
        "Positive electrode LAM constant exponential term": 2,
        "Negative electrode LAM constant exponential term": 2,
        "Negative electrode active material volume fraction": eps_n_data,
        "Positive electrode active material volume fraction": eps_p_data,
        # "Negative electrode porosity": 0.3,
        # "Positive electrode porosity": 0.3,
        # "Separator porosity": 0.4,
        # "Negative electrode porosity": 0.28,
        # "Positive electrode porosity": 0.28,
        # "Separator porosity": 0.38,
        "Negative electrode porosity": 0.15,
        "Positive electrode porosity": 0.15,
        "Separator porosity": 0.2,
    },
    check_already_exists=False,
)
# all_sumvars_dict = cycle_adaptive_simulation(spm, parameter_values, experiment, save_at_cycles=2)

# %%
sim_long = pybamm.Simulation(spm, experiment=experiment, parameter_values=parameter_values, 
                            solver=pybamm.CasadiSolver("safe"))
sol_long_2 = sim_long.solve(initial_soc=1)
long_sol_output_2 =sol_long_2.summary_variables
# Out:
# 2022-05-11 13:16:20,599 - [NOTICE] simulation.solve(855): Cycle 1/328 (36.007 ms elapsed) --------------------
# 2022-05-11 13:16:20,599 - [NOTICE] simulation.solve(889): Cycle 1/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:16:20,855 - [NOTICE] simulation.solve(889): Cycle 1/328, step 2/4: Rest for 5 min
# 2022-05-11 13:16:21,002 - [NOTICE] simulation.solve(889): Cycle 1/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:16:21,262 - [NOTICE] simulation.solve(889): Cycle 1/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:16:21,941 - [NOTICE] simulation.solve(977): Capacity is now 5.031 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:16:21,941 - [NOTICE] simulation.solve(855): Cycle 2/328 (1.378 s elapsed) --------------------
# 2022-05-11 13:16:21,942 - [NOTICE] simulation.solve(889): Cycle 2/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:16:22,098 - [NOTICE] simulation.solve(889): Cycle 2/328, step 2/4: Rest for 5 min
# 2022-05-11 13:16:22,132 - [NOTICE] simulation.solve(889): Cycle 2/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:16:22,291 - [NOTICE] simulation.solve(889): Cycle 2/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:16:22,673 - [NOTICE] simulation.solve(977): Capacity is now 5.025 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:16:22,674 - [NOTICE] simulation.solve(855): Cycle 3/328 (2.110 s elapsed) --------------------
# 2022-05-11 13:16:22,674 - [NOTICE] simulation.solve(889): Cycle 3/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:16:22,821 - [NOTICE] simulation.solve(889): Cycle 3/328, step 2/4: Rest for 5 min
# 2022-05-11 13:16:22,853 - [NOTICE] simulation.solve(889): Cycle 3/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:16:22,978 - [NOTICE] simulation.solve(889): Cycle 3/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:16:23,330 - [NOTICE] simulation.solve(977): Capacity is now 5.019 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:16:23,332 - [NOTICE] simulation.solve(855): Cycle 4/328 (2.769 s elapsed) --------------------
# 2022-05-11 13:16:23,332 - [NOTICE] simulation.solve(889): Cycle 4/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:16:23,509 - [NOTICE] simulation.solve(889): Cycle 4/328, step 2/4: Rest for 5 min
# 2022-05-11 13:16:23,542 - [NOTICE] simulation.solve(889): Cycle 4/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:16:23,698 - [NOTICE] simulation.solve(889): Cycle 4/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:16:23,996 - [NOTICE] simulation.solve(977): Capacity is now 5.013 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:16:23,996 - [NOTICE] simulation.solve(855): Cycle 5/328 (3.434 s elapsed) --------------------
# 2022-05-11 13:16:23,997 - [NOTICE] simulation.solve(889): Cycle 5/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:16:24,152 - [NOTICE] simulation.solve(889): Cycle 5/328, step 2/4: Rest for 5 min
# 2022-05-11 13:16:24,191 - [NOTICE] simulation.solve(889): Cycle 5/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:16:24,338 - [NOTICE] simulation.solve(889): Cycle 5/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:16:24,674 - [NOTICE] simulation.solve(977): Capacity is now 5.007 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:16:24,675 - [NOTICE] simulation.solve(855): Cycle 6/328 (4.112 s elapsed) --------------------
# 2022-05-11 13:16:24,675 - [NOTICE] simulation.solve(889): Cycle 6/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:16:24,822 - [NOTICE] simulation.solve(889): Cycle 6/328, step 2/4: Rest for 5 min
# 2022-05-11 13:16:24,850 - [NOTICE] simulation.solve(889): Cycle 6/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:16:24,983 - [NOTICE] simulation.solve(889): Cycle 6/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:16:25,291 - [NOTICE] simulation.solve(977): Capacity is now 5.001 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:16:25,291 - [NOTICE] simulation.solve(855): Cycle 7/328 (4.729 s elapsed) --------------------
# 2022-05-11 13:16:25,292 - [NOTICE] simulation.solve(889): Cycle 7/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:16:25,459 - [NOTICE] simulation.solve(889): Cycle 7/328, step 2/4: Rest for 5 min
# 2022-05-11 13:16:25,494 - [NOTICE] simulation.solve(889): Cycle 7/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:16:25,660 - [NOTICE] simulation.solve(889): Cycle 7/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:16:25,961 - [NOTICE] simulation.solve(977): Capacity is now 4.995 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:16:25,962 - [NOTICE] simulation.solve(855): Cycle 8/328 (5.399 s elapsed) --------------------
# 2022-05-11 13:16:25,962 - [NOTICE] simulation.solve(889): Cycle 8/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:16:26,108 - [NOTICE] simulation.solve(889): Cycle 8/328, step 2/4: Rest for 5 min
# 2022-05-11 13:16:26,138 - [NOTICE] simulation.solve(889): Cycle 8/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:16:26,292 - [NOTICE] simulation.solve(889): Cycle 8/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:16:26,627 - [NOTICE] simulation.solve(977): Capacity is now 4.989 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:16:26,628 - [NOTICE] simulation.solve(855): Cycle 9/328 (6.065 s elapsed) --------------------
# 2022-05-11 13:16:26,628 - [NOTICE] simulation.solve(889): Cycle 9/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:16:26,807 - [NOTICE] simulation.solve(889): Cycle 9/328, step 2/4: Rest for 5 min
# 2022-05-11 13:16:26,839 - [NOTICE] simulation.solve(889): Cycle 9/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:16:26,971 - [NOTICE] simulation.solve(889): Cycle 9/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:16:27,269 - [NOTICE] simulation.solve(977): Capacity is now 4.982 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:16:27,270 - [NOTICE] simulation.solve(855): Cycle 10/328 (6.707 s elapsed) --------------------
# 2022-05-11 13:16:27,270 - [NOTICE] simulation.solve(889): Cycle 10/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:16:27,424 - [NOTICE] simulation.solve(889): Cycle 10/328, step 2/4: Rest for 5 min
# 2022-05-11 13:16:27,456 - [NOTICE] simulation.solve(889): Cycle 10/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:16:27,606 - [NOTICE] simulation.solve(889): Cycle 10/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:16:27,912 - [NOTICE] simulation.solve(977): Capacity is now 4.980 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:16:27,913 - [NOTICE] simulation.solve(855): Cycle 11/328 (7.350 s elapsed) --------------------
# 2022-05-11 13:16:27,914 - [NOTICE] simulation.solve(889): Cycle 11/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:16:28,060 - [NOTICE] simulation.solve(889): Cycle 11/328, step 2/4: Rest for 5 min
# 2022-05-11 13:16:28,089 - [NOTICE] simulation.solve(889): Cycle 11/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:16:28,249 - [NOTICE] simulation.solve(889): Cycle 11/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:16:28,559 - [NOTICE] simulation.solve(977): Capacity is now 4.970 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:16:28,560 - [NOTICE] simulation.solve(855): Cycle 12/328 (7.997 s elapsed) --------------------
# 2022-05-11 13:16:28,560 - [NOTICE] simulation.solve(889): Cycle 12/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:16:28,740 - [NOTICE] simulation.solve(889): Cycle 12/328, step 2/4: Rest for 5 min
# 2022-05-11 13:16:28,775 - [NOTICE] simulation.solve(889): Cycle 12/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:16:28,915 - [NOTICE] simulation.solve(889): Cycle 12/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:16:29,213 - [NOTICE] simulation.solve(977): Capacity is now 4.967 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:16:29,214 - [NOTICE] simulation.solve(855): Cycle 13/328 (8.650 s elapsed) --------------------
# 2022-05-11 13:16:29,214 - [NOTICE] simulation.solve(889): Cycle 13/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:16:29,376 - [NOTICE] simulation.solve(889): Cycle 13/328, step 2/4: Rest for 5 min
# 2022-05-11 13:16:29,407 - [NOTICE] simulation.solve(889): Cycle 13/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:16:29,566 - [NOTICE] simulation.solve(889): Cycle 13/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:16:29,899 - [NOTICE] simulation.solve(977): Capacity is now 4.957 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:16:29,900 - [NOTICE] simulation.solve(855): Cycle 14/328 (9.336 s elapsed) --------------------
# 2022-05-11 13:16:29,900 - [NOTICE] simulation.solve(889): Cycle 14/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:16:30,086 - [NOTICE] simulation.solve(889): Cycle 14/328, step 2/4: Rest for 5 min
# 2022-05-11 13:16:30,115 - [NOTICE] simulation.solve(889): Cycle 14/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:16:30,289 - [NOTICE] simulation.solve(889): Cycle 14/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:16:30,640 - [NOTICE] simulation.solve(977): Capacity is now 4.954 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:16:30,640 - [NOTICE] simulation.solve(855): Cycle 15/328 (10.078 s elapsed) --------------------
# 2022-05-11 13:16:30,641 - [NOTICE] simulation.solve(889): Cycle 15/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:16:30,817 - [NOTICE] simulation.solve(889): Cycle 15/328, step 2/4: Rest for 5 min
# 2022-05-11 13:16:30,849 - [NOTICE] simulation.solve(889): Cycle 15/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:16:31,019 - [NOTICE] simulation.solve(889): Cycle 15/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:16:31,345 - [NOTICE] simulation.solve(977): Capacity is now 4.944 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:16:31,345 - [NOTICE] simulation.solve(855): Cycle 16/328 (10.782 s elapsed) --------------------
# 2022-05-11 13:16:31,346 - [NOTICE] simulation.solve(889): Cycle 16/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:16:31,504 - [NOTICE] simulation.solve(889): Cycle 16/328, step 2/4: Rest for 5 min
# 2022-05-11 13:16:31,546 - [NOTICE] simulation.solve(889): Cycle 16/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:16:31,729 - [NOTICE] simulation.solve(889): Cycle 16/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:16:32,023 - [NOTICE] simulation.solve(977): Capacity is now 4.938 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:16:32,023 - [NOTICE] simulation.solve(855): Cycle 17/328 (11.461 s elapsed) --------------------
# 2022-05-11 13:16:32,024 - [NOTICE] simulation.solve(889): Cycle 17/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:16:32,180 - [NOTICE] simulation.solve(889): Cycle 17/328, step 2/4: Rest for 5 min
# 2022-05-11 13:16:32,214 - [NOTICE] simulation.solve(889): Cycle 17/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:16:32,382 - [NOTICE] simulation.solve(889): Cycle 17/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:16:32,702 - [NOTICE] simulation.solve(977): Capacity is now 4.934 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:16:32,703 - [NOTICE] simulation.solve(855): Cycle 18/328 (12.140 s elapsed) --------------------
# 2022-05-11 13:16:32,704 - [NOTICE] simulation.solve(889): Cycle 18/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:16:32,863 - [NOTICE] simulation.solve(889): Cycle 18/328, step 2/4: Rest for 5 min
# 2022-05-11 13:16:32,896 - [NOTICE] simulation.solve(889): Cycle 18/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:16:33,059 - [NOTICE] simulation.solve(889): Cycle 18/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:16:33,408 - [NOTICE] simulation.solve(977): Capacity is now 4.925 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:16:33,409 - [NOTICE] simulation.solve(855): Cycle 19/328 (12.846 s elapsed) --------------------
# 2022-05-11 13:16:33,409 - [NOTICE] simulation.solve(889): Cycle 19/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:16:33,575 - [NOTICE] simulation.solve(889): Cycle 19/328, step 2/4: Rest for 5 min
# 2022-05-11 13:16:33,618 - [NOTICE] simulation.solve(889): Cycle 19/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:16:33,773 - [NOTICE] simulation.solve(889): Cycle 19/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:16:34,083 - [NOTICE] simulation.solve(977): Capacity is now 4.921 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:16:34,084 - [NOTICE] simulation.solve(855): Cycle 20/328 (13.521 s elapsed) --------------------
# 2022-05-11 13:16:34,085 - [NOTICE] simulation.solve(889): Cycle 20/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:16:34,260 - [NOTICE] simulation.solve(889): Cycle 20/328, step 2/4: Rest for 5 min
# 2022-05-11 13:16:34,297 - [NOTICE] simulation.solve(889): Cycle 20/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:16:34,479 - [NOTICE] simulation.solve(889): Cycle 20/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:16:34,856 - [NOTICE] simulation.solve(977): Capacity is now 4.914 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:16:34,857 - [NOTICE] simulation.solve(855): Cycle 21/328 (14.294 s elapsed) --------------------
# 2022-05-11 13:16:34,858 - [NOTICE] simulation.solve(889): Cycle 21/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:16:35,042 - [NOTICE] simulation.solve(889): Cycle 21/328, step 2/4: Rest for 5 min
# 2022-05-11 13:16:35,078 - [NOTICE] simulation.solve(889): Cycle 21/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:16:35,301 - [NOTICE] simulation.solve(889): Cycle 21/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:16:35,676 - [NOTICE] simulation.solve(977): Capacity is now 4.907 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:16:35,678 - [NOTICE] simulation.solve(855): Cycle 22/328 (15.114 s elapsed) --------------------
# 2022-05-11 13:16:35,678 - [NOTICE] simulation.solve(889): Cycle 22/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:16:35,928 - [NOTICE] simulation.solve(889): Cycle 22/328, step 2/4: Rest for 5 min
# 2022-05-11 13:16:35,986 - [NOTICE] simulation.solve(889): Cycle 22/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:16:36,154 - [NOTICE] simulation.solve(889): Cycle 22/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:16:36,548 - [NOTICE] simulation.solve(977): Capacity is now 4.901 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:16:36,549 - [NOTICE] simulation.solve(855): Cycle 23/328 (15.987 s elapsed) --------------------
# 2022-05-11 13:16:36,550 - [NOTICE] simulation.solve(889): Cycle 23/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:16:36,698 - [NOTICE] simulation.solve(889): Cycle 23/328, step 2/4: Rest for 5 min
# 2022-05-11 13:16:36,794 - [NOTICE] simulation.solve(889): Cycle 23/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:16:36,954 - [NOTICE] simulation.solve(889): Cycle 23/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:16:37,260 - [NOTICE] simulation.solve(977): Capacity is now 4.894 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:16:37,260 - [NOTICE] simulation.solve(855): Cycle 24/328 (16.698 s elapsed) --------------------
# 2022-05-11 13:16:37,261 - [NOTICE] simulation.solve(889): Cycle 24/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:16:37,411 - [NOTICE] simulation.solve(889): Cycle 24/328, step 2/4: Rest for 5 min
# 2022-05-11 13:16:37,450 - [NOTICE] simulation.solve(889): Cycle 24/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:16:37,603 - [NOTICE] simulation.solve(889): Cycle 24/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:16:37,949 - [NOTICE] simulation.solve(977): Capacity is now 4.888 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:16:37,950 - [NOTICE] simulation.solve(855): Cycle 25/328 (17.387 s elapsed) --------------------
# 2022-05-11 13:16:37,951 - [NOTICE] simulation.solve(889): Cycle 25/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:16:38,082 - [NOTICE] simulation.solve(889): Cycle 25/328, step 2/4: Rest for 5 min
# 2022-05-11 13:16:38,114 - [NOTICE] simulation.solve(889): Cycle 25/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:16:38,253 - [NOTICE] simulation.solve(889): Cycle 25/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:16:38,583 - [NOTICE] simulation.solve(977): Capacity is now 4.881 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:16:38,584 - [NOTICE] simulation.solve(855): Cycle 26/328 (18.021 s elapsed) --------------------
# 2022-05-11 13:16:38,585 - [NOTICE] simulation.solve(889): Cycle 26/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:16:38,750 - [NOTICE] simulation.solve(889): Cycle 26/328, step 2/4: Rest for 5 min
# 2022-05-11 13:16:38,794 - [NOTICE] simulation.solve(889): Cycle 26/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:16:39,001 - [NOTICE] simulation.solve(889): Cycle 26/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:16:39,465 - [NOTICE] simulation.solve(977): Capacity is now 4.875 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:16:39,466 - [NOTICE] simulation.solve(855): Cycle 27/328 (18.904 s elapsed) --------------------
# 2022-05-11 13:16:39,467 - [NOTICE] simulation.solve(889): Cycle 27/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:16:39,728 - [NOTICE] simulation.solve(889): Cycle 27/328, step 2/4: Rest for 5 min
# 2022-05-11 13:16:39,779 - [NOTICE] simulation.solve(889): Cycle 27/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:16:39,995 - [NOTICE] simulation.solve(889): Cycle 27/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:16:40,427 - [NOTICE] simulation.solve(977): Capacity is now 4.868 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:16:40,428 - [NOTICE] simulation.solve(855): Cycle 28/328 (19.865 s elapsed) --------------------
# 2022-05-11 13:16:40,429 - [NOTICE] simulation.solve(889): Cycle 28/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:16:40,640 - [NOTICE] simulation.solve(889): Cycle 28/328, step 2/4: Rest for 5 min
# 2022-05-11 13:16:40,693 - [NOTICE] simulation.solve(889): Cycle 28/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:16:40,916 - [NOTICE] simulation.solve(889): Cycle 28/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:16:41,359 - [NOTICE] simulation.solve(977): Capacity is now 4.862 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:16:41,360 - [NOTICE] simulation.solve(855): Cycle 29/328 (20.797 s elapsed) --------------------
# 2022-05-11 13:16:41,361 - [NOTICE] simulation.solve(889): Cycle 29/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:16:41,577 - [NOTICE] simulation.solve(889): Cycle 29/328, step 2/4: Rest for 5 min
# 2022-05-11 13:16:41,626 - [NOTICE] simulation.solve(889): Cycle 29/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:16:41,859 - [NOTICE] simulation.solve(889): Cycle 29/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:16:42,267 - [NOTICE] simulation.solve(977): Capacity is now 4.856 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:16:42,268 - [NOTICE] simulation.solve(855): Cycle 30/328 (21.705 s elapsed) --------------------
# 2022-05-11 13:16:42,269 - [NOTICE] simulation.solve(889): Cycle 30/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:16:42,488 - [NOTICE] simulation.solve(889): Cycle 30/328, step 2/4: Rest for 5 min
# 2022-05-11 13:16:42,532 - [NOTICE] simulation.solve(889): Cycle 30/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:16:42,729 - [NOTICE] simulation.solve(889): Cycle 30/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:16:43,153 - [NOTICE] simulation.solve(977): Capacity is now 4.849 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:16:43,154 - [NOTICE] simulation.solve(855): Cycle 31/328 (22.591 s elapsed) --------------------
# 2022-05-11 13:16:43,154 - [NOTICE] simulation.solve(889): Cycle 31/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:16:43,342 - [NOTICE] simulation.solve(889): Cycle 31/328, step 2/4: Rest for 5 min
# 2022-05-11 13:16:43,389 - [NOTICE] simulation.solve(889): Cycle 31/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:16:43,597 - [NOTICE] simulation.solve(889): Cycle 31/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:16:44,080 - [NOTICE] simulation.solve(977): Capacity is now 4.843 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:16:44,081 - [NOTICE] simulation.solve(855): Cycle 32/328 (23.519 s elapsed) --------------------
# 2022-05-11 13:16:44,082 - [NOTICE] simulation.solve(889): Cycle 32/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:16:44,276 - [NOTICE] simulation.solve(889): Cycle 32/328, step 2/4: Rest for 5 min
# 2022-05-11 13:16:44,317 - [NOTICE] simulation.solve(889): Cycle 32/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:16:44,519 - [NOTICE] simulation.solve(889): Cycle 32/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:16:44,914 - [NOTICE] simulation.solve(977): Capacity is now 4.836 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:16:44,915 - [NOTICE] simulation.solve(855): Cycle 33/328 (24.352 s elapsed) --------------------
# 2022-05-11 13:16:44,916 - [NOTICE] simulation.solve(889): Cycle 33/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:16:45,065 - [NOTICE] simulation.solve(889): Cycle 33/328, step 2/4: Rest for 5 min
# 2022-05-11 13:16:45,094 - [NOTICE] simulation.solve(889): Cycle 33/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:16:45,224 - [NOTICE] simulation.solve(889): Cycle 33/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:16:45,557 - [NOTICE] simulation.solve(977): Capacity is now 4.830 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:16:45,558 - [NOTICE] simulation.solve(855): Cycle 34/328 (24.994 s elapsed) --------------------
# 2022-05-11 13:16:45,558 - [NOTICE] simulation.solve(889): Cycle 34/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:16:45,738 - [NOTICE] simulation.solve(889): Cycle 34/328, step 2/4: Rest for 5 min
# 2022-05-11 13:16:45,774 - [NOTICE] simulation.solve(889): Cycle 34/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:16:45,929 - [NOTICE] simulation.solve(889): Cycle 34/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:16:46,228 - [NOTICE] simulation.solve(977): Capacity is now 4.824 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:16:46,229 - [NOTICE] simulation.solve(855): Cycle 35/328 (25.666 s elapsed) --------------------
# 2022-05-11 13:16:46,229 - [NOTICE] simulation.solve(889): Cycle 35/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:16:46,381 - [NOTICE] simulation.solve(889): Cycle 35/328, step 2/4: Rest for 5 min
# 2022-05-11 13:16:46,416 - [NOTICE] simulation.solve(889): Cycle 35/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:16:46,562 - [NOTICE] simulation.solve(889): Cycle 35/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:16:46,922 - [NOTICE] simulation.solve(977): Capacity is now 4.817 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:16:46,923 - [NOTICE] simulation.solve(855): Cycle 36/328 (26.360 s elapsed) --------------------
# 2022-05-11 13:16:46,924 - [NOTICE] simulation.solve(889): Cycle 36/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:16:47,065 - [NOTICE] simulation.solve(889): Cycle 36/328, step 2/4: Rest for 5 min
# 2022-05-11 13:16:47,104 - [NOTICE] simulation.solve(889): Cycle 36/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:16:47,247 - [NOTICE] simulation.solve(889): Cycle 36/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:16:47,587 - [NOTICE] simulation.solve(977): Capacity is now 4.811 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:16:47,588 - [NOTICE] simulation.solve(855): Cycle 37/328 (27.025 s elapsed) --------------------
# 2022-05-11 13:16:47,589 - [NOTICE] simulation.solve(889): Cycle 37/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:16:47,759 - [NOTICE] simulation.solve(889): Cycle 37/328, step 2/4: Rest for 5 min
# 2022-05-11 13:16:47,799 - [NOTICE] simulation.solve(889): Cycle 37/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:16:47,945 - [NOTICE] simulation.solve(889): Cycle 37/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:16:48,229 - [NOTICE] simulation.solve(977): Capacity is now 4.804 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:16:48,229 - [NOTICE] simulation.solve(855): Cycle 38/328 (27.666 s elapsed) --------------------
# 2022-05-11 13:16:48,230 - [NOTICE] simulation.solve(889): Cycle 38/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:16:48,373 - [NOTICE] simulation.solve(889): Cycle 38/328, step 2/4: Rest for 5 min
# 2022-05-11 13:16:48,409 - [NOTICE] simulation.solve(889): Cycle 38/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:16:48,549 - [NOTICE] simulation.solve(889): Cycle 38/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:16:48,926 - [NOTICE] simulation.solve(977): Capacity is now 4.798 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:16:48,927 - [NOTICE] simulation.solve(855): Cycle 39/328 (28.364 s elapsed) --------------------
# 2022-05-11 13:16:48,928 - [NOTICE] simulation.solve(889): Cycle 39/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:16:49,079 - [NOTICE] simulation.solve(889): Cycle 39/328, step 2/4: Rest for 5 min
# 2022-05-11 13:16:49,109 - [NOTICE] simulation.solve(889): Cycle 39/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:16:49,227 - [NOTICE] simulation.solve(889): Cycle 39/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:16:49,549 - [NOTICE] simulation.solve(977): Capacity is now 4.792 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:16:49,550 - [NOTICE] simulation.solve(855): Cycle 40/328 (28.987 s elapsed) --------------------
# 2022-05-11 13:16:49,551 - [NOTICE] simulation.solve(889): Cycle 40/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:16:49,715 - [NOTICE] simulation.solve(889): Cycle 40/328, step 2/4: Rest for 5 min
# 2022-05-11 13:16:49,751 - [NOTICE] simulation.solve(889): Cycle 40/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:16:49,901 - [NOTICE] simulation.solve(889): Cycle 40/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:16:50,181 - [NOTICE] simulation.solve(977): Capacity is now 4.785 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:16:50,181 - [NOTICE] simulation.solve(855): Cycle 41/328 (29.618 s elapsed) --------------------
# 2022-05-11 13:16:50,182 - [NOTICE] simulation.solve(889): Cycle 41/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:16:50,339 - [NOTICE] simulation.solve(889): Cycle 41/328, step 2/4: Rest for 5 min
# 2022-05-11 13:16:50,378 - [NOTICE] simulation.solve(889): Cycle 41/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:16:50,523 - [NOTICE] simulation.solve(889): Cycle 41/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:16:50,871 - [NOTICE] simulation.solve(977): Capacity is now 4.779 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:16:50,872 - [NOTICE] simulation.solve(855): Cycle 42/328 (30.309 s elapsed) --------------------
# 2022-05-11 13:16:50,872 - [NOTICE] simulation.solve(889): Cycle 42/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:16:51,036 - [NOTICE] simulation.solve(889): Cycle 42/328, step 2/4: Rest for 5 min
# 2022-05-11 13:16:51,082 - [NOTICE] simulation.solve(889): Cycle 42/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:16:51,196 - [NOTICE] simulation.solve(889): Cycle 42/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:16:51,507 - [NOTICE] simulation.solve(977): Capacity is now 4.773 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:16:51,507 - [NOTICE] simulation.solve(855): Cycle 43/328 (30.944 s elapsed) --------------------
# 2022-05-11 13:16:51,507 - [NOTICE] simulation.solve(889): Cycle 43/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:16:51,670 - [NOTICE] simulation.solve(889): Cycle 43/328, step 2/4: Rest for 5 min
# 2022-05-11 13:16:51,706 - [NOTICE] simulation.solve(889): Cycle 43/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:16:51,849 - [NOTICE] simulation.solve(889): Cycle 43/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:16:52,210 - [NOTICE] simulation.solve(977): Capacity is now 4.766 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:16:52,211 - [NOTICE] simulation.solve(855): Cycle 44/328 (31.648 s elapsed) --------------------
# 2022-05-11 13:16:52,212 - [NOTICE] simulation.solve(889): Cycle 44/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:16:52,398 - [NOTICE] simulation.solve(889): Cycle 44/328, step 2/4: Rest for 5 min
# 2022-05-11 13:16:52,441 - [NOTICE] simulation.solve(889): Cycle 44/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:16:52,594 - [NOTICE] simulation.solve(889): Cycle 44/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:16:52,922 - [NOTICE] simulation.solve(977): Capacity is now 4.760 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:16:52,923 - [NOTICE] simulation.solve(855): Cycle 45/328 (32.360 s elapsed) --------------------
# 2022-05-11 13:16:52,924 - [NOTICE] simulation.solve(889): Cycle 45/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:16:53,085 - [NOTICE] simulation.solve(889): Cycle 45/328, step 2/4: Rest for 5 min
# 2022-05-11 13:16:53,126 - [NOTICE] simulation.solve(889): Cycle 45/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:16:53,251 - [NOTICE] simulation.solve(889): Cycle 45/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:16:54,293 - [NOTICE] simulation.solve(977): Capacity is now 4.754 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:16:54,295 - [NOTICE] simulation.solve(855): Cycle 46/328 (33.732 s elapsed) --------------------
# 2022-05-11 13:16:54,296 - [NOTICE] simulation.solve(889): Cycle 46/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:16:54,441 - [NOTICE] simulation.solve(889): Cycle 46/328, step 2/4: Rest for 5 min
# 2022-05-11 13:16:54,471 - [NOTICE] simulation.solve(889): Cycle 46/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:16:54,659 - [NOTICE] simulation.solve(889): Cycle 46/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:16:54,996 - [NOTICE] simulation.solve(977): Capacity is now 4.747 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:16:54,996 - [NOTICE] simulation.solve(855): Cycle 47/328 (34.433 s elapsed) --------------------
# 2022-05-11 13:16:54,997 - [NOTICE] simulation.solve(889): Cycle 47/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:16:55,155 - [NOTICE] simulation.solve(889): Cycle 47/328, step 2/4: Rest for 5 min
# 2022-05-11 13:16:55,188 - [NOTICE] simulation.solve(889): Cycle 47/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:16:55,322 - [NOTICE] simulation.solve(889): Cycle 47/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:16:55,625 - [NOTICE] simulation.solve(977): Capacity is now 4.741 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:16:55,626 - [NOTICE] simulation.solve(855): Cycle 48/328 (35.063 s elapsed) --------------------
# 2022-05-11 13:16:55,626 - [NOTICE] simulation.solve(889): Cycle 48/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:16:55,788 - [NOTICE] simulation.solve(889): Cycle 48/328, step 2/4: Rest for 5 min
# 2022-05-11 13:16:55,824 - [NOTICE] simulation.solve(889): Cycle 48/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:16:55,974 - [NOTICE] simulation.solve(889): Cycle 48/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:16:56,338 - [NOTICE] simulation.solve(977): Capacity is now 4.735 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:16:56,338 - [NOTICE] simulation.solve(855): Cycle 49/328 (35.775 s elapsed) --------------------
# 2022-05-11 13:16:56,339 - [NOTICE] simulation.solve(889): Cycle 49/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:16:56,480 - [NOTICE] simulation.solve(889): Cycle 49/328, step 2/4: Rest for 5 min
# 2022-05-11 13:16:56,509 - [NOTICE] simulation.solve(889): Cycle 49/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:16:56,639 - [NOTICE] simulation.solve(889): Cycle 49/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:16:57,013 - [NOTICE] simulation.solve(977): Capacity is now 4.728 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:16:57,014 - [NOTICE] simulation.solve(855): Cycle 50/328 (36.451 s elapsed) --------------------
# 2022-05-11 13:16:57,015 - [NOTICE] simulation.solve(889): Cycle 50/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:16:57,180 - [NOTICE] simulation.solve(889): Cycle 50/328, step 2/4: Rest for 5 min
# 2022-05-11 13:16:57,213 - [NOTICE] simulation.solve(889): Cycle 50/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:16:57,352 - [NOTICE] simulation.solve(889): Cycle 50/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:16:57,674 - [NOTICE] simulation.solve(977): Capacity is now 4.722 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:16:57,674 - [NOTICE] simulation.solve(855): Cycle 51/328 (37.112 s elapsed) --------------------
# 2022-05-11 13:16:57,675 - [NOTICE] simulation.solve(889): Cycle 51/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:16:57,853 - [NOTICE] simulation.solve(889): Cycle 51/328, step 2/4: Rest for 5 min
# 2022-05-11 13:16:57,889 - [NOTICE] simulation.solve(889): Cycle 51/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:16:58,042 - [NOTICE] simulation.solve(889): Cycle 51/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:16:58,402 - [NOTICE] simulation.solve(977): Capacity is now 4.716 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:16:58,403 - [NOTICE] simulation.solve(855): Cycle 52/328 (37.840 s elapsed) --------------------
# 2022-05-11 13:16:58,404 - [NOTICE] simulation.solve(889): Cycle 52/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:16:58,534 - [NOTICE] simulation.solve(889): Cycle 52/328, step 2/4: Rest for 5 min
# 2022-05-11 13:16:58,563 - [NOTICE] simulation.solve(889): Cycle 52/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:16:58,693 - [NOTICE] simulation.solve(889): Cycle 52/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:16:59,076 - [NOTICE] simulation.solve(977): Capacity is now 4.710 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:16:59,077 - [NOTICE] simulation.solve(855): Cycle 53/328 (38.513 s elapsed) --------------------
# 2022-05-11 13:16:59,077 - [NOTICE] simulation.solve(889): Cycle 53/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:16:59,239 - [NOTICE] simulation.solve(889): Cycle 53/328, step 2/4: Rest for 5 min
# 2022-05-11 13:16:59,272 - [NOTICE] simulation.solve(889): Cycle 53/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:16:59,434 - [NOTICE] simulation.solve(889): Cycle 53/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:16:59,740 - [NOTICE] simulation.solve(977): Capacity is now 4.703 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:16:59,740 - [NOTICE] simulation.solve(855): Cycle 54/328 (39.178 s elapsed) --------------------
# 2022-05-11 13:16:59,741 - [NOTICE] simulation.solve(889): Cycle 54/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:16:59,890 - [NOTICE] simulation.solve(889): Cycle 54/328, step 2/4: Rest for 5 min
# 2022-05-11 13:16:59,931 - [NOTICE] simulation.solve(889): Cycle 54/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:17:00,077 - [NOTICE] simulation.solve(889): Cycle 54/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:17:00,434 - [NOTICE] simulation.solve(977): Capacity is now 4.697 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:17:00,436 - [NOTICE] simulation.solve(855): Cycle 55/328 (39.873 s elapsed) --------------------
# 2022-05-11 13:17:00,436 - [NOTICE] simulation.solve(889): Cycle 55/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:17:00,579 - [NOTICE] simulation.solve(889): Cycle 55/328, step 2/4: Rest for 5 min
# 2022-05-11 13:17:00,613 - [NOTICE] simulation.solve(889): Cycle 55/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:17:00,752 - [NOTICE] simulation.solve(889): Cycle 55/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:17:01,057 - [NOTICE] simulation.solve(977): Capacity is now 4.691 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:17:01,058 - [NOTICE] simulation.solve(855): Cycle 56/328 (40.495 s elapsed) --------------------
# 2022-05-11 13:17:01,059 - [NOTICE] simulation.solve(889): Cycle 56/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:17:01,218 - [NOTICE] simulation.solve(889): Cycle 56/328, step 2/4: Rest for 5 min
# 2022-05-11 13:17:01,253 - [NOTICE] simulation.solve(889): Cycle 56/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:17:01,400 - [NOTICE] simulation.solve(889): Cycle 56/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:17:01,740 - [NOTICE] simulation.solve(977): Capacity is now 4.685 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:17:01,740 - [NOTICE] simulation.solve(855): Cycle 57/328 (41.177 s elapsed) --------------------
# 2022-05-11 13:17:01,741 - [NOTICE] simulation.solve(889): Cycle 57/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:17:01,874 - [NOTICE] simulation.solve(889): Cycle 57/328, step 2/4: Rest for 5 min
# 2022-05-11 13:17:01,905 - [NOTICE] simulation.solve(889): Cycle 57/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:17:02,040 - [NOTICE] simulation.solve(889): Cycle 57/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:17:02,402 - [NOTICE] simulation.solve(977): Capacity is now 4.678 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:17:02,403 - [NOTICE] simulation.solve(855): Cycle 58/328 (41.840 s elapsed) --------------------
# 2022-05-11 13:17:02,403 - [NOTICE] simulation.solve(889): Cycle 58/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:17:02,554 - [NOTICE] simulation.solve(889): Cycle 58/328, step 2/4: Rest for 5 min
# 2022-05-11 13:17:02,592 - [NOTICE] simulation.solve(889): Cycle 58/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:17:02,731 - [NOTICE] simulation.solve(889): Cycle 58/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:17:03,038 - [NOTICE] simulation.solve(977): Capacity is now 4.672 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:17:03,039 - [NOTICE] simulation.solve(855): Cycle 59/328 (42.476 s elapsed) --------------------
# 2022-05-11 13:17:03,040 - [NOTICE] simulation.solve(889): Cycle 59/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:17:03,179 - [NOTICE] simulation.solve(889): Cycle 59/328, step 2/4: Rest for 5 min
# 2022-05-11 13:17:03,213 - [NOTICE] simulation.solve(889): Cycle 59/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:17:03,382 - [NOTICE] simulation.solve(889): Cycle 59/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:17:03,763 - [NOTICE] simulation.solve(977): Capacity is now 4.666 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:17:03,764 - [NOTICE] simulation.solve(855): Cycle 60/328 (43.201 s elapsed) --------------------
# 2022-05-11 13:17:03,765 - [NOTICE] simulation.solve(889): Cycle 60/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:17:03,926 - [NOTICE] simulation.solve(889): Cycle 60/328, step 2/4: Rest for 5 min
# 2022-05-11 13:17:03,956 - [NOTICE] simulation.solve(889): Cycle 60/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:17:04,113 - [NOTICE] simulation.solve(889): Cycle 60/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:17:04,470 - [NOTICE] simulation.solve(977): Capacity is now 4.660 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:17:04,471 - [NOTICE] simulation.solve(855): Cycle 61/328 (43.909 s elapsed) --------------------
# 2022-05-11 13:17:04,472 - [NOTICE] simulation.solve(889): Cycle 61/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:17:04,615 - [NOTICE] simulation.solve(889): Cycle 61/328, step 2/4: Rest for 5 min
# 2022-05-11 13:17:04,645 - [NOTICE] simulation.solve(889): Cycle 61/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:17:04,781 - [NOTICE] simulation.solve(889): Cycle 61/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:17:05,181 - [NOTICE] simulation.solve(977): Capacity is now 4.653 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:17:05,182 - [NOTICE] simulation.solve(855): Cycle 62/328 (44.619 s elapsed) --------------------
# 2022-05-11 13:17:05,183 - [NOTICE] simulation.solve(889): Cycle 62/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:17:05,346 - [NOTICE] simulation.solve(889): Cycle 62/328, step 2/4: Rest for 5 min
# 2022-05-11 13:17:05,378 - [NOTICE] simulation.solve(889): Cycle 62/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:17:05,526 - [NOTICE] simulation.solve(889): Cycle 62/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:17:05,855 - [NOTICE] simulation.solve(977): Capacity is now 4.647 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:17:05,855 - [NOTICE] simulation.solve(855): Cycle 63/328 (45.292 s elapsed) --------------------
# 2022-05-11 13:17:05,856 - [NOTICE] simulation.solve(889): Cycle 63/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:17:05,986 - [NOTICE] simulation.solve(889): Cycle 63/328, step 2/4: Rest for 5 min
# 2022-05-11 13:17:06,020 - [NOTICE] simulation.solve(889): Cycle 63/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:17:06,188 - [NOTICE] simulation.solve(889): Cycle 63/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:17:06,554 - [NOTICE] simulation.solve(977): Capacity is now 4.641 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:17:06,555 - [NOTICE] simulation.solve(855): Cycle 64/328 (45.991 s elapsed) --------------------
# 2022-05-11 13:17:06,555 - [NOTICE] simulation.solve(889): Cycle 64/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:17:06,697 - [NOTICE] simulation.solve(889): Cycle 64/328, step 2/4: Rest for 5 min
# 2022-05-11 13:17:06,728 - [NOTICE] simulation.solve(889): Cycle 64/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:17:06,864 - [NOTICE] simulation.solve(889): Cycle 64/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:17:07,324 - [NOTICE] simulation.solve(977): Capacity is now 4.635 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:17:07,325 - [NOTICE] simulation.solve(855): Cycle 65/328 (46.763 s elapsed) --------------------
# 2022-05-11 13:17:07,326 - [NOTICE] simulation.solve(889): Cycle 65/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:17:07,524 - [NOTICE] simulation.solve(889): Cycle 65/328, step 2/4: Rest for 5 min
# 2022-05-11 13:17:07,571 - [NOTICE] simulation.solve(889): Cycle 65/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:17:07,737 - [NOTICE] simulation.solve(889): Cycle 65/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:17:08,071 - [NOTICE] simulation.solve(977): Capacity is now 4.629 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:17:08,072 - [NOTICE] simulation.solve(855): Cycle 66/328 (47.509 s elapsed) --------------------
# 2022-05-11 13:17:08,072 - [NOTICE] simulation.solve(889): Cycle 66/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:17:08,213 - [NOTICE] simulation.solve(889): Cycle 66/328, step 2/4: Rest for 5 min
# 2022-05-11 13:17:08,243 - [NOTICE] simulation.solve(889): Cycle 66/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:17:08,416 - [NOTICE] simulation.solve(889): Cycle 66/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:17:08,783 - [NOTICE] simulation.solve(977): Capacity is now 4.623 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:17:08,783 - [NOTICE] simulation.solve(855): Cycle 67/328 (48.221 s elapsed) --------------------
# 2022-05-11 13:17:08,784 - [NOTICE] simulation.solve(889): Cycle 67/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:17:08,938 - [NOTICE] simulation.solve(889): Cycle 67/328, step 2/4: Rest for 5 min
# 2022-05-11 13:17:08,970 - [NOTICE] simulation.solve(889): Cycle 67/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:17:09,109 - [NOTICE] simulation.solve(889): Cycle 67/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:17:09,433 - [NOTICE] simulation.solve(977): Capacity is now 4.616 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:17:09,434 - [NOTICE] simulation.solve(855): Cycle 68/328 (48.871 s elapsed) --------------------
# 2022-05-11 13:17:09,435 - [NOTICE] simulation.solve(889): Cycle 68/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:17:09,637 - [NOTICE] simulation.solve(889): Cycle 68/328, step 2/4: Rest for 5 min
# 2022-05-11 13:17:09,669 - [NOTICE] simulation.solve(889): Cycle 68/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:17:09,815 - [NOTICE] simulation.solve(889): Cycle 68/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:17:10,163 - [NOTICE] simulation.solve(977): Capacity is now 4.610 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:17:10,163 - [NOTICE] simulation.solve(855): Cycle 69/328 (49.600 s elapsed) --------------------
# 2022-05-11 13:17:10,164 - [NOTICE] simulation.solve(889): Cycle 69/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:17:10,306 - [NOTICE] simulation.solve(889): Cycle 69/328, step 2/4: Rest for 5 min
# 2022-05-11 13:17:10,337 - [NOTICE] simulation.solve(889): Cycle 69/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:17:10,512 - [NOTICE] simulation.solve(889): Cycle 69/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:17:10,858 - [NOTICE] simulation.solve(977): Capacity is now 4.604 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:17:10,859 - [NOTICE] simulation.solve(855): Cycle 70/328 (50.296 s elapsed) --------------------
# 2022-05-11 13:17:10,860 - [NOTICE] simulation.solve(889): Cycle 70/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:17:11,005 - [NOTICE] simulation.solve(889): Cycle 70/328, step 2/4: Rest for 5 min
# 2022-05-11 13:17:11,043 - [NOTICE] simulation.solve(889): Cycle 70/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:17:11,197 - [NOTICE] simulation.solve(889): Cycle 70/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:17:11,571 - [NOTICE] simulation.solve(977): Capacity is now 4.598 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:17:11,572 - [NOTICE] simulation.solve(855): Cycle 71/328 (51.009 s elapsed) --------------------
# 2022-05-11 13:17:11,572 - [NOTICE] simulation.solve(889): Cycle 71/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:17:11,703 - [NOTICE] simulation.solve(889): Cycle 71/328, step 2/4: Rest for 5 min
# 2022-05-11 13:17:11,731 - [NOTICE] simulation.solve(889): Cycle 71/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:17:11,865 - [NOTICE] simulation.solve(889): Cycle 71/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:17:12,280 - [NOTICE] simulation.solve(977): Capacity is now 4.592 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:17:12,280 - [NOTICE] simulation.solve(855): Cycle 72/328 (51.718 s elapsed) --------------------
# 2022-05-11 13:17:12,281 - [NOTICE] simulation.solve(889): Cycle 72/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:17:12,452 - [NOTICE] simulation.solve(889): Cycle 72/328, step 2/4: Rest for 5 min
# 2022-05-11 13:17:12,493 - [NOTICE] simulation.solve(889): Cycle 72/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:17:12,631 - [NOTICE] simulation.solve(889): Cycle 72/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:17:12,953 - [NOTICE] simulation.solve(977): Capacity is now 4.586 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:17:12,954 - [NOTICE] simulation.solve(855): Cycle 73/328 (52.391 s elapsed) --------------------
# 2022-05-11 13:17:12,954 - [NOTICE] simulation.solve(889): Cycle 73/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:17:13,118 - [NOTICE] simulation.solve(889): Cycle 73/328, step 2/4: Rest for 5 min
# 2022-05-11 13:17:13,151 - [NOTICE] simulation.solve(889): Cycle 73/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:17:13,292 - [NOTICE] simulation.solve(889): Cycle 73/328, step 4/4: Hold at 4.2V until C/50
# ...
# 2022-05-11 13:19:54,079 - [NOTICE] simulation.solve(889): Cycle 305/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:19:54,505 - [NOTICE] simulation.solve(977): Capacity is now 3.306 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:19:54,506 - [NOTICE] simulation.solve(855): Cycle 306/328 (3 minutes, 34 seconds elapsed) --------------------
# 2022-05-11 13:19:54,506 - [NOTICE] simulation.solve(889): Cycle 306/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:19:54,667 - [NOTICE] simulation.solve(889): Cycle 306/328, step 2/4: Rest for 5 min
# 2022-05-11 13:19:54,700 - [NOTICE] simulation.solve(889): Cycle 306/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:19:54,823 - [NOTICE] simulation.solve(889): Cycle 306/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:19:55,240 - [NOTICE] simulation.solve(977): Capacity is now 3.301 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:19:55,241 - [NOTICE] simulation.solve(855): Cycle 307/328 (3 minutes, 35 seconds elapsed) --------------------
# 2022-05-11 13:19:55,241 - [NOTICE] simulation.solve(889): Cycle 307/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:19:55,368 - [NOTICE] simulation.solve(889): Cycle 307/328, step 2/4: Rest for 5 min
# 2022-05-11 13:19:55,404 - [NOTICE] simulation.solve(889): Cycle 307/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:19:55,505 - [NOTICE] simulation.solve(889): Cycle 307/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:19:55,866 - [NOTICE] simulation.solve(977): Capacity is now 3.296 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:19:55,867 - [NOTICE] simulation.solve(855): Cycle 308/328 (3 minutes, 35 seconds elapsed) --------------------
# 2022-05-11 13:19:55,868 - [NOTICE] simulation.solve(889): Cycle 308/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:19:55,980 - [NOTICE] simulation.solve(889): Cycle 308/328, step 2/4: Rest for 5 min
# 2022-05-11 13:19:56,013 - [NOTICE] simulation.solve(889): Cycle 308/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:19:56,133 - [NOTICE] simulation.solve(889): Cycle 308/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:19:56,556 - [NOTICE] simulation.solve(977): Capacity is now 3.290 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:19:56,557 - [NOTICE] simulation.solve(855): Cycle 309/328 (3 minutes, 36 seconds elapsed) --------------------
# 2022-05-11 13:19:56,558 - [NOTICE] simulation.solve(889): Cycle 309/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:19:56,692 - [NOTICE] simulation.solve(889): Cycle 309/328, step 2/4: Rest for 5 min
# 2022-05-11 13:19:56,734 - [NOTICE] simulation.solve(889): Cycle 309/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:19:56,870 - [NOTICE] simulation.solve(889): Cycle 309/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:19:57,453 - [NOTICE] simulation.solve(977): Capacity is now 3.285 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:19:57,454 - [NOTICE] simulation.solve(855): Cycle 310/328 (3 minutes, 37 seconds elapsed) --------------------
# 2022-05-11 13:19:57,455 - [NOTICE] simulation.solve(889): Cycle 310/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:19:57,654 - [NOTICE] simulation.solve(889): Cycle 310/328, step 2/4: Rest for 5 min
# 2022-05-11 13:19:57,706 - [NOTICE] simulation.solve(889): Cycle 310/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:19:57,868 - [NOTICE] simulation.solve(889): Cycle 310/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:19:58,522 - [NOTICE] simulation.solve(977): Capacity is now 3.280 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:19:58,523 - [NOTICE] simulation.solve(855): Cycle 311/328 (3 minutes, 38 seconds elapsed) --------------------
# 2022-05-11 13:19:58,523 - [NOTICE] simulation.solve(889): Cycle 311/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:19:58,696 - [NOTICE] simulation.solve(889): Cycle 311/328, step 2/4: Rest for 5 min
# 2022-05-11 13:19:58,738 - [NOTICE] simulation.solve(889): Cycle 311/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:19:58,926 - [NOTICE] simulation.solve(889): Cycle 311/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:19:59,533 - [NOTICE] simulation.solve(977): Capacity is now 3.275 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:19:59,534 - [NOTICE] simulation.solve(855): Cycle 312/328 (3 minutes, 39 seconds elapsed) --------------------
# 2022-05-11 13:19:59,535 - [NOTICE] simulation.solve(889): Cycle 312/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:19:59,725 - [NOTICE] simulation.solve(889): Cycle 312/328, step 2/4: Rest for 5 min
# 2022-05-11 13:19:59,774 - [NOTICE] simulation.solve(889): Cycle 312/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:19:59,929 - [NOTICE] simulation.solve(889): Cycle 312/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:20:00,526 - [NOTICE] simulation.solve(977): Capacity is now 3.270 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:20:00,527 - [NOTICE] simulation.solve(855): Cycle 313/328 (3 minutes, 40 seconds elapsed) --------------------
# 2022-05-11 13:20:00,527 - [NOTICE] simulation.solve(889): Cycle 313/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:20:00,681 - [NOTICE] simulation.solve(889): Cycle 313/328, step 2/4: Rest for 5 min
# 2022-05-11 13:20:00,722 - [NOTICE] simulation.solve(889): Cycle 313/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:20:00,857 - [NOTICE] simulation.solve(889): Cycle 313/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:20:01,604 - [NOTICE] simulation.solve(977): Capacity is now 3.265 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:20:01,605 - [NOTICE] simulation.solve(855): Cycle 314/328 (3 minutes, 41 seconds elapsed) --------------------
# 2022-05-11 13:20:01,605 - [NOTICE] simulation.solve(889): Cycle 314/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:20:01,804 - [NOTICE] simulation.solve(889): Cycle 314/328, step 2/4: Rest for 5 min
# 2022-05-11 13:20:01,861 - [NOTICE] simulation.solve(889): Cycle 314/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:20:02,014 - [NOTICE] simulation.solve(889): Cycle 314/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:20:02,629 - [NOTICE] simulation.solve(977): Capacity is now 3.260 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:20:02,629 - [NOTICE] simulation.solve(855): Cycle 315/328 (3 minutes, 42 seconds elapsed) --------------------
# 2022-05-11 13:20:02,630 - [NOTICE] simulation.solve(889): Cycle 315/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:20:02,789 - [NOTICE] simulation.solve(889): Cycle 315/328, step 2/4: Rest for 5 min
# 2022-05-11 13:20:02,837 - [NOTICE] simulation.solve(889): Cycle 315/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:20:02,989 - [NOTICE] simulation.solve(889): Cycle 315/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:20:03,487 - [NOTICE] simulation.solve(977): Capacity is now 3.255 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:20:03,487 - [NOTICE] simulation.solve(855): Cycle 316/328 (3 minutes, 43 seconds elapsed) --------------------
# 2022-05-11 13:20:03,488 - [NOTICE] simulation.solve(889): Cycle 316/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:20:03,641 - [NOTICE] simulation.solve(889): Cycle 316/328, step 2/4: Rest for 5 min
# 2022-05-11 13:20:03,675 - [NOTICE] simulation.solve(889): Cycle 316/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:20:03,812 - [NOTICE] simulation.solve(889): Cycle 316/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:20:04,288 - [NOTICE] simulation.solve(977): Capacity is now 3.250 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:20:04,289 - [NOTICE] simulation.solve(855): Cycle 317/328 (3 minutes, 44 seconds elapsed) --------------------
# 2022-05-11 13:20:04,290 - [NOTICE] simulation.solve(889): Cycle 317/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:20:04,429 - [NOTICE] simulation.solve(889): Cycle 317/328, step 2/4: Rest for 5 min
# 2022-05-11 13:20:04,464 - [NOTICE] simulation.solve(889): Cycle 317/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:20:04,576 - [NOTICE] simulation.solve(889): Cycle 317/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:20:04,961 - [NOTICE] simulation.solve(977): Capacity is now 3.245 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:20:04,962 - [NOTICE] simulation.solve(855): Cycle 318/328 (3 minutes, 44 seconds elapsed) --------------------
# 2022-05-11 13:20:04,962 - [NOTICE] simulation.solve(889): Cycle 318/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:20:05,131 - [NOTICE] simulation.solve(889): Cycle 318/328, step 2/4: Rest for 5 min
# 2022-05-11 13:20:05,167 - [NOTICE] simulation.solve(889): Cycle 318/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:20:05,300 - [NOTICE] simulation.solve(889): Cycle 318/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:20:05,735 - [NOTICE] simulation.solve(977): Capacity is now 3.240 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:20:05,736 - [NOTICE] simulation.solve(855): Cycle 319/328 (3 minutes, 45 seconds elapsed) --------------------
# 2022-05-11 13:20:05,736 - [NOTICE] simulation.solve(889): Cycle 319/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:20:05,877 - [NOTICE] simulation.solve(889): Cycle 319/328, step 2/4: Rest for 5 min
# 2022-05-11 13:20:05,912 - [NOTICE] simulation.solve(889): Cycle 319/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:20:06,006 - [NOTICE] simulation.solve(889): Cycle 319/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:20:07,236 - [NOTICE] simulation.solve(977): Capacity is now 3.235 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:20:07,237 - [NOTICE] simulation.solve(855): Cycle 320/328 (3 minutes, 47 seconds elapsed) --------------------
# 2022-05-11 13:20:07,238 - [NOTICE] simulation.solve(889): Cycle 320/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:20:07,396 - [NOTICE] simulation.solve(889): Cycle 320/328, step 2/4: Rest for 5 min
# 2022-05-11 13:20:07,445 - [NOTICE] simulation.solve(889): Cycle 320/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:20:07,550 - [NOTICE] simulation.solve(889): Cycle 320/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:20:08,117 - [NOTICE] simulation.solve(977): Capacity is now 3.230 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:20:08,117 - [NOTICE] simulation.solve(855): Cycle 321/328 (3 minutes, 48 seconds elapsed) --------------------
# 2022-05-11 13:20:08,118 - [NOTICE] simulation.solve(889): Cycle 321/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:20:08,305 - [NOTICE] simulation.solve(889): Cycle 321/328, step 2/4: Rest for 5 min
# 2022-05-11 13:20:08,338 - [NOTICE] simulation.solve(889): Cycle 321/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:20:08,467 - [NOTICE] simulation.solve(889): Cycle 321/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:20:08,899 - [NOTICE] simulation.solve(977): Capacity is now 3.224 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:20:08,899 - [NOTICE] simulation.solve(855): Cycle 322/328 (3 minutes, 48 seconds elapsed) --------------------
# 2022-05-11 13:20:08,900 - [NOTICE] simulation.solve(889): Cycle 322/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:20:09,013 - [NOTICE] simulation.solve(889): Cycle 322/328, step 2/4: Rest for 5 min
# 2022-05-11 13:20:09,043 - [NOTICE] simulation.solve(889): Cycle 322/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:20:09,136 - [NOTICE] simulation.solve(889): Cycle 322/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:20:09,631 - [NOTICE] simulation.solve(977): Capacity is now 3.219 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:20:09,633 - [NOTICE] simulation.solve(855): Cycle 323/328 (3 minutes, 49 seconds elapsed) --------------------
# 2022-05-11 13:20:09,634 - [NOTICE] simulation.solve(889): Cycle 323/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:20:09,772 - [NOTICE] simulation.solve(889): Cycle 323/328, step 2/4: Rest for 5 min
# 2022-05-11 13:20:09,806 - [NOTICE] simulation.solve(889): Cycle 323/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:20:09,895 - [NOTICE] simulation.solve(889): Cycle 323/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:20:10,253 - [NOTICE] simulation.solve(977): Capacity is now 3.214 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:20:10,253 - [NOTICE] simulation.solve(855): Cycle 324/328 (3 minutes, 50 seconds elapsed) --------------------
# 2022-05-11 13:20:10,254 - [NOTICE] simulation.solve(889): Cycle 324/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:20:10,397 - [NOTICE] simulation.solve(889): Cycle 324/328, step 2/4: Rest for 5 min
# 2022-05-11 13:20:10,429 - [NOTICE] simulation.solve(889): Cycle 324/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:20:10,532 - [NOTICE] simulation.solve(889): Cycle 324/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:20:10,929 - [NOTICE] simulation.solve(977): Capacity is now 3.209 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:20:10,930 - [NOTICE] simulation.solve(855): Cycle 325/328 (3 minutes, 50 seconds elapsed) --------------------
# 2022-05-11 13:20:10,930 - [NOTICE] simulation.solve(889): Cycle 325/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:20:11,043 - [NOTICE] simulation.solve(889): Cycle 325/328, step 2/4: Rest for 5 min
# 2022-05-11 13:20:11,087 - [NOTICE] simulation.solve(889): Cycle 325/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:20:11,212 - [NOTICE] simulation.solve(889): Cycle 325/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:20:11,737 - [NOTICE] simulation.solve(977): Capacity is now 3.204 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:20:11,738 - [NOTICE] simulation.solve(855): Cycle 326/328 (3 minutes, 51 seconds elapsed) --------------------
# 2022-05-11 13:20:11,739 - [NOTICE] simulation.solve(889): Cycle 326/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:20:11,910 - [NOTICE] simulation.solve(889): Cycle 326/328, step 2/4: Rest for 5 min
# 2022-05-11 13:20:11,958 - [NOTICE] simulation.solve(889): Cycle 326/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:20:12,058 - [NOTICE] simulation.solve(889): Cycle 326/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:20:12,466 - [NOTICE] simulation.solve(977): Capacity is now 3.199 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:20:12,467 - [NOTICE] simulation.solve(855): Cycle 327/328 (3 minutes, 52 seconds elapsed) --------------------
# 2022-05-11 13:20:12,468 - [NOTICE] simulation.solve(889): Cycle 327/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:20:12,590 - [NOTICE] simulation.solve(889): Cycle 327/328, step 2/4: Rest for 5 min
# 2022-05-11 13:20:12,622 - [NOTICE] simulation.solve(889): Cycle 327/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:20:12,728 - [NOTICE] simulation.solve(889): Cycle 327/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:20:13,093 - [NOTICE] simulation.solve(977): Capacity is now 3.194 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:20:13,094 - [NOTICE] simulation.solve(855): Cycle 328/328 (3 minutes, 53 seconds elapsed) --------------------
# 2022-05-11 13:20:13,094 - [NOTICE] simulation.solve(889): Cycle 328/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-11 13:20:13,199 - [NOTICE] simulation.solve(889): Cycle 328/328, step 2/4: Rest for 5 min
# 2022-05-11 13:20:13,230 - [NOTICE] simulation.solve(889): Cycle 328/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-11 13:20:13,322 - [NOTICE] simulation.solve(889): Cycle 328/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-11 13:20:13,755 - [NOTICE] simulation.solve(977): Capacity is now 3.189 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-11 13:20:13,761 - [NOTICE] simulation.solve(1011): Finish experiment simulation, took 3 minutes, 53 seconds

# %%
def plotc3(all_sumvars_dict,all_sumvars_dict1,all_sumvars_dict2,esoh_data):
    esoh_vars = ["x_100", "y_0", "C_n", "C_p", "Capacity [A.h]", "Loss of lithium inventory [%]"]
    esoh_data["Capacity [A.h]"]=esoh_data["Cap"]
    param = pybamm.LithiumIonParameters()
    esoh_data["n_Li"]= 3600/param.F.value*(esoh_data["y_100"]*esoh_data["C_p"]+esoh_data["x_100"]*esoh_data["C_n"])
    esoh_data["Loss of lithium inventory [%]"]=(1-esoh_data["n_Li"]/esoh_data["n_Li"][0])*100
    fig, axes = plt.subplots(3,2,figsize=(7,7))
    for k, name in enumerate(esoh_vars):
        ax = axes.flat[k]
        ax.plot(all_sumvars_dict["Cycle number"],all_sumvars_dict[name],"ro")
        ax.plot(all_sumvars_dict1["Cycle number"],all_sumvars_dict[name],"bo")
        ax.plot(all_sumvars_dict2["Cycle number"],all_sumvars_dict[name],"go")
        ax.plot(esoh_data["N"],esoh_data[name],"kx")
        ax.set_title(split_long_string(name))
        if k>3:
            ax.set_xlabel("Cycle number")
    fig.legend(["Normal"] + ["10% Comp"] + ["50% Comp"] + ["Reported"], 
           loc="lower center",bbox_to_anchor=[0.5,-0.02], ncol=1, fontsize=11)
    fig.tight_layout()
    return fig

# %%
fig = plotc3(long_sol_output_0,long_sol_output_1,long_sol_output_2,esoh_data);
fig.savefig(fig_DIR +'normal_sim_'+cell_no+'highc_comp_esoh.png')

# %%
asdasd
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\spannala\PyBaMM\gmproj\fast_sim_pressure.ipynb Cell 27' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/spannala/PyBaMM/gmproj/fast_sim_pressure.ipynb#ch0000040?line=0'>1</a> asdasd
#
# NameError: name 'asdasd' is not defined

# %%
fig = plotc(long_sol_output,esoh_data);
fig.savefig(fig_DIR +'normal_sim_'+cell_no+'highc_normal_esoh.png')
# fig.savefig(fig_DIR +'normal_sim_'+cell_no+'highc_pressure_esoh.png')
# fig.savefig(fig_DIR +'normal_sim_'+cell_no+'lowc_pressure2_esoh.png')

# %%
dfdsfdsf

# %% [markdown]
# ## Comparison Plots

# %%
def plot_comp_long(all_sumvars_dict,esoh_data,long_sol_output,n: int = 1):
    esoh_vars = ["x_0", "y_0", "x_100", "y_100", "C_n", "C_p"]
    # esoh_vars = ["Capacity [A.h]", "Loss of lithium inventory [%]",
    #              "Loss of active material in negative electrode [%]",
    #              "Loss of active material in positive electrode [%]"]
    esoh_data['N']=esoh_data['N'].astype(int)
    esoh_data1 = esoh_data
    esoh_data1['N'] = esoh_data1['N']-1
    esoh_data1['N'].iloc[0] =esoh_data1['N'].iloc[0]+1 
    fig, axes = plt.subplots(3,2,figsize=(7,9))
    for k, name in enumerate(esoh_vars):
        ax = axes.flat[k]
        ax.plot(all_sumvars_dict["Cycle number"],all_sumvars_dict[name],"ro")
        ax.plot(long_sol_output["Cycle number"],long_sol_output[name],"b.")
        ax.plot(esoh_data["N"],esoh_data[name],"kx")
#         ax.scatter(all_sumvars_dict["Cycle number"],all_sumvars_dict[name],color="r")
    #     ax.plot(long_sol.summary_variables[name],"b-")
        ax.set_title(split_long_string(name))
        if k>3:
            ax.set_xlabel("Cycle number")
    # fig.subplots_adjust(bottom=0.4)
    fig.legend(["Acc Sim"] + ["Long Sim"] + ["Reported"], 
           loc="lower center", ncol=1, fontsize=11)
    fig.tight_layout()

    return fig

def plot1_comp_long(all_sumvars_dict,esoh_data,long_sol_output,n: int = 1):
    esoh_vars = ["Capacity [A.h]","n_Li"]
    esoh_data["Capacity [A.h]"]=esoh_data["Cap"]
    param = pybamm.LithiumIonParameters()
    esoh_data["n_Li"]= 3600/param.F.value*(esoh_data["y_100"]*esoh_data["C_p"]+esoh_data["x_100"]*esoh_data["C_n"])
    esoh_data['N']=esoh_data['N'].astype(int)
    esoh_data1 = esoh_data
    esoh_data1 = esoh_data
    esoh_data1['N'] = esoh_data1['N']-1
    esoh_data1['N'].iloc[0] =esoh_data1['N'].iloc[0]+1 
    fig, axes = plt.subplots(2,1,figsize=(7,9))
    for k, name in enumerate(esoh_vars):
        ax = axes.flat[k]
        ax.plot(all_sumvars_dict["Cycle number"][esoh_data1['N']//n],all_sumvars_dict[name][esoh_data1['N']//n],"ro")
        ax.plot(long_sol_output["Cycle number"][esoh_data1['N']],long_sol_output[name][esoh_data1['N']],"b.")
        ax.plot(esoh_data["N"],esoh_data[name],"kx")
        ax.set_title(split_long_string(name))
        ax.set_xlabel("Cycle number")
    ax.legend(["Acc Sim"] + ["Long Sim"] + ["Reported"], 
           loc="upper right", ncol=1, fontsize=11)
    fig.tight_layout()
    return fig

# %%
fig = plot_comp_long(all_sumvars_dict,esoh_data,long_sol_output,1)

# %%
# spm.variables.search("Concentration")

# %%
t = sol_long["Time [s]"].entries
I = sol_long["Current [A]"].entries
Q = -sol_long['Discharge capacity [A.h]'].entries
Vt = sol_long["Terminal voltage [V]"].entries
exp = 30e6*sol_long["Cell thickness change [m]"].entries
exp_n = 30e6*sol_long["Negative Electrode thickness change [m]"].entries
exp_p = 30e6*sol_long["Positive Electrode thickness change [m]"].entries
ee_p = sol_long["X-averaged positive electrode porosity"].entries
ee_n = sol_long["X-averaged negative electrode porosity"].entries
ee_s = sol_long["X-averaged separator porosity"].entries
j_n = sol_long["X-averaged negative electrode total interfacial current density [A.m-2]"].entries
j_p = sol_long["X-averaged positive electrode total interfacial current density [A.m-2]"].entries

# %%
plt.figure()
plt.plot(-Q,Vt)
plt.xlim(left=0)
plt.xlabel('Q [Ah]')
plt.ylabel('Voltage [V]')

# %%
plt.figure()
plt.plot(t,Vt)
# plt.xlim(left=0)
plt.xlabel('Q [Ah]')
plt.ylabel('Voltage [V]')

# %%
fig = plt.figure(figsize=[8,4])
ax1 = plt.subplot(1,3,1)
ax1.plot(-Q,exp_n)
ax1.set_xlim(left=0)
ax1.set_xlabel('Q [Ah]')
ax1.set_ylabel('Exp [$\mu$m]')
ax1.set_title('NE')
ax2 = plt.subplot(1,3,2)
ax2.plot(-Q,exp)
ax2.set_xlim(left=0)
ax2.set_xlabel('Q [Ah]')
ax2.set_title('Total')
ax2.set_ylabel('Exp [$\mu$m]')
ax3 = plt.subplot(1,3,3)
ax3.plot(-Q,exp_p)
ax3.set_xlim(left=0)
ax3.set_xlabel('Q [Ah]')
ax3.set_ylabel('Exp [$\mu$m]')
ax3.set_title('PE')
fig.tight_layout()
