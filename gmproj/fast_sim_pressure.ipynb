# %% [markdown]
# # Low c-rate aging simulation ORIGINAL Code from ACC Paper

# %%
import pybamm
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import math
from scipy.integrate import solve_ivp

DATA_DIR  = "./data/esoh_V/"
fig_DIR = "./figures/"

# %% [markdown]
# # Set Parameters and Expansion Functions

# %%
def nmc_volume_change_mohtat(sto):
    t_change = -1.10/100*(1-sto)
    return t_change

def graphite_volume_change_mohtat(sto):
    stoichpoints = np.array([0,0.12,0.18,0.24,0.50,1])
    thicknesspoints = np.array([0,2.406/100,3.3568/100,4.3668/100,5.583/100,13.0635/100])
    x = [sto]
    t_change = pybamm.Interpolant(stoichpoints, thicknesspoints, x, name=None, interpolator='linear', extrapolate=True, entries_string=None)
    return t_change

def get_parameter_values():
    parameter_values = pybamm.ParameterValues(chemistry=pybamm.parameter_sets.Mohtat2020)
    parameter_values.update(
        {
            # mechanical properties
            "Positive electrode Poisson's ratio": 0.3,
            "Positive electrode Young's modulus [Pa]": 375e9,
            "Positive electrode reference concentration for free of deformation [mol.m-3]": 0,
            "Positive electrode partial molar volume [m3.mol-1]": -7.28e-7,
            "Positive electrode volume change": nmc_volume_change_mohtat,
            # Loss of active materials (LAM) model
            "Positive electrode LAM constant exponential term": 2,
            "Positive electrode critical stress [Pa]": 375e6,
            # mechanical properties
            "Negative electrode Poisson's ratio": 0.2,
            "Negative electrode Young's modulus [Pa]": 15e9,
            "Negative electrode reference concentration for free of deformation [mol.m-3]": 0,
            "Negative electrode partial molar volume [m3.mol-1]": 3.1e-6,
            "Negative electrode volume change": graphite_volume_change_mohtat,
            # Loss of active materials (LAM) model
            "Negative electrode LAM constant exponential term": 2,
            "Negative electrode critical stress [Pa]": 60e6,
            # Other
            "Cell thermal expansion coefficient [m.K-1]": 1.48E-6,
            "Lower voltage cut-off [V]": 3.0
        },
        check_already_exists=False,
    )
    return parameter_values
parameter_values = get_parameter_values()

# %%
parameter_values.search("Li")
# Out:
# Cell cooling surface area [m2]	0.41
# Initial plated lithium concentration [mol.m-3]	0.0
# Inner SEI lithium interstitial diffusivity [m2.s-1]	1e-20
# Lithium interstitial reference concentration [mol.m-3]	15.0
# Lithium metal partial molar volume [m3.mol-1]	1.3e-05
# Typical lithium ion diffusivity [m2.s-1]	5.34e-10
# Typical plated lithium concentration [mol.m-3]	1000.0

# %%
def split_long_string(title, max_words=None):
    """Get title in a nice format"""
    max_words = max_words or pybamm.settings.max_words_in_line
    words = title.split()
    # Don't split if fits on one line, don't split just for units
    if len(words) <= max_words or words[max_words].startswith("["):
        return title
    else:
        first_line = (" ").join(words[:max_words])
        second_line = (" ").join(words[max_words:])
        return first_line + "\n" + second_line

# %% [markdown]
# # Accelerated Simulations Function

# %%
def cycle_adaptive_simulation(model, parameter_values, experiment,SOC_0=1, save_at_cycles=None):
    experiment_one_cycle = pybamm.Experiment(
        experiment.operating_conditions_cycles[:1],
        termination=experiment.termination_string,
        cccv_handling=experiment.cccv_handling,
    )
    Vmin = 3.0
    Vmax = 4.2
    esoh_model = pybamm.lithium_ion.ElectrodeSOH()
    esoh_sim = pybamm.Simulation(esoh_model, parameter_values=parameter_values)
    param = model.param
    Cn = parameter_values.evaluate(param.C_n_init)
    Cp = parameter_values.evaluate(param.C_p_init)
    eps_n = parameter_values["Negative electrode active material volume fraction"]
    eps_p = parameter_values["Positive electrode active material volume fraction"]
    C_over_eps_n = Cn / eps_n
    C_over_eps_p = Cp / eps_p
    c_n_max = parameter_values.evaluate(param.c_n_max)
    c_p_max = parameter_values.evaluate(param.c_p_max)
    n_Li_init = parameter_values.evaluate(param.n_Li_particles_init)
    
    esoh_sol = esoh_sim.solve(
        [0],
        inputs={"V_min": Vmin, "V_max": Vmax, "C_n": Cn, "C_p": Cp, "n_Li": n_Li_init},
        solver=pybamm.AlgebraicSolver(),
    )

    parameter_values.update(
        {
            "Initial concentration in negative electrode [mol.m-3]": esoh_sol[
                "x_100"
            ].data[0]
            * c_n_max,
            "Initial concentration in positive electrode [mol.m-3]": esoh_sol[
                "y_100"
            ].data[0]
            * c_p_max,
            
        }
    )

    sim_ode = pybamm.Simulation(
        model, experiment=experiment_one_cycle, parameter_values=parameter_values,
        solver=pybamm.CasadiSolver("safe")
    )
    sol0 = sim_ode.solve(initial_soc=SOC_0)
    model = sim_ode.solution.all_models[0]
    cap0 = sol0.summary_variables["Capacity [A.h]"]

    def sol_to_y(sol, loc="end"):
        if loc == "start":
            pos = 0
        elif loc == "end":
            pos = -1
        model = sol.all_models[0]
        n_Li = sol["Total lithium in particles [mol]"].data[pos].flatten()
        Cn = sol["Negative electrode capacity [A.h]"].data[pos].flatten()
        Cp = sol["Positive electrode capacity [A.h]"].data[pos].flatten()
        # y = np.concatenate([n_Li, Cn, Cp])
        y = n_Li
        for var in model.initial_conditions:
            if var.name not in [
                "X-averaged negative particle concentration",
                "X-averaged positive particle concentration",
                "Discharge capacity [A.h]",
            ]:
                value = sol[var.name].data
                if value.ndim == 1:
                    value = value[pos]
                elif value.ndim == 2:
                    value = value[:, pos]
                elif value.ndim == 3:
                    value = value[:, :, pos]
                y = np.concatenate([y, value.flatten()])
        return y

    def y_to_sol(y, esoh_sim, model):
        n_Li = y[0]
        Cn = C_over_eps_n * y[1]
        Cp = C_over_eps_p * y[2]

        esoh_sol = esoh_sim.solve(
            [0],
            inputs={"V_min": Vmin, "V_max": Vmax, "C_n": Cn, "C_p": Cp, "n_Li": n_Li},
        )
        esoh_sim.built_model.set_initial_conditions_from(esoh_sol)
        ics = {}
        x_100 = esoh_sol["x_100"].data[0]
        y_100 = esoh_sol["y_100"].data[0]
        x_0 = esoh_sol["x_0"].data[0]
        y_0 = esoh_sol["y_0"].data[0]
        start = 1
        for var in model.initial_conditions:
            if var.name == "X-averaged negative particle concentration":
                ics[var.name] = ((x_100-x_0)*SOC_0+x_0) * np.ones((model.variables[var.name].size, 2))
            elif var.name == "X-averaged positive particle concentration":
                ics[var.name] = ((y_100-y_0)*SOC_0+y_0) * np.ones((model.variables[var.name].size, 2))
            elif var.name == "Discharge capacity [A.h]":
                ics[var.name] = np.zeros(1)
            else:
                end = start + model.variables[var.name].size
                ics[var.name] = y[start:end, np.newaxis]
                start = end
        model.set_initial_conditions_from(ics)
        return pybamm.Solution(
            [np.array([0])],
            model.concatenated_initial_conditions.evaluate()[:, np.newaxis],
            model,
            {},
        )

    def dydt(t, y):
        if y[0] < 0 or y[1] < 0 or y[2] < 0:
            return 0 * y

        print(t)
        # Set up based on current value of y
        y_to_sol(
            y,
            esoh_sim,
            sim_ode.op_conds_to_built_models[
                experiment_one_cycle.operating_conditions[0]["electric"]
            ],
        )

        # Simulate one cycle
        sol = sim_ode.solve()

        dy = sol_to_y(sol) - y

        return dy

    if experiment.termination == {}:
        event = None
    else:

        def capacity_cutoff(t, y):
            sol = y_to_sol(y, esoh_sim, model)
            cap = pybamm.make_cycle_solution([sol], esoh_sim, True)[1]["Capacity [A.h]"]
            return cap / cap0 - experiment_one_cycle.termination["capacity"][0] / 100

        capacity_cutoff.terminal = True

    num_cycles = len(experiment.operating_conditions_cycles)
    if save_at_cycles is None:
        t_eval = np.arange(1, num_cycles + 1)
    elif save_at_cycles == -1:
        t_eval = None
    else:
        t_eval = np.arange(1, num_cycles + 1, save_at_cycles)
    y0 = sol_to_y(sol0, loc="start")
    timer = pybamm.Timer()
    sol = solve_ivp(
        dydt,
        [1, num_cycles],
        y0,
        t_eval=t_eval,
        events=capacity_cutoff,
        first_step=10,
        method="RK23",
        atol=1e-2,
        rtol=1e-2,
    )
    time = timer.time()

    all_sumvars = []
    for idx in range(sol.y.shape[1]):
        fullsol = y_to_sol(sol.y[:, idx], esoh_sim, model)
        sumvars = pybamm.make_cycle_solution([fullsol], esoh_sim, True)[1]
        all_sumvars.append(sumvars)

    all_sumvars_dict = {
        key: np.array([sumvars[key] for sumvars in all_sumvars])
        for key in all_sumvars[0].keys()
    }
    all_sumvars_dict["Cycle number"] = sol.t
    
    all_sumvars_dict["cycles evaluated"] = sol.nfev
    all_sumvars_dict["solution time"] = time
    
    return all_sumvars_dict

# %% [markdown]
# # Plot Functions

# %%
def plot(all_sumvars_dict,esoh_data):
    esoh_vars = ["x_0", "y_0", "x_100", "y_100", "C_n", "C_p"]
    # esoh_vars = ["Capacity [A.h]", "Loss of lithium inventory [%]",
    #              "Loss of active material in negative electrode [%]",
    #              "Loss of active material in positive electrode [%]"]
    fig, axes = plt.subplots(3,2,figsize=(7,9))
    for k, name in enumerate(esoh_vars):
        ax = axes.flat[k]
        ax.plot(all_sumvars_dict["Cycle number"],all_sumvars_dict[name],"ro")
        ax.plot(esoh_data["N"],esoh_data[name],"kx")
#         ax.scatter(all_sumvars_dict["Cycle number"],all_sumvars_dict[name],color="r")
    #     ax.plot(long_sol.summary_variables[name],"b-")
        ax.set_title(split_long_string(name))
        if k>3:
            ax.set_xlabel("Cycle number")
    # fig.subplots_adjust(bottom=0.4)
    fig.legend(["Acc Sim"] + ["Reported"], 
           loc="lower center", ncol=1, fontsize=11)
    fig.tight_layout()
    return fig

def plot1(all_sumvars_dict,esoh_data):
    esoh_vars = ["Capacity [A.h]","n_Li"]
    esoh_data["Capacity [A.h]"]=esoh_data["Cap"]
    param = pybamm.LithiumIonParameters()
    esoh_data["n_Li"]= 3600/param.F.value*(esoh_data["y_100"]*esoh_data["C_p"]+esoh_data["x_100"]*esoh_data["C_n"])
    fig, axes = plt.subplots(2,1,figsize=(7,9))
    for k, name in enumerate(esoh_vars):
        ax = axes.flat[k]
        ax.plot(all_sumvars_dict["Cycle number"],all_sumvars_dict[name],"ro")
        ax.plot(esoh_data["N"],esoh_data[name],"kx")
        ax.set_title(split_long_string(name))
        ax.set_xlabel("Cycle number")
    fig.legend(["Acc Sim"] + ["Reported"], 
           loc="upper right", ncol=1, fontsize=11)
    fig.tight_layout()
    return fig
    
def plotc(all_sumvars_dict,esoh_data):
    esoh_vars = ["x_100", "y_0", "C_n", "C_p", "Capacity [A.h]", "Loss of lithium inventory [%]"]
    esoh_data["Capacity [A.h]"]=esoh_data["Cap"]
    param = pybamm.LithiumIonParameters()
    esoh_data["n_Li"]= 3600/param.F.value*(esoh_data["y_100"]*esoh_data["C_p"]+esoh_data["x_100"]*esoh_data["C_n"])
    esoh_data["Loss of lithium inventory [%]"]=(1-esoh_data["n_Li"]/esoh_data["n_Li"][0])*100
    fig, axes = plt.subplots(3,2,figsize=(7,7))
    for k, name in enumerate(esoh_vars):
        ax = axes.flat[k]
        ax.plot(all_sumvars_dict["Cycle number"],all_sumvars_dict[name],"ro")
        # ax.plot(esoh_data["N"],esoh_data[name],"kx")
        ax.set_title(split_long_string(name))
        if k>3:
            ax.set_xlabel("Cycle number")
    # fig.legend(["Acc Sim"] + ["Reported"], 
    #        loc="lower center",bbox_to_anchor=[0.5,-0.02], ncol=1, fontsize=11)
    fig.tight_layout()
    return fig

# %% [markdown]
# # Choose Cell

# %%
cell = 4

# %% [markdown]
# ## Set cell eSOH and cycling parameters

# %%
cell_no = f'{cell:02d}'
if cell_no=='01':
    c_rate_c = 'C/5'
    c_rate_d = 'C/5'
    dis_set = " until 3V"
    eps_n_data = 0.6234
    eps_p_data = 0.4542
elif cell_no=='04':
    c_rate_c = '1.5C'
    c_rate_d = '1.5C'
    dis_set = " until 3V"
    eps_n_data = 0.6247
    eps_p_data = 0.4512
elif cell_no=='07':
    c_rate_c = '2C'
    c_rate_d = '2C'
    dis_set = " until 3V"
    eps_n_data = 0.6166
    eps_p_data = 0.4529
elif cell_no=='10':
    c_rate_c = 'C/5'
    c_rate_d = '1.5C'
    dis_set = " until 3V"
    eps_n_data = 0.6250
    eps_p_data = 0.4493
elif cell_no=='13':
    c_rate_c = 'C/5'
    c_rate_d = 'C/5'
    dis_set = " for 150 min"
    eps_n_data = 0.6247
    eps_p_data = 0.4544
elif cell_no=='16':
    c_rate_c = 'C/5'
    c_rate_d = '1.5C'
    dis_set = " for 20 min"
    eps_n_data = 0.6243
    eps_p_data = 0.4501
esoh_data =  pd.read_csv(DATA_DIR +'aging_param_cell_'+cell_no+'.csv')  
esoh_data.N.iloc[-1]
# Out:
# 328

# %% [markdown]
# # Define Experiment and Model

# %%
pybamm.set_logging_level("WARNING")
pybamm.set_logging_level("NOTICE")
experiment = pybamm.Experiment(
    [
        ("Discharge at "+c_rate_d+dis_set,
         "Rest for 5 min",
         "Charge at "+c_rate_c+" until 4.2V", 
         "Hold at 4.2V until C/50")
    ] *esoh_data.N.iloc[-1],
    termination="50% capacity",
#     cccv_handling="ode",
)
spm = pybamm.lithium_ion.SPMe(
    {
        "SEI": "ec reaction limited",
        # "loss of active material": ("stress-driven","none"),
        "loss of active material": "stress-driven",
        "stress-induced diffusion": "true",
        # "lithium plating": "reversible",
    }
)
# spm.print_parameter_info()

# %% [markdown]
# # Set Additional Parameter Value and Simulate

# %%
parameter_values = get_parameter_values()
parameter_values.update(
    {

        "Positive electrode LAM constant proportional term [s-1]": 8.7864e-07,
        "Negative electrode LAM constant proportional term [s-1]": 1.08031e-05,
        "SEI kinetic rate constant [m.s-1]": 1.6297e-15,
        "EC diffusivity [m2.s-1]": 2e-18,
        "Positive electrode LAM constant exponential term": 2,
        "Negative electrode LAM constant exponential term": 2,
        "Negative electrode active material volume fraction": eps_n_data,
        "Positive electrode active material volume fraction": eps_p_data,
        "Negative electrode porosity": 0.3,
        "Positive electrode porosity": 0.3,
        "Separator porosity": 0.4,
        # "Negative electrode porosity": 0.28,
        # "Positive electrode porosity": 0.28,
        # "Separator porosity": 0.38,
        # "Negative electrode porosity": 0.15,
        # "Positive electrode porosity": 0.15,
        # "Separator porosity": 0.2,
    },
    check_already_exists=False,
)
# all_sumvars_dict = cycle_adaptive_simulation(spm, parameter_values, experiment, save_at_cycles=2)

# %%
# fig = plotc(all_sumvars_dict,esoh_data);
# fig.savefig(fig_DIR +'fast_sim_'+cell_no+'_esoh.png')

# %%
# afsdfsd

# %% [markdown]
# # Normal Simulations

# %%
sim_long = pybamm.Simulation(spm, experiment=experiment, parameter_values=parameter_values, 
                            solver=pybamm.CasadiSolver("safe"))
sol_long_0 = sim_long.solve(initial_soc=1)
long_sol_output_0 =sol_long_0.summary_variables
# Out:
# 2022-05-18 18:17:20,154 - [NOTICE] simulation.solve(855): Cycle 1/328 (37.089 ms elapsed) --------------------
# 2022-05-18 18:17:20,155 - [NOTICE] simulation.solve(889): Cycle 1/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:17:20,432 - [NOTICE] simulation.solve(889): Cycle 1/328, step 2/4: Rest for 5 min
# 2022-05-18 18:17:20,556 - [NOTICE] simulation.solve(889): Cycle 1/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:17:20,843 - [NOTICE] simulation.solve(889): Cycle 1/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:17:21,607 - [NOTICE] simulation.solve(977): Capacity is now 5.032 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:17:21,609 - [NOTICE] simulation.solve(855): Cycle 2/328 (1.492 s elapsed) --------------------
# 2022-05-18 18:17:21,609 - [NOTICE] simulation.solve(889): Cycle 2/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:17:21,821 - [NOTICE] simulation.solve(889): Cycle 2/328, step 2/4: Rest for 5 min
# 2022-05-18 18:17:21,859 - [NOTICE] simulation.solve(889): Cycle 2/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:17:22,009 - [NOTICE] simulation.solve(889): Cycle 2/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:17:22,272 - [NOTICE] simulation.solve(977): Capacity is now 5.026 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:17:22,272 - [NOTICE] simulation.solve(855): Cycle 3/328 (2.155 s elapsed) --------------------
# 2022-05-18 18:17:22,273 - [NOTICE] simulation.solve(889): Cycle 3/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:17:22,461 - [NOTICE] simulation.solve(889): Cycle 3/328, step 2/4: Rest for 5 min
# 2022-05-18 18:17:22,503 - [NOTICE] simulation.solve(889): Cycle 3/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:17:22,674 - [NOTICE] simulation.solve(889): Cycle 3/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:17:22,950 - [NOTICE] simulation.solve(977): Capacity is now 5.020 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:17:22,951 - [NOTICE] simulation.solve(855): Cycle 4/328 (2.834 s elapsed) --------------------
# 2022-05-18 18:17:22,952 - [NOTICE] simulation.solve(889): Cycle 4/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:17:23,171 - [NOTICE] simulation.solve(889): Cycle 4/328, step 2/4: Rest for 5 min
# 2022-05-18 18:17:23,208 - [NOTICE] simulation.solve(889): Cycle 4/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:17:23,371 - [NOTICE] simulation.solve(889): Cycle 4/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:17:23,685 - [NOTICE] simulation.solve(977): Capacity is now 5.014 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:17:23,686 - [NOTICE] simulation.solve(855): Cycle 5/328 (3.569 s elapsed) --------------------
# 2022-05-18 18:17:23,687 - [NOTICE] simulation.solve(889): Cycle 5/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:17:23,896 - [NOTICE] simulation.solve(889): Cycle 5/328, step 2/4: Rest for 5 min
# 2022-05-18 18:17:23,934 - [NOTICE] simulation.solve(889): Cycle 5/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:17:24,087 - [NOTICE] simulation.solve(889): Cycle 5/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:17:24,431 - [NOTICE] simulation.solve(977): Capacity is now 5.008 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:17:24,432 - [NOTICE] simulation.solve(855): Cycle 6/328 (4.315 s elapsed) --------------------
# 2022-05-18 18:17:24,432 - [NOTICE] simulation.solve(889): Cycle 6/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:17:24,603 - [NOTICE] simulation.solve(889): Cycle 6/328, step 2/4: Rest for 5 min
# 2022-05-18 18:17:24,635 - [NOTICE] simulation.solve(889): Cycle 6/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:17:24,792 - [NOTICE] simulation.solve(889): Cycle 6/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:17:25,105 - [NOTICE] simulation.solve(977): Capacity is now 5.002 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:17:25,106 - [NOTICE] simulation.solve(855): Cycle 7/328 (4.990 s elapsed) --------------------
# 2022-05-18 18:17:25,107 - [NOTICE] simulation.solve(889): Cycle 7/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:17:25,274 - [NOTICE] simulation.solve(889): Cycle 7/328, step 2/4: Rest for 5 min
# 2022-05-18 18:17:25,308 - [NOTICE] simulation.solve(889): Cycle 7/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:17:25,496 - [NOTICE] simulation.solve(889): Cycle 7/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:17:25,772 - [NOTICE] simulation.solve(977): Capacity is now 4.997 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:17:25,773 - [NOTICE] simulation.solve(855): Cycle 8/328 (5.656 s elapsed) --------------------
# 2022-05-18 18:17:25,773 - [NOTICE] simulation.solve(889): Cycle 8/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:17:25,928 - [NOTICE] simulation.solve(889): Cycle 8/328, step 2/4: Rest for 5 min
# 2022-05-18 18:17:25,962 - [NOTICE] simulation.solve(889): Cycle 8/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:17:26,107 - [NOTICE] simulation.solve(889): Cycle 8/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:17:26,413 - [NOTICE] simulation.solve(977): Capacity is now 4.991 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:17:26,414 - [NOTICE] simulation.solve(855): Cycle 9/328 (6.297 s elapsed) --------------------
# 2022-05-18 18:17:26,414 - [NOTICE] simulation.solve(889): Cycle 9/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:17:26,563 - [NOTICE] simulation.solve(889): Cycle 9/328, step 2/4: Rest for 5 min
# 2022-05-18 18:17:26,597 - [NOTICE] simulation.solve(889): Cycle 9/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:17:26,740 - [NOTICE] simulation.solve(889): Cycle 9/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:17:27,023 - [NOTICE] simulation.solve(977): Capacity is now 4.985 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:17:27,023 - [NOTICE] simulation.solve(855): Cycle 10/328 (6.907 s elapsed) --------------------
# 2022-05-18 18:17:27,024 - [NOTICE] simulation.solve(889): Cycle 10/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:17:27,182 - [NOTICE] simulation.solve(889): Cycle 10/328, step 2/4: Rest for 5 min
# 2022-05-18 18:17:27,219 - [NOTICE] simulation.solve(889): Cycle 10/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:17:27,372 - [NOTICE] simulation.solve(889): Cycle 10/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:17:27,672 - [NOTICE] simulation.solve(977): Capacity is now 4.978 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:17:27,673 - [NOTICE] simulation.solve(855): Cycle 11/328 (7.556 s elapsed) --------------------
# 2022-05-18 18:17:27,674 - [NOTICE] simulation.solve(889): Cycle 11/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:17:27,853 - [NOTICE] simulation.solve(889): Cycle 11/328, step 2/4: Rest for 5 min
# 2022-05-18 18:17:27,895 - [NOTICE] simulation.solve(889): Cycle 11/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:17:28,062 - [NOTICE] simulation.solve(889): Cycle 11/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:17:28,341 - [NOTICE] simulation.solve(977): Capacity is now 4.976 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:17:28,341 - [NOTICE] simulation.solve(855): Cycle 12/328 (8.225 s elapsed) --------------------
# 2022-05-18 18:17:28,342 - [NOTICE] simulation.solve(889): Cycle 12/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:17:28,529 - [NOTICE] simulation.solve(889): Cycle 12/328, step 2/4: Rest for 5 min
# 2022-05-18 18:17:28,563 - [NOTICE] simulation.solve(889): Cycle 12/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:17:28,719 - [NOTICE] simulation.solve(889): Cycle 12/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:17:29,043 - [NOTICE] simulation.solve(977): Capacity is now 4.966 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:17:29,044 - [NOTICE] simulation.solve(855): Cycle 13/328 (8.928 s elapsed) --------------------
# 2022-05-18 18:17:29,045 - [NOTICE] simulation.solve(889): Cycle 13/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:17:29,202 - [NOTICE] simulation.solve(889): Cycle 13/328, step 2/4: Rest for 5 min
# 2022-05-18 18:17:29,237 - [NOTICE] simulation.solve(889): Cycle 13/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:17:29,396 - [NOTICE] simulation.solve(889): Cycle 13/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:17:29,700 - [NOTICE] simulation.solve(977): Capacity is now 4.964 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:17:29,701 - [NOTICE] simulation.solve(855): Cycle 14/328 (9.585 s elapsed) --------------------
# 2022-05-18 18:17:29,702 - [NOTICE] simulation.solve(889): Cycle 14/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:17:29,857 - [NOTICE] simulation.solve(889): Cycle 14/328, step 2/4: Rest for 5 min
# 2022-05-18 18:17:29,892 - [NOTICE] simulation.solve(889): Cycle 14/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:17:30,032 - [NOTICE] simulation.solve(889): Cycle 14/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:17:30,311 - [NOTICE] simulation.solve(977): Capacity is now 4.954 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:17:30,312 - [NOTICE] simulation.solve(855): Cycle 15/328 (10.195 s elapsed) --------------------
# 2022-05-18 18:17:30,313 - [NOTICE] simulation.solve(889): Cycle 15/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:17:30,475 - [NOTICE] simulation.solve(889): Cycle 15/328, step 2/4: Rest for 5 min
# 2022-05-18 18:17:30,518 - [NOTICE] simulation.solve(889): Cycle 15/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:17:30,657 - [NOTICE] simulation.solve(889): Cycle 15/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:17:30,935 - [NOTICE] simulation.solve(977): Capacity is now 4.948 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:17:30,936 - [NOTICE] simulation.solve(855): Cycle 16/328 (10.819 s elapsed) --------------------
# 2022-05-18 18:17:30,937 - [NOTICE] simulation.solve(889): Cycle 16/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:17:31,088 - [NOTICE] simulation.solve(889): Cycle 16/328, step 2/4: Rest for 5 min
# 2022-05-18 18:17:31,119 - [NOTICE] simulation.solve(889): Cycle 16/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:17:31,251 - [NOTICE] simulation.solve(889): Cycle 16/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:17:31,522 - [NOTICE] simulation.solve(977): Capacity is now 4.942 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:17:31,523 - [NOTICE] simulation.solve(855): Cycle 17/328 (11.406 s elapsed) --------------------
# 2022-05-18 18:17:31,524 - [NOTICE] simulation.solve(889): Cycle 17/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:17:31,680 - [NOTICE] simulation.solve(889): Cycle 17/328, step 2/4: Rest for 5 min
# 2022-05-18 18:17:31,712 - [NOTICE] simulation.solve(889): Cycle 17/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:17:31,847 - [NOTICE] simulation.solve(889): Cycle 17/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:17:32,136 - [NOTICE] simulation.solve(977): Capacity is now 4.936 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:17:32,137 - [NOTICE] simulation.solve(855): Cycle 18/328 (12.021 s elapsed) --------------------
# 2022-05-18 18:17:32,138 - [NOTICE] simulation.solve(889): Cycle 18/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:17:32,277 - [NOTICE] simulation.solve(889): Cycle 18/328, step 2/4: Rest for 5 min
# 2022-05-18 18:17:32,314 - [NOTICE] simulation.solve(889): Cycle 18/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:17:32,447 - [NOTICE] simulation.solve(889): Cycle 18/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:17:32,726 - [NOTICE] simulation.solve(977): Capacity is now 4.932 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:17:32,727 - [NOTICE] simulation.solve(855): Cycle 19/328 (12.611 s elapsed) --------------------
# 2022-05-18 18:17:32,728 - [NOTICE] simulation.solve(889): Cycle 19/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:17:32,881 - [NOTICE] simulation.solve(889): Cycle 19/328, step 2/4: Rest for 5 min
# 2022-05-18 18:17:32,913 - [NOTICE] simulation.solve(889): Cycle 19/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:17:33,047 - [NOTICE] simulation.solve(889): Cycle 19/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:17:33,316 - [NOTICE] simulation.solve(977): Capacity is now 4.923 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:17:33,317 - [NOTICE] simulation.solve(855): Cycle 20/328 (13.201 s elapsed) --------------------
# 2022-05-18 18:17:33,318 - [NOTICE] simulation.solve(889): Cycle 20/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:17:33,489 - [NOTICE] simulation.solve(889): Cycle 20/328, step 2/4: Rest for 5 min
# 2022-05-18 18:17:33,522 - [NOTICE] simulation.solve(889): Cycle 20/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:17:33,672 - [NOTICE] simulation.solve(889): Cycle 20/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:17:33,944 - [NOTICE] simulation.solve(977): Capacity is now 4.919 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:17:33,945 - [NOTICE] simulation.solve(855): Cycle 21/328 (13.828 s elapsed) --------------------
# 2022-05-18 18:17:33,945 - [NOTICE] simulation.solve(889): Cycle 21/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:17:34,088 - [NOTICE] simulation.solve(889): Cycle 21/328, step 2/4: Rest for 5 min
# 2022-05-18 18:17:34,120 - [NOTICE] simulation.solve(889): Cycle 21/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:17:34,277 - [NOTICE] simulation.solve(889): Cycle 21/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:17:34,557 - [NOTICE] simulation.solve(977): Capacity is now 4.913 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:17:34,558 - [NOTICE] simulation.solve(855): Cycle 22/328 (14.441 s elapsed) --------------------
# 2022-05-18 18:17:34,559 - [NOTICE] simulation.solve(889): Cycle 22/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:17:34,711 - [NOTICE] simulation.solve(889): Cycle 22/328, step 2/4: Rest for 5 min
# 2022-05-18 18:17:34,751 - [NOTICE] simulation.solve(889): Cycle 22/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:17:34,900 - [NOTICE] simulation.solve(889): Cycle 22/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:17:35,199 - [NOTICE] simulation.solve(977): Capacity is now 4.907 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:17:35,199 - [NOTICE] simulation.solve(855): Cycle 23/328 (15.083 s elapsed) --------------------
# 2022-05-18 18:17:35,200 - [NOTICE] simulation.solve(889): Cycle 23/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:17:35,364 - [NOTICE] simulation.solve(889): Cycle 23/328, step 2/4: Rest for 5 min
# 2022-05-18 18:17:35,397 - [NOTICE] simulation.solve(889): Cycle 23/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:17:35,531 - [NOTICE] simulation.solve(889): Cycle 23/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:17:35,810 - [NOTICE] simulation.solve(977): Capacity is now 4.900 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:17:35,811 - [NOTICE] simulation.solve(855): Cycle 24/328 (15.694 s elapsed) --------------------
# 2022-05-18 18:17:35,811 - [NOTICE] simulation.solve(889): Cycle 24/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:17:35,949 - [NOTICE] simulation.solve(889): Cycle 24/328, step 2/4: Rest for 5 min
# 2022-05-18 18:17:35,984 - [NOTICE] simulation.solve(889): Cycle 24/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:17:36,122 - [NOTICE] simulation.solve(889): Cycle 24/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:17:36,408 - [NOTICE] simulation.solve(977): Capacity is now 4.894 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:17:36,409 - [NOTICE] simulation.solve(855): Cycle 25/328 (16.293 s elapsed) --------------------
# 2022-05-18 18:17:36,410 - [NOTICE] simulation.solve(889): Cycle 25/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:17:36,551 - [NOTICE] simulation.solve(889): Cycle 25/328, step 2/4: Rest for 5 min
# 2022-05-18 18:17:36,582 - [NOTICE] simulation.solve(889): Cycle 25/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:17:36,715 - [NOTICE] simulation.solve(889): Cycle 25/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:17:36,998 - [NOTICE] simulation.solve(977): Capacity is now 4.888 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:17:36,998 - [NOTICE] simulation.solve(855): Cycle 26/328 (16.881 s elapsed) --------------------
# 2022-05-18 18:17:36,999 - [NOTICE] simulation.solve(889): Cycle 26/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:17:37,133 - [NOTICE] simulation.solve(889): Cycle 26/328, step 2/4: Rest for 5 min
# 2022-05-18 18:17:37,165 - [NOTICE] simulation.solve(889): Cycle 26/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:17:37,299 - [NOTICE] simulation.solve(889): Cycle 26/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:17:37,570 - [NOTICE] simulation.solve(977): Capacity is now 4.882 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:17:37,571 - [NOTICE] simulation.solve(855): Cycle 27/328 (17.454 s elapsed) --------------------
# 2022-05-18 18:17:37,572 - [NOTICE] simulation.solve(889): Cycle 27/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:17:37,711 - [NOTICE] simulation.solve(889): Cycle 27/328, step 2/4: Rest for 5 min
# 2022-05-18 18:17:37,746 - [NOTICE] simulation.solve(889): Cycle 27/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:17:37,890 - [NOTICE] simulation.solve(889): Cycle 27/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:17:38,164 - [NOTICE] simulation.solve(977): Capacity is now 4.875 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:17:38,165 - [NOTICE] simulation.solve(855): Cycle 28/328 (18.048 s elapsed) --------------------
# 2022-05-18 18:17:38,165 - [NOTICE] simulation.solve(889): Cycle 28/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:17:38,311 - [NOTICE] simulation.solve(889): Cycle 28/328, step 2/4: Rest for 5 min
# 2022-05-18 18:17:38,346 - [NOTICE] simulation.solve(889): Cycle 28/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:17:38,481 - [NOTICE] simulation.solve(889): Cycle 28/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:17:38,754 - [NOTICE] simulation.solve(977): Capacity is now 4.869 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:17:38,755 - [NOTICE] simulation.solve(855): Cycle 29/328 (18.638 s elapsed) --------------------
# 2022-05-18 18:17:38,756 - [NOTICE] simulation.solve(889): Cycle 29/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:17:38,906 - [NOTICE] simulation.solve(889): Cycle 29/328, step 2/4: Rest for 5 min
# 2022-05-18 18:17:38,939 - [NOTICE] simulation.solve(889): Cycle 29/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:17:39,066 - [NOTICE] simulation.solve(889): Cycle 29/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:17:39,337 - [NOTICE] simulation.solve(977): Capacity is now 4.863 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:17:39,338 - [NOTICE] simulation.solve(855): Cycle 30/328 (19.221 s elapsed) --------------------
# 2022-05-18 18:17:39,339 - [NOTICE] simulation.solve(889): Cycle 30/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:17:39,490 - [NOTICE] simulation.solve(889): Cycle 30/328, step 2/4: Rest for 5 min
# 2022-05-18 18:17:39,526 - [NOTICE] simulation.solve(889): Cycle 30/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:17:39,659 - [NOTICE] simulation.solve(889): Cycle 30/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:17:39,945 - [NOTICE] simulation.solve(977): Capacity is now 4.857 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:17:39,945 - [NOTICE] simulation.solve(855): Cycle 31/328 (19.829 s elapsed) --------------------
# 2022-05-18 18:17:39,946 - [NOTICE] simulation.solve(889): Cycle 31/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:17:40,085 - [NOTICE] simulation.solve(889): Cycle 31/328, step 2/4: Rest for 5 min
# 2022-05-18 18:17:40,117 - [NOTICE] simulation.solve(889): Cycle 31/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:17:40,246 - [NOTICE] simulation.solve(889): Cycle 31/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:17:40,540 - [NOTICE] simulation.solve(977): Capacity is now 4.851 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:17:40,542 - [NOTICE] simulation.solve(855): Cycle 32/328 (20.425 s elapsed) --------------------
# 2022-05-18 18:17:40,544 - [NOTICE] simulation.solve(889): Cycle 32/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:17:40,706 - [NOTICE] simulation.solve(889): Cycle 32/328, step 2/4: Rest for 5 min
# 2022-05-18 18:17:40,741 - [NOTICE] simulation.solve(889): Cycle 32/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:17:40,880 - [NOTICE] simulation.solve(889): Cycle 32/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:17:41,159 - [NOTICE] simulation.solve(977): Capacity is now 4.844 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:17:41,160 - [NOTICE] simulation.solve(855): Cycle 33/328 (21.044 s elapsed) --------------------
# 2022-05-18 18:17:41,161 - [NOTICE] simulation.solve(889): Cycle 33/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:17:41,308 - [NOTICE] simulation.solve(889): Cycle 33/328, step 2/4: Rest for 5 min
# 2022-05-18 18:17:41,347 - [NOTICE] simulation.solve(889): Cycle 33/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:17:41,477 - [NOTICE] simulation.solve(889): Cycle 33/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:17:41,740 - [NOTICE] simulation.solve(977): Capacity is now 4.838 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:17:41,741 - [NOTICE] simulation.solve(855): Cycle 34/328 (21.624 s elapsed) --------------------
# 2022-05-18 18:17:41,742 - [NOTICE] simulation.solve(889): Cycle 34/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:17:41,887 - [NOTICE] simulation.solve(889): Cycle 34/328, step 2/4: Rest for 5 min
# 2022-05-18 18:17:41,925 - [NOTICE] simulation.solve(889): Cycle 34/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:17:42,088 - [NOTICE] simulation.solve(889): Cycle 34/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:17:42,454 - [NOTICE] simulation.solve(977): Capacity is now 4.832 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:17:42,455 - [NOTICE] simulation.solve(855): Cycle 35/328 (22.338 s elapsed) --------------------
# 2022-05-18 18:17:42,455 - [NOTICE] simulation.solve(889): Cycle 35/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:17:42,644 - [NOTICE] simulation.solve(889): Cycle 35/328, step 2/4: Rest for 5 min
# 2022-05-18 18:17:42,684 - [NOTICE] simulation.solve(889): Cycle 35/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:17:42,833 - [NOTICE] simulation.solve(889): Cycle 35/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:17:43,154 - [NOTICE] simulation.solve(977): Capacity is now 4.826 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:17:43,155 - [NOTICE] simulation.solve(855): Cycle 36/328 (23.038 s elapsed) --------------------
# 2022-05-18 18:17:43,156 - [NOTICE] simulation.solve(889): Cycle 36/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:17:43,372 - [NOTICE] simulation.solve(889): Cycle 36/328, step 2/4: Rest for 5 min
# 2022-05-18 18:17:43,408 - [NOTICE] simulation.solve(889): Cycle 36/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:17:43,591 - [NOTICE] simulation.solve(889): Cycle 36/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:17:43,997 - [NOTICE] simulation.solve(977): Capacity is now 4.820 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:17:43,999 - [NOTICE] simulation.solve(855): Cycle 37/328 (23.882 s elapsed) --------------------
# 2022-05-18 18:17:43,999 - [NOTICE] simulation.solve(889): Cycle 37/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:17:44,165 - [NOTICE] simulation.solve(889): Cycle 37/328, step 2/4: Rest for 5 min
# 2022-05-18 18:17:44,199 - [NOTICE] simulation.solve(889): Cycle 37/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:17:44,325 - [NOTICE] simulation.solve(889): Cycle 37/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:17:44,656 - [NOTICE] simulation.solve(977): Capacity is now 4.814 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:17:44,657 - [NOTICE] simulation.solve(855): Cycle 38/328 (24.540 s elapsed) --------------------
# 2022-05-18 18:17:44,657 - [NOTICE] simulation.solve(889): Cycle 38/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:17:44,821 - [NOTICE] simulation.solve(889): Cycle 38/328, step 2/4: Rest for 5 min
# 2022-05-18 18:17:44,861 - [NOTICE] simulation.solve(889): Cycle 38/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:17:45,040 - [NOTICE] simulation.solve(889): Cycle 38/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:17:45,349 - [NOTICE] simulation.solve(977): Capacity is now 4.807 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:17:45,349 - [NOTICE] simulation.solve(855): Cycle 39/328 (25.233 s elapsed) --------------------
# 2022-05-18 18:17:45,350 - [NOTICE] simulation.solve(889): Cycle 39/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:17:45,548 - [NOTICE] simulation.solve(889): Cycle 39/328, step 2/4: Rest for 5 min
# 2022-05-18 18:17:45,587 - [NOTICE] simulation.solve(889): Cycle 39/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:17:45,729 - [NOTICE] simulation.solve(889): Cycle 39/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:17:46,003 - [NOTICE] simulation.solve(977): Capacity is now 4.801 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:17:46,004 - [NOTICE] simulation.solve(855): Cycle 40/328 (25.887 s elapsed) --------------------
# 2022-05-18 18:17:46,004 - [NOTICE] simulation.solve(889): Cycle 40/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:17:46,158 - [NOTICE] simulation.solve(889): Cycle 40/328, step 2/4: Rest for 5 min
# 2022-05-18 18:17:46,195 - [NOTICE] simulation.solve(889): Cycle 40/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:17:46,359 - [NOTICE] simulation.solve(889): Cycle 40/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:17:46,633 - [NOTICE] simulation.solve(977): Capacity is now 4.795 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:17:46,634 - [NOTICE] simulation.solve(855): Cycle 41/328 (26.518 s elapsed) --------------------
# 2022-05-18 18:17:46,635 - [NOTICE] simulation.solve(889): Cycle 41/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:17:46,800 - [NOTICE] simulation.solve(889): Cycle 41/328, step 2/4: Rest for 5 min
# 2022-05-18 18:17:46,834 - [NOTICE] simulation.solve(889): Cycle 41/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:17:47,003 - [NOTICE] simulation.solve(889): Cycle 41/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:17:47,518 - [NOTICE] simulation.solve(977): Capacity is now 4.789 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:17:47,519 - [NOTICE] simulation.solve(855): Cycle 42/328 (27.402 s elapsed) --------------------
# 2022-05-18 18:17:47,519 - [NOTICE] simulation.solve(889): Cycle 42/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:17:47,725 - [NOTICE] simulation.solve(889): Cycle 42/328, step 2/4: Rest for 5 min
# 2022-05-18 18:17:47,778 - [NOTICE] simulation.solve(889): Cycle 42/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:17:47,951 - [NOTICE] simulation.solve(889): Cycle 42/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:17:48,236 - [NOTICE] simulation.solve(977): Capacity is now 4.783 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:17:48,237 - [NOTICE] simulation.solve(855): Cycle 43/328 (28.121 s elapsed) --------------------
# 2022-05-18 18:17:48,238 - [NOTICE] simulation.solve(889): Cycle 43/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:17:48,399 - [NOTICE] simulation.solve(889): Cycle 43/328, step 2/4: Rest for 5 min
# 2022-05-18 18:17:48,438 - [NOTICE] simulation.solve(889): Cycle 43/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:17:48,612 - [NOTICE] simulation.solve(889): Cycle 43/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:17:48,965 - [NOTICE] simulation.solve(977): Capacity is now 4.777 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:17:48,966 - [NOTICE] simulation.solve(855): Cycle 44/328 (28.849 s elapsed) --------------------
# 2022-05-18 18:17:48,966 - [NOTICE] simulation.solve(889): Cycle 44/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:17:49,155 - [NOTICE] simulation.solve(889): Cycle 44/328, step 2/4: Rest for 5 min
# 2022-05-18 18:17:49,194 - [NOTICE] simulation.solve(889): Cycle 44/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:17:49,362 - [NOTICE] simulation.solve(889): Cycle 44/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:17:49,661 - [NOTICE] simulation.solve(977): Capacity is now 4.771 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:17:49,662 - [NOTICE] simulation.solve(855): Cycle 45/328 (29.545 s elapsed) --------------------
# 2022-05-18 18:17:49,662 - [NOTICE] simulation.solve(889): Cycle 45/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:17:49,838 - [NOTICE] simulation.solve(889): Cycle 45/328, step 2/4: Rest for 5 min
# 2022-05-18 18:17:49,872 - [NOTICE] simulation.solve(889): Cycle 45/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:17:50,076 - [NOTICE] simulation.solve(889): Cycle 45/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:17:50,510 - [NOTICE] simulation.solve(977): Capacity is now 4.765 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:17:50,510 - [NOTICE] simulation.solve(855): Cycle 46/328 (30.394 s elapsed) --------------------
# 2022-05-18 18:17:50,511 - [NOTICE] simulation.solve(889): Cycle 46/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:17:50,691 - [NOTICE] simulation.solve(889): Cycle 46/328, step 2/4: Rest for 5 min
# 2022-05-18 18:17:50,723 - [NOTICE] simulation.solve(889): Cycle 46/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:17:50,887 - [NOTICE] simulation.solve(889): Cycle 46/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:17:51,219 - [NOTICE] simulation.solve(977): Capacity is now 4.758 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:17:51,220 - [NOTICE] simulation.solve(855): Cycle 47/328 (31.104 s elapsed) --------------------
# 2022-05-18 18:17:51,221 - [NOTICE] simulation.solve(889): Cycle 47/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:17:51,390 - [NOTICE] simulation.solve(889): Cycle 47/328, step 2/4: Rest for 5 min
# 2022-05-18 18:17:51,424 - [NOTICE] simulation.solve(889): Cycle 47/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:17:51,579 - [NOTICE] simulation.solve(889): Cycle 47/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:17:51,880 - [NOTICE] simulation.solve(977): Capacity is now 4.752 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:17:51,881 - [NOTICE] simulation.solve(855): Cycle 48/328 (31.764 s elapsed) --------------------
# 2022-05-18 18:17:51,881 - [NOTICE] simulation.solve(889): Cycle 48/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:17:52,078 - [NOTICE] simulation.solve(889): Cycle 48/328, step 2/4: Rest for 5 min
# 2022-05-18 18:17:52,114 - [NOTICE] simulation.solve(889): Cycle 48/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:17:52,292 - [NOTICE] simulation.solve(889): Cycle 48/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:17:52,592 - [NOTICE] simulation.solve(977): Capacity is now 4.746 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:17:52,593 - [NOTICE] simulation.solve(855): Cycle 49/328 (32.477 s elapsed) --------------------
# 2022-05-18 18:17:52,594 - [NOTICE] simulation.solve(889): Cycle 49/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:17:52,773 - [NOTICE] simulation.solve(889): Cycle 49/328, step 2/4: Rest for 5 min
# 2022-05-18 18:17:52,817 - [NOTICE] simulation.solve(889): Cycle 49/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:17:52,984 - [NOTICE] simulation.solve(889): Cycle 49/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:17:53,291 - [NOTICE] simulation.solve(977): Capacity is now 4.740 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:17:53,292 - [NOTICE] simulation.solve(855): Cycle 50/328 (33.175 s elapsed) --------------------
# 2022-05-18 18:17:53,292 - [NOTICE] simulation.solve(889): Cycle 50/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:17:53,467 - [NOTICE] simulation.solve(889): Cycle 50/328, step 2/4: Rest for 5 min
# 2022-05-18 18:17:53,500 - [NOTICE] simulation.solve(889): Cycle 50/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:17:53,663 - [NOTICE] simulation.solve(889): Cycle 50/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:17:54,022 - [NOTICE] simulation.solve(977): Capacity is now 4.734 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:17:54,022 - [NOTICE] simulation.solve(855): Cycle 51/328 (33.906 s elapsed) --------------------
# 2022-05-18 18:17:54,023 - [NOTICE] simulation.solve(889): Cycle 51/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:17:54,184 - [NOTICE] simulation.solve(889): Cycle 51/328, step 2/4: Rest for 5 min
# 2022-05-18 18:17:54,225 - [NOTICE] simulation.solve(889): Cycle 51/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:17:54,362 - [NOTICE] simulation.solve(889): Cycle 51/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:17:54,666 - [NOTICE] simulation.solve(977): Capacity is now 4.728 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:17:54,668 - [NOTICE] simulation.solve(855): Cycle 52/328 (34.551 s elapsed) --------------------
# 2022-05-18 18:17:54,668 - [NOTICE] simulation.solve(889): Cycle 52/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:17:54,857 - [NOTICE] simulation.solve(889): Cycle 52/328, step 2/4: Rest for 5 min
# 2022-05-18 18:17:54,895 - [NOTICE] simulation.solve(889): Cycle 52/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:17:55,040 - [NOTICE] simulation.solve(889): Cycle 52/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:17:55,344 - [NOTICE] simulation.solve(977): Capacity is now 4.722 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:17:55,345 - [NOTICE] simulation.solve(855): Cycle 53/328 (35.227 s elapsed) --------------------
# 2022-05-18 18:17:55,345 - [NOTICE] simulation.solve(889): Cycle 53/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:17:55,527 - [NOTICE] simulation.solve(889): Cycle 53/328, step 2/4: Rest for 5 min
# 2022-05-18 18:17:55,572 - [NOTICE] simulation.solve(889): Cycle 53/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:17:55,718 - [NOTICE] simulation.solve(889): Cycle 53/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:17:56,013 - [NOTICE] simulation.solve(977): Capacity is now 4.716 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:17:56,013 - [NOTICE] simulation.solve(855): Cycle 54/328 (35.897 s elapsed) --------------------
# 2022-05-18 18:17:56,014 - [NOTICE] simulation.solve(889): Cycle 54/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:17:56,189 - [NOTICE] simulation.solve(889): Cycle 54/328, step 2/4: Rest for 5 min
# 2022-05-18 18:17:56,225 - [NOTICE] simulation.solve(889): Cycle 54/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:17:56,370 - [NOTICE] simulation.solve(889): Cycle 54/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:17:56,656 - [NOTICE] simulation.solve(977): Capacity is now 4.710 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:17:56,656 - [NOTICE] simulation.solve(855): Cycle 55/328 (36.539 s elapsed) --------------------
# 2022-05-18 18:17:56,657 - [NOTICE] simulation.solve(889): Cycle 55/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:17:56,815 - [NOTICE] simulation.solve(889): Cycle 55/328, step 2/4: Rest for 5 min
# 2022-05-18 18:17:56,852 - [NOTICE] simulation.solve(889): Cycle 55/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:17:56,994 - [NOTICE] simulation.solve(889): Cycle 55/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:17:57,307 - [NOTICE] simulation.solve(977): Capacity is now 4.704 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:17:57,308 - [NOTICE] simulation.solve(855): Cycle 56/328 (37.192 s elapsed) --------------------
# 2022-05-18 18:17:57,309 - [NOTICE] simulation.solve(889): Cycle 56/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:17:57,456 - [NOTICE] simulation.solve(889): Cycle 56/328, step 2/4: Rest for 5 min
# 2022-05-18 18:17:57,488 - [NOTICE] simulation.solve(889): Cycle 56/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:17:57,634 - [NOTICE] simulation.solve(889): Cycle 56/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:17:57,932 - [NOTICE] simulation.solve(977): Capacity is now 4.698 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:17:57,933 - [NOTICE] simulation.solve(855): Cycle 57/328 (37.816 s elapsed) --------------------
# 2022-05-18 18:17:57,933 - [NOTICE] simulation.solve(889): Cycle 57/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:17:58,153 - [NOTICE] simulation.solve(889): Cycle 57/328, step 2/4: Rest for 5 min
# 2022-05-18 18:17:58,188 - [NOTICE] simulation.solve(889): Cycle 57/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:17:58,356 - [NOTICE] simulation.solve(889): Cycle 57/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:17:58,658 - [NOTICE] simulation.solve(977): Capacity is now 4.692 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:17:58,659 - [NOTICE] simulation.solve(855): Cycle 58/328 (38.542 s elapsed) --------------------
# 2022-05-18 18:17:58,660 - [NOTICE] simulation.solve(889): Cycle 58/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:17:58,813 - [NOTICE] simulation.solve(889): Cycle 58/328, step 2/4: Rest for 5 min
# 2022-05-18 18:17:58,849 - [NOTICE] simulation.solve(889): Cycle 58/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:17:58,980 - [NOTICE] simulation.solve(889): Cycle 58/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:17:59,295 - [NOTICE] simulation.solve(977): Capacity is now 4.686 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:17:59,296 - [NOTICE] simulation.solve(855): Cycle 59/328 (39.179 s elapsed) --------------------
# 2022-05-18 18:17:59,296 - [NOTICE] simulation.solve(889): Cycle 59/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:17:59,587 - [NOTICE] simulation.solve(889): Cycle 59/328, step 2/4: Rest for 5 min
# 2022-05-18 18:17:59,626 - [NOTICE] simulation.solve(889): Cycle 59/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:17:59,776 - [NOTICE] simulation.solve(889): Cycle 59/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:18:00,104 - [NOTICE] simulation.solve(977): Capacity is now 4.680 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:18:00,105 - [NOTICE] simulation.solve(855): Cycle 60/328 (39.988 s elapsed) --------------------
# 2022-05-18 18:18:00,106 - [NOTICE] simulation.solve(889): Cycle 60/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:18:00,250 - [NOTICE] simulation.solve(889): Cycle 60/328, step 2/4: Rest for 5 min
# 2022-05-18 18:18:00,282 - [NOTICE] simulation.solve(889): Cycle 60/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:18:00,450 - [NOTICE] simulation.solve(889): Cycle 60/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:18:00,760 - [NOTICE] simulation.solve(977): Capacity is now 4.674 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:18:00,761 - [NOTICE] simulation.solve(855): Cycle 61/328 (40.644 s elapsed) --------------------
# 2022-05-18 18:18:00,762 - [NOTICE] simulation.solve(889): Cycle 61/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:18:00,911 - [NOTICE] simulation.solve(889): Cycle 61/328, step 2/4: Rest for 5 min
# 2022-05-18 18:18:00,946 - [NOTICE] simulation.solve(889): Cycle 61/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:18:01,094 - [NOTICE] simulation.solve(889): Cycle 61/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:18:01,373 - [NOTICE] simulation.solve(977): Capacity is now 4.668 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:18:01,373 - [NOTICE] simulation.solve(855): Cycle 62/328 (41.257 s elapsed) --------------------
# 2022-05-18 18:18:01,375 - [NOTICE] simulation.solve(889): Cycle 62/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:18:01,546 - [NOTICE] simulation.solve(889): Cycle 62/328, step 2/4: Rest for 5 min
# 2022-05-18 18:18:01,581 - [NOTICE] simulation.solve(889): Cycle 62/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:18:01,753 - [NOTICE] simulation.solve(889): Cycle 62/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:18:02,055 - [NOTICE] simulation.solve(977): Capacity is now 4.662 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:18:02,056 - [NOTICE] simulation.solve(855): Cycle 63/328 (41.939 s elapsed) --------------------
# 2022-05-18 18:18:02,056 - [NOTICE] simulation.solve(889): Cycle 63/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:18:02,204 - [NOTICE] simulation.solve(889): Cycle 63/328, step 2/4: Rest for 5 min
# 2022-05-18 18:18:02,245 - [NOTICE] simulation.solve(889): Cycle 63/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:18:02,399 - [NOTICE] simulation.solve(889): Cycle 63/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:18:02,685 - [NOTICE] simulation.solve(977): Capacity is now 4.656 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:18:02,686 - [NOTICE] simulation.solve(855): Cycle 64/328 (42.569 s elapsed) --------------------
# 2022-05-18 18:18:02,687 - [NOTICE] simulation.solve(889): Cycle 64/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:18:02,848 - [NOTICE] simulation.solve(889): Cycle 64/328, step 2/4: Rest for 5 min
# 2022-05-18 18:18:02,880 - [NOTICE] simulation.solve(889): Cycle 64/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:18:03,027 - [NOTICE] simulation.solve(889): Cycle 64/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:18:03,337 - [NOTICE] simulation.solve(977): Capacity is now 4.650 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:18:03,338 - [NOTICE] simulation.solve(855): Cycle 65/328 (43.222 s elapsed) --------------------
# 2022-05-18 18:18:03,339 - [NOTICE] simulation.solve(889): Cycle 65/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:18:03,508 - [NOTICE] simulation.solve(889): Cycle 65/328, step 2/4: Rest for 5 min
# 2022-05-18 18:18:03,542 - [NOTICE] simulation.solve(889): Cycle 65/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:18:03,682 - [NOTICE] simulation.solve(889): Cycle 65/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:18:03,989 - [NOTICE] simulation.solve(977): Capacity is now 4.644 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:18:03,990 - [NOTICE] simulation.solve(855): Cycle 66/328 (43.874 s elapsed) --------------------
# 2022-05-18 18:18:03,991 - [NOTICE] simulation.solve(889): Cycle 66/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:18:04,163 - [NOTICE] simulation.solve(889): Cycle 66/328, step 2/4: Rest for 5 min
# 2022-05-18 18:18:04,197 - [NOTICE] simulation.solve(889): Cycle 66/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:18:04,355 - [NOTICE] simulation.solve(889): Cycle 66/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:18:04,638 - [NOTICE] simulation.solve(977): Capacity is now 4.638 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:18:04,639 - [NOTICE] simulation.solve(855): Cycle 67/328 (44.522 s elapsed) --------------------
# 2022-05-18 18:18:04,640 - [NOTICE] simulation.solve(889): Cycle 67/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:18:04,809 - [NOTICE] simulation.solve(889): Cycle 67/328, step 2/4: Rest for 5 min
# 2022-05-18 18:18:04,853 - [NOTICE] simulation.solve(889): Cycle 67/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:18:05,010 - [NOTICE] simulation.solve(889): Cycle 67/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:18:05,291 - [NOTICE] simulation.solve(977): Capacity is now 4.632 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:18:05,292 - [NOTICE] simulation.solve(855): Cycle 68/328 (45.175 s elapsed) --------------------
# 2022-05-18 18:18:05,293 - [NOTICE] simulation.solve(889): Cycle 68/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:18:05,443 - [NOTICE] simulation.solve(889): Cycle 68/328, step 2/4: Rest for 5 min
# 2022-05-18 18:18:05,479 - [NOTICE] simulation.solve(889): Cycle 68/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:18:05,647 - [NOTICE] simulation.solve(889): Cycle 68/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:18:05,957 - [NOTICE] simulation.solve(977): Capacity is now 4.626 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:18:05,958 - [NOTICE] simulation.solve(855): Cycle 69/328 (45.841 s elapsed) --------------------
# 2022-05-18 18:18:05,959 - [NOTICE] simulation.solve(889): Cycle 69/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:18:06,146 - [NOTICE] simulation.solve(889): Cycle 69/328, step 2/4: Rest for 5 min
# 2022-05-18 18:18:06,177 - [NOTICE] simulation.solve(889): Cycle 69/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:18:06,324 - [NOTICE] simulation.solve(889): Cycle 69/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:18:06,658 - [NOTICE] simulation.solve(977): Capacity is now 4.620 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:18:06,659 - [NOTICE] simulation.solve(855): Cycle 70/328 (46.543 s elapsed) --------------------
# 2022-05-18 18:18:06,659 - [NOTICE] simulation.solve(889): Cycle 70/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:18:06,840 - [NOTICE] simulation.solve(889): Cycle 70/328, step 2/4: Rest for 5 min
# 2022-05-18 18:18:06,874 - [NOTICE] simulation.solve(889): Cycle 70/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:18:07,022 - [NOTICE] simulation.solve(889): Cycle 70/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:18:07,313 - [NOTICE] simulation.solve(977): Capacity is now 4.614 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:18:07,314 - [NOTICE] simulation.solve(855): Cycle 71/328 (47.197 s elapsed) --------------------
# 2022-05-18 18:18:07,315 - [NOTICE] simulation.solve(889): Cycle 71/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:18:07,504 - [NOTICE] simulation.solve(889): Cycle 71/328, step 2/4: Rest for 5 min
# 2022-05-18 18:18:07,556 - [NOTICE] simulation.solve(889): Cycle 71/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:18:07,689 - [NOTICE] simulation.solve(889): Cycle 71/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:18:07,975 - [NOTICE] simulation.solve(977): Capacity is now 4.608 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:18:07,975 - [NOTICE] simulation.solve(855): Cycle 72/328 (47.859 s elapsed) --------------------
# 2022-05-18 18:18:07,976 - [NOTICE] simulation.solve(889): Cycle 72/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:18:08,127 - [NOTICE] simulation.solve(889): Cycle 72/328, step 2/4: Rest for 5 min
# 2022-05-18 18:18:08,160 - [NOTICE] simulation.solve(889): Cycle 72/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:18:08,333 - [NOTICE] simulation.solve(889): Cycle 72/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:18:08,660 - [NOTICE] simulation.solve(977): Capacity is now 4.602 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:18:08,660 - [NOTICE] simulation.solve(855): Cycle 73/328 (48.544 s elapsed) --------------------
# 2022-05-18 18:18:08,661 - [NOTICE] simulation.solve(889): Cycle 73/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:18:08,817 - [NOTICE] simulation.solve(889): Cycle 73/328, step 2/4: Rest for 5 min
# 2022-05-18 18:18:08,854 - [NOTICE] simulation.solve(889): Cycle 73/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:18:09,027 - [NOTICE] simulation.solve(889): Cycle 73/328, step 4/4: Hold at 4.2V until C/50
# ...
# 2022-05-18 18:20:35,950 - [NOTICE] simulation.solve(889): Cycle 305/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:20:36,303 - [NOTICE] simulation.solve(977): Capacity is now 3.346 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:20:36,304 - [NOTICE] simulation.solve(855): Cycle 306/328 (3 minutes, 16 seconds elapsed) --------------------
# 2022-05-18 18:20:36,305 - [NOTICE] simulation.solve(889): Cycle 306/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:20:36,432 - [NOTICE] simulation.solve(889): Cycle 306/328, step 2/4: Rest for 5 min
# 2022-05-18 18:20:36,465 - [NOTICE] simulation.solve(889): Cycle 306/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:20:36,567 - [NOTICE] simulation.solve(889): Cycle 306/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:20:36,919 - [NOTICE] simulation.solve(977): Capacity is now 3.341 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:20:36,920 - [NOTICE] simulation.solve(855): Cycle 307/328 (3 minutes, 17 seconds elapsed) --------------------
# 2022-05-18 18:20:36,921 - [NOTICE] simulation.solve(889): Cycle 307/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:20:37,084 - [NOTICE] simulation.solve(889): Cycle 307/328, step 2/4: Rest for 5 min
# 2022-05-18 18:20:37,119 - [NOTICE] simulation.solve(889): Cycle 307/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:20:37,207 - [NOTICE] simulation.solve(889): Cycle 307/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:20:37,596 - [NOTICE] simulation.solve(977): Capacity is now 3.336 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:20:37,597 - [NOTICE] simulation.solve(855): Cycle 308/328 (3 minutes, 17 seconds elapsed) --------------------
# 2022-05-18 18:20:37,598 - [NOTICE] simulation.solve(889): Cycle 308/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:20:37,729 - [NOTICE] simulation.solve(889): Cycle 308/328, step 2/4: Rest for 5 min
# 2022-05-18 18:20:37,761 - [NOTICE] simulation.solve(889): Cycle 308/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:20:37,850 - [NOTICE] simulation.solve(889): Cycle 308/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:20:38,213 - [NOTICE] simulation.solve(977): Capacity is now 3.331 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:20:38,214 - [NOTICE] simulation.solve(855): Cycle 309/328 (3 minutes, 18 seconds elapsed) --------------------
# 2022-05-18 18:20:38,214 - [NOTICE] simulation.solve(889): Cycle 309/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:20:38,343 - [NOTICE] simulation.solve(889): Cycle 309/328, step 2/4: Rest for 5 min
# 2022-05-18 18:20:38,377 - [NOTICE] simulation.solve(889): Cycle 309/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:20:38,479 - [NOTICE] simulation.solve(889): Cycle 309/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:20:38,817 - [NOTICE] simulation.solve(977): Capacity is now 3.326 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:20:38,817 - [NOTICE] simulation.solve(855): Cycle 310/328 (3 minutes, 19 seconds elapsed) --------------------
# 2022-05-18 18:20:38,818 - [NOTICE] simulation.solve(889): Cycle 310/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:20:38,941 - [NOTICE] simulation.solve(889): Cycle 310/328, step 2/4: Rest for 5 min
# 2022-05-18 18:20:38,977 - [NOTICE] simulation.solve(889): Cycle 310/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:20:39,116 - [NOTICE] simulation.solve(889): Cycle 310/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:20:39,453 - [NOTICE] simulation.solve(977): Capacity is now 3.321 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:20:39,454 - [NOTICE] simulation.solve(855): Cycle 311/328 (3 minutes, 19 seconds elapsed) --------------------
# 2022-05-18 18:20:39,454 - [NOTICE] simulation.solve(889): Cycle 311/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:20:39,610 - [NOTICE] simulation.solve(889): Cycle 311/328, step 2/4: Rest for 5 min
# 2022-05-18 18:20:39,644 - [NOTICE] simulation.solve(889): Cycle 311/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:20:39,738 - [NOTICE] simulation.solve(889): Cycle 311/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:20:40,087 - [NOTICE] simulation.solve(977): Capacity is now 3.316 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:20:40,088 - [NOTICE] simulation.solve(855): Cycle 312/328 (3 minutes, 20 seconds elapsed) --------------------
# 2022-05-18 18:20:40,088 - [NOTICE] simulation.solve(889): Cycle 312/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:20:40,205 - [NOTICE] simulation.solve(889): Cycle 312/328, step 2/4: Rest for 5 min
# 2022-05-18 18:20:40,244 - [NOTICE] simulation.solve(889): Cycle 312/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:20:40,372 - [NOTICE] simulation.solve(889): Cycle 312/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:20:40,717 - [NOTICE] simulation.solve(977): Capacity is now 3.311 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:20:40,718 - [NOTICE] simulation.solve(855): Cycle 313/328 (3 minutes, 21 seconds elapsed) --------------------
# 2022-05-18 18:20:40,719 - [NOTICE] simulation.solve(889): Cycle 313/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:20:40,861 - [NOTICE] simulation.solve(889): Cycle 313/328, step 2/4: Rest for 5 min
# 2022-05-18 18:20:40,893 - [NOTICE] simulation.solve(889): Cycle 313/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:20:40,992 - [NOTICE] simulation.solve(889): Cycle 313/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:20:41,351 - [NOTICE] simulation.solve(977): Capacity is now 3.306 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:20:41,352 - [NOTICE] simulation.solve(855): Cycle 314/328 (3 minutes, 21 seconds elapsed) --------------------
# 2022-05-18 18:20:41,353 - [NOTICE] simulation.solve(889): Cycle 314/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:20:41,470 - [NOTICE] simulation.solve(889): Cycle 314/328, step 2/4: Rest for 5 min
# 2022-05-18 18:20:41,506 - [NOTICE] simulation.solve(889): Cycle 314/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:20:41,605 - [NOTICE] simulation.solve(889): Cycle 314/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:20:42,027 - [NOTICE] simulation.solve(977): Capacity is now 3.301 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:20:42,028 - [NOTICE] simulation.solve(855): Cycle 315/328 (3 minutes, 22 seconds elapsed) --------------------
# 2022-05-18 18:20:42,028 - [NOTICE] simulation.solve(889): Cycle 315/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:20:42,160 - [NOTICE] simulation.solve(889): Cycle 315/328, step 2/4: Rest for 5 min
# 2022-05-18 18:20:42,195 - [NOTICE] simulation.solve(889): Cycle 315/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:20:42,301 - [NOTICE] simulation.solve(889): Cycle 315/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:20:42,697 - [NOTICE] simulation.solve(977): Capacity is now 3.296 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:20:42,698 - [NOTICE] simulation.solve(855): Cycle 316/328 (3 minutes, 23 seconds elapsed) --------------------
# 2022-05-18 18:20:42,699 - [NOTICE] simulation.solve(889): Cycle 316/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:20:42,820 - [NOTICE] simulation.solve(889): Cycle 316/328, step 2/4: Rest for 5 min
# 2022-05-18 18:20:42,852 - [NOTICE] simulation.solve(889): Cycle 316/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:20:42,948 - [NOTICE] simulation.solve(889): Cycle 316/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:20:43,297 - [NOTICE] simulation.solve(977): Capacity is now 3.290 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:20:43,298 - [NOTICE] simulation.solve(855): Cycle 317/328 (3 minutes, 23 seconds elapsed) --------------------
# 2022-05-18 18:20:43,299 - [NOTICE] simulation.solve(889): Cycle 317/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:20:43,439 - [NOTICE] simulation.solve(889): Cycle 317/328, step 2/4: Rest for 5 min
# 2022-05-18 18:20:43,470 - [NOTICE] simulation.solve(889): Cycle 317/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:20:43,584 - [NOTICE] simulation.solve(889): Cycle 317/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:20:43,927 - [NOTICE] simulation.solve(977): Capacity is now 3.285 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:20:43,928 - [NOTICE] simulation.solve(855): Cycle 318/328 (3 minutes, 24 seconds elapsed) --------------------
# 2022-05-18 18:20:43,929 - [NOTICE] simulation.solve(889): Cycle 318/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:20:44,127 - [NOTICE] simulation.solve(889): Cycle 318/328, step 2/4: Rest for 5 min
# 2022-05-18 18:20:44,160 - [NOTICE] simulation.solve(889): Cycle 318/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:20:44,258 - [NOTICE] simulation.solve(889): Cycle 318/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:20:44,627 - [NOTICE] simulation.solve(977): Capacity is now 3.280 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:20:44,628 - [NOTICE] simulation.solve(855): Cycle 319/328 (3 minutes, 25 seconds elapsed) --------------------
# 2022-05-18 18:20:44,628 - [NOTICE] simulation.solve(889): Cycle 319/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:20:44,740 - [NOTICE] simulation.solve(889): Cycle 319/328, step 2/4: Rest for 5 min
# 2022-05-18 18:20:44,774 - [NOTICE] simulation.solve(889): Cycle 319/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:20:44,863 - [NOTICE] simulation.solve(889): Cycle 319/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:20:45,207 - [NOTICE] simulation.solve(977): Capacity is now 3.275 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:20:45,208 - [NOTICE] simulation.solve(855): Cycle 320/328 (3 minutes, 25 seconds elapsed) --------------------
# 2022-05-18 18:20:45,208 - [NOTICE] simulation.solve(889): Cycle 320/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:20:45,344 - [NOTICE] simulation.solve(889): Cycle 320/328, step 2/4: Rest for 5 min
# 2022-05-18 18:20:45,382 - [NOTICE] simulation.solve(889): Cycle 320/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:20:45,488 - [NOTICE] simulation.solve(889): Cycle 320/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:20:45,852 - [NOTICE] simulation.solve(977): Capacity is now 3.270 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:20:45,853 - [NOTICE] simulation.solve(855): Cycle 321/328 (3 minutes, 26 seconds elapsed) --------------------
# 2022-05-18 18:20:45,854 - [NOTICE] simulation.solve(889): Cycle 321/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:20:46,062 - [NOTICE] simulation.solve(889): Cycle 321/328, step 2/4: Rest for 5 min
# 2022-05-18 18:20:46,116 - [NOTICE] simulation.solve(889): Cycle 321/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:20:46,230 - [NOTICE] simulation.solve(889): Cycle 321/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:20:46,652 - [NOTICE] simulation.solve(977): Capacity is now 3.265 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:20:46,652 - [NOTICE] simulation.solve(855): Cycle 322/328 (3 minutes, 27 seconds elapsed) --------------------
# 2022-05-18 18:20:46,653 - [NOTICE] simulation.solve(889): Cycle 322/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:20:46,783 - [NOTICE] simulation.solve(889): Cycle 322/328, step 2/4: Rest for 5 min
# 2022-05-18 18:20:46,831 - [NOTICE] simulation.solve(889): Cycle 322/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:20:46,982 - [NOTICE] simulation.solve(889): Cycle 322/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:20:47,445 - [NOTICE] simulation.solve(977): Capacity is now 3.260 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:20:47,445 - [NOTICE] simulation.solve(855): Cycle 323/328 (3 minutes, 27 seconds elapsed) --------------------
# 2022-05-18 18:20:47,446 - [NOTICE] simulation.solve(889): Cycle 323/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:20:47,669 - [NOTICE] simulation.solve(889): Cycle 323/328, step 2/4: Rest for 5 min
# 2022-05-18 18:20:47,787 - [NOTICE] simulation.solve(889): Cycle 323/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:20:48,085 - [NOTICE] simulation.solve(889): Cycle 323/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:20:48,882 - [NOTICE] simulation.solve(977): Capacity is now 3.255 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:20:48,883 - [NOTICE] simulation.solve(855): Cycle 324/328 (3 minutes, 29 seconds elapsed) --------------------
# 2022-05-18 18:20:48,883 - [NOTICE] simulation.solve(889): Cycle 324/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:20:49,102 - [NOTICE] simulation.solve(889): Cycle 324/328, step 2/4: Rest for 5 min
# 2022-05-18 18:20:49,146 - [NOTICE] simulation.solve(889): Cycle 324/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:20:49,293 - [NOTICE] simulation.solve(889): Cycle 324/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:20:49,776 - [NOTICE] simulation.solve(977): Capacity is now 3.250 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:20:49,777 - [NOTICE] simulation.solve(855): Cycle 325/328 (3 minutes, 30 seconds elapsed) --------------------
# 2022-05-18 18:20:49,778 - [NOTICE] simulation.solve(889): Cycle 325/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:20:49,907 - [NOTICE] simulation.solve(889): Cycle 325/328, step 2/4: Rest for 5 min
# 2022-05-18 18:20:49,942 - [NOTICE] simulation.solve(889): Cycle 325/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:20:50,067 - [NOTICE] simulation.solve(889): Cycle 325/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:20:50,444 - [NOTICE] simulation.solve(977): Capacity is now 3.245 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:20:50,446 - [NOTICE] simulation.solve(855): Cycle 326/328 (3 minutes, 30 seconds elapsed) --------------------
# 2022-05-18 18:20:50,447 - [NOTICE] simulation.solve(889): Cycle 326/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:20:50,560 - [NOTICE] simulation.solve(889): Cycle 326/328, step 2/4: Rest for 5 min
# 2022-05-18 18:20:50,606 - [NOTICE] simulation.solve(889): Cycle 326/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:20:50,717 - [NOTICE] simulation.solve(889): Cycle 326/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:20:51,068 - [NOTICE] simulation.solve(977): Capacity is now 3.240 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:20:51,069 - [NOTICE] simulation.solve(855): Cycle 327/328 (3 minutes, 31 seconds elapsed) --------------------
# 2022-05-18 18:20:51,070 - [NOTICE] simulation.solve(889): Cycle 327/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:20:51,236 - [NOTICE] simulation.solve(889): Cycle 327/328, step 2/4: Rest for 5 min
# 2022-05-18 18:20:51,270 - [NOTICE] simulation.solve(889): Cycle 327/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:20:51,379 - [NOTICE] simulation.solve(889): Cycle 327/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:20:51,719 - [NOTICE] simulation.solve(977): Capacity is now 3.235 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:20:51,720 - [NOTICE] simulation.solve(855): Cycle 328/328 (3 minutes, 32 seconds elapsed) --------------------
# 2022-05-18 18:20:51,721 - [NOTICE] simulation.solve(889): Cycle 328/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:20:51,838 - [NOTICE] simulation.solve(889): Cycle 328/328, step 2/4: Rest for 5 min
# 2022-05-18 18:20:51,873 - [NOTICE] simulation.solve(889): Cycle 328/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:20:51,997 - [NOTICE] simulation.solve(889): Cycle 328/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:20:52,385 - [NOTICE] simulation.solve(977): Capacity is now 3.230 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:20:52,393 - [NOTICE] simulation.solve(1011): Finish experiment simulation, took 3 minutes, 32 seconds

# %%
parameter_values = get_parameter_values()
parameter_values.update(
    {

        "Positive electrode LAM constant proportional term [s-1]": 8.7864e-07,
        "Negative electrode LAM constant proportional term [s-1]": 1.08031e-05,
        "SEI kinetic rate constant [m.s-1]": 1.6297e-15,
        "EC diffusivity [m2.s-1]": 2e-18,
        "Positive electrode LAM constant exponential term": 2,
        "Negative electrode LAM constant exponential term": 2,
        "Negative electrode active material volume fraction": eps_n_data,
        "Positive electrode active material volume fraction": eps_p_data,
        # "Negative electrode porosity": 0.3,
        # "Positive electrode porosity": 0.3,
        # "Separator porosity": 0.4,
        "Negative electrode porosity": 0.28,
        "Positive electrode porosity": 0.28,
        "Separator porosity": 0.38,
        # "Negative electrode porosity": 0.15,
        # "Positive electrode porosity": 0.15,
        # "Separator porosity": 0.2,
    },
    check_already_exists=False,
)
# all_sumvars_dict = cycle_adaptive_simulation(spm, parameter_values, experiment, save_at_cycles=2)

# %%
sim_long = pybamm.Simulation(spm, experiment=experiment, parameter_values=parameter_values, 
                            solver=pybamm.CasadiSolver("safe"))
sol_long_1 = sim_long.solve(initial_soc=1)
long_sol_output_1 =sol_long_1.summary_variables
# Out:
# 2022-05-18 18:20:56,218 - [NOTICE] simulation.solve(855): Cycle 1/328 (37.726 ms elapsed) --------------------
# 2022-05-18 18:20:56,219 - [NOTICE] simulation.solve(889): Cycle 1/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:20:56,473 - [NOTICE] simulation.solve(889): Cycle 1/328, step 2/4: Rest for 5 min
# 2022-05-18 18:20:56,602 - [NOTICE] simulation.solve(889): Cycle 1/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:20:56,848 - [NOTICE] simulation.solve(889): Cycle 1/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:20:57,552 - [NOTICE] simulation.solve(977): Capacity is now 5.032 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:20:57,553 - [NOTICE] simulation.solve(855): Cycle 2/328 (1.373 s elapsed) --------------------
# 2022-05-18 18:20:57,553 - [NOTICE] simulation.solve(889): Cycle 2/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:20:57,707 - [NOTICE] simulation.solve(889): Cycle 2/328, step 2/4: Rest for 5 min
# 2022-05-18 18:20:57,740 - [NOTICE] simulation.solve(889): Cycle 2/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:20:57,883 - [NOTICE] simulation.solve(889): Cycle 2/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:20:58,223 - [NOTICE] simulation.solve(977): Capacity is now 5.026 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:20:58,224 - [NOTICE] simulation.solve(855): Cycle 3/328 (2.044 s elapsed) --------------------
# 2022-05-18 18:20:58,225 - [NOTICE] simulation.solve(889): Cycle 3/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:20:58,372 - [NOTICE] simulation.solve(889): Cycle 3/328, step 2/4: Rest for 5 min
# 2022-05-18 18:20:58,403 - [NOTICE] simulation.solve(889): Cycle 3/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:20:58,560 - [NOTICE] simulation.solve(889): Cycle 3/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:20:58,833 - [NOTICE] simulation.solve(977): Capacity is now 5.020 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:20:58,835 - [NOTICE] simulation.solve(855): Cycle 4/328 (2.654 s elapsed) --------------------
# 2022-05-18 18:20:58,835 - [NOTICE] simulation.solve(889): Cycle 4/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:20:58,989 - [NOTICE] simulation.solve(889): Cycle 4/328, step 2/4: Rest for 5 min
# 2022-05-18 18:20:59,030 - [NOTICE] simulation.solve(889): Cycle 4/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:20:59,179 - [NOTICE] simulation.solve(889): Cycle 4/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:20:59,444 - [NOTICE] simulation.solve(977): Capacity is now 5.014 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:20:59,444 - [NOTICE] simulation.solve(855): Cycle 5/328 (3.264 s elapsed) --------------------
# 2022-05-18 18:20:59,445 - [NOTICE] simulation.solve(889): Cycle 5/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:20:59,627 - [NOTICE] simulation.solve(889): Cycle 5/328, step 2/4: Rest for 5 min
# 2022-05-18 18:20:59,666 - [NOTICE] simulation.solve(889): Cycle 5/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:21:00,222 - [NOTICE] simulation.solve(889): Cycle 5/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:21:00,518 - [NOTICE] simulation.solve(977): Capacity is now 5.008 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:21:00,519 - [NOTICE] simulation.solve(855): Cycle 6/328 (4.339 s elapsed) --------------------
# 2022-05-18 18:21:00,520 - [NOTICE] simulation.solve(889): Cycle 6/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:21:00,692 - [NOTICE] simulation.solve(889): Cycle 6/328, step 2/4: Rest for 5 min
# 2022-05-18 18:21:00,723 - [NOTICE] simulation.solve(889): Cycle 6/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:21:00,862 - [NOTICE] simulation.solve(889): Cycle 6/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:21:01,171 - [NOTICE] simulation.solve(977): Capacity is now 5.002 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:21:01,172 - [NOTICE] simulation.solve(855): Cycle 7/328 (4.992 s elapsed) --------------------
# 2022-05-18 18:21:01,173 - [NOTICE] simulation.solve(889): Cycle 7/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:21:01,347 - [NOTICE] simulation.solve(889): Cycle 7/328, step 2/4: Rest for 5 min
# 2022-05-18 18:21:01,383 - [NOTICE] simulation.solve(889): Cycle 7/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:21:01,562 - [NOTICE] simulation.solve(889): Cycle 7/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:21:01,898 - [NOTICE] simulation.solve(977): Capacity is now 4.996 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:21:01,898 - [NOTICE] simulation.solve(855): Cycle 8/328 (5.718 s elapsed) --------------------
# 2022-05-18 18:21:01,900 - [NOTICE] simulation.solve(889): Cycle 8/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:21:02,076 - [NOTICE] simulation.solve(889): Cycle 8/328, step 2/4: Rest for 5 min
# 2022-05-18 18:21:02,113 - [NOTICE] simulation.solve(889): Cycle 8/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:21:02,262 - [NOTICE] simulation.solve(889): Cycle 8/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:21:02,525 - [NOTICE] simulation.solve(977): Capacity is now 4.990 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:21:02,526 - [NOTICE] simulation.solve(855): Cycle 9/328 (6.346 s elapsed) --------------------
# 2022-05-18 18:21:02,527 - [NOTICE] simulation.solve(889): Cycle 9/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:21:02,676 - [NOTICE] simulation.solve(889): Cycle 9/328, step 2/4: Rest for 5 min
# 2022-05-18 18:21:02,709 - [NOTICE] simulation.solve(889): Cycle 9/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:21:02,861 - [NOTICE] simulation.solve(889): Cycle 9/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:21:03,183 - [NOTICE] simulation.solve(977): Capacity is now 4.984 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:21:03,184 - [NOTICE] simulation.solve(855): Cycle 10/328 (7.004 s elapsed) --------------------
# 2022-05-18 18:21:03,185 - [NOTICE] simulation.solve(889): Cycle 10/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:21:03,352 - [NOTICE] simulation.solve(889): Cycle 10/328, step 2/4: Rest for 5 min
# 2022-05-18 18:21:03,387 - [NOTICE] simulation.solve(889): Cycle 10/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:21:03,543 - [NOTICE] simulation.solve(889): Cycle 10/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:21:03,827 - [NOTICE] simulation.solve(977): Capacity is now 4.978 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:21:03,828 - [NOTICE] simulation.solve(855): Cycle 11/328 (7.647 s elapsed) --------------------
# 2022-05-18 18:21:03,829 - [NOTICE] simulation.solve(889): Cycle 11/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:21:04,041 - [NOTICE] simulation.solve(889): Cycle 11/328, step 2/4: Rest for 5 min
# 2022-05-18 18:21:04,086 - [NOTICE] simulation.solve(889): Cycle 11/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:21:04,229 - [NOTICE] simulation.solve(889): Cycle 11/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:21:04,516 - [NOTICE] simulation.solve(977): Capacity is now 4.976 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:21:04,517 - [NOTICE] simulation.solve(855): Cycle 12/328 (8.336 s elapsed) --------------------
# 2022-05-18 18:21:04,517 - [NOTICE] simulation.solve(889): Cycle 12/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:21:04,665 - [NOTICE] simulation.solve(889): Cycle 12/328, step 2/4: Rest for 5 min
# 2022-05-18 18:21:04,708 - [NOTICE] simulation.solve(889): Cycle 12/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:21:04,846 - [NOTICE] simulation.solve(889): Cycle 12/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:21:05,203 - [NOTICE] simulation.solve(977): Capacity is now 4.966 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:21:05,204 - [NOTICE] simulation.solve(855): Cycle 13/328 (9.024 s elapsed) --------------------
# 2022-05-18 18:21:05,205 - [NOTICE] simulation.solve(889): Cycle 13/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:21:05,359 - [NOTICE] simulation.solve(889): Cycle 13/328, step 2/4: Rest for 5 min
# 2022-05-18 18:21:05,392 - [NOTICE] simulation.solve(889): Cycle 13/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:21:05,566 - [NOTICE] simulation.solve(889): Cycle 13/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:21:05,857 - [NOTICE] simulation.solve(977): Capacity is now 4.963 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:21:05,857 - [NOTICE] simulation.solve(855): Cycle 14/328 (9.677 s elapsed) --------------------
# 2022-05-18 18:21:05,858 - [NOTICE] simulation.solve(889): Cycle 14/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:21:06,036 - [NOTICE] simulation.solve(889): Cycle 14/328, step 2/4: Rest for 5 min
# 2022-05-18 18:21:06,080 - [NOTICE] simulation.solve(889): Cycle 14/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:21:06,227 - [NOTICE] simulation.solve(889): Cycle 14/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:21:06,517 - [NOTICE] simulation.solve(977): Capacity is now 4.954 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:21:06,517 - [NOTICE] simulation.solve(855): Cycle 15/328 (10.337 s elapsed) --------------------
# 2022-05-18 18:21:06,518 - [NOTICE] simulation.solve(889): Cycle 15/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:21:06,674 - [NOTICE] simulation.solve(889): Cycle 15/328, step 2/4: Rest for 5 min
# 2022-05-18 18:21:06,706 - [NOTICE] simulation.solve(889): Cycle 15/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:21:06,830 - [NOTICE] simulation.solve(889): Cycle 15/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:21:07,145 - [NOTICE] simulation.solve(977): Capacity is now 4.948 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:21:07,145 - [NOTICE] simulation.solve(855): Cycle 16/328 (10.965 s elapsed) --------------------
# 2022-05-18 18:21:07,146 - [NOTICE] simulation.solve(889): Cycle 16/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:21:07,296 - [NOTICE] simulation.solve(889): Cycle 16/328, step 2/4: Rest for 5 min
# 2022-05-18 18:21:07,330 - [NOTICE] simulation.solve(889): Cycle 16/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:21:07,459 - [NOTICE] simulation.solve(889): Cycle 16/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:21:07,744 - [NOTICE] simulation.solve(977): Capacity is now 4.942 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:21:07,745 - [NOTICE] simulation.solve(855): Cycle 17/328 (11.565 s elapsed) --------------------
# 2022-05-18 18:21:07,746 - [NOTICE] simulation.solve(889): Cycle 17/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:21:07,881 - [NOTICE] simulation.solve(889): Cycle 17/328, step 2/4: Rest for 5 min
# 2022-05-18 18:21:07,912 - [NOTICE] simulation.solve(889): Cycle 17/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:21:08,110 - [NOTICE] simulation.solve(889): Cycle 17/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:21:08,453 - [NOTICE] simulation.solve(977): Capacity is now 4.935 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:21:08,453 - [NOTICE] simulation.solve(855): Cycle 18/328 (12.273 s elapsed) --------------------
# 2022-05-18 18:21:08,454 - [NOTICE] simulation.solve(889): Cycle 18/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:21:08,618 - [NOTICE] simulation.solve(889): Cycle 18/328, step 2/4: Rest for 5 min
# 2022-05-18 18:21:08,648 - [NOTICE] simulation.solve(889): Cycle 18/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:21:08,782 - [NOTICE] simulation.solve(889): Cycle 18/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:21:09,126 - [NOTICE] simulation.solve(977): Capacity is now 4.932 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:21:09,127 - [NOTICE] simulation.solve(855): Cycle 19/328 (12.947 s elapsed) --------------------
# 2022-05-18 18:21:09,128 - [NOTICE] simulation.solve(889): Cycle 19/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:21:09,281 - [NOTICE] simulation.solve(889): Cycle 19/328, step 2/4: Rest for 5 min
# 2022-05-18 18:21:09,317 - [NOTICE] simulation.solve(889): Cycle 19/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:21:09,481 - [NOTICE] simulation.solve(889): Cycle 19/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:21:09,789 - [NOTICE] simulation.solve(977): Capacity is now 4.923 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:21:09,789 - [NOTICE] simulation.solve(855): Cycle 20/328 (13.609 s elapsed) --------------------
# 2022-05-18 18:21:09,790 - [NOTICE] simulation.solve(889): Cycle 20/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:21:09,933 - [NOTICE] simulation.solve(889): Cycle 20/328, step 2/4: Rest for 5 min
# 2022-05-18 18:21:09,969 - [NOTICE] simulation.solve(889): Cycle 20/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:21:10,122 - [NOTICE] simulation.solve(889): Cycle 20/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:21:10,385 - [NOTICE] simulation.solve(977): Capacity is now 4.919 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:21:10,386 - [NOTICE] simulation.solve(855): Cycle 21/328 (14.205 s elapsed) --------------------
# 2022-05-18 18:21:10,386 - [NOTICE] simulation.solve(889): Cycle 21/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:21:10,547 - [NOTICE] simulation.solve(889): Cycle 21/328, step 2/4: Rest for 5 min
# 2022-05-18 18:21:10,581 - [NOTICE] simulation.solve(889): Cycle 21/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:21:10,730 - [NOTICE] simulation.solve(889): Cycle 21/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:21:11,015 - [NOTICE] simulation.solve(977): Capacity is now 4.913 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:21:11,016 - [NOTICE] simulation.solve(855): Cycle 22/328 (14.836 s elapsed) --------------------
# 2022-05-18 18:21:11,018 - [NOTICE] simulation.solve(889): Cycle 22/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:21:11,171 - [NOTICE] simulation.solve(889): Cycle 22/328, step 2/4: Rest for 5 min
# 2022-05-18 18:21:11,201 - [NOTICE] simulation.solve(889): Cycle 22/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:21:11,326 - [NOTICE] simulation.solve(889): Cycle 22/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:21:11,615 - [NOTICE] simulation.solve(977): Capacity is now 4.906 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:21:11,616 - [NOTICE] simulation.solve(855): Cycle 23/328 (15.436 s elapsed) --------------------
# 2022-05-18 18:21:11,617 - [NOTICE] simulation.solve(889): Cycle 23/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:21:11,789 - [NOTICE] simulation.solve(889): Cycle 23/328, step 2/4: Rest for 5 min
# 2022-05-18 18:21:11,820 - [NOTICE] simulation.solve(889): Cycle 23/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:21:11,963 - [NOTICE] simulation.solve(889): Cycle 23/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:21:12,315 - [NOTICE] simulation.solve(977): Capacity is now 4.900 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:21:12,316 - [NOTICE] simulation.solve(855): Cycle 24/328 (16.136 s elapsed) --------------------
# 2022-05-18 18:21:12,316 - [NOTICE] simulation.solve(889): Cycle 24/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:21:12,516 - [NOTICE] simulation.solve(889): Cycle 24/328, step 2/4: Rest for 5 min
# 2022-05-18 18:21:12,551 - [NOTICE] simulation.solve(889): Cycle 24/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:21:12,676 - [NOTICE] simulation.solve(889): Cycle 24/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:21:12,953 - [NOTICE] simulation.solve(977): Capacity is now 4.894 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:21:12,954 - [NOTICE] simulation.solve(855): Cycle 25/328 (16.774 s elapsed) --------------------
# 2022-05-18 18:21:12,955 - [NOTICE] simulation.solve(889): Cycle 25/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:21:13,129 - [NOTICE] simulation.solve(889): Cycle 25/328, step 2/4: Rest for 5 min
# 2022-05-18 18:21:13,165 - [NOTICE] simulation.solve(889): Cycle 25/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:21:13,291 - [NOTICE] simulation.solve(889): Cycle 25/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:21:13,588 - [NOTICE] simulation.solve(977): Capacity is now 4.887 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:21:13,588 - [NOTICE] simulation.solve(855): Cycle 26/328 (17.408 s elapsed) --------------------
# 2022-05-18 18:21:13,589 - [NOTICE] simulation.solve(889): Cycle 26/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:21:13,777 - [NOTICE] simulation.solve(889): Cycle 26/328, step 2/4: Rest for 5 min
# 2022-05-18 18:21:13,816 - [NOTICE] simulation.solve(889): Cycle 26/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:21:13,996 - [NOTICE] simulation.solve(889): Cycle 26/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:21:14,379 - [NOTICE] simulation.solve(977): Capacity is now 4.881 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:21:14,380 - [NOTICE] simulation.solve(855): Cycle 27/328 (18.200 s elapsed) --------------------
# 2022-05-18 18:21:14,381 - [NOTICE] simulation.solve(889): Cycle 27/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:21:14,598 - [NOTICE] simulation.solve(889): Cycle 27/328, step 2/4: Rest for 5 min
# 2022-05-18 18:21:14,651 - [NOTICE] simulation.solve(889): Cycle 27/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:21:14,830 - [NOTICE] simulation.solve(889): Cycle 27/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:21:15,170 - [NOTICE] simulation.solve(977): Capacity is now 4.875 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:21:15,171 - [NOTICE] simulation.solve(855): Cycle 28/328 (18.990 s elapsed) --------------------
# 2022-05-18 18:21:15,171 - [NOTICE] simulation.solve(889): Cycle 28/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:21:15,311 - [NOTICE] simulation.solve(889): Cycle 28/328, step 2/4: Rest for 5 min
# 2022-05-18 18:21:15,346 - [NOTICE] simulation.solve(889): Cycle 28/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:21:15,477 - [NOTICE] simulation.solve(889): Cycle 28/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:21:15,766 - [NOTICE] simulation.solve(977): Capacity is now 4.869 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:21:15,766 - [NOTICE] simulation.solve(855): Cycle 29/328 (19.586 s elapsed) --------------------
# 2022-05-18 18:21:15,767 - [NOTICE] simulation.solve(889): Cycle 29/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:21:15,905 - [NOTICE] simulation.solve(889): Cycle 29/328, step 2/4: Rest for 5 min
# 2022-05-18 18:21:15,951 - [NOTICE] simulation.solve(889): Cycle 29/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:21:16,114 - [NOTICE] simulation.solve(889): Cycle 29/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:21:16,376 - [NOTICE] simulation.solve(977): Capacity is now 4.863 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:21:16,377 - [NOTICE] simulation.solve(855): Cycle 30/328 (20.197 s elapsed) --------------------
# 2022-05-18 18:21:16,378 - [NOTICE] simulation.solve(889): Cycle 30/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:21:16,553 - [NOTICE] simulation.solve(889): Cycle 30/328, step 2/4: Rest for 5 min
# 2022-05-18 18:21:16,588 - [NOTICE] simulation.solve(889): Cycle 30/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:21:16,724 - [NOTICE] simulation.solve(889): Cycle 30/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:21:17,008 - [NOTICE] simulation.solve(977): Capacity is now 4.856 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:21:17,009 - [NOTICE] simulation.solve(855): Cycle 31/328 (20.828 s elapsed) --------------------
# 2022-05-18 18:21:17,010 - [NOTICE] simulation.solve(889): Cycle 31/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:21:17,170 - [NOTICE] simulation.solve(889): Cycle 31/328, step 2/4: Rest for 5 min
# 2022-05-18 18:21:17,203 - [NOTICE] simulation.solve(889): Cycle 31/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:21:17,333 - [NOTICE] simulation.solve(889): Cycle 31/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:21:17,606 - [NOTICE] simulation.solve(977): Capacity is now 4.850 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:21:17,607 - [NOTICE] simulation.solve(855): Cycle 32/328 (21.427 s elapsed) --------------------
# 2022-05-18 18:21:17,608 - [NOTICE] simulation.solve(889): Cycle 32/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:21:17,744 - [NOTICE] simulation.solve(889): Cycle 32/328, step 2/4: Rest for 5 min
# 2022-05-18 18:21:17,778 - [NOTICE] simulation.solve(889): Cycle 32/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:21:17,908 - [NOTICE] simulation.solve(889): Cycle 32/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:21:18,217 - [NOTICE] simulation.solve(977): Capacity is now 4.844 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:21:18,218 - [NOTICE] simulation.solve(855): Cycle 33/328 (22.038 s elapsed) --------------------
# 2022-05-18 18:21:18,219 - [NOTICE] simulation.solve(889): Cycle 33/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:21:18,363 - [NOTICE] simulation.solve(889): Cycle 33/328, step 2/4: Rest for 5 min
# 2022-05-18 18:21:18,396 - [NOTICE] simulation.solve(889): Cycle 33/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:21:18,534 - [NOTICE] simulation.solve(889): Cycle 33/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:21:18,866 - [NOTICE] simulation.solve(977): Capacity is now 4.838 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:21:18,866 - [NOTICE] simulation.solve(855): Cycle 34/328 (22.686 s elapsed) --------------------
# 2022-05-18 18:21:18,867 - [NOTICE] simulation.solve(889): Cycle 34/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:21:19,069 - [NOTICE] simulation.solve(889): Cycle 34/328, step 2/4: Rest for 5 min
# 2022-05-18 18:21:19,106 - [NOTICE] simulation.solve(889): Cycle 34/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:21:19,234 - [NOTICE] simulation.solve(889): Cycle 34/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:21:19,509 - [NOTICE] simulation.solve(977): Capacity is now 4.832 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:21:19,509 - [NOTICE] simulation.solve(855): Cycle 35/328 (23.329 s elapsed) --------------------
# 2022-05-18 18:21:19,510 - [NOTICE] simulation.solve(889): Cycle 35/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:21:19,654 - [NOTICE] simulation.solve(889): Cycle 35/328, step 2/4: Rest for 5 min
# 2022-05-18 18:21:19,692 - [NOTICE] simulation.solve(889): Cycle 35/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:21:19,824 - [NOTICE] simulation.solve(889): Cycle 35/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:21:20,192 - [NOTICE] simulation.solve(977): Capacity is now 4.825 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:21:20,193 - [NOTICE] simulation.solve(855): Cycle 36/328 (24.012 s elapsed) --------------------
# 2022-05-18 18:21:20,194 - [NOTICE] simulation.solve(889): Cycle 36/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:21:20,336 - [NOTICE] simulation.solve(889): Cycle 36/328, step 2/4: Rest for 5 min
# 2022-05-18 18:21:20,368 - [NOTICE] simulation.solve(889): Cycle 36/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:21:20,503 - [NOTICE] simulation.solve(889): Cycle 36/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:21:20,798 - [NOTICE] simulation.solve(977): Capacity is now 4.819 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:21:20,799 - [NOTICE] simulation.solve(855): Cycle 37/328 (24.619 s elapsed) --------------------
# 2022-05-18 18:21:20,800 - [NOTICE] simulation.solve(889): Cycle 37/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:21:20,951 - [NOTICE] simulation.solve(889): Cycle 37/328, step 2/4: Rest for 5 min
# 2022-05-18 18:21:20,988 - [NOTICE] simulation.solve(889): Cycle 37/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:21:21,156 - [NOTICE] simulation.solve(889): Cycle 37/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:21:21,419 - [NOTICE] simulation.solve(977): Capacity is now 4.813 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:21:21,420 - [NOTICE] simulation.solve(855): Cycle 38/328 (25.240 s elapsed) --------------------
# 2022-05-18 18:21:21,420 - [NOTICE] simulation.solve(889): Cycle 38/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:21:21,578 - [NOTICE] simulation.solve(889): Cycle 38/328, step 2/4: Rest for 5 min
# 2022-05-18 18:21:21,612 - [NOTICE] simulation.solve(889): Cycle 38/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:21:21,742 - [NOTICE] simulation.solve(889): Cycle 38/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:21:22,019 - [NOTICE] simulation.solve(977): Capacity is now 4.807 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:21:22,020 - [NOTICE] simulation.solve(855): Cycle 39/328 (25.840 s elapsed) --------------------
# 2022-05-18 18:21:22,021 - [NOTICE] simulation.solve(889): Cycle 39/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:21:22,186 - [NOTICE] simulation.solve(889): Cycle 39/328, step 2/4: Rest for 5 min
# 2022-05-18 18:21:22,227 - [NOTICE] simulation.solve(889): Cycle 39/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:21:22,359 - [NOTICE] simulation.solve(889): Cycle 39/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:21:22,646 - [NOTICE] simulation.solve(977): Capacity is now 4.801 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:21:22,647 - [NOTICE] simulation.solve(855): Cycle 40/328 (26.466 s elapsed) --------------------
# 2022-05-18 18:21:22,648 - [NOTICE] simulation.solve(889): Cycle 40/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:21:22,791 - [NOTICE] simulation.solve(889): Cycle 40/328, step 2/4: Rest for 5 min
# 2022-05-18 18:21:22,823 - [NOTICE] simulation.solve(889): Cycle 40/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:21:22,966 - [NOTICE] simulation.solve(889): Cycle 40/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:21:23,259 - [NOTICE] simulation.solve(977): Capacity is now 4.795 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:21:23,260 - [NOTICE] simulation.solve(855): Cycle 41/328 (27.079 s elapsed) --------------------
# 2022-05-18 18:21:23,261 - [NOTICE] simulation.solve(889): Cycle 41/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:21:23,413 - [NOTICE] simulation.solve(889): Cycle 41/328, step 2/4: Rest for 5 min
# 2022-05-18 18:21:23,443 - [NOTICE] simulation.solve(889): Cycle 41/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:21:23,572 - [NOTICE] simulation.solve(889): Cycle 41/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:21:23,842 - [NOTICE] simulation.solve(977): Capacity is now 4.788 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:21:23,843 - [NOTICE] simulation.solve(855): Cycle 42/328 (27.663 s elapsed) --------------------
# 2022-05-18 18:21:23,843 - [NOTICE] simulation.solve(889): Cycle 42/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:21:24,016 - [NOTICE] simulation.solve(889): Cycle 42/328, step 2/4: Rest for 5 min
# 2022-05-18 18:21:24,051 - [NOTICE] simulation.solve(889): Cycle 42/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:21:24,198 - [NOTICE] simulation.solve(889): Cycle 42/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:21:24,464 - [NOTICE] simulation.solve(977): Capacity is now 4.782 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:21:24,465 - [NOTICE] simulation.solve(855): Cycle 43/328 (28.285 s elapsed) --------------------
# 2022-05-18 18:21:24,466 - [NOTICE] simulation.solve(889): Cycle 43/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:21:24,615 - [NOTICE] simulation.solve(889): Cycle 43/328, step 2/4: Rest for 5 min
# 2022-05-18 18:21:24,650 - [NOTICE] simulation.solve(889): Cycle 43/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:21:24,786 - [NOTICE] simulation.solve(889): Cycle 43/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:21:25,090 - [NOTICE] simulation.solve(977): Capacity is now 4.776 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:21:25,091 - [NOTICE] simulation.solve(855): Cycle 44/328 (28.911 s elapsed) --------------------
# 2022-05-18 18:21:25,092 - [NOTICE] simulation.solve(889): Cycle 44/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:21:25,237 - [NOTICE] simulation.solve(889): Cycle 44/328, step 2/4: Rest for 5 min
# 2022-05-18 18:21:25,269 - [NOTICE] simulation.solve(889): Cycle 44/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:21:25,399 - [NOTICE] simulation.solve(889): Cycle 44/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:21:25,685 - [NOTICE] simulation.solve(977): Capacity is now 4.770 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:21:25,686 - [NOTICE] simulation.solve(855): Cycle 45/328 (29.506 s elapsed) --------------------
# 2022-05-18 18:21:25,687 - [NOTICE] simulation.solve(889): Cycle 45/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:21:25,839 - [NOTICE] simulation.solve(889): Cycle 45/328, step 2/4: Rest for 5 min
# 2022-05-18 18:21:25,870 - [NOTICE] simulation.solve(889): Cycle 45/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:21:26,020 - [NOTICE] simulation.solve(889): Cycle 45/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:21:26,310 - [NOTICE] simulation.solve(977): Capacity is now 4.764 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:21:26,310 - [NOTICE] simulation.solve(855): Cycle 46/328 (30.130 s elapsed) --------------------
# 2022-05-18 18:21:26,311 - [NOTICE] simulation.solve(889): Cycle 46/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:21:26,463 - [NOTICE] simulation.solve(889): Cycle 46/328, step 2/4: Rest for 5 min
# 2022-05-18 18:21:26,496 - [NOTICE] simulation.solve(889): Cycle 46/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:21:26,639 - [NOTICE] simulation.solve(889): Cycle 46/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:21:26,895 - [NOTICE] simulation.solve(977): Capacity is now 4.758 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:21:26,895 - [NOTICE] simulation.solve(855): Cycle 47/328 (30.715 s elapsed) --------------------
# 2022-05-18 18:21:26,896 - [NOTICE] simulation.solve(889): Cycle 47/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:21:27,076 - [NOTICE] simulation.solve(889): Cycle 47/328, step 2/4: Rest for 5 min
# 2022-05-18 18:21:27,113 - [NOTICE] simulation.solve(889): Cycle 47/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:21:27,251 - [NOTICE] simulation.solve(889): Cycle 47/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:21:27,518 - [NOTICE] simulation.solve(977): Capacity is now 4.752 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:21:27,519 - [NOTICE] simulation.solve(855): Cycle 48/328 (31.339 s elapsed) --------------------
# 2022-05-18 18:21:27,519 - [NOTICE] simulation.solve(889): Cycle 48/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:21:27,666 - [NOTICE] simulation.solve(889): Cycle 48/328, step 2/4: Rest for 5 min
# 2022-05-18 18:21:27,697 - [NOTICE] simulation.solve(889): Cycle 48/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:21:27,828 - [NOTICE] simulation.solve(889): Cycle 48/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:21:28,131 - [NOTICE] simulation.solve(977): Capacity is now 4.746 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:21:28,132 - [NOTICE] simulation.solve(855): Cycle 49/328 (31.952 s elapsed) --------------------
# 2022-05-18 18:21:28,133 - [NOTICE] simulation.solve(889): Cycle 49/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:21:28,280 - [NOTICE] simulation.solve(889): Cycle 49/328, step 2/4: Rest for 5 min
# 2022-05-18 18:21:28,324 - [NOTICE] simulation.solve(889): Cycle 49/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:21:28,458 - [NOTICE] simulation.solve(889): Cycle 49/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:21:28,723 - [NOTICE] simulation.solve(977): Capacity is now 4.740 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:21:28,724 - [NOTICE] simulation.solve(855): Cycle 50/328 (32.543 s elapsed) --------------------
# 2022-05-18 18:21:28,725 - [NOTICE] simulation.solve(889): Cycle 50/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:21:28,874 - [NOTICE] simulation.solve(889): Cycle 50/328, step 2/4: Rest for 5 min
# 2022-05-18 18:21:28,907 - [NOTICE] simulation.solve(889): Cycle 50/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:21:29,052 - [NOTICE] simulation.solve(889): Cycle 50/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:21:29,338 - [NOTICE] simulation.solve(977): Capacity is now 4.734 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:21:29,339 - [NOTICE] simulation.solve(855): Cycle 51/328 (33.158 s elapsed) --------------------
# 2022-05-18 18:21:29,340 - [NOTICE] simulation.solve(889): Cycle 51/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:21:29,498 - [NOTICE] simulation.solve(889): Cycle 51/328, step 2/4: Rest for 5 min
# 2022-05-18 18:21:29,530 - [NOTICE] simulation.solve(889): Cycle 51/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:21:29,653 - [NOTICE] simulation.solve(889): Cycle 51/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:21:29,913 - [NOTICE] simulation.solve(977): Capacity is now 4.727 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:21:29,913 - [NOTICE] simulation.solve(855): Cycle 52/328 (33.733 s elapsed) --------------------
# 2022-05-18 18:21:29,914 - [NOTICE] simulation.solve(889): Cycle 52/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:21:30,104 - [NOTICE] simulation.solve(889): Cycle 52/328, step 2/4: Rest for 5 min
# 2022-05-18 18:21:30,135 - [NOTICE] simulation.solve(889): Cycle 52/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:21:30,257 - [NOTICE] simulation.solve(889): Cycle 52/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:21:30,552 - [NOTICE] simulation.solve(977): Capacity is now 4.721 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:21:30,553 - [NOTICE] simulation.solve(855): Cycle 53/328 (34.372 s elapsed) --------------------
# 2022-05-18 18:21:30,553 - [NOTICE] simulation.solve(889): Cycle 53/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:21:30,708 - [NOTICE] simulation.solve(889): Cycle 53/328, step 2/4: Rest for 5 min
# 2022-05-18 18:21:30,741 - [NOTICE] simulation.solve(889): Cycle 53/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:21:30,868 - [NOTICE] simulation.solve(889): Cycle 53/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:21:31,176 - [NOTICE] simulation.solve(977): Capacity is now 4.715 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:21:31,177 - [NOTICE] simulation.solve(855): Cycle 54/328 (34.996 s elapsed) --------------------
# 2022-05-18 18:21:31,178 - [NOTICE] simulation.solve(889): Cycle 54/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:21:31,325 - [NOTICE] simulation.solve(889): Cycle 54/328, step 2/4: Rest for 5 min
# 2022-05-18 18:21:31,368 - [NOTICE] simulation.solve(889): Cycle 54/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:21:31,560 - [NOTICE] simulation.solve(889): Cycle 54/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:21:31,887 - [NOTICE] simulation.solve(977): Capacity is now 4.709 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:21:31,888 - [NOTICE] simulation.solve(855): Cycle 55/328 (35.707 s elapsed) --------------------
# 2022-05-18 18:21:31,888 - [NOTICE] simulation.solve(889): Cycle 55/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:21:32,074 - [NOTICE] simulation.solve(889): Cycle 55/328, step 2/4: Rest for 5 min
# 2022-05-18 18:21:32,108 - [NOTICE] simulation.solve(889): Cycle 55/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:21:32,224 - [NOTICE] simulation.solve(889): Cycle 55/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:21:32,519 - [NOTICE] simulation.solve(977): Capacity is now 4.703 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:21:32,520 - [NOTICE] simulation.solve(855): Cycle 56/328 (36.339 s elapsed) --------------------
# 2022-05-18 18:21:32,521 - [NOTICE] simulation.solve(889): Cycle 56/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:21:32,655 - [NOTICE] simulation.solve(889): Cycle 56/328, step 2/4: Rest for 5 min
# 2022-05-18 18:21:32,687 - [NOTICE] simulation.solve(889): Cycle 56/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:21:32,809 - [NOTICE] simulation.solve(889): Cycle 56/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:21:33,133 - [NOTICE] simulation.solve(977): Capacity is now 4.697 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:21:33,133 - [NOTICE] simulation.solve(855): Cycle 57/328 (36.953 s elapsed) --------------------
# 2022-05-18 18:21:33,134 - [NOTICE] simulation.solve(889): Cycle 57/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:21:33,276 - [NOTICE] simulation.solve(889): Cycle 57/328, step 2/4: Rest for 5 min
# 2022-05-18 18:21:33,311 - [NOTICE] simulation.solve(889): Cycle 57/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:21:33,444 - [NOTICE] simulation.solve(889): Cycle 57/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:21:33,741 - [NOTICE] simulation.solve(977): Capacity is now 4.691 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:21:33,741 - [NOTICE] simulation.solve(855): Cycle 58/328 (37.561 s elapsed) --------------------
# 2022-05-18 18:21:33,742 - [NOTICE] simulation.solve(889): Cycle 58/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:21:33,877 - [NOTICE] simulation.solve(889): Cycle 58/328, step 2/4: Rest for 5 min
# 2022-05-18 18:21:33,908 - [NOTICE] simulation.solve(889): Cycle 58/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:21:34,063 - [NOTICE] simulation.solve(889): Cycle 58/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:21:34,338 - [NOTICE] simulation.solve(977): Capacity is now 4.685 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:21:34,338 - [NOTICE] simulation.solve(855): Cycle 59/328 (38.157 s elapsed) --------------------
# 2022-05-18 18:21:34,339 - [NOTICE] simulation.solve(889): Cycle 59/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:21:34,478 - [NOTICE] simulation.solve(889): Cycle 59/328, step 2/4: Rest for 5 min
# 2022-05-18 18:21:34,510 - [NOTICE] simulation.solve(889): Cycle 59/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:21:34,635 - [NOTICE] simulation.solve(889): Cycle 59/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:21:34,917 - [NOTICE] simulation.solve(977): Capacity is now 4.679 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:21:34,918 - [NOTICE] simulation.solve(855): Cycle 60/328 (38.738 s elapsed) --------------------
# 2022-05-18 18:21:34,919 - [NOTICE] simulation.solve(889): Cycle 60/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:21:35,108 - [NOTICE] simulation.solve(889): Cycle 60/328, step 2/4: Rest for 5 min
# 2022-05-18 18:21:35,137 - [NOTICE] simulation.solve(889): Cycle 60/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:21:35,260 - [NOTICE] simulation.solve(889): Cycle 60/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:21:35,523 - [NOTICE] simulation.solve(977): Capacity is now 4.673 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:21:35,525 - [NOTICE] simulation.solve(855): Cycle 61/328 (39.344 s elapsed) --------------------
# 2022-05-18 18:21:35,525 - [NOTICE] simulation.solve(889): Cycle 61/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:21:35,667 - [NOTICE] simulation.solve(889): Cycle 61/328, step 2/4: Rest for 5 min
# 2022-05-18 18:21:35,700 - [NOTICE] simulation.solve(889): Cycle 61/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:21:35,828 - [NOTICE] simulation.solve(889): Cycle 61/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:21:36,233 - [NOTICE] simulation.solve(977): Capacity is now 4.667 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:21:36,234 - [NOTICE] simulation.solve(855): Cycle 62/328 (40.054 s elapsed) --------------------
# 2022-05-18 18:21:36,235 - [NOTICE] simulation.solve(889): Cycle 62/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:21:36,404 - [NOTICE] simulation.solve(889): Cycle 62/328, step 2/4: Rest for 5 min
# 2022-05-18 18:21:36,434 - [NOTICE] simulation.solve(889): Cycle 62/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:21:36,559 - [NOTICE] simulation.solve(889): Cycle 62/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:21:36,832 - [NOTICE] simulation.solve(977): Capacity is now 4.661 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:21:36,833 - [NOTICE] simulation.solve(855): Cycle 63/328 (40.653 s elapsed) --------------------
# 2022-05-18 18:21:36,834 - [NOTICE] simulation.solve(889): Cycle 63/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:21:37,002 - [NOTICE] simulation.solve(889): Cycle 63/328, step 2/4: Rest for 5 min
# 2022-05-18 18:21:37,046 - [NOTICE] simulation.solve(889): Cycle 63/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:21:37,175 - [NOTICE] simulation.solve(889): Cycle 63/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:21:37,436 - [NOTICE] simulation.solve(977): Capacity is now 4.655 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:21:37,437 - [NOTICE] simulation.solve(855): Cycle 64/328 (41.256 s elapsed) --------------------
# 2022-05-18 18:21:37,437 - [NOTICE] simulation.solve(889): Cycle 64/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:21:37,576 - [NOTICE] simulation.solve(889): Cycle 64/328, step 2/4: Rest for 5 min
# 2022-05-18 18:21:37,614 - [NOTICE] simulation.solve(889): Cycle 64/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:21:37,735 - [NOTICE] simulation.solve(889): Cycle 64/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:21:38,056 - [NOTICE] simulation.solve(977): Capacity is now 4.649 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:21:38,056 - [NOTICE] simulation.solve(855): Cycle 65/328 (41.876 s elapsed) --------------------
# 2022-05-18 18:21:38,057 - [NOTICE] simulation.solve(889): Cycle 65/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:21:38,205 - [NOTICE] simulation.solve(889): Cycle 65/328, step 2/4: Rest for 5 min
# 2022-05-18 18:21:38,238 - [NOTICE] simulation.solve(889): Cycle 65/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:21:38,365 - [NOTICE] simulation.solve(889): Cycle 65/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:21:38,651 - [NOTICE] simulation.solve(977): Capacity is now 4.643 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:21:38,652 - [NOTICE] simulation.solve(855): Cycle 66/328 (42.472 s elapsed) --------------------
# 2022-05-18 18:21:38,653 - [NOTICE] simulation.solve(889): Cycle 66/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:21:38,795 - [NOTICE] simulation.solve(889): Cycle 66/328, step 2/4: Rest for 5 min
# 2022-05-18 18:21:38,828 - [NOTICE] simulation.solve(889): Cycle 66/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:21:38,978 - [NOTICE] simulation.solve(889): Cycle 66/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:21:39,295 - [NOTICE] simulation.solve(977): Capacity is now 4.637 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:21:39,295 - [NOTICE] simulation.solve(855): Cycle 67/328 (43.115 s elapsed) --------------------
# 2022-05-18 18:21:39,296 - [NOTICE] simulation.solve(889): Cycle 67/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:21:39,430 - [NOTICE] simulation.solve(889): Cycle 67/328, step 2/4: Rest for 5 min
# 2022-05-18 18:21:39,462 - [NOTICE] simulation.solve(889): Cycle 67/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:21:39,588 - [NOTICE] simulation.solve(889): Cycle 67/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:21:39,945 - [NOTICE] simulation.solve(977): Capacity is now 4.631 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:21:39,945 - [NOTICE] simulation.solve(855): Cycle 68/328 (43.765 s elapsed) --------------------
# 2022-05-18 18:21:39,946 - [NOTICE] simulation.solve(889): Cycle 68/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:21:40,170 - [NOTICE] simulation.solve(889): Cycle 68/328, step 2/4: Rest for 5 min
# 2022-05-18 18:21:40,208 - [NOTICE] simulation.solve(889): Cycle 68/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:21:40,330 - [NOTICE] simulation.solve(889): Cycle 68/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:21:40,620 - [NOTICE] simulation.solve(977): Capacity is now 4.625 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:21:40,620 - [NOTICE] simulation.solve(855): Cycle 69/328 (44.440 s elapsed) --------------------
# 2022-05-18 18:21:40,621 - [NOTICE] simulation.solve(889): Cycle 69/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:21:40,756 - [NOTICE] simulation.solve(889): Cycle 69/328, step 2/4: Rest for 5 min
# 2022-05-18 18:21:40,789 - [NOTICE] simulation.solve(889): Cycle 69/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:21:40,912 - [NOTICE] simulation.solve(889): Cycle 69/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:21:41,222 - [NOTICE] simulation.solve(977): Capacity is now 4.619 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:21:41,223 - [NOTICE] simulation.solve(855): Cycle 70/328 (45.042 s elapsed) --------------------
# 2022-05-18 18:21:41,223 - [NOTICE] simulation.solve(889): Cycle 70/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:21:41,356 - [NOTICE] simulation.solve(889): Cycle 70/328, step 2/4: Rest for 5 min
# 2022-05-18 18:21:41,387 - [NOTICE] simulation.solve(889): Cycle 70/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:21:41,513 - [NOTICE] simulation.solve(889): Cycle 70/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:21:41,781 - [NOTICE] simulation.solve(977): Capacity is now 4.613 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:21:41,781 - [NOTICE] simulation.solve(855): Cycle 71/328 (45.601 s elapsed) --------------------
# 2022-05-18 18:21:41,781 - [NOTICE] simulation.solve(889): Cycle 71/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:21:41,934 - [NOTICE] simulation.solve(889): Cycle 71/328, step 2/4: Rest for 5 min
# 2022-05-18 18:21:41,970 - [NOTICE] simulation.solve(889): Cycle 71/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:21:42,129 - [NOTICE] simulation.solve(889): Cycle 71/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:21:42,447 - [NOTICE] simulation.solve(977): Capacity is now 4.607 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:21:42,448 - [NOTICE] simulation.solve(855): Cycle 72/328 (46.268 s elapsed) --------------------
# 2022-05-18 18:21:42,448 - [NOTICE] simulation.solve(889): Cycle 72/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:21:42,590 - [NOTICE] simulation.solve(889): Cycle 72/328, step 2/4: Rest for 5 min
# 2022-05-18 18:21:42,623 - [NOTICE] simulation.solve(889): Cycle 72/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:21:42,764 - [NOTICE] simulation.solve(889): Cycle 72/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:21:43,124 - [NOTICE] simulation.solve(977): Capacity is now 4.601 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:21:43,125 - [NOTICE] simulation.solve(855): Cycle 73/328 (46.944 s elapsed) --------------------
# 2022-05-18 18:21:43,125 - [NOTICE] simulation.solve(889): Cycle 73/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:21:43,303 - [NOTICE] simulation.solve(889): Cycle 73/328, step 2/4: Rest for 5 min
# 2022-05-18 18:21:43,346 - [NOTICE] simulation.solve(889): Cycle 73/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:21:43,522 - [NOTICE] simulation.solve(889): Cycle 73/328, step 4/4: Hold at 4.2V until C/50
# ...
# 2022-05-18 18:24:06,225 - [NOTICE] simulation.solve(889): Cycle 305/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:24:06,579 - [NOTICE] simulation.solve(977): Capacity is now 3.344 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:24:06,580 - [NOTICE] simulation.solve(855): Cycle 306/328 (3 minutes, 10 seconds elapsed) --------------------
# 2022-05-18 18:24:06,581 - [NOTICE] simulation.solve(889): Cycle 306/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:24:06,705 - [NOTICE] simulation.solve(889): Cycle 306/328, step 2/4: Rest for 5 min
# 2022-05-18 18:24:06,747 - [NOTICE] simulation.solve(889): Cycle 306/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:24:06,834 - [NOTICE] simulation.solve(889): Cycle 306/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:24:07,179 - [NOTICE] simulation.solve(977): Capacity is now 3.339 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:24:07,180 - [NOTICE] simulation.solve(855): Cycle 307/328 (3 minutes, 11 seconds elapsed) --------------------
# 2022-05-18 18:24:07,180 - [NOTICE] simulation.solve(889): Cycle 307/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:24:07,291 - [NOTICE] simulation.solve(889): Cycle 307/328, step 2/4: Rest for 5 min
# 2022-05-18 18:24:07,325 - [NOTICE] simulation.solve(889): Cycle 307/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:24:07,414 - [NOTICE] simulation.solve(889): Cycle 307/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:24:07,754 - [NOTICE] simulation.solve(977): Capacity is now 3.334 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:24:07,755 - [NOTICE] simulation.solve(855): Cycle 308/328 (3 minutes, 12 seconds elapsed) --------------------
# 2022-05-18 18:24:07,755 - [NOTICE] simulation.solve(889): Cycle 308/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:24:07,879 - [NOTICE] simulation.solve(889): Cycle 308/328, step 2/4: Rest for 5 min
# 2022-05-18 18:24:07,911 - [NOTICE] simulation.solve(889): Cycle 308/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:24:08,007 - [NOTICE] simulation.solve(889): Cycle 308/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:24:08,421 - [NOTICE] simulation.solve(977): Capacity is now 3.329 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:24:08,422 - [NOTICE] simulation.solve(855): Cycle 309/328 (3 minutes, 12 seconds elapsed) --------------------
# 2022-05-18 18:24:08,423 - [NOTICE] simulation.solve(889): Cycle 309/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:24:08,547 - [NOTICE] simulation.solve(889): Cycle 309/328, step 2/4: Rest for 5 min
# 2022-05-18 18:24:08,583 - [NOTICE] simulation.solve(889): Cycle 309/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:24:08,664 - [NOTICE] simulation.solve(889): Cycle 309/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:24:09,027 - [NOTICE] simulation.solve(977): Capacity is now 3.324 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:24:09,028 - [NOTICE] simulation.solve(855): Cycle 310/328 (3 minutes, 13 seconds elapsed) --------------------
# 2022-05-18 18:24:09,029 - [NOTICE] simulation.solve(889): Cycle 310/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:24:09,203 - [NOTICE] simulation.solve(889): Cycle 310/328, step 2/4: Rest for 5 min
# 2022-05-18 18:24:09,236 - [NOTICE] simulation.solve(889): Cycle 310/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:24:09,337 - [NOTICE] simulation.solve(889): Cycle 310/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:24:09,661 - [NOTICE] simulation.solve(977): Capacity is now 3.319 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:24:09,662 - [NOTICE] simulation.solve(855): Cycle 311/328 (3 minutes, 13 seconds elapsed) --------------------
# 2022-05-18 18:24:09,663 - [NOTICE] simulation.solve(889): Cycle 311/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:24:09,771 - [NOTICE] simulation.solve(889): Cycle 311/328, step 2/4: Rest for 5 min
# 2022-05-18 18:24:09,801 - [NOTICE] simulation.solve(889): Cycle 311/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:24:09,907 - [NOTICE] simulation.solve(889): Cycle 311/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:24:10,272 - [NOTICE] simulation.solve(977): Capacity is now 3.314 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:24:10,272 - [NOTICE] simulation.solve(855): Cycle 312/328 (3 minutes, 14 seconds elapsed) --------------------
# 2022-05-18 18:24:10,273 - [NOTICE] simulation.solve(889): Cycle 312/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:24:10,385 - [NOTICE] simulation.solve(889): Cycle 312/328, step 2/4: Rest for 5 min
# 2022-05-18 18:24:10,418 - [NOTICE] simulation.solve(889): Cycle 312/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:24:10,507 - [NOTICE] simulation.solve(889): Cycle 312/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:24:10,832 - [NOTICE] simulation.solve(977): Capacity is now 3.309 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:24:10,834 - [NOTICE] simulation.solve(855): Cycle 313/328 (3 minutes, 15 seconds elapsed) --------------------
# 2022-05-18 18:24:10,834 - [NOTICE] simulation.solve(889): Cycle 313/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:24:10,947 - [NOTICE] simulation.solve(889): Cycle 313/328, step 2/4: Rest for 5 min
# 2022-05-18 18:24:10,978 - [NOTICE] simulation.solve(889): Cycle 313/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:24:11,103 - [NOTICE] simulation.solve(889): Cycle 313/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:24:11,480 - [NOTICE] simulation.solve(977): Capacity is now 3.304 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:24:11,481 - [NOTICE] simulation.solve(855): Cycle 314/328 (3 minutes, 15 seconds elapsed) --------------------
# 2022-05-18 18:24:11,482 - [NOTICE] simulation.solve(889): Cycle 314/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:24:11,594 - [NOTICE] simulation.solve(889): Cycle 314/328, step 2/4: Rest for 5 min
# 2022-05-18 18:24:11,635 - [NOTICE] simulation.solve(889): Cycle 314/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:24:11,743 - [NOTICE] simulation.solve(889): Cycle 314/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:24:12,098 - [NOTICE] simulation.solve(977): Capacity is now 3.298 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:24:12,099 - [NOTICE] simulation.solve(855): Cycle 315/328 (3 minutes, 16 seconds elapsed) --------------------
# 2022-05-18 18:24:12,099 - [NOTICE] simulation.solve(889): Cycle 315/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:24:12,220 - [NOTICE] simulation.solve(889): Cycle 315/328, step 2/4: Rest for 5 min
# 2022-05-18 18:24:12,253 - [NOTICE] simulation.solve(889): Cycle 315/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:24:12,339 - [NOTICE] simulation.solve(889): Cycle 315/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:24:12,692 - [NOTICE] simulation.solve(977): Capacity is now 3.293 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:24:12,693 - [NOTICE] simulation.solve(855): Cycle 316/328 (3 minutes, 17 seconds elapsed) --------------------
# 2022-05-18 18:24:12,694 - [NOTICE] simulation.solve(889): Cycle 316/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:24:12,804 - [NOTICE] simulation.solve(889): Cycle 316/328, step 2/4: Rest for 5 min
# 2022-05-18 18:24:12,839 - [NOTICE] simulation.solve(889): Cycle 316/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:24:12,975 - [NOTICE] simulation.solve(889): Cycle 316/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:24:13,315 - [NOTICE] simulation.solve(977): Capacity is now 3.288 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:24:13,316 - [NOTICE] simulation.solve(855): Cycle 317/328 (3 minutes, 17 seconds elapsed) --------------------
# 2022-05-18 18:24:13,317 - [NOTICE] simulation.solve(889): Cycle 317/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:24:13,463 - [NOTICE] simulation.solve(889): Cycle 317/328, step 2/4: Rest for 5 min
# 2022-05-18 18:24:13,499 - [NOTICE] simulation.solve(889): Cycle 317/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:24:13,595 - [NOTICE] simulation.solve(889): Cycle 317/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:24:13,932 - [NOTICE] simulation.solve(977): Capacity is now 3.283 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:24:13,933 - [NOTICE] simulation.solve(855): Cycle 318/328 (3 minutes, 18 seconds elapsed) --------------------
# 2022-05-18 18:24:13,934 - [NOTICE] simulation.solve(889): Cycle 318/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:24:14,049 - [NOTICE] simulation.solve(889): Cycle 318/328, step 2/4: Rest for 5 min
# 2022-05-18 18:24:14,084 - [NOTICE] simulation.solve(889): Cycle 318/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:24:14,175 - [NOTICE] simulation.solve(889): Cycle 318/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:24:14,556 - [NOTICE] simulation.solve(977): Capacity is now 3.278 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:24:14,557 - [NOTICE] simulation.solve(855): Cycle 319/328 (3 minutes, 18 seconds elapsed) --------------------
# 2022-05-18 18:24:14,557 - [NOTICE] simulation.solve(889): Cycle 319/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:24:14,699 - [NOTICE] simulation.solve(889): Cycle 319/328, step 2/4: Rest for 5 min
# 2022-05-18 18:24:14,744 - [NOTICE] simulation.solve(889): Cycle 319/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:24:14,850 - [NOTICE] simulation.solve(889): Cycle 319/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:24:15,206 - [NOTICE] simulation.solve(977): Capacity is now 3.273 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:24:15,207 - [NOTICE] simulation.solve(855): Cycle 320/328 (3 minutes, 19 seconds elapsed) --------------------
# 2022-05-18 18:24:15,208 - [NOTICE] simulation.solve(889): Cycle 320/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:24:15,317 - [NOTICE] simulation.solve(889): Cycle 320/328, step 2/4: Rest for 5 min
# 2022-05-18 18:24:15,347 - [NOTICE] simulation.solve(889): Cycle 320/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:24:15,433 - [NOTICE] simulation.solve(889): Cycle 320/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:24:15,772 - [NOTICE] simulation.solve(977): Capacity is now 3.268 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:24:15,772 - [NOTICE] simulation.solve(855): Cycle 321/328 (3 minutes, 20 seconds elapsed) --------------------
# 2022-05-18 18:24:15,773 - [NOTICE] simulation.solve(889): Cycle 321/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:24:15,889 - [NOTICE] simulation.solve(889): Cycle 321/328, step 2/4: Rest for 5 min
# 2022-05-18 18:24:15,923 - [NOTICE] simulation.solve(889): Cycle 321/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:24:16,020 - [NOTICE] simulation.solve(889): Cycle 321/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:24:16,394 - [NOTICE] simulation.solve(977): Capacity is now 3.263 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:24:16,395 - [NOTICE] simulation.solve(855): Cycle 322/328 (3 minutes, 20 seconds elapsed) --------------------
# 2022-05-18 18:24:16,395 - [NOTICE] simulation.solve(889): Cycle 322/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:24:16,503 - [NOTICE] simulation.solve(889): Cycle 322/328, step 2/4: Rest for 5 min
# 2022-05-18 18:24:16,537 - [NOTICE] simulation.solve(889): Cycle 322/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:24:16,629 - [NOTICE] simulation.solve(889): Cycle 322/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:24:16,976 - [NOTICE] simulation.solve(977): Capacity is now 3.258 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:24:16,976 - [NOTICE] simulation.solve(855): Cycle 323/328 (3 minutes, 21 seconds elapsed) --------------------
# 2022-05-18 18:24:16,978 - [NOTICE] simulation.solve(889): Cycle 323/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:24:17,085 - [NOTICE] simulation.solve(889): Cycle 323/328, step 2/4: Rest for 5 min
# 2022-05-18 18:24:17,122 - [NOTICE] simulation.solve(889): Cycle 323/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:24:17,213 - [NOTICE] simulation.solve(889): Cycle 323/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:24:17,542 - [NOTICE] simulation.solve(977): Capacity is now 3.253 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:24:17,543 - [NOTICE] simulation.solve(855): Cycle 324/328 (3 minutes, 21 seconds elapsed) --------------------
# 2022-05-18 18:24:17,543 - [NOTICE] simulation.solve(889): Cycle 324/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:24:17,649 - [NOTICE] simulation.solve(889): Cycle 324/328, step 2/4: Rest for 5 min
# 2022-05-18 18:24:17,704 - [NOTICE] simulation.solve(889): Cycle 324/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:24:17,797 - [NOTICE] simulation.solve(889): Cycle 324/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:24:18,126 - [NOTICE] simulation.solve(977): Capacity is now 3.248 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:24:18,127 - [NOTICE] simulation.solve(855): Cycle 325/328 (3 minutes, 22 seconds elapsed) --------------------
# 2022-05-18 18:24:18,128 - [NOTICE] simulation.solve(889): Cycle 325/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:24:18,243 - [NOTICE] simulation.solve(889): Cycle 325/328, step 2/4: Rest for 5 min
# 2022-05-18 18:24:18,274 - [NOTICE] simulation.solve(889): Cycle 325/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:24:18,367 - [NOTICE] simulation.solve(889): Cycle 325/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:24:18,747 - [NOTICE] simulation.solve(977): Capacity is now 3.243 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:24:18,747 - [NOTICE] simulation.solve(855): Cycle 326/328 (3 minutes, 23 seconds elapsed) --------------------
# 2022-05-18 18:24:18,748 - [NOTICE] simulation.solve(889): Cycle 326/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:24:18,855 - [NOTICE] simulation.solve(889): Cycle 326/328, step 2/4: Rest for 5 min
# 2022-05-18 18:24:18,891 - [NOTICE] simulation.solve(889): Cycle 326/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:24:18,984 - [NOTICE] simulation.solve(889): Cycle 326/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:24:19,328 - [NOTICE] simulation.solve(977): Capacity is now 3.238 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:24:19,329 - [NOTICE] simulation.solve(855): Cycle 327/328 (3 minutes, 23 seconds elapsed) --------------------
# 2022-05-18 18:24:19,330 - [NOTICE] simulation.solve(889): Cycle 327/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:24:19,500 - [NOTICE] simulation.solve(889): Cycle 327/328, step 2/4: Rest for 5 min
# 2022-05-18 18:24:19,535 - [NOTICE] simulation.solve(889): Cycle 327/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:24:19,628 - [NOTICE] simulation.solve(889): Cycle 327/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:24:19,947 - [NOTICE] simulation.solve(977): Capacity is now 3.232 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:24:19,948 - [NOTICE] simulation.solve(855): Cycle 328/328 (3 minutes, 24 seconds elapsed) --------------------
# 2022-05-18 18:24:19,949 - [NOTICE] simulation.solve(889): Cycle 328/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:24:20,059 - [NOTICE] simulation.solve(889): Cycle 328/328, step 2/4: Rest for 5 min
# 2022-05-18 18:24:20,095 - [NOTICE] simulation.solve(889): Cycle 328/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:24:20,191 - [NOTICE] simulation.solve(889): Cycle 328/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:24:20,528 - [NOTICE] simulation.solve(977): Capacity is now 3.227 Ah (originally 5.032 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:24:20,536 - [NOTICE] simulation.solve(1011): Finish experiment simulation, took 3 minutes, 24 seconds

# %%
parameter_values = get_parameter_values()
parameter_values.update(
    {

        "Positive electrode LAM constant proportional term [s-1]": 8.7864e-07,
        "Negative electrode LAM constant proportional term [s-1]": 1.08031e-05,
        "SEI kinetic rate constant [m.s-1]": 1.6297e-15,
        "EC diffusivity [m2.s-1]": 2e-18,
        "Positive electrode LAM constant exponential term": 2,
        "Negative electrode LAM constant exponential term": 2,
        "Negative electrode active material volume fraction": eps_n_data,
        "Positive electrode active material volume fraction": eps_p_data,
        # "Negative electrode porosity": 0.3,
        # "Positive electrode porosity": 0.3,
        # "Separator porosity": 0.4,
        # "Negative electrode porosity": 0.28,
        # "Positive electrode porosity": 0.28,
        # "Separator porosity": 0.38,
        "Negative electrode porosity": 0.15,
        "Positive electrode porosity": 0.15,
        "Separator porosity": 0.2,
    },
    check_already_exists=False,
)
# all_sumvars_dict = cycle_adaptive_simulation(spm, parameter_values, experiment, save_at_cycles=2)

# %%
sim_long = pybamm.Simulation(spm, experiment=experiment, parameter_values=parameter_values, 
                            solver=pybamm.CasadiSolver("safe"))
sol_long_2 = sim_long.solve(initial_soc=1)
long_sol_output_2 =sol_long_2.summary_variables
# Out:
# 2022-05-18 18:24:24,452 - [NOTICE] simulation.solve(855): Cycle 1/328 (51.984 ms elapsed) --------------------
# 2022-05-18 18:24:24,453 - [NOTICE] simulation.solve(889): Cycle 1/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:24:24,702 - [NOTICE] simulation.solve(889): Cycle 1/328, step 2/4: Rest for 5 min
# 2022-05-18 18:24:24,819 - [NOTICE] simulation.solve(889): Cycle 1/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:24:25,054 - [NOTICE] simulation.solve(889): Cycle 1/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:24:25,864 - [NOTICE] simulation.solve(977): Capacity is now 5.031 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:24:25,865 - [NOTICE] simulation.solve(855): Cycle 2/328 (1.465 s elapsed) --------------------
# 2022-05-18 18:24:25,865 - [NOTICE] simulation.solve(889): Cycle 2/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:24:26,007 - [NOTICE] simulation.solve(889): Cycle 2/328, step 2/4: Rest for 5 min
# 2022-05-18 18:24:26,041 - [NOTICE] simulation.solve(889): Cycle 2/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:24:26,198 - [NOTICE] simulation.solve(889): Cycle 2/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:24:26,483 - [NOTICE] simulation.solve(977): Capacity is now 5.025 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:24:26,484 - [NOTICE] simulation.solve(855): Cycle 3/328 (2.084 s elapsed) --------------------
# 2022-05-18 18:24:26,485 - [NOTICE] simulation.solve(889): Cycle 3/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:24:26,629 - [NOTICE] simulation.solve(889): Cycle 3/328, step 2/4: Rest for 5 min
# 2022-05-18 18:24:26,659 - [NOTICE] simulation.solve(889): Cycle 3/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:24:26,801 - [NOTICE] simulation.solve(889): Cycle 3/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:24:27,090 - [NOTICE] simulation.solve(977): Capacity is now 5.019 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:24:27,091 - [NOTICE] simulation.solve(855): Cycle 4/328 (2.691 s elapsed) --------------------
# 2022-05-18 18:24:27,092 - [NOTICE] simulation.solve(889): Cycle 4/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:24:27,269 - [NOTICE] simulation.solve(889): Cycle 4/328, step 2/4: Rest for 5 min
# 2022-05-18 18:24:27,305 - [NOTICE] simulation.solve(889): Cycle 4/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:24:27,462 - [NOTICE] simulation.solve(889): Cycle 4/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:24:27,781 - [NOTICE] simulation.solve(977): Capacity is now 5.013 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:24:27,782 - [NOTICE] simulation.solve(855): Cycle 5/328 (3.382 s elapsed) --------------------
# 2022-05-18 18:24:27,783 - [NOTICE] simulation.solve(889): Cycle 5/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:24:27,933 - [NOTICE] simulation.solve(889): Cycle 5/328, step 2/4: Rest for 5 min
# 2022-05-18 18:24:27,964 - [NOTICE] simulation.solve(889): Cycle 5/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:24:28,095 - [NOTICE] simulation.solve(889): Cycle 5/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:24:28,384 - [NOTICE] simulation.solve(977): Capacity is now 5.007 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:24:28,385 - [NOTICE] simulation.solve(855): Cycle 6/328 (3.985 s elapsed) --------------------
# 2022-05-18 18:24:28,385 - [NOTICE] simulation.solve(889): Cycle 6/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:24:28,533 - [NOTICE] simulation.solve(889): Cycle 6/328, step 2/4: Rest for 5 min
# 2022-05-18 18:24:28,563 - [NOTICE] simulation.solve(889): Cycle 6/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:24:28,715 - [NOTICE] simulation.solve(889): Cycle 6/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:24:29,000 - [NOTICE] simulation.solve(977): Capacity is now 5.001 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:24:29,000 - [NOTICE] simulation.solve(855): Cycle 7/328 (4.600 s elapsed) --------------------
# 2022-05-18 18:24:29,001 - [NOTICE] simulation.solve(889): Cycle 7/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:24:29,147 - [NOTICE] simulation.solve(889): Cycle 7/328, step 2/4: Rest for 5 min
# 2022-05-18 18:24:29,181 - [NOTICE] simulation.solve(889): Cycle 7/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:24:29,308 - [NOTICE] simulation.solve(889): Cycle 7/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:24:29,614 - [NOTICE] simulation.solve(977): Capacity is now 4.995 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:24:29,615 - [NOTICE] simulation.solve(855): Cycle 8/328 (5.216 s elapsed) --------------------
# 2022-05-18 18:24:29,616 - [NOTICE] simulation.solve(889): Cycle 8/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:24:29,752 - [NOTICE] simulation.solve(889): Cycle 8/328, step 2/4: Rest for 5 min
# 2022-05-18 18:24:29,781 - [NOTICE] simulation.solve(889): Cycle 8/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:24:29,909 - [NOTICE] simulation.solve(889): Cycle 8/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:24:30,193 - [NOTICE] simulation.solve(977): Capacity is now 4.989 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:24:30,193 - [NOTICE] simulation.solve(855): Cycle 9/328 (5.794 s elapsed) --------------------
# 2022-05-18 18:24:30,194 - [NOTICE] simulation.solve(889): Cycle 9/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:24:30,345 - [NOTICE] simulation.solve(889): Cycle 9/328, step 2/4: Rest for 5 min
# 2022-05-18 18:24:30,376 - [NOTICE] simulation.solve(889): Cycle 9/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:24:30,522 - [NOTICE] simulation.solve(889): Cycle 9/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:24:30,814 - [NOTICE] simulation.solve(977): Capacity is now 4.982 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:24:30,815 - [NOTICE] simulation.solve(855): Cycle 10/328 (6.414 s elapsed) --------------------
# 2022-05-18 18:24:30,816 - [NOTICE] simulation.solve(889): Cycle 10/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:24:30,955 - [NOTICE] simulation.solve(889): Cycle 10/328, step 2/4: Rest for 5 min
# 2022-05-18 18:24:30,984 - [NOTICE] simulation.solve(889): Cycle 10/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:24:31,130 - [NOTICE] simulation.solve(889): Cycle 10/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:24:31,441 - [NOTICE] simulation.solve(977): Capacity is now 4.980 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:24:31,442 - [NOTICE] simulation.solve(855): Cycle 11/328 (7.042 s elapsed) --------------------
# 2022-05-18 18:24:31,443 - [NOTICE] simulation.solve(889): Cycle 11/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:24:31,590 - [NOTICE] simulation.solve(889): Cycle 11/328, step 2/4: Rest for 5 min
# 2022-05-18 18:24:31,623 - [NOTICE] simulation.solve(889): Cycle 11/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:24:31,754 - [NOTICE] simulation.solve(889): Cycle 11/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:24:32,051 - [NOTICE] simulation.solve(977): Capacity is now 4.970 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:24:32,051 - [NOTICE] simulation.solve(855): Cycle 12/328 (7.652 s elapsed) --------------------
# 2022-05-18 18:24:32,052 - [NOTICE] simulation.solve(889): Cycle 12/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:24:32,227 - [NOTICE] simulation.solve(889): Cycle 12/328, step 2/4: Rest for 5 min
# 2022-05-18 18:24:32,258 - [NOTICE] simulation.solve(889): Cycle 12/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:24:32,389 - [NOTICE] simulation.solve(889): Cycle 12/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:24:32,691 - [NOTICE] simulation.solve(977): Capacity is now 4.967 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:24:32,691 - [NOTICE] simulation.solve(855): Cycle 13/328 (8.292 s elapsed) --------------------
# 2022-05-18 18:24:32,692 - [NOTICE] simulation.solve(889): Cycle 13/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:24:32,825 - [NOTICE] simulation.solve(889): Cycle 13/328, step 2/4: Rest for 5 min
# 2022-05-18 18:24:32,862 - [NOTICE] simulation.solve(889): Cycle 13/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:24:32,994 - [NOTICE] simulation.solve(889): Cycle 13/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:24:33,277 - [NOTICE] simulation.solve(977): Capacity is now 4.957 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:24:33,278 - [NOTICE] simulation.solve(855): Cycle 14/328 (8.878 s elapsed) --------------------
# 2022-05-18 18:24:33,278 - [NOTICE] simulation.solve(889): Cycle 14/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:24:33,412 - [NOTICE] simulation.solve(889): Cycle 14/328, step 2/4: Rest for 5 min
# 2022-05-18 18:24:33,443 - [NOTICE] simulation.solve(889): Cycle 14/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:24:33,575 - [NOTICE] simulation.solve(889): Cycle 14/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:24:33,880 - [NOTICE] simulation.solve(977): Capacity is now 4.954 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:24:33,880 - [NOTICE] simulation.solve(855): Cycle 15/328 (9.480 s elapsed) --------------------
# 2022-05-18 18:24:33,881 - [NOTICE] simulation.solve(889): Cycle 15/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:24:34,021 - [NOTICE] simulation.solve(889): Cycle 15/328, step 2/4: Rest for 5 min
# 2022-05-18 18:24:34,051 - [NOTICE] simulation.solve(889): Cycle 15/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:24:34,174 - [NOTICE] simulation.solve(889): Cycle 15/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:24:34,455 - [NOTICE] simulation.solve(977): Capacity is now 4.944 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:24:34,456 - [NOTICE] simulation.solve(855): Cycle 16/328 (10.057 s elapsed) --------------------
# 2022-05-18 18:24:34,456 - [NOTICE] simulation.solve(889): Cycle 16/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:24:34,603 - [NOTICE] simulation.solve(889): Cycle 16/328, step 2/4: Rest for 5 min
# 2022-05-18 18:24:34,633 - [NOTICE] simulation.solve(889): Cycle 16/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:24:34,769 - [NOTICE] simulation.solve(889): Cycle 16/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:24:35,078 - [NOTICE] simulation.solve(977): Capacity is now 4.938 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:24:35,078 - [NOTICE] simulation.solve(855): Cycle 17/328 (10.679 s elapsed) --------------------
# 2022-05-18 18:24:35,079 - [NOTICE] simulation.solve(889): Cycle 17/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:24:35,255 - [NOTICE] simulation.solve(889): Cycle 17/328, step 2/4: Rest for 5 min
# 2022-05-18 18:24:35,292 - [NOTICE] simulation.solve(889): Cycle 17/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:24:35,462 - [NOTICE] simulation.solve(889): Cycle 17/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:24:35,743 - [NOTICE] simulation.solve(977): Capacity is now 4.934 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:24:35,744 - [NOTICE] simulation.solve(855): Cycle 18/328 (11.344 s elapsed) --------------------
# 2022-05-18 18:24:35,745 - [NOTICE] simulation.solve(889): Cycle 18/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:24:35,893 - [NOTICE] simulation.solve(889): Cycle 18/328, step 2/4: Rest for 5 min
# 2022-05-18 18:24:35,923 - [NOTICE] simulation.solve(889): Cycle 18/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:24:36,060 - [NOTICE] simulation.solve(889): Cycle 18/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:24:36,363 - [NOTICE] simulation.solve(977): Capacity is now 4.925 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:24:36,363 - [NOTICE] simulation.solve(855): Cycle 19/328 (11.963 s elapsed) --------------------
# 2022-05-18 18:24:36,364 - [NOTICE] simulation.solve(889): Cycle 19/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:24:36,518 - [NOTICE] simulation.solve(889): Cycle 19/328, step 2/4: Rest for 5 min
# 2022-05-18 18:24:36,550 - [NOTICE] simulation.solve(889): Cycle 19/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:24:36,688 - [NOTICE] simulation.solve(889): Cycle 19/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:24:36,963 - [NOTICE] simulation.solve(977): Capacity is now 4.921 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:24:36,964 - [NOTICE] simulation.solve(855): Cycle 20/328 (12.564 s elapsed) --------------------
# 2022-05-18 18:24:36,965 - [NOTICE] simulation.solve(889): Cycle 20/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:24:37,104 - [NOTICE] simulation.solve(889): Cycle 20/328, step 2/4: Rest for 5 min
# 2022-05-18 18:24:37,139 - [NOTICE] simulation.solve(889): Cycle 20/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:24:37,293 - [NOTICE] simulation.solve(889): Cycle 20/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:24:37,606 - [NOTICE] simulation.solve(977): Capacity is now 4.914 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:24:37,606 - [NOTICE] simulation.solve(855): Cycle 21/328 (13.207 s elapsed) --------------------
# 2022-05-18 18:24:37,607 - [NOTICE] simulation.solve(889): Cycle 21/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:24:37,749 - [NOTICE] simulation.solve(889): Cycle 21/328, step 2/4: Rest for 5 min
# 2022-05-18 18:24:37,782 - [NOTICE] simulation.solve(889): Cycle 21/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:24:37,984 - [NOTICE] simulation.solve(889): Cycle 21/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:24:38,409 - [NOTICE] simulation.solve(977): Capacity is now 4.907 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:24:38,410 - [NOTICE] simulation.solve(855): Cycle 22/328 (14.010 s elapsed) --------------------
# 2022-05-18 18:24:38,411 - [NOTICE] simulation.solve(889): Cycle 22/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:24:38,551 - [NOTICE] simulation.solve(889): Cycle 22/328, step 2/4: Rest for 5 min
# 2022-05-18 18:24:38,583 - [NOTICE] simulation.solve(889): Cycle 22/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:24:38,754 - [NOTICE] simulation.solve(889): Cycle 22/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:24:39,045 - [NOTICE] simulation.solve(977): Capacity is now 4.901 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:24:39,046 - [NOTICE] simulation.solve(855): Cycle 23/328 (14.646 s elapsed) --------------------
# 2022-05-18 18:24:39,046 - [NOTICE] simulation.solve(889): Cycle 23/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:24:39,196 - [NOTICE] simulation.solve(889): Cycle 23/328, step 2/4: Rest for 5 min
# 2022-05-18 18:24:39,233 - [NOTICE] simulation.solve(889): Cycle 23/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:24:39,428 - [NOTICE] simulation.solve(889): Cycle 23/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:24:39,888 - [NOTICE] simulation.solve(977): Capacity is now 4.894 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:24:39,889 - [NOTICE] simulation.solve(855): Cycle 24/328 (15.489 s elapsed) --------------------
# 2022-05-18 18:24:39,889 - [NOTICE] simulation.solve(889): Cycle 24/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:24:40,083 - [NOTICE] simulation.solve(889): Cycle 24/328, step 2/4: Rest for 5 min
# 2022-05-18 18:24:40,133 - [NOTICE] simulation.solve(889): Cycle 24/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:24:40,309 - [NOTICE] simulation.solve(889): Cycle 24/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:24:40,701 - [NOTICE] simulation.solve(977): Capacity is now 4.888 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:24:40,702 - [NOTICE] simulation.solve(855): Cycle 25/328 (16.301 s elapsed) --------------------
# 2022-05-18 18:24:40,702 - [NOTICE] simulation.solve(889): Cycle 25/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:24:40,863 - [NOTICE] simulation.solve(889): Cycle 25/328, step 2/4: Rest for 5 min
# 2022-05-18 18:24:40,892 - [NOTICE] simulation.solve(889): Cycle 25/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:24:41,036 - [NOTICE] simulation.solve(889): Cycle 25/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:24:41,355 - [NOTICE] simulation.solve(977): Capacity is now 4.881 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:24:41,355 - [NOTICE] simulation.solve(855): Cycle 26/328 (16.955 s elapsed) --------------------
# 2022-05-18 18:24:41,356 - [NOTICE] simulation.solve(889): Cycle 26/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:24:41,531 - [NOTICE] simulation.solve(889): Cycle 26/328, step 2/4: Rest for 5 min
# 2022-05-18 18:24:41,565 - [NOTICE] simulation.solve(889): Cycle 26/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:24:41,730 - [NOTICE] simulation.solve(889): Cycle 26/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:24:42,047 - [NOTICE] simulation.solve(977): Capacity is now 4.875 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:24:42,048 - [NOTICE] simulation.solve(855): Cycle 27/328 (17.648 s elapsed) --------------------
# 2022-05-18 18:24:42,048 - [NOTICE] simulation.solve(889): Cycle 27/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:24:42,238 - [NOTICE] simulation.solve(889): Cycle 27/328, step 2/4: Rest for 5 min
# 2022-05-18 18:24:42,274 - [NOTICE] simulation.solve(889): Cycle 27/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:24:42,425 - [NOTICE] simulation.solve(889): Cycle 27/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:24:42,728 - [NOTICE] simulation.solve(977): Capacity is now 4.868 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:24:42,729 - [NOTICE] simulation.solve(855): Cycle 28/328 (18.329 s elapsed) --------------------
# 2022-05-18 18:24:42,729 - [NOTICE] simulation.solve(889): Cycle 28/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:24:42,945 - [NOTICE] simulation.solve(889): Cycle 28/328, step 2/4: Rest for 5 min
# 2022-05-18 18:24:42,994 - [NOTICE] simulation.solve(889): Cycle 28/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:24:43,145 - [NOTICE] simulation.solve(889): Cycle 28/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:24:43,432 - [NOTICE] simulation.solve(977): Capacity is now 4.862 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:24:43,433 - [NOTICE] simulation.solve(855): Cycle 29/328 (19.033 s elapsed) --------------------
# 2022-05-18 18:24:43,433 - [NOTICE] simulation.solve(889): Cycle 29/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:24:43,587 - [NOTICE] simulation.solve(889): Cycle 29/328, step 2/4: Rest for 5 min
# 2022-05-18 18:24:43,623 - [NOTICE] simulation.solve(889): Cycle 29/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:24:43,832 - [NOTICE] simulation.solve(889): Cycle 29/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:24:44,177 - [NOTICE] simulation.solve(977): Capacity is now 4.856 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:24:44,178 - [NOTICE] simulation.solve(855): Cycle 30/328 (19.778 s elapsed) --------------------
# 2022-05-18 18:24:44,179 - [NOTICE] simulation.solve(889): Cycle 30/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:24:44,327 - [NOTICE] simulation.solve(889): Cycle 30/328, step 2/4: Rest for 5 min
# 2022-05-18 18:24:44,369 - [NOTICE] simulation.solve(889): Cycle 30/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:24:44,566 - [NOTICE] simulation.solve(889): Cycle 30/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:24:45,048 - [NOTICE] simulation.solve(977): Capacity is now 4.849 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:24:45,049 - [NOTICE] simulation.solve(855): Cycle 31/328 (20.649 s elapsed) --------------------
# 2022-05-18 18:24:45,049 - [NOTICE] simulation.solve(889): Cycle 31/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:24:45,212 - [NOTICE] simulation.solve(889): Cycle 31/328, step 2/4: Rest for 5 min
# 2022-05-18 18:24:45,243 - [NOTICE] simulation.solve(889): Cycle 31/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:24:45,384 - [NOTICE] simulation.solve(889): Cycle 31/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:24:45,790 - [NOTICE] simulation.solve(977): Capacity is now 4.843 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:24:45,792 - [NOTICE] simulation.solve(855): Cycle 32/328 (21.392 s elapsed) --------------------
# 2022-05-18 18:24:45,792 - [NOTICE] simulation.solve(889): Cycle 32/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:24:45,939 - [NOTICE] simulation.solve(889): Cycle 32/328, step 2/4: Rest for 5 min
# 2022-05-18 18:24:45,976 - [NOTICE] simulation.solve(889): Cycle 32/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:24:46,123 - [NOTICE] simulation.solve(889): Cycle 32/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:24:46,480 - [NOTICE] simulation.solve(977): Capacity is now 4.836 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:24:46,481 - [NOTICE] simulation.solve(855): Cycle 33/328 (22.080 s elapsed) --------------------
# 2022-05-18 18:24:46,481 - [NOTICE] simulation.solve(889): Cycle 33/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:24:46,619 - [NOTICE] simulation.solve(889): Cycle 33/328, step 2/4: Rest for 5 min
# 2022-05-18 18:24:46,651 - [NOTICE] simulation.solve(889): Cycle 33/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:24:46,775 - [NOTICE] simulation.solve(889): Cycle 33/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:24:47,062 - [NOTICE] simulation.solve(977): Capacity is now 4.830 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:24:47,063 - [NOTICE] simulation.solve(855): Cycle 34/328 (22.663 s elapsed) --------------------
# 2022-05-18 18:24:47,064 - [NOTICE] simulation.solve(889): Cycle 34/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:24:47,240 - [NOTICE] simulation.solve(889): Cycle 34/328, step 2/4: Rest for 5 min
# 2022-05-18 18:24:47,276 - [NOTICE] simulation.solve(889): Cycle 34/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:24:47,480 - [NOTICE] simulation.solve(889): Cycle 34/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:24:47,779 - [NOTICE] simulation.solve(977): Capacity is now 4.824 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:24:47,780 - [NOTICE] simulation.solve(855): Cycle 35/328 (23.380 s elapsed) --------------------
# 2022-05-18 18:24:47,781 - [NOTICE] simulation.solve(889): Cycle 35/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:24:47,949 - [NOTICE] simulation.solve(889): Cycle 35/328, step 2/4: Rest for 5 min
# 2022-05-18 18:24:47,987 - [NOTICE] simulation.solve(889): Cycle 35/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:24:48,134 - [NOTICE] simulation.solve(889): Cycle 35/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:24:48,442 - [NOTICE] simulation.solve(977): Capacity is now 4.817 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:24:48,443 - [NOTICE] simulation.solve(855): Cycle 36/328 (24.043 s elapsed) --------------------
# 2022-05-18 18:24:48,444 - [NOTICE] simulation.solve(889): Cycle 36/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:24:48,592 - [NOTICE] simulation.solve(889): Cycle 36/328, step 2/4: Rest for 5 min
# 2022-05-18 18:24:48,622 - [NOTICE] simulation.solve(889): Cycle 36/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:24:48,739 - [NOTICE] simulation.solve(889): Cycle 36/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:24:49,035 - [NOTICE] simulation.solve(977): Capacity is now 4.811 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:24:49,036 - [NOTICE] simulation.solve(855): Cycle 37/328 (24.636 s elapsed) --------------------
# 2022-05-18 18:24:49,036 - [NOTICE] simulation.solve(889): Cycle 37/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:24:49,178 - [NOTICE] simulation.solve(889): Cycle 37/328, step 2/4: Rest for 5 min
# 2022-05-18 18:24:49,212 - [NOTICE] simulation.solve(889): Cycle 37/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:24:49,333 - [NOTICE] simulation.solve(889): Cycle 37/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:24:49,660 - [NOTICE] simulation.solve(977): Capacity is now 4.804 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:24:49,661 - [NOTICE] simulation.solve(855): Cycle 38/328 (25.261 s elapsed) --------------------
# 2022-05-18 18:24:49,661 - [NOTICE] simulation.solve(889): Cycle 38/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:24:49,819 - [NOTICE] simulation.solve(889): Cycle 38/328, step 2/4: Rest for 5 min
# 2022-05-18 18:24:49,850 - [NOTICE] simulation.solve(889): Cycle 38/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:24:50,012 - [NOTICE] simulation.solve(889): Cycle 38/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:24:50,335 - [NOTICE] simulation.solve(977): Capacity is now 4.798 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:24:50,336 - [NOTICE] simulation.solve(855): Cycle 39/328 (25.936 s elapsed) --------------------
# 2022-05-18 18:24:50,336 - [NOTICE] simulation.solve(889): Cycle 39/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:24:50,522 - [NOTICE] simulation.solve(889): Cycle 39/328, step 2/4: Rest for 5 min
# 2022-05-18 18:24:50,558 - [NOTICE] simulation.solve(889): Cycle 39/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:24:50,698 - [NOTICE] simulation.solve(889): Cycle 39/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:24:51,079 - [NOTICE] simulation.solve(977): Capacity is now 4.792 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:24:51,080 - [NOTICE] simulation.solve(855): Cycle 40/328 (26.681 s elapsed) --------------------
# 2022-05-18 18:24:51,081 - [NOTICE] simulation.solve(889): Cycle 40/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:24:51,270 - [NOTICE] simulation.solve(889): Cycle 40/328, step 2/4: Rest for 5 min
# 2022-05-18 18:24:51,315 - [NOTICE] simulation.solve(889): Cycle 40/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:24:51,463 - [NOTICE] simulation.solve(889): Cycle 40/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:24:51,788 - [NOTICE] simulation.solve(977): Capacity is now 4.785 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:24:51,788 - [NOTICE] simulation.solve(855): Cycle 41/328 (27.388 s elapsed) --------------------
# 2022-05-18 18:24:51,789 - [NOTICE] simulation.solve(889): Cycle 41/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:24:51,985 - [NOTICE] simulation.solve(889): Cycle 41/328, step 2/4: Rest for 5 min
# 2022-05-18 18:24:52,024 - [NOTICE] simulation.solve(889): Cycle 41/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:24:52,231 - [NOTICE] simulation.solve(889): Cycle 41/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:24:52,539 - [NOTICE] simulation.solve(977): Capacity is now 4.779 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:24:52,539 - [NOTICE] simulation.solve(855): Cycle 42/328 (28.140 s elapsed) --------------------
# 2022-05-18 18:24:52,540 - [NOTICE] simulation.solve(889): Cycle 42/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:24:52,685 - [NOTICE] simulation.solve(889): Cycle 42/328, step 2/4: Rest for 5 min
# 2022-05-18 18:24:52,716 - [NOTICE] simulation.solve(889): Cycle 42/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:24:52,829 - [NOTICE] simulation.solve(889): Cycle 42/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:24:53,156 - [NOTICE] simulation.solve(977): Capacity is now 4.773 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:24:53,157 - [NOTICE] simulation.solve(855): Cycle 43/328 (28.758 s elapsed) --------------------
# 2022-05-18 18:24:53,158 - [NOTICE] simulation.solve(889): Cycle 43/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:24:53,315 - [NOTICE] simulation.solve(889): Cycle 43/328, step 2/4: Rest for 5 min
# 2022-05-18 18:24:53,349 - [NOTICE] simulation.solve(889): Cycle 43/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:24:53,482 - [NOTICE] simulation.solve(889): Cycle 43/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:24:53,768 - [NOTICE] simulation.solve(977): Capacity is now 4.766 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:24:53,768 - [NOTICE] simulation.solve(855): Cycle 44/328 (29.368 s elapsed) --------------------
# 2022-05-18 18:24:53,769 - [NOTICE] simulation.solve(889): Cycle 44/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:24:53,913 - [NOTICE] simulation.solve(889): Cycle 44/328, step 2/4: Rest for 5 min
# 2022-05-18 18:24:53,947 - [NOTICE] simulation.solve(889): Cycle 44/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:24:54,080 - [NOTICE] simulation.solve(889): Cycle 44/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:24:54,418 - [NOTICE] simulation.solve(977): Capacity is now 4.760 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:24:54,419 - [NOTICE] simulation.solve(855): Cycle 45/328 (30.019 s elapsed) --------------------
# 2022-05-18 18:24:54,419 - [NOTICE] simulation.solve(889): Cycle 45/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:24:54,557 - [NOTICE] simulation.solve(889): Cycle 45/328, step 2/4: Rest for 5 min
# 2022-05-18 18:24:54,586 - [NOTICE] simulation.solve(889): Cycle 45/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:24:54,732 - [NOTICE] simulation.solve(889): Cycle 45/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:24:55,067 - [NOTICE] simulation.solve(977): Capacity is now 4.754 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:24:55,068 - [NOTICE] simulation.solve(855): Cycle 46/328 (30.668 s elapsed) --------------------
# 2022-05-18 18:24:55,068 - [NOTICE] simulation.solve(889): Cycle 46/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:24:55,252 - [NOTICE] simulation.solve(889): Cycle 46/328, step 2/4: Rest for 5 min
# 2022-05-18 18:24:55,302 - [NOTICE] simulation.solve(889): Cycle 46/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:24:55,441 - [NOTICE] simulation.solve(889): Cycle 46/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:24:55,767 - [NOTICE] simulation.solve(977): Capacity is now 4.747 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:24:55,768 - [NOTICE] simulation.solve(855): Cycle 47/328 (31.367 s elapsed) --------------------
# 2022-05-18 18:24:55,769 - [NOTICE] simulation.solve(889): Cycle 47/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:24:55,922 - [NOTICE] simulation.solve(889): Cycle 47/328, step 2/4: Rest for 5 min
# 2022-05-18 18:24:55,952 - [NOTICE] simulation.solve(889): Cycle 47/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:24:56,090 - [NOTICE] simulation.solve(889): Cycle 47/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:24:56,461 - [NOTICE] simulation.solve(977): Capacity is now 4.741 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:24:56,462 - [NOTICE] simulation.solve(855): Cycle 48/328 (32.061 s elapsed) --------------------
# 2022-05-18 18:24:56,462 - [NOTICE] simulation.solve(889): Cycle 48/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:24:56,612 - [NOTICE] simulation.solve(889): Cycle 48/328, step 2/4: Rest for 5 min
# 2022-05-18 18:24:56,648 - [NOTICE] simulation.solve(889): Cycle 48/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:24:56,791 - [NOTICE] simulation.solve(889): Cycle 48/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:24:57,125 - [NOTICE] simulation.solve(977): Capacity is now 4.735 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:24:57,126 - [NOTICE] simulation.solve(855): Cycle 49/328 (32.726 s elapsed) --------------------
# 2022-05-18 18:24:57,127 - [NOTICE] simulation.solve(889): Cycle 49/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:24:57,293 - [NOTICE] simulation.solve(889): Cycle 49/328, step 2/4: Rest for 5 min
# 2022-05-18 18:24:57,337 - [NOTICE] simulation.solve(889): Cycle 49/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:24:57,489 - [NOTICE] simulation.solve(889): Cycle 49/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:24:57,872 - [NOTICE] simulation.solve(977): Capacity is now 4.728 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:24:57,873 - [NOTICE] simulation.solve(855): Cycle 50/328 (33.473 s elapsed) --------------------
# 2022-05-18 18:24:57,873 - [NOTICE] simulation.solve(889): Cycle 50/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:24:58,023 - [NOTICE] simulation.solve(889): Cycle 50/328, step 2/4: Rest for 5 min
# 2022-05-18 18:24:58,054 - [NOTICE] simulation.solve(889): Cycle 50/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:24:58,193 - [NOTICE] simulation.solve(889): Cycle 50/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:24:58,548 - [NOTICE] simulation.solve(977): Capacity is now 4.722 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:24:58,549 - [NOTICE] simulation.solve(855): Cycle 51/328 (34.149 s elapsed) --------------------
# 2022-05-18 18:24:58,550 - [NOTICE] simulation.solve(889): Cycle 51/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:24:58,708 - [NOTICE] simulation.solve(889): Cycle 51/328, step 2/4: Rest for 5 min
# 2022-05-18 18:24:58,741 - [NOTICE] simulation.solve(889): Cycle 51/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:24:58,901 - [NOTICE] simulation.solve(889): Cycle 51/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:24:59,238 - [NOTICE] simulation.solve(977): Capacity is now 4.716 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:24:59,239 - [NOTICE] simulation.solve(855): Cycle 52/328 (34.839 s elapsed) --------------------
# 2022-05-18 18:24:59,240 - [NOTICE] simulation.solve(889): Cycle 52/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:24:59,376 - [NOTICE] simulation.solve(889): Cycle 52/328, step 2/4: Rest for 5 min
# 2022-05-18 18:24:59,412 - [NOTICE] simulation.solve(889): Cycle 52/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:24:59,625 - [NOTICE] simulation.solve(889): Cycle 52/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:24:59,991 - [NOTICE] simulation.solve(977): Capacity is now 4.710 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:24:59,992 - [NOTICE] simulation.solve(855): Cycle 53/328 (35.592 s elapsed) --------------------
# 2022-05-18 18:24:59,992 - [NOTICE] simulation.solve(889): Cycle 53/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:25:00,141 - [NOTICE] simulation.solve(889): Cycle 53/328, step 2/4: Rest for 5 min
# 2022-05-18 18:25:00,171 - [NOTICE] simulation.solve(889): Cycle 53/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:25:00,305 - [NOTICE] simulation.solve(889): Cycle 53/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:25:00,648 - [NOTICE] simulation.solve(977): Capacity is now 4.703 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:25:00,648 - [NOTICE] simulation.solve(855): Cycle 54/328 (36.248 s elapsed) --------------------
# 2022-05-18 18:25:00,649 - [NOTICE] simulation.solve(889): Cycle 54/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:25:00,801 - [NOTICE] simulation.solve(889): Cycle 54/328, step 2/4: Rest for 5 min
# 2022-05-18 18:25:00,832 - [NOTICE] simulation.solve(889): Cycle 54/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:25:00,976 - [NOTICE] simulation.solve(889): Cycle 54/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:25:01,319 - [NOTICE] simulation.solve(977): Capacity is now 4.697 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:25:01,319 - [NOTICE] simulation.solve(855): Cycle 55/328 (36.919 s elapsed) --------------------
# 2022-05-18 18:25:01,320 - [NOTICE] simulation.solve(889): Cycle 55/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:25:01,463 - [NOTICE] simulation.solve(889): Cycle 55/328, step 2/4: Rest for 5 min
# 2022-05-18 18:25:01,498 - [NOTICE] simulation.solve(889): Cycle 55/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:25:01,694 - [NOTICE] simulation.solve(889): Cycle 55/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:25:02,026 - [NOTICE] simulation.solve(977): Capacity is now 4.691 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:25:02,027 - [NOTICE] simulation.solve(855): Cycle 56/328 (37.627 s elapsed) --------------------
# 2022-05-18 18:25:02,028 - [NOTICE] simulation.solve(889): Cycle 56/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:25:02,185 - [NOTICE] simulation.solve(889): Cycle 56/328, step 2/4: Rest for 5 min
# 2022-05-18 18:25:02,224 - [NOTICE] simulation.solve(889): Cycle 56/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:25:02,373 - [NOTICE] simulation.solve(889): Cycle 56/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:25:02,737 - [NOTICE] simulation.solve(977): Capacity is now 4.685 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:25:02,738 - [NOTICE] simulation.solve(855): Cycle 57/328 (38.338 s elapsed) --------------------
# 2022-05-18 18:25:02,738 - [NOTICE] simulation.solve(889): Cycle 57/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:25:02,962 - [NOTICE] simulation.solve(889): Cycle 57/328, step 2/4: Rest for 5 min
# 2022-05-18 18:25:02,999 - [NOTICE] simulation.solve(889): Cycle 57/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:25:03,186 - [NOTICE] simulation.solve(889): Cycle 57/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:25:03,549 - [NOTICE] simulation.solve(977): Capacity is now 4.678 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:25:03,549 - [NOTICE] simulation.solve(855): Cycle 58/328 (39.149 s elapsed) --------------------
# 2022-05-18 18:25:03,550 - [NOTICE] simulation.solve(889): Cycle 58/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:25:03,687 - [NOTICE] simulation.solve(889): Cycle 58/328, step 2/4: Rest for 5 min
# 2022-05-18 18:25:03,721 - [NOTICE] simulation.solve(889): Cycle 58/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:25:03,874 - [NOTICE] simulation.solve(889): Cycle 58/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:25:04,232 - [NOTICE] simulation.solve(977): Capacity is now 4.672 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:25:04,233 - [NOTICE] simulation.solve(855): Cycle 59/328 (39.833 s elapsed) --------------------
# 2022-05-18 18:25:04,233 - [NOTICE] simulation.solve(889): Cycle 59/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:25:04,373 - [NOTICE] simulation.solve(889): Cycle 59/328, step 2/4: Rest for 5 min
# 2022-05-18 18:25:04,410 - [NOTICE] simulation.solve(889): Cycle 59/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:25:04,547 - [NOTICE] simulation.solve(889): Cycle 59/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:25:04,868 - [NOTICE] simulation.solve(977): Capacity is now 4.666 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:25:04,869 - [NOTICE] simulation.solve(855): Cycle 60/328 (40.470 s elapsed) --------------------
# 2022-05-18 18:25:04,870 - [NOTICE] simulation.solve(889): Cycle 60/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:25:05,020 - [NOTICE] simulation.solve(889): Cycle 60/328, step 2/4: Rest for 5 min
# 2022-05-18 18:25:05,055 - [NOTICE] simulation.solve(889): Cycle 60/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:25:05,200 - [NOTICE] simulation.solve(889): Cycle 60/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:25:05,517 - [NOTICE] simulation.solve(977): Capacity is now 4.660 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:25:05,518 - [NOTICE] simulation.solve(855): Cycle 61/328 (41.119 s elapsed) --------------------
# 2022-05-18 18:25:05,519 - [NOTICE] simulation.solve(889): Cycle 61/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:25:05,683 - [NOTICE] simulation.solve(889): Cycle 61/328, step 2/4: Rest for 5 min
# 2022-05-18 18:25:05,716 - [NOTICE] simulation.solve(889): Cycle 61/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:25:05,860 - [NOTICE] simulation.solve(889): Cycle 61/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:25:06,215 - [NOTICE] simulation.solve(977): Capacity is now 4.653 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:25:06,216 - [NOTICE] simulation.solve(855): Cycle 62/328 (41.816 s elapsed) --------------------
# 2022-05-18 18:25:06,216 - [NOTICE] simulation.solve(889): Cycle 62/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:25:06,383 - [NOTICE] simulation.solve(889): Cycle 62/328, step 2/4: Rest for 5 min
# 2022-05-18 18:25:06,415 - [NOTICE] simulation.solve(889): Cycle 62/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:25:06,578 - [NOTICE] simulation.solve(889): Cycle 62/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:25:06,918 - [NOTICE] simulation.solve(977): Capacity is now 4.647 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:25:06,918 - [NOTICE] simulation.solve(855): Cycle 63/328 (42.519 s elapsed) --------------------
# 2022-05-18 18:25:06,919 - [NOTICE] simulation.solve(889): Cycle 63/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:25:07,056 - [NOTICE] simulation.solve(889): Cycle 63/328, step 2/4: Rest for 5 min
# 2022-05-18 18:25:07,092 - [NOTICE] simulation.solve(889): Cycle 63/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:25:07,233 - [NOTICE] simulation.solve(889): Cycle 63/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:25:07,570 - [NOTICE] simulation.solve(977): Capacity is now 4.641 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:25:07,570 - [NOTICE] simulation.solve(855): Cycle 64/328 (43.171 s elapsed) --------------------
# 2022-05-18 18:25:07,571 - [NOTICE] simulation.solve(889): Cycle 64/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:25:07,720 - [NOTICE] simulation.solve(889): Cycle 64/328, step 2/4: Rest for 5 min
# 2022-05-18 18:25:07,750 - [NOTICE] simulation.solve(889): Cycle 64/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:25:07,892 - [NOTICE] simulation.solve(889): Cycle 64/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:25:08,213 - [NOTICE] simulation.solve(977): Capacity is now 4.635 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:25:08,214 - [NOTICE] simulation.solve(855): Cycle 65/328 (43.814 s elapsed) --------------------
# 2022-05-18 18:25:08,214 - [NOTICE] simulation.solve(889): Cycle 65/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:25:08,370 - [NOTICE] simulation.solve(889): Cycle 65/328, step 2/4: Rest for 5 min
# 2022-05-18 18:25:08,409 - [NOTICE] simulation.solve(889): Cycle 65/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:25:08,550 - [NOTICE] simulation.solve(889): Cycle 65/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:25:08,890 - [NOTICE] simulation.solve(977): Capacity is now 4.629 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:25:08,891 - [NOTICE] simulation.solve(855): Cycle 66/328 (44.492 s elapsed) --------------------
# 2022-05-18 18:25:08,892 - [NOTICE] simulation.solve(889): Cycle 66/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:25:09,057 - [NOTICE] simulation.solve(889): Cycle 66/328, step 2/4: Rest for 5 min
# 2022-05-18 18:25:09,091 - [NOTICE] simulation.solve(889): Cycle 66/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:25:09,231 - [NOTICE] simulation.solve(889): Cycle 66/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:25:09,557 - [NOTICE] simulation.solve(977): Capacity is now 4.623 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:25:09,557 - [NOTICE] simulation.solve(855): Cycle 67/328 (45.157 s elapsed) --------------------
# 2022-05-18 18:25:09,558 - [NOTICE] simulation.solve(889): Cycle 67/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:25:09,699 - [NOTICE] simulation.solve(889): Cycle 67/328, step 2/4: Rest for 5 min
# 2022-05-18 18:25:09,731 - [NOTICE] simulation.solve(889): Cycle 67/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:25:09,874 - [NOTICE] simulation.solve(889): Cycle 67/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:25:10,234 - [NOTICE] simulation.solve(977): Capacity is now 4.616 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:25:10,234 - [NOTICE] simulation.solve(855): Cycle 68/328 (45.834 s elapsed) --------------------
# 2022-05-18 18:25:10,235 - [NOTICE] simulation.solve(889): Cycle 68/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:25:10,403 - [NOTICE] simulation.solve(889): Cycle 68/328, step 2/4: Rest for 5 min
# 2022-05-18 18:25:10,441 - [NOTICE] simulation.solve(889): Cycle 68/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:25:10,618 - [NOTICE] simulation.solve(889): Cycle 68/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:25:10,951 - [NOTICE] simulation.solve(977): Capacity is now 4.610 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:25:10,951 - [NOTICE] simulation.solve(855): Cycle 69/328 (46.552 s elapsed) --------------------
# 2022-05-18 18:25:10,952 - [NOTICE] simulation.solve(889): Cycle 69/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:25:11,098 - [NOTICE] simulation.solve(889): Cycle 69/328, step 2/4: Rest for 5 min
# 2022-05-18 18:25:11,135 - [NOTICE] simulation.solve(889): Cycle 69/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:25:11,298 - [NOTICE] simulation.solve(889): Cycle 69/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:25:11,646 - [NOTICE] simulation.solve(977): Capacity is now 4.604 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:25:11,646 - [NOTICE] simulation.solve(855): Cycle 70/328 (47.247 s elapsed) --------------------
# 2022-05-18 18:25:11,647 - [NOTICE] simulation.solve(889): Cycle 70/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:25:11,805 - [NOTICE] simulation.solve(889): Cycle 70/328, step 2/4: Rest for 5 min
# 2022-05-18 18:25:11,836 - [NOTICE] simulation.solve(889): Cycle 70/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:25:11,980 - [NOTICE] simulation.solve(889): Cycle 70/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:25:12,299 - [NOTICE] simulation.solve(977): Capacity is now 4.598 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:25:12,300 - [NOTICE] simulation.solve(855): Cycle 71/328 (47.900 s elapsed) --------------------
# 2022-05-18 18:25:12,300 - [NOTICE] simulation.solve(889): Cycle 71/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:25:12,453 - [NOTICE] simulation.solve(889): Cycle 71/328, step 2/4: Rest for 5 min
# 2022-05-18 18:25:12,490 - [NOTICE] simulation.solve(889): Cycle 71/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:25:12,610 - [NOTICE] simulation.solve(889): Cycle 71/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:25:12,931 - [NOTICE] simulation.solve(977): Capacity is now 4.592 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:25:12,932 - [NOTICE] simulation.solve(855): Cycle 72/328 (48.532 s elapsed) --------------------
# 2022-05-18 18:25:12,933 - [NOTICE] simulation.solve(889): Cycle 72/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:25:13,071 - [NOTICE] simulation.solve(889): Cycle 72/328, step 2/4: Rest for 5 min
# 2022-05-18 18:25:13,112 - [NOTICE] simulation.solve(889): Cycle 72/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:25:13,232 - [NOTICE] simulation.solve(889): Cycle 72/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:25:13,579 - [NOTICE] simulation.solve(977): Capacity is now 4.586 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:25:13,580 - [NOTICE] simulation.solve(855): Cycle 73/328 (49.181 s elapsed) --------------------
# 2022-05-18 18:25:13,581 - [NOTICE] simulation.solve(889): Cycle 73/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:25:13,726 - [NOTICE] simulation.solve(889): Cycle 73/328, step 2/4: Rest for 5 min
# 2022-05-18 18:25:13,764 - [NOTICE] simulation.solve(889): Cycle 73/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:25:13,894 - [NOTICE] simulation.solve(889): Cycle 73/328, step 4/4: Hold at 4.2V until C/50
# ...
# 2022-05-18 18:27:50,578 - [NOTICE] simulation.solve(889): Cycle 305/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:27:51,048 - [NOTICE] simulation.solve(977): Capacity is now 3.306 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:27:51,048 - [NOTICE] simulation.solve(855): Cycle 306/328 (3 minutes, 27 seconds elapsed) --------------------
# 2022-05-18 18:27:51,049 - [NOTICE] simulation.solve(889): Cycle 306/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:27:51,179 - [NOTICE] simulation.solve(889): Cycle 306/328, step 2/4: Rest for 5 min
# 2022-05-18 18:27:51,217 - [NOTICE] simulation.solve(889): Cycle 306/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:27:51,319 - [NOTICE] simulation.solve(889): Cycle 306/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:27:51,695 - [NOTICE] simulation.solve(977): Capacity is now 3.301 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:27:51,695 - [NOTICE] simulation.solve(855): Cycle 307/328 (3 minutes, 27 seconds elapsed) --------------------
# 2022-05-18 18:27:51,696 - [NOTICE] simulation.solve(889): Cycle 307/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:27:51,856 - [NOTICE] simulation.solve(889): Cycle 307/328, step 2/4: Rest for 5 min
# 2022-05-18 18:27:51,906 - [NOTICE] simulation.solve(889): Cycle 307/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:27:52,008 - [NOTICE] simulation.solve(889): Cycle 307/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:27:52,418 - [NOTICE] simulation.solve(977): Capacity is now 3.296 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:27:52,419 - [NOTICE] simulation.solve(855): Cycle 308/328 (3 minutes, 28 seconds elapsed) --------------------
# 2022-05-18 18:27:52,420 - [NOTICE] simulation.solve(889): Cycle 308/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:27:52,558 - [NOTICE] simulation.solve(889): Cycle 308/328, step 2/4: Rest for 5 min
# 2022-05-18 18:27:52,594 - [NOTICE] simulation.solve(889): Cycle 308/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:27:52,727 - [NOTICE] simulation.solve(889): Cycle 308/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:27:53,185 - [NOTICE] simulation.solve(977): Capacity is now 3.290 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:27:53,185 - [NOTICE] simulation.solve(855): Cycle 309/328 (3 minutes, 29 seconds elapsed) --------------------
# 2022-05-18 18:27:53,186 - [NOTICE] simulation.solve(889): Cycle 309/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:27:53,303 - [NOTICE] simulation.solve(889): Cycle 309/328, step 2/4: Rest for 5 min
# 2022-05-18 18:27:53,342 - [NOTICE] simulation.solve(889): Cycle 309/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:27:53,439 - [NOTICE] simulation.solve(889): Cycle 309/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:27:53,851 - [NOTICE] simulation.solve(977): Capacity is now 3.285 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:27:53,851 - [NOTICE] simulation.solve(855): Cycle 310/328 (3 minutes, 29 seconds elapsed) --------------------
# 2022-05-18 18:27:53,852 - [NOTICE] simulation.solve(889): Cycle 310/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:27:53,983 - [NOTICE] simulation.solve(889): Cycle 310/328, step 2/4: Rest for 5 min
# 2022-05-18 18:27:54,016 - [NOTICE] simulation.solve(889): Cycle 310/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:27:54,133 - [NOTICE] simulation.solve(889): Cycle 310/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:27:54,507 - [NOTICE] simulation.solve(977): Capacity is now 3.280 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:27:54,508 - [NOTICE] simulation.solve(855): Cycle 311/328 (3 minutes, 30 seconds elapsed) --------------------
# 2022-05-18 18:27:54,509 - [NOTICE] simulation.solve(889): Cycle 311/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:27:54,635 - [NOTICE] simulation.solve(889): Cycle 311/328, step 2/4: Rest for 5 min
# 2022-05-18 18:27:54,670 - [NOTICE] simulation.solve(889): Cycle 311/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:27:54,827 - [NOTICE] simulation.solve(889): Cycle 311/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:27:55,263 - [NOTICE] simulation.solve(977): Capacity is now 3.275 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:27:55,265 - [NOTICE] simulation.solve(855): Cycle 312/328 (3 minutes, 31 seconds elapsed) --------------------
# 2022-05-18 18:27:55,265 - [NOTICE] simulation.solve(889): Cycle 312/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:27:55,385 - [NOTICE] simulation.solve(889): Cycle 312/328, step 2/4: Rest for 5 min
# 2022-05-18 18:27:55,421 - [NOTICE] simulation.solve(889): Cycle 312/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:27:55,526 - [NOTICE] simulation.solve(889): Cycle 312/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:27:55,951 - [NOTICE] simulation.solve(977): Capacity is now 3.270 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:27:55,951 - [NOTICE] simulation.solve(855): Cycle 313/328 (3 minutes, 32 seconds elapsed) --------------------
# 2022-05-18 18:27:55,952 - [NOTICE] simulation.solve(889): Cycle 313/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:27:56,070 - [NOTICE] simulation.solve(889): Cycle 313/328, step 2/4: Rest for 5 min
# 2022-05-18 18:27:56,113 - [NOTICE] simulation.solve(889): Cycle 313/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:27:56,237 - [NOTICE] simulation.solve(889): Cycle 313/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:27:56,611 - [NOTICE] simulation.solve(977): Capacity is now 3.265 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:27:56,612 - [NOTICE] simulation.solve(855): Cycle 314/328 (3 minutes, 32 seconds elapsed) --------------------
# 2022-05-18 18:27:56,613 - [NOTICE] simulation.solve(889): Cycle 314/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:27:56,803 - [NOTICE] simulation.solve(889): Cycle 314/328, step 2/4: Rest for 5 min
# 2022-05-18 18:27:56,859 - [NOTICE] simulation.solve(889): Cycle 314/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:27:56,975 - [NOTICE] simulation.solve(889): Cycle 314/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:27:57,372 - [NOTICE] simulation.solve(977): Capacity is now 3.260 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:27:57,373 - [NOTICE] simulation.solve(855): Cycle 315/328 (3 minutes, 33 seconds elapsed) --------------------
# 2022-05-18 18:27:57,374 - [NOTICE] simulation.solve(889): Cycle 315/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:27:57,489 - [NOTICE] simulation.solve(889): Cycle 315/328, step 2/4: Rest for 5 min
# 2022-05-18 18:27:57,523 - [NOTICE] simulation.solve(889): Cycle 315/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:27:57,627 - [NOTICE] simulation.solve(889): Cycle 315/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:27:58,074 - [NOTICE] simulation.solve(977): Capacity is now 3.255 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:27:58,075 - [NOTICE] simulation.solve(855): Cycle 316/328 (3 minutes, 34 seconds elapsed) --------------------
# 2022-05-18 18:27:58,076 - [NOTICE] simulation.solve(889): Cycle 316/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:27:58,232 - [NOTICE] simulation.solve(889): Cycle 316/328, step 2/4: Rest for 5 min
# 2022-05-18 18:27:58,261 - [NOTICE] simulation.solve(889): Cycle 316/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:27:58,417 - [NOTICE] simulation.solve(889): Cycle 316/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:27:58,805 - [NOTICE] simulation.solve(977): Capacity is now 3.250 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:27:58,805 - [NOTICE] simulation.solve(855): Cycle 317/328 (3 minutes, 34 seconds elapsed) --------------------
# 2022-05-18 18:27:58,806 - [NOTICE] simulation.solve(889): Cycle 317/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:27:58,969 - [NOTICE] simulation.solve(889): Cycle 317/328, step 2/4: Rest for 5 min
# 2022-05-18 18:27:59,004 - [NOTICE] simulation.solve(889): Cycle 317/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:27:59,126 - [NOTICE] simulation.solve(889): Cycle 317/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:27:59,624 - [NOTICE] simulation.solve(977): Capacity is now 3.245 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:27:59,624 - [NOTICE] simulation.solve(855): Cycle 318/328 (3 minutes, 35 seconds elapsed) --------------------
# 2022-05-18 18:27:59,625 - [NOTICE] simulation.solve(889): Cycle 318/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:27:59,785 - [NOTICE] simulation.solve(889): Cycle 318/328, step 2/4: Rest for 5 min
# 2022-05-18 18:27:59,824 - [NOTICE] simulation.solve(889): Cycle 318/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:27:59,941 - [NOTICE] simulation.solve(889): Cycle 318/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:28:00,347 - [NOTICE] simulation.solve(977): Capacity is now 3.240 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:28:00,348 - [NOTICE] simulation.solve(855): Cycle 319/328 (3 minutes, 36 seconds elapsed) --------------------
# 2022-05-18 18:28:00,348 - [NOTICE] simulation.solve(889): Cycle 319/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:28:00,565 - [NOTICE] simulation.solve(889): Cycle 319/328, step 2/4: Rest for 5 min
# 2022-05-18 18:28:00,605 - [NOTICE] simulation.solve(889): Cycle 319/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:28:00,727 - [NOTICE] simulation.solve(889): Cycle 319/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:28:01,128 - [NOTICE] simulation.solve(977): Capacity is now 3.235 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:28:01,128 - [NOTICE] simulation.solve(855): Cycle 320/328 (3 minutes, 37 seconds elapsed) --------------------
# 2022-05-18 18:28:01,129 - [NOTICE] simulation.solve(889): Cycle 320/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:28:01,249 - [NOTICE] simulation.solve(889): Cycle 320/328, step 2/4: Rest for 5 min
# 2022-05-18 18:28:01,281 - [NOTICE] simulation.solve(889): Cycle 320/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:28:01,372 - [NOTICE] simulation.solve(889): Cycle 320/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:28:01,814 - [NOTICE] simulation.solve(977): Capacity is now 3.230 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:28:01,814 - [NOTICE] simulation.solve(855): Cycle 321/328 (3 minutes, 37 seconds elapsed) --------------------
# 2022-05-18 18:28:01,815 - [NOTICE] simulation.solve(889): Cycle 321/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:28:01,982 - [NOTICE] simulation.solve(889): Cycle 321/328, step 2/4: Rest for 5 min
# 2022-05-18 18:28:02,015 - [NOTICE] simulation.solve(889): Cycle 321/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:28:02,098 - [NOTICE] simulation.solve(889): Cycle 321/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:28:02,539 - [NOTICE] simulation.solve(977): Capacity is now 3.224 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:28:02,539 - [NOTICE] simulation.solve(855): Cycle 322/328 (3 minutes, 38 seconds elapsed) --------------------
# 2022-05-18 18:28:02,540 - [NOTICE] simulation.solve(889): Cycle 322/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:28:02,660 - [NOTICE] simulation.solve(889): Cycle 322/328, step 2/4: Rest for 5 min
# 2022-05-18 18:28:02,694 - [NOTICE] simulation.solve(889): Cycle 322/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:28:02,810 - [NOTICE] simulation.solve(889): Cycle 322/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:28:03,214 - [NOTICE] simulation.solve(977): Capacity is now 3.219 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:28:03,214 - [NOTICE] simulation.solve(855): Cycle 323/328 (3 minutes, 39 seconds elapsed) --------------------
# 2022-05-18 18:28:03,215 - [NOTICE] simulation.solve(889): Cycle 323/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:28:03,352 - [NOTICE] simulation.solve(889): Cycle 323/328, step 2/4: Rest for 5 min
# 2022-05-18 18:28:03,417 - [NOTICE] simulation.solve(889): Cycle 323/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:28:03,570 - [NOTICE] simulation.solve(889): Cycle 323/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:28:04,036 - [NOTICE] simulation.solve(977): Capacity is now 3.214 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:28:04,037 - [NOTICE] simulation.solve(855): Cycle 324/328 (3 minutes, 40 seconds elapsed) --------------------
# 2022-05-18 18:28:04,038 - [NOTICE] simulation.solve(889): Cycle 324/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:28:04,163 - [NOTICE] simulation.solve(889): Cycle 324/328, step 2/4: Rest for 5 min
# 2022-05-18 18:28:04,197 - [NOTICE] simulation.solve(889): Cycle 324/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:28:04,286 - [NOTICE] simulation.solve(889): Cycle 324/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:28:04,702 - [NOTICE] simulation.solve(977): Capacity is now 3.209 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:28:04,703 - [NOTICE] simulation.solve(855): Cycle 325/328 (3 minutes, 40 seconds elapsed) --------------------
# 2022-05-18 18:28:04,704 - [NOTICE] simulation.solve(889): Cycle 325/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:28:04,849 - [NOTICE] simulation.solve(889): Cycle 325/328, step 2/4: Rest for 5 min
# 2022-05-18 18:28:04,904 - [NOTICE] simulation.solve(889): Cycle 325/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:28:05,049 - [NOTICE] simulation.solve(889): Cycle 325/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:28:05,473 - [NOTICE] simulation.solve(977): Capacity is now 3.204 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:28:05,474 - [NOTICE] simulation.solve(855): Cycle 326/328 (3 minutes, 41 seconds elapsed) --------------------
# 2022-05-18 18:28:05,475 - [NOTICE] simulation.solve(889): Cycle 326/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:28:05,658 - [NOTICE] simulation.solve(889): Cycle 326/328, step 2/4: Rest for 5 min
# 2022-05-18 18:28:05,695 - [NOTICE] simulation.solve(889): Cycle 326/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:28:05,833 - [NOTICE] simulation.solve(889): Cycle 326/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:28:06,312 - [NOTICE] simulation.solve(977): Capacity is now 3.199 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:28:06,312 - [NOTICE] simulation.solve(855): Cycle 327/328 (3 minutes, 42 seconds elapsed) --------------------
# 2022-05-18 18:28:06,313 - [NOTICE] simulation.solve(889): Cycle 327/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:28:06,448 - [NOTICE] simulation.solve(889): Cycle 327/328, step 2/4: Rest for 5 min
# 2022-05-18 18:28:06,485 - [NOTICE] simulation.solve(889): Cycle 327/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:28:06,644 - [NOTICE] simulation.solve(889): Cycle 327/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:28:07,082 - [NOTICE] simulation.solve(977): Capacity is now 3.194 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:28:07,082 - [NOTICE] simulation.solve(855): Cycle 328/328 (3 minutes, 43 seconds elapsed) --------------------
# 2022-05-18 18:28:07,083 - [NOTICE] simulation.solve(889): Cycle 328/328, step 1/4: Discharge at 1.5C until 3V
# 2022-05-18 18:28:07,205 - [NOTICE] simulation.solve(889): Cycle 328/328, step 2/4: Rest for 5 min
# 2022-05-18 18:28:07,241 - [NOTICE] simulation.solve(889): Cycle 328/328, step 3/4: Charge at 1.5C until 4.2V
# 2022-05-18 18:28:07,348 - [NOTICE] simulation.solve(889): Cycle 328/328, step 4/4: Hold at 4.2V until C/50
# 2022-05-18 18:28:07,781 - [NOTICE] simulation.solve(977): Capacity is now 3.189 Ah (originally 5.031 Ah, will stop at 2.516 Ah)
# 2022-05-18 18:28:07,787 - [NOTICE] simulation.solve(1011): Finish experiment simulation, took 3 minutes, 43 seconds

# %%
long_sol_output_0.keys()
# Out:
# dict_keys(['Minimum measured discharge capacity [A.h]', 'Maximum measured discharge capacity [A.h]', 'Measured capacity [A.h]', 'Positive electrode capacity [A.h]', 'Change in positive electrode capacity [A.h]', 'Loss of active material in positive electrode [%]', 'Change in loss of active material in positive electrode [%]', 'Loss of lithium inventory [%]', 'Change in loss of lithium inventory [%]', 'Loss of lithium inventory, including electrolyte [%]', 'Change in loss of lithium inventory, including electrolyte [%]', 'Total lithium [mol]', 'Change in total lithium [mol]', 'Total lithium in electrolyte [mol]', 'Change in total lithium in electrolyte [mol]', 'Total lithium in positive electrode [mol]', 'Change in total lithium in positive electrode [mol]', 'Total lithium in particles [mol]', 'Change in total lithium in particles [mol]', 'Total lithium lost [mol]', 'Change in total lithium lost [mol]', 'Total lithium lost from particles [mol]', 'Change in total lithium lost from particles [mol]', 'Total lithium lost from electrolyte [mol]', 'Change in total lithium lost from electrolyte [mol]', 'Loss of lithium to SEI [mol]', 'Change in loss of lithium to SEI [mol]', 'Loss of capacity to SEI [A.h]', 'Change in loss of capacity to SEI [A.h]', 'Total lithium lost to side reactions [mol]', 'Change in total lithium lost to side reactions [mol]', 'Total capacity lost to side reactions [A.h]', 'Change in total capacity lost to side reactions [A.h]', 'Local ECM resistance [Ohm]', 'Change in local ECM resistance [Ohm]', 'Negative electrode capacity [A.h]', 'Change in negative electrode capacity [A.h]', 'Loss of active material in negative electrode [%]', 'Change in loss of active material in negative electrode [%]', 'Total lithium in negative electrode [mol]', 'Change in total lithium in negative electrode [mol]', 'Loss of lithium to lithium plating [mol]', 'Change in loss of lithium to lithium plating [mol]', 'Loss of capacity to lithium plating [A.h]', 'Change in loss of capacity to lithium plating [A.h]', 'X-averaged SEI thickness [m]', 'Change in x-averaged SEI thickness [m]', 'x_100', 'y_100', 'C', 'x_0', 'y_0', 'Un(x_100)', 'Un(x_0)', 'Up(y_100)', 'Up(y_0)', 'Up(y_100) - Un(x_100)', 'Up(y_0) - Un(x_0)', 'n_Li_100', 'n_Li_0', 'n_Li', 'C_n', 'C_p', 'C_n * (x_100 - x_0)', 'C_p * (y_100 - y_0)', 'Capacity [A.h]', 'Cycle number'])

# %%
def plotc3(all_sumvars_dict,all_sumvars_dict1,all_sumvars_dict2,esoh_data):
    esoh_vars = ["x_100", "y_100","x_0", "y_0", "C_n", "C_p", ]
    esoh_data["Capacity [A.h]"]=esoh_data["Cap"]
    param = pybamm.LithiumIonParameters()
    esoh_data["n_Li"]= 3600/param.F.value*(esoh_data["y_100"]*esoh_data["C_p"]+esoh_data["x_100"]*esoh_data["C_n"])
    esoh_data["Loss of lithium inventory [%]"]=(1-esoh_data["n_Li"]/esoh_data["n_Li"][0])*100
    fig, axes = plt.subplots(3,2,figsize=(7,7))
    for k, name in enumerate(esoh_vars):
        ax = axes.flat[k]
        ax.plot(all_sumvars_dict["Cycle number"],all_sumvars_dict[name],"ro")
        ax.plot(all_sumvars_dict1["Cycle number"],all_sumvars_dict[name],"bo")
        ax.plot(all_sumvars_dict2["Cycle number"],all_sumvars_dict[name],"go")
        ax.plot(esoh_data["N"],esoh_data[name],"kx")
        ax.set_title(split_long_string(name))
        if k>3:
            ax.set_xlabel("Cycle number")
    fig.legend(["Normal"] + ["10% Comp"] + ["50% Comp"] + ["Reported"], 
           loc="lower center",bbox_to_anchor=[0.5,-0.02], ncol=1, fontsize=11)
    fig.tight_layout()
    return fig

# %%
fig = plotc3(long_sol_output_0,long_sol_output_1,long_sol_output_2,esoh_data);
fig.savefig(fig_DIR +'normal_sim_'+cell_no+'highc_comp_esoh_1.png')

# %%
for value in long_sol_output_0.keys():
    print(value)
# Out:
# Minimum measured discharge capacity [A.h]
# Maximum measured discharge capacity [A.h]
# Measured capacity [A.h]
# Positive electrode capacity [A.h]
# Change in positive electrode capacity [A.h]
# Loss of active material in positive electrode [%]
# Change in loss of active material in positive electrode [%]
# Loss of lithium inventory [%]
# Change in loss of lithium inventory [%]
# Loss of lithium inventory, including electrolyte [%]
# Change in loss of lithium inventory, including electrolyte [%]
# Total lithium [mol]
# Change in total lithium [mol]
# Total lithium in electrolyte [mol]
# Change in total lithium in electrolyte [mol]
# Total lithium in positive electrode [mol]
# Change in total lithium in positive electrode [mol]
# Total lithium in particles [mol]
# Change in total lithium in particles [mol]
# Total lithium lost [mol]
# Change in total lithium lost [mol]
# Total lithium lost from particles [mol]
# Change in total lithium lost from particles [mol]
# Total lithium lost from electrolyte [mol]
# Change in total lithium lost from electrolyte [mol]
# Loss of lithium to SEI [mol]
# Change in loss of lithium to SEI [mol]
# Loss of capacity to SEI [A.h]
# Change in loss of capacity to SEI [A.h]
# Total lithium lost to side reactions [mol]
# Change in total lithium lost to side reactions [mol]
# Total capacity lost to side reactions [A.h]
# Change in total capacity lost to side reactions [A.h]
# Local ECM resistance [Ohm]
# Change in local ECM resistance [Ohm]
# Negative electrode capacity [A.h]
# Change in negative electrode capacity [A.h]
# Loss of active material in negative electrode [%]
# Change in loss of active material in negative electrode [%]
# Total lithium in negative electrode [mol]
# Change in total lithium in negative electrode [mol]
# Loss of lithium to lithium plating [mol]
# Change in loss of lithium to lithium plating [mol]
# Loss of capacity to lithium plating [A.h]
# Change in loss of capacity to lithium plating [A.h]
# X-averaged SEI thickness [m]
# Change in x-averaged SEI thickness [m]
# x_100
# y_100
# C
# x_0
# y_0
# Un(x_100)
# Un(x_0)
# Up(y_100)
# Up(y_0)
# Up(y_100) - Un(x_100)
# Up(y_0) - Un(x_0)
# n_Li_100
# n_Li_0
# n_Li
# C_n
# C_p
# C_n * (x_100 - x_0)
# C_p * (y_100 - y_0)
# Capacity [A.h]
# Cycle number

# %%
def plotc4(all_sumvars_dict,all_sumvars_dict1,all_sumvars_dict2,esoh_data):
    esoh_vars = ["Capacity [A.h]", "Loss of lithium inventory [%]","Loss of active material in negative electrode [%]","Loss of active material in positive electrode [%]","Total capacity lost to side reactions [A.h]","Local ECM resistance [Ohm]"]
    esoh_data["Capacity [A.h]"]=esoh_data["Cap"]
    param = pybamm.LithiumIonParameters()
    esoh_data["n_Li"]= 3600/param.F.value*(esoh_data["y_100"]*esoh_data["C_p"]+esoh_data["x_100"]*esoh_data["C_n"])
    esoh_data["Loss of lithium inventory [%]"]=(1-esoh_data["n_Li"]/esoh_data["n_Li"][0])*100
    esoh_data["Loss of active material in negative electrode [%]"]=(1-esoh_data["C_n"]/esoh_data["C_n"][0])*100
    esoh_data["Loss of active material in positive electrode [%]"]=(1-esoh_data["C_p"]/esoh_data["C_p"][0])*100
    fig, axes = plt.subplots(3,2,figsize=(7,7))
    for k, name in enumerate(esoh_vars):
        ax = axes.flat[k]
        ax.plot(all_sumvars_dict["Cycle number"],all_sumvars_dict[name],"ro")
        ax.plot(all_sumvars_dict1["Cycle number"],all_sumvars_dict[name],"bo")
        ax.plot(all_sumvars_dict2["Cycle number"],all_sumvars_dict[name],"go")
        if k<4:
            ax.plot(esoh_data["N"],esoh_data[name],"kx")
        ax.set_title(split_long_string(name))
        if k>3:
            ax.set_xlabel("Cycle number")
    fig.legend(["Normal"] + ["10% Comp"] + ["50% Comp"] + ["Reported"], 
           loc="lower center",bbox_to_anchor=[0.5,-0.07], ncol=4, fontsize=11)
    fig.tight_layout()
    return fig

# %%
fig = plotc4(long_sol_output_0,long_sol_output_1,long_sol_output_2,esoh_data);
fig.savefig(fig_DIR +'normal_sim_'+cell_no+'highc_comp_esoh_2.png')

# %%
asdasd
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\spannala\PyBaMM\gmproj\fast_sim_pressure.ipynb Cell 27' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/spannala/PyBaMM/gmproj/fast_sim_pressure.ipynb#ch0000040?line=0'>1</a> asdasd
#
# NameError: name 'asdasd' is not defined

# %%
fig = plotc(long_sol_output,esoh_data);
fig.savefig(fig_DIR +'normal_sim_'+cell_no+'highc_normal_esoh.png')
# fig.savefig(fig_DIR +'normal_sim_'+cell_no+'highc_pressure_esoh.png')
# fig.savefig(fig_DIR +'normal_sim_'+cell_no+'lowc_pressure2_esoh.png')

# %%
dfdsfdsf

# %% [markdown]
# ## Comparison Plots

# %%
def plot_comp_long(all_sumvars_dict,esoh_data,long_sol_output,n: int = 1):
    esoh_vars = ["x_0", "y_0", "x_100", "y_100", "C_n", "C_p"]
    # esoh_vars = ["Capacity [A.h]", "Loss of lithium inventory [%]",
    #              "Loss of active material in negative electrode [%]",
    #              "Loss of active material in positive electrode [%]"]
    esoh_data['N']=esoh_data['N'].astype(int)
    esoh_data1 = esoh_data
    esoh_data1['N'] = esoh_data1['N']-1
    esoh_data1['N'].iloc[0] =esoh_data1['N'].iloc[0]+1 
    fig, axes = plt.subplots(3,2,figsize=(7,9))
    for k, name in enumerate(esoh_vars):
        ax = axes.flat[k]
        ax.plot(all_sumvars_dict["Cycle number"],all_sumvars_dict[name],"ro")
        ax.plot(long_sol_output["Cycle number"],long_sol_output[name],"b.")
        ax.plot(esoh_data["N"],esoh_data[name],"kx")
#         ax.scatter(all_sumvars_dict["Cycle number"],all_sumvars_dict[name],color="r")
    #     ax.plot(long_sol.summary_variables[name],"b-")
        ax.set_title(split_long_string(name))
        if k>3:
            ax.set_xlabel("Cycle number")
    # fig.subplots_adjust(bottom=0.4)
    fig.legend(["Acc Sim"] + ["Long Sim"] + ["Reported"], 
           loc="lower center", ncol=1, fontsize=11)
    fig.tight_layout()

    return fig

def plot1_comp_long(all_sumvars_dict,esoh_data,long_sol_output,n: int = 1):
    esoh_vars = ["Capacity [A.h]","n_Li"]
    esoh_data["Capacity [A.h]"]=esoh_data["Cap"]
    param = pybamm.LithiumIonParameters()
    esoh_data["n_Li"]= 3600/param.F.value*(esoh_data["y_100"]*esoh_data["C_p"]+esoh_data["x_100"]*esoh_data["C_n"])
    esoh_data['N']=esoh_data['N'].astype(int)
    esoh_data1 = esoh_data
    esoh_data1 = esoh_data
    esoh_data1['N'] = esoh_data1['N']-1
    esoh_data1['N'].iloc[0] =esoh_data1['N'].iloc[0]+1 
    fig, axes = plt.subplots(2,1,figsize=(7,9))
    for k, name in enumerate(esoh_vars):
        ax = axes.flat[k]
        ax.plot(all_sumvars_dict["Cycle number"][esoh_data1['N']//n],all_sumvars_dict[name][esoh_data1['N']//n],"ro")
        ax.plot(long_sol_output["Cycle number"][esoh_data1['N']],long_sol_output[name][esoh_data1['N']],"b.")
        ax.plot(esoh_data["N"],esoh_data[name],"kx")
        ax.set_title(split_long_string(name))
        ax.set_xlabel("Cycle number")
    ax.legend(["Acc Sim"] + ["Long Sim"] + ["Reported"], 
           loc="upper right", ncol=1, fontsize=11)
    fig.tight_layout()
    return fig

# %%
fig = plot_comp_long(all_sumvars_dict,esoh_data,long_sol_output,1)

# %%
# spm.variables.search("Concentration")

# %%
t = sol_long["Time [s]"].entries
I = sol_long["Current [A]"].entries
Q = -sol_long['Discharge capacity [A.h]'].entries
Vt = sol_long["Terminal voltage [V]"].entries
exp = 30e6*sol_long["Cell thickness change [m]"].entries
exp_n = 30e6*sol_long["Negative Electrode thickness change [m]"].entries
exp_p = 30e6*sol_long["Positive Electrode thickness change [m]"].entries
ee_p = sol_long["X-averaged positive electrode porosity"].entries
ee_n = sol_long["X-averaged negative electrode porosity"].entries
ee_s = sol_long["X-averaged separator porosity"].entries
j_n = sol_long["X-averaged negative electrode total interfacial current density [A.m-2]"].entries
j_p = sol_long["X-averaged positive electrode total interfacial current density [A.m-2]"].entries

# %%
plt.figure()
plt.plot(-Q,Vt)
plt.xlim(left=0)
plt.xlabel('Q [Ah]')
plt.ylabel('Voltage [V]')

# %%
plt.figure()
plt.plot(t,Vt)
# plt.xlim(left=0)
plt.xlabel('Q [Ah]')
plt.ylabel('Voltage [V]')

# %%
fig = plt.figure(figsize=[8,4])
ax1 = plt.subplot(1,3,1)
ax1.plot(-Q,exp_n)
ax1.set_xlim(left=0)
ax1.set_xlabel('Q [Ah]')
ax1.set_ylabel('Exp [$\mu$m]')
ax1.set_title('NE')
ax2 = plt.subplot(1,3,2)
ax2.plot(-Q,exp)
ax2.set_xlim(left=0)
ax2.set_xlabel('Q [Ah]')
ax2.set_title('Total')
ax2.set_ylabel('Exp [$\mu$m]')
ax3 = plt.subplot(1,3,3)
ax3.plot(-Q,exp_p)
ax3.set_xlim(left=0)
ax3.set_xlabel('Q [Ah]')
ax3.set_ylabel('Exp [$\mu$m]')
ax3.set_title('PE')
fig.tight_layout()
