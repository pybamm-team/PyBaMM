# %% [markdown]
# # Single Particle Model (SPM): Fast discharge with concentration dependent diffusion

# %% [markdown]
# ## Model Equations

# %% [markdown]
# The SPM consists of two spherically symmetric diffusion equations: one within a representative negative particle ($\text{k}=\text{n}$) and one within a representative positive particle ($\text{k}=\text{p}$). In the centre of the particle the standard no-flux condition is imposed. Since the SPM assumes that all particles in an electrode behave in exactly the same way, the flux on the surface of a particle is simply the current $I$ divided by the thickness of the electrode $L_{\text{k}}$. The concentration of lithium in electrode $\text{k}$ is denoted $c_{\text{k}}$ and the current is denoted by $I$. All parameters in the model stated here are dimensionless and are given in terms of dimensional parameters at the end of this notebook. The model equations for the SPM are then:
# $$
# \begin{align}
# \mathcal{C}_{\text{k}} \frac{\partial c_{\text{s,k}}}{\partial t} &= -\frac{1}{r_{\text{k}}^2} \frac{\partial}{\partial r_{\text{k}}} \left(r_{\text{k}}^2 N_{\text{s,k}}\right), \\
# N_{\text{s,k}} &= -D_{\text{s,k}}(c_{\text{s,k}}) \frac{\partial c_{\text{s,k}}}{\partial r_{\text{k}}}, \quad \text{k} \in \text{n, p},
# \end{align}
# $$
# $$
# N_{\text{s,k}}\big|_{r_{\text{k}}=0} = 0, \quad \text{k} \in \text{n, p}, \quad \ \ - \frac{a_{R, \text{k}}\gamma_{\text{k}}}{\mathcal{C}_{\text{k}}} N_{\text{s,k}}\big|_{r_{\text{k}}=1} =
# \begin{cases}
# 		  \frac{I}{L_{\text{n}}}, \quad &\text{k}=\text{n}, \\
# 		  -\frac{I}{L_{\text{p}}}, \quad &\text{k}=\text{p},
# \end{cases} \\
# c_{\text{s,k}}(r_{\text{k}},0) = c_{\text{s,k,0}}, \quad \text{k} \in \text{n, p},$$
# where $D_{\text{s,k}}$ is the diffusion coefficient in the solid, $N_{\text{s,k}}$ denotes the flux of lithium ions in the solid particle within the region $\text{k}$, and $r_{\text{k}} \in[0,1]$ is the radial coordinate of the particle in electrode $\text{k}$.
#
# ### Voltage Expression
# The terminal voltage is obtained from the expression:
# $$
# V = U_{\text{p}}(c_{\text{p}})\big|_{r_{\text{p}}=1} - U_{\text{n}}(c_{\text{n}})\big|_{r_{\text{n}}=1} -2\sinh^{-1}\left(\frac{I}{j_{\text{0,p}} L_{\text{p}}}\right) - 2\sinh^{-1}\left(\frac{I}{j_{\text{0,n}} L_{\text{n}}}\right)
# $$
# with the exchange current densities given by
# $$j_{\text{0,k}} =  \frac{\gamma_{\text{k}}}{\mathcal{C}_{\text{r,k}}}(c_{\text{k}})^{1/2}(1-c_{\text{k}})^{1/2}  $$
#
# More details can be found in [[3]](#References).

# %% [markdown]
# ## Example solving SPM using PyBaMM
#
# Below we show how to solve the Single Particle Model, using the default geometry, mesh, parameters, discretisation and solver provided with PyBaMM. In this notebook we explicitly handle all the stages of setting up, processing and solving the model in order to explain them in detail. However, it is often simpler in practice to use the `Simulation` class, which handles many of the stages automatically, as shown [here](../simulation-class.ipynb).
#
# First we need to import `pybamm`, and then change our working directory to the root of the pybamm folder.

# %%
# %pip install DFO-LS -q
# need to restart jupyter server? kernal? whenever a change is made to the pybamm module? 
import sys
import os
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
os.chdir(sys.path[0] + '\..') # change our working directory to the root of the pybamm folder
import pybamm
import dfols
from scipy.optimize import curve_fit

# from multiprocessing import Process, Pool

# from scipy.optimize import minimize
print(pybamm.__path__[0])
# %matplotlib widget
# Out:
# c:\Users\Vivian\Dropbox (University of Michigan)\from_box\Research\PyBaMM\PyBaMM\pybamm

# %% [markdown]
# # Load pulse testing data

# %%
data = pd.read_csv(
    "./fast_discharge/2C_pulse_test_data_DCR_Cell_43.csv"#, comment="#", header=None
)
df_labels = ['t', 'V', 'AhT','Temp', 'Q', 'I']
data.set_axis(df_labels, axis=1, inplace=True)
data.AhT = -data.AhT/1000 
data['I_C'] = data.I/4.6
data['SOC'] = 1-data.AhT/4.2
data
# Out:
# C:\Users\Vivian\AppData\Local\Temp\ipykernel_25644\1251893854.py:5: FutureWarning: DataFrame.set_axis 'inplace' keyword is deprecated and will be removed in a future version. Use `obj = obj.set_axis(..., copy=False)` instead
#   data.set_axis(df_labels, axis=1, inplace=True)
#                 t         V       AhT       Temp            Q         I  \
# 0        0.000000  4.196902 -0.000000  22.914967  2292.862303 -0.000000
# 1       10.000000  4.196824 -0.000000  23.048939  2292.862303 -0.000000
# 2       20.000001  4.196784 -0.000000  22.993774  2292.862303 -0.000000
# 3       30.000001  4.196745 -0.000000  22.993774  2292.862303 -0.000000
# 4       40.000002  4.196627 -0.000000  22.788877  2292.862303 -0.000000
# ...           ...       ...       ...        ...          ...       ...
# 4096  5602.088266  3.204265  4.073620  24.183754  4072.425625  8.995825
# 4097  5612.088267  3.162594  4.098613  24.231037  4097.418306  8.995825
# 4098  5622.088267  3.106940  4.123605  24.412292  4122.410880  8.996416
# 4099  5632.088268  3.029937  4.148598  24.459576  4147.403525  8.997204
# 4100  5639.608268  2.949981  4.167393  24.640831  4166.198008  8.996220
#
#            I_C       SOC
# 0    -0.000000  1.000000
# 1    -0.000000  1.000000
# 2    -0.000000  1.000000
# 3    -0.000000  1.000000
# 4    -0.000000  1.000000
# ...        ...       ...
# 4096  1.955614  0.030090
# 4097  1.955614  0.024140
# 4098  1.955743  0.018189
# 4099  1.955914  0.012239
# 4100  1.955700  0.007764
#
# [4101 rows x 8 columns]

# %% [markdown]
# # Find and plot indices of pulse rest

# %%
# find pulse indices
I = data.I
pulse_current = max(I)
i1 = np.where((np.diff(I)<-0.1))[0]
i1 = i1+1
# i1 = np.append(i1,len(I)-1)
i2 = np.where((np.diff(I)>0.1) & (I[1:]>pulse_current-0.1)& (I[1:]<pulse_current+0.1))[0]
# i2 = np.insert(i2,0,1)
# plot
fig, ax = plt.subplots(2,2, figsize=(8,4), sharex=True)
ax = ax.flatten()
linestyles = ['-','--',':','.-']*2

t = data.t/60
xlabel = "Time [min]"
data_color = 'k'
ax[0].plot(t,data.I_C, label='Data', color = data_color)
ax[0].scatter(t[i1], data.I_C[i1])
ax[0].scatter(t[i2], data.I_C[i2])
ax[0].set_xlabel(xlabel)
ax[0].set_ylabel('C-rate')

ax[2].plot(t, data.V,color = data_color)
ax[2].scatter(t[i1], data.V[i1])
ax[2].scatter(t[i2], data.V[i2])
ax[2].set_xlabel(xlabel)
ax[2].set_ylabel('Terminal voltage [V]')

ax[1].plot(t, data.Temp, color = data_color)
ax[1].scatter(t[i1], data.Temp[i1])
ax[1].scatter(t[i2], data.Temp[i2])
ax[1].set_xlabel(xlabel)
ax[1].set_ylabel('Temperature [$^\circ$C]')

ax[3].plot(t, data.SOC, color = data_color)
ax[3].scatter(t[i1], data.SOC[i1])
ax[3].scatter(t[i2], data.SOC[i2])
ax[3].set_xlabel(xlabel)
ax[3].set_ylabel('SOC')

plt.tight_layout()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def plot_pulse(data, solutions, labels = []):
    fig, ax = plt.subplots(2,2, figsize=(8,4), sharex=True)
    ax = ax.flatten()
    linestyles = ['-','--',':','.-']*2

    t = data.t/60
    xlabel = "Time [min]"
    data_color = 'k'
    ax[0].plot(t,data.I_C, label='Data', color = data_color)
    ax[0].set_xlabel(xlabel)
    ax[0].set_ylabel('C-rate')


    ax[2].plot(t, data.V,color = data_color)
    ax[2].set_xlabel(xlabel)
    ax[2].set_ylabel('Terminal voltage [V]')

    ax[1].plot(t, data.Temp, color = data_color)
    ax[1].set_xlabel(xlabel)
    ax[1].set_ylabel('Temperature [$^\circ$C]')

    ax[3].plot(t, data.SOC, color = data_color)
    ax[3].set_xlabel(xlabel)
    ax[3].set_ylabel('SOC')

    sim_colors = ['r','g','b','m']*2
    for i,solution in enumerate(solutions):
        t = solution["Time [s]"].entries
        x = solution["x [m]"].entries[:, 0]
        I = solution['C-rate']
        V = solution['Terminal voltage [V]']
        T = solution['Volume-averaged cell temperature [K]'].entries - 273.15
        soc = solution['R-averaged negative particle concentration']

        x_plot = t/60
        ax[0].plot(x_plot, I(t), linestyle=':',color = sim_colors[i])
        ax[2].plot(x_plot, V(t), linestyle=':',color = sim_colors[i])
        ax[1].plot(x_plot, T,linestyle=':',color = sim_colors[i])  # can evaluate at arbitrary x (single representative particle)
        ax[3].plot(x_plot, soc(t=t, x=x[-1]),linestyle=':',color = sim_colors[i])  # can evaluate at arbitrary x (single representative particle)


    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Set up nominal model

# %%
# set up pulse data
pulse_num = 0
pulse = data[i2[pulse_num]:i2[pulse_num+1]].copy()
pulse.t = pulse.t-pulse.t.iloc[0]

# define parameters for simulation
SOC_0 = pulse.SOC.iloc[0]
pulse_current = pulse[['t','I']].to_numpy()

# set up and solve model
solutions = []
options = {
    # "thermal": "x-lumped",
}
model = pybamm.lithium_ion.SPMe(options = options)
param = pybamm.ParameterValues(pybamm.parameter_sets.Mohtat2020)
param.update({
    "Lower voltage cut-off [V]": 0,
    "Nominal cell capacity [A.h]": 4.6,
    "Typical current [A]":4.6,
    "Negative tab width [m]":2.5e-2,
    "Positive tab width [m]":2.5e-2,
    "Negative electrode thickness [m]":62E-06*4.2/5,
    "Positive electrode thickness [m]":67E-06*4.2/5,
    "Negative current collector surface heat transfer coefficient [W.m-2.K-1]": 5,  
    "Positive current collector surface heat transfer coefficient [W.m-2.K-1]": 5,  
    "Negative tab heat transfer coefficient [W.m-2.K-1]":5,  
    "Positive tab heat transfer coefficient [W.m-2.K-1]":5,  
    "Edge heat transfer coefficient [W.m-2.K-1]":5,
    "Total heat transfer coefficient [W.m-2.K-1]":5,
    # "Negative electrode diffusivity [m2.s-1]": 8.0E-14*0.6, 
    # "Positive electrode diffusivity [m2.s-1]": 8.0E-15*0.6, 
    # "Negative electrode reference exchange-current density [A.m-2(m3.mol)1.5]": 4.244E-06*0.9, 
    # "Positive electrode reference exchange-current density [A.m-2(m3.mol)1.5]": 4.824E-06*0.9,
    "Ambient temperature [K]": 23+273.15,
    "Initial temperature [K]": 23 + 273.15,

}, check_already_exists = False)
experiment = pybamm.Experiment(
        [
        "Run pulse (A) until 3.0 V"
        ],
        drive_cycles={
            'pulse': pulse_current
        }
    )
sim = pybamm.Simulation(model, experiment=experiment, parameter_values = param)
solution = sim.solve( initial_soc=SOC_0)
solutions.append(solution)

# plot simulation results 
plot_pulse(pulse,solutions)
# Out:
# 2023-05-09 10:28:51.015 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Set up loss function for parameterization

# %%
# # run simulation with input k to scale D and output error metric
# # Input and output are np.array
def simulate_pulse(k:np.ndarray): 
    Dp_0 = 8.0E-15
    Dn_0 = 8.0E-14
    i0n_0 = 4.244E-06
    i0p_0 = 4.824E-06

    param.update({
        "Positive electrode diffusivity [m2.s-1]": Dp_0*k[0],
        "Negative electrode diffusivity [m2.s-1]": Dn_0*k[1],
        "Positive electrode reference exchange-current density [A.m-2(m3.mol)1.5]": i0p_0*k[2], 
        "Negative electrode reference exchange-current density [A.m-2(m3.mol)1.5]": i0n_0*k[3],
        }, check_already_exists = False)
    sim = pybamm.Simulation(model, experiment=experiment, parameter_values = param)
    solution = sim.solve(initial_soc=SOC_0)
    
    # calculate rmse for rest period
    V = solution['Terminal voltage [V]']
    t_error = pulse.t[(pulse.V > 3.0)].to_numpy() #  & (pulse.I ==0)
    rmse_V = np.sqrt(np.mean(np.square(pulse.V[(pulse.V > 3.0)]- V(t_error))))
    # rmse_V = np.sum(np.square(pulse.V[(pulse.V > 3.0)]- V(t_error)))
    # rmse_dV = np.sqrt(np.mean(np.square(np.diff(pulse.V[(pulse.V > 3.0)])- np.diff(V(t_error)))))
    # rmse_V = np.sum(np.square(pulse.V[(pulse.V > 3.0)]- V(t_error)))

    return np.array([rmse_V])
    

# test function
print(simulate_pulse(np.array([1,1, 2, 2])))


def simulate_pulse_pos(kp:np.ndarray, kn, pn): 
    Dp_0 = 8.0E-15
    Dn_0 = 8.0E-14
    i0n_0 = 4.244E-06
    i0p_0 = 4.824E-06

    param.update({
        "Positive electrode diffusivity [m2.s-1]": Dp_0*kp[0],
        "Negative electrode diffusivity [m2.s-1]": Dn_0*kn,
        "Positive electrode reference exchange-current density [A.m-2(m3.mol)1.5]": i0p_0*kp[1], 
        "Negative electrode reference exchange-current density [A.m-2(m3.mol)1.5]": i0n_0*pn,
        }, check_already_exists = False)
    sim = pybamm.Simulation(model, experiment=experiment, parameter_values = param)
    solution = sim.solve(initial_soc=SOC_0)
    
    # calculate rmse for rest period
    V = solution['Terminal voltage [V]']
    t_error = pulse.t[(pulse.V > 3.0)].to_numpy() #  & (pulse.I ==0)
    rmse_V = np.sqrt(np.mean(np.square(pulse.V[(pulse.V > 3.0)]- V(t_error))))
    # rmse_V = np.sum(np.square(pulse.V[(pulse.V > 3.0)]- V(t_error)))
    # rmse_dV = np.sqrt(np.mean(np.square(np.diff(pulse.V[(pulse.V > 3.0)])- np.diff(V(t_error)))))
    # rmse_V = np.sum(np.square(pulse.V[(pulse.V > 3.0)]- V(t_error)))

    return np.array([rmse_V])

def simulate_pulse_neg(kn:np.ndarray, kp, pp): 
    Dp_0 = 8.0E-15
    Dn_0 = 8.0E-14
    i0n_0 = 4.244E-06
    i0p_0 = 4.824E-06

    param.update({
        "Positive electrode diffusivity [m2.s-1]": Dp_0*kp,
        "Negative electrode diffusivity [m2.s-1]": Dn_0*kn[0],
        "Positive electrode reference exchange-current density [A.m-2(m3.mol)1.5]": i0p_0*pp, 
        "Negative electrode reference exchange-current density [A.m-2(m3.mol)1.5]": i0n_0*kn[1],
        }, check_already_exists = True)
    sim = pybamm.Simulation(model, experiment=experiment, parameter_values = param)
    solution = sim.solve(initial_soc=SOC_0)
    
    # calculate rmse for rest period
    V = solution['Terminal voltage [V]']
    t_error = pulse.t[(pulse.V > 3.0)].to_numpy() #  & (pulse.I ==0)
    rmse_V = np.sqrt(np.mean(np.square(pulse.V[(pulse.V > 3.0)]- V(t_error))))
    # rmse_V = np.sum(np.square(pulse.V[(pulse.V > 3.0)]- V(t_error)))
    # rmse_dV = np.sqrt(np.mean(np.square(np.diff(pulse.V[(pulse.V > 3.0)& (pulse.I ==0)])- np.diff(V(t_error)))))
    # rmse_V = np.sum(np.square(pulse.V[(pulse.V > 3.0)]- V(t_error)))

    return np.array([rmse_V])




# run simulation with input k to scale D and output error metric
# Input and output are np.array
def simulate_pulse_dV(k:np.ndarray): 
    Dp_0 = 8.0E-15
    Dn_0 = 8.0E-14
    i0n_0 = 4.244E-06
    i0p_0 = 4.824E-06

    param.update({
        "Positive electrode diffusivity [m2.s-1]": Dp_0*k[0],
        "Negative electrode diffusivity [m2.s-1]": Dn_0*k[1],
        "Positive electrode reference exchange-current density [A.m-2(m3.mol)1.5]": i0p_0*k[2], 
        "Negative electrode reference exchange-current density [A.m-2(m3.mol)1.5]": i0n_0*k[3],
        }, check_already_exists = False)
    sim = pybamm.Simulation(model, experiment=experiment, parameter_values = param)
    solution = sim.solve(initial_soc=SOC_0)
    
    # calculate rmse for rest period
    V = solution['Terminal voltage [V]']
    t_error = pulse.t[(pulse.V > 3.0)].to_numpy() #  & (pulse.I ==0)
    # rmse_V = np.sqrt(np.mean(np.square(pulse.V[(pulse.V > 3.0)]- V(t_error))))
    # rmse_V = np.sum(np.square(pulse.V[(pulse.V > 3.0)]- V(t_error)))
    e_dV = np.sum(abs(np.diff(pulse.V[pulse.V > 3.0])- np.diff(V(t_error))))

    return np.array([e_dV])

# test function
print(simulate_pulse_dV(np.array([1,1, 2, 2])))
# Out:
# [0.00599217]
# [0.08390937]

# %% [markdown]
# # Fit all pulses (positive and negative)

# %%
Dp_0 = 8.0E-15
Dn_0 = 8.0E-14
i0n_0 = 4.244E-06
i0p_0 = 4.824E-06
lb = np.array([1e-1]*4)
ub =  np.array([1e2]*4)
k_list = []                               
SOC_list = []
e_list = []
for c,(i,j) in enumerate(zip(i2[0:-1],i2[1::])): #zip(i2[0:-1],i2[1::])

    # define pulse data
    pulse = data[i:j].copy()
    pulse.t = pulse.t-pulse.t.iloc[0]

    # define sim parameters
    SOC_0 = pulse.SOC.iloc[0]
    pulse_current = pulse[['t','I']].to_numpy()

    # Fit D
    # # if SOC_0 < 0:
    loss_function = simulate_pulse
    k0 = np.array([SOC_0]*2 + [SOC_0+0.5]*2)
    k = dfols.solve(loss_function, k0, bounds = (lb,ub), rhoend=1e-4)
    k_list.append(k.x)
    SOC_list.append(pulse.SOC.iloc[-1])  
    e_list.append(loss_function(k.x))
    
    # simulate with k
    solutions = []
    # nominal
    param.update({
        "Positive electrode diffusivity [m2.s-1]": Dp_0,
        "Negative electrode diffusivity [m2.s-1]": Dn_0,
        "Positive electrode reference exchange-current density [A.m-2(m3.mol)1.5]": i0p_0, 
        "Negative electrode reference exchange-current density [A.m-2(m3.mol)1.5]": i0n_0,
        }, check_already_exists = False)
    sim0 = pybamm.Simulation(model, experiment=experiment, parameter_values = param)
    solution0 = sim0.solve(initial_soc=SOC_0)
    solutions.append(solution0)
    
    # fitted
    param.update({
        "Positive electrode diffusivity [m2.s-1]": Dp_0*k_list[c][0],
        "Negative electrode diffusivity [m2.s-1]": Dn_0*k_list[c][1],
        "Positive electrode reference exchange-current density [A.m-2(m3.mol)1.5]": i0p_0*k_list[c][2], 
        "Negative electrode reference exchange-current density [A.m-2(m3.mol)1.5]": i0n_0*k_list[c][3],
        }, check_already_exists = False)
    sim = pybamm.Simulation(model, experiment=experiment, parameter_values = param)
    solution = sim.solve(initial_soc=SOC_0)
    solutions.append(solution)

    # plot with 
    plot_pulse(pulse,solutions)

print(len(solutions))
# Out:
# 2023-05-09 12:51:31.868 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:51:33.592 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 2023-05-09 12:51:35.596 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:51:37.333 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:51:39.072 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:51:41.066 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:51:43.422 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:51:45.169 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:51:46.979 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:51:48.784 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:51:50.550 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:51:52.321 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:51:54.052 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:51:55.970 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:51:58.323 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:52:00.138 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:52:02.187 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:52:03.922 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:52:05.687 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:52:07.504 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:52:09.279 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:52:11.039 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:52:12.837 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:52:15.116 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:52:16.861 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:52:18.644 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:52:20.402 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:52:22.175 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:52:23.997 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:52:25.750 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:52:27.669 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:52:29.812 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:52:31.502 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:52:33.277 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:52:35.106 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:52:36.980 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:52:38.995 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:52:40.682 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:52:42.472 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:52:44.209 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:52:46.575 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:52:48.361 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:52:50.145 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:52:51.911 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:52:53.674 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:52:55.451 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:52:57.184 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:53:01.847 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:53:03.190 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 2023-05-09 12:53:05.308 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:53:07.071 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:53:08.859 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:53:10.616 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:53:12.404 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:53:14.295 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:53:16.009 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:53:17.740 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:53:20.078 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:53:21.828 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:53:23.565 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:53:25.326 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:53:27.165 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:53:29.100 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:53:30.886 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:53:32.632 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:53:34.794 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:53:36.551 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:53:38.322 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:53:40.109 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:53:42.034 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:53:44.174 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:53:45.972 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:53:47.729 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:53:49.503 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:53:51.819 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:53:53.539 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:53:55.279 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:53:57.021 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:53:58.829 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:54:00.844 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:54:02.685 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:54:04.444 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:54:06.169 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:54:08.531 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:54:10.288 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:54:12.054 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:54:13.799 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:54:15.575 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:54:17.494 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:54:19.262 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:54:21.042 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:54:23.206 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:54:24.959 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:54:26.743 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:54:28.537 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:54:30.310 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:54:32.263 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:54:33.991 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:54:35.738 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:54:37.470 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:54:39.737 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:54:41.517 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:54:43.276 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:54:45.013 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:54:46.863 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:54:48.990 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:54:50.860 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:54:53.099 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:54:55.307 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:54:58.509 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:55:04.278 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:55:06.356 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 2023-05-09 12:55:08.937 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:55:11.395 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:55:13.796 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:55:16.137 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:55:18.433 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:55:21.324 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:55:23.953 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:55:26.433 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:55:29.282 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:55:32.121 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:55:34.892 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:55:37.574 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:55:42.050 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:55:46.296 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:55:49.745 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:55:52.250 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:55:55.260 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:55:58.296 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:56:00.973 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:56:03.885 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:56:07.157 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:56:09.953 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:56:12.854 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:56:16.418 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:56:19.062 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:56:21.859 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:56:25.548 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:56:28.932 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:56:33.266 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:56:36.510 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:56:40.045 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:56:42.785 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:56:46.072 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:56:48.331 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:56:51.029 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:56:53.913 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:56:56.495 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:56:59.461 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:57:02.100 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:57:04.929 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:57:07.674 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:57:10.850 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:57:13.331 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:57:15.427 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:57:17.492 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:57:19.552 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:57:21.808 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:57:23.869 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:57:25.864 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:57:28.386 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:57:30.437 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:57:32.591 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:57:34.716 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:57:36.785 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:57:39.096 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:57:41.181 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:57:43.256 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:57:45.317 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:57:47.991 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:57:50.091 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:57:52.194 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:57:54.386 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:57:56.492 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:57:58.684 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:58:00.824 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:58:02.944 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:58:05.137 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:58:08.008 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:58:10.181 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:58:12.313 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:58:14.374 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:58:16.463 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:58:18.685 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:58:20.746 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:58:22.798 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:58:24.847 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:58:27.564 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:58:29.621 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:58:31.655 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:58:33.702 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:58:35.723 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:58:37.904 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:58:39.925 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:58:41.973 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:58:44.004 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:58:46.722 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:58:48.761 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:58:50.832 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:58:52.914 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:58:54.987 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:58:57.177 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:58:59.180 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:59:01.214 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:59:03.295 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:59:05.989 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:59:08.040 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:59:10.156 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:59:12.354 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:59:14.528 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:59:16.743 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:59:18.763 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:59:20.987 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:59:23.529 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:59:25.559 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:59:27.578 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:59:29.644 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:59:31.709 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:59:33.925 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:59:35.941 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:59:37.999 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:59:40.063 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:59:42.742 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:59:44.771 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:59:46.833 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:59:48.931 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:59:51.104 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:59:53.360 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:59:55.427 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:59:57.475 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 12:59:59.492 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:00:02.321 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:00:04.380 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:00:06.401 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:00:08.422 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:00:10.492 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:00:12.743 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:00:14.808 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:00:17.029 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:00:19.187 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:00:22.004 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:00:24.077 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:00:26.110 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:00:31.003 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:00:32.568 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 2023-05-09 13:00:35.067 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:00:37.087 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:00:39.082 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:00:41.818 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:00:43.796 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:00:45.815 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:00:47.821 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:00:49.773 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:00:51.952 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:00:55.483 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:00:57.407 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:00:59.458 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:01:02.517 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:01:04.539 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:01:06.569 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:01:08.674 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:01:10.806 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:01:13.043 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:01:15.259 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:01:17.316 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:01:19.407 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:01:22.416 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:01:24.786 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:01:27.004 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:01:29.209 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:01:31.427 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:01:33.646 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:01:35.851 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:01:38.155 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:01:40.216 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:01:42.997 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:01:45.089 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:01:47.183 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:01:49.222 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:01:51.315 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:01:53.529 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:01:55.607 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:01:57.780 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:01:59.729 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:02:02.565 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:02:04.728 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:02:06.768 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:02:08.907 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:02:10.989 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:02:13.265 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:02:15.264 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:02:17.220 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:02:19.765 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:02:21.861 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:02:23.782 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:02:25.795 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:02:27.774 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:02:29.945 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:02:32.202 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:02:34.327 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:02:36.382 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:02:38.920 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:02:41.039 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:02:43.107 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:02:45.156 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:02:47.234 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:02:49.425 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:02:51.766 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:02:54.093 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:02:56.512 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:02:59.453 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:03:01.981 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:03:04.354 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:03:06.783 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:03:09.065 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:03:11.618 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:03:14.047 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:03:16.031 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:03:18.038 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:03:20.511 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:03:22.444 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:03:24.371 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:03:26.280 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:03:28.107 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:03:30.337 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:03:32.335 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:03:34.283 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:03:36.229 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:03:38.828 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:03:40.824 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:03:42.785 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:03:44.738 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:03:46.660 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:03:48.736 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:03:50.679 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:03:52.760 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:03:54.695 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:03:57.288 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:03:59.255 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:04:01.275 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:04:03.904 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:04:05.979 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:04:08.603 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:04:10.735 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:04:12.798 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:04:14.785 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:04:17.498 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:04:19.422 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:04:21.445 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:04:23.387 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:04:25.285 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:04:27.285 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:04:29.131 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:04:31.066 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:04:32.932 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:04:35.440 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:04:40.090 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:04:41.712 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 2023-05-09 13:04:43.946 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:04:45.866 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:04:47.955 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# ...
# 2023-05-09 13:18:10.391 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:18:11.884 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:18:13.397 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:18:14.852 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:18:16.342 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:18:17.775 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:18:19.138 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:18:20.505 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:18:22.266 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:18:23.680 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:18:25.104 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:18:26.566 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:18:27.969 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:18:29.392 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:18:30.754 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:18:32.265 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:18:33.647 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:18:37.416 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:18:38.497 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 2023-05-09 13:21:30.203 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:21:31.243 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 2023-05-09 13:27:14.495 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:27:16.430 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 2023-05-09 13:27:18.339 - [WARNING] callbacks.on_experiment_infeasible(233):
#
# 	Experiment is infeasible: 'event: Minimum voltage' was triggered during 'Run pulse (A) until 3.0 V'. The returned solution only contains up to step 1 of cycle 1.
# 2023-05-09 13:27:18.659 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:27:19.764 - [WARNING] callbacks.on_experiment_infeasible(233):
#
# 	Experiment is infeasible: 'event: Minimum voltage' was triggered during 'Run pulse (A) until 3.0 V'. The returned solution only contains up to step 1 of cycle 1.
# 2023-05-09 13:27:20.235 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:27:21.126 - [WARNING] callbacks.on_experiment_infeasible(233):
#
# 	Experiment is infeasible: 'event: Minimum voltage' was triggered during 'Run pulse (A) until 3.0 V'. The returned solution only contains up to step 1 of cycle 1.
# 2023-05-09 13:27:21.525 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:27:22.427 - [WARNING] callbacks.on_experiment_infeasible(233):
#
# 	Experiment is infeasible: 'event: Minimum voltage' was triggered during 'Run pulse (A) until 3.0 V'. The returned solution only contains up to step 1 of cycle 1.
# 2023-05-09 13:27:22.812 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:27:23.630 - [WARNING] callbacks.on_experiment_infeasible(233):
#
# 	Experiment is infeasible: 'event: Minimum voltage' was triggered during 'Run pulse (A) until 3.0 V'. The returned solution only contains up to step 1 of cycle 1.
# 2023-05-09 13:27:24.015 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:27:24.945 - [WARNING] callbacks.on_experiment_infeasible(233):
#
# 	Experiment is infeasible: 'event: Minimum voltage' was triggered during 'Run pulse (A) until 3.0 V'. The returned solution only contains up to step 1 of cycle 1.
# 2023-05-09 13:27:25.314 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:27:26.290 - [WARNING] callbacks.on_experiment_infeasible(233):
#
# 	Experiment is infeasible: 'event: Minimum voltage' was triggered during 'Run pulse (A) until 3.0 V'. The returned solution only contains up to step 1 of cycle 1.
# 2023-05-09 13:27:26.811 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:27:27.579 - [WARNING] callbacks.on_experiment_infeasible(233):
#
# 	Experiment is infeasible: 'event: Minimum voltage' was triggered during 'Run pulse (A) until 3.0 V'. The returned solution only contains up to step 1 of cycle 1.
# 2023-05-09 13:27:27.948 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:27:28.853 - [WARNING] callbacks.on_experiment_infeasible(233):
#
# 	Experiment is infeasible: 'event: Minimum voltage' was triggered during 'Run pulse (A) until 3.0 V'. The returned solution only contains up to step 1 of cycle 1.
# 2023-05-09 13:27:29.222 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:27:31.100 - [WARNING] callbacks.on_experiment_infeasible(233):
#
# 	Experiment is infeasible: 'event: Minimum voltage' was triggered during 'Run pulse (A) until 3.0 V'. The returned solution only contains up to step 1 of cycle 1.
# 2023-05-09 13:27:31.492 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:27:32.384 - [WARNING] callbacks.on_experiment_infeasible(233):
#
# 	Experiment is infeasible: 'event: Minimum voltage' was triggered during 'Run pulse (A) until 3.0 V'. The returned solution only contains up to step 1 of cycle 1.
# 2023-05-09 13:27:32.719 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:27:33.624 - [WARNING] callbacks.on_experiment_infeasible(233):
#
# 	Experiment is infeasible: 'event: Minimum voltage' was triggered during 'Run pulse (A) until 3.0 V'. The returned solution only contains up to step 1 of cycle 1.
# 2023-05-09 13:27:34.016 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:27:34.999 - [WARNING] callbacks.on_experiment_infeasible(233):
#
# 	Experiment is infeasible: 'event: Minimum voltage' was triggered during 'Run pulse (A) until 3.0 V'. The returned solution only contains up to step 1 of cycle 1.
# 2023-05-09 13:27:35.390 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:27:36.260 - [WARNING] callbacks.on_experiment_infeasible(233):
#
# 	Experiment is infeasible: 'event: Minimum voltage' was triggered during 'Run pulse (A) until 3.0 V'. The returned solution only contains up to step 1 of cycle 1.
# 2023-05-09 13:27:36.720 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:27:37.640 - [WARNING] callbacks.on_experiment_infeasible(233):
#
# 	Experiment is infeasible: 'event: Minimum voltage' was triggered during 'Run pulse (A) until 3.0 V'. The returned solution only contains up to step 1 of cycle 1.
# 2023-05-09 13:27:38.015 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:27:38.898 - [WARNING] callbacks.on_experiment_infeasible(233):
#
# 	Experiment is infeasible: 'event: Minimum voltage' was triggered during 'Run pulse (A) until 3.0 V'. The returned solution only contains up to step 1 of cycle 1.
# 2023-05-09 13:27:39.235 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:27:40.183 - [WARNING] callbacks.on_experiment_infeasible(233):
#
# 	Experiment is infeasible: 'event: Minimum voltage' was triggered during 'Run pulse (A) until 3.0 V'. The returned solution only contains up to step 1 of cycle 1.
# 2023-05-09 13:27:40.526 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:27:41.356 - [WARNING] callbacks.on_experiment_infeasible(233):
#
# 	Experiment is infeasible: 'event: Minimum voltage' was triggered during 'Run pulse (A) until 3.0 V'. The returned solution only contains up to step 1 of cycle 1.
# 2023-05-09 13:27:41.695 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:27:42.488 - [WARNING] callbacks.on_experiment_infeasible(233):
#
# 	Experiment is infeasible: 'event: Minimum voltage' was triggered during 'Run pulse (A) until 3.0 V'. The returned solution only contains up to step 1 of cycle 1.
# 2023-05-09 13:27:42.893 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:27:45.052 - [WARNING] callbacks.on_experiment_infeasible(233):
#
# 	Experiment is infeasible: 'event: Minimum voltage' was triggered during 'Run pulse (A) until 3.0 V'. The returned solution only contains up to step 1 of cycle 1.
# 2023-05-09 13:27:45.566 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:27:46.695 - [WARNING] callbacks.on_experiment_infeasible(233):
#
# 	Experiment is infeasible: 'event: Minimum voltage' was triggered during 'Run pulse (A) until 3.0 V'. The returned solution only contains up to step 1 of cycle 1.
# 2023-05-09 13:27:47.731 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:27:49.080 - [WARNING] callbacks.on_experiment_infeasible(233):
#
# 	Experiment is infeasible: 'event: Minimum voltage' was triggered during 'Run pulse (A) until 3.0 V'. The returned solution only contains up to step 1 of cycle 1.
# 2023-05-09 13:27:49.820 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:27:51.233 - [WARNING] callbacks.on_experiment_infeasible(233):
#
# 	Experiment is infeasible: 'event: Minimum voltage' was triggered during 'Run pulse (A) until 3.0 V'. The returned solution only contains up to step 1 of cycle 1.
# 2023-05-09 13:27:51.962 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:27:53.070 - [WARNING] callbacks.on_experiment_infeasible(233):
#
# 	Experiment is infeasible: 'event: Minimum voltage' was triggered during 'Run pulse (A) until 3.0 V'. The returned solution only contains up to step 1 of cycle 1.
# 2023-05-09 13:27:53.704 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:27:54.634 - [WARNING] callbacks.on_experiment_infeasible(233):
#
# 	Experiment is infeasible: 'event: Minimum voltage' was triggered during 'Run pulse (A) until 3.0 V'. The returned solution only contains up to step 1 of cycle 1.
# 2023-05-09 13:27:55.076 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:27:56.234 - [WARNING] callbacks.on_experiment_infeasible(233):
#
# 	Experiment is infeasible: 'event: Minimum voltage' was triggered during 'Run pulse (A) until 3.0 V'. The returned solution only contains up to step 1 of cycle 1.
# 2023-05-09 13:27:56.832 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:27:57.707 - [WARNING] callbacks.on_experiment_infeasible(233):
#
# 	Experiment is infeasible: 'event: Minimum voltage' was triggered during 'Run pulse (A) until 3.0 V'. The returned solution only contains up to step 1 of cycle 1.
# 2023-05-09 13:27:58.113 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:27:58.951 - [WARNING] callbacks.on_experiment_infeasible(233):
#
# 	Experiment is infeasible: 'event: Minimum voltage' was triggered during 'Run pulse (A) until 3.0 V'. The returned solution only contains up to step 1 of cycle 1.
# 2023-05-09 13:27:59.348 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:28:00.351 - [WARNING] callbacks.on_experiment_infeasible(233):
#
# 	Experiment is infeasible: 'event: Minimum voltage' was triggered during 'Run pulse (A) until 3.0 V'. The returned solution only contains up to step 1 of cycle 1.
# 2023-05-09 13:28:01.608 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:28:04.771 - [WARNING] callbacks.on_experiment_infeasible(233):
#
# 	Experiment is infeasible: 'event: Minimum voltage' was triggered during 'Run pulse (A) until 3.0 V'. The returned solution only contains up to step 1 of cycle 1.
# 2023-05-09 13:28:05.671 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:28:07.959 - [WARNING] callbacks.on_experiment_infeasible(233):
#
# 	Experiment is infeasible: 'event: Minimum voltage' was triggered during 'Run pulse (A) until 3.0 V'. The returned solution only contains up to step 1 of cycle 1.
# 2023-05-09 13:28:08.863 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:28:11.239 - [WARNING] callbacks.on_experiment_infeasible(233):
#
# 	Experiment is infeasible: 'event: Minimum voltage' was triggered during 'Run pulse (A) until 3.0 V'. The returned solution only contains up to step 1 of cycle 1.
# 2023-05-09 13:28:12.180 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:28:18.769 - [WARNING] callbacks.on_experiment_infeasible(233):
#
# 	Experiment is infeasible: 'event: Minimum voltage' was triggered during 'Run pulse (A) until 3.0 V'. The returned solution only contains up to step 1 of cycle 1.
# 2023-05-09 13:28:24.433 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 13:28:25.052 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 2

# %%
# save parameters and soc 
Ds = pd.DataFrame(columns=('SOC', 'kDp','kDn', 'ki0p', 'ki0n','e'))
for i,(k, soc, e) in enumerate(zip(k_list, SOC_list, e_list)):
   Ds.loc[i] = [soc, k[0], k[1], k[2], k[3], e[0]]

display(Ds)
# Ds.to_csv('./fast_discharge/Dsi01.csv')
# Out:
#          SOC       kDp       kDn      ki0p      ki0n         e
# 0   0.928590  0.848000  1.070958  1.881683  2.147217  0.005115
# 1   0.857179  0.772561  1.053477  1.458665  1.552503  0.002354
# 2   0.785771  0.618731  0.937715  1.365904  1.380567  0.001985
# 3   0.714363  0.443352  0.734751  1.233742  1.387005  0.002035
# 4   0.642953  0.278094  1.011894  1.203619  1.347323  0.005241
# 5   0.571544  0.592504  0.206884  0.933023  1.349614  0.002415
# 6   0.500135  0.364772  0.560222  1.145047  1.134645  0.002101
# 7   0.428726  0.230352  0.464591  0.968342  1.035825  0.002835
# 8   0.357318  0.131901  0.468007  0.999866  1.018006  0.004038
# 9   0.285910  0.113754  0.411372  0.905243  1.075859  0.003975
# 10  0.214502  0.727584  0.367484  1.105256  1.066831  0.004813
# 11  0.143095  1.158105  1.521460  0.969077  0.996880  0.015256
# 12  0.071683  0.434147  0.133752  0.705447  0.646744  0.111928

# %% [markdown]
# # Fit single pulse and save

# %%
k_list = []     
k0_list = []                               
SOC_list = []
e_list = []

# %%
pulse_num=9

# %%
Dp_0 = 8.0E-15
Dn_0 = 8.0E-14
i0n_0 = 4.244E-06
i0p_0 = 4.824E-06
lb = np.array([1e-1]*4)
ub =  np.array([1e2]*4)

for i,j in zip(i2[pulse_num:pulse_num+1],i2[pulse_num+1:pulse_num+2]):

    # define pulse data
    pulse = data[i:j].copy()
    pulse.t = pulse.t-pulse.t.iloc[0]

    # define sim parameters
    SOC_0 = pulse.SOC.iloc[0]
    pulse_current = pulse[['t','I']].to_numpy()
    
    # Fit D

    k0 = np.array([SOC_0]*2 + [SOC_0]*2)
    k = dfols.solve(simulate_pulse, k0, bounds = (lb,ub), rhoend=1e-4)
    
    # simulate with k
    # solutions = []
    # nominal
    if len(solutions)>1:
        param.update({
            "Positive electrode diffusivity [m2.s-1]": Dp_0,
            "Negative electrode diffusivity [m2.s-1]": Dn_0,
            "Positive electrode reference exchange-current density [A.m-2(m3.mol)1.5]": i0p_0, 
            "Negative electrode reference exchange-current density [A.m-2(m3.mol)1.5]": i0n_0,
            }, check_already_exists = False)
        sim0 = pybamm.Simulation(model, experiment=experiment, parameter_values = param)
        solution0 = sim0.solve(initial_soc=SOC_0)
        solutions.append(solution0)
    
    # fitted
    param.update({
        "Positive electrode diffusivity [m2.s-1]": Dp_0*k.x[0],
        "Negative electrode diffusivity [m2.s-1]": Dn_0*k.x[1],
        "Positive electrode reference exchange-current density [A.m-2(m3.mol)1.5]": i0p_0*k.x[2], 
        "Negative electrode reference exchange-current density [A.m-2(m3.mol)1.5]": i0n_0*k.x[3],
        }, check_already_exists = False)
    sim = pybamm.Simulation(model, experiment=experiment, parameter_values = param)
    solution = sim.solve(initial_soc=SOC_0)
    solutions.append(solution)

    # plot with 
    plot_pulse(pulse,solutions)

# %%
k.x
# Out:
# array([0.11375403, 0.41137247, 0.90524331, 1.07585944])

# %%
# save values to lists for later
k_list.append(k.x[:])
k0_list.append(k0)
SOC_list.append(pulse.SOC.iloc[-1])  
e_list.append(simulate_pulse(k.x))
# Out:
# 2023-05-09 12:16:56.398 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')

# %%
# save parameters and soc 
Ds = pd.DataFrame(columns=('SOC', 'kDp','kDn', 'ki0p', 'ki0n','e'))
for i,(k, soc, e) in enumerate(zip(k_list, SOC_list, e_list)):
   Ds.loc[i] = [soc, k[0], k[1], k[2], k[3], e[0]]

display(Ds)
# Ds.to_csv('./fast_discharge/Ds16.csv',sep='\t')

# %% [markdown]
# # Fit concentration dependence

# %% [markdown]
# # Polyfit concentration dependence

# %%
def polystr(pk):    
    label = []
    for i, p in enumerate(pk):
        #coeff
        label.append(str(round(p,3)))

        # x^n
        if len(pk)-i-1>1:
            label.append('$x^' + str(len(pk)-i-1) + '$' + ' + ')
        elif i== len(pk)-2:
            label.append('$x$'  + ' + ')

    return ''.join(label)

# %%
k_fit = pd.read_csv('./fast_discharge/Dsi01.csv', usecols=range(1,7)) #
display(k_fit)
# Out:
#          SOC       kDp       kDn      ki0p      ki0n         e
# 0   0.928590  0.848000  1.070958  1.881683  2.147217  0.005115
# 1   0.857179  0.772561  1.053477  1.458665  1.552503  0.002354
# 2   0.785771  0.618731  0.937715  1.365904  1.380567  0.001985
# 3   0.714363  0.443352  0.734751  1.233742  1.387005  0.002035
# 4   0.642953  0.278094  1.011894  1.203619  1.347323  0.005241
# 5   0.571544  0.592504  0.206884  0.933023  1.349614  0.002415
# 6   0.500135  0.364772  0.560222  1.145047  1.134645  0.002101
# 7   0.428726  0.230352  0.464591  0.968342  1.035825  0.002835
# 8   0.357318  0.131901  0.468007  0.999866  1.018006  0.004038
# 9   0.285910  0.113754  0.411372  0.905243  1.075859  0.003975
# 10  0.214502  0.727584  0.367484  1.105256  1.066831  0.004813
# 11  0.143095  1.158105  1.521460  0.969077  0.996880  0.015256
# 12  0.071683  0.434147  0.133752  0.705447  0.646744  0.111928

# %%
# load values
# k_fit = k_fit.iloc[0::]
k_fit= k_fit[k_fit.e<0.01]

# polyfit data
num_plots = len(k_fit.columns)-1
fig, ax = plt.subplots(num_plots,1, figsize=(6,num_plots*2), sharex=True)
ax = ax.flatten()
order = [2,2,2,2,2]
for i,col in enumerate(k_fit):
    if i >0:
        x = np.linspace(0,1,200)
        p = np.polyfit(k_fit.SOC, k_fit[col], order[i-1]) 
        y = np.polyval(p,x)

        # plot fits
        ax[i-1].scatter(k_fit.SOC, k_fit[col], color = 'k')
        ax[i-1].plot(x, y, label = polystr(p) , color = 'k')
        ax[i-1].set_ylabel(col)
        ax[i-1].legend()

ax[i-1].set_xlabel('SOC')
plt.tight_layout()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
Ds0
# Out:
#          SOC        kp        kn         e
# 0   0.928590  1.015607  0.979803  0.010165
# 1   0.857179  0.848269  0.849601  0.005493
# 2   0.785771  0.649258  0.806764  0.004130
# 3   0.714363  0.465132  0.774202  0.003887
# 4   0.642953  0.301661  0.666933  0.007599
# 5   0.571544  0.545960  0.618617  0.003799
# 6   0.500135  0.371549  0.572065  0.002625
# 7   0.428726  0.229748  0.649411  0.002843
# 8   0.285910  0.155254  0.277319  0.005169
# 9   0.214502  0.527034  0.415443  0.005104
# 10  0.143095  1.105328  1.600560  0.015253

# %%
# %matplotlib widget
k_fit = pd.read_csv('./fast_discharge/Dsi01.csv', usecols=range(1,7))
Ds0 = pd.read_csv('./fast_discharge/Ds17.csv', usecols=range(1,5))
Ds = Ds0
fig, ax = plt.subplots(len(Ds), 2, figsize=(10,len(Ds)*2), sharex=True)
# ax = ax.flatten()

Dp_0 = 8.0E-15
Dn_0 = 8.0E-14
i0n_0 = 4.244E-06
i0p_0 = 4.824E-06

for k, (i,j) in enumerate(zip(i2[0:len(Ds)],i2[1::])):
    print(k)

    # define pulse data
    pulse = data[i:j].copy()
    pulse.t = pulse.t-pulse.t.iloc[0]

    # define sim parameters
    SOC_0 = pulse.SOC.iloc[0]
    pulse_current = pulse[['t','I']].to_numpy()

    # simulate with k
    solutions = []
    # nominal
    param.update({
        "Positive electrode diffusivity [m2.s-1]": Dp_0,
        "Negative electrode diffusivity [m2.s-1]": Dn_0,
        "Positive electrode reference exchange-current density [A.m-2(m3.mol)1.5]": i0p_0, 
        "Negative electrode reference exchange-current density [A.m-2(m3.mol)1.5]": i0n_0,
       }, check_already_exists = False)
    sim0 = pybamm.Simulation(model, experiment=experiment, parameter_values = param)
    solution0 = sim0.solve( initial_soc=SOC_0)
    solutions.append(solution0)
    
    # fitted D
    param.update({
        "Positive electrode diffusivity [m2.s-1]": Dp_0*Ds.iloc[k].kp,
        "Negative electrode diffusivity [m2.s-1]": Dn_0*Ds.iloc[k].kn,
        }, check_already_exists = False)
    simD = pybamm.Simulation(model, experiment=experiment, parameter_values = param)
    solutionD = simD.solve( initial_soc=SOC_0)
    solutions.append(solutionD)

    # fitted D and i0
    # display(k_fit.iloc[k])
    param.update({
        "Positive electrode diffusivity [m2.s-1]": Dp_0*k_fit.iloc[k].kDp,
        "Negative electrode diffusivity [m2.s-1]": Dn_0*k_fit.iloc[k].kDn,
        "Positive electrode reference exchange-current density [A.m-2(m3.mol)1.5]": i0p_0*k_fit.iloc[k].ki0p, 
        "Negative electrode reference exchange-current density [A.m-2(m3.mol)1.5]": i0n_0*k_fit.iloc[k].ki0n,
        }, check_already_exists = False)
    simDi0 = pybamm.Simulation(model, experiment=experiment, parameter_values = param)
    solutionDi0 = simDi0.solve( initial_soc=SOC_0)
    solutions.append(solutionDi0)

    # plot with 
    ax[k,0].plot(pulse.t, pulse.V, color = 'k')
    ax[k,0].set_xlabel(xlabel)
    ax[k,0].set_ylabel('Terminal voltage [V]')
    
    colors = ['r','g', 'b']
    linestyles = ['-', ':', '-.']
    for j,solution in enumerate(solutions):
        t = solution["Time [s]"].entries
        V = solution['Terminal voltage [V]']
        ax[k,0].plot(t, V(t), color = colors[j], linestyle = linestyles[j])
        ax[k,0].legend(["Data", "Nominal", "Fitted $D$", "Fitted $D$ & $i_0$"])

        e_V = abs(pulse.V - V(pulse.t))
        ax[k,1].plot(pulse.t, e_V, color = colors[j], linestyle = linestyles[j])
        ax[k,1].set_xlabel(xlabel)
        ax[k,1].set_ylabel('|Error [V]|')

plt.subplots_adjust(bottom=0.05, top=0.99)
# Out:
# 0
# 1
# 2023-05-09 16:22:34.497 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 16:22:34.986 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 16:22:35.453 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2
# 2023-05-09 16:22:40.665 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 16:22:41.228 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 16:22:41.707 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 3
# 2023-05-09 16:22:46.709 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 16:22:47.268 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 16:22:47.785 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 4
# 2023-05-09 16:22:52.510 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 16:22:53.001 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 16:22:53.484 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 5
# 2023-05-09 16:22:58.229 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 16:22:58.863 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 16:22:59.520 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 6
# 2023-05-09 16:23:04.302 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 16:23:04.841 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 16:23:05.354 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 7
# 2023-05-09 16:23:10.663 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 16:23:11.186 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 16:23:11.725 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 8
# 2023-05-09 16:23:18.014 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 16:23:18.529 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 16:23:19.034 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 9
# 2023-05-09 16:23:23.845 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 16:23:24.371 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-09 16:23:24.857 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 10
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
