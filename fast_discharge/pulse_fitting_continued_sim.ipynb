# %% [markdown]
# # Single Particle Model (SPM): Fast discharge with concentration dependent diffusion

# %% [markdown]
# ## Model Equations

# %% [markdown]
# The SPM consists of two spherically symmetric diffusion equations: one within a representative negative particle ($\text{k}=\text{n}$) and one within a representative positive particle ($\text{k}=\text{p}$). In the centre of the particle the standard no-flux condition is imposed. Since the SPM assumes that all particles in an electrode behave in exactly the same way, the flux on the surface of a particle is simply the current $I$ divided by the thickness of the electrode $L_{\text{k}}$. The concentration of lithium in electrode $\text{k}$ is denoted $c_{\text{k}}$ and the current is denoted by $I$. All parameters in the model stated here are dimensionless and are given in terms of dimensional parameters at the end of this notebook. The model equations for the SPM are then:
# $$
# \begin{align}
# \mathcal{C}_{\text{k}} \frac{\partial c_{\text{s,k}}}{\partial t} &= -\frac{1}{r_{\text{k}}^2} \frac{\partial}{\partial r_{\text{k}}} \left(r_{\text{k}}^2 N_{\text{s,k}}\right), \\
# N_{\text{s,k}} &= -D_{\text{s,k}}(c_{\text{s,k}}) \frac{\partial c_{\text{s,k}}}{\partial r_{\text{k}}}, \quad \text{k} \in \text{n, p},
# \end{align}
# $$
# $$
# N_{\text{s,k}}\big|_{r_{\text{k}}=0} = 0, \quad \text{k} \in \text{n, p}, \quad \ \ - \frac{a_{R, \text{k}}\gamma_{\text{k}}}{\mathcal{C}_{\text{k}}} N_{\text{s,k}}\big|_{r_{\text{k}}=1} =
# \begin{cases}
# 		  \frac{I}{L_{\text{n}}}, \quad &\text{k}=\text{n}, \\
# 		  -\frac{I}{L_{\text{p}}}, \quad &\text{k}=\text{p},
# \end{cases} \\
# c_{\text{s,k}}(r_{\text{k}},0) = c_{\text{s,k,0}}, \quad \text{k} \in \text{n, p},$$
# where $D_{\text{s,k}}$ is the diffusion coefficient in the solid, $N_{\text{s,k}}$ denotes the flux of lithium ions in the solid particle within the region $\text{k}$, and $r_{\text{k}} \in[0,1]$ is the radial coordinate of the particle in electrode $\text{k}$.
#
# ### Voltage Expression
# The terminal voltage is obtained from the expression:
# $$
# V = U_{\text{p}}(c_{\text{p}})\big|_{r_{\text{p}}=1} - U_{\text{n}}(c_{\text{n}})\big|_{r_{\text{n}}=1} -2\sinh^{-1}\left(\frac{I}{j_{\text{0,p}} L_{\text{p}}}\right) - 2\sinh^{-1}\left(\frac{I}{j_{\text{0,n}} L_{\text{n}}}\right)
# $$
# with the exchange current densities given by
# $$j_{\text{0,k}} =  \frac{\gamma_{\text{k}}}{\mathcal{C}_{\text{r,k}}}(c_{\text{k}})^{1/2}(1-c_{\text{k}})^{1/2}  $$
#
# More details can be found in [[3]](#References).

# %% [markdown]
# ## Example solving SPM using PyBaMM
#
# Below we show how to solve the Single Particle Model, using the default geometry, mesh, parameters, discretisation and solver provided with PyBaMM. In this notebook we explicitly handle all the stages of setting up, processing and solving the model in order to explain them in detail. However, it is often simpler in practice to use the `Simulation` class, which handles many of the stages automatically, as shown [here](../simulation-class.ipynb).
#
# First we need to import `pybamm`, and then change our working directory to the root of the pybamm folder.

# %%
# %pip install DFO-LS -q
# need to restart jupyter server? kernal? whenever a change is made to the pybamm module? 
import sys
import os
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
os.chdir(sys.path[0] + '\..') # change our working directory to the root of the pybamm folder
import pybamm
import dfols
from scipy.optimize import curve_fit

# from multiprocessing import Process, Pool

# from scipy.optimize import minimize
print(pybamm.__path__[0])
# %matplotlib widget
# Out:
# c:\Users\Vivian\Dropbox (University of Michigan)\from_box\Research\PyBaMM\PyBaMM\pybamm

# %% [markdown]
# # Load pulse testing data

# %%
data = pd.read_csv(
    "./fast_discharge/2C_pulse_test_data_DCR_Cell_43.csv"#, comment="#", header=None
)
df_labels = ['t', 'V', 'AhT','Temp', 'Q', 'I']
data.set_axis(df_labels, axis=1, inplace=True)
data.AhT = -data.AhT/1000 
data['I_C'] = data.I/4.6
data['SOC'] = 1-data.AhT/4.2
data
# Out:
# C:\Users\Vivian\AppData\Local\Temp\ipykernel_22216\1251893854.py:5: FutureWarning: DataFrame.set_axis 'inplace' keyword is deprecated and will be removed in a future version. Use `obj = obj.set_axis(..., copy=False)` instead
#   data.set_axis(df_labels, axis=1, inplace=True)
#                 t         V       AhT       Temp            Q         I  \
# 0        0.000000  4.196902 -0.000000  22.914967  2292.862303 -0.000000
# 1       10.000000  4.196824 -0.000000  23.048939  2292.862303 -0.000000
# 2       20.000001  4.196784 -0.000000  22.993774  2292.862303 -0.000000
# 3       30.000001  4.196745 -0.000000  22.993774  2292.862303 -0.000000
# 4       40.000002  4.196627 -0.000000  22.788877  2292.862303 -0.000000
# ...           ...       ...       ...        ...          ...       ...
# 4096  5602.088266  3.204265  4.073620  24.183754  4072.425625  8.995825
# 4097  5612.088267  3.162594  4.098613  24.231037  4097.418306  8.995825
# 4098  5622.088267  3.106940  4.123605  24.412292  4122.410880  8.996416
# 4099  5632.088268  3.029937  4.148598  24.459576  4147.403525  8.997204
# 4100  5639.608268  2.949981  4.167393  24.640831  4166.198008  8.996220
#
#            I_C       SOC
# 0    -0.000000  1.000000
# 1    -0.000000  1.000000
# 2    -0.000000  1.000000
# 3    -0.000000  1.000000
# 4    -0.000000  1.000000
# ...        ...       ...
# 4096  1.955614  0.030090
# 4097  1.955614  0.024140
# 4098  1.955743  0.018189
# 4099  1.955914  0.012239
# 4100  1.955700  0.007764
#
# [4101 rows x 8 columns]

# %% [markdown]
# # Find and plot indices of pulse rest

# %%
# find pulse indices
I = data.I
pulse_current = max(I)
i1 = np.where((np.diff(I)<-0.1))[0]
i1 = i1+1
# i1 = np.append(i1,len(I)-1)
i2 = np.where((np.diff(I)>0.1) & (I[1:]>pulse_current-0.1)& (I[1:]<pulse_current+0.1))[0]
# i2 = np.insert(i2,0,1)
# plot
fig, ax = plt.subplots(2,2, figsize=(8,4), sharex=True)
ax = ax.flatten()
linestyles = ['-','--',':','.-']*2

t = data.t/60
xlabel = "Time [min]"
data_color = 'k'
ax[0].plot(t,data.I_C, label='Data', color = data_color)
ax[0].scatter(t[i1], data.I_C[i1])
ax[0].scatter(t[i2], data.I_C[i2])
ax[0].set_xlabel(xlabel)
ax[0].set_ylabel('C-rate')

ax[2].plot(t, data.V,color = data_color)
ax[2].scatter(t[i1], data.V[i1])
ax[2].scatter(t[i2], data.V[i2])
ax[2].set_xlabel(xlabel)
ax[2].set_ylabel('Terminal voltage [V]')

ax[1].plot(t, data.Temp, color = data_color)
ax[1].scatter(t[i1], data.Temp[i1])
ax[1].scatter(t[i2], data.Temp[i2])
ax[1].set_xlabel(xlabel)
ax[1].set_ylabel('Temperature [$^\circ$C]')

ax[3].plot(t, data.SOC, color = data_color)
ax[3].scatter(t[i1], data.SOC[i1])
ax[3].scatter(t[i2], data.SOC[i2])
ax[3].set_xlabel(xlabel)
ax[3].set_ylabel('SOC')

plt.tight_layout()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
def plot_pulse(data, solutions, labels = []):
    fig, ax = plt.subplots(2,2, figsize=(8,4), sharex=True)
    ax = ax.flatten()
    linestyles = ['-','--',':','.-']*2

    t = data.t/60
    xlabel = "Time [min]"
    data_color = 'k'
    ax[0].plot(t,data.I_C, label='Data', color = data_color)
    ax[0].set_xlabel(xlabel)
    ax[0].set_ylabel('C-rate')


    ax[2].plot(t, data.V,color = data_color)
    ax[2].set_xlabel(xlabel)
    ax[2].set_ylabel('Terminal voltage [V]')

    ax[1].plot(t, data.Temp, color = data_color)
    ax[1].set_xlabel(xlabel)
    ax[1].set_ylabel('Temperature [$^\circ$C]')

    ax[3].plot(t, data.SOC, color = data_color)
    ax[3].set_xlabel(xlabel)
    ax[3].set_ylabel('SOC')

    sim_colors = ['r','g','b','m']*2
    for i,solution in enumerate(solutions):
        t = solution["Time [s]"].entries
        x = solution["x [m]"].entries[:, 0]
        I = solution['C-rate']
        V = solution['Terminal voltage [V]']
        T = solution['Volume-averaged cell temperature [K]'].entries - 273.15
        soc = solution['R-averaged negative particle concentration']

        x_plot = t/60
        ax[0].plot(x_plot, I(t), linestyle=':',color = sim_colors[i])
        ax[2].plot(x_plot, V(t), linestyle=':',color = sim_colors[i])
        ax[1].plot(x_plot, T,linestyle=':',color = sim_colors[i])  # can evaluate at arbitrary x (single representative particle)
        ax[3].plot(x_plot, soc(t=t, x=x[-1]),linestyle=':',color = sim_colors[i])  # can evaluate at arbitrary x (single representative particle)


    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Set up nominal model

# %%
# set up pulse data
pulse = data[i2[0]:i2[1]].copy()
pulse.t = pulse.t-pulse.t.iloc[0]

# define parameters for simulation
SOC_0 = pulse.SOC.iloc[0]
pulse_current = pulse[['t','I']].to_numpy()

# set up and solve model
solutions = []
options = {
    # "thermal": "x-lumped",
}
nominal_model = pybamm.lithium_ion.SPMe(options = options)
param = pybamm.ParameterValues(pybamm.parameter_sets.Mohtat2020)
param.update({
    "Lower voltage cut-off [V]": 0,
    "Nominal cell capacity [A.h]": 4.6,
    "Typical current [A]":4.6,
    "Negative tab width [m]":2.5e-2,
    "Positive tab width [m]":2.5e-2,
    "Negative electrode thickness [m]":62E-06*4.2/5,
    "Positive electrode thickness [m]":67E-06*4.2/5,
    "Negative current collector surface heat transfer coefficient [W.m-2.K-1]": 5,  
    "Positive current collector surface heat transfer coefficient [W.m-2.K-1]": 5,  
    "Negative electrode specific heat capacity [J.kg-1.K-1]": 1100*1.5,
    "Positive electrode specific heat capacity [J.kg-1.K-1]": 1100*1.5,
    "Negative tab heat transfer coefficient [W.m-2.K-1]":5,  
    "Positive tab heat transfer coefficient [W.m-2.K-1]":5,  
    "Edge heat transfer coefficient [W.m-2.K-1]":5,
    "Total heat transfer coefficient [W.m-2.K-1]":5,
    "Negative electrode diffusivity [m2.s-1]": 8.0E-14, 
    "Positive electrode diffusivity [m2.s-1]": 8.0E-15,
    "Negative electrode reference exchange-current density [A.m-2(m3.mol)1.5]": 4.244E-06, 
    "Positive electrode reference exchange-current density [A.m-2(m3.mol)1.5]": 4.824E-06,
    "Ambient temperature [K]": 23+273.15,
    "Initial temperature [K]": 23 + 273.15,

    # "Typical electrolyte diffusivity [m2.s-1]": 5.35 * 10 ** (-10)*10,
    # "Typical electrolyte conductivity [m2.s-1]":1.3*10,

}, check_already_exists = False)
experiment = pybamm.Experiment(
        [
        "Run pulse (A) until 3.0 V"
        ],
        drive_cycles={
            'pulse': pulse_current
        }
    )
sim = pybamm.Simulation(nominal_model, experiment=experiment, parameter_values = param)
solution = sim.solve( initial_soc=SOC_0)
solutions.append(solution)

# plot simulation results 
plot_pulse(pulse,solutions)
# Out:
# 2023-05-09 09:53:54.412 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %% [markdown]
# # Set up loss function for parameterization

# %%
# # run simulation with input k to scale D and output error metric
# # Input and output are np.array
def pulse_error(k:np.ndarray, model = nominal_model): 
    Dp_0 = 8.0E-15
    Dn_0 = 8.0E-14

    param.update({
        "Positive electrode diffusivity [m2.s-1]": Dp_0*k[0],
        "Negative electrode diffusivity [m2.s-1]": Dn_0*k[1],
        })
    sim = pybamm.Simulation(model, experiment=experiment, parameter_values = param)
    solution = sim.solve(initial_soc=SOC_0)
    
    # calculate rmse for rest period
    V = solution['Terminal voltage [V]']
    t_error = pulse.t[(pulse.V > 3.0)].to_numpy() #  & (pulse.I ==0)
    rmse_V = np.sqrt(np.mean(np.square(pulse.V[(pulse.V > 3.0)]- V(t_error))))
    # rmse_V = np.sum(np.square(pulse.V[(pulse.V > 3.0)]- V(t_error)))
    # rmse_dV = np.sqrt(np.mean(np.square(np.diff(pulse.V[(pulse.V > 3.0)])- np.diff(V(t_error)))))
    # rmse_V = np.sum(np.square(pulse.V[(pulse.V > 3.0)]- V(t_error)))

    return np.array([rmse_V])
    

# test function
print(pulse_error(np.array([1,1]), nominal_model))


def pulse_error_pos(kp:np.ndarray, kn, model = nominal_model): 
    Dp_0 = 8.0E-15
    Dn_0 = 8.0E-14

    param.update({
        "Positive electrode diffusivity [m2.s-1]": Dp_0*kp[0],
        "Negative electrode diffusivity [m2.s-1]": Dn_0*kn,
        })
    sim = pybamm.Simulation(model, experiment=experiment, parameter_values = param)
    solution = sim.solve(initial_soc=SOC_0)
    
    # calculate rmse for rest period
    V = solution['Terminal voltage [V]']
    t_error = pulse.t[(pulse.V > 3.0)].to_numpy() #  & (pulse.I ==0)
    rmse_V = np.sqrt(np.mean(np.square(pulse.V[(pulse.V > 3.0)]- V(t_error))))
    # rmse_V = np.sum(np.square(pulse.V[(pulse.V > 3.0)]- V(t_error)))
    # rmse_dV = np.sqrt(np.mean(np.square(np.diff(pulse.V[(pulse.V > 3.0)])- np.diff(V(t_error)))))
    # rmse_V = np.sum(np.square(pulse.V[(pulse.V > 3.0)]- V(t_error)))

    return np.array([rmse_V])
print(pulse_error_pos(np.array([1]), 1, model = nominal_model))

def pulse_error_neg(kn:np.ndarray, kp, model = nominal_model): 
    Dp_0 = 8.0E-15
    Dn_0 = 8.0E-14

    param.update({
        "Positive electrode diffusivity [m2.s-1]": Dp_0*kp,
        "Negative electrode diffusivity [m2.s-1]": Dn_0*kn[0],
        })
    sim = pybamm.Simulation(model, experiment=experiment, parameter_values = param)
    solution = sim.solve(initial_soc=SOC_0)
    
    # calculate rmse for rest period
    V = solution['Terminal voltage [V]']
    t_error = pulse.t[(pulse.V > 3.0)].to_numpy() #  & (pulse.I ==0)
    rmse_V = np.sqrt(np.mean(np.square(pulse.V[(pulse.V > 3.0)]- V(t_error))))
    # rmse_V = np.sum(np.square(pulse.V[(pulse.V > 3.0)]- V(t_error)))
    # rmse_dV = np.sqrt(np.mean(np.square(np.diff(pulse.V[(pulse.V > 3.0)& (pulse.I ==0)])- np.diff(V(t_error)))))
    # rmse_V = np.sum(np.square(pulse.V[(pulse.V > 3.0)]- V(t_error)))

    return np.array([rmse_V])
print(pulse_error_neg(np.array([1]), 1, model = nominal_model))

# run simulation with input k to scale D and output error metric
# Input and output are np.array
def pulse_error_dV(k:np.ndarray, model = nominal_model): 
    Dp_0 = 8.0E-15
    Dn_0 = 8.0E-14

    param.update({
        "Positive electrode diffusivity [m2.s-1]": Dp_0*k[0],
        "Negative electrode diffusivity [m2.s-1]": Dn_0*k[1],
        })
    sim = pybamm.Simulation(model, experiment=experiment, parameter_values = param)
    solution = sim.solve(initial_soc=SOC_0)
    
    # calculate rmse for rest period
    V = solution['Terminal voltage [V]']
    t_error = pulse.t[(pulse.V > 3.0)].to_numpy() #  & (pulse.I ==0)
    # rmse_V = np.sqrt(np.mean(np.square(pulse.V[(pulse.V > 3.0)]- V(t_error))))
    # rmse_V = np.sum(np.square(pulse.V[(pulse.V > 3.0)]- V(t_error)))
    e_dV = np.sum(np.diff(pulse.V[pulse.V > 3.0])- np.diff(V(t_error)))

    return np.array([e_dV])

# test function
print(pulse_error_dV(np.array([0.5,0.5]), model = nominal_model))
# Out:
# [0.00601915]
# [0.00601915]
# [0.00601915]
# [0.00284378]

# %% [markdown]
# # Fit single pulse and save

# %%
k_list = []     
k0_list = []                               
SOC_list = []
e_list = []

# %%
pulse_num=12

# %%
aDp_0 = 8.0E-15
Dn_0 = 8.0E-14
lb = np.array([1e-1]*2)
ub = np.array([1e1]*2)

for i,j in zip(i2[pulse_num:pulse_num+1],i2[pulse_num+1:pulse_num+2]):

    # define pulse data
    pulse = data[i:j].copy()
    pulse.t = pulse.t-pulse.t.iloc[0]

    # define sim parameters
    SOC_0 = pulse.SOC.iloc[0]
    pulse_current = pulse[['t','I']].to_numpy()
       
    # Fit D
    # if SOC_0 < 0.2:
    #     k0 = np.array([0.8, 1])
    # else:
    #     k0 = np.array([SOC_0,1])   
    k0 = np.array([SOC_0,1])   
    k = dfols.solve(pulse_error, k0, bounds = (lb,ub), rhoend=1e-2)

    # iters = 0
    # rmse_V = pulse_error(k0)
    # while  rmse_V > 0.002 and iters<3:  
    #     k = dfols.solve(pulse_error, k0, bounds = (lb,ub), rhoend=1e-2)
    #     k0 = k.x
    #     rmse_V = pulse_error(k0)
    #     iters = iters+1
    #     print(iters)
    
    # simulate with k
    solutions = []
    # nominal
    param.update({
        "Positive electrode diffusivity [m2.s-1]": Dp_0,
        "Negative electrode diffusivity [m2.s-1]": Dn_0,
        "Negative electrode thickness [m]":62E-06*4.2/5,
        "Positive electrode thickness [m]":67E-06*4.2/5,
        })
    sim0 = pybamm.Simulation(nominal_model, experiment=experiment, parameter_values = param)
    solution0 = sim.solve( initial_soc=SOC_0)
    solutions.append(solution0)
    
    # fitted
    param.update({
        "Positive electrode diffusivity [m2.s-1]": Dp_0*k.x[0],
        "Negative electrode diffusivity [m2.s-1]": Dn_0*k.x[1],
        })
        
    sim = pybamm.Simulation(nominal_model, experiment=experiment, parameter_values = param)
    solution = sim.solve( initial_soc=SOC_0)
    solutions.append(solution)

    # plot with 
    plot_pulse(pulse,solutions)
# Out:
# 2023-05-08 14:39:35.398 - [WARNING] callbacks.on_experiment_infeasible(233):
#
# 	Experiment is infeasible: 'event: Minimum voltage' was triggered during 'Run pulse (A) until 3.0 V'. The returned solution only contains up to step 1 of cycle 1.
# 2023-05-08 14:39:35.652 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-08 14:39:37.835 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-08 14:39:38.376 - [WARNING] callbacks.on_experiment_infeasible(233):
#
# 	Experiment is infeasible: 'event: Minimum voltage' was triggered during 'Run pulse (A) until 3.0 V'. The returned solution only contains up to step 1 of cycle 1.
# 2023-05-08 14:39:38.609 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-08 14:39:39.043 - [WARNING] callbacks.on_experiment_infeasible(233):
#
# 	Experiment is infeasible: 'event: Minimum voltage' was triggered during 'Run pulse (A) until 3.0 V'. The returned solution only contains up to step 1 of cycle 1.
# 2023-05-08 14:39:39.254 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-08 14:39:39.788 - [WARNING] callbacks.on_experiment_infeasible(233):
#
# 	Experiment is infeasible: 'event: Minimum voltage' was triggered during 'Run pulse (A) until 3.0 V'. The returned solution only contains up to step 1 of cycle 1.
# 2023-05-08 14:39:40.079 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-08 14:39:41.118 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-08 14:39:42.402 - [WARNING] callbacks.on_experiment_infeasible(233):
#
# 	Experiment is infeasible: 'event: Minimum voltage' was triggered during 'Run pulse (A) until 3.0 V'. The returned solution only contains up to step 1 of cycle 1.
# 2023-05-08 14:39:43.789 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-08 14:39:44.010 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# save values to lists for later
# k_list.append(k.x[:])
# k0_list.append(k0)
# SOC_list.append(pulse.SOC.iloc[-1])  
# e_list.append(pulse_error(k.x))

# %%
# save parameters and soc 
Ds = pd.DataFrame(columns=('SOC', 'kp','kn','e', 'k0'))
for i,(k, soc, e, k0) in enumerate(zip(k_list, SOC_list, e_list, k0_list)):
   Ds.loc[i] = [soc, k[0], k[1],e[0], k0[:]]

display(Ds)
# Ds.to_csv('./fast_discharge/Ds8_rmse_V.csv',sep='\t')
# Out:
# Empty DataFrame
# Columns: [SOC, kp, kn, e, k0]
# Index: []

# %% [markdown]
# # Fit all pulses (positive and negative)

# %%
Dp_0 = 8.0E-15
Dn_0 = 8.0E-14
i0p_0 = 4.244E-06
i0n_0 = 4.824E-06
lb = np.array([1e-1]*2)
ub =  np.array([1e2]*2)
k_list = []                               
SOC_list = []
e_list = []

# for each pulse...
for c,(i,j) in enumerate(zip(i2[0:-1],i2[1::])): #zip(i2[0:-1],i2[1::])
    print(c)

    # define pulse data
    pulse = data[i:j].copy()
    pulse.t = pulse.t-pulse.t.iloc[0]

    # define sim parameters
    SOC_0 = pulse.SOC.iloc[0]
    pulse_current = pulse[['t','I']].to_numpy()
    experiment = pybamm.Experiment(
        [
        "Run pulse (A) until 3.0 V"
        ],
        drive_cycles={
            'pulse': pulse_current
        }
    )
       
    # define model 
    if c==0:
        model = pybamm.lithium_ion.SPMe()
    else:
        model.set_initial_conditions_from(solution, inplace=True)

    # Fit D
    k0 = np.array([SOC_0]*2)
    k = dfols.solve(pulse_error, k0, bounds = (lb,ub), rhoend=1e-2)

    # save values 
    k_list.append(k.x)
    SOC_list.append(pulse.SOC.iloc[-1])  
    e_list.append(pulse_error_dV(k.x))

    # simulate with k
    solutions = []
    # nominal
    param.update({
        "Positive electrode diffusivity [m2.s-1]": Dp_0,
        "Negative electrode diffusivity [m2.s-1]": Dn_0,
        })
    sim0 = pybamm.Simulation(pybamm.lithium_ion.SPMe(), experiment = experiment, parameter_values = param)
    solution0 = sim.solve(initial_soc=SOC_0)
    solutions.append(solution0)
    
    # fitted
    param.update({
        "Positive electrode diffusivity [m2.s-1]": Dp_0*k_list[c][0],
        "Negative electrode diffusivity [m2.s-1]": Dn_0*k_list[c][1],
        })
    sim = pybamm.Simulation(model, experiment = experiment, parameter_values = param)
    solution = sim.solve(initial_soc=SOC_0)
    solutions.append(solution)

    # plot with 
    plot_pulse(pulse,solutions)

    # save model
    # old_model = model.new_copy
# Out:
# 0
# 2023-05-08 14:45:52.467 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-08 14:45:53.919 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 1
# 2023-05-08 14:46:35.100 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-08 14:46:37.330 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 2
# 2023-05-08 14:47:16.657 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-08 14:47:18.540 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 3
# 2023-05-08 14:47:48.169 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-08 14:47:49.802 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 4
# 2023-05-08 14:48:13.787 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-08 14:48:15.383 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 5
# 2023-05-08 14:48:36.970 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-08 14:48:38.492 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 6
# 2023-05-08 14:49:06.084 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-08 14:49:08.483 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 7
# 2023-05-08 14:49:35.727 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-08 14:49:37.162 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 8
# 2023-05-08 14:49:58.846 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-08 14:50:00.802 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 9
# 2023-05-08 14:50:25.661 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-08 14:50:27.100 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 10
# 2023-05-08 14:50:54.353 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-08 14:50:55.800 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 11
# 2023-05-08 14:51:36.787 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-08 14:51:38.203 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# 12
# 2023-05-08 14:51:39.160 - [WARNING] callbacks.on_experiment_infeasible(233):
#
# 	Experiment is infeasible: 'event: Minimum voltage' was triggered during 'Run pulse (A) until 3.0 V'. The returned solution only contains up to step 1 of cycle 1.
# 2023-05-08 14:51:39.445 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-08 14:51:39.963 - [WARNING] callbacks.on_experiment_infeasible(233):
#
# 	Experiment is infeasible: 'event: Minimum voltage' was triggered during 'Run pulse (A) until 3.0 V'. The returned solution only contains up to step 1 of cycle 1.
# 2023-05-08 14:51:40.222 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-08 14:51:40.711 - [WARNING] callbacks.on_experiment_infeasible(233):
#
# 	Experiment is infeasible: 'event: Minimum voltage' was triggered during 'Run pulse (A) until 3.0 V'. The returned solution only contains up to step 1 of cycle 1.
# 2023-05-08 14:51:41.000 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-08 14:51:41.492 - [WARNING] callbacks.on_experiment_infeasible(233):
#
# 	Experiment is infeasible: 'event: Minimum voltage' was triggered during 'Run pulse (A) until 3.0 V'. The returned solution only contains up to step 1 of cycle 1.
# 2023-05-08 14:51:41.728 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-08 14:51:42.223 - [WARNING] callbacks.on_experiment_infeasible(233):
#
# 	Experiment is infeasible: 'event: Minimum voltage' was triggered during 'Run pulse (A) until 3.0 V'. The returned solution only contains up to step 1 of cycle 1.
# 2023-05-08 14:51:42.467 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-08 14:51:42.966 - [WARNING] callbacks.on_experiment_infeasible(233):
#
# 	Experiment is infeasible: 'event: Minimum voltage' was triggered during 'Run pulse (A) until 3.0 V'. The returned solution only contains up to step 1 of cycle 1.
# 2023-05-08 14:51:43.203 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-08 14:51:43.705 - [WARNING] callbacks.on_experiment_infeasible(233):
#
# 	Experiment is infeasible: 'event: Minimum voltage' was triggered during 'Run pulse (A) until 3.0 V'. The returned solution only contains up to step 1 of cycle 1.
# 2023-05-08 14:51:43.951 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-08 14:51:44.439 - [WARNING] callbacks.on_experiment_infeasible(233):
#
# 	Experiment is infeasible: 'event: Minimum voltage' was triggered during 'Run pulse (A) until 3.0 V'. The returned solution only contains up to step 1 of cycle 1.
# 2023-05-08 14:51:44.682 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-08 14:51:45.162 - [WARNING] callbacks.on_experiment_infeasible(233):
#
# 	Experiment is infeasible: 'event: Minimum voltage' was triggered during 'Run pulse (A) until 3.0 V'. The returned solution only contains up to step 1 of cycle 1.
# 2023-05-08 14:51:45.477 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-08 14:51:46.104 - [WARNING] callbacks.on_experiment_infeasible(233):
#
# 	Experiment is infeasible: 'event: Minimum voltage' was triggered during 'Run pulse (A) until 3.0 V'. The returned solution only contains up to step 1 of cycle 1.
# 2023-05-08 14:51:46.399 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-08 14:51:46.995 - [WARNING] callbacks.on_experiment_infeasible(233):
#
# 	Experiment is infeasible: 'event: Minimum voltage' was triggered during 'Run pulse (A) until 3.0 V'. The returned solution only contains up to step 1 of cycle 1.
# 2023-05-08 14:51:47.249 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-08 14:51:47.787 - [WARNING] callbacks.on_experiment_infeasible(233):
#
# 	Experiment is infeasible: 'event: Minimum voltage' was triggered during 'Run pulse (A) until 3.0 V'. The returned solution only contains up to step 1 of cycle 1.
# 2023-05-08 14:51:48.070 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-08 14:51:48.645 - [WARNING] callbacks.on_experiment_infeasible(233):
#
# 	Experiment is infeasible: 'event: Minimum voltage' was triggered during 'Run pulse (A) until 3.0 V'. The returned solution only contains up to step 1 of cycle 1.
# 2023-05-08 14:51:48.903 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-08 14:51:49.493 - [WARNING] callbacks.on_experiment_infeasible(233):
#
# 	Experiment is infeasible: 'event: Minimum voltage' was triggered during 'Run pulse (A) until 3.0 V'. The returned solution only contains up to step 1 of cycle 1.
# 2023-05-08 14:51:49.731 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-08 14:51:50.222 - [WARNING] callbacks.on_experiment_infeasible(233):
#
# 	Experiment is infeasible: 'event: Minimum voltage' was triggered during 'Run pulse (A) until 3.0 V'. The returned solution only contains up to step 1 of cycle 1.
# 2023-05-08 14:51:50.472 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-08 14:51:50.962 - [WARNING] callbacks.on_experiment_infeasible(233):
#
# 	Experiment is infeasible: 'event: Minimum voltage' was triggered during 'Run pulse (A) until 3.0 V'. The returned solution only contains up to step 1 of cycle 1.
# 2023-05-08 14:51:51.214 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-08 14:51:52.758 - [WARNING] callbacks.on_experiment_infeasible(233):
#
# 	Experiment is infeasible: 'event: Minimum voltage' was triggered during 'Run pulse (A) until 3.0 V'. The returned solution only contains up to step 1 of cycle 1.
# 2023-05-08 14:51:53.025 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-08 14:51:53.512 - [WARNING] callbacks.on_experiment_infeasible(233):
#
# 	Experiment is infeasible: 'event: Minimum voltage' was triggered during 'Run pulse (A) until 3.0 V'. The returned solution only contains up to step 1 of cycle 1.
# 2023-05-08 14:51:53.745 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-08 14:51:54.240 - [WARNING] callbacks.on_experiment_infeasible(233):
#
# 	Experiment is infeasible: 'event: Minimum voltage' was triggered during 'Run pulse (A) until 3.0 V'. The returned solution only contains up to step 1 of cycle 1.
# 2023-05-08 14:51:54.490 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-08 14:51:54.974 - [WARNING] callbacks.on_experiment_infeasible(233):
#
# 	Experiment is infeasible: 'event: Minimum voltage' was triggered during 'Run pulse (A) until 3.0 V'. The returned solution only contains up to step 1 of cycle 1.
# 2023-05-08 14:51:55.199 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-08 14:51:55.688 - [WARNING] callbacks.on_experiment_infeasible(233):
#
# 	Experiment is infeasible: 'event: Minimum voltage' was triggered during 'Run pulse (A) until 3.0 V'. The returned solution only contains up to step 1 of cycle 1.
# 2023-05-08 14:51:55.928 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-08 14:51:56.394 - [WARNING] callbacks.on_experiment_infeasible(233):
#
# 	Experiment is infeasible: 'event: Minimum voltage' was triggered during 'Run pulse (A) until 3.0 V'. The returned solution only contains up to step 1 of cycle 1.
# 2023-05-08 14:51:56.630 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-08 14:52:03.308 - [WARNING] callbacks.on_experiment_infeasible(233):
#
# 	Experiment is infeasible: 'event: Minimum voltage' was triggered during 'Run pulse (A) until 3.0 V'. The returned solution only contains up to step 1 of cycle 1.
# 2023-05-08 14:52:03.539 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-08 14:52:07.992 - [WARNING] callbacks.on_experiment_infeasible(233):
#
# 	Experiment is infeasible: 'event: Minimum voltage' was triggered during 'Run pulse (A) until 3.0 V'. The returned solution only contains up to step 1 of cycle 1.
# 2023-05-08 14:52:08.236 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-08 14:52:11.368 - [WARNING] callbacks.on_experiment_infeasible(233):
#
# 	Experiment is infeasible: 'event: Minimum voltage' was triggered during 'Run pulse (A) until 3.0 V'. The returned solution only contains up to step 1 of cycle 1.
# 2023-05-08 14:52:11.596 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-08 14:52:13.436 - [WARNING] callbacks.on_experiment_infeasible(233):
#
# 	Experiment is infeasible: 'event: Minimum voltage' was triggered during 'Run pulse (A) until 3.0 V'. The returned solution only contains up to step 1 of cycle 1.
# 2023-05-08 14:52:13.692 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-08 14:52:19.193 - [WARNING] callbacks.on_experiment_infeasible(233):
#
# 	Experiment is infeasible: 'event: Minimum voltage' was triggered during 'Run pulse (A) until 3.0 V'. The returned solution only contains up to step 1 of cycle 1.
# 2023-05-08 14:52:19.435 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-08 14:52:23.290 - [WARNING] callbacks.on_experiment_infeasible(233):
#
# 	Experiment is infeasible: 'event: Minimum voltage' was triggered during 'Run pulse (A) until 3.0 V'. The returned solution only contains up to step 1 of cycle 1.
# 2023-05-08 14:52:23.599 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-08 14:52:42.201 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# 2023-05-08 14:52:43.580 - [WARNING] processed_variable.__call__(459): Calling variable outside interpolation range (returns 'nan')
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# save parameters and soc 
Ds = pd.DataFrame(columns=('SOC', 'kp','kn','e'))
for i,(k, soc, e) in enumerate(zip(k_list, SOC_list, e_list)):
   if  (k[0]<2) and (k[1] <2):
      Ds.loc[i] = [soc, k[0], k[1], e[0]]

display(Ds)
# Ds.to_csv('./fast_discharge/Ds16.csv')

# %% [markdown]
# # Fit concentration dependence

# %% [markdown]
# # Polyfit concentration dependence

# %%
def polystr(pk):    
    label = []
    for i, p in enumerate(pk):
        #coeff
        label.append(str(round(p,3)))

        # x^n
        if len(pk)-i-1>1:
            label.append('$x^' + str(len(pk)-i-1) + '$' + ' + ')
        elif i== len(pk)-2:
            label.append('$x$'  + ' + ')

    return ''.join(label)

# %%
Ds0 = pd.read_csv('./fast_discharge/Ds8_rmse_V.csv', usecols=range(1,4), sep = '\t') #
display(Ds0)

# %%
Ds0 = pd.read_csv('./fast_discharge/Ds12.csv', usecols=range(1,5)) #, sep = '\t'
display(Ds0)

# %%
# load values
Ds = Ds0.iloc[0::]
# Ds = Ds0[Ds0.e<0.009]

# polyfit data

pp = np.polyfit(Ds.SOC, Ds.kp,2) # low soc
pn = np.polyfit(Ds.SOC, Ds.kn,1) # low soc
x = np.linspace(0,1,200)
yp = np.polyval(pp,x)
yn = np.polyval(pn,x)

# plot fits
fig, ax = plt.subplots(2,1, figsize=(6,4), sharex=True)
ax = ax.flatten()

ax[0].scatter(Ds.SOC, Ds.kp, color = 'k')
ax[0].plot(x, yp, label = polystr(pp) , color = 'k')
ax[0].set_ylabel('$p_p$')
ax[0].legend()
# ax[0].set_ylim([0,2])
ax[1].scatter(Ds.SOC, Ds.kn , color = 'k')
ax[1].plot(x, yn, label = polystr(pn), color = 'k')
ax[1].set_xlabel('SOC')
ax[1].set_ylabel('$p_n$')
# ax[1].set_ylim([0,2])
ax[1].legend()

# display(Ds)

print(pp)
print(pn)# Ds.loc[len(Ds.index)] = [0, np.nan, Ds.kn.iloc[-1], np.nan] 

plt.rcParams.update({'font.size': 14})
plt.savefig('./fast_discharge/figs/p.jpg', format='jpg')
plt.tight_layout()
plt.show()

# %%
def monoExp(x, a, b):
    return a*(x)**b


# load values
Ds = Ds0.iloc[0::]
Ds = Ds0[Ds0.e<0.009]

# polyfit data
pp = np.polyfit(Ds.SOC, Ds.kp,2) # low soc
pn = np.polyfit(Ds.SOC, Ds.kn,1) # low soc
x = np.linspace(0,1,200)
yp = np.polyval(pp,x)
yn = np.polyval(pn,x)
# p0 = (1,0.5)
# params, cv = curve_fit(monoExp, Ds.SOC, Ds.kn, p0)
# a,b = params
# yn= a*(x+0.03)**b

# plot fits
fig, ax = plt.subplots(2,1, figsize=(6,4), sharex=True)
ax = ax.flatten()

ax[0].scatter(Ds.SOC, Ds.kp, color = 'k')
ax[0].plot(x, yp, label = polystr(pp) , color = 'k')
ax[0].set_ylabel('$p_p$')
ax[0].legend()
# ax[0].set_ylim([0,2])
ax[1].scatter(Ds.SOC, Ds.kn , color = 'k')
ax[1].plot(x, yn, label = polystr(pn), color = 'k')
ax[1].set_xlabel('SOC')
ax[1].set_ylabel('$p_n$')
# ax[1].set_ylim([0,2])
ax[1].legend()

# display(Ds)

print(pp)
print(pn)# Ds.loc[len(Ds.index)] = [0, np.nan, Ds.kn.iloc[-1], np.nan] 

plt.savefig('./fast_discharge/figs/p.eps', format='eps')

# %%
# load values
Ds0 = pd.read_csv('./fast_discharge/Ds13.csv', usecols=range(1,5))
Ds = Ds0[Ds0.e<0.008]

# polyfit data

pp = np.polyfit(Ds.SOC, Ds.kp,2) # low soc
pn = np.polyfit(Ds.SOC, Ds.kn,2) # low soc
x = np.linspace(0,1,200)
yp = np.polyval(pp,x)
yn = np.polyval(pn,x)

# plot fits
fig, ax = plt.subplots(2,1, figsize=(6,4), sharex=True)
ax = ax.flatten()

ax[0].scatter(Ds.SOC, Ds.kp)
ax[0].plot(x, yp)
ax[0].set_ylabel('$k_p$')
# ax[0].set_ylim([0,2])
ax[1].scatter(Ds.SOC, Ds.kn)
ax[1].plot(x, yn)
ax[1].set_xlabel('SOC')
ax[1].set_ylabel('$k_n$')
# ax[1].set_ylim([0,2])

# display(Ds)

print(pp)
print(pn)

# %%
Ds

# %%
# load values
Ds0 = pd.read_csv('./fast_discharge/Ds12.csv', usecols=range(1,5))
Ds = Ds0[Ds0.e<0.008]
# polyfit data

pp_high = np.polyfit(Ds.SOC[0:5], Ds.kp[0:5],1) # high soc
pp_low = np.polyfit(Ds.SOC[5::], Ds.kp[5::],2) # low soc
pn_high = np.polyfit(Ds.SOC[Ds.SOC>0.4], Ds.kn[Ds.SOC>0.4],1) # high soc
pn_low = np.polyfit(Ds.SOC[Ds.SOC<0.4], Ds.kn[Ds.SOC<0.4],1) # low soc
x = np.linspace(0,1,200)
yp = np.polyval(pp_high,x)*(1/(1 + np.exp(-(x-0.6)*100)))+ np.polyval(pp_low,x)*(1-1/(1 + np.exp(((0.6-x)*100))))
yn = np.polyval(pn_high,x)*(1/(1 + np.exp(-(x-0.4)*20)))+ np.polyval(pn_low,x)*(1-1/(1 + np.exp(((0.4-x)*20))))
# yn = np.polyval(pn1,x) + np.polyval(pn2,x)

# plot fits
fig, ax = plt.subplots(2,1, figsize=(6,4), sharex=True)
ax = ax.flatten()

ax[0].scatter(Ds.SOC, Ds.kp)
ax[0].plot(x, yp)
ax[0].set_ylabel('$k_p$')
# ax[0].set_ylim([0,2])
ax[1].scatter(Ds.SOC, Ds.kn)
ax[1].plot(x, yn)
ax[1].set_xlabel('SOC')
ax[1].set_ylabel('$k_n$')
# ax[1].set_ylim([0,2])

# display(Ds)

print(pp_high)
print(pp_low)
print(pn_high)
print(pn_low)

# %%
Ds

# %%
# %matplotlib widget
fig, ax = plt.subplots(len(Ds), 2, figsize=(10,len(Ds)*2), sharex=True)
# ax = ax.flatten()

Dp_0 = 8.0E-15
Dn_0 = 8.0E-14

for k, (i,j) in enumerate(zip(i2[0:len(Ds)],i2[1::])):
    print(k)

    # define pulse data
    pulse = data[i:j].copy()
    pulse.t = pulse.t-pulse.t.iloc[0]

    # define sim parameters
    SOC_0 = pulse.SOC.iloc[0]
    pulse_current = pulse[['t','I']].to_numpy()

    # simulate with k
    solutions = []
    # nominal
    param.update({
        "Positive electrode diffusivity [m2.s-1]": Dp_0,
        "Negative electrode diffusivity [m2.s-1]": Dn_0,
        })
    sim0 = pybamm.Simulation(model, experiment=experiment, parameter_values = param)
    solution0 = sim.solve( initial_soc=SOC_0)
    solutions.append(solution0)
    
    # fitted
    param.update({
        "Positive electrode diffusivity [m2.s-1]": Dp_0*Ds.iloc[k].kp,
        "Negative electrode diffusivity [m2.s-1]": Dn_0*Ds.iloc[k].kn,
        })
    sim = pybamm.Simulation(model, experiment=experiment, parameter_values = param)
    solution = sim.solve( initial_soc=SOC_0)
    solutions.append(solution)

    # plot with 
    ax[k,0].plot(pulse.t, pulse.V, color = 'k')
    ax[k,0].set_xlabel(xlabel)
    ax[k,0].set_ylabel('Terminal voltage [V]')
    
    colors = ['r','g']
    linestyles = ['-', ':']
    for j,solution in enumerate(solutions):
        t = solution["Time [s]"].entries
        V = solution['Terminal voltage [V]']
        ax[k,0].plot(t, V(t), color = colors[j], linestyle = linestyles[j])
        ax[k,0].legend(["Data", "Nominal", "Fitted"])

        e_V = abs(pulse.V - V(pulse.t))
        ax[k,1].plot(pulse.t, e_V, color = colors[j], linestyle = linestyles[j])
        ax[k,1].set_xlabel(xlabel)
        ax[k,1].set_ylabel('|Error [V]|')

plt.subplots_adjust(bottom=0.05, top=0.99)

# %% [markdown]
# # Curve fit concentration dependence (OReagan's form)

# %%
def Dsp_c(soc,a1,a2,a3,b1,b2,b3,c0,c1,c2,c3,c):
    # sto = (1-soc)*(1-y0)+0.353
    sto = (1-soc)*(0.837-0.034)+0.034
    # sto = 0.837-soc*(0.837-0.034)
    # soc = (0.837-sto)/(0.837-0.034)

    D_ref = (
            10
            ** (
                c0
                + a1 * np.exp(-((sto - b1) ** 2) / c1)
                + a2 * np.exp(-((sto - b2) ** 2) / c2)
                + a3 * np.exp(-((sto - b3) ** 2) / c3)
            )
            # *0.3672467477  # correcting factor (see O'Regan et al 2021)
            *c
        )

    return D_ref


def Dsn_c(sto,a1,a2,a3,b1,b2,b3,c0,c1,c2,c3,c):
    D_ref = (
            10
            ** (
                c0
                + a1 * np.exp(-((sto - b1) ** 2) / c1)
                + a2 * np.exp(-((sto - b2) ** 2) / c2)
                + a3 * np.exp(-((sto - b3) ** 2) / c3)
                # + a4 * np.exp(-((sto - b4) ** 2) / c4)

            )
            * c
        )

    return D_ref

# %%
# load values
Ds0 = pd.read_csv('./fast_discharge/Ds10.csv', usecols=range(1,5))
Ds = Ds0[Ds0.e<0.01]
Ds['Ds_p'] = Dp_0*Ds.kp
Ds['Ds_n'] = Dp_0*Ds.kn


# find curve fit parameters
# p0_p = [-0.9231, -0.4066,-0.993,0.3216,0.4532,0.8098,-13.96,0.002534,0.003926,0.09924,0.4]
p0_p = [-0.9231, -0.4066,-0.993,0.3216,0.4532,0.8098,-13.96,0.002534,0.003926,0.09924,0.4]
pp, covariance = curve_fit(Dsp_c, Ds.SOC, Ds.Ds_p, p0 = p0_p)
# p0_n = [11.17,-1.553,-6.136, -9.725,1.85,0.2031,0.5375,0.9144, 0.5953,-15.11,0.0006091,0.06438,0.0578,0.001356,2092]
p0_n = [-1.553,-6.136, -9.725,0.2031,0.5375,0.9144, -15.11,0.0006091,0.06438,0.0578,3.0321]
pn, covariance = curve_fit(Dsn_c, Ds.SOC, Ds.Ds_n, p0 = pp*10)

# calculate fitted values
x = np.linspace(0,1,100)
yp = Dsp_c(x,*pp)
yn = Dsn_c(x,*pn)

# plot fits
fig, ax = plt.subplots(2,1, figsize=(6,4), sharex=True)
ax = ax.flatten()

ax[0].scatter(Ds.SOC, Ds.Ds_p)
ax[0].plot(x, yp)
ax[0].set_ylabel('$D_{s,p}(SOC)$')
ax[1].scatter(Ds.SOC, Ds.kn)
ax[1].plot(x, yn)
ax[1].set_xlabel('SOC')
ax[1].set_ylabel('$D_{s,n}(SOC)$')
ax[1].set_ylim([0,2])

# display(Ds)

print(pp)
# print(pn)

# %% [markdown]
# # Curve fit concnetration dependent diffusion from literature

# %%
Dn = pd.read_csv('./fast_discharge/Levi Aurbach 1997 graphite diffusion.csv', header=None)
df_labels = ['SOC', 'Dn']
Dn.set_axis(df_labels, axis=1, inplace=True)
Dn.Dn = Dn.Dn
# display(Dn0)

Dp = pd.read_csv('./fast_discharge/Wu 2012 NMC diffusion.csv', header=None)
df_labels = ['SOC', 'Dp']
Dp.set_axis(df_labels, axis=1, inplace=True)
# display(Dp0)

# %%
def Dsp_c(soc,a1,a2,a3,b1,b2,b3,c0,c1,c2,c3,c):
    # sto = (1-soc)*(1-y0)+0.353
    # sto = (1-soc)*(0.837-0.034)+0.034
    # sto = 0.837-soc*(0.837-0.034)
    # soc = (0.837-sto)/(0.837-0.034)
    sto = (1-soc)*(1-0.034)+0.034
    # sto = soc
    D_ref = (
            10
            ** (
                c0
                + a1 * np.exp(-((sto - b1)/ c1)** 2 )
                + a2 * np.exp(-((sto - b2)/ c2)** 2 )
                + a3 * np.exp(-((sto - b3)/ c3)** 2 )
            )
            *c
            # *0.3672467477  # correcting factor (see O'Regan et al 2021)
        )

    return D_ref

def monoExp(x, a, b):
    return a*(x)**b

# %%
# calculate fitted values
x = np.linspace(0,1,100)
yn = 10**(
    -5.9401e-1*np.exp(-((x-2.5720e-1)/8.4006e-2)**2)\
    +5.1118e-1*np.exp(-((x-5.1715e-1)/1.0308e-1)**2)\
    -6.6628e-2*np.exp(-((x-7.5004e-1)/6.0470e-2)**2)\
    -1.9021e-1*np.exp(-((x-5.7634e-1)/4.1183e-2)**2)\
    +5.7993e-1*np.exp(-((x-5.0993e-1)/3.2647e-2)**2)\
    -1.0736e1*np.exp(-((x-5.5128e-1)/1.0588)**2)\
    -1.2463*np.exp(-((x-4.7459e-2)/3.0551e-2)**2)\
    -4
)

p0 = (1e-14,0.5)
params, cv = curve_fit(monoExp, Dp.SOC, Dp.Dp, p0)
a,b = params
yp = a*(x+0.07)**b
# y = (1-x)
# yp = 10**(
#     -1.3922e12*np.exp(-((y-4.0704)/5.8343e-1)**2)\
#     -1.4516e1*np.exp(-((y-1.0490)/1.8016)**2)\
#     -8.6982e-1*np.exp(-((y-3.0124e-1)/2.1998e-1)**2)\
#     # -8.6982e-1*np.exp(-((y-3.0124e-1)/2.1998e-1)**2)\

# )

# p0_p = [-1.3922e12, -1.4516e1,-8.6982e-1,4.0704,1.0490,3.0124e-1,0,5.8343e-1,1.8016,2.1998e-1,1]
# pp, covariance = curve_fit(Dsp_c, Dp.SOC, Dp.Dp, p0 = p0_p)
# yp = Dsp_c(x,*pp)

# pp = np.polyfit(Dp.SOC, np.log(Dp.Dp), 1)
# a = np.exp(pp[1])
# b = pp[0]
# yp = a * np.exp(b * x)

# plot fits
fig, ax = plt.subplots(2,1, figsize=(6,4), sharex=True)
ax = ax.flatten()

ax[0].scatter(Dp.SOC, Dp.Dp)
ax[0].semilogy(x, yp)
ax[0].set_ylabel('$D_{s,p}(SOC)$')


ax[1].scatter(Dn.SOC, Dn.Dn)
ax[1].semilogy(x, yn)
ax[1].set_xlabel('SOC')
ax[1].set_ylabel('$D_{s,n}(SOC)$')
# ax[1].set_ylim([0,2])

# display(Ds)

print(params)
# print(pn)

# %%
yp[0]

# %%
# calculate fitted values
x = np.linspace(0,1,100)
yn = 10**(
    -5.9401e-1*np.exp(-((x-2.5720e-1)/8.4006e-2)**2)\
    +5.1118e-1*np.exp(-((x-5.1715e-1)/1.0308e-1)**2)\
    -6.6628e-2*np.exp(-((x-7.5004e-1)/6.0470e-2)**2)\
    -1.9021e-1*np.exp(-((x-5.7634e-1)/4.1183e-2)**2)\
    +5.7993e-1*np.exp(-((x-5.0993e-1)/3.2647e-2)**2)\
    -1.0736e1*np.exp(-((x-5.5128e-1)/1.0588)**2)\
    -1.2463*np.exp(-((x-4.7459e-2)/3.0551e-2)**2)\
    -4
)

y = (1-x)
yp = 10**(
    -1.3922e12*np.exp(-((y-4.0704)/5.8343e-1)**2)\
    -1.4516e1*np.exp(-((y-1.0490)/1.8016)**2)\
    -8.6982e-1*np.exp(-((y-3.0124e-1)/2.1998e-1)**2)\
)

# plot fits
fig, ax = plt.subplots(2,1, figsize=(6,4), sharex=True)
ax = ax.flatten()

ax[0].scatter(Dp.SOC, Dp.Dp)
ax[0].semilogy(x, yp)
ax[0].set_ylabel('$D_{s,p}(SOC)$')


ax[1].scatter(Dn.SOC, Dn.Dn)
ax[1].semilogy(x, yn)
ax[1].set_xlabel('SOC')
ax[1].set_ylabel('$D_{s,n}(SOC)$')
# ax[1].set_ylim([0,2])

# display(Ds)

print(pp)
# print(pn)
