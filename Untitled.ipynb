# %%
import pybamm
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-4478c83dbc15> in <module>
# ----> 1 import pybamm
#
# ~/Documents/PyBaMM/pybamm/__init__.py in <module>
#     101 )
#     102 from .expression_tree.operations.jacobian import Jacobian
# --> 103 from .expression_tree.operations.convert_to_casadi import CasadiConverter
#     104 from .expression_tree.operations.unpack_symbols import SymbolUnpacker
#     105
#
# ~/Documents/PyBaMM/pybamm/expression_tree/operations/convert_to_casadi.py in <module>
#       3 #
#       4 import pybamm
# ----> 5 import casadi
#       6 import numpy as np
#       7 from scipy.interpolate import PchipInterpolator, CubicSpline
#
# ModuleNotFoundError: No module named 'casadi'
