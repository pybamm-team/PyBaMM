# %%
import Pkg; Pkg.add("OrdinaryDiffEq")
using ModelingToolkit, OrdinaryDiffEq
# Out:
#    Updating registry at `~/.julia/registries/General`
#    Updating git-repo `https://github.com/JuliaRegistries/General.git`
#     Fetching: [
#     Fetching: [==============>                          ]
# Fetching: [========================================>]  100.0 %                  ]  52.4 % [============================>            ]  69.0 %]  85.4 %Fetching: [=======================================> ]  97.2 %
#   Resolving package versions...
#   Installed Adapt ────────────────── v2.3.0
#   Installed ArrayInterface ───────── v2.13.3
#   Installed FillArrays ───────────── v0.8.14
#   Installed DiffEqJump ───────────── v6.10.0
#   Installed FiniteDiff ───────────── v2.7.0
#   Installed OrderedCollections ───── v1.3.1
#   Installed Unitful ──────────────── v1.4.1
#   Installed OrdinaryDiffEq ───────── v5.42.3
#   Installed Showoff ──────────────── v0.3.2
#   Installed HTTP ─────────────────── v0.8.19
#   Installed ProgressMeter ────────── v1.4.0
#   Installed DiffEqNoiseProcess ───── v5.3.1
#   Installed Grisu ────────────────── v1.0.0
#   Installed Compat ───────────────── v3.17.0
#   Installed Requires ─────────────── v1.1.0
#   Installed ChainRulesCore ───────── v0.9.10
#   Installed RecipesBase ──────────── v1.1.0
#   Installed SIMDPirates ──────────── v0.8.25
#   Installed PlotUtils ────────────── v1.0.7
#   Installed PDMats ───────────────── v0.10.1
#   Installed OffsetArrays ─────────── v1.3.0
#   Installed RecipesPipeline ──────── v0.1.13
#   Installed RecursiveArrayTools ──── v2.7.1
#   Installed LoopVectorization ────── v0.8.26
#   Installed Contour ──────────────── v0.5.5
#   Installed LaTeXStrings ─────────── v1.2.0
#   Installed ParameterizedFunctions ─ v5.6.0
#   Installed JSON ─────────────────── v0.21.1
#   Installed StochasticDiffEq ─────── v6.25.0
#   Installed ColorSchemes ─────────── v3.10.1
# Updating `~/.julia/environments/v1.5/Project.toml`
#   [1dea7af3] + OrdinaryDiffEq v5.42.3
# Updating `~/.julia/environments/v1.5/Manifest.toml`
#   [79e6a3ab] ↑ Adapt v2.0.2 ⇒ v2.3.0
#   [4fba245c] ↑ ArrayInterface v2.11.0 ⇒ v2.13.3
#   [6e34b625] ↑ Bzip2_jll v1.0.6+3 ⇒ v1.0.6+4
#   [a603d957] ↑ CanonicalTraits v0.1.0 ⇒ v0.2.2
#   [d360d2e6] ↑ ChainRulesCore v0.9.5 ⇒ v0.9.10
#   [35d6a980] ↑ ColorSchemes v3.9.0 ⇒ v3.10.1
#   [3da002f7] ↑ ColorTypes v0.10.8 ⇒ v0.10.9
#   [5ae59095] ↑ Colors v0.12.3 ⇒ v0.12.4
#   [34da2185] ↑ Compat v3.13.0 ⇒ v3.17.0
#   [d38c429a] ↑ Contour v0.5.4 ⇒ v0.5.5
#   [c894b116] ↑ DiffEqJump v6.9.3 ⇒ v6.10.0
#   [77a26b50] ↑ DiffEqNoiseProcess v4.3.0 ⇒ v5.3.1
#   [055956cb] ↑ DiffEqPhysics v3.2.0 ⇒ v3.6.0
#   [ffbed154] ↑ DocStringExtensions v0.8.2 ⇒ v0.8.3
#   [d4d017d3] ↑ ExponentialUtilities v1.7.0 ⇒ v1.8.0
#   [b22a6f82] ↑ FFMPEG_jll v4.3.1+1 ⇒ v4.3.1+2
#   [1a297f60] ↑ FillArrays v0.8.13 ⇒ v0.8.14
#   [6a86dc24] ↑ FiniteDiff v2.5.2 ⇒ v2.7.0
#   [d7e528f0] ↑ FreeType2_jll v2.10.1+3 ⇒ v2.10.1+4
#   [559328eb] ↑ FriBidi_jll v1.0.5+4 ⇒ v1.0.5+5
#   [6b9d7cbe] ↑ GeneralizedGenerated v0.2.5 ⇒ v0.2.7
#   [42e2da0e] + Grisu v1.0.0
#   [cd3eb016] ↑ HTTP v0.8.17 ⇒ v0.8.19
#   [682c06a0] ↑ JSON v0.21.0 ⇒ v0.21.1
#   [b964fa9f] ↑ LaTeXStrings v1.1.0 ⇒ v1.2.0
#   [d3d80556] ↑ LineSearches v7.0.1 ⇒ v7.1.0
#   [bdcacae8] ↑ LoopVectorization v0.8.22 ⇒ v0.8.26
#   [d8e11817] ↑ MLStyle v0.4.3 ⇒ v0.4.6
#   [c8ffd9c3] ↑ MbedTLS_jll v2.16.6+1 ⇒ v2.16.8+0
#   [e1d29d7a] ↑ Missings v0.4.3 ⇒ v0.4.4
#   [d41bc354] ↑ NLSolversBase v7.6.1 ⇒ v7.7.0
#   [2774e3e8] ↑ NLsolve v4.4.0 ⇒ v4.4.1
#   [71a1bf82] ↑ NameResolution v0.1.4 ⇒ v0.1.5
#   [6fe1bfb0] ↑ OffsetArrays v1.1.2 ⇒ v1.3.0
#   [4536629a] ↑ OpenBLAS_jll v0.3.9+5 ⇒ v0.3.10+0
#   [bac558e1] ↑ OrderedCollections v1.3.0 ⇒ v1.3.1
#   [1dea7af3] ↑ OrdinaryDiffEq v5.42.1 ⇒ v5.42.3
#   [90014a1f] ↑ PDMats v0.10.0 ⇒ v0.10.1
#   [65888b18] ↑ ParameterizedFunctions v5.4.0 ⇒ v5.6.0
#   [69de0a69] ↑ Parsers v1.0.7 ⇒ v1.0.10
#   [995b91a9] ↑ PlotUtils v1.0.5 ⇒ v1.0.7
#   [92933f4c] ↑ ProgressMeter v1.3.2 ⇒ v1.4.0
#   [1fd47b50] ↑ QuadGK v2.4.0 ⇒ v2.4.1
#   [3cdcf5f2] ↑ RecipesBase v1.0.2 ⇒ v1.1.0
#   [01d81517] ↑ RecipesPipeline v0.1.12 ⇒ v0.1.13
#   [731186ca] ↑ RecursiveArrayTools v2.5.0 ⇒ v2.7.1
#   [ae029012] ↑ Requires v1.0.1 ⇒ v1.1.0
#   [f2b01f46] ↑ Roots v1.0.4 ⇒ v1.0.5
#   [21efa798] ↑ SIMDPirates v0.8.21 ⇒ v0.8.25
#   [992d4aef] ↑ Showoff v0.3.1 ⇒ v0.3.2
#   [699a6c99] ↑ SimpleTraits v0.9.2 ⇒ v0.9.3
#   [47a9eef4] ↑ SparseDiffTools v1.9.1 ⇒ v1.10.0
#   [2913bbd2] ↑ StatsBase v0.33.0 ⇒ v0.33.1
#   [789caeaf] ↑ StochasticDiffEq v6.23.1 ⇒ v6.25.0
#   [c3572dad] ↑ Sundials v4.2.5 ⇒ v4.2.6
#   [fb77eaff] ↑ Sundials_jll v5.2.0+0 ⇒ v5.2.0+1
#   [3a884ed6] ↑ UnPack v1.0.1 ⇒ v1.0.2
#   [1986cc42] ↑ Unitful v1.3.0 ⇒ v1.4.1
#   [3d5dd08c] ↑ VectorizationBase v0.12.30 ⇒ v0.12.33
#   [83775a58] ↑ Zlib_jll v1.2.11+15 ⇒ v1.2.11+16
# ┌ Info: Precompiling OrdinaryDiffEq [1dea7af3-3e70-54e6-95c3-0bf5283fa5ed]
# └ @ Base loading.jl:1278

# %%
@parameters t σ ρ β
@variables x(t) y(t) z(t)
@derivatives D'~t

eqs = [D(x) ~ σ*(y-x),
       D(y) ~ x*(ρ-z)-y,
       D(z) ~ x*y - β*z]

u0 = [x => 1.0,
      y => 0.0,
      z => 0.0,
      ]

p  = [σ => 10.0,
      ρ => 28.0,
      β => 8/3,
      ]

tspan = (0.0,100.0)
prob = ODEProblem(eqs,u0,tspan,p)
sol = solve(prob,Rodas5())
# Out:
# ArgumentError: reducing over an empty collection is not allowed
#
# Stacktrace:
#  [1] _empty_reduce_error() at ./reduce.jl:299
#  [2] reduce_empty(::Function, ::Type{Any}) at ./reduce.jl:309
#  [3] mapreduce_empty(::typeof(identity), ::Function, ::Type{T} where T) at ./reduce.jl:343
#  [4] reduce_empty(::Base.MappingRF{typeof(identity),typeof(max)}, ::Type{Any}) at ./reduce.jl:329
#  [5] reduce_empty_iter at ./reduce.jl:355 [inlined]
#  [6] mapreduce_empty_iter(::Function, ::Function, ::Array{Any,1}, ::Base.HasEltype) at ./reduce.jl:351
#  [7] _mapreduce(::typeof(identity), ::typeof(max), ::IndexLinear, ::Array{Any,1}) at ./reduce.jl:400
#  [8] _mapreduce_dim at ./reducedim.jl:318 [inlined]
#  [9] #mapreduce#620 at ./reducedim.jl:310 [inlined]
#  [10] mapreduce at ./reducedim.jl:310 [inlined]
#  [11] _maximum at ./reducedim.jl:727 [inlined]
#  [12] _maximum at ./reducedim.jl:726 [inlined]
#  [13] #maximum#631 at ./reducedim.jl:722 [inlined]
#  [14] maximum(::Array{Any,1}) at ./reducedim.jl:722
#  [15] numargs(::Array{Equation,1}) at /Users/vsulzer/.julia/packages/DiffEqBase/T5smF/src/utils.jl:13
#  [16] isinplace(::Array{Equation,1}, ::Int64) at /Users/vsulzer/.julia/packages/DiffEqBase/T5smF/src/utils.jl:42
#  [17] ODEFunction(::Array{Equation,1}; kwargs::Base.Iterators.Pairs{Symbol,Nothing,NTuple{10,Symbol},NamedTuple{(:analytic, :tgrad, :jac, :jvp, :vjp, :Wfact, :Wfact_t, :paramjac, :syms, :colorvec),NTuple{10,Nothing}}}) at /Users/vsulzer/.julia/packages/DiffEqBase/T5smF/src/diffeqfunction.jl:391
#  [18] convert at /Users/vsulzer/.julia/packages/DiffEqBase/T5smF/src/diffeqfunction.jl:1083 [inlined]
#  [19] ODEProblem(::Array{Equation,1}, ::Array{Pair{Operation,Float64},1}, ::Tuple{Float64,Float64}, ::Array{Pair{Operation,Float64},1}; kwargs::Base.Iterators.Pairs{Union{},Union{},Tuple{},NamedTuple{(),Tuple{}}}) at /Users/vsulzer/.julia/packages/DiffEqBase/T5smF/src/problems/ode_problems.jl:76
#  [20] ODEProblem(::Array{Equation,1}, ::Array{Pair{Operation,Float64},1}, ::Tuple{Float64,Float64}, ::Array{Pair{Operation,Float64},1}) at /Users/vsulzer/.julia/packages/DiffEqBase/T5smF/src/problems/ode_problems.jl:76
#  [21] top-level scope at In[11]:20
#  [22] include_string(::Function, ::Module, ::String, ::String) at ./loading.jl:1091

# %%
using Plots; plot(sol,vars=(a,lorenz1.x,lorenz2.z))
# Out:
# ┌ Info: Precompiling Plots [91a5bcdd-55d7-5caf-9e0b-520d859cae80]
# └ @ Base loading.jl:1278

# %%
using ModelingToolkit, OrdinaryDiffEq, Plots
# t = Variable{Float64}(:t)()
# σ = Variable{Float64}(:σ)()
# x = Variable{Float64}(:x)(t)
# D = Differential(t)

@variables t, x(t)
# @parameters σ
@derivatives D'~t

eqs = [D(x) ~ -2.0 * x]
sys = ODESystem(eqs,t)
u0 = [x => 1.0]
p = [σ => 2.0]
tspan = (0.0,1.0)
prob = ODEProblem(sys,u0,tspan)
sol = solve(prob, Tsit5())
plot(sol)
