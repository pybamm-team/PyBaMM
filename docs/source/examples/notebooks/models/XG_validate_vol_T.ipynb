# %% [markdown]
# To validate battery base model for LG M50, Use revised OKane2022 parameters with parameters used in Paper 1,2
# 1. To validate BoL voltage and thermal response

# %%
import pybamm
import matplotlib.pyplot as plt
import numpy as np


model = pybamm.lithium_ion.DFN(
    {
        #"particle phases": ("2", "1"),
        #"open-circuit potential": (("single", "current sigmoid"), "single"),
        
        "SEI": "solvent-diffusion limited",
        "SEI porosity change": "true",
        "lithium plating": "partially reversible",
        "lithium plating porosity change": "true",  # alias for "SEI porosity change"
        "particle mechanics": ("swelling and cracking", "swelling only"),
        "SEI on cracks": "true",
        "loss of active material": "stress-driven",
        "calculate discharge energy": "true",  # for compatibility with older PyBaMM versions

        "thermal": "lumped", 
    }
)

param = pybamm.ParameterValues("OKane2022_posmolar_0703")
var_pts = {
    "x_n": 10,  # negative electrode
    "x_s": 10,  # separator
    "x_p": 10,  # positive electrode
    "r_n": 30,  # negative particle
    "r_p": 30,  # positive particle
}

cycle_number = 1
exp = pybamm.Experiment(
    # [
    #     "Hold at 4.2 V until C/100 (5 minute period)",
    #     "Rest for 4 hours (5 minute period)",
    #     "Discharge at 0.1C until 2.5 V (5 minute period)",  # initial capacity check
    #     "Charge at 1C until 4.2 V (5 minute period)",
    #     "Hold at 4.2 V until C/100 (5 minute period)",
    # ]
    # + 
    [
        (
            "Charge at 0.3C until 4.2 V",
            "Hold at 4.2 V until C/20",
            "Discharge at 1C until 2.5 V",  # ageing cycles
            #"Discharge at 1C until 2.5 V"

        )
    ]
    * cycle_number
    #+ ["Discharge at 0.1C until 2.5 V (5 minute period)"],  # final capacity check
)

# exp = pybamm.Experiment(
#     [
#         "Hold at 4.2 V until C/100 (5 minute period)",
#         "Discharge at 0.1C until 2.5 V (5 minute period)",  # initial capacity check
#         "Charge at 0.1C until 4.2 V (5 minute period)",
#         "Hold at 4.2 V until C/100 (5 minute period)",
#     ]
# )


sim = pybamm.Simulation(model, parameter_values=param, experiment=exp, var_pts=var_pts )
#sim_thermal = pybamm.Simulation(model_thermal, parameter_values=param, experiment=exp, var_pts=var_pts)
sol = sim.solve(initial_soc=0)
#sol = sim.solve()
# Out:
# At t = 350.172 and h = 1.46605e-10, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 174.88 and h = 2.45356e-11, the corrector convergence failed repeatedly or with |h| = hmin.

# %%
model_nodeg = pybamm.lithium_ion.DFN(
    {
        #"particle phases": ("2", "1"),
        #"open-circuit potential": (("single", "current sigmoid"), "single"),
        
        # "SEI": "solvent-diffusion limited",
        # "SEI porosity change": "true",
        # "lithium plating": "partially reversible",
        # "lithium plating porosity change": "true",  # alias for "SEI porosity change"
        # "particle mechanics": ("swelling and cracking", "swelling only"),
        # "SEI on cracks": "true",
        # "loss of active material": "stress-driven",
        # "calculate discharge energy": "true",  # for compatibility with older PyBaMM versions

        "thermal": "lumped", 
    }
)

param = pybamm.ParameterValues("OKane2022_posmolar_0703")
var_pts = {
    "x_n": 10,  # negative electrode
    "x_s": 10,  # separator
    "x_p": 10,  # positive electrode
    "r_n": 30,  # negative particle
    "r_p": 30,  # positive particle
}

cycle_number = 1
exp = pybamm.Experiment(
    # [
    #     "Hold at 4.2 V until C/100 (5 minute period)",
    #     "Rest for 4 hours (5 minute period)",
    #     "Discharge at 0.1C until 2.5 V (5 minute period)",  # initial capacity check
    #     "Charge at 1C until 4.2 V (5 minute period)",
    #     "Hold at 4.2 V until C/100 (5 minute period)",
    # ]
    # + 
    [
        (
            "Charge at 0.3C until 4.2 V",
            "Hold at 4.2 V until C/20",
            "Discharge at 1C until 2.5 V",  # ageing cycles
            #"Discharge at 1C until 2.5 V"

        )
    ]
    * cycle_number
    #+ ["Discharge at 0.1C until 2.5 V (5 minute period)"],  # final capacity check
)

# exp = pybamm.Experiment(
#     [
#         "Hold at 4.2 V until C/100 (5 minute period)",
#         "Discharge at 0.1C until 2.5 V (5 minute period)",  # initial capacity check
#         "Charge at 0.1C until 4.2 V (5 minute period)",
#         "Hold at 4.2 V until C/100 (5 minute period)",
#     ]
# )


sim_nodeg = pybamm.Simulation(model_nodeg, parameter_values=param, experiment=exp, var_pts=var_pts )
#sim_thermal = pybamm.Simulation(model_thermal, parameter_values=param, experiment=exp, var_pts=var_pts)
sol_nodeg = sim_nodeg.solve(initial_soc=0)
#sol = sim.solve()
# Out:
# At t = 409.099 and h = 6.07732e-19, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 169.099 and h = 4.00752e-19, the corrector convergence failed repeatedly or with |h| = hmin.

# %%
model.variables
# Out:
# {'Time [s]': Time(0x6c31452b945f1d96, time, children=[], domains={}),
#  'Time [min]': Multiplication(-0x1fb12df3d36d6773, *, children=['0.016666666666666666', 'time'], domains={}),
#  'Time [h]': Multiplication(0x551d444bbed52b07, *, children=['0.0002777777777777778', 'time'], domains={}),
#  'x [m]': SpatialVariable(-0x59fd0a5aac1c5b59, x, children=[], domains={'primary': ['negative electrode', 'separator', 'positive electrode'], 'secondary': ['current collector']}),
#  'x_n [m]': SpatialVariable(0x289a3f471aa55830, x_n, children=[], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'x_s [m]': SpatialVariable(-0x232b86b969c1e49e, x_s, children=[], domains={'primary': ['separator'], 'secondary': ['current collector']}),
#  'x_p [m]': SpatialVariable(0x7df69a0e0af4d9f6, x_p, children=[], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'r_n [m]': SpatialVariable(-0x1c110462af07d037, r_n, children=[], domains={'primary': ['negative particle'], 'secondary': ['negative electrode'], 'tertiary': ['current collector']}),
#  'r_p [m]': SpatialVariable(0x64106c1e2a2dac6f, r_p, children=[], domains={'primary': ['positive particle'], 'secondary': ['positive electrode'], 'tertiary': ['current collector']}),
#  'Current variable [A]': FunctionParameter(0x2b0f7f69a0b884a7, Current function [A], children=['time'], domains={}),
#  'Total current density [A.m-2]': Division(0x77b63cd24bb02609, /, children=['Current function [A]', 'Number of electrodes connected in parallel to make a cell * Electrode width [m] * Electrode height [m]'], domains={}),
#  'Current [A]': FunctionParameter(0x2b0f7f69a0b884a7, Current function [A], children=['time'], domains={}),
#  'C-rate': Division(-0x5fa1d9a0761c8779, /, children=['Current function [A]', 'Nominal cell capacity [A.h]'], domains={}),
#  'Discharge capacity [A.h]': Variable(-0x540127835e1d16c1, Discharge capacity [A.h], children=[], domains={}),
#  'Throughput capacity [A.h]': Variable(0x67b889c8c892e802, Throughput capacity [A.h], children=[], domains={}),
#  'Discharge energy [W.h]': Variable(-0x35749bc93cc6902c, Discharge energy [W.h], children=[], domains={}),
#  'Throughput energy [W.h]': Variable(-0x29a85dec5177b5b, Throughput energy [W.h], children=[], domains={}),
#  'Negative electrode interface utilisation variable': FullBroadcast(-0x69cba1ed73eaf79f, broadcast, children=['1.0'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrode interface utilisation variable': PrimaryBroadcast(0x5afd7db397fce113, broadcast, children=['1.0'], domains={'primary': ['current collector']}),
#  'Negative electrode interface utilisation': FullBroadcast(-0x69cba1ed73eaf79f, broadcast, children=['1.0'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrode interface utilisation': PrimaryBroadcast(0x5afd7db397fce113, broadcast, children=['1.0'], domains={'primary': ['current collector']}),
#  'Positive electrode interface utilisation variable': FullBroadcast(0x497bcfd6c005114d, broadcast, children=['1.0'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrode interface utilisation variable': PrimaryBroadcast(0x5afd7db397fce113, broadcast, children=['1.0'], domains={'primary': ['current collector']}),
#  'Positive electrode interface utilisation': FullBroadcast(0x497bcfd6c005114d, broadcast, children=['1.0'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrode interface utilisation': PrimaryBroadcast(0x5afd7db397fce113, broadcast, children=['1.0'], domains={'primary': ['current collector']}),
#  'Negative particle crack length [m]': Variable(0x70cc54e10e1be437, Negative particle crack length [m], children=[], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative particle crack length [m]': XAverage(-0x59cd39681f846ff2, x-average, children=['Negative particle crack length [m]'], domains={'primary': ['current collector']}),
#  'Positive particle crack length [m]': FullBroadcast(-0x7035f9cbaa83ee38, broadcast, children=['0.0'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive particle crack length [m]': PrimaryBroadcast(-0x1e04279eddc09a00, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'Positive particle cracking rate [m.s-1]': FullBroadcast(-0x7035f9cbaa83ee38, broadcast, children=['0.0'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive particle cracking rate [m.s-1]': PrimaryBroadcast(-0x1e04279eddc09a00, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'Negative electrode active material volume fraction': Variable(-0x3a307434ca25e76a, Negative electrode active material volume fraction, children=[], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrode active material volume fraction': XAverage(-0x6b5b6b2f0715b698, x-average, children=['Negative electrode active material volume fraction'], domains={'primary': ['current collector']}),
#  'Negative electrode capacity [A.h]': Multiplication(-0x223b5f41a934b32d, *, children=['0.0002777777777777778', 'yz-average(x-average(Negative electrode active material volume fraction)) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] * Maximum concentration in negative electrode [mol.m-3] * Faraday constant [C.mol-1]'], domains={}),
#  'Negative particle radius': Division(-0x6650ebea62dbe4ee, /, children=['Negative particle radius [m]', 'Negative particle radius [m]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Negative particle radius [m]': FunctionParameter(0x4c2b8d90a0202b17, Negative particle radius [m], children=['x_n'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative particle radius [m]': XAverage(-0x29bdb7e27c5a7c3, x-average, children=['Negative particle radius [m]'], domains={'primary': ['current collector']}),
#  'Negative electrode surface area to volume ratio [m-1]': Division(0x1dfe928d2e00873, /, children=['3.0 * Negative electrode active material volume fraction', 'Negative particle radius [m]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrode surface area to volume ratio [m-1]': XAverage(-0x207a447068e8cba0, x-average, children=['3.0 * Negative electrode active material volume fraction / Negative particle radius [m]'], domains={'primary': ['current collector']}),
#  'Loss of lithium due to loss of active material in negative electrode [mol]': Variable(-0x4f18c2d1d86617c3, Loss of lithium due to loss of active material in negative electrode [mol], children=[], domains={}),
#  'Positive electrode active material volume fraction': Variable(0x4bbf1a668bdcbb27, Positive electrode active material volume fraction, children=[], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrode active material volume fraction': XAverage(-0x910e4f6c138939a, x-average, children=['Positive electrode active material volume fraction'], domains={'primary': ['current collector']}),
#  'Positive electrode capacity [A.h]': Multiplication(-0x1af44071cc849648, *, children=['0.0002777777777777778', 'yz-average(x-average(Positive electrode active material volume fraction)) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m] * Maximum concentration in positive electrode [mol.m-3] * Faraday constant [C.mol-1]'], domains={}),
#  'Positive particle radius': Division(0x136f96c53587c310, /, children=['Positive particle radius [m]', 'Positive particle radius [m]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Positive particle radius [m]': FunctionParameter(0x44c424f54d6d4bd8, Positive particle radius [m], children=['x_p'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive particle radius [m]': XAverage(0x6d483b02f4d71f06, x-average, children=['Positive particle radius [m]'], domains={'primary': ['current collector']}),
#  'Positive electrode surface area to volume ratio [m-1]': Division(-0x7e43e4748610cb7a, /, children=['3.0 * Positive electrode active material volume fraction', 'Positive particle radius [m]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrode surface area to volume ratio [m-1]': XAverage(-0x1914b85cb136e1f1, x-average, children=['3.0 * Positive electrode active material volume fraction / Positive particle radius [m]'], domains={'primary': ['current collector']}),
#  'Loss of lithium due to loss of active material in positive electrode [mol]': Variable(0x84367e42d7bae67, Loss of lithium due to loss of active material in positive electrode [mol], children=[], domains={}),
#  'Separator pressure [Pa]': PrimaryBroadcast(-0xe58a970da795032, broadcast, children=['broadcast(0.0)'], domains={'primary': ['separator'], 'secondary': ['current collector']}),
#  'X-averaged separator pressure [Pa]': PrimaryBroadcast(-0x1e04279eddc09a00, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'negative electrode transverse volume-averaged velocity [m.s-1]': PrimaryBroadcast(0x7608f989be1c0e68, broadcast, children=['broadcast(0.0)'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrode transverse volume-averaged velocity [m.s-1]': PrimaryBroadcast(-0x1e04279eddc09a00, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'separator transverse volume-averaged velocity [m.s-1]': PrimaryBroadcast(-0xe58a970da795032, broadcast, children=['broadcast(0.0)'], domains={'primary': ['separator'], 'secondary': ['current collector']}),
#  'X-averaged separator transverse volume-averaged velocity [m.s-1]': PrimaryBroadcast(-0x1e04279eddc09a00, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'positive electrode transverse volume-averaged velocity [m.s-1]': PrimaryBroadcast(0x29506b4df20c1754, broadcast, children=['broadcast(0.0)'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrode transverse volume-averaged velocity [m.s-1]': PrimaryBroadcast(-0x1e04279eddc09a00, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'Transverse volume-averaged velocity [m.s-1]': PrimaryBroadcast(0x1abbb11ed9f76bd1, broadcast, children=['broadcast(0.0)'], domains={'primary': ['negative electrode', 'separator', 'positive electrode'], 'secondary': ['current collector']}),
#  'negative electrode transverse volume-averaged acceleration [m.s-2]': PrimaryBroadcast(0x7608f989be1c0e68, broadcast, children=['broadcast(0.0)'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrode transverse volume-averaged acceleration [m.s-2]': PrimaryBroadcast(-0x1e04279eddc09a00, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'separator transverse volume-averaged acceleration [m.s-2]': PrimaryBroadcast(-0xe58a970da795032, broadcast, children=['broadcast(0.0)'], domains={'primary': ['separator'], 'secondary': ['current collector']}),
#  'X-averaged separator transverse volume-averaged acceleration [m.s-2]': PrimaryBroadcast(-0x1e04279eddc09a00, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'positive electrode transverse volume-averaged acceleration [m.s-2]': PrimaryBroadcast(0x29506b4df20c1754, broadcast, children=['broadcast(0.0)'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrode transverse volume-averaged acceleration [m.s-2]': PrimaryBroadcast(-0x1e04279eddc09a00, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'Transverse volume-averaged acceleration [m.s-2]': PrimaryBroadcast(0x1abbb11ed9f76bd1, broadcast, children=['broadcast(0.0)'], domains={'primary': ['negative electrode', 'separator', 'positive electrode'], 'secondary': ['current collector']}),
#  'Negative electrode volume-averaged velocity [m.s-1]': FullBroadcast(-0x543a12c81736921a, broadcast, children=['0.0'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Negative electrode volume-averaged acceleration [m.s-2]': FullBroadcast(-0x543a12c81736921a, broadcast, children=['0.0'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrode volume-averaged acceleration [m.s-2]': PrimaryBroadcast(-0x1e04279eddc09a00, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'Negative electrode pressure [Pa]': FullBroadcast(-0x543a12c81736921a, broadcast, children=['0.0'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrode pressure [Pa]': PrimaryBroadcast(-0x1e04279eddc09a00, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'Positive electrode volume-averaged velocity [m.s-1]': FullBroadcast(-0x7035f9cbaa83ee38, broadcast, children=['0.0'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Positive electrode volume-averaged acceleration [m.s-2]': FullBroadcast(-0x7035f9cbaa83ee38, broadcast, children=['0.0'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrode volume-averaged acceleration [m.s-2]': PrimaryBroadcast(-0x1e04279eddc09a00, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'Positive electrode pressure [Pa]': FullBroadcast(-0x7035f9cbaa83ee38, broadcast, children=['0.0'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrode pressure [Pa]': PrimaryBroadcast(-0x1e04279eddc09a00, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'Total negative electrode interfacial current density variable [A.m-2]': Variable(0x1f62d5a8ddbc2ec1, Total negative electrode interfacial current density variable [A.m-2], children=[], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged total negative electrode interfacial current density variable [A.m-2]': XAverage(-0x4404e08467b95c34, x-average, children=['Total negative electrode interfacial current density variable [A.m-2]'], domains={'primary': ['current collector']}),
#  'Total positive electrode interfacial current density variable [A.m-2]': Variable(0xea80706c6127018, Total positive electrode interfacial current density variable [A.m-2], children=[], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged total positive electrode interfacial current density variable [A.m-2]': XAverage(0x6c711bd1b848bfe1, x-average, children=['Total positive electrode interfacial current density variable [A.m-2]'], domains={'primary': ['current collector']}),
#  'Negative particle concentration [mol.m-3]': Variable(0x7a835a37bd30cff0, Negative particle concentration [mol.m-3], children=[], domains={'primary': ['negative particle'], 'secondary': ['negative electrode'], 'tertiary': ['current collector']}),
#  'X-averaged negative particle concentration [mol.m-3]': XAverage(-0x4bcd3586552344e9, x-average, children=['Negative particle concentration [mol.m-3]'], domains={'primary': ['negative particle'], 'secondary': ['current collector']}),
#  'R-averaged negative particle concentration [mol.m-3]': RAverage(0x7bed4c914e4f2353, r-average, children=['Negative particle concentration [mol.m-3]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Average negative particle concentration [mol.m-3]': RAverage(-0x156e88ba48861121, r-average, children=['x-average(Negative particle concentration [mol.m-3])'], domains={'primary': ['current collector']}),
#  'Negative particle surface concentration [mol.m-3]': BoundaryValue(0x4b8334f196aa709a, boundary value, children=['Negative particle concentration [mol.m-3]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative particle surface concentration [mol.m-3]': XAverage(-0x46c0ce3a3ea9194b, x-average, children=['boundary value(Negative particle concentration [mol.m-3])'], domains={'primary': ['current collector']}),
#  'Minimum negative particle concentration [mol.m-3]': Min(-0x44d3eb7288aeaa49, function (min), children=['Negative particle concentration [mol.m-3]'], domains={'primary': ['negative particle'], 'secondary': ['negative electrode'], 'tertiary': ['current collector']}),
#  'Maximum negative particle concentration [mol.m-3]': Max(0x417f032006b0f844, function (max), children=['Negative particle concentration [mol.m-3]'], domains={'primary': ['negative particle'], 'secondary': ['negative electrode'], 'tertiary': ['current collector']}),
#  'Minimum negative particle Minimum negative particle surface concentration [mol.m-3]': Min(0x26414af4810d6610, function (min), children=['boundary value(Negative particle concentration [mol.m-3])'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Maximum negative particle surface concentration [mol.m-3]': Max(0x619dfaa3c107d5ff, function (max), children=['boundary value(Negative particle concentration [mol.m-3])'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Negative particle concentration': Division(-0x4ddde9da40aa8378, /, children=['Negative particle concentration [mol.m-3]', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative particle'], 'secondary': ['negative electrode'], 'tertiary': ['current collector']}),
#  'X-averaged negative particle concentration': Division(-0x28020eed8d86b385, /, children=['x-average(Negative particle concentration [mol.m-3])', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative particle'], 'secondary': ['current collector']}),
#  'R-averaged negative particle concentration': Division(-0x1e0de9984af884a8, /, children=['r-average(Negative particle concentration [mol.m-3])', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Average negative particle concentration': Division(0x2521912a54e44275, /, children=['r-average(x-average(Negative particle concentration [mol.m-3]))', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['current collector']}),
#  'Negative particle surface concentration': Division(0x65c754c3171a7073, /, children=['boundary value(Negative particle concentration [mol.m-3])', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative particle surface concentration': Division(-0x135267fe76cf6924, /, children=['x-average(boundary value(Negative particle concentration [mol.m-3]))', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['current collector']}),
#  'Minimum negative particle concentration': Division(-0x6ef9167c48aea387, /, children=['min(Negative particle concentration [mol.m-3])', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative particle'], 'secondary': ['negative electrode'], 'tertiary': ['current collector']}),
#  'Maximum negative particle concentration': Division(-0x76013ed76df87ceb, /, children=['max(Negative particle concentration [mol.m-3])', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative particle'], 'secondary': ['negative electrode'], 'tertiary': ['current collector']}),
#  'Minimum negative particle surface concentration': Division(0x65ee57fd4713d271, /, children=['min(boundary value(Negative particle concentration [mol.m-3]))', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Maximum negative particle surface concentration': Division(-0x3c14887555064cc5, /, children=['max(boundary value(Negative particle concentration [mol.m-3]))', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Negative particle stoichiometry': Division(-0x4ddde9da40aa8378, /, children=['Negative particle concentration [mol.m-3]', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative particle'], 'secondary': ['negative electrode'], 'tertiary': ['current collector']}),
#  'X-averaged negative particle stoichiometry': Division(-0x28020eed8d86b385, /, children=['x-average(Negative particle concentration [mol.m-3])', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative particle'], 'secondary': ['current collector']}),
#  'R-averaged negative particle stoichiometry': Division(-0x1e0de9984af884a8, /, children=['r-average(Negative particle concentration [mol.m-3])', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Average negative particle stoichiometry': Division(0x2521912a54e44275, /, children=['r-average(x-average(Negative particle concentration [mol.m-3]))', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['current collector']}),
#  'Negative particle surface stoichiometry': Division(0x65c754c3171a7073, /, children=['boundary value(Negative particle concentration [mol.m-3])', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative particle surface stoichiometry': Division(-0x135267fe76cf6924, /, children=['x-average(boundary value(Negative particle concentration [mol.m-3]))', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['current collector']}),
#  'Minimum negative particle stoichiometry': Division(-0x6ef9167c48aea387, /, children=['min(Negative particle concentration [mol.m-3])', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative particle'], 'secondary': ['negative electrode'], 'tertiary': ['current collector']}),
#  'Maximum negative particle stoichiometry': Division(-0x76013ed76df87ceb, /, children=['max(Negative particle concentration [mol.m-3])', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative particle'], 'secondary': ['negative electrode'], 'tertiary': ['current collector']}),
#  'Minimum negative particle surface stoichiometry': Division(0x65ee57fd4713d271, /, children=['min(boundary value(Negative particle concentration [mol.m-3]))', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Maximum negative particle surface stoichiometry': Division(-0x3c14887555064cc5, /, children=['max(boundary value(Negative particle concentration [mol.m-3]))', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Negative electrode extent of lithiation': Division(-0x1e0de9984af884a8, /, children=['r-average(Negative particle concentration [mol.m-3])', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrode extent of lithiation': Division(0x2521912a54e44275, /, children=['r-average(x-average(Negative particle concentration [mol.m-3]))', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['current collector']}),
#  'Positive particle concentration [mol.m-3]': Variable(-0x2d38ceb83f94fe17, Positive particle concentration [mol.m-3], children=[], domains={'primary': ['positive particle'], 'secondary': ['positive electrode'], 'tertiary': ['current collector']}),
#  'X-averaged positive particle concentration [mol.m-3]': XAverage(-0x5b60d3e8b1f226ff, x-average, children=['Positive particle concentration [mol.m-3]'], domains={'primary': ['positive particle'], 'secondary': ['current collector']}),
#  'R-averaged positive particle concentration [mol.m-3]': RAverage(-0x596d5194b19b1c0a, r-average, children=['Positive particle concentration [mol.m-3]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Average positive particle concentration [mol.m-3]': RAverage(-0x1a0425241fbed9e1, r-average, children=['x-average(Positive particle concentration [mol.m-3])'], domains={'primary': ['current collector']}),
#  'Positive particle surface concentration [mol.m-3]': BoundaryValue(0x6c129ccf020609a5, boundary value, children=['Positive particle concentration [mol.m-3]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive particle surface concentration [mol.m-3]': XAverage(-0x255156c92f34a8ab, x-average, children=['boundary value(Positive particle concentration [mol.m-3])'], domains={'primary': ['current collector']}),
#  'Minimum positive particle concentration [mol.m-3]': Min(0x2c68feb43e83d128, function (min), children=['Positive particle concentration [mol.m-3]'], domains={'primary': ['positive particle'], 'secondary': ['positive electrode'], 'tertiary': ['current collector']}),
#  'Maximum positive particle concentration [mol.m-3]': Max(-0x533f4462df36bf0, function (max), children=['Positive particle concentration [mol.m-3]'], domains={'primary': ['positive particle'], 'secondary': ['positive electrode'], 'tertiary': ['current collector']}),
#  'Minimum positive particle Minimum positive particle surface concentration [mol.m-3]': Min(-0x28b10c794b257058, function (min), children=['boundary value(Positive particle concentration [mol.m-3])'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Maximum positive particle surface concentration [mol.m-3]': Max(0x5020d261d7f41ce2, function (max), children=['boundary value(Positive particle concentration [mol.m-3])'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Positive particle concentration': Division(0x2b4ef03b8382d152, /, children=['Positive particle concentration [mol.m-3]', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive particle'], 'secondary': ['positive electrode'], 'tertiary': ['current collector']}),
#  'X-averaged positive particle concentration': Division(-0x35e9901adff81727, /, children=['x-average(Positive particle concentration [mol.m-3])', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive particle'], 'secondary': ['current collector']}),
#  'R-averaged positive particle concentration': Division(0x113376313cfe7f37, /, children=['r-average(Positive particle concentration [mol.m-3])', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Average positive particle concentration': Division(-0x3312f5cfe4cea39c, /, children=['r-average(x-average(Positive particle concentration [mol.m-3]))', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['current collector']}),
#  'Positive particle surface concentration': Division(0x3b72bbf08cd0fbf6, /, children=['boundary value(Positive particle concentration [mol.m-3])', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive particle surface concentration': Division(-0x51bd301ae8ddd1bd, /, children=['x-average(boundary value(Positive particle concentration [mol.m-3]))', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['current collector']}),
#  'Minimum positive particle concentration': Division(0x1fd7596315e3accc, /, children=['min(Positive particle concentration [mol.m-3])', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive particle'], 'secondary': ['positive electrode'], 'tertiary': ['current collector']}),
#  'Maximum positive particle concentration': Division(-0x68ad904cfdbc1d19, /, children=['max(Positive particle concentration [mol.m-3])', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive particle'], 'secondary': ['positive electrode'], 'tertiary': ['current collector']}),
#  'Minimum positive particle surface concentration': Division(-0x4c7e01360bb42862, /, children=['min(boundary value(Positive particle concentration [mol.m-3]))', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Maximum positive particle surface concentration': Division(-0x1aef6c2373024dd5, /, children=['max(boundary value(Positive particle concentration [mol.m-3]))', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Positive particle stoichiometry': Division(0x2b4ef03b8382d152, /, children=['Positive particle concentration [mol.m-3]', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive particle'], 'secondary': ['positive electrode'], 'tertiary': ['current collector']}),
#  'X-averaged positive particle stoichiometry': Division(-0x35e9901adff81727, /, children=['x-average(Positive particle concentration [mol.m-3])', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive particle'], 'secondary': ['current collector']}),
#  'R-averaged positive particle stoichiometry': Division(0x113376313cfe7f37, /, children=['r-average(Positive particle concentration [mol.m-3])', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Average positive particle stoichiometry': Division(-0x3312f5cfe4cea39c, /, children=['r-average(x-average(Positive particle concentration [mol.m-3]))', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['current collector']}),
#  'Positive particle surface stoichiometry': Division(0x3b72bbf08cd0fbf6, /, children=['boundary value(Positive particle concentration [mol.m-3])', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive particle surface stoichiometry': Division(-0x51bd301ae8ddd1bd, /, children=['x-average(boundary value(Positive particle concentration [mol.m-3]))', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['current collector']}),
#  'Minimum positive particle stoichiometry': Division(0x1fd7596315e3accc, /, children=['min(Positive particle concentration [mol.m-3])', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive particle'], 'secondary': ['positive electrode'], 'tertiary': ['current collector']}),
#  'Maximum positive particle stoichiometry': Division(-0x68ad904cfdbc1d19, /, children=['max(Positive particle concentration [mol.m-3])', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive particle'], 'secondary': ['positive electrode'], 'tertiary': ['current collector']}),
#  'Minimum positive particle surface stoichiometry': Division(-0x4c7e01360bb42862, /, children=['min(boundary value(Positive particle concentration [mol.m-3]))', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Maximum positive particle surface stoichiometry': Division(-0x1aef6c2373024dd5, /, children=['max(boundary value(Positive particle concentration [mol.m-3]))', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Positive electrode extent of lithiation': Division(0x113376313cfe7f37, /, children=['r-average(Positive particle concentration [mol.m-3])', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrode extent of lithiation': Division(-0x3312f5cfe4cea39c, /, children=['r-average(x-average(Positive particle concentration [mol.m-3]))', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['current collector']}),
#  'Negative electrode potential [V]': Variable(-0x3c431812b1c0d03e, Negative electrode potential [V], children=[], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrode potential [V]': XAverage(0x206573848963f82a, x-average, children=['Negative electrode potential [V]'], domains={'primary': ['current collector']}),
#  'Negative electrode ohmic losses [V]': Subtraction(0x7281e9552c5a4476, -, children=['broadcast(boundary value(Negative electrode potential [V]))', 'Negative electrode potential [V]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrode ohmic losses [V]': Subtraction(0x63e21088a0f4a454, -, children=['boundary value(Negative electrode potential [V])', 'x-average(Negative electrode potential [V])'], domains={'primary': ['current collector']}),
#  'Gradient of negative electrode potential [V.m-1]': Gradient(0xa73b15565e8a3e7, grad, children=['Negative electrode potential [V]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Positive electrode potential [V]': Variable(-0x6281e7a5f460f557, Positive electrode potential [V], children=[], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrode potential [V]': XAverage(-0x6c46971bd1bc2910, x-average, children=['Positive electrode potential [V]'], domains={'primary': ['current collector']}),
#  'Positive electrode ohmic losses [V]': Subtraction(0x4b95cb9cdf080331, -, children=['broadcast(boundary value(Positive electrode potential [V]))', 'Positive electrode potential [V]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrode ohmic losses [V]': Subtraction(0x485e0c4885bf562a, -, children=['boundary value(Positive electrode potential [V])', 'x-average(Positive electrode potential [V])'], domains={'primary': ['current collector']}),
#  'Gradient of positive electrode potential [V.m-1]': Gradient(-0x72e6cc3157142138, grad, children=['Positive electrode potential [V]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Porosity times concentration [mol.m-3]': ConcatenationVariable(0xc791f0dfc66270b, Porosity times concentration [mol.m-3], children=['Negative electrode porosity times concentration [mol.m-3]', 'Separator porosity times concentration [mol.m-3]', 'Positive electrode porosity times concentration [mol.m-3]'], domains={'primary': ['negative electrode', 'separator', 'positive electrode'], 'secondary': ['current collector']}),
#  'Negative electrode porosity times concentration [mol.m-3]': Variable(0x6d320b0faf95f451, Negative electrode porosity times concentration [mol.m-3], children=[], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Separator porosity times concentration [mol.m-3]': Variable(-0x5b8ad4d14e9001df, Separator porosity times concentration [mol.m-3], children=[], domains={'primary': ['separator'], 'secondary': ['current collector']}),
#  'Positive electrode porosity times concentration [mol.m-3]': Variable(0x7f1ea4b5e04d3e9c, Positive electrode porosity times concentration [mol.m-3], children=[], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Total lithium in electrolyte [mol]': Multiplication(-0x37355069b9e2c4ff, *, children=['(Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]) * Electrode width [m] * Electrode height [m]', 'yz-average(x-average(Porosity times concentration [mol.m-3](Negative electrode porosity times concentration [mol.m-3], Separator porosity times concentration [mol.m-3], Positive electrode porosity times concentration [mol.m-3])))'], domains={}),
#  'Electrolyte potential [V]': ConcatenationVariable(0x542bf273136be8d, Electrolyte potential [V], children=['Negative electrolyte potential [V]', 'Separator electrolyte potential [V]', 'Positive electrolyte potential [V]'], domains={'primary': ['negative electrode', 'separator', 'positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged electrolyte potential [V]': XAverage(-0x283787829414f865, x-average, children=['Electrolyte potential [V](Negative electrolyte potential [V], Separator electrolyte potential [V], Positive electrolyte potential [V])'], domains={'primary': ['current collector']}),
#  'X-averaged electrolyte overpotential [V]': Subtraction(-0x64b22cd324b60699, -, children=['x-average(Positive electrolyte potential [V])', 'x-average(Negative electrolyte potential [V])'], domains={'primary': ['current collector']}),
#  'Gradient of electrolyte potential [V.m-1]': Gradient(-0x453c46b457acbbb6, grad, children=['Electrolyte potential [V](Negative electrolyte potential [V], Separator electrolyte potential [V], Positive electrolyte potential [V])'], domains={'primary': ['negative electrode', 'separator', 'positive electrode'], 'secondary': ['current collector']}),
#  'Negative electrolyte potential [V]': Variable(-0x40144109da2eb18f, Negative electrolyte potential [V], children=[], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrolyte potential [V]': XAverage(-0x22df07ab148d3cb6, x-average, children=['Negative electrolyte potential [V]'], domains={'primary': ['current collector']}),
#  'Gradient of negative electrolyte potential [V.m-1]': Gradient(0xe9f406d550f092e, grad, children=['Negative electrolyte potential [V]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Separator electrolyte potential [V]': Variable(0x44e8bc1116c6dcd6, Separator electrolyte potential [V], children=[], domains={'primary': ['separator'], 'secondary': ['current collector']}),
#  'X-averaged separator electrolyte potential [V]': XAverage(-0x5b7053f0395835b2, x-average, children=['Separator electrolyte potential [V]'], domains={'primary': ['current collector']}),
#  'Gradient of separator electrolyte potential [V.m-1]': Gradient(0x226b2fa4188da8de, grad, children=['Separator electrolyte potential [V]'], domains={'primary': ['separator'], 'secondary': ['current collector']}),
#  'Positive electrolyte potential [V]': Variable(0x746f303a91571ecb, Positive electrolyte potential [V], children=[], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrolyte potential [V]': XAverage(0x65fa4a8ecee7fab4, x-average, children=['Positive electrolyte potential [V]'], domains={'primary': ['current collector']}),
#  'Gradient of positive electrolyte potential [V.m-1]': Gradient(-0x7242c537515f3320, grad, children=['Positive electrolyte potential [V]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Ambient temperature [K]': FunctionParameter(-0x65a9efaee7e22be2, Ambient temperature [K], children=['y', 'z', 'time'], domains={'primary': ['current collector']}),
#  'Volume-averaged ambient temperature [K]': ZAverage(0x11779336177e9610, z-average, children=['Ambient temperature [K]'], domains={}),
#  'Cell temperature [K]': PrimaryBroadcast(0x5bdcf06e24be1caa, broadcast, children=['broadcast(Volume-averaged cell temperature [K])'], domains={'primary': ['negative electrode', 'separator', 'positive electrode'], 'secondary': ['current collector']}),
#  'Negative current collector temperature [K]': PrimaryBroadcast(-0x7dbb87f13b80f0da, broadcast, children=['Volume-averaged cell temperature [K]'], domains={'primary': ['current collector']}),
#  'Positive current collector temperature [K]': PrimaryBroadcast(-0x7dbb87f13b80f0da, broadcast, children=['Volume-averaged cell temperature [K]'], domains={'primary': ['current collector']}),
#  'X-averaged cell temperature [K]': PrimaryBroadcast(-0x7dbb87f13b80f0da, broadcast, children=['Volume-averaged cell temperature [K]'], domains={'primary': ['current collector']}),
#  'Volume-averaged cell temperature [K]': Variable(0x6416d9c439999f11, Volume-averaged cell temperature [K], children=[], domains={}),
#  'Negative electrode temperature [K]': PrimaryBroadcast(-0x2a0b56975fe01447, broadcast, children=['broadcast(Volume-averaged cell temperature [K])'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrode temperature [K]': PrimaryBroadcast(-0x7dbb87f13b80f0da, broadcast, children=['Volume-averaged cell temperature [K]'], domains={'primary': ['current collector']}),
#  'Separator temperature [K]': PrimaryBroadcast(-0x5fbc97a842896fc8, broadcast, children=['broadcast(Volume-averaged cell temperature [K])'], domains={'primary': ['separator'], 'secondary': ['current collector']}),
#  'X-averaged separator temperature [K]': PrimaryBroadcast(-0x7dbb87f13b80f0da, broadcast, children=['Volume-averaged cell temperature [K]'], domains={'primary': ['current collector']}),
#  'Positive electrode temperature [K]': PrimaryBroadcast(0x277394de59fbbf2c, broadcast, children=['broadcast(Volume-averaged cell temperature [K])'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrode temperature [K]': PrimaryBroadcast(-0x7dbb87f13b80f0da, broadcast, children=['Volume-averaged cell temperature [K]'], domains={'primary': ['current collector']}),
#  'Ambient temperature [C]': Addition(0x3f8893cd8bee3280, +, children=['-273.15', 'Ambient temperature [K]'], domains={'primary': ['current collector']}),
#  'Volume-averaged ambient temperature [C]': Addition(-0x4d26303a0568f276, +, children=['-273.15', 'z-average(Ambient temperature [K])'], domains={}),
#  'Cell temperature [C]': PrimaryBroadcast(0x435fcdd08952d6bb, broadcast, children=['broadcast(-273.15 + Volume-averaged cell temperature [K])'], domains={'primary': ['negative electrode', 'separator', 'positive electrode'], 'secondary': ['current collector']}),
#  'Negative current collector temperature [C]': PrimaryBroadcast(0x51bc2cf98b111461, broadcast, children=['-273.15 + Volume-averaged cell temperature [K]'], domains={'primary': ['current collector']}),
#  'Positive current collector temperature [C]': PrimaryBroadcast(0x51bc2cf98b111461, broadcast, children=['-273.15 + Volume-averaged cell temperature [K]'], domains={'primary': ['current collector']}),
#  'X-averaged cell temperature [C]': PrimaryBroadcast(0x51bc2cf98b111461, broadcast, children=['-273.15 + Volume-averaged cell temperature [K]'], domains={'primary': ['current collector']}),
#  'Volume-averaged cell temperature [C]': Addition(-0xb9398a78c21255f, +, children=['-273.15', 'Volume-averaged cell temperature [K]'], domains={}),
#  'Negative electrode temperature [C]': PrimaryBroadcast(-0x6152e9c4928886ae, broadcast, children=['broadcast(-273.15 + Volume-averaged cell temperature [K])'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrode temperature [C]': PrimaryBroadcast(0x51bc2cf98b111461, broadcast, children=['-273.15 + Volume-averaged cell temperature [K]'], domains={'primary': ['current collector']}),
#  'Separator temperature [C]': PrimaryBroadcast(0x1a4b7340d4e21ab8, broadcast, children=['broadcast(-273.15 + Volume-averaged cell temperature [K])'], domains={'primary': ['separator'], 'secondary': ['current collector']}),
#  'X-averaged separator temperature [C]': PrimaryBroadcast(0x51bc2cf98b111461, broadcast, children=['-273.15 + Volume-averaged cell temperature [K]'], domains={'primary': ['current collector']}),
#  'Positive electrode temperature [C]': PrimaryBroadcast(0x51f487ffa167823e, broadcast, children=['broadcast(-273.15 + Volume-averaged cell temperature [K])'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrode temperature [C]': PrimaryBroadcast(0x51bc2cf98b111461, broadcast, children=['-273.15 + Volume-averaged cell temperature [K]'], domains={'primary': ['current collector']}),
#  'Negative current collector potential [V]': PrimaryBroadcast(-0x1e04279eddc09a00, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'Negative inner SEI thickness [m]': Variable(0x55cec7013341d913, Negative inner SEI thickness [m], children=[], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Negative outer SEI thickness [m]': Variable(-0x11ceb00c23372093, Negative outer SEI thickness [m], children=[], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative inner SEI thickness [m]': XAverage(-0x545a65ab75e5af89, x-average, children=['Negative inner SEI thickness [m]'], domains={'primary': ['current collector']}),
#  'X-averaged negative outer SEI thickness [m]': XAverage(-0x1176949414a38ccc, x-average, children=['Negative outer SEI thickness [m]'], domains={'primary': ['current collector']}),
#  'Negative SEI [m]': Addition(-0x40da6c63c8308b8a, +, children=['Negative inner SEI thickness [m]', 'Negative outer SEI thickness [m]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Negative total SEI thickness [m]': Addition(-0x40da6c63c8308b8a, +, children=['Negative inner SEI thickness [m]', 'Negative outer SEI thickness [m]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative SEI thickness [m]': Addition(0x3b77dd3f439068c7, +, children=['x-average(Negative inner SEI thickness [m])', 'x-average(Negative outer SEI thickness [m])'], domains={'primary': ['current collector']}),
#  'X-averaged negative total SEI thickness [m]': Addition(0x3b77dd3f439068c7, +, children=['x-average(Negative inner SEI thickness [m])', 'x-average(Negative outer SEI thickness [m])'], domains={'primary': ['current collector']}),
#  'X-averaged negative electrode resistance [Ohm.m2]': Multiplication(0x51a70713d05629b3, *, children=['x-average(Negative inner SEI thickness [m]) + x-average(Negative outer SEI thickness [m])', 'SEI resistivity [Ohm.m]'], domains={'primary': ['current collector']}),
#  'Positive inner SEI thickness [m]': FullBroadcast(-0x7035f9cbaa83ee38, broadcast, children=['0.0'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Positive outer SEI thickness [m]': FullBroadcast(-0x7035f9cbaa83ee38, broadcast, children=['0.0'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive inner SEI thickness [m]': PrimaryBroadcast(-0x1e04279eddc09a00, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'X-averaged positive outer SEI thickness [m]': PrimaryBroadcast(-0x1e04279eddc09a00, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'Positive SEI [m]': FullBroadcast(-0x7035f9cbaa83ee38, broadcast, children=['0.0'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
# ...
#  'Loss of lithium inventory [%]': Subtraction(-0x6a458a532c7062c6, -, children=['100.0', '100.0 * (yz-average(x-average(Negative electrode active material volume fraction * r-average(Negative particle concentration [mol.m-3]))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] + yz-average(x-average(Positive electrode active material volume fraction * r-average(Positive particle concentration [mol.m-3]))) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m]) / (yz-average(x-average(Negative electrode active material volume fraction * r-average(Initial concentration in negative electrode [mol.m-3]))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] + yz-average(x-average(Positive electrode active material volume fraction * r-average(Initial concentration in positive electrode [mol.m-3]))) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m])'], domains={}),
#  'Loss of lithium inventory, including electrolyte [%]': Subtraction(-0x6633c0b97d8316d2, -, children=['100.0', '100.0 * (yz-average(x-average(Negative electrode active material volume fraction * r-average(Negative particle concentration [mol.m-3]))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] + yz-average(x-average(Positive electrode active material volume fraction * r-average(Positive particle concentration [mol.m-3]))) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m] + (Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]) * Electrode width [m] * Electrode height [m] * yz-average(x-average(Porosity times concentration [mol.m-3](Negative electrode porosity times concentration [mol.m-3], Separator porosity times concentration [mol.m-3], Positive electrode porosity times concentration [mol.m-3])))) / (yz-average(x-average(Negative electrode active material volume fraction * r-average(Initial concentration in negative electrode [mol.m-3]))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] + yz-average(x-average(Positive electrode active material volume fraction * r-average(Initial concentration in positive electrode [mol.m-3]))) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m] + yz-average((Negative electrode thickness [m] * x-average(Negative electrode porosity) + Separator thickness [m] * x-average(Separator porosity) + Positive electrode thickness [m] * x-average(Positive electrode porosity)) / (Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m])) * Initial concentration in electrolyte [mol.m-3] * (Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]) * Electrode width [m] * Electrode height [m])'], domains={}),
#  'Total lithium [mol]': Addition(0x7767cb404bb27664, +, children=['yz-average(x-average(Negative electrode active material volume fraction * r-average(Negative particle concentration [mol.m-3]))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] + yz-average(x-average(Positive electrode active material volume fraction * r-average(Positive particle concentration [mol.m-3]))) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m]', '(Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]) * Electrode width [m] * Electrode height [m] * yz-average(x-average(Porosity times concentration [mol.m-3](Negative electrode porosity times concentration [mol.m-3], Separator porosity times concentration [mol.m-3], Positive electrode porosity times concentration [mol.m-3])))'], domains={}),
#  'Total lithium in particles [mol]': Addition(0x56fd14d22efa9a1e, +, children=['yz-average(x-average(Negative electrode active material volume fraction * r-average(Negative particle concentration [mol.m-3]))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m]', 'yz-average(x-average(Positive electrode active material volume fraction * r-average(Positive particle concentration [mol.m-3]))) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m]'], domains={}),
#  'Total lithium capacity [A.h]': Multiplication(-0x44aa33a196d7485a, *, children=['0.0002777777777777778', '(yz-average(x-average(Negative electrode active material volume fraction * r-average(Negative particle concentration [mol.m-3]))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] + yz-average(x-average(Positive electrode active material volume fraction * r-average(Positive particle concentration [mol.m-3]))) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m] + (Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]) * Electrode width [m] * Electrode height [m] * yz-average(x-average(Porosity times concentration [mol.m-3](Negative electrode porosity times concentration [mol.m-3], Separator porosity times concentration [mol.m-3], Positive electrode porosity times concentration [mol.m-3])))) * Faraday constant [C.mol-1]'], domains={}),
#  'Total lithium capacity in particles [A.h]': Multiplication(-0x559fab4900b70419, *, children=['0.0002777777777777778', '(yz-average(x-average(Negative electrode active material volume fraction * r-average(Negative particle concentration [mol.m-3]))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] + yz-average(x-average(Positive electrode active material volume fraction * r-average(Positive particle concentration [mol.m-3]))) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m]) * Faraday constant [C.mol-1]'], domains={}),
#  'Total lithium lost [mol]': Subtraction(-0x5981d8cb501791b6, -, children=['yz-average(x-average(Negative electrode active material volume fraction * r-average(Initial concentration in negative electrode [mol.m-3]))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] + yz-average(x-average(Positive electrode active material volume fraction * r-average(Initial concentration in positive electrode [mol.m-3]))) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m] + yz-average((Negative electrode thickness [m] * x-average(Negative electrode porosity) + Separator thickness [m] * x-average(Separator porosity) + Positive electrode thickness [m] * x-average(Positive electrode porosity)) / (Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m])) * Initial concentration in electrolyte [mol.m-3] * (Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]) * Electrode width [m] * Electrode height [m]', 'yz-average(x-average(Negative electrode active material volume fraction * r-average(Negative particle concentration [mol.m-3]))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] + yz-average(x-average(Positive electrode active material volume fraction * r-average(Positive particle concentration [mol.m-3]))) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m] + (Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]) * Electrode width [m] * Electrode height [m] * yz-average(x-average(Porosity times concentration [mol.m-3](Negative electrode porosity times concentration [mol.m-3], Separator porosity times concentration [mol.m-3], Positive electrode porosity times concentration [mol.m-3])))'], domains={}),
#  'Total lithium lost from particles [mol]': Subtraction(-0xdd96642c27cd772, -, children=['yz-average(x-average(Negative electrode active material volume fraction * r-average(Initial concentration in negative electrode [mol.m-3]))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] + yz-average(x-average(Positive electrode active material volume fraction * r-average(Initial concentration in positive electrode [mol.m-3]))) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m]', 'yz-average(x-average(Negative electrode active material volume fraction * r-average(Negative particle concentration [mol.m-3]))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] + yz-average(x-average(Positive electrode active material volume fraction * r-average(Positive particle concentration [mol.m-3]))) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m]'], domains={}),
#  'Total lithium lost from electrolyte [mol]': Subtraction(0x527b3cc09e27672d, -, children=['yz-average((Negative electrode thickness [m] * x-average(Negative electrode porosity) + Separator thickness [m] * x-average(Separator porosity) + Positive electrode thickness [m] * x-average(Positive electrode porosity)) / (Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m])) * Initial concentration in electrolyte [mol.m-3] * (Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]) * Electrode width [m] * Electrode height [m]', '(Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]) * Electrode width [m] * Electrode height [m] * yz-average(x-average(Porosity times concentration [mol.m-3](Negative electrode porosity times concentration [mol.m-3], Separator porosity times concentration [mol.m-3], Positive electrode porosity times concentration [mol.m-3])))'], domains={}),
#  'Total lithium lost to side reactions [mol]': Addition(-0x688323255bddbc25, +, children=['Ratio of lithium moles to SEI moles * (yz-average(x-average(Negative inner SEI thickness [m] * 3.0 * Negative electrode active material volume fraction / Negative particle radius [m] / Inner SEI partial molar volume [m3.mol-1])) + yz-average(x-average(Negative outer SEI thickness [m] * 3.0 * Negative electrode active material volume fraction / Negative particle radius [m] / Outer SEI partial molar volume [m3.mol-1])) - (Initial inner SEI thickness [m] * 3.0 * yz-average(x-average(Negative electrode active material volume fraction)) / Negative particle radius [m] / Inner SEI partial molar volume [m3.mol-1] + Initial outer SEI thickness [m] * 3.0 * yz-average(x-average(Negative electrode active material volume fraction)) / Negative particle radius [m] / Outer SEI partial molar volume [m3.mol-1])) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m]', 'Ratio of lithium moles to SEI moles * (yz-average(x-average(Negative inner SEI on cracks thickness [m] * 3.0 * Negative electrode active material volume fraction / Negative particle radius [m] / Inner SEI partial molar volume [m3.mol-1] * 2.0 * Negative particle crack length [m] * Negative electrode number of cracks per unit area [m-2] * Negative electrode initial crack width [m])) + yz-average(x-average(Negative outer SEI on cracks thickness [m] * 3.0 * Negative electrode active material volume fraction / Negative particle radius [m] / Outer SEI partial molar volume [m3.mol-1] * 2.0 * Negative particle crack length [m] * Negative electrode number of cracks per unit area [m-2] * Negative electrode initial crack width [m])) - ((Initial inner SEI on cracks thickness [m] * 3.0 * yz-average(x-average(Negative electrode active material volume fraction)) / Negative particle radius [m] / Inner SEI partial molar volume [m3.mol-1] + Initial outer SEI on cracks thickness [m] * 3.0 * yz-average(x-average(Negative electrode active material volume fraction)) / Negative particle radius [m] / Outer SEI partial molar volume [m3.mol-1]) * yz-average(x-average(2.0 * Negative particle crack length [m] * Negative electrode number of cracks per unit area [m-2] * Negative electrode initial crack width [m])))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] + x-average(Negative lithium plating concentration [mol.m-3]) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] + x-average(Negative dead lithium concentration [mol.m-3]) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m]'], domains={'primary': ['current collector']}),
#  'Total capacity lost to side reactions [A.h]': Multiplication(-0x18214f083177764, *, children=['0.0002777777777777778', '(Ratio of lithium moles to SEI moles * (yz-average(x-average(Negative inner SEI thickness [m] * 3.0 * Negative electrode active material volume fraction / Negative particle radius [m] / Inner SEI partial molar volume [m3.mol-1])) + yz-average(x-average(Negative outer SEI thickness [m] * 3.0 * Negative electrode active material volume fraction / Negative particle radius [m] / Outer SEI partial molar volume [m3.mol-1])) - (Initial inner SEI thickness [m] * 3.0 * yz-average(x-average(Negative electrode active material volume fraction)) / Negative particle radius [m] / Inner SEI partial molar volume [m3.mol-1] + Initial outer SEI thickness [m] * 3.0 * yz-average(x-average(Negative electrode active material volume fraction)) / Negative particle radius [m] / Outer SEI partial molar volume [m3.mol-1])) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] + Ratio of lithium moles to SEI moles * (yz-average(x-average(Negative inner SEI on cracks thickness [m] * 3.0 * Negative electrode active material volume fraction / Negative particle radius [m] / Inner SEI partial molar volume [m3.mol-1] * 2.0 * Negative particle crack length [m] * Negative electrode number of cracks per unit area [m-2] * Negative electrode initial crack width [m])) + yz-average(x-average(Negative outer SEI on cracks thickness [m] * 3.0 * Negative electrode active material volume fraction / Negative particle radius [m] / Outer SEI partial molar volume [m3.mol-1] * 2.0 * Negative particle crack length [m] * Negative electrode number of cracks per unit area [m-2] * Negative electrode initial crack width [m])) - ((Initial inner SEI on cracks thickness [m] * 3.0 * yz-average(x-average(Negative electrode active material volume fraction)) / Negative particle radius [m] / Inner SEI partial molar volume [m3.mol-1] + Initial outer SEI on cracks thickness [m] * 3.0 * yz-average(x-average(Negative electrode active material volume fraction)) / Negative particle radius [m] / Outer SEI partial molar volume [m3.mol-1]) * yz-average(x-average(2.0 * Negative particle crack length [m] * Negative electrode number of cracks per unit area [m-2] * Negative electrode initial crack width [m])))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] + x-average(Negative lithium plating concentration [mol.m-3]) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] + x-average(Negative dead lithium concentration [mol.m-3]) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m]) * Faraday constant [C.mol-1]'], domains={'primary': ['current collector']})}

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
cwd = os.getcwd()


# 读取 pickle 文件
pickle_file_path = cwd + '/docs/source/examples/notebooks/models/exp_LG/processed_data.pkl'
cycles_df = pd.read_pickle(pickle_file_path)
print("DataFrame loaded from pickle file")
print(cycles_df.head())
# Out:
# DataFrame loaded from pickle file
#             Mode  RelativeTime   Voltage          I  Q_dis     Q_cha  \
# Cycle Step
# 1     1      1.0        0.0000  2.680430  1407.8055    0.0  0.000078
#       2      1.0        0.0084  2.690530  1574.4427    0.0  0.003691
#       3      1.0        0.0294  2.700598  1640.2499    0.0  0.013108
#       4      1.0        0.0634  2.710643  1664.4644    0.0  0.028749
#       5      1.0        0.1074  2.720645  1668.5892    0.0  0.049123
#
#                  Cap         R    Pressure  Temperature
# Cycle Step
# 1     1     0.000078  1.903978  159.026607      25.3794
#       2     0.003691  1.708878  158.944819      25.3885
#       3     0.013108  1.646455  158.998347      25.4014
#       4     0.028749  1.628537  159.049016      25.4088
#       5     0.049123  1.630506  158.990980      25.4014

# %%
# Compare model data to experiment including degradation

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(13, 4))

# plot the 1C results
t_sol = sol["Time [s]"].entries


ax1.plot(t_sol, sol["Voltage [V]"](t_sol))
ax1.plot(cycles_df.loc[1]["RelativeTime"],cycles_df.loc[1]["Voltage"], "o")
ax1.set_xlabel("Time [s]")
ax1.set_ylabel("Voltage [V]")
ax1.set_title("Voltage")
ax1.legend(["Model", "Experiment"], loc="best")


ax2.plot(t_sol, sol["X-averaged cell temperature [C]"](t_sol))
ax2.plot(cycles_df.loc[1]["RelativeTime"],cycles_df.loc[1]["Temperature"], "o")
ax2.set_xlabel("Time [s]")
ax2.set_ylabel("Temperature [degC]")
ax2.set_title("Temperature")
ax2.legend(["Model", "Experiment"], loc="best")

plt.tight_layout()
plt.show()

# %%
plt.plot(sol["Time [s]"].entries,sol["Discharge capacity [A.h]"].entries )

# %%
sol["Discharge capacity [A.h]"].entries
# Out:
# array([ 0.        , -0.025     , -0.05      , -0.075     , -0.1       ,
#        -0.125     , -0.15      , -0.175     , -0.2       , -0.225     ,
#        -0.25      , -0.275     , -0.3       , -0.325     , -0.35      ,
#        -0.375     , -0.4       , -0.425     , -0.45      , -0.475     ,
#        -0.5       , -0.525     , -0.55      , -0.575     , -0.6       ,
#        -0.625     , -0.65      , -0.675     , -0.7       , -0.725     ,
#        -0.75      , -0.775     , -0.8       , -0.825     , -0.85      ,
#        -0.875     , -0.9       , -0.925     , -0.95      , -0.975     ,
#        -1.        , -1.025     , -1.05      , -1.075     , -1.1       ,
#        -1.125     , -1.15      , -1.175     , -1.2       , -1.225     ,
#        -1.25      , -1.275     , -1.3       , -1.325     , -1.35      ,
#        -1.375     , -1.4       , -1.425     , -1.45      , -1.475     ,
#        -1.5       , -1.525     , -1.55      , -1.575     , -1.6       ,
#        -1.625     , -1.65      , -1.675     , -1.7       , -1.725     ,
#        -1.75      , -1.775     , -1.8       , -1.825     , -1.85      ,
#        -1.875     , -1.9       , -1.925     , -1.95      , -1.975     ,
#        -2.        , -2.025     , -2.05      , -2.075     , -2.1       ,
#        -2.125     , -2.15      , -2.175     , -2.2       , -2.225     ,
#        -2.25      , -2.275     , -2.3       , -2.325     , -2.35      ,
#        -2.375     , -2.4       , -2.425     , -2.45      , -2.475     ,
#        -2.5       , -2.525     , -2.55      , -2.575     , -2.6       ,
#        -2.625     , -2.65      , -2.675     , -2.7       , -2.725     ,
#        -2.75      , -2.775     , -2.8       , -2.825     , -2.85      ,
#        -2.875     , -2.9       , -2.925     , -2.95      , -2.975     ,
#        -3.        , -3.025     , -3.05      , -3.075     , -3.1       ,
#        -3.125     , -3.15      , -3.175     , -3.2       , -3.225     ,
#        -3.25      , -3.275     , -3.3       , -3.325     , -3.35      ,
#        -3.375     , -3.4       , -3.425     , -3.45      , -3.475     ,
#        -3.5       , -3.525     , -3.55      , -3.575     , -3.6       ,
#        -3.625     , -3.65      , -3.675     , -3.7       , -3.725     ,
#        -3.75      , -3.775     , -3.8       , -3.825     , -3.85      ,
#        -3.875     , -3.9       , -3.925     , -3.95      , -3.975     ,
#        -4.        , -4.025     , -4.05      , -4.075     , -4.1       ,
#        -4.125     , -4.15      , -4.175     , -4.2       , -4.225     ,
#        -4.25      , -4.275     , -4.3       , -4.325     , -4.35      ,
#        -4.375     , -4.4       , -4.425     , -4.45      , -4.475     ,
#        -4.5       , -4.525     , -4.55      , -4.575     , -4.6       ,
#        -4.625     , -4.65      , -4.675     , -4.7       , -4.725     ,
#        -4.75      , -4.775     , -4.78802564, -4.78802564, -4.81169634,
#        -4.83330484, -4.8531352 , -4.87142733, -4.88829201, -4.90382378,
#        -4.91820566, -4.93152666, -4.94386681, -4.95534299, -4.96596968,
#        -4.97578458, -4.98489003, -4.99337769, -5.00129431, -5.0086671 ,
#        -5.01551751, -5.02187439, -5.02778036, -5.03328222, -5.0384276 ,
#        -5.04324675, -5.04776216, -5.05072921, -5.05072921, -4.96739588,
#        -4.88406254, -4.80072921, -4.71739588, -4.63406254, -4.55072921,
#        -4.46739588, -4.38406254, -4.30072921, -4.21739588, -4.13406254,
#        -4.05072921, -3.96739588, -3.88406254, -3.80072921, -3.71739588,
#        -3.63406254, -3.55072921, -3.46739588, -3.38406254, -3.30072921,
#        -3.21739588, -3.13406254, -3.05072921, -2.96739588, -2.88406254,
#        -2.80072921, -2.71739588, -2.63406254, -2.55072921, -2.46739588,
#        -2.38406254, -2.30072921, -2.21739588, -2.13406254, -2.05072921,
#        -1.96739588, -1.88406254, -1.80072921, -1.71739588, -1.63406254,
#        -1.55072921, -1.46739588, -1.38406254, -1.30072921, -1.21739588,
#        -1.13406254, -1.05072921, -0.96739588, -0.88406254, -0.80072921,
#        -0.71739588, -0.63406254, -0.55072921, -0.46739588, -0.38406254,
#        -0.30072921, -0.21739588, -0.13406254, -0.11229527])

# %%
# Compare model data to experiment without degradation

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(13, 4))

# plot the 1C results
t_sol_nodeg = sol_nodeg["Time [s]"].entries


ax1.plot(t_sol_nodeg, sol_nodeg["Voltage [V]"](t_sol_nodeg))
ax1.plot(cycles_df.loc[1]["RelativeTime"],cycles_df.loc[1]["Voltage"], "o")
ax1.set_xlabel("Time [s]")
ax1.set_ylabel("Voltage [V]")
ax1.set_title("Voltage")
ax1.legend(["Model", "Experiment"], loc="best")


ax2.plot(t_sol_nodeg, sol_nodeg["X-averaged cell temperature [C]"](t_sol_nodeg))
ax2.plot(cycles_df.loc[1]["RelativeTime"],cycles_df.loc[1]["Temperature"], "o")
ax2.set_xlabel("Time [s]")
ax2.set_ylabel("Temperature [degC]")
ax2.set_title("Temperature")
ax2.legend(["Model", "Experiment"], loc="best")

plt.tight_layout()
plt.show()

# %%
model.variables
# Out:
# {'Time [s]': Time(0x6c31452b945f1d96, time, children=[], domains={}),
#  'Time [min]': Multiplication(-0x1fb12df3d36d6773, *, children=['0.016666666666666666', 'time'], domains={}),
#  'Time [h]': Multiplication(0x551d444bbed52b07, *, children=['0.0002777777777777778', 'time'], domains={}),
#  'x [m]': SpatialVariable(-0x59fd0a5aac1c5b59, x, children=[], domains={'primary': ['negative electrode', 'separator', 'positive electrode'], 'secondary': ['current collector']}),
#  'x_n [m]': SpatialVariable(0x289a3f471aa55830, x_n, children=[], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'x_s [m]': SpatialVariable(-0x232b86b969c1e49e, x_s, children=[], domains={'primary': ['separator'], 'secondary': ['current collector']}),
#  'x_p [m]': SpatialVariable(0x7df69a0e0af4d9f6, x_p, children=[], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'r_n [m]': SpatialVariable(-0x1c110462af07d037, r_n, children=[], domains={'primary': ['negative particle'], 'secondary': ['negative electrode'], 'tertiary': ['current collector']}),
#  'r_p [m]': SpatialVariable(0x64106c1e2a2dac6f, r_p, children=[], domains={'primary': ['positive particle'], 'secondary': ['positive electrode'], 'tertiary': ['current collector']}),
#  'Current variable [A]': FunctionParameter(0x2b0f7f69a0b884a7, Current function [A], children=['time'], domains={}),
#  'Total current density [A.m-2]': Division(0x77b63cd24bb02609, /, children=['Current function [A]', 'Number of electrodes connected in parallel to make a cell * Electrode width [m] * Electrode height [m]'], domains={}),
#  'Current [A]': FunctionParameter(0x2b0f7f69a0b884a7, Current function [A], children=['time'], domains={}),
#  'C-rate': Division(-0x5fa1d9a0761c8779, /, children=['Current function [A]', 'Nominal cell capacity [A.h]'], domains={}),
#  'Discharge capacity [A.h]': Variable(-0x540127835e1d16c1, Discharge capacity [A.h], children=[], domains={}),
#  'Throughput capacity [A.h]': Variable(0x67b889c8c892e802, Throughput capacity [A.h], children=[], domains={}),
#  'Discharge energy [W.h]': Variable(-0x35749bc93cc6902c, Discharge energy [W.h], children=[], domains={}),
#  'Throughput energy [W.h]': Variable(-0x29a85dec5177b5b, Throughput energy [W.h], children=[], domains={}),
#  'Negative electrode interface utilisation variable': FullBroadcast(-0x69cba1ed73eaf79f, broadcast, children=['1.0'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrode interface utilisation variable': PrimaryBroadcast(0x5afd7db397fce113, broadcast, children=['1.0'], domains={'primary': ['current collector']}),
#  'Negative electrode interface utilisation': FullBroadcast(-0x69cba1ed73eaf79f, broadcast, children=['1.0'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrode interface utilisation': PrimaryBroadcast(0x5afd7db397fce113, broadcast, children=['1.0'], domains={'primary': ['current collector']}),
#  'Positive electrode interface utilisation variable': FullBroadcast(0x497bcfd6c005114d, broadcast, children=['1.0'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrode interface utilisation variable': PrimaryBroadcast(0x5afd7db397fce113, broadcast, children=['1.0'], domains={'primary': ['current collector']}),
#  'Positive electrode interface utilisation': FullBroadcast(0x497bcfd6c005114d, broadcast, children=['1.0'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrode interface utilisation': PrimaryBroadcast(0x5afd7db397fce113, broadcast, children=['1.0'], domains={'primary': ['current collector']}),
#  'Negative particle crack length [m]': Variable(0x70cc54e10e1be437, Negative particle crack length [m], children=[], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative particle crack length [m]': XAverage(-0x59cd39681f846ff2, x-average, children=['Negative particle crack length [m]'], domains={'primary': ['current collector']}),
#  'Positive particle crack length [m]': FullBroadcast(-0x7035f9cbaa83ee38, broadcast, children=['0.0'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive particle crack length [m]': PrimaryBroadcast(-0x1e04279eddc09a00, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'Positive particle cracking rate [m.s-1]': FullBroadcast(-0x7035f9cbaa83ee38, broadcast, children=['0.0'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive particle cracking rate [m.s-1]': PrimaryBroadcast(-0x1e04279eddc09a00, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'Negative electrode active material volume fraction': Variable(-0x3a307434ca25e76a, Negative electrode active material volume fraction, children=[], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrode active material volume fraction': XAverage(-0x6b5b6b2f0715b698, x-average, children=['Negative electrode active material volume fraction'], domains={'primary': ['current collector']}),
#  'Negative electrode capacity [A.h]': Multiplication(-0x223b5f41a934b32d, *, children=['0.0002777777777777778', 'yz-average(x-average(Negative electrode active material volume fraction)) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] * Maximum concentration in negative electrode [mol.m-3] * Faraday constant [C.mol-1]'], domains={}),
#  'Negative particle radius': Division(-0x6650ebea62dbe4ee, /, children=['Negative particle radius [m]', 'Negative particle radius [m]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Negative particle radius [m]': FunctionParameter(0x4c2b8d90a0202b17, Negative particle radius [m], children=['x_n'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative particle radius [m]': XAverage(-0x29bdb7e27c5a7c3, x-average, children=['Negative particle radius [m]'], domains={'primary': ['current collector']}),
#  'Negative electrode surface area to volume ratio [m-1]': Division(0x1dfe928d2e00873, /, children=['3.0 * Negative electrode active material volume fraction', 'Negative particle radius [m]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrode surface area to volume ratio [m-1]': XAverage(-0x207a447068e8cba0, x-average, children=['3.0 * Negative electrode active material volume fraction / Negative particle radius [m]'], domains={'primary': ['current collector']}),
#  'Loss of lithium due to loss of active material in negative electrode [mol]': Variable(-0x4f18c2d1d86617c3, Loss of lithium due to loss of active material in negative electrode [mol], children=[], domains={}),
#  'Positive electrode active material volume fraction': Variable(0x4bbf1a668bdcbb27, Positive electrode active material volume fraction, children=[], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrode active material volume fraction': XAverage(-0x910e4f6c138939a, x-average, children=['Positive electrode active material volume fraction'], domains={'primary': ['current collector']}),
#  'Positive electrode capacity [A.h]': Multiplication(-0x1af44071cc849648, *, children=['0.0002777777777777778', 'yz-average(x-average(Positive electrode active material volume fraction)) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m] * Maximum concentration in positive electrode [mol.m-3] * Faraday constant [C.mol-1]'], domains={}),
#  'Positive particle radius': Division(0x136f96c53587c310, /, children=['Positive particle radius [m]', 'Positive particle radius [m]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Positive particle radius [m]': FunctionParameter(0x44c424f54d6d4bd8, Positive particle radius [m], children=['x_p'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive particle radius [m]': XAverage(0x6d483b02f4d71f06, x-average, children=['Positive particle radius [m]'], domains={'primary': ['current collector']}),
#  'Positive electrode surface area to volume ratio [m-1]': Division(-0x7e43e4748610cb7a, /, children=['3.0 * Positive electrode active material volume fraction', 'Positive particle radius [m]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrode surface area to volume ratio [m-1]': XAverage(-0x1914b85cb136e1f1, x-average, children=['3.0 * Positive electrode active material volume fraction / Positive particle radius [m]'], domains={'primary': ['current collector']}),
#  'Loss of lithium due to loss of active material in positive electrode [mol]': Variable(0x84367e42d7bae67, Loss of lithium due to loss of active material in positive electrode [mol], children=[], domains={}),
#  'Separator pressure [Pa]': PrimaryBroadcast(-0xe58a970da795032, broadcast, children=['broadcast(0.0)'], domains={'primary': ['separator'], 'secondary': ['current collector']}),
#  'X-averaged separator pressure [Pa]': PrimaryBroadcast(-0x1e04279eddc09a00, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'negative electrode transverse volume-averaged velocity [m.s-1]': PrimaryBroadcast(0x7608f989be1c0e68, broadcast, children=['broadcast(0.0)'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrode transverse volume-averaged velocity [m.s-1]': PrimaryBroadcast(-0x1e04279eddc09a00, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'separator transverse volume-averaged velocity [m.s-1]': PrimaryBroadcast(-0xe58a970da795032, broadcast, children=['broadcast(0.0)'], domains={'primary': ['separator'], 'secondary': ['current collector']}),
#  'X-averaged separator transverse volume-averaged velocity [m.s-1]': PrimaryBroadcast(-0x1e04279eddc09a00, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'positive electrode transverse volume-averaged velocity [m.s-1]': PrimaryBroadcast(0x29506b4df20c1754, broadcast, children=['broadcast(0.0)'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrode transverse volume-averaged velocity [m.s-1]': PrimaryBroadcast(-0x1e04279eddc09a00, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'Transverse volume-averaged velocity [m.s-1]': PrimaryBroadcast(0x1abbb11ed9f76bd1, broadcast, children=['broadcast(0.0)'], domains={'primary': ['negative electrode', 'separator', 'positive electrode'], 'secondary': ['current collector']}),
#  'negative electrode transverse volume-averaged acceleration [m.s-2]': PrimaryBroadcast(0x7608f989be1c0e68, broadcast, children=['broadcast(0.0)'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrode transverse volume-averaged acceleration [m.s-2]': PrimaryBroadcast(-0x1e04279eddc09a00, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'separator transverse volume-averaged acceleration [m.s-2]': PrimaryBroadcast(-0xe58a970da795032, broadcast, children=['broadcast(0.0)'], domains={'primary': ['separator'], 'secondary': ['current collector']}),
#  'X-averaged separator transverse volume-averaged acceleration [m.s-2]': PrimaryBroadcast(-0x1e04279eddc09a00, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'positive electrode transverse volume-averaged acceleration [m.s-2]': PrimaryBroadcast(0x29506b4df20c1754, broadcast, children=['broadcast(0.0)'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrode transverse volume-averaged acceleration [m.s-2]': PrimaryBroadcast(-0x1e04279eddc09a00, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'Transverse volume-averaged acceleration [m.s-2]': PrimaryBroadcast(0x1abbb11ed9f76bd1, broadcast, children=['broadcast(0.0)'], domains={'primary': ['negative electrode', 'separator', 'positive electrode'], 'secondary': ['current collector']}),
#  'Negative electrode volume-averaged velocity [m.s-1]': FullBroadcast(-0x543a12c81736921a, broadcast, children=['0.0'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Negative electrode volume-averaged acceleration [m.s-2]': FullBroadcast(-0x543a12c81736921a, broadcast, children=['0.0'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrode volume-averaged acceleration [m.s-2]': PrimaryBroadcast(-0x1e04279eddc09a00, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'Negative electrode pressure [Pa]': FullBroadcast(-0x543a12c81736921a, broadcast, children=['0.0'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrode pressure [Pa]': PrimaryBroadcast(-0x1e04279eddc09a00, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'Positive electrode volume-averaged velocity [m.s-1]': FullBroadcast(-0x7035f9cbaa83ee38, broadcast, children=['0.0'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Positive electrode volume-averaged acceleration [m.s-2]': FullBroadcast(-0x7035f9cbaa83ee38, broadcast, children=['0.0'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrode volume-averaged acceleration [m.s-2]': PrimaryBroadcast(-0x1e04279eddc09a00, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'Positive electrode pressure [Pa]': FullBroadcast(-0x7035f9cbaa83ee38, broadcast, children=['0.0'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrode pressure [Pa]': PrimaryBroadcast(-0x1e04279eddc09a00, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'Total negative electrode interfacial current density variable [A.m-2]': Variable(0x1f62d5a8ddbc2ec1, Total negative electrode interfacial current density variable [A.m-2], children=[], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged total negative electrode interfacial current density variable [A.m-2]': XAverage(-0x4404e08467b95c34, x-average, children=['Total negative electrode interfacial current density variable [A.m-2]'], domains={'primary': ['current collector']}),
#  'Total positive electrode interfacial current density variable [A.m-2]': Variable(0xea80706c6127018, Total positive electrode interfacial current density variable [A.m-2], children=[], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged total positive electrode interfacial current density variable [A.m-2]': XAverage(0x6c711bd1b848bfe1, x-average, children=['Total positive electrode interfacial current density variable [A.m-2]'], domains={'primary': ['current collector']}),
#  'Negative particle concentration [mol.m-3]': Variable(0x7a835a37bd30cff0, Negative particle concentration [mol.m-3], children=[], domains={'primary': ['negative particle'], 'secondary': ['negative electrode'], 'tertiary': ['current collector']}),
#  'X-averaged negative particle concentration [mol.m-3]': XAverage(-0x4bcd3586552344e9, x-average, children=['Negative particle concentration [mol.m-3]'], domains={'primary': ['negative particle'], 'secondary': ['current collector']}),
#  'R-averaged negative particle concentration [mol.m-3]': RAverage(0x7bed4c914e4f2353, r-average, children=['Negative particle concentration [mol.m-3]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Average negative particle concentration [mol.m-3]': RAverage(-0x156e88ba48861121, r-average, children=['x-average(Negative particle concentration [mol.m-3])'], domains={'primary': ['current collector']}),
#  'Negative particle surface concentration [mol.m-3]': BoundaryValue(0x4b8334f196aa709a, boundary value, children=['Negative particle concentration [mol.m-3]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative particle surface concentration [mol.m-3]': XAverage(-0x46c0ce3a3ea9194b, x-average, children=['boundary value(Negative particle concentration [mol.m-3])'], domains={'primary': ['current collector']}),
#  'Minimum negative particle concentration [mol.m-3]': Min(-0x44d3eb7288aeaa49, function (min), children=['Negative particle concentration [mol.m-3]'], domains={'primary': ['negative particle'], 'secondary': ['negative electrode'], 'tertiary': ['current collector']}),
#  'Maximum negative particle concentration [mol.m-3]': Max(0x417f032006b0f844, function (max), children=['Negative particle concentration [mol.m-3]'], domains={'primary': ['negative particle'], 'secondary': ['negative electrode'], 'tertiary': ['current collector']}),
#  'Minimum negative particle Minimum negative particle surface concentration [mol.m-3]': Min(0x26414af4810d6610, function (min), children=['boundary value(Negative particle concentration [mol.m-3])'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Maximum negative particle surface concentration [mol.m-3]': Max(0x619dfaa3c107d5ff, function (max), children=['boundary value(Negative particle concentration [mol.m-3])'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Negative particle concentration': Division(-0x4ddde9da40aa8378, /, children=['Negative particle concentration [mol.m-3]', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative particle'], 'secondary': ['negative electrode'], 'tertiary': ['current collector']}),
#  'X-averaged negative particle concentration': Division(-0x28020eed8d86b385, /, children=['x-average(Negative particle concentration [mol.m-3])', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative particle'], 'secondary': ['current collector']}),
#  'R-averaged negative particle concentration': Division(-0x1e0de9984af884a8, /, children=['r-average(Negative particle concentration [mol.m-3])', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Average negative particle concentration': Division(0x2521912a54e44275, /, children=['r-average(x-average(Negative particle concentration [mol.m-3]))', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['current collector']}),
#  'Negative particle surface concentration': Division(0x65c754c3171a7073, /, children=['boundary value(Negative particle concentration [mol.m-3])', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative particle surface concentration': Division(-0x135267fe76cf6924, /, children=['x-average(boundary value(Negative particle concentration [mol.m-3]))', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['current collector']}),
#  'Minimum negative particle concentration': Division(-0x6ef9167c48aea387, /, children=['min(Negative particle concentration [mol.m-3])', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative particle'], 'secondary': ['negative electrode'], 'tertiary': ['current collector']}),
#  'Maximum negative particle concentration': Division(-0x76013ed76df87ceb, /, children=['max(Negative particle concentration [mol.m-3])', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative particle'], 'secondary': ['negative electrode'], 'tertiary': ['current collector']}),
#  'Minimum negative particle surface concentration': Division(0x65ee57fd4713d271, /, children=['min(boundary value(Negative particle concentration [mol.m-3]))', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Maximum negative particle surface concentration': Division(-0x3c14887555064cc5, /, children=['max(boundary value(Negative particle concentration [mol.m-3]))', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Negative particle stoichiometry': Division(-0x4ddde9da40aa8378, /, children=['Negative particle concentration [mol.m-3]', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative particle'], 'secondary': ['negative electrode'], 'tertiary': ['current collector']}),
#  'X-averaged negative particle stoichiometry': Division(-0x28020eed8d86b385, /, children=['x-average(Negative particle concentration [mol.m-3])', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative particle'], 'secondary': ['current collector']}),
#  'R-averaged negative particle stoichiometry': Division(-0x1e0de9984af884a8, /, children=['r-average(Negative particle concentration [mol.m-3])', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Average negative particle stoichiometry': Division(0x2521912a54e44275, /, children=['r-average(x-average(Negative particle concentration [mol.m-3]))', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['current collector']}),
#  'Negative particle surface stoichiometry': Division(0x65c754c3171a7073, /, children=['boundary value(Negative particle concentration [mol.m-3])', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative particle surface stoichiometry': Division(-0x135267fe76cf6924, /, children=['x-average(boundary value(Negative particle concentration [mol.m-3]))', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['current collector']}),
#  'Minimum negative particle stoichiometry': Division(-0x6ef9167c48aea387, /, children=['min(Negative particle concentration [mol.m-3])', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative particle'], 'secondary': ['negative electrode'], 'tertiary': ['current collector']}),
#  'Maximum negative particle stoichiometry': Division(-0x76013ed76df87ceb, /, children=['max(Negative particle concentration [mol.m-3])', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative particle'], 'secondary': ['negative electrode'], 'tertiary': ['current collector']}),
#  'Minimum negative particle surface stoichiometry': Division(0x65ee57fd4713d271, /, children=['min(boundary value(Negative particle concentration [mol.m-3]))', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Maximum negative particle surface stoichiometry': Division(-0x3c14887555064cc5, /, children=['max(boundary value(Negative particle concentration [mol.m-3]))', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Negative electrode extent of lithiation': Division(-0x1e0de9984af884a8, /, children=['r-average(Negative particle concentration [mol.m-3])', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrode extent of lithiation': Division(0x2521912a54e44275, /, children=['r-average(x-average(Negative particle concentration [mol.m-3]))', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['current collector']}),
#  'Positive particle concentration [mol.m-3]': Variable(-0x2d38ceb83f94fe17, Positive particle concentration [mol.m-3], children=[], domains={'primary': ['positive particle'], 'secondary': ['positive electrode'], 'tertiary': ['current collector']}),
#  'X-averaged positive particle concentration [mol.m-3]': XAverage(-0x5b60d3e8b1f226ff, x-average, children=['Positive particle concentration [mol.m-3]'], domains={'primary': ['positive particle'], 'secondary': ['current collector']}),
#  'R-averaged positive particle concentration [mol.m-3]': RAverage(-0x596d5194b19b1c0a, r-average, children=['Positive particle concentration [mol.m-3]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Average positive particle concentration [mol.m-3]': RAverage(-0x1a0425241fbed9e1, r-average, children=['x-average(Positive particle concentration [mol.m-3])'], domains={'primary': ['current collector']}),
#  'Positive particle surface concentration [mol.m-3]': BoundaryValue(0x6c129ccf020609a5, boundary value, children=['Positive particle concentration [mol.m-3]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive particle surface concentration [mol.m-3]': XAverage(-0x255156c92f34a8ab, x-average, children=['boundary value(Positive particle concentration [mol.m-3])'], domains={'primary': ['current collector']}),
#  'Minimum positive particle concentration [mol.m-3]': Min(0x2c68feb43e83d128, function (min), children=['Positive particle concentration [mol.m-3]'], domains={'primary': ['positive particle'], 'secondary': ['positive electrode'], 'tertiary': ['current collector']}),
#  'Maximum positive particle concentration [mol.m-3]': Max(-0x533f4462df36bf0, function (max), children=['Positive particle concentration [mol.m-3]'], domains={'primary': ['positive particle'], 'secondary': ['positive electrode'], 'tertiary': ['current collector']}),
#  'Minimum positive particle Minimum positive particle surface concentration [mol.m-3]': Min(-0x28b10c794b257058, function (min), children=['boundary value(Positive particle concentration [mol.m-3])'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Maximum positive particle surface concentration [mol.m-3]': Max(0x5020d261d7f41ce2, function (max), children=['boundary value(Positive particle concentration [mol.m-3])'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Positive particle concentration': Division(0x2b4ef03b8382d152, /, children=['Positive particle concentration [mol.m-3]', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive particle'], 'secondary': ['positive electrode'], 'tertiary': ['current collector']}),
#  'X-averaged positive particle concentration': Division(-0x35e9901adff81727, /, children=['x-average(Positive particle concentration [mol.m-3])', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive particle'], 'secondary': ['current collector']}),
#  'R-averaged positive particle concentration': Division(0x113376313cfe7f37, /, children=['r-average(Positive particle concentration [mol.m-3])', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Average positive particle concentration': Division(-0x3312f5cfe4cea39c, /, children=['r-average(x-average(Positive particle concentration [mol.m-3]))', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['current collector']}),
#  'Positive particle surface concentration': Division(0x3b72bbf08cd0fbf6, /, children=['boundary value(Positive particle concentration [mol.m-3])', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive particle surface concentration': Division(-0x51bd301ae8ddd1bd, /, children=['x-average(boundary value(Positive particle concentration [mol.m-3]))', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['current collector']}),
#  'Minimum positive particle concentration': Division(0x1fd7596315e3accc, /, children=['min(Positive particle concentration [mol.m-3])', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive particle'], 'secondary': ['positive electrode'], 'tertiary': ['current collector']}),
#  'Maximum positive particle concentration': Division(-0x68ad904cfdbc1d19, /, children=['max(Positive particle concentration [mol.m-3])', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive particle'], 'secondary': ['positive electrode'], 'tertiary': ['current collector']}),
#  'Minimum positive particle surface concentration': Division(-0x4c7e01360bb42862, /, children=['min(boundary value(Positive particle concentration [mol.m-3]))', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Maximum positive particle surface concentration': Division(-0x1aef6c2373024dd5, /, children=['max(boundary value(Positive particle concentration [mol.m-3]))', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Positive particle stoichiometry': Division(0x2b4ef03b8382d152, /, children=['Positive particle concentration [mol.m-3]', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive particle'], 'secondary': ['positive electrode'], 'tertiary': ['current collector']}),
#  'X-averaged positive particle stoichiometry': Division(-0x35e9901adff81727, /, children=['x-average(Positive particle concentration [mol.m-3])', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive particle'], 'secondary': ['current collector']}),
#  'R-averaged positive particle stoichiometry': Division(0x113376313cfe7f37, /, children=['r-average(Positive particle concentration [mol.m-3])', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Average positive particle stoichiometry': Division(-0x3312f5cfe4cea39c, /, children=['r-average(x-average(Positive particle concentration [mol.m-3]))', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['current collector']}),
#  'Positive particle surface stoichiometry': Division(0x3b72bbf08cd0fbf6, /, children=['boundary value(Positive particle concentration [mol.m-3])', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive particle surface stoichiometry': Division(-0x51bd301ae8ddd1bd, /, children=['x-average(boundary value(Positive particle concentration [mol.m-3]))', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['current collector']}),
#  'Minimum positive particle stoichiometry': Division(0x1fd7596315e3accc, /, children=['min(Positive particle concentration [mol.m-3])', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive particle'], 'secondary': ['positive electrode'], 'tertiary': ['current collector']}),
#  'Maximum positive particle stoichiometry': Division(-0x68ad904cfdbc1d19, /, children=['max(Positive particle concentration [mol.m-3])', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive particle'], 'secondary': ['positive electrode'], 'tertiary': ['current collector']}),
#  'Minimum positive particle surface stoichiometry': Division(-0x4c7e01360bb42862, /, children=['min(boundary value(Positive particle concentration [mol.m-3]))', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Maximum positive particle surface stoichiometry': Division(-0x1aef6c2373024dd5, /, children=['max(boundary value(Positive particle concentration [mol.m-3]))', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Positive electrode extent of lithiation': Division(0x113376313cfe7f37, /, children=['r-average(Positive particle concentration [mol.m-3])', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrode extent of lithiation': Division(-0x3312f5cfe4cea39c, /, children=['r-average(x-average(Positive particle concentration [mol.m-3]))', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['current collector']}),
#  'Negative electrode potential [V]': Variable(-0x3c431812b1c0d03e, Negative electrode potential [V], children=[], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrode potential [V]': XAverage(0x206573848963f82a, x-average, children=['Negative electrode potential [V]'], domains={'primary': ['current collector']}),
#  'Negative electrode ohmic losses [V]': Subtraction(0x7281e9552c5a4476, -, children=['broadcast(boundary value(Negative electrode potential [V]))', 'Negative electrode potential [V]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrode ohmic losses [V]': Subtraction(0x63e21088a0f4a454, -, children=['boundary value(Negative electrode potential [V])', 'x-average(Negative electrode potential [V])'], domains={'primary': ['current collector']}),
#  'Gradient of negative electrode potential [V.m-1]': Gradient(0xa73b15565e8a3e7, grad, children=['Negative electrode potential [V]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Positive electrode potential [V]': Variable(-0x6281e7a5f460f557, Positive electrode potential [V], children=[], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrode potential [V]': XAverage(-0x6c46971bd1bc2910, x-average, children=['Positive electrode potential [V]'], domains={'primary': ['current collector']}),
#  'Positive electrode ohmic losses [V]': Subtraction(0x4b95cb9cdf080331, -, children=['broadcast(boundary value(Positive electrode potential [V]))', 'Positive electrode potential [V]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrode ohmic losses [V]': Subtraction(0x485e0c4885bf562a, -, children=['boundary value(Positive electrode potential [V])', 'x-average(Positive electrode potential [V])'], domains={'primary': ['current collector']}),
#  'Gradient of positive electrode potential [V.m-1]': Gradient(-0x72e6cc3157142138, grad, children=['Positive electrode potential [V]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Porosity times concentration [mol.m-3]': ConcatenationVariable(0xc791f0dfc66270b, Porosity times concentration [mol.m-3], children=['Negative electrode porosity times concentration [mol.m-3]', 'Separator porosity times concentration [mol.m-3]', 'Positive electrode porosity times concentration [mol.m-3]'], domains={'primary': ['negative electrode', 'separator', 'positive electrode'], 'secondary': ['current collector']}),
#  'Negative electrode porosity times concentration [mol.m-3]': Variable(0x6d320b0faf95f451, Negative electrode porosity times concentration [mol.m-3], children=[], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Separator porosity times concentration [mol.m-3]': Variable(-0x5b8ad4d14e9001df, Separator porosity times concentration [mol.m-3], children=[], domains={'primary': ['separator'], 'secondary': ['current collector']}),
#  'Positive electrode porosity times concentration [mol.m-3]': Variable(0x7f1ea4b5e04d3e9c, Positive electrode porosity times concentration [mol.m-3], children=[], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Total lithium in electrolyte [mol]': Multiplication(-0x37355069b9e2c4ff, *, children=['(Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]) * Electrode width [m] * Electrode height [m]', 'yz-average(x-average(Porosity times concentration [mol.m-3](Negative electrode porosity times concentration [mol.m-3], Separator porosity times concentration [mol.m-3], Positive electrode porosity times concentration [mol.m-3])))'], domains={}),
#  'Electrolyte potential [V]': ConcatenationVariable(0x542bf273136be8d, Electrolyte potential [V], children=['Negative electrolyte potential [V]', 'Separator electrolyte potential [V]', 'Positive electrolyte potential [V]'], domains={'primary': ['negative electrode', 'separator', 'positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged electrolyte potential [V]': XAverage(-0x283787829414f865, x-average, children=['Electrolyte potential [V](Negative electrolyte potential [V], Separator electrolyte potential [V], Positive electrolyte potential [V])'], domains={'primary': ['current collector']}),
#  'X-averaged electrolyte overpotential [V]': Subtraction(-0x64b22cd324b60699, -, children=['x-average(Positive electrolyte potential [V])', 'x-average(Negative electrolyte potential [V])'], domains={'primary': ['current collector']}),
#  'Gradient of electrolyte potential [V.m-1]': Gradient(-0x453c46b457acbbb6, grad, children=['Electrolyte potential [V](Negative electrolyte potential [V], Separator electrolyte potential [V], Positive electrolyte potential [V])'], domains={'primary': ['negative electrode', 'separator', 'positive electrode'], 'secondary': ['current collector']}),
#  'Negative electrolyte potential [V]': Variable(-0x40144109da2eb18f, Negative electrolyte potential [V], children=[], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrolyte potential [V]': XAverage(-0x22df07ab148d3cb6, x-average, children=['Negative electrolyte potential [V]'], domains={'primary': ['current collector']}),
#  'Gradient of negative electrolyte potential [V.m-1]': Gradient(0xe9f406d550f092e, grad, children=['Negative electrolyte potential [V]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Separator electrolyte potential [V]': Variable(0x44e8bc1116c6dcd6, Separator electrolyte potential [V], children=[], domains={'primary': ['separator'], 'secondary': ['current collector']}),
#  'X-averaged separator electrolyte potential [V]': XAverage(-0x5b7053f0395835b2, x-average, children=['Separator electrolyte potential [V]'], domains={'primary': ['current collector']}),
#  'Gradient of separator electrolyte potential [V.m-1]': Gradient(0x226b2fa4188da8de, grad, children=['Separator electrolyte potential [V]'], domains={'primary': ['separator'], 'secondary': ['current collector']}),
#  'Positive electrolyte potential [V]': Variable(0x746f303a91571ecb, Positive electrolyte potential [V], children=[], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrolyte potential [V]': XAverage(0x65fa4a8ecee7fab4, x-average, children=['Positive electrolyte potential [V]'], domains={'primary': ['current collector']}),
#  'Gradient of positive electrolyte potential [V.m-1]': Gradient(-0x7242c537515f3320, grad, children=['Positive electrolyte potential [V]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Ambient temperature [K]': FunctionParameter(-0x65a9efaee7e22be2, Ambient temperature [K], children=['y', 'z', 'time'], domains={'primary': ['current collector']}),
#  'Volume-averaged ambient temperature [K]': ZAverage(0x11779336177e9610, z-average, children=['Ambient temperature [K]'], domains={}),
#  'Cell temperature [K]': PrimaryBroadcast(0x5bdcf06e24be1caa, broadcast, children=['broadcast(Volume-averaged cell temperature [K])'], domains={'primary': ['negative electrode', 'separator', 'positive electrode'], 'secondary': ['current collector']}),
#  'Negative current collector temperature [K]': PrimaryBroadcast(-0x7dbb87f13b80f0da, broadcast, children=['Volume-averaged cell temperature [K]'], domains={'primary': ['current collector']}),
#  'Positive current collector temperature [K]': PrimaryBroadcast(-0x7dbb87f13b80f0da, broadcast, children=['Volume-averaged cell temperature [K]'], domains={'primary': ['current collector']}),
#  'X-averaged cell temperature [K]': PrimaryBroadcast(-0x7dbb87f13b80f0da, broadcast, children=['Volume-averaged cell temperature [K]'], domains={'primary': ['current collector']}),
#  'Volume-averaged cell temperature [K]': Variable(0x6416d9c439999f11, Volume-averaged cell temperature [K], children=[], domains={}),
#  'Negative electrode temperature [K]': PrimaryBroadcast(-0x2a0b56975fe01447, broadcast, children=['broadcast(Volume-averaged cell temperature [K])'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrode temperature [K]': PrimaryBroadcast(-0x7dbb87f13b80f0da, broadcast, children=['Volume-averaged cell temperature [K]'], domains={'primary': ['current collector']}),
#  'Separator temperature [K]': PrimaryBroadcast(-0x5fbc97a842896fc8, broadcast, children=['broadcast(Volume-averaged cell temperature [K])'], domains={'primary': ['separator'], 'secondary': ['current collector']}),
#  'X-averaged separator temperature [K]': PrimaryBroadcast(-0x7dbb87f13b80f0da, broadcast, children=['Volume-averaged cell temperature [K]'], domains={'primary': ['current collector']}),
#  'Positive electrode temperature [K]': PrimaryBroadcast(0x277394de59fbbf2c, broadcast, children=['broadcast(Volume-averaged cell temperature [K])'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrode temperature [K]': PrimaryBroadcast(-0x7dbb87f13b80f0da, broadcast, children=['Volume-averaged cell temperature [K]'], domains={'primary': ['current collector']}),
#  'Ambient temperature [C]': Addition(0x3f8893cd8bee3280, +, children=['-273.15', 'Ambient temperature [K]'], domains={'primary': ['current collector']}),
#  'Volume-averaged ambient temperature [C]': Addition(-0x4d26303a0568f276, +, children=['-273.15', 'z-average(Ambient temperature [K])'], domains={}),
#  'Cell temperature [C]': PrimaryBroadcast(0x435fcdd08952d6bb, broadcast, children=['broadcast(-273.15 + Volume-averaged cell temperature [K])'], domains={'primary': ['negative electrode', 'separator', 'positive electrode'], 'secondary': ['current collector']}),
#  'Negative current collector temperature [C]': PrimaryBroadcast(0x51bc2cf98b111461, broadcast, children=['-273.15 + Volume-averaged cell temperature [K]'], domains={'primary': ['current collector']}),
#  'Positive current collector temperature [C]': PrimaryBroadcast(0x51bc2cf98b111461, broadcast, children=['-273.15 + Volume-averaged cell temperature [K]'], domains={'primary': ['current collector']}),
#  'X-averaged cell temperature [C]': PrimaryBroadcast(0x51bc2cf98b111461, broadcast, children=['-273.15 + Volume-averaged cell temperature [K]'], domains={'primary': ['current collector']}),
#  'Volume-averaged cell temperature [C]': Addition(-0xb9398a78c21255f, +, children=['-273.15', 'Volume-averaged cell temperature [K]'], domains={}),
#  'Negative electrode temperature [C]': PrimaryBroadcast(-0x6152e9c4928886ae, broadcast, children=['broadcast(-273.15 + Volume-averaged cell temperature [K])'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrode temperature [C]': PrimaryBroadcast(0x51bc2cf98b111461, broadcast, children=['-273.15 + Volume-averaged cell temperature [K]'], domains={'primary': ['current collector']}),
#  'Separator temperature [C]': PrimaryBroadcast(0x1a4b7340d4e21ab8, broadcast, children=['broadcast(-273.15 + Volume-averaged cell temperature [K])'], domains={'primary': ['separator'], 'secondary': ['current collector']}),
#  'X-averaged separator temperature [C]': PrimaryBroadcast(0x51bc2cf98b111461, broadcast, children=['-273.15 + Volume-averaged cell temperature [K]'], domains={'primary': ['current collector']}),
#  'Positive electrode temperature [C]': PrimaryBroadcast(0x51f487ffa167823e, broadcast, children=['broadcast(-273.15 + Volume-averaged cell temperature [K])'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrode temperature [C]': PrimaryBroadcast(0x51bc2cf98b111461, broadcast, children=['-273.15 + Volume-averaged cell temperature [K]'], domains={'primary': ['current collector']}),
#  'Negative current collector potential [V]': PrimaryBroadcast(-0x1e04279eddc09a00, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'Negative inner SEI thickness [m]': Variable(0x55cec7013341d913, Negative inner SEI thickness [m], children=[], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Negative outer SEI thickness [m]': Variable(-0x11ceb00c23372093, Negative outer SEI thickness [m], children=[], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative inner SEI thickness [m]': XAverage(-0x545a65ab75e5af89, x-average, children=['Negative inner SEI thickness [m]'], domains={'primary': ['current collector']}),
#  'X-averaged negative outer SEI thickness [m]': XAverage(-0x1176949414a38ccc, x-average, children=['Negative outer SEI thickness [m]'], domains={'primary': ['current collector']}),
#  'Negative SEI [m]': Addition(-0x40da6c63c8308b8a, +, children=['Negative inner SEI thickness [m]', 'Negative outer SEI thickness [m]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Negative total SEI thickness [m]': Addition(-0x40da6c63c8308b8a, +, children=['Negative inner SEI thickness [m]', 'Negative outer SEI thickness [m]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative SEI thickness [m]': Addition(0x3b77dd3f439068c7, +, children=['x-average(Negative inner SEI thickness [m])', 'x-average(Negative outer SEI thickness [m])'], domains={'primary': ['current collector']}),
#  'X-averaged negative total SEI thickness [m]': Addition(0x3b77dd3f439068c7, +, children=['x-average(Negative inner SEI thickness [m])', 'x-average(Negative outer SEI thickness [m])'], domains={'primary': ['current collector']}),
#  'X-averaged negative electrode resistance [Ohm.m2]': Multiplication(0x51a70713d05629b3, *, children=['x-average(Negative inner SEI thickness [m]) + x-average(Negative outer SEI thickness [m])', 'SEI resistivity [Ohm.m]'], domains={'primary': ['current collector']}),
#  'Positive inner SEI thickness [m]': FullBroadcast(-0x7035f9cbaa83ee38, broadcast, children=['0.0'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Positive outer SEI thickness [m]': FullBroadcast(-0x7035f9cbaa83ee38, broadcast, children=['0.0'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive inner SEI thickness [m]': PrimaryBroadcast(-0x1e04279eddc09a00, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'X-averaged positive outer SEI thickness [m]': PrimaryBroadcast(-0x1e04279eddc09a00, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'Positive SEI [m]': FullBroadcast(-0x7035f9cbaa83ee38, broadcast, children=['0.0'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
# ...
#  'Loss of lithium inventory [%]': Subtraction(-0x6a458a532c7062c6, -, children=['100.0', '100.0 * (yz-average(x-average(Negative electrode active material volume fraction * r-average(Negative particle concentration [mol.m-3]))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] + yz-average(x-average(Positive electrode active material volume fraction * r-average(Positive particle concentration [mol.m-3]))) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m]) / (yz-average(x-average(Negative electrode active material volume fraction * r-average(Initial concentration in negative electrode [mol.m-3]))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] + yz-average(x-average(Positive electrode active material volume fraction * r-average(Initial concentration in positive electrode [mol.m-3]))) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m])'], domains={}),
#  'Loss of lithium inventory, including electrolyte [%]': Subtraction(-0x6633c0b97d8316d2, -, children=['100.0', '100.0 * (yz-average(x-average(Negative electrode active material volume fraction * r-average(Negative particle concentration [mol.m-3]))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] + yz-average(x-average(Positive electrode active material volume fraction * r-average(Positive particle concentration [mol.m-3]))) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m] + (Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]) * Electrode width [m] * Electrode height [m] * yz-average(x-average(Porosity times concentration [mol.m-3](Negative electrode porosity times concentration [mol.m-3], Separator porosity times concentration [mol.m-3], Positive electrode porosity times concentration [mol.m-3])))) / (yz-average(x-average(Negative electrode active material volume fraction * r-average(Initial concentration in negative electrode [mol.m-3]))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] + yz-average(x-average(Positive electrode active material volume fraction * r-average(Initial concentration in positive electrode [mol.m-3]))) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m] + yz-average((Negative electrode thickness [m] * x-average(Negative electrode porosity) + Separator thickness [m] * x-average(Separator porosity) + Positive electrode thickness [m] * x-average(Positive electrode porosity)) / (Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m])) * Initial concentration in electrolyte [mol.m-3] * (Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]) * Electrode width [m] * Electrode height [m])'], domains={}),
#  'Total lithium [mol]': Addition(0x7767cb404bb27664, +, children=['yz-average(x-average(Negative electrode active material volume fraction * r-average(Negative particle concentration [mol.m-3]))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] + yz-average(x-average(Positive electrode active material volume fraction * r-average(Positive particle concentration [mol.m-3]))) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m]', '(Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]) * Electrode width [m] * Electrode height [m] * yz-average(x-average(Porosity times concentration [mol.m-3](Negative electrode porosity times concentration [mol.m-3], Separator porosity times concentration [mol.m-3], Positive electrode porosity times concentration [mol.m-3])))'], domains={}),
#  'Total lithium in particles [mol]': Addition(0x56fd14d22efa9a1e, +, children=['yz-average(x-average(Negative electrode active material volume fraction * r-average(Negative particle concentration [mol.m-3]))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m]', 'yz-average(x-average(Positive electrode active material volume fraction * r-average(Positive particle concentration [mol.m-3]))) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m]'], domains={}),
#  'Total lithium capacity [A.h]': Multiplication(-0x44aa33a196d7485a, *, children=['0.0002777777777777778', '(yz-average(x-average(Negative electrode active material volume fraction * r-average(Negative particle concentration [mol.m-3]))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] + yz-average(x-average(Positive electrode active material volume fraction * r-average(Positive particle concentration [mol.m-3]))) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m] + (Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]) * Electrode width [m] * Electrode height [m] * yz-average(x-average(Porosity times concentration [mol.m-3](Negative electrode porosity times concentration [mol.m-3], Separator porosity times concentration [mol.m-3], Positive electrode porosity times concentration [mol.m-3])))) * Faraday constant [C.mol-1]'], domains={}),
#  'Total lithium capacity in particles [A.h]': Multiplication(-0x559fab4900b70419, *, children=['0.0002777777777777778', '(yz-average(x-average(Negative electrode active material volume fraction * r-average(Negative particle concentration [mol.m-3]))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] + yz-average(x-average(Positive electrode active material volume fraction * r-average(Positive particle concentration [mol.m-3]))) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m]) * Faraday constant [C.mol-1]'], domains={}),
#  'Total lithium lost [mol]': Subtraction(-0x5981d8cb501791b6, -, children=['yz-average(x-average(Negative electrode active material volume fraction * r-average(Initial concentration in negative electrode [mol.m-3]))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] + yz-average(x-average(Positive electrode active material volume fraction * r-average(Initial concentration in positive electrode [mol.m-3]))) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m] + yz-average((Negative electrode thickness [m] * x-average(Negative electrode porosity) + Separator thickness [m] * x-average(Separator porosity) + Positive electrode thickness [m] * x-average(Positive electrode porosity)) / (Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m])) * Initial concentration in electrolyte [mol.m-3] * (Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]) * Electrode width [m] * Electrode height [m]', 'yz-average(x-average(Negative electrode active material volume fraction * r-average(Negative particle concentration [mol.m-3]))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] + yz-average(x-average(Positive electrode active material volume fraction * r-average(Positive particle concentration [mol.m-3]))) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m] + (Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]) * Electrode width [m] * Electrode height [m] * yz-average(x-average(Porosity times concentration [mol.m-3](Negative electrode porosity times concentration [mol.m-3], Separator porosity times concentration [mol.m-3], Positive electrode porosity times concentration [mol.m-3])))'], domains={}),
#  'Total lithium lost from particles [mol]': Subtraction(-0xdd96642c27cd772, -, children=['yz-average(x-average(Negative electrode active material volume fraction * r-average(Initial concentration in negative electrode [mol.m-3]))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] + yz-average(x-average(Positive electrode active material volume fraction * r-average(Initial concentration in positive electrode [mol.m-3]))) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m]', 'yz-average(x-average(Negative electrode active material volume fraction * r-average(Negative particle concentration [mol.m-3]))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] + yz-average(x-average(Positive electrode active material volume fraction * r-average(Positive particle concentration [mol.m-3]))) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m]'], domains={}),
#  'Total lithium lost from electrolyte [mol]': Subtraction(0x527b3cc09e27672d, -, children=['yz-average((Negative electrode thickness [m] * x-average(Negative electrode porosity) + Separator thickness [m] * x-average(Separator porosity) + Positive electrode thickness [m] * x-average(Positive electrode porosity)) / (Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m])) * Initial concentration in electrolyte [mol.m-3] * (Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]) * Electrode width [m] * Electrode height [m]', '(Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]) * Electrode width [m] * Electrode height [m] * yz-average(x-average(Porosity times concentration [mol.m-3](Negative electrode porosity times concentration [mol.m-3], Separator porosity times concentration [mol.m-3], Positive electrode porosity times concentration [mol.m-3])))'], domains={}),
#  'Total lithium lost to side reactions [mol]': Addition(-0x688323255bddbc25, +, children=['Ratio of lithium moles to SEI moles * (yz-average(x-average(Negative inner SEI thickness [m] * 3.0 * Negative electrode active material volume fraction / Negative particle radius [m] / Inner SEI partial molar volume [m3.mol-1])) + yz-average(x-average(Negative outer SEI thickness [m] * 3.0 * Negative electrode active material volume fraction / Negative particle radius [m] / Outer SEI partial molar volume [m3.mol-1])) - (Initial inner SEI thickness [m] * 3.0 * yz-average(x-average(Negative electrode active material volume fraction)) / Negative particle radius [m] / Inner SEI partial molar volume [m3.mol-1] + Initial outer SEI thickness [m] * 3.0 * yz-average(x-average(Negative electrode active material volume fraction)) / Negative particle radius [m] / Outer SEI partial molar volume [m3.mol-1])) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m]', 'Ratio of lithium moles to SEI moles * (yz-average(x-average(Negative inner SEI on cracks thickness [m] * 3.0 * Negative electrode active material volume fraction / Negative particle radius [m] / Inner SEI partial molar volume [m3.mol-1] * 2.0 * Negative particle crack length [m] * Negative electrode number of cracks per unit area [m-2] * Negative electrode initial crack width [m])) + yz-average(x-average(Negative outer SEI on cracks thickness [m] * 3.0 * Negative electrode active material volume fraction / Negative particle radius [m] / Outer SEI partial molar volume [m3.mol-1] * 2.0 * Negative particle crack length [m] * Negative electrode number of cracks per unit area [m-2] * Negative electrode initial crack width [m])) - ((Initial inner SEI on cracks thickness [m] * 3.0 * yz-average(x-average(Negative electrode active material volume fraction)) / Negative particle radius [m] / Inner SEI partial molar volume [m3.mol-1] + Initial outer SEI on cracks thickness [m] * 3.0 * yz-average(x-average(Negative electrode active material volume fraction)) / Negative particle radius [m] / Outer SEI partial molar volume [m3.mol-1]) * yz-average(x-average(2.0 * Negative particle crack length [m] * Negative electrode number of cracks per unit area [m-2] * Negative electrode initial crack width [m])))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] + x-average(Negative lithium plating concentration [mol.m-3]) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] + x-average(Negative dead lithium concentration [mol.m-3]) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m]'], domains={'primary': ['current collector']}),
#  'Total capacity lost to side reactions [A.h]': Multiplication(-0x18214f083177764, *, children=['0.0002777777777777778', '(Ratio of lithium moles to SEI moles * (yz-average(x-average(Negative inner SEI thickness [m] * 3.0 * Negative electrode active material volume fraction / Negative particle radius [m] / Inner SEI partial molar volume [m3.mol-1])) + yz-average(x-average(Negative outer SEI thickness [m] * 3.0 * Negative electrode active material volume fraction / Negative particle radius [m] / Outer SEI partial molar volume [m3.mol-1])) - (Initial inner SEI thickness [m] * 3.0 * yz-average(x-average(Negative electrode active material volume fraction)) / Negative particle radius [m] / Inner SEI partial molar volume [m3.mol-1] + Initial outer SEI thickness [m] * 3.0 * yz-average(x-average(Negative electrode active material volume fraction)) / Negative particle radius [m] / Outer SEI partial molar volume [m3.mol-1])) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] + Ratio of lithium moles to SEI moles * (yz-average(x-average(Negative inner SEI on cracks thickness [m] * 3.0 * Negative electrode active material volume fraction / Negative particle radius [m] / Inner SEI partial molar volume [m3.mol-1] * 2.0 * Negative particle crack length [m] * Negative electrode number of cracks per unit area [m-2] * Negative electrode initial crack width [m])) + yz-average(x-average(Negative outer SEI on cracks thickness [m] * 3.0 * Negative electrode active material volume fraction / Negative particle radius [m] / Outer SEI partial molar volume [m3.mol-1] * 2.0 * Negative particle crack length [m] * Negative electrode number of cracks per unit area [m-2] * Negative electrode initial crack width [m])) - ((Initial inner SEI on cracks thickness [m] * 3.0 * yz-average(x-average(Negative electrode active material volume fraction)) / Negative particle radius [m] / Inner SEI partial molar volume [m3.mol-1] + Initial outer SEI on cracks thickness [m] * 3.0 * yz-average(x-average(Negative electrode active material volume fraction)) / Negative particle radius [m] / Outer SEI partial molar volume [m3.mol-1]) * yz-average(x-average(2.0 * Negative particle crack length [m] * Negative electrode number of cracks per unit area [m-2] * Negative electrode initial crack width [m])))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] + x-average(Negative lithium plating concentration [mol.m-3]) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] + x-average(Negative dead lithium concentration [mol.m-3]) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m]) * Faraday constant [C.mol-1]'], domains={'primary': ['current collector']})}

# %%
cycles_df
# Out:
#              Mode  RelativeTime   Voltage          I        Q_dis     Q_cha  \
# Cycle Step
# 1     1       1.0  0.000000e+00  2.680430  1407.8055     0.000000  0.000078
#       2       1.0  8.400000e-03  2.690530  1574.4427     0.000000  0.003691
#       3       1.0  2.940000e-02  2.700598  1640.2499     0.000000  0.013108
#       4       1.0  6.340000e-02  2.710643  1664.4644     0.000000  0.028749
#       5       1.0  1.074000e-01  2.720645  1668.5892     0.000000  0.049123
# ...           ...           ...       ...        ...          ...       ...
# 105   14017   1.0  1.510170e+06  2.517027 -4997.5547  4461.105642  0.000000
#       14018   1.0  1.510171e+06  2.510488 -4997.8223  4462.493874  0.000000
#       14019   1.0  1.510172e+06  2.503801 -4997.8223  4463.882105  0.000000
#       14020   1.0  1.510173e+06  2.499954 -4997.1729  4464.662006  0.000000
#       14021   1.0  1.510173e+06  2.499981 -4997.4785  4464.662284  0.000000
#
#                      Cap         R    Pressure  Temperature
# Cycle Step
# 1     1         0.000078  1.903978  159.026607      25.3794
#       2         0.003691  1.708878  158.944819      25.3885
#       3         0.013108  1.646455  158.998347      25.4014
#       4         0.028749  1.628537  159.049016      25.4088
#       5         0.049123  1.630506  158.990980      25.4014
# ...                  ...       ...         ...          ...
# 105   14017  4461.105642  0.503652  278.040252      30.8711
#       14018  4462.493874  0.502316  277.965417      30.8656
#       14019  4463.882105  0.500978  277.965771      30.8428
#       14020  4464.662006  0.500274  277.854785      30.8390
#       14021  4464.662284  0.500248  277.859008      30.8190
#
# [1512250 rows x 10 columns]

# %%
# Compare model data to experiment

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(13, 4))

# plot the 1C results
t_sol = sol["Time [s]"].entries


ax1.plot(t_sol, sol["Current variable [A]"](t_sol))
ax1.plot(cycles_df.loc[1]["RelativeTime"],cycles_df.loc[1]["I"]/1000, "o")
ax1.set_xlabel("Time [s]")
ax1.set_ylabel("Voltage [V]")
ax1.set_title("Voltage")
ax1.legend(["Model", "Experiment"], loc="best")


ax2.plot(t_sol, sol["X-averaged cell temperature [C]"](t_sol))
ax2.plot(cycles_df.loc[1]["RelativeTime"],cycles_df.loc[1]["Temperature"], "o")
ax2.set_xlabel("Time [s]")
ax2.set_ylabel("Temperature [degC]")
ax2.set_title("Temperature")
ax2.legend(["Model", "Experiment"], loc="best")

plt.tight_layout()
plt.show()

# %% [markdown]
# 下面是处理源数据的方法

# %%
# 读取 CSV 文件
# cwd = os.getcwd()
# csv_file_path = cwd + '/docs/source/examples/notebooks/models/exp_LG/allData_C7_removefront.csv'
# Cell_7 = pd.read_csv(csv_file_path)

# %%
# Cell_7['RelativeTime'] = Cell_7['RelativeTime'] - Cell_7['RelativeTime'][0]

# %%
# # 定义存储循环的列表
# cycles = []
# current_cycle = []
# charging = False

# # 遍历 DataFrame，识别循环
# for i, row in Cell_7.iterrows():
#     if row['Q_cha'] > 0 and not charging:
#         # 开始充电
#         charging = True
#         if current_cycle:
#             cycles.append(current_cycle)
#         current_cycle = [row]
#     elif row['Q_dis'] > 0 and charging:
#         # 结束充电，开始放电
#         charging = False
#         current_cycle.append(row)
#     else:
#         # 在当前循环中添加行
#         current_cycle.append(row)

# # 添加最后一个循环
# if current_cycle:
#     cycles.append(current_cycle)

# # 将循环数据转换为带有 MultiIndex 的 DataFrame
# cycle_data = []
# for cycle_num, cycle in enumerate(cycles):
#     for step_num, row in enumerate(cycle):
#         cycle_data.append((cycle_num + 1, step_num + 1, *row.values))

# # 定义多重索引
# multi_index = pd.MultiIndex.from_tuples(
#     [(cycle, step) for cycle, step, *rest in cycle_data],
#     names=['Cycle', 'Step']
# )

# # 定义 DataFrame 列名
# columns = ['Mode', 'RelativeTime', 'Voltage', 'I', 'Q_dis', 'Q_cha', 'Cap', 'R', 'Pressure', 'Temperature']

# # 创建最终的 DataFrame
# cycles_df = pd.DataFrame([rest for cycle, step, *rest in cycle_data], index=multi_index, columns=columns)

# # 打印前几行以验证
# print(cycles_df.head())

# # 示例：访问第一个循环的数据
# cycle_1_data = cycles_df.loc[1]
# print("\nCycle 1 Data:")
# print(cycle_1_data)

# # 示例：访问第一个循环的第一步数据
# cycle_1_step_1_data = cycles_df.loc[(1, 1)]
# print("\nCycle 1 Step 1 Data:")
# print(cycle_1_step_1_data)

# %%
# 将 DataFrame 存储为 pickle 文件
# pickle_file_path = cwd + '/docs/source/examples/notebooks/models/exp_LG/processed_data.pkl'
# cycles_df.to_pickle(pickle_file_path)
# print(f"DataFrame saved to {pickle_file_path}")
