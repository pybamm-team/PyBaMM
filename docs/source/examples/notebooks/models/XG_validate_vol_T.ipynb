# %% [markdown]
# To validate battery base model for LG M50, Use revised OKane2022 parameters with parameters used in Paper 1,2
# 1. To validate BoL voltage and thermal response

# %%
import pybamm
import matplotlib.pyplot as plt
import numpy as np


model = pybamm.lithium_ion.DFN(
    {
        #"particle phases": ("2", "1"),
        #"open-circuit potential": (("single", "current sigmoid"), "single"),
        
        "SEI": "solvent-diffusion limited",
        "SEI porosity change": "true",
        "lithium plating": "partially reversible",
        "lithium plating porosity change": "true",  # alias for "SEI porosity change"
        "particle mechanics": ("swelling and cracking", "swelling only"),
        "SEI on cracks": "true",
        "loss of active material": "stress-driven",
        "calculate discharge energy": "true",  # for compatibility with older PyBaMM versions

        "thermal": "lumped", 
    }
)

param = pybamm.ParameterValues("OKane2022_posmolar_0703")
var_pts = {
    "x_n": 10,  # negative electrode
    "x_s": 10,  # separator
    "x_p": 10,  # positive electrode
    "r_n": 30,  # negative particle
    "r_p": 30,  # positive particle
}

cycle_number = 1
exp = pybamm.Experiment(
    # [
    #     "Hold at 4.2 V until C/100 (5 minute period)",
    #     "Rest for 4 hours (5 minute period)",
    #     "Discharge at 0.1C until 2.5 V (5 minute period)",  # initial capacity check
    #     "Charge at 1C until 4.2 V (5 minute period)",
    #     "Hold at 4.2 V until C/100 (5 minute period)",
    # ]
    # + 
    [
        (
            "Charge at 0.3C until 4.2 V",
            "Hold at 4.2 V until C/20",
            "Discharge at 1C until 2.5 V",  # ageing cycles
            #"Discharge at 1C until 2.5 V"

        )
    ]
    * cycle_number
    #+ ["Discharge at 0.1C until 2.5 V (5 minute period)"],  # final capacity check
)

# exp = pybamm.Experiment(
#     [
#         "Hold at 4.2 V until C/100 (5 minute period)",
#         "Discharge at 0.1C until 2.5 V (5 minute period)",  # initial capacity check
#         "Charge at 0.1C until 4.2 V (5 minute period)",
#         "Hold at 4.2 V until C/100 (5 minute period)",
#     ]
# )


sim = pybamm.Simulation(model, parameter_values=param, experiment=exp, var_pts=var_pts )
#sim_thermal = pybamm.Simulation(model_thermal, parameter_values=param, experiment=exp, var_pts=var_pts)
sol = sim.solve(initial_soc=0)
#sol = sim.solve()

# %%
model_nodeg = pybamm.lithium_ion.DFN(
    {
        #"particle phases": ("2", "1"),
        #"open-circuit potential": (("single", "current sigmoid"), "single"),
        
        # "SEI": "solvent-diffusion limited",
        # "SEI porosity change": "true",
        # "lithium plating": "partially reversible",
        # "lithium plating porosity change": "true",  # alias for "SEI porosity change"
        # "particle mechanics": ("swelling and cracking", "swelling only"),
        # "SEI on cracks": "true",
        # "loss of active material": "stress-driven",
        # "calculate discharge energy": "true",  # for compatibility with older PyBaMM versions

        "thermal": "lumped", 
    }
)

param = pybamm.ParameterValues("OKane2022_posmolar_0703")
var_pts = {
    "x_n": 10,  # negative electrode
    "x_s": 10,  # separator
    "x_p": 10,  # positive electrode
    "r_n": 30,  # negative particle
    "r_p": 30,  # positive particle
}

cycle_number = 1
exp = pybamm.Experiment(
    # [
    #     "Hold at 4.2 V until C/100 (5 minute period)",
    #     "Rest for 4 hours (5 minute period)",
    #     "Discharge at 0.1C until 2.5 V (5 minute period)",  # initial capacity check
    #     "Charge at 1C until 4.2 V (5 minute period)",
    #     "Hold at 4.2 V until C/100 (5 minute period)",
    # ]
    # + 
    [
        (
            "Charge at 0.3C until 4.2 V",
            "Hold at 4.2 V until C/20",
            "Discharge at 1C until 2.5 V",  # ageing cycles
            #"Discharge at 1C until 2.5 V"

        )
    ]
    * cycle_number
    #+ ["Discharge at 0.1C until 2.5 V (5 minute period)"],  # final capacity check
)

# exp = pybamm.Experiment(
#     [
#         "Hold at 4.2 V until C/100 (5 minute period)",
#         "Discharge at 0.1C until 2.5 V (5 minute period)",  # initial capacity check
#         "Charge at 0.1C until 4.2 V (5 minute period)",
#         "Hold at 4.2 V until C/100 (5 minute period)",
#     ]
# )


sim_nodeg = pybamm.Simulation(model_nodeg, parameter_values=param, experiment=exp, var_pts=var_pts )
#sim_thermal = pybamm.Simulation(model_thermal, parameter_values=param, experiment=exp, var_pts=var_pts)
sol_nodeg = sim_nodeg.solve(initial_soc=0)
#sol = sim.solve()

# %%
model.variables
# Out:
# {'Time [s]': Time(-0x200d97ea54ed6be3, time, children=[], domains={}),
#  'Time [min]': Multiplication(0x10422a3f66b0d2d4, *, children=['0.016666666666666666', 'time'], domains={}),
#  'Time [h]': Multiplication(0xa1f0d95ced7cade, *, children=['0.0002777777777777778', 'time'], domains={}),
#  'x [m]': SpatialVariable(-0x2a9b6bd3ee0dfb0, x, children=[], domains={'primary': ['negative electrode', 'separator', 'positive electrode'], 'secondary': ['current collector']}),
#  'x_n [m]': SpatialVariable(0x4881a48bf8a8d7e1, x_n, children=[], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'x_s [m]': SpatialVariable(-0x7ef61b12b13057ea, x_s, children=[], domains={'primary': ['separator'], 'secondary': ['current collector']}),
#  'x_p [m]': SpatialVariable(-0x568f1bb8000c13ce, x_p, children=[], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'r_n [m]': SpatialVariable(-0x550f81106c51cb77, r_n, children=[], domains={'primary': ['negative particle'], 'secondary': ['negative electrode'], 'tertiary': ['current collector']}),
#  'r_p [m]': SpatialVariable(-0x6d82a910c3c849b6, r_p, children=[], domains={'primary': ['positive particle'], 'secondary': ['positive electrode'], 'tertiary': ['current collector']}),
#  'Current variable [A]': FunctionParameter(-0x6a64630a9ff8c812, Current function [A], children=['time'], domains={}),
#  'Total current density [A.m-2]': Division(0x31d3e6cd92c8f32b, /, children=['Current function [A]', 'Number of electrodes connected in parallel to make a cell * Electrode width [m] * Electrode height [m]'], domains={}),
#  'Current [A]': FunctionParameter(-0x6a64630a9ff8c812, Current function [A], children=['time'], domains={}),
#  'C-rate': Division(-0x4bdd3daa4a5db666, /, children=['Current function [A]', 'Nominal cell capacity [A.h]'], domains={}),
#  'Discharge capacity [A.h]': Variable(0x7b57943bc0c2d3e3, Discharge capacity [A.h], children=[], domains={}),
#  'Throughput capacity [A.h]': Variable(0x5450dfd855bc050, Throughput capacity [A.h], children=[], domains={}),
#  'Discharge energy [W.h]': Variable(0x3b39b9f6f8fd616b, Discharge energy [W.h], children=[], domains={}),
#  'Throughput energy [W.h]': Variable(0x43a880d1f7b9a84f, Throughput energy [W.h], children=[], domains={}),
#  'Negative electrode interface utilisation variable': FullBroadcast(0x429b4c8e25ec8092, broadcast, children=['1.0'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrode interface utilisation variable': PrimaryBroadcast(0x4381b98637762658, broadcast, children=['1.0'], domains={'primary': ['current collector']}),
#  'Negative electrode interface utilisation': FullBroadcast(0x429b4c8e25ec8092, broadcast, children=['1.0'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrode interface utilisation': PrimaryBroadcast(0x4381b98637762658, broadcast, children=['1.0'], domains={'primary': ['current collector']}),
#  'Positive electrode interface utilisation variable': FullBroadcast(-0x7c4bc5d21c6ea961, broadcast, children=['1.0'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrode interface utilisation variable': PrimaryBroadcast(0x4381b98637762658, broadcast, children=['1.0'], domains={'primary': ['current collector']}),
#  'Positive electrode interface utilisation': FullBroadcast(-0x7c4bc5d21c6ea961, broadcast, children=['1.0'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrode interface utilisation': PrimaryBroadcast(0x4381b98637762658, broadcast, children=['1.0'], domains={'primary': ['current collector']}),
#  'Negative particle crack length [m]': Variable(0x40a61395bb559250, Negative particle crack length [m], children=[], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative particle crack length [m]': XAverage(-0x66cacf5760af42f3, x-average, children=['Negative particle crack length [m]'], domains={'primary': ['current collector']}),
#  'Positive particle crack length [m]': FullBroadcast(-0x5d8f24b06e2cb9b6, broadcast, children=['0.0'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive particle crack length [m]': PrimaryBroadcast(0x5311a8eb06f4e2f6, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'Positive particle cracking rate [m.s-1]': FullBroadcast(-0x5d8f24b06e2cb9b6, broadcast, children=['0.0'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive particle cracking rate [m.s-1]': PrimaryBroadcast(0x5311a8eb06f4e2f6, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'Negative electrode active material volume fraction': Variable(0x2d8a2387061e68a7, Negative electrode active material volume fraction, children=[], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrode active material volume fraction': XAverage(-0x4335e8faa3b9e482, x-average, children=['Negative electrode active material volume fraction'], domains={'primary': ['current collector']}),
#  'Negative electrode capacity [A.h]': Multiplication(-0x19bf0467086b7ce1, *, children=['0.0002777777777777778', 'yz-average(x-average(Negative electrode active material volume fraction)) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] * Maximum concentration in negative electrode [mol.m-3] * Faraday constant [C.mol-1]'], domains={}),
#  'Negative particle radius': Division(0x11eed7e61feb83ab, /, children=['Negative particle radius [m]', 'Negative particle radius [m]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Negative particle radius [m]': FunctionParameter(0x6b3a70a57177bbfe, Negative particle radius [m], children=['x_n'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative particle radius [m]': XAverage(-0x1d7b3318ed477af4, x-average, children=['Negative particle radius [m]'], domains={'primary': ['current collector']}),
#  'Negative electrode surface area to volume ratio [m-1]': Division(0x70db9dfba6642ff1, /, children=['3.0 * Negative electrode active material volume fraction', 'Negative particle radius [m]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrode surface area to volume ratio [m-1]': XAverage(-0x7257f14d3062c262, x-average, children=['3.0 * Negative electrode active material volume fraction / Negative particle radius [m]'], domains={'primary': ['current collector']}),
#  'Loss of lithium due to loss of active material in negative electrode [mol]': Variable(0x5c473f98638a2093, Loss of lithium due to loss of active material in negative electrode [mol], children=[], domains={}),
#  'Positive electrode active material volume fraction': Variable(-0x38b9aac182543009, Positive electrode active material volume fraction, children=[], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrode active material volume fraction': XAverage(-0x37a7bd2c8832c762, x-average, children=['Positive electrode active material volume fraction'], domains={'primary': ['current collector']}),
#  'Positive electrode capacity [A.h]': Multiplication(0xce5e1b422de7f3f, *, children=['0.0002777777777777778', 'yz-average(x-average(Positive electrode active material volume fraction)) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m] * Maximum concentration in positive electrode [mol.m-3] * Faraday constant [C.mol-1]'], domains={}),
#  'Positive particle radius': Division(-0x296bb90653e4970f, /, children=['Positive particle radius [m]', 'Positive particle radius [m]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Positive particle radius [m]': FunctionParameter(-0x6966102c80b57848, Positive particle radius [m], children=['x_p'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive particle radius [m]': XAverage(-0x15bc5a67a2bfde65, x-average, children=['Positive particle radius [m]'], domains={'primary': ['current collector']}),
#  'Positive electrode surface area to volume ratio [m-1]': Division(0x20dc088dc2c9877a, /, children=['3.0 * Positive electrode active material volume fraction', 'Positive particle radius [m]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrode surface area to volume ratio [m-1]': XAverage(-0x683ba3bc27e4dc3, x-average, children=['3.0 * Positive electrode active material volume fraction / Positive particle radius [m]'], domains={'primary': ['current collector']}),
#  'Loss of lithium due to loss of active material in positive electrode [mol]': Variable(0x790e4940632ff2c8, Loss of lithium due to loss of active material in positive electrode [mol], children=[], domains={}),
#  'Separator pressure [Pa]': PrimaryBroadcast(0x5655a9ee5c40df5c, broadcast, children=['broadcast(0.0)'], domains={'primary': ['separator'], 'secondary': ['current collector']}),
#  'X-averaged separator pressure [Pa]': PrimaryBroadcast(0x5311a8eb06f4e2f6, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'negative electrode transverse volume-averaged velocity [m.s-1]': PrimaryBroadcast(-0x28e1de97b411ccc7, broadcast, children=['broadcast(0.0)'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrode transverse volume-averaged velocity [m.s-1]': PrimaryBroadcast(0x5311a8eb06f4e2f6, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'separator transverse volume-averaged velocity [m.s-1]': PrimaryBroadcast(0x5655a9ee5c40df5c, broadcast, children=['broadcast(0.0)'], domains={'primary': ['separator'], 'secondary': ['current collector']}),
#  'X-averaged separator transverse volume-averaged velocity [m.s-1]': PrimaryBroadcast(0x5311a8eb06f4e2f6, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'positive electrode transverse volume-averaged velocity [m.s-1]': PrimaryBroadcast(0x5ba11fcb99341d8, broadcast, children=['broadcast(0.0)'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrode transverse volume-averaged velocity [m.s-1]': PrimaryBroadcast(0x5311a8eb06f4e2f6, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'Transverse volume-averaged velocity [m.s-1]': PrimaryBroadcast(0x4d3bfbcecdcb8c7b, broadcast, children=['broadcast(0.0)'], domains={'primary': ['negative electrode', 'separator', 'positive electrode'], 'secondary': ['current collector']}),
#  'negative electrode transverse volume-averaged acceleration [m.s-2]': PrimaryBroadcast(-0x28e1de97b411ccc7, broadcast, children=['broadcast(0.0)'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrode transverse volume-averaged acceleration [m.s-2]': PrimaryBroadcast(0x5311a8eb06f4e2f6, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'separator transverse volume-averaged acceleration [m.s-2]': PrimaryBroadcast(0x5655a9ee5c40df5c, broadcast, children=['broadcast(0.0)'], domains={'primary': ['separator'], 'secondary': ['current collector']}),
#  'X-averaged separator transverse volume-averaged acceleration [m.s-2]': PrimaryBroadcast(0x5311a8eb06f4e2f6, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'positive electrode transverse volume-averaged acceleration [m.s-2]': PrimaryBroadcast(0x5ba11fcb99341d8, broadcast, children=['broadcast(0.0)'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrode transverse volume-averaged acceleration [m.s-2]': PrimaryBroadcast(0x5311a8eb06f4e2f6, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'Transverse volume-averaged acceleration [m.s-2]': PrimaryBroadcast(0x4d3bfbcecdcb8c7b, broadcast, children=['broadcast(0.0)'], domains={'primary': ['negative electrode', 'separator', 'positive electrode'], 'secondary': ['current collector']}),
#  'Negative electrode volume-averaged velocity [m.s-1]': FullBroadcast(0x73d4eabb242e37ab, broadcast, children=['0.0'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Negative electrode volume-averaged acceleration [m.s-2]': FullBroadcast(0x73d4eabb242e37ab, broadcast, children=['0.0'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrode volume-averaged acceleration [m.s-2]': PrimaryBroadcast(0x5311a8eb06f4e2f6, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'Negative electrode pressure [Pa]': FullBroadcast(0x73d4eabb242e37ab, broadcast, children=['0.0'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrode pressure [Pa]': PrimaryBroadcast(0x5311a8eb06f4e2f6, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'Positive electrode volume-averaged velocity [m.s-1]': FullBroadcast(-0x5d8f24b06e2cb9b6, broadcast, children=['0.0'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Positive electrode volume-averaged acceleration [m.s-2]': FullBroadcast(-0x5d8f24b06e2cb9b6, broadcast, children=['0.0'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrode volume-averaged acceleration [m.s-2]': PrimaryBroadcast(0x5311a8eb06f4e2f6, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'Positive electrode pressure [Pa]': FullBroadcast(-0x5d8f24b06e2cb9b6, broadcast, children=['0.0'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrode pressure [Pa]': PrimaryBroadcast(0x5311a8eb06f4e2f6, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'Total negative electrode interfacial current density variable [A.m-2]': Variable(0x3512ff7a5c8eb57e, Total negative electrode interfacial current density variable [A.m-2], children=[], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged total negative electrode interfacial current density variable [A.m-2]': XAverage(-0x16ac46b08eaafb39, x-average, children=['Total negative electrode interfacial current density variable [A.m-2]'], domains={'primary': ['current collector']}),
#  'Total positive electrode interfacial current density variable [A.m-2]': Variable(0x3d1f6b34fae34dd, Total positive electrode interfacial current density variable [A.m-2], children=[], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged total positive electrode interfacial current density variable [A.m-2]': XAverage(0x64b197e3f050812f, x-average, children=['Total positive electrode interfacial current density variable [A.m-2]'], domains={'primary': ['current collector']}),
#  'Negative particle concentration [mol.m-3]': Variable(0x2dc77cc36d0cd7d3, Negative particle concentration [mol.m-3], children=[], domains={'primary': ['negative particle'], 'secondary': ['negative electrode'], 'tertiary': ['current collector']}),
#  'X-averaged negative particle concentration [mol.m-3]': XAverage(0x7799f3fbc5dffc76, x-average, children=['Negative particle concentration [mol.m-3]'], domains={'primary': ['negative particle'], 'secondary': ['current collector']}),
#  'R-averaged negative particle concentration [mol.m-3]': RAverage(-0x3fb16deb79cf19c4, r-average, children=['Negative particle concentration [mol.m-3]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Average negative particle concentration [mol.m-3]': RAverage(-0x640ab5283f25a892, r-average, children=['x-average(Negative particle concentration [mol.m-3])'], domains={'primary': ['current collector']}),
#  'Negative particle surface concentration [mol.m-3]': BoundaryValue(-0x7895aa3aa5b1c73, boundary value, children=['Negative particle concentration [mol.m-3]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative particle surface concentration [mol.m-3]': XAverage(-0x35ab445a62b55dd1, x-average, children=['boundary value(Negative particle concentration [mol.m-3])'], domains={'primary': ['current collector']}),
#  'Minimum negative particle concentration [mol.m-3]': Min(-0x4dc1ff905623a52, function (min), children=['Negative particle concentration [mol.m-3]'], domains={'primary': ['negative particle'], 'secondary': ['negative electrode'], 'tertiary': ['current collector']}),
#  'Maximum negative particle concentration [mol.m-3]': Max(-0x743f7feb0f2c250b, function (max), children=['Negative particle concentration [mol.m-3]'], domains={'primary': ['negative particle'], 'secondary': ['negative electrode'], 'tertiary': ['current collector']}),
#  'Minimum negative particle Minimum negative particle surface concentration [mol.m-3]': Min(-0x6962e5cdbac4866b, function (min), children=['boundary value(Negative particle concentration [mol.m-3])'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Maximum negative particle surface concentration [mol.m-3]': Max(0x16ee6ecbc6b50f49, function (max), children=['boundary value(Negative particle concentration [mol.m-3])'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Negative particle concentration': Division(0x75001223e3c850fd, /, children=['Negative particle concentration [mol.m-3]', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative particle'], 'secondary': ['negative electrode'], 'tertiary': ['current collector']}),
#  'X-averaged negative particle concentration': Division(-0x4f35dc704c6852c4, /, children=['x-average(Negative particle concentration [mol.m-3])', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative particle'], 'secondary': ['current collector']}),
#  'R-averaged negative particle concentration': Division(-0x44bbf6e4eeca9b7, /, children=['r-average(Negative particle concentration [mol.m-3])', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Average negative particle concentration': Division(0x178bc122dddee698, /, children=['r-average(x-average(Negative particle concentration [mol.m-3]))', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['current collector']}),
#  'Negative particle surface concentration': Division(-0x69bd91a3fb5070aa, /, children=['boundary value(Negative particle concentration [mol.m-3])', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative particle surface concentration': Division(-0x457745044f8c1317, /, children=['x-average(boundary value(Negative particle concentration [mol.m-3]))', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['current collector']}),
#  'Minimum negative particle concentration': Division(-0xc56fbbd5b7ae3ea, /, children=['min(Negative particle concentration [mol.m-3])', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative particle'], 'secondary': ['negative electrode'], 'tertiary': ['current collector']}),
#  'Maximum negative particle concentration': Division(-0xb1654086bccfdbd, /, children=['max(Negative particle concentration [mol.m-3])', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative particle'], 'secondary': ['negative electrode'], 'tertiary': ['current collector']}),
#  'Minimum negative particle surface concentration': Division(-0x45ffd154a616f63a, /, children=['min(boundary value(Negative particle concentration [mol.m-3]))', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Maximum negative particle surface concentration': Division(0x5c81bd4676dbe051, /, children=['max(boundary value(Negative particle concentration [mol.m-3]))', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Negative particle stoichiometry': Division(0x75001223e3c850fd, /, children=['Negative particle concentration [mol.m-3]', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative particle'], 'secondary': ['negative electrode'], 'tertiary': ['current collector']}),
#  'X-averaged negative particle stoichiometry': Division(-0x4f35dc704c6852c4, /, children=['x-average(Negative particle concentration [mol.m-3])', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative particle'], 'secondary': ['current collector']}),
#  'R-averaged negative particle stoichiometry': Division(-0x44bbf6e4eeca9b7, /, children=['r-average(Negative particle concentration [mol.m-3])', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Average negative particle stoichiometry': Division(0x178bc122dddee698, /, children=['r-average(x-average(Negative particle concentration [mol.m-3]))', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['current collector']}),
#  'Negative particle surface stoichiometry': Division(-0x69bd91a3fb5070aa, /, children=['boundary value(Negative particle concentration [mol.m-3])', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative particle surface stoichiometry': Division(-0x457745044f8c1317, /, children=['x-average(boundary value(Negative particle concentration [mol.m-3]))', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['current collector']}),
#  'Minimum negative particle stoichiometry': Division(-0xc56fbbd5b7ae3ea, /, children=['min(Negative particle concentration [mol.m-3])', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative particle'], 'secondary': ['negative electrode'], 'tertiary': ['current collector']}),
#  'Maximum negative particle stoichiometry': Division(-0xb1654086bccfdbd, /, children=['max(Negative particle concentration [mol.m-3])', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative particle'], 'secondary': ['negative electrode'], 'tertiary': ['current collector']}),
#  'Minimum negative particle surface stoichiometry': Division(-0x45ffd154a616f63a, /, children=['min(boundary value(Negative particle concentration [mol.m-3]))', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Maximum negative particle surface stoichiometry': Division(0x5c81bd4676dbe051, /, children=['max(boundary value(Negative particle concentration [mol.m-3]))', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Negative electrode extent of lithiation': Division(-0x44bbf6e4eeca9b7, /, children=['r-average(Negative particle concentration [mol.m-3])', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrode extent of lithiation': Division(0x178bc122dddee698, /, children=['r-average(x-average(Negative particle concentration [mol.m-3]))', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['current collector']}),
#  'Positive particle concentration [mol.m-3]': Variable(-0x26f40dc7782bf9d4, Positive particle concentration [mol.m-3], children=[], domains={'primary': ['positive particle'], 'secondary': ['positive electrode'], 'tertiary': ['current collector']}),
#  'X-averaged positive particle concentration [mol.m-3]': XAverage(0x6e89debf27a25843, x-average, children=['Positive particle concentration [mol.m-3]'], domains={'primary': ['positive particle'], 'secondary': ['current collector']}),
#  'R-averaged positive particle concentration [mol.m-3]': RAverage(0x72d950f9bc901839, r-average, children=['Positive particle concentration [mol.m-3]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Average positive particle concentration [mol.m-3]': RAverage(0x7b69dde1cee9d7db, r-average, children=['x-average(Positive particle concentration [mol.m-3])'], domains={'primary': ['current collector']}),
#  'Positive particle surface concentration [mol.m-3]': BoundaryValue(0x61bbc77097a9d860, boundary value, children=['Positive particle concentration [mol.m-3]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive particle surface concentration [mol.m-3]': XAverage(0xc1ca1347f643ae0, x-average, children=['boundary value(Positive particle concentration [mol.m-3])'], domains={'primary': ['current collector']}),
#  'Minimum positive particle concentration [mol.m-3]': Min(0x18fc17a13c54f45c, function (min), children=['Positive particle concentration [mol.m-3]'], domains={'primary': ['positive particle'], 'secondary': ['positive electrode'], 'tertiary': ['current collector']}),
#  'Maximum positive particle concentration [mol.m-3]': Max(0x4d31f26143f7d51e, function (max), children=['Positive particle concentration [mol.m-3]'], domains={'primary': ['positive particle'], 'secondary': ['positive electrode'], 'tertiary': ['current collector']}),
#  'Minimum positive particle Minimum positive particle surface concentration [mol.m-3]': Min(0xbc35be325250c0d, function (min), children=['boundary value(Positive particle concentration [mol.m-3])'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Maximum positive particle surface concentration [mol.m-3]': Max(0x4f0a95c0269ea1c1, function (max), children=['boundary value(Positive particle concentration [mol.m-3])'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Positive particle concentration': Division(0x6668ef0e7fac9b94, /, children=['Positive particle concentration [mol.m-3]', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive particle'], 'secondary': ['positive electrode'], 'tertiary': ['current collector']}),
#  'X-averaged positive particle concentration': Division(-0x7cde42bc4e8d6ddf, /, children=['x-average(Positive particle concentration [mol.m-3])', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive particle'], 'secondary': ['current collector']}),
#  'R-averaged positive particle concentration': Division(-0x75b5b85e4e3c33d4, /, children=['r-average(Positive particle concentration [mol.m-3])', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Average positive particle concentration': Division(-0x1eae593eb278ed39, /, children=['r-average(x-average(Positive particle concentration [mol.m-3]))', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['current collector']}),
#  'Positive particle surface concentration': Division(-0x64967882389f1b61, /, children=['boundary value(Positive particle concentration [mol.m-3])', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive particle surface concentration': Division(-0x7a8b1a8695bf0a3b, /, children=['x-average(boundary value(Positive particle concentration [mol.m-3]))', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['current collector']}),
#  'Minimum positive particle concentration': Division(-0x7cb2a52846d28906, /, children=['min(Positive particle concentration [mol.m-3])', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive particle'], 'secondary': ['positive electrode'], 'tertiary': ['current collector']}),
#  'Maximum positive particle concentration': Division(0x3d751ce99200a9a0, /, children=['max(Positive particle concentration [mol.m-3])', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive particle'], 'secondary': ['positive electrode'], 'tertiary': ['current collector']}),
#  'Minimum positive particle surface concentration': Division(0x5e39ddb73836abd, /, children=['min(boundary value(Positive particle concentration [mol.m-3]))', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Maximum positive particle surface concentration': Division(-0x165743164f47b761, /, children=['max(boundary value(Positive particle concentration [mol.m-3]))', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Positive particle stoichiometry': Division(0x6668ef0e7fac9b94, /, children=['Positive particle concentration [mol.m-3]', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive particle'], 'secondary': ['positive electrode'], 'tertiary': ['current collector']}),
#  'X-averaged positive particle stoichiometry': Division(-0x7cde42bc4e8d6ddf, /, children=['x-average(Positive particle concentration [mol.m-3])', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive particle'], 'secondary': ['current collector']}),
#  'R-averaged positive particle stoichiometry': Division(-0x75b5b85e4e3c33d4, /, children=['r-average(Positive particle concentration [mol.m-3])', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Average positive particle stoichiometry': Division(-0x1eae593eb278ed39, /, children=['r-average(x-average(Positive particle concentration [mol.m-3]))', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['current collector']}),
#  'Positive particle surface stoichiometry': Division(-0x64967882389f1b61, /, children=['boundary value(Positive particle concentration [mol.m-3])', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive particle surface stoichiometry': Division(-0x7a8b1a8695bf0a3b, /, children=['x-average(boundary value(Positive particle concentration [mol.m-3]))', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['current collector']}),
#  'Minimum positive particle stoichiometry': Division(-0x7cb2a52846d28906, /, children=['min(Positive particle concentration [mol.m-3])', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive particle'], 'secondary': ['positive electrode'], 'tertiary': ['current collector']}),
#  'Maximum positive particle stoichiometry': Division(0x3d751ce99200a9a0, /, children=['max(Positive particle concentration [mol.m-3])', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive particle'], 'secondary': ['positive electrode'], 'tertiary': ['current collector']}),
#  'Minimum positive particle surface stoichiometry': Division(0x5e39ddb73836abd, /, children=['min(boundary value(Positive particle concentration [mol.m-3]))', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Maximum positive particle surface stoichiometry': Division(-0x165743164f47b761, /, children=['max(boundary value(Positive particle concentration [mol.m-3]))', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Positive electrode extent of lithiation': Division(-0x75b5b85e4e3c33d4, /, children=['r-average(Positive particle concentration [mol.m-3])', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrode extent of lithiation': Division(-0x1eae593eb278ed39, /, children=['r-average(x-average(Positive particle concentration [mol.m-3]))', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['current collector']}),
#  'Negative electrode potential [V]': Variable(-0x2be3e2173e37a16f, Negative electrode potential [V], children=[], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrode potential [V]': XAverage(0x9d123648b428dae, x-average, children=['Negative electrode potential [V]'], domains={'primary': ['current collector']}),
#  'Negative electrode ohmic losses [V]': Subtraction(-0x6ddc9fb34f787c56, -, children=['broadcast(boundary value(Negative electrode potential [V]))', 'Negative electrode potential [V]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrode ohmic losses [V]': Subtraction(0x6bc05f4227de1490, -, children=['boundary value(Negative electrode potential [V])', 'x-average(Negative electrode potential [V])'], domains={'primary': ['current collector']}),
#  'Gradient of negative electrode potential [V.m-1]': Gradient(-0x7ae8dc8c1574364e, grad, children=['Negative electrode potential [V]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Positive electrode potential [V]': Variable(-0x69caf94414931f7c, Positive electrode potential [V], children=[], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrode potential [V]': XAverage(0x3d5f473e54d6e20d, x-average, children=['Positive electrode potential [V]'], domains={'primary': ['current collector']}),
#  'Positive electrode ohmic losses [V]': Subtraction(0x3f388443d95c2ce7, -, children=['broadcast(boundary value(Positive electrode potential [V]))', 'Positive electrode potential [V]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrode ohmic losses [V]': Subtraction(0x4d6770effad4616b, -, children=['boundary value(Positive electrode potential [V])', 'x-average(Positive electrode potential [V])'], domains={'primary': ['current collector']}),
#  'Gradient of positive electrode potential [V.m-1]': Gradient(-0x7206ee0fbc6434e4, grad, children=['Positive electrode potential [V]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Porosity times concentration [mol.m-3]': ConcatenationVariable(0x3aafc3c155d65ba3, Porosity times concentration [mol.m-3], children=['Negative electrode porosity times concentration [mol.m-3]', 'Separator porosity times concentration [mol.m-3]', 'Positive electrode porosity times concentration [mol.m-3]'], domains={'primary': ['negative electrode', 'separator', 'positive electrode'], 'secondary': ['current collector']}),
#  'Negative electrode porosity times concentration [mol.m-3]': Variable(0x3f49e545afc0c96e, Negative electrode porosity times concentration [mol.m-3], children=[], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Separator porosity times concentration [mol.m-3]': Variable(0x262db3d94d6cf56c, Separator porosity times concentration [mol.m-3], children=[], domains={'primary': ['separator'], 'secondary': ['current collector']}),
#  'Positive electrode porosity times concentration [mol.m-3]': Variable(0x2e2a267902b990bc, Positive electrode porosity times concentration [mol.m-3], children=[], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Total lithium in electrolyte [mol]': Multiplication(-0x4016181730ef9ea3, *, children=['(Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]) * Electrode width [m] * Electrode height [m]', 'yz-average(x-average(Porosity times concentration [mol.m-3](Negative electrode porosity times concentration [mol.m-3], Separator porosity times concentration [mol.m-3], Positive electrode porosity times concentration [mol.m-3])))'], domains={}),
#  'Electrolyte potential [V]': ConcatenationVariable(0xb4a465e324a6619, Electrolyte potential [V], children=['Negative electrolyte potential [V]', 'Separator electrolyte potential [V]', 'Positive electrolyte potential [V]'], domains={'primary': ['negative electrode', 'separator', 'positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged electrolyte potential [V]': XAverage(-0x2da76023a56f6965, x-average, children=['Electrolyte potential [V](Negative electrolyte potential [V], Separator electrolyte potential [V], Positive electrolyte potential [V])'], domains={'primary': ['current collector']}),
#  'X-averaged electrolyte overpotential [V]': Subtraction(0x45707754b8f50d98, -, children=['x-average(Positive electrolyte potential [V])', 'x-average(Negative electrolyte potential [V])'], domains={'primary': ['current collector']}),
#  'Gradient of electrolyte potential [V.m-1]': Gradient(-0x40cab0453ddb8fb9, grad, children=['Electrolyte potential [V](Negative electrolyte potential [V], Separator electrolyte potential [V], Positive electrolyte potential [V])'], domains={'primary': ['negative electrode', 'separator', 'positive electrode'], 'secondary': ['current collector']}),
#  'Negative electrolyte potential [V]': Variable(-0x10524889149720b2, Negative electrolyte potential [V], children=[], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrolyte potential [V]': XAverage(0x708ed8c98a231cda, x-average, children=['Negative electrolyte potential [V]'], domains={'primary': ['current collector']}),
#  'Gradient of negative electrolyte potential [V.m-1]': Gradient(-0x29eea38437a19e01, grad, children=['Negative electrolyte potential [V]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Separator electrolyte potential [V]': Variable(0x1234f8570388f603, Separator electrolyte potential [V], children=[], domains={'primary': ['separator'], 'secondary': ['current collector']}),
#  'X-averaged separator electrolyte potential [V]': XAverage(0x484dc94e3ae51f02, x-average, children=['Separator electrolyte potential [V]'], domains={'primary': ['current collector']}),
#  'Gradient of separator electrolyte potential [V.m-1]': Gradient(-0x39b457858db4f185, grad, children=['Separator electrolyte potential [V]'], domains={'primary': ['separator'], 'secondary': ['current collector']}),
#  'Positive electrolyte potential [V]': Variable(0x749c140b6bb540af, Positive electrolyte potential [V], children=[], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrolyte potential [V]': XAverage(0x61c7b1117f88637b, x-average, children=['Positive electrolyte potential [V]'], domains={'primary': ['current collector']}),
#  'Gradient of positive electrolyte potential [V.m-1]': Gradient(-0x21530825b34dd2da, grad, children=['Positive electrolyte potential [V]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Ambient temperature [K]': FunctionParameter(-0x2b5840066ebb1e52, Ambient temperature [K], children=['y', 'z', 'time'], domains={'primary': ['current collector']}),
#  'Volume-averaged ambient temperature [K]': ZAverage(0x79f8741d3a686a85, z-average, children=['Ambient temperature [K]'], domains={}),
#  'Cell temperature [K]': PrimaryBroadcast(0x27d56357c1ce7ff, broadcast, children=['broadcast(Volume-averaged cell temperature [K])'], domains={'primary': ['negative electrode', 'separator', 'positive electrode'], 'secondary': ['current collector']}),
#  'Negative current collector temperature [K]': PrimaryBroadcast(0x20048ece8b565a51, broadcast, children=['Volume-averaged cell temperature [K]'], domains={'primary': ['current collector']}),
#  'Positive current collector temperature [K]': PrimaryBroadcast(0x20048ece8b565a51, broadcast, children=['Volume-averaged cell temperature [K]'], domains={'primary': ['current collector']}),
#  'X-averaged cell temperature [K]': PrimaryBroadcast(0x20048ece8b565a51, broadcast, children=['Volume-averaged cell temperature [K]'], domains={'primary': ['current collector']}),
#  'Volume-averaged cell temperature [K]': Variable(-0x6d74ac66193b17fe, Volume-averaged cell temperature [K], children=[], domains={}),
#  'Negative electrode temperature [K]': PrimaryBroadcast(0x79e27ec3aa3fc74f, broadcast, children=['broadcast(Volume-averaged cell temperature [K])'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrode temperature [K]': PrimaryBroadcast(0x20048ece8b565a51, broadcast, children=['Volume-averaged cell temperature [K]'], domains={'primary': ['current collector']}),
#  'Separator temperature [K]': PrimaryBroadcast(-0x6e5f8b6456d8c8e, broadcast, children=['broadcast(Volume-averaged cell temperature [K])'], domains={'primary': ['separator'], 'secondary': ['current collector']}),
#  'X-averaged separator temperature [K]': PrimaryBroadcast(0x20048ece8b565a51, broadcast, children=['Volume-averaged cell temperature [K]'], domains={'primary': ['current collector']}),
#  'Positive electrode temperature [K]': PrimaryBroadcast(-0x4504939c981b62a4, broadcast, children=['broadcast(Volume-averaged cell temperature [K])'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrode temperature [K]': PrimaryBroadcast(0x20048ece8b565a51, broadcast, children=['Volume-averaged cell temperature [K]'], domains={'primary': ['current collector']}),
#  'Ambient temperature [C]': Addition(-0x1de8eea3728b3370, +, children=['-273.15', 'Ambient temperature [K]'], domains={'primary': ['current collector']}),
#  'Volume-averaged ambient temperature [C]': Addition(-0x356f974b9f6c7544, +, children=['-273.15', 'z-average(Ambient temperature [K])'], domains={}),
#  'Cell temperature [C]': PrimaryBroadcast(0x3b78b3ef8160614a, broadcast, children=['broadcast(-273.15 + Volume-averaged cell temperature [K])'], domains={'primary': ['negative electrode', 'separator', 'positive electrode'], 'secondary': ['current collector']}),
#  'Negative current collector temperature [C]': PrimaryBroadcast(0xc9ca0005176520d, broadcast, children=['-273.15 + Volume-averaged cell temperature [K]'], domains={'primary': ['current collector']}),
#  'Positive current collector temperature [C]': PrimaryBroadcast(0xc9ca0005176520d, broadcast, children=['-273.15 + Volume-averaged cell temperature [K]'], domains={'primary': ['current collector']}),
#  'X-averaged cell temperature [C]': PrimaryBroadcast(0xc9ca0005176520d, broadcast, children=['-273.15 + Volume-averaged cell temperature [K]'], domains={'primary': ['current collector']}),
#  'Volume-averaged cell temperature [C]': Addition(0x659bf4fb12355e3, +, children=['-273.15', 'Volume-averaged cell temperature [K]'], domains={}),
#  'Negative electrode temperature [C]': PrimaryBroadcast(-0x34b12b749da5eef7, broadcast, children=['broadcast(-273.15 + Volume-averaged cell temperature [K])'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrode temperature [C]': PrimaryBroadcast(0xc9ca0005176520d, broadcast, children=['-273.15 + Volume-averaged cell temperature [K]'], domains={'primary': ['current collector']}),
#  'Separator temperature [C]': PrimaryBroadcast(-0x786f88320d5342d4, broadcast, children=['broadcast(-273.15 + Volume-averaged cell temperature [K])'], domains={'primary': ['separator'], 'secondary': ['current collector']}),
#  'X-averaged separator temperature [C]': PrimaryBroadcast(0xc9ca0005176520d, broadcast, children=['-273.15 + Volume-averaged cell temperature [K]'], domains={'primary': ['current collector']}),
#  'Positive electrode temperature [C]': PrimaryBroadcast(0x4971dce79ffee716, broadcast, children=['broadcast(-273.15 + Volume-averaged cell temperature [K])'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrode temperature [C]': PrimaryBroadcast(0xc9ca0005176520d, broadcast, children=['-273.15 + Volume-averaged cell temperature [K]'], domains={'primary': ['current collector']}),
#  'Negative current collector potential [V]': PrimaryBroadcast(0x5311a8eb06f4e2f6, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'Negative inner SEI thickness [m]': Variable(0x454c65fabd8f8c6c, Negative inner SEI thickness [m], children=[], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Negative outer SEI thickness [m]': Variable(0x7c2da63ab3c9aec6, Negative outer SEI thickness [m], children=[], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative inner SEI thickness [m]': XAverage(-0x4fe1d83a3df49b8d, x-average, children=['Negative inner SEI thickness [m]'], domains={'primary': ['current collector']}),
#  'X-averaged negative outer SEI thickness [m]': XAverage(0x40ad0ab953ab2b30, x-average, children=['Negative outer SEI thickness [m]'], domains={'primary': ['current collector']}),
#  'Negative SEI [m]': Addition(-0x24a49da26b95ed82, +, children=['Negative inner SEI thickness [m]', 'Negative outer SEI thickness [m]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Negative total SEI thickness [m]': Addition(-0x24a49da26b95ed82, +, children=['Negative inner SEI thickness [m]', 'Negative outer SEI thickness [m]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative SEI thickness [m]': Addition(0x47a06fab504d7fab, +, children=['x-average(Negative inner SEI thickness [m])', 'x-average(Negative outer SEI thickness [m])'], domains={'primary': ['current collector']}),
#  'X-averaged negative total SEI thickness [m]': Addition(0x47a06fab504d7fab, +, children=['x-average(Negative inner SEI thickness [m])', 'x-average(Negative outer SEI thickness [m])'], domains={'primary': ['current collector']}),
#  'X-averaged negative electrode resistance [Ohm.m2]': Multiplication(-0x6fc0c6e5f0734f0b, *, children=['x-average(Negative inner SEI thickness [m]) + x-average(Negative outer SEI thickness [m])', 'SEI resistivity [Ohm.m]'], domains={'primary': ['current collector']}),
#  'Positive inner SEI thickness [m]': FullBroadcast(-0x5d8f24b06e2cb9b6, broadcast, children=['0.0'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Positive outer SEI thickness [m]': FullBroadcast(-0x5d8f24b06e2cb9b6, broadcast, children=['0.0'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive inner SEI thickness [m]': PrimaryBroadcast(0x5311a8eb06f4e2f6, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'X-averaged positive outer SEI thickness [m]': PrimaryBroadcast(0x5311a8eb06f4e2f6, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'Positive SEI [m]': FullBroadcast(-0x5d8f24b06e2cb9b6, broadcast, children=['0.0'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
# ...
#  'Loss of lithium inventory [%]': Subtraction(0x56c2753771a2d976, -, children=['100.0', '100.0 * (yz-average(x-average(Negative electrode active material volume fraction * r-average(Negative particle concentration [mol.m-3]))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] + yz-average(x-average(Positive electrode active material volume fraction * r-average(Positive particle concentration [mol.m-3]))) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m]) / (yz-average(x-average(Negative electrode active material volume fraction * r-average(Initial concentration in negative electrode [mol.m-3]))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] + yz-average(x-average(Positive electrode active material volume fraction * r-average(Initial concentration in positive electrode [mol.m-3]))) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m])'], domains={}),
#  'Loss of lithium inventory, including electrolyte [%]': Subtraction(-0x5128ef6fdd8e6c9e, -, children=['100.0', '100.0 * (yz-average(x-average(Negative electrode active material volume fraction * r-average(Negative particle concentration [mol.m-3]))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] + yz-average(x-average(Positive electrode active material volume fraction * r-average(Positive particle concentration [mol.m-3]))) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m] + (Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]) * Electrode width [m] * Electrode height [m] * yz-average(x-average(Porosity times concentration [mol.m-3](Negative electrode porosity times concentration [mol.m-3], Separator porosity times concentration [mol.m-3], Positive electrode porosity times concentration [mol.m-3])))) / (yz-average(x-average(Negative electrode active material volume fraction * r-average(Initial concentration in negative electrode [mol.m-3]))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] + yz-average(x-average(Positive electrode active material volume fraction * r-average(Initial concentration in positive electrode [mol.m-3]))) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m] + yz-average((Negative electrode thickness [m] * x-average(Negative electrode porosity) + Separator thickness [m] * x-average(Separator porosity) + Positive electrode thickness [m] * x-average(Positive electrode porosity)) / (Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m])) * Initial concentration in electrolyte [mol.m-3] * (Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]) * Electrode width [m] * Electrode height [m])'], domains={}),
#  'Total lithium [mol]': Addition(-0x393b5e0e82647b1d, +, children=['yz-average(x-average(Negative electrode active material volume fraction * r-average(Negative particle concentration [mol.m-3]))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] + yz-average(x-average(Positive electrode active material volume fraction * r-average(Positive particle concentration [mol.m-3]))) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m]', '(Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]) * Electrode width [m] * Electrode height [m] * yz-average(x-average(Porosity times concentration [mol.m-3](Negative electrode porosity times concentration [mol.m-3], Separator porosity times concentration [mol.m-3], Positive electrode porosity times concentration [mol.m-3])))'], domains={}),
#  'Total lithium in particles [mol]': Addition(-0x26cbbbce5d875c46, +, children=['yz-average(x-average(Negative electrode active material volume fraction * r-average(Negative particle concentration [mol.m-3]))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m]', 'yz-average(x-average(Positive electrode active material volume fraction * r-average(Positive particle concentration [mol.m-3]))) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m]'], domains={}),
#  'Total lithium capacity [A.h]': Multiplication(0x29399a250bbdf684, *, children=['0.0002777777777777778', '(yz-average(x-average(Negative electrode active material volume fraction * r-average(Negative particle concentration [mol.m-3]))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] + yz-average(x-average(Positive electrode active material volume fraction * r-average(Positive particle concentration [mol.m-3]))) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m] + (Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]) * Electrode width [m] * Electrode height [m] * yz-average(x-average(Porosity times concentration [mol.m-3](Negative electrode porosity times concentration [mol.m-3], Separator porosity times concentration [mol.m-3], Positive electrode porosity times concentration [mol.m-3])))) * Faraday constant [C.mol-1]'], domains={}),
#  'Total lithium capacity in particles [A.h]': Multiplication(-0x3b7e8420eeeffc4d, *, children=['0.0002777777777777778', '(yz-average(x-average(Negative electrode active material volume fraction * r-average(Negative particle concentration [mol.m-3]))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] + yz-average(x-average(Positive electrode active material volume fraction * r-average(Positive particle concentration [mol.m-3]))) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m]) * Faraday constant [C.mol-1]'], domains={}),
#  'Total lithium lost [mol]': Subtraction(0x3e32612aaa40bb72, -, children=['yz-average(x-average(Negative electrode active material volume fraction * r-average(Initial concentration in negative electrode [mol.m-3]))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] + yz-average(x-average(Positive electrode active material volume fraction * r-average(Initial concentration in positive electrode [mol.m-3]))) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m] + yz-average((Negative electrode thickness [m] * x-average(Negative electrode porosity) + Separator thickness [m] * x-average(Separator porosity) + Positive electrode thickness [m] * x-average(Positive electrode porosity)) / (Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m])) * Initial concentration in electrolyte [mol.m-3] * (Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]) * Electrode width [m] * Electrode height [m]', 'yz-average(x-average(Negative electrode active material volume fraction * r-average(Negative particle concentration [mol.m-3]))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] + yz-average(x-average(Positive electrode active material volume fraction * r-average(Positive particle concentration [mol.m-3]))) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m] + (Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]) * Electrode width [m] * Electrode height [m] * yz-average(x-average(Porosity times concentration [mol.m-3](Negative electrode porosity times concentration [mol.m-3], Separator porosity times concentration [mol.m-3], Positive electrode porosity times concentration [mol.m-3])))'], domains={}),
#  'Total lithium lost from particles [mol]': Subtraction(0x75116b1e9b4cc883, -, children=['yz-average(x-average(Negative electrode active material volume fraction * r-average(Initial concentration in negative electrode [mol.m-3]))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] + yz-average(x-average(Positive electrode active material volume fraction * r-average(Initial concentration in positive electrode [mol.m-3]))) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m]', 'yz-average(x-average(Negative electrode active material volume fraction * r-average(Negative particle concentration [mol.m-3]))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] + yz-average(x-average(Positive electrode active material volume fraction * r-average(Positive particle concentration [mol.m-3]))) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m]'], domains={}),
#  'Total lithium lost from electrolyte [mol]': Subtraction(0x6a975b7e3e9005e0, -, children=['yz-average((Negative electrode thickness [m] * x-average(Negative electrode porosity) + Separator thickness [m] * x-average(Separator porosity) + Positive electrode thickness [m] * x-average(Positive electrode porosity)) / (Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m])) * Initial concentration in electrolyte [mol.m-3] * (Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]) * Electrode width [m] * Electrode height [m]', '(Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]) * Electrode width [m] * Electrode height [m] * yz-average(x-average(Porosity times concentration [mol.m-3](Negative electrode porosity times concentration [mol.m-3], Separator porosity times concentration [mol.m-3], Positive electrode porosity times concentration [mol.m-3])))'], domains={}),
#  'Total lithium lost to side reactions [mol]': Addition(-0x5129e989431f3321, +, children=['Ratio of lithium moles to SEI moles * (yz-average(x-average(Negative inner SEI thickness [m] * 3.0 * Negative electrode active material volume fraction / Negative particle radius [m] / Inner SEI partial molar volume [m3.mol-1])) + yz-average(x-average(Negative outer SEI thickness [m] * 3.0 * Negative electrode active material volume fraction / Negative particle radius [m] / Outer SEI partial molar volume [m3.mol-1])) - (Initial inner SEI thickness [m] * 3.0 * yz-average(x-average(Negative electrode active material volume fraction)) / Negative particle radius [m] / Inner SEI partial molar volume [m3.mol-1] + Initial outer SEI thickness [m] * 3.0 * yz-average(x-average(Negative electrode active material volume fraction)) / Negative particle radius [m] / Outer SEI partial molar volume [m3.mol-1])) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m]', 'Ratio of lithium moles to SEI moles * (yz-average(x-average(Negative inner SEI on cracks thickness [m] * 3.0 * Negative electrode active material volume fraction / Negative particle radius [m] / Inner SEI partial molar volume [m3.mol-1] * 2.0 * Negative particle crack length [m] * Negative electrode number of cracks per unit area [m-2] * Negative electrode initial crack width [m])) + yz-average(x-average(Negative outer SEI on cracks thickness [m] * 3.0 * Negative electrode active material volume fraction / Negative particle radius [m] / Outer SEI partial molar volume [m3.mol-1] * 2.0 * Negative particle crack length [m] * Negative electrode number of cracks per unit area [m-2] * Negative electrode initial crack width [m])) - ((Initial inner SEI on cracks thickness [m] * 3.0 * yz-average(x-average(Negative electrode active material volume fraction)) / Negative particle radius [m] / Inner SEI partial molar volume [m3.mol-1] + Initial outer SEI on cracks thickness [m] * 3.0 * yz-average(x-average(Negative electrode active material volume fraction)) / Negative particle radius [m] / Outer SEI partial molar volume [m3.mol-1]) * yz-average(x-average(2.0 * Negative particle crack length [m] * Negative electrode number of cracks per unit area [m-2] * Negative electrode initial crack width [m])))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] + x-average(Negative lithium plating concentration [mol.m-3]) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] + x-average(Negative dead lithium concentration [mol.m-3]) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m]'], domains={'primary': ['current collector']}),
#  'Total capacity lost to side reactions [A.h]': Multiplication(-0x35ee2dfc1d85b23d, *, children=['0.0002777777777777778', '(Ratio of lithium moles to SEI moles * (yz-average(x-average(Negative inner SEI thickness [m] * 3.0 * Negative electrode active material volume fraction / Negative particle radius [m] / Inner SEI partial molar volume [m3.mol-1])) + yz-average(x-average(Negative outer SEI thickness [m] * 3.0 * Negative electrode active material volume fraction / Negative particle radius [m] / Outer SEI partial molar volume [m3.mol-1])) - (Initial inner SEI thickness [m] * 3.0 * yz-average(x-average(Negative electrode active material volume fraction)) / Negative particle radius [m] / Inner SEI partial molar volume [m3.mol-1] + Initial outer SEI thickness [m] * 3.0 * yz-average(x-average(Negative electrode active material volume fraction)) / Negative particle radius [m] / Outer SEI partial molar volume [m3.mol-1])) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] + Ratio of lithium moles to SEI moles * (yz-average(x-average(Negative inner SEI on cracks thickness [m] * 3.0 * Negative electrode active material volume fraction / Negative particle radius [m] / Inner SEI partial molar volume [m3.mol-1] * 2.0 * Negative particle crack length [m] * Negative electrode number of cracks per unit area [m-2] * Negative electrode initial crack width [m])) + yz-average(x-average(Negative outer SEI on cracks thickness [m] * 3.0 * Negative electrode active material volume fraction / Negative particle radius [m] / Outer SEI partial molar volume [m3.mol-1] * 2.0 * Negative particle crack length [m] * Negative electrode number of cracks per unit area [m-2] * Negative electrode initial crack width [m])) - ((Initial inner SEI on cracks thickness [m] * 3.0 * yz-average(x-average(Negative electrode active material volume fraction)) / Negative particle radius [m] / Inner SEI partial molar volume [m3.mol-1] + Initial outer SEI on cracks thickness [m] * 3.0 * yz-average(x-average(Negative electrode active material volume fraction)) / Negative particle radius [m] / Outer SEI partial molar volume [m3.mol-1]) * yz-average(x-average(2.0 * Negative particle crack length [m] * Negative electrode number of cracks per unit area [m-2] * Negative electrode initial crack width [m])))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] + x-average(Negative lithium plating concentration [mol.m-3]) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] + x-average(Negative dead lithium concentration [mol.m-3]) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m]) * Faraday constant [C.mol-1]'], domains={'primary': ['current collector']})}

# %%
param
# Out:
# {'Ambient temperature [K]': 298.15,
#  'Boltzmann constant [J.K-1]': 1.380649e-23,
#  'Bulk solvent concentration [mol.m-3]': 2636.0,
#  'Cation transference number': 0.2594,
#  'Cell cooling surface area [m2]': 0.00531,
#  'Cell thermal expansion coefficient [m.K-1]': 1.1e-06,
#  'Cell volume [m3]': 2.42e-05,
#  'Contact resistance [Ohm]': 0,
#  'Current function [A]': 5.0,
#  'Dead lithium decay constant [s-1]': 1e-06,
#  'Dead lithium decay rate [s-1]': <function SEI_limited_dead_lithium_OKane2022 at 0x7ff8e4f89ca0>,
#  'EC diffusivity [m2.s-1]': 2e-18,
#  'EC initial concentration in electrolyte [mol.m-3]': 4541.0,
#  'Electrode height [m]': 0.065,
#  'Electrode width [m]': 1.58,
#  'Electrolyte conductivity [S.m-1]': <function electrolyte_conductivity_Nyman2008_arrhenius at 0x7ff8e4f89670>,
#  'Electrolyte diffusivity [m2.s-1]': <function electrolyte_diffusivity_Nyman2008_arrhenius at 0x7ff8e4f89700>,
#  'Electron charge [C]': 1.602176634e-19,
#  'Exchange-current density for plating [A.m-2]': <function plating_exchange_current_density_OKane2020 at 0x7ff8e4f89dc0>,
#  'Exchange-current density for stripping [A.m-2]': <function stripping_exchange_current_density_OKane2020 at 0x7ff8e4f89d30>,
#  'Faraday constant [C.mol-1]': 96485.33212,
#  'Ideal gas constant [J.K-1.mol-1]': 8.314462618,
#  'Initial concentration in electrolyte [mol.m-3]': 1000.0,
#  'Initial concentration in negative electrode [mol.m-3]': 29866.0,
#  'Initial concentration in positive electrode [mol.m-3]': 17038.0,
#  'Initial inner SEI on cracks thickness [m]': 0,
#  'Initial inner SEI thickness [m]': 0.0,
#  'Initial outer SEI on cracks thickness [m]': 5e-13,
#  'Initial outer SEI thickness [m]': 5e-09,
#  'Initial plated lithium concentration [mol.m-3]': 0.0,
#  'Initial temperature [K]': 298.15,
#  'Inner SEI electron conductivity [S.m-1]': 8.95e-14,
#  'Inner SEI lithium interstitial diffusivity [m2.s-1]': 1e-20,
#  'Inner SEI open-circuit potential [V]': 0.1,
#  'Inner SEI partial molar volume [m3.mol-1]': 9.585e-05,
#  'Inner SEI reaction proportion': 0.0,
#  'Lithium interstitial reference concentration [mol.m-3]': 15.0,
#  'Lithium metal partial molar volume [m3.mol-1]': 1.3e-05,
#  'Lithium plating kinetic rate constant [m.s-1]': 1e-09,
#  'Lithium plating transfer coefficient': 0.65,
#  'Lower voltage cut-off [V]': 2.5,
#  'Maximum concentration in negative electrode [mol.m-3]': 33133.0,
#  'Maximum concentration in positive electrode [mol.m-3]': 63104.0,
#  'Negative current collector conductivity [S.m-1]': 58411000.0,
#  'Negative current collector density [kg.m-3]': 8960.0,
#  'Negative current collector specific heat capacity [J.kg-1.K-1]': 385.0,
#  'Negative current collector thermal conductivity [W.m-1.K-1]': 401.0,
#  'Negative current collector thickness [m]': 1.2e-05,
#  'Negative electrode Bruggeman coefficient (electrode)': 1.5,
#  'Negative electrode Bruggeman coefficient (electrolyte)': 1.5,
#  'Negative electrode LAM constant exponential term': 2.0,
#  'Negative electrode LAM constant proportional term [s-1]': 2.7778e-07,
#  'Negative electrode OCP [V]': <function graphite_LGM50_ocp_Chen2020 at 0x7ff8e4f89550>,
#  'Negative electrode OCP entropic change [V.K-1]': 0.0,
#  "Negative electrode Paris' law constant b": 1.12,
#  "Negative electrode Paris' law constant m": 2.2,
#  "Negative electrode Poisson's ratio": 0.3,
#  "Negative electrode Young's modulus [Pa]": 15000000000.0,
#  'Negative electrode active material volume fraction': 0.75,
#  'Negative electrode charge transfer coefficient': 0.5,
#  'Negative electrode conductivity [S.m-1]': 215.0,
#  'Negative electrode cracking rate': <function graphite_cracking_rate_Ai2020 at 0x7ff8e4f89a60>,
#  'Negative electrode critical stress [Pa]': 60000000.0,
#  'Negative electrode density [kg.m-3]': 1657.0,
#  'Negative electrode double-layer capacity [F.m-2]': 0.2,
#  'Negative electrode exchange-current density [A.m-2]': <function graphite_LGM50_electrolyte_exchange_current_density_Chen2020 at 0x7ff8e4f89b80>,
#  'Negative electrode initial crack length [m]': 2e-08,
#  'Negative electrode initial crack width [m]': 1.5e-08,
#  'Negative electrode number of cracks per unit area [m-2]': 3180000000000000.0,
#  'Negative electrode partial molar volume [m3.mol-1]': 3.1e-06,
#  'Negative electrode porosity': 0.25,
#  'Negative electrode reaction-driven LAM factor [m3.mol-1]': 0.0,
#  'Negative electrode reference concentration for free of deformation [mol.m-3]': 0.0,
#  'Negative electrode specific heat capacity [J.kg-1.K-1]': 700.0,
#  'Negative electrode thermal conductivity [W.m-1.K-1]': 1.7,
#  'Negative electrode thickness [m]': 8.52e-05,
#  'Negative electrode volume change': <function graphite_volume_change_Ai2020 at 0x7ff8e4f89af0>,
#  'Negative particle diffusivity [m2.s-1]': <function graphite_LGM50_diffusivity_Chen2020 at 0x7ff8e4f89c10>,
#  'Negative particle radius [m]': 5.86e-06,
#  'Nominal cell capacity [A.h]': 4.8,
#  'Number of cells connected in series to make a battery': 1.0,
#  'Number of electrodes connected in parallel to make a cell': 1.0,
#  'Open-circuit voltage at 0% SOC [V]': 2.5,
#  'Open-circuit voltage at 100% SOC [V]': 4.2,
#  'Outer SEI open-circuit potential [V]': 0.8,
#  'Outer SEI partial molar volume [m3.mol-1]': 9.585e-05,
#  'Outer SEI solvent diffusivity [m2.s-1]': 2.5000000000000002e-22,
#  'Positive current collector conductivity [S.m-1]': 36914000.0,
#  'Positive current collector density [kg.m-3]': 2700.0,
#  'Positive current collector specific heat capacity [J.kg-1.K-1]': 897.0,
#  'Positive current collector thermal conductivity [W.m-1.K-1]': 237.0,
#  'Positive current collector thickness [m]': 1.6e-05,
#  'Positive electrode Bruggeman coefficient (electrode)': 1.5,
#  'Positive electrode Bruggeman coefficient (electrolyte)': 1.5,
#  'Positive electrode LAM constant exponential term': 2.0,
#  'Positive electrode LAM constant proportional term [s-1]': 2.7778e-07,
#  'Positive electrode OCP [V]': <function nmc_LGM50_ocp_Chen2020 at 0x7ff8e4f89940>,
#  'Positive electrode OCP entropic change [V.K-1]': 0.0,
#  "Positive electrode Paris' law constant b": 1.12,
#  "Positive electrode Paris' law constant m": 2.2,
#  "Positive electrode Poisson's ratio": 0.2,
#  "Positive electrode Young's modulus [Pa]": 375000000000.0,
#  'Positive electrode active material volume fraction': 0.665,
#  'Positive electrode charge transfer coefficient': 0.5,
#  'Positive electrode conductivity [S.m-1]': 0.18,
#  'Positive electrode cracking rate': <function cracking_rate_Ai2020 at 0x7ff8e4f89790>,
#  'Positive electrode critical stress [Pa]': 375000000.0,
#  'Positive electrode density [kg.m-3]': 3262.0,
#  'Positive electrode double-layer capacity [F.m-2]': 0.2,
#  'Positive electrode exchange-current density [A.m-2]': <function nmc_LGM50_electrolyte_exchange_current_density_Chen2020 at 0x7ff8e4f898b0>,
#  'Positive electrode initial crack length [m]': 2e-08,
#  'Positive electrode initial crack width [m]': 1.5e-08,
#  'Positive electrode number of cracks per unit area [m-2]': 3180000000000000.0,
#  'Positive electrode partial molar volume [m3.mol-1]': 7.88e-07,
#  'Positive electrode porosity': 0.335,
#  'Positive electrode reaction-driven LAM factor [m3.mol-1]': 0.0,
#  'Positive electrode reference concentration for free of deformation [mol.m-3]': 0.0,
#  'Positive electrode specific heat capacity [J.kg-1.K-1]': 700.0,
#  'Positive electrode thermal conductivity [W.m-1.K-1]': 2.1,
#  'Positive electrode thickness [m]': 7.56e-05,
#  'Positive electrode volume change': <function volume_change_Ai2020 at 0x7ff8e4f89820>,
#  'Positive particle diffusivity [m2.s-1]': <function nmc_LGM50_diffusivity_Chen2020 at 0x7ff8e4f899d0>,
#  'Positive particle radius [m]': 5.22e-06,
#  'Ratio of lithium moles to SEI moles': 1.0,
#  'Reference temperature [K]': 298.15,
#  'SEI growth activation energy [J.mol-1]': 38000.0,
#  'SEI kinetic rate constant [m.s-1]': 1e-12,
#  'SEI open-circuit potential [V]': 0.4,
#  'SEI reaction exchange current density [A.m-2]': 1.5e-07,
#  'SEI resistivity [Ohm.m]': 200000.0,
#  'Separator Bruggeman coefficient (electrolyte)': 1.5,
#  'Separator density [kg.m-3]': 397.0,
#  'Separator porosity': 0.47,
#  'Separator specific heat capacity [J.kg-1.K-1]': 700.0,
#  'Separator thermal conductivity [W.m-1.K-1]': 0.16,
#  'Separator thickness [m]': 1.2e-05,
#  'Thermodynamic factor': 1.0,
#  'Total heat transfer coefficient [W.m-2.K-1]': 15.0,
#  'Typical plated lithium concentration [mol.m-3]': 1000.0,
#  'Upper voltage cut-off [V]': 4.2,
#  'citations': ['OKane2022',
#                'OKane2020',
#                'Chen2020']}

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
cwd = os.getcwd()


# 读取 pickle 文件
#pickle_file_path = cwd + '/docs/source/examples/notebooks/models/exp_LG/processed_data.pkl'
pickle_file_path = cwd + '/exp_LG/processed_data.pkl'
cycles_df = pd.read_pickle(pickle_file_path)
print("DataFrame loaded from pickle file")
print(cycles_df.head())
# Out:
# DataFrame loaded from pickle file
#             Mode  RelativeTime   Voltage          I  Q_dis     Q_cha  \
# Cycle Step
# 1     1      1.0        0.0000  2.680430  1407.8055    0.0  0.000078
#       2      1.0        0.0084  2.690530  1574.4427    0.0  0.003691
#       3      1.0        0.0294  2.700598  1640.2499    0.0  0.013108
#       4      1.0        0.0634  2.710643  1664.4644    0.0  0.028749
#       5      1.0        0.1074  2.720645  1668.5892    0.0  0.049123
#
#                  Cap         R    Pressure  Temperature
# Cycle Step
# 1     1     0.000078  1.903978  159.026607      25.3794
#       2     0.003691  1.708878  158.944819      25.3885
#       3     0.013108  1.646455  158.998347      25.4014
#       4     0.028749  1.628537  159.049016      25.4088
#       5     0.049123  1.630506  158.990980      25.4014

# %%
# Compare model data to experiment including degradation

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(13, 4))

# plot the 1C results
t_sol = sol["Time [s]"].entries


ax1.plot(t_sol, sol["Voltage [V]"](t_sol))
ax1.plot(cycles_df.loc[1]["RelativeTime"],cycles_df.loc[1]["Voltage"], "o")
ax1.set_xlabel("Time [s]")
ax1.set_ylabel("Voltage [V]")
ax1.set_title("Voltage")
ax1.legend(["Model", "Experiment"], loc="best")


ax2.plot(t_sol, sol["X-averaged cell temperature [C]"](t_sol))
ax2.plot(cycles_df.loc[1]["RelativeTime"],cycles_df.loc[1]["Temperature"], "o")
ax2.set_xlabel("Time [s]")
ax2.set_ylabel("Temperature [degC]")
ax2.set_title("Temperature")
ax2.legend(["Model", "Experiment"], loc="best")

plt.tight_layout()
plt.show()

# %%
plt.plot(sol["Time [s]"].entries,sol["Discharge capacity [A.h]"].entries )

# %%
sol["Discharge capacity [A.h]"].entries
# Out:
# array([ 0.        , -0.024     , -0.048     , -0.072     , -0.096     ,
#        -0.12      , -0.144     , -0.168     , -0.192     , -0.216     ,
#        -0.24      , -0.264     , -0.288     , -0.312     , -0.336     ,
#        -0.36      , -0.384     , -0.408     , -0.432     , -0.456     ,
#        -0.48      , -0.504     , -0.528     , -0.552     , -0.576     ,
#        -0.6       , -0.624     , -0.648     , -0.672     , -0.696     ,
#        -0.72      , -0.744     , -0.768     , -0.792     , -0.816     ,
#        -0.84      , -0.864     , -0.888     , -0.912     , -0.936     ,
#        -0.96      , -0.984     , -1.008     , -1.032     , -1.056     ,
#        -1.08      , -1.104     , -1.128     , -1.152     , -1.176     ,
#        -1.2       , -1.224     , -1.248     , -1.272     , -1.296     ,
#        -1.32      , -1.344     , -1.368     , -1.392     , -1.416     ,
#        -1.44      , -1.464     , -1.488     , -1.512     , -1.536     ,
#        -1.56      , -1.584     , -1.608     , -1.632     , -1.656     ,
#        -1.68      , -1.704     , -1.728     , -1.752     , -1.776     ,
#        -1.8       , -1.824     , -1.848     , -1.872     , -1.896     ,
#        -1.92      , -1.944     , -1.968     , -1.992     , -2.016     ,
#        -2.04      , -2.064     , -2.088     , -2.112     , -2.136     ,
#        -2.16      , -2.184     , -2.208     , -2.232     , -2.256     ,
#        -2.28      , -2.304     , -2.328     , -2.352     , -2.376     ,
#        -2.4       , -2.424     , -2.448     , -2.472     , -2.496     ,
#        -2.52      , -2.544     , -2.568     , -2.592     , -2.616     ,
#        -2.64      , -2.664     , -2.688     , -2.712     , -2.736     ,
#        -2.76      , -2.784     , -2.808     , -2.832     , -2.856     ,
#        -2.88      , -2.904     , -2.928     , -2.952     , -2.976     ,
#        -3.        , -3.024     , -3.048     , -3.072     , -3.096     ,
#        -3.12      , -3.144     , -3.168     , -3.192     , -3.216     ,
#        -3.24      , -3.264     , -3.288     , -3.312     , -3.336     ,
#        -3.36      , -3.384     , -3.408     , -3.432     , -3.456     ,
#        -3.48      , -3.504     , -3.528     , -3.552     , -3.576     ,
#        -3.6       , -3.624     , -3.648     , -3.672     , -3.696     ,
#        -3.72      , -3.744     , -3.768     , -3.792     , -3.816     ,
#        -3.84      , -3.864     , -3.888     , -3.912     , -3.936     ,
#        -3.96      , -3.984     , -4.008     , -4.032     , -4.056     ,
#        -4.08      , -4.104     , -4.128     , -4.152     , -4.176     ,
#        -4.2       , -4.224     , -4.248     , -4.272     , -4.296     ,
#        -4.32      , -4.344     , -4.368     , -4.392     , -4.416     ,
#        -4.44      , -4.464     , -4.488     , -4.512     , -4.536     ,
#        -4.56      , -4.584     , -4.608     , -4.632     , -4.656     ,
#        -4.68      , -4.704     , -4.728     , -4.752     , -4.776     ,
#        -4.8       , -4.80049385, -4.80049385, -4.82325466, -4.84399979,
#        -4.863047  , -4.88061676, -4.89677353, -4.91170296, -4.92554259,
#        -4.9383368 , -4.95022127, -4.96123591, -4.97139967, -4.98081842,
#        -4.98959476, -4.99778411, -5.00541447, -5.01250578, -5.01908309,
#        -5.0251883 , -5.03087225, -5.03618094, -5.04115501, -5.04581485,
#        -5.05017279, -5.05314566, -5.05314566, -4.97314566, -4.89314566,
#        -4.81314566, -4.73314566, -4.65314566, -4.57314566, -4.49314566,
#        -4.41314566, -4.33314566, -4.25314566, -4.17314566, -4.09314566,
#        -4.01314566, -3.93314566, -3.85314566, -3.77314566, -3.69314566,
#        -3.61314566, -3.53314566, -3.45314566, -3.37314566, -3.29314566,
#        -3.21314566, -3.13314566, -3.05314566, -2.97314566, -2.89314566,
#        -2.81314566, -2.73314566, -2.65314566, -2.57314566, -2.49314566,
#        -2.41314566, -2.33314566, -2.25314566, -2.17314566, -2.09314566,
#        -2.01314566, -1.93314566, -1.85314566, -1.77314566, -1.69314566,
#        -1.61314566, -1.53314566, -1.45314566, -1.37314566, -1.29314566,
#        -1.21314566, -1.13314566, -1.05314566, -0.97314566, -0.89314566,
#        -0.81314566, -0.73314566, -0.65314566, -0.57314566, -0.49314566,
#        -0.41314566, -0.33314566, -0.25314566, -0.17314566, -0.11032768])

# %%
# Compare model data to experiment without degradation

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(13, 4))

# plot the 1C results
t_sol_nodeg = sol_nodeg["Time [s]"].entries


ax1.plot(t_sol_nodeg, sol_nodeg["Voltage [V]"](t_sol_nodeg))
ax1.plot(cycles_df.loc[1]["RelativeTime"],cycles_df.loc[1]["Voltage"], "o")
ax1.set_xlabel("Time [s]")
ax1.set_ylabel("Voltage [V]")
ax1.set_title("Voltage")
ax1.legend(["Model", "Experiment"], loc="best")


#ax2.plot(t_sol_nodeg, sol_nodeg["X-averaged cell temperature [C]"](t_sol_nodeg))
ax2.plot(cycles_df.loc[1]["RelativeTime"],cycles_df.loc[1]["Temperature"], "o")
ax2.set_xlabel("Time [s]")
ax2.set_ylabel("Temperature [degC]")
ax2.set_title("Temperature")
ax2.legend(["Model", "Experiment"], loc="best")

plt.tight_layout()
plt.show()

# %%
model.variables
# Out:
# {'Time [s]': Time(-0x200d97ea54ed6be3, time, children=[], domains={}),
#  'Time [min]': Multiplication(0x10422a3f66b0d2d4, *, children=['0.016666666666666666', 'time'], domains={}),
#  'Time [h]': Multiplication(0xa1f0d95ced7cade, *, children=['0.0002777777777777778', 'time'], domains={}),
#  'x [m]': SpatialVariable(-0x2a9b6bd3ee0dfb0, x, children=[], domains={'primary': ['negative electrode', 'separator', 'positive electrode'], 'secondary': ['current collector']}),
#  'x_n [m]': SpatialVariable(0x4881a48bf8a8d7e1, x_n, children=[], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'x_s [m]': SpatialVariable(-0x7ef61b12b13057ea, x_s, children=[], domains={'primary': ['separator'], 'secondary': ['current collector']}),
#  'x_p [m]': SpatialVariable(-0x568f1bb8000c13ce, x_p, children=[], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'r_n [m]': SpatialVariable(-0x550f81106c51cb77, r_n, children=[], domains={'primary': ['negative particle'], 'secondary': ['negative electrode'], 'tertiary': ['current collector']}),
#  'r_p [m]': SpatialVariable(-0x6d82a910c3c849b6, r_p, children=[], domains={'primary': ['positive particle'], 'secondary': ['positive electrode'], 'tertiary': ['current collector']}),
#  'Current variable [A]': FunctionParameter(-0x6a64630a9ff8c812, Current function [A], children=['time'], domains={}),
#  'Total current density [A.m-2]': Division(0x31d3e6cd92c8f32b, /, children=['Current function [A]', 'Number of electrodes connected in parallel to make a cell * Electrode width [m] * Electrode height [m]'], domains={}),
#  'Current [A]': FunctionParameter(-0x6a64630a9ff8c812, Current function [A], children=['time'], domains={}),
#  'C-rate': Division(-0x4bdd3daa4a5db666, /, children=['Current function [A]', 'Nominal cell capacity [A.h]'], domains={}),
#  'Discharge capacity [A.h]': Variable(0x7b57943bc0c2d3e3, Discharge capacity [A.h], children=[], domains={}),
#  'Throughput capacity [A.h]': Variable(0x5450dfd855bc050, Throughput capacity [A.h], children=[], domains={}),
#  'Discharge energy [W.h]': Variable(0x3b39b9f6f8fd616b, Discharge energy [W.h], children=[], domains={}),
#  'Throughput energy [W.h]': Variable(0x43a880d1f7b9a84f, Throughput energy [W.h], children=[], domains={}),
#  'Negative electrode interface utilisation variable': FullBroadcast(0x429b4c8e25ec8092, broadcast, children=['1.0'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrode interface utilisation variable': PrimaryBroadcast(0x4381b98637762658, broadcast, children=['1.0'], domains={'primary': ['current collector']}),
#  'Negative electrode interface utilisation': FullBroadcast(0x429b4c8e25ec8092, broadcast, children=['1.0'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrode interface utilisation': PrimaryBroadcast(0x4381b98637762658, broadcast, children=['1.0'], domains={'primary': ['current collector']}),
#  'Positive electrode interface utilisation variable': FullBroadcast(-0x7c4bc5d21c6ea961, broadcast, children=['1.0'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrode interface utilisation variable': PrimaryBroadcast(0x4381b98637762658, broadcast, children=['1.0'], domains={'primary': ['current collector']}),
#  'Positive electrode interface utilisation': FullBroadcast(-0x7c4bc5d21c6ea961, broadcast, children=['1.0'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrode interface utilisation': PrimaryBroadcast(0x4381b98637762658, broadcast, children=['1.0'], domains={'primary': ['current collector']}),
#  'Negative particle crack length [m]': Variable(0x40a61395bb559250, Negative particle crack length [m], children=[], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative particle crack length [m]': XAverage(-0x66cacf5760af42f3, x-average, children=['Negative particle crack length [m]'], domains={'primary': ['current collector']}),
#  'Positive particle crack length [m]': FullBroadcast(-0x5d8f24b06e2cb9b6, broadcast, children=['0.0'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive particle crack length [m]': PrimaryBroadcast(0x5311a8eb06f4e2f6, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'Positive particle cracking rate [m.s-1]': FullBroadcast(-0x5d8f24b06e2cb9b6, broadcast, children=['0.0'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive particle cracking rate [m.s-1]': PrimaryBroadcast(0x5311a8eb06f4e2f6, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'Negative electrode active material volume fraction': Variable(0x2d8a2387061e68a7, Negative electrode active material volume fraction, children=[], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrode active material volume fraction': XAverage(-0x4335e8faa3b9e482, x-average, children=['Negative electrode active material volume fraction'], domains={'primary': ['current collector']}),
#  'Negative electrode capacity [A.h]': Multiplication(-0x19bf0467086b7ce1, *, children=['0.0002777777777777778', 'yz-average(x-average(Negative electrode active material volume fraction)) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] * Maximum concentration in negative electrode [mol.m-3] * Faraday constant [C.mol-1]'], domains={}),
#  'Negative particle radius': Division(0x11eed7e61feb83ab, /, children=['Negative particle radius [m]', 'Negative particle radius [m]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Negative particle radius [m]': FunctionParameter(0x6b3a70a57177bbfe, Negative particle radius [m], children=['x_n'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative particle radius [m]': XAverage(-0x1d7b3318ed477af4, x-average, children=['Negative particle radius [m]'], domains={'primary': ['current collector']}),
#  'Negative electrode surface area to volume ratio [m-1]': Division(0x70db9dfba6642ff1, /, children=['3.0 * Negative electrode active material volume fraction', 'Negative particle radius [m]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrode surface area to volume ratio [m-1]': XAverage(-0x7257f14d3062c262, x-average, children=['3.0 * Negative electrode active material volume fraction / Negative particle radius [m]'], domains={'primary': ['current collector']}),
#  'Loss of lithium due to loss of active material in negative electrode [mol]': Variable(0x5c473f98638a2093, Loss of lithium due to loss of active material in negative electrode [mol], children=[], domains={}),
#  'Positive electrode active material volume fraction': Variable(-0x38b9aac182543009, Positive electrode active material volume fraction, children=[], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrode active material volume fraction': XAverage(-0x37a7bd2c8832c762, x-average, children=['Positive electrode active material volume fraction'], domains={'primary': ['current collector']}),
#  'Positive electrode capacity [A.h]': Multiplication(0xce5e1b422de7f3f, *, children=['0.0002777777777777778', 'yz-average(x-average(Positive electrode active material volume fraction)) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m] * Maximum concentration in positive electrode [mol.m-3] * Faraday constant [C.mol-1]'], domains={}),
#  'Positive particle radius': Division(-0x296bb90653e4970f, /, children=['Positive particle radius [m]', 'Positive particle radius [m]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Positive particle radius [m]': FunctionParameter(-0x6966102c80b57848, Positive particle radius [m], children=['x_p'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive particle radius [m]': XAverage(-0x15bc5a67a2bfde65, x-average, children=['Positive particle radius [m]'], domains={'primary': ['current collector']}),
#  'Positive electrode surface area to volume ratio [m-1]': Division(0x20dc088dc2c9877a, /, children=['3.0 * Positive electrode active material volume fraction', 'Positive particle radius [m]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrode surface area to volume ratio [m-1]': XAverage(-0x683ba3bc27e4dc3, x-average, children=['3.0 * Positive electrode active material volume fraction / Positive particle radius [m]'], domains={'primary': ['current collector']}),
#  'Loss of lithium due to loss of active material in positive electrode [mol]': Variable(0x790e4940632ff2c8, Loss of lithium due to loss of active material in positive electrode [mol], children=[], domains={}),
#  'Separator pressure [Pa]': PrimaryBroadcast(0x5655a9ee5c40df5c, broadcast, children=['broadcast(0.0)'], domains={'primary': ['separator'], 'secondary': ['current collector']}),
#  'X-averaged separator pressure [Pa]': PrimaryBroadcast(0x5311a8eb06f4e2f6, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'negative electrode transverse volume-averaged velocity [m.s-1]': PrimaryBroadcast(-0x28e1de97b411ccc7, broadcast, children=['broadcast(0.0)'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrode transverse volume-averaged velocity [m.s-1]': PrimaryBroadcast(0x5311a8eb06f4e2f6, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'separator transverse volume-averaged velocity [m.s-1]': PrimaryBroadcast(0x5655a9ee5c40df5c, broadcast, children=['broadcast(0.0)'], domains={'primary': ['separator'], 'secondary': ['current collector']}),
#  'X-averaged separator transverse volume-averaged velocity [m.s-1]': PrimaryBroadcast(0x5311a8eb06f4e2f6, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'positive electrode transverse volume-averaged velocity [m.s-1]': PrimaryBroadcast(0x5ba11fcb99341d8, broadcast, children=['broadcast(0.0)'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrode transverse volume-averaged velocity [m.s-1]': PrimaryBroadcast(0x5311a8eb06f4e2f6, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'Transverse volume-averaged velocity [m.s-1]': PrimaryBroadcast(0x4d3bfbcecdcb8c7b, broadcast, children=['broadcast(0.0)'], domains={'primary': ['negative electrode', 'separator', 'positive electrode'], 'secondary': ['current collector']}),
#  'negative electrode transverse volume-averaged acceleration [m.s-2]': PrimaryBroadcast(-0x28e1de97b411ccc7, broadcast, children=['broadcast(0.0)'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrode transverse volume-averaged acceleration [m.s-2]': PrimaryBroadcast(0x5311a8eb06f4e2f6, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'separator transverse volume-averaged acceleration [m.s-2]': PrimaryBroadcast(0x5655a9ee5c40df5c, broadcast, children=['broadcast(0.0)'], domains={'primary': ['separator'], 'secondary': ['current collector']}),
#  'X-averaged separator transverse volume-averaged acceleration [m.s-2]': PrimaryBroadcast(0x5311a8eb06f4e2f6, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'positive electrode transverse volume-averaged acceleration [m.s-2]': PrimaryBroadcast(0x5ba11fcb99341d8, broadcast, children=['broadcast(0.0)'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrode transverse volume-averaged acceleration [m.s-2]': PrimaryBroadcast(0x5311a8eb06f4e2f6, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'Transverse volume-averaged acceleration [m.s-2]': PrimaryBroadcast(0x4d3bfbcecdcb8c7b, broadcast, children=['broadcast(0.0)'], domains={'primary': ['negative electrode', 'separator', 'positive electrode'], 'secondary': ['current collector']}),
#  'Negative electrode volume-averaged velocity [m.s-1]': FullBroadcast(0x73d4eabb242e37ab, broadcast, children=['0.0'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Negative electrode volume-averaged acceleration [m.s-2]': FullBroadcast(0x73d4eabb242e37ab, broadcast, children=['0.0'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrode volume-averaged acceleration [m.s-2]': PrimaryBroadcast(0x5311a8eb06f4e2f6, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'Negative electrode pressure [Pa]': FullBroadcast(0x73d4eabb242e37ab, broadcast, children=['0.0'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrode pressure [Pa]': PrimaryBroadcast(0x5311a8eb06f4e2f6, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'Positive electrode volume-averaged velocity [m.s-1]': FullBroadcast(-0x5d8f24b06e2cb9b6, broadcast, children=['0.0'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Positive electrode volume-averaged acceleration [m.s-2]': FullBroadcast(-0x5d8f24b06e2cb9b6, broadcast, children=['0.0'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrode volume-averaged acceleration [m.s-2]': PrimaryBroadcast(0x5311a8eb06f4e2f6, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'Positive electrode pressure [Pa]': FullBroadcast(-0x5d8f24b06e2cb9b6, broadcast, children=['0.0'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrode pressure [Pa]': PrimaryBroadcast(0x5311a8eb06f4e2f6, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'Total negative electrode interfacial current density variable [A.m-2]': Variable(0x3512ff7a5c8eb57e, Total negative electrode interfacial current density variable [A.m-2], children=[], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged total negative electrode interfacial current density variable [A.m-2]': XAverage(-0x16ac46b08eaafb39, x-average, children=['Total negative electrode interfacial current density variable [A.m-2]'], domains={'primary': ['current collector']}),
#  'Total positive electrode interfacial current density variable [A.m-2]': Variable(0x3d1f6b34fae34dd, Total positive electrode interfacial current density variable [A.m-2], children=[], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged total positive electrode interfacial current density variable [A.m-2]': XAverage(0x64b197e3f050812f, x-average, children=['Total positive electrode interfacial current density variable [A.m-2]'], domains={'primary': ['current collector']}),
#  'Negative particle concentration [mol.m-3]': Variable(0x2dc77cc36d0cd7d3, Negative particle concentration [mol.m-3], children=[], domains={'primary': ['negative particle'], 'secondary': ['negative electrode'], 'tertiary': ['current collector']}),
#  'X-averaged negative particle concentration [mol.m-3]': XAverage(0x7799f3fbc5dffc76, x-average, children=['Negative particle concentration [mol.m-3]'], domains={'primary': ['negative particle'], 'secondary': ['current collector']}),
#  'R-averaged negative particle concentration [mol.m-3]': RAverage(-0x3fb16deb79cf19c4, r-average, children=['Negative particle concentration [mol.m-3]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Average negative particle concentration [mol.m-3]': RAverage(-0x640ab5283f25a892, r-average, children=['x-average(Negative particle concentration [mol.m-3])'], domains={'primary': ['current collector']}),
#  'Negative particle surface concentration [mol.m-3]': BoundaryValue(-0x7895aa3aa5b1c73, boundary value, children=['Negative particle concentration [mol.m-3]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative particle surface concentration [mol.m-3]': XAverage(-0x35ab445a62b55dd1, x-average, children=['boundary value(Negative particle concentration [mol.m-3])'], domains={'primary': ['current collector']}),
#  'Minimum negative particle concentration [mol.m-3]': Min(-0x4dc1ff905623a52, function (min), children=['Negative particle concentration [mol.m-3]'], domains={'primary': ['negative particle'], 'secondary': ['negative electrode'], 'tertiary': ['current collector']}),
#  'Maximum negative particle concentration [mol.m-3]': Max(-0x743f7feb0f2c250b, function (max), children=['Negative particle concentration [mol.m-3]'], domains={'primary': ['negative particle'], 'secondary': ['negative electrode'], 'tertiary': ['current collector']}),
#  'Minimum negative particle Minimum negative particle surface concentration [mol.m-3]': Min(-0x6962e5cdbac4866b, function (min), children=['boundary value(Negative particle concentration [mol.m-3])'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Maximum negative particle surface concentration [mol.m-3]': Max(0x16ee6ecbc6b50f49, function (max), children=['boundary value(Negative particle concentration [mol.m-3])'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Negative particle concentration': Division(0x75001223e3c850fd, /, children=['Negative particle concentration [mol.m-3]', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative particle'], 'secondary': ['negative electrode'], 'tertiary': ['current collector']}),
#  'X-averaged negative particle concentration': Division(-0x4f35dc704c6852c4, /, children=['x-average(Negative particle concentration [mol.m-3])', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative particle'], 'secondary': ['current collector']}),
#  'R-averaged negative particle concentration': Division(-0x44bbf6e4eeca9b7, /, children=['r-average(Negative particle concentration [mol.m-3])', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Average negative particle concentration': Division(0x178bc122dddee698, /, children=['r-average(x-average(Negative particle concentration [mol.m-3]))', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['current collector']}),
#  'Negative particle surface concentration': Division(-0x69bd91a3fb5070aa, /, children=['boundary value(Negative particle concentration [mol.m-3])', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative particle surface concentration': Division(-0x457745044f8c1317, /, children=['x-average(boundary value(Negative particle concentration [mol.m-3]))', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['current collector']}),
#  'Minimum negative particle concentration': Division(-0xc56fbbd5b7ae3ea, /, children=['min(Negative particle concentration [mol.m-3])', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative particle'], 'secondary': ['negative electrode'], 'tertiary': ['current collector']}),
#  'Maximum negative particle concentration': Division(-0xb1654086bccfdbd, /, children=['max(Negative particle concentration [mol.m-3])', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative particle'], 'secondary': ['negative electrode'], 'tertiary': ['current collector']}),
#  'Minimum negative particle surface concentration': Division(-0x45ffd154a616f63a, /, children=['min(boundary value(Negative particle concentration [mol.m-3]))', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Maximum negative particle surface concentration': Division(0x5c81bd4676dbe051, /, children=['max(boundary value(Negative particle concentration [mol.m-3]))', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Negative particle stoichiometry': Division(0x75001223e3c850fd, /, children=['Negative particle concentration [mol.m-3]', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative particle'], 'secondary': ['negative electrode'], 'tertiary': ['current collector']}),
#  'X-averaged negative particle stoichiometry': Division(-0x4f35dc704c6852c4, /, children=['x-average(Negative particle concentration [mol.m-3])', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative particle'], 'secondary': ['current collector']}),
#  'R-averaged negative particle stoichiometry': Division(-0x44bbf6e4eeca9b7, /, children=['r-average(Negative particle concentration [mol.m-3])', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Average negative particle stoichiometry': Division(0x178bc122dddee698, /, children=['r-average(x-average(Negative particle concentration [mol.m-3]))', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['current collector']}),
#  'Negative particle surface stoichiometry': Division(-0x69bd91a3fb5070aa, /, children=['boundary value(Negative particle concentration [mol.m-3])', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative particle surface stoichiometry': Division(-0x457745044f8c1317, /, children=['x-average(boundary value(Negative particle concentration [mol.m-3]))', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['current collector']}),
#  'Minimum negative particle stoichiometry': Division(-0xc56fbbd5b7ae3ea, /, children=['min(Negative particle concentration [mol.m-3])', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative particle'], 'secondary': ['negative electrode'], 'tertiary': ['current collector']}),
#  'Maximum negative particle stoichiometry': Division(-0xb1654086bccfdbd, /, children=['max(Negative particle concentration [mol.m-3])', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative particle'], 'secondary': ['negative electrode'], 'tertiary': ['current collector']}),
#  'Minimum negative particle surface stoichiometry': Division(-0x45ffd154a616f63a, /, children=['min(boundary value(Negative particle concentration [mol.m-3]))', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Maximum negative particle surface stoichiometry': Division(0x5c81bd4676dbe051, /, children=['max(boundary value(Negative particle concentration [mol.m-3]))', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Negative electrode extent of lithiation': Division(-0x44bbf6e4eeca9b7, /, children=['r-average(Negative particle concentration [mol.m-3])', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrode extent of lithiation': Division(0x178bc122dddee698, /, children=['r-average(x-average(Negative particle concentration [mol.m-3]))', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['current collector']}),
#  'Positive particle concentration [mol.m-3]': Variable(-0x26f40dc7782bf9d4, Positive particle concentration [mol.m-3], children=[], domains={'primary': ['positive particle'], 'secondary': ['positive electrode'], 'tertiary': ['current collector']}),
#  'X-averaged positive particle concentration [mol.m-3]': XAverage(0x6e89debf27a25843, x-average, children=['Positive particle concentration [mol.m-3]'], domains={'primary': ['positive particle'], 'secondary': ['current collector']}),
#  'R-averaged positive particle concentration [mol.m-3]': RAverage(0x72d950f9bc901839, r-average, children=['Positive particle concentration [mol.m-3]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Average positive particle concentration [mol.m-3]': RAverage(0x7b69dde1cee9d7db, r-average, children=['x-average(Positive particle concentration [mol.m-3])'], domains={'primary': ['current collector']}),
#  'Positive particle surface concentration [mol.m-3]': BoundaryValue(0x61bbc77097a9d860, boundary value, children=['Positive particle concentration [mol.m-3]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive particle surface concentration [mol.m-3]': XAverage(0xc1ca1347f643ae0, x-average, children=['boundary value(Positive particle concentration [mol.m-3])'], domains={'primary': ['current collector']}),
#  'Minimum positive particle concentration [mol.m-3]': Min(0x18fc17a13c54f45c, function (min), children=['Positive particle concentration [mol.m-3]'], domains={'primary': ['positive particle'], 'secondary': ['positive electrode'], 'tertiary': ['current collector']}),
#  'Maximum positive particle concentration [mol.m-3]': Max(0x4d31f26143f7d51e, function (max), children=['Positive particle concentration [mol.m-3]'], domains={'primary': ['positive particle'], 'secondary': ['positive electrode'], 'tertiary': ['current collector']}),
#  'Minimum positive particle Minimum positive particle surface concentration [mol.m-3]': Min(0xbc35be325250c0d, function (min), children=['boundary value(Positive particle concentration [mol.m-3])'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Maximum positive particle surface concentration [mol.m-3]': Max(0x4f0a95c0269ea1c1, function (max), children=['boundary value(Positive particle concentration [mol.m-3])'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Positive particle concentration': Division(0x6668ef0e7fac9b94, /, children=['Positive particle concentration [mol.m-3]', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive particle'], 'secondary': ['positive electrode'], 'tertiary': ['current collector']}),
#  'X-averaged positive particle concentration': Division(-0x7cde42bc4e8d6ddf, /, children=['x-average(Positive particle concentration [mol.m-3])', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive particle'], 'secondary': ['current collector']}),
#  'R-averaged positive particle concentration': Division(-0x75b5b85e4e3c33d4, /, children=['r-average(Positive particle concentration [mol.m-3])', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Average positive particle concentration': Division(-0x1eae593eb278ed39, /, children=['r-average(x-average(Positive particle concentration [mol.m-3]))', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['current collector']}),
#  'Positive particle surface concentration': Division(-0x64967882389f1b61, /, children=['boundary value(Positive particle concentration [mol.m-3])', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive particle surface concentration': Division(-0x7a8b1a8695bf0a3b, /, children=['x-average(boundary value(Positive particle concentration [mol.m-3]))', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['current collector']}),
#  'Minimum positive particle concentration': Division(-0x7cb2a52846d28906, /, children=['min(Positive particle concentration [mol.m-3])', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive particle'], 'secondary': ['positive electrode'], 'tertiary': ['current collector']}),
#  'Maximum positive particle concentration': Division(0x3d751ce99200a9a0, /, children=['max(Positive particle concentration [mol.m-3])', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive particle'], 'secondary': ['positive electrode'], 'tertiary': ['current collector']}),
#  'Minimum positive particle surface concentration': Division(0x5e39ddb73836abd, /, children=['min(boundary value(Positive particle concentration [mol.m-3]))', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Maximum positive particle surface concentration': Division(-0x165743164f47b761, /, children=['max(boundary value(Positive particle concentration [mol.m-3]))', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Positive particle stoichiometry': Division(0x6668ef0e7fac9b94, /, children=['Positive particle concentration [mol.m-3]', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive particle'], 'secondary': ['positive electrode'], 'tertiary': ['current collector']}),
#  'X-averaged positive particle stoichiometry': Division(-0x7cde42bc4e8d6ddf, /, children=['x-average(Positive particle concentration [mol.m-3])', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive particle'], 'secondary': ['current collector']}),
#  'R-averaged positive particle stoichiometry': Division(-0x75b5b85e4e3c33d4, /, children=['r-average(Positive particle concentration [mol.m-3])', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Average positive particle stoichiometry': Division(-0x1eae593eb278ed39, /, children=['r-average(x-average(Positive particle concentration [mol.m-3]))', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['current collector']}),
#  'Positive particle surface stoichiometry': Division(-0x64967882389f1b61, /, children=['boundary value(Positive particle concentration [mol.m-3])', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive particle surface stoichiometry': Division(-0x7a8b1a8695bf0a3b, /, children=['x-average(boundary value(Positive particle concentration [mol.m-3]))', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['current collector']}),
#  'Minimum positive particle stoichiometry': Division(-0x7cb2a52846d28906, /, children=['min(Positive particle concentration [mol.m-3])', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive particle'], 'secondary': ['positive electrode'], 'tertiary': ['current collector']}),
#  'Maximum positive particle stoichiometry': Division(0x3d751ce99200a9a0, /, children=['max(Positive particle concentration [mol.m-3])', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive particle'], 'secondary': ['positive electrode'], 'tertiary': ['current collector']}),
#  'Minimum positive particle surface stoichiometry': Division(0x5e39ddb73836abd, /, children=['min(boundary value(Positive particle concentration [mol.m-3]))', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Maximum positive particle surface stoichiometry': Division(-0x165743164f47b761, /, children=['max(boundary value(Positive particle concentration [mol.m-3]))', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Positive electrode extent of lithiation': Division(-0x75b5b85e4e3c33d4, /, children=['r-average(Positive particle concentration [mol.m-3])', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrode extent of lithiation': Division(-0x1eae593eb278ed39, /, children=['r-average(x-average(Positive particle concentration [mol.m-3]))', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['current collector']}),
#  'Negative electrode potential [V]': Variable(-0x2be3e2173e37a16f, Negative electrode potential [V], children=[], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrode potential [V]': XAverage(0x9d123648b428dae, x-average, children=['Negative electrode potential [V]'], domains={'primary': ['current collector']}),
#  'Negative electrode ohmic losses [V]': Subtraction(-0x6ddc9fb34f787c56, -, children=['broadcast(boundary value(Negative electrode potential [V]))', 'Negative electrode potential [V]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrode ohmic losses [V]': Subtraction(0x6bc05f4227de1490, -, children=['boundary value(Negative electrode potential [V])', 'x-average(Negative electrode potential [V])'], domains={'primary': ['current collector']}),
#  'Gradient of negative electrode potential [V.m-1]': Gradient(-0x7ae8dc8c1574364e, grad, children=['Negative electrode potential [V]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Positive electrode potential [V]': Variable(-0x69caf94414931f7c, Positive electrode potential [V], children=[], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrode potential [V]': XAverage(0x3d5f473e54d6e20d, x-average, children=['Positive electrode potential [V]'], domains={'primary': ['current collector']}),
#  'Positive electrode ohmic losses [V]': Subtraction(0x3f388443d95c2ce7, -, children=['broadcast(boundary value(Positive electrode potential [V]))', 'Positive electrode potential [V]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrode ohmic losses [V]': Subtraction(0x4d6770effad4616b, -, children=['boundary value(Positive electrode potential [V])', 'x-average(Positive electrode potential [V])'], domains={'primary': ['current collector']}),
#  'Gradient of positive electrode potential [V.m-1]': Gradient(-0x7206ee0fbc6434e4, grad, children=['Positive electrode potential [V]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Porosity times concentration [mol.m-3]': ConcatenationVariable(0x3aafc3c155d65ba3, Porosity times concentration [mol.m-3], children=['Negative electrode porosity times concentration [mol.m-3]', 'Separator porosity times concentration [mol.m-3]', 'Positive electrode porosity times concentration [mol.m-3]'], domains={'primary': ['negative electrode', 'separator', 'positive electrode'], 'secondary': ['current collector']}),
#  'Negative electrode porosity times concentration [mol.m-3]': Variable(0x3f49e545afc0c96e, Negative electrode porosity times concentration [mol.m-3], children=[], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Separator porosity times concentration [mol.m-3]': Variable(0x262db3d94d6cf56c, Separator porosity times concentration [mol.m-3], children=[], domains={'primary': ['separator'], 'secondary': ['current collector']}),
#  'Positive electrode porosity times concentration [mol.m-3]': Variable(0x2e2a267902b990bc, Positive electrode porosity times concentration [mol.m-3], children=[], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Total lithium in electrolyte [mol]': Multiplication(-0x4016181730ef9ea3, *, children=['(Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]) * Electrode width [m] * Electrode height [m]', 'yz-average(x-average(Porosity times concentration [mol.m-3](Negative electrode porosity times concentration [mol.m-3], Separator porosity times concentration [mol.m-3], Positive electrode porosity times concentration [mol.m-3])))'], domains={}),
#  'Electrolyte potential [V]': ConcatenationVariable(0xb4a465e324a6619, Electrolyte potential [V], children=['Negative electrolyte potential [V]', 'Separator electrolyte potential [V]', 'Positive electrolyte potential [V]'], domains={'primary': ['negative electrode', 'separator', 'positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged electrolyte potential [V]': XAverage(-0x2da76023a56f6965, x-average, children=['Electrolyte potential [V](Negative electrolyte potential [V], Separator electrolyte potential [V], Positive electrolyte potential [V])'], domains={'primary': ['current collector']}),
#  'X-averaged electrolyte overpotential [V]': Subtraction(0x45707754b8f50d98, -, children=['x-average(Positive electrolyte potential [V])', 'x-average(Negative electrolyte potential [V])'], domains={'primary': ['current collector']}),
#  'Gradient of electrolyte potential [V.m-1]': Gradient(-0x40cab0453ddb8fb9, grad, children=['Electrolyte potential [V](Negative electrolyte potential [V], Separator electrolyte potential [V], Positive electrolyte potential [V])'], domains={'primary': ['negative electrode', 'separator', 'positive electrode'], 'secondary': ['current collector']}),
#  'Negative electrolyte potential [V]': Variable(-0x10524889149720b2, Negative electrolyte potential [V], children=[], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrolyte potential [V]': XAverage(0x708ed8c98a231cda, x-average, children=['Negative electrolyte potential [V]'], domains={'primary': ['current collector']}),
#  'Gradient of negative electrolyte potential [V.m-1]': Gradient(-0x29eea38437a19e01, grad, children=['Negative electrolyte potential [V]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Separator electrolyte potential [V]': Variable(0x1234f8570388f603, Separator electrolyte potential [V], children=[], domains={'primary': ['separator'], 'secondary': ['current collector']}),
#  'X-averaged separator electrolyte potential [V]': XAverage(0x484dc94e3ae51f02, x-average, children=['Separator electrolyte potential [V]'], domains={'primary': ['current collector']}),
#  'Gradient of separator electrolyte potential [V.m-1]': Gradient(-0x39b457858db4f185, grad, children=['Separator electrolyte potential [V]'], domains={'primary': ['separator'], 'secondary': ['current collector']}),
#  'Positive electrolyte potential [V]': Variable(0x749c140b6bb540af, Positive electrolyte potential [V], children=[], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrolyte potential [V]': XAverage(0x61c7b1117f88637b, x-average, children=['Positive electrolyte potential [V]'], domains={'primary': ['current collector']}),
#  'Gradient of positive electrolyte potential [V.m-1]': Gradient(-0x21530825b34dd2da, grad, children=['Positive electrolyte potential [V]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Ambient temperature [K]': FunctionParameter(-0x2b5840066ebb1e52, Ambient temperature [K], children=['y', 'z', 'time'], domains={'primary': ['current collector']}),
#  'Volume-averaged ambient temperature [K]': ZAverage(0x79f8741d3a686a85, z-average, children=['Ambient temperature [K]'], domains={}),
#  'Cell temperature [K]': PrimaryBroadcast(0x27d56357c1ce7ff, broadcast, children=['broadcast(Volume-averaged cell temperature [K])'], domains={'primary': ['negative electrode', 'separator', 'positive electrode'], 'secondary': ['current collector']}),
#  'Negative current collector temperature [K]': PrimaryBroadcast(0x20048ece8b565a51, broadcast, children=['Volume-averaged cell temperature [K]'], domains={'primary': ['current collector']}),
#  'Positive current collector temperature [K]': PrimaryBroadcast(0x20048ece8b565a51, broadcast, children=['Volume-averaged cell temperature [K]'], domains={'primary': ['current collector']}),
#  'X-averaged cell temperature [K]': PrimaryBroadcast(0x20048ece8b565a51, broadcast, children=['Volume-averaged cell temperature [K]'], domains={'primary': ['current collector']}),
#  'Volume-averaged cell temperature [K]': Variable(-0x6d74ac66193b17fe, Volume-averaged cell temperature [K], children=[], domains={}),
#  'Negative electrode temperature [K]': PrimaryBroadcast(0x79e27ec3aa3fc74f, broadcast, children=['broadcast(Volume-averaged cell temperature [K])'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrode temperature [K]': PrimaryBroadcast(0x20048ece8b565a51, broadcast, children=['Volume-averaged cell temperature [K]'], domains={'primary': ['current collector']}),
#  'Separator temperature [K]': PrimaryBroadcast(-0x6e5f8b6456d8c8e, broadcast, children=['broadcast(Volume-averaged cell temperature [K])'], domains={'primary': ['separator'], 'secondary': ['current collector']}),
#  'X-averaged separator temperature [K]': PrimaryBroadcast(0x20048ece8b565a51, broadcast, children=['Volume-averaged cell temperature [K]'], domains={'primary': ['current collector']}),
#  'Positive electrode temperature [K]': PrimaryBroadcast(-0x4504939c981b62a4, broadcast, children=['broadcast(Volume-averaged cell temperature [K])'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrode temperature [K]': PrimaryBroadcast(0x20048ece8b565a51, broadcast, children=['Volume-averaged cell temperature [K]'], domains={'primary': ['current collector']}),
#  'Ambient temperature [C]': Addition(-0x1de8eea3728b3370, +, children=['-273.15', 'Ambient temperature [K]'], domains={'primary': ['current collector']}),
#  'Volume-averaged ambient temperature [C]': Addition(-0x356f974b9f6c7544, +, children=['-273.15', 'z-average(Ambient temperature [K])'], domains={}),
#  'Cell temperature [C]': PrimaryBroadcast(0x3b78b3ef8160614a, broadcast, children=['broadcast(-273.15 + Volume-averaged cell temperature [K])'], domains={'primary': ['negative electrode', 'separator', 'positive electrode'], 'secondary': ['current collector']}),
#  'Negative current collector temperature [C]': PrimaryBroadcast(0xc9ca0005176520d, broadcast, children=['-273.15 + Volume-averaged cell temperature [K]'], domains={'primary': ['current collector']}),
#  'Positive current collector temperature [C]': PrimaryBroadcast(0xc9ca0005176520d, broadcast, children=['-273.15 + Volume-averaged cell temperature [K]'], domains={'primary': ['current collector']}),
#  'X-averaged cell temperature [C]': PrimaryBroadcast(0xc9ca0005176520d, broadcast, children=['-273.15 + Volume-averaged cell temperature [K]'], domains={'primary': ['current collector']}),
#  'Volume-averaged cell temperature [C]': Addition(0x659bf4fb12355e3, +, children=['-273.15', 'Volume-averaged cell temperature [K]'], domains={}),
#  'Negative electrode temperature [C]': PrimaryBroadcast(-0x34b12b749da5eef7, broadcast, children=['broadcast(-273.15 + Volume-averaged cell temperature [K])'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrode temperature [C]': PrimaryBroadcast(0xc9ca0005176520d, broadcast, children=['-273.15 + Volume-averaged cell temperature [K]'], domains={'primary': ['current collector']}),
#  'Separator temperature [C]': PrimaryBroadcast(-0x786f88320d5342d4, broadcast, children=['broadcast(-273.15 + Volume-averaged cell temperature [K])'], domains={'primary': ['separator'], 'secondary': ['current collector']}),
#  'X-averaged separator temperature [C]': PrimaryBroadcast(0xc9ca0005176520d, broadcast, children=['-273.15 + Volume-averaged cell temperature [K]'], domains={'primary': ['current collector']}),
#  'Positive electrode temperature [C]': PrimaryBroadcast(0x4971dce79ffee716, broadcast, children=['broadcast(-273.15 + Volume-averaged cell temperature [K])'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrode temperature [C]': PrimaryBroadcast(0xc9ca0005176520d, broadcast, children=['-273.15 + Volume-averaged cell temperature [K]'], domains={'primary': ['current collector']}),
#  'Negative current collector potential [V]': PrimaryBroadcast(0x5311a8eb06f4e2f6, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'Negative inner SEI thickness [m]': Variable(0x454c65fabd8f8c6c, Negative inner SEI thickness [m], children=[], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Negative outer SEI thickness [m]': Variable(0x7c2da63ab3c9aec6, Negative outer SEI thickness [m], children=[], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative inner SEI thickness [m]': XAverage(-0x4fe1d83a3df49b8d, x-average, children=['Negative inner SEI thickness [m]'], domains={'primary': ['current collector']}),
#  'X-averaged negative outer SEI thickness [m]': XAverage(0x40ad0ab953ab2b30, x-average, children=['Negative outer SEI thickness [m]'], domains={'primary': ['current collector']}),
#  'Negative SEI [m]': Addition(-0x24a49da26b95ed82, +, children=['Negative inner SEI thickness [m]', 'Negative outer SEI thickness [m]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Negative total SEI thickness [m]': Addition(-0x24a49da26b95ed82, +, children=['Negative inner SEI thickness [m]', 'Negative outer SEI thickness [m]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative SEI thickness [m]': Addition(0x47a06fab504d7fab, +, children=['x-average(Negative inner SEI thickness [m])', 'x-average(Negative outer SEI thickness [m])'], domains={'primary': ['current collector']}),
#  'X-averaged negative total SEI thickness [m]': Addition(0x47a06fab504d7fab, +, children=['x-average(Negative inner SEI thickness [m])', 'x-average(Negative outer SEI thickness [m])'], domains={'primary': ['current collector']}),
#  'X-averaged negative electrode resistance [Ohm.m2]': Multiplication(-0x6fc0c6e5f0734f0b, *, children=['x-average(Negative inner SEI thickness [m]) + x-average(Negative outer SEI thickness [m])', 'SEI resistivity [Ohm.m]'], domains={'primary': ['current collector']}),
#  'Positive inner SEI thickness [m]': FullBroadcast(-0x5d8f24b06e2cb9b6, broadcast, children=['0.0'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Positive outer SEI thickness [m]': FullBroadcast(-0x5d8f24b06e2cb9b6, broadcast, children=['0.0'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive inner SEI thickness [m]': PrimaryBroadcast(0x5311a8eb06f4e2f6, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'X-averaged positive outer SEI thickness [m]': PrimaryBroadcast(0x5311a8eb06f4e2f6, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'Positive SEI [m]': FullBroadcast(-0x5d8f24b06e2cb9b6, broadcast, children=['0.0'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
# ...
#  'Loss of lithium inventory [%]': Subtraction(0x56c2753771a2d976, -, children=['100.0', '100.0 * (yz-average(x-average(Negative electrode active material volume fraction * r-average(Negative particle concentration [mol.m-3]))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] + yz-average(x-average(Positive electrode active material volume fraction * r-average(Positive particle concentration [mol.m-3]))) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m]) / (yz-average(x-average(Negative electrode active material volume fraction * r-average(Initial concentration in negative electrode [mol.m-3]))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] + yz-average(x-average(Positive electrode active material volume fraction * r-average(Initial concentration in positive electrode [mol.m-3]))) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m])'], domains={}),
#  'Loss of lithium inventory, including electrolyte [%]': Subtraction(-0x5128ef6fdd8e6c9e, -, children=['100.0', '100.0 * (yz-average(x-average(Negative electrode active material volume fraction * r-average(Negative particle concentration [mol.m-3]))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] + yz-average(x-average(Positive electrode active material volume fraction * r-average(Positive particle concentration [mol.m-3]))) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m] + (Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]) * Electrode width [m] * Electrode height [m] * yz-average(x-average(Porosity times concentration [mol.m-3](Negative electrode porosity times concentration [mol.m-3], Separator porosity times concentration [mol.m-3], Positive electrode porosity times concentration [mol.m-3])))) / (yz-average(x-average(Negative electrode active material volume fraction * r-average(Initial concentration in negative electrode [mol.m-3]))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] + yz-average(x-average(Positive electrode active material volume fraction * r-average(Initial concentration in positive electrode [mol.m-3]))) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m] + yz-average((Negative electrode thickness [m] * x-average(Negative electrode porosity) + Separator thickness [m] * x-average(Separator porosity) + Positive electrode thickness [m] * x-average(Positive electrode porosity)) / (Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m])) * Initial concentration in electrolyte [mol.m-3] * (Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]) * Electrode width [m] * Electrode height [m])'], domains={}),
#  'Total lithium [mol]': Addition(-0x393b5e0e82647b1d, +, children=['yz-average(x-average(Negative electrode active material volume fraction * r-average(Negative particle concentration [mol.m-3]))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] + yz-average(x-average(Positive electrode active material volume fraction * r-average(Positive particle concentration [mol.m-3]))) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m]', '(Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]) * Electrode width [m] * Electrode height [m] * yz-average(x-average(Porosity times concentration [mol.m-3](Negative electrode porosity times concentration [mol.m-3], Separator porosity times concentration [mol.m-3], Positive electrode porosity times concentration [mol.m-3])))'], domains={}),
#  'Total lithium in particles [mol]': Addition(-0x26cbbbce5d875c46, +, children=['yz-average(x-average(Negative electrode active material volume fraction * r-average(Negative particle concentration [mol.m-3]))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m]', 'yz-average(x-average(Positive electrode active material volume fraction * r-average(Positive particle concentration [mol.m-3]))) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m]'], domains={}),
#  'Total lithium capacity [A.h]': Multiplication(0x29399a250bbdf684, *, children=['0.0002777777777777778', '(yz-average(x-average(Negative electrode active material volume fraction * r-average(Negative particle concentration [mol.m-3]))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] + yz-average(x-average(Positive electrode active material volume fraction * r-average(Positive particle concentration [mol.m-3]))) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m] + (Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]) * Electrode width [m] * Electrode height [m] * yz-average(x-average(Porosity times concentration [mol.m-3](Negative electrode porosity times concentration [mol.m-3], Separator porosity times concentration [mol.m-3], Positive electrode porosity times concentration [mol.m-3])))) * Faraday constant [C.mol-1]'], domains={}),
#  'Total lithium capacity in particles [A.h]': Multiplication(-0x3b7e8420eeeffc4d, *, children=['0.0002777777777777778', '(yz-average(x-average(Negative electrode active material volume fraction * r-average(Negative particle concentration [mol.m-3]))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] + yz-average(x-average(Positive electrode active material volume fraction * r-average(Positive particle concentration [mol.m-3]))) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m]) * Faraday constant [C.mol-1]'], domains={}),
#  'Total lithium lost [mol]': Subtraction(0x3e32612aaa40bb72, -, children=['yz-average(x-average(Negative electrode active material volume fraction * r-average(Initial concentration in negative electrode [mol.m-3]))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] + yz-average(x-average(Positive electrode active material volume fraction * r-average(Initial concentration in positive electrode [mol.m-3]))) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m] + yz-average((Negative electrode thickness [m] * x-average(Negative electrode porosity) + Separator thickness [m] * x-average(Separator porosity) + Positive electrode thickness [m] * x-average(Positive electrode porosity)) / (Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m])) * Initial concentration in electrolyte [mol.m-3] * (Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]) * Electrode width [m] * Electrode height [m]', 'yz-average(x-average(Negative electrode active material volume fraction * r-average(Negative particle concentration [mol.m-3]))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] + yz-average(x-average(Positive electrode active material volume fraction * r-average(Positive particle concentration [mol.m-3]))) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m] + (Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]) * Electrode width [m] * Electrode height [m] * yz-average(x-average(Porosity times concentration [mol.m-3](Negative electrode porosity times concentration [mol.m-3], Separator porosity times concentration [mol.m-3], Positive electrode porosity times concentration [mol.m-3])))'], domains={}),
#  'Total lithium lost from particles [mol]': Subtraction(0x75116b1e9b4cc883, -, children=['yz-average(x-average(Negative electrode active material volume fraction * r-average(Initial concentration in negative electrode [mol.m-3]))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] + yz-average(x-average(Positive electrode active material volume fraction * r-average(Initial concentration in positive electrode [mol.m-3]))) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m]', 'yz-average(x-average(Negative electrode active material volume fraction * r-average(Negative particle concentration [mol.m-3]))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] + yz-average(x-average(Positive electrode active material volume fraction * r-average(Positive particle concentration [mol.m-3]))) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m]'], domains={}),
#  'Total lithium lost from electrolyte [mol]': Subtraction(0x6a975b7e3e9005e0, -, children=['yz-average((Negative electrode thickness [m] * x-average(Negative electrode porosity) + Separator thickness [m] * x-average(Separator porosity) + Positive electrode thickness [m] * x-average(Positive electrode porosity)) / (Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m])) * Initial concentration in electrolyte [mol.m-3] * (Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]) * Electrode width [m] * Electrode height [m]', '(Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]) * Electrode width [m] * Electrode height [m] * yz-average(x-average(Porosity times concentration [mol.m-3](Negative electrode porosity times concentration [mol.m-3], Separator porosity times concentration [mol.m-3], Positive electrode porosity times concentration [mol.m-3])))'], domains={}),
#  'Total lithium lost to side reactions [mol]': Addition(-0x5129e989431f3321, +, children=['Ratio of lithium moles to SEI moles * (yz-average(x-average(Negative inner SEI thickness [m] * 3.0 * Negative electrode active material volume fraction / Negative particle radius [m] / Inner SEI partial molar volume [m3.mol-1])) + yz-average(x-average(Negative outer SEI thickness [m] * 3.0 * Negative electrode active material volume fraction / Negative particle radius [m] / Outer SEI partial molar volume [m3.mol-1])) - (Initial inner SEI thickness [m] * 3.0 * yz-average(x-average(Negative electrode active material volume fraction)) / Negative particle radius [m] / Inner SEI partial molar volume [m3.mol-1] + Initial outer SEI thickness [m] * 3.0 * yz-average(x-average(Negative electrode active material volume fraction)) / Negative particle radius [m] / Outer SEI partial molar volume [m3.mol-1])) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m]', 'Ratio of lithium moles to SEI moles * (yz-average(x-average(Negative inner SEI on cracks thickness [m] * 3.0 * Negative electrode active material volume fraction / Negative particle radius [m] / Inner SEI partial molar volume [m3.mol-1] * 2.0 * Negative particle crack length [m] * Negative electrode number of cracks per unit area [m-2] * Negative electrode initial crack width [m])) + yz-average(x-average(Negative outer SEI on cracks thickness [m] * 3.0 * Negative electrode active material volume fraction / Negative particle radius [m] / Outer SEI partial molar volume [m3.mol-1] * 2.0 * Negative particle crack length [m] * Negative electrode number of cracks per unit area [m-2] * Negative electrode initial crack width [m])) - ((Initial inner SEI on cracks thickness [m] * 3.0 * yz-average(x-average(Negative electrode active material volume fraction)) / Negative particle radius [m] / Inner SEI partial molar volume [m3.mol-1] + Initial outer SEI on cracks thickness [m] * 3.0 * yz-average(x-average(Negative electrode active material volume fraction)) / Negative particle radius [m] / Outer SEI partial molar volume [m3.mol-1]) * yz-average(x-average(2.0 * Negative particle crack length [m] * Negative electrode number of cracks per unit area [m-2] * Negative electrode initial crack width [m])))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] + x-average(Negative lithium plating concentration [mol.m-3]) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] + x-average(Negative dead lithium concentration [mol.m-3]) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m]'], domains={'primary': ['current collector']}),
#  'Total capacity lost to side reactions [A.h]': Multiplication(-0x35ee2dfc1d85b23d, *, children=['0.0002777777777777778', '(Ratio of lithium moles to SEI moles * (yz-average(x-average(Negative inner SEI thickness [m] * 3.0 * Negative electrode active material volume fraction / Negative particle radius [m] / Inner SEI partial molar volume [m3.mol-1])) + yz-average(x-average(Negative outer SEI thickness [m] * 3.0 * Negative electrode active material volume fraction / Negative particle radius [m] / Outer SEI partial molar volume [m3.mol-1])) - (Initial inner SEI thickness [m] * 3.0 * yz-average(x-average(Negative electrode active material volume fraction)) / Negative particle radius [m] / Inner SEI partial molar volume [m3.mol-1] + Initial outer SEI thickness [m] * 3.0 * yz-average(x-average(Negative electrode active material volume fraction)) / Negative particle radius [m] / Outer SEI partial molar volume [m3.mol-1])) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] + Ratio of lithium moles to SEI moles * (yz-average(x-average(Negative inner SEI on cracks thickness [m] * 3.0 * Negative electrode active material volume fraction / Negative particle radius [m] / Inner SEI partial molar volume [m3.mol-1] * 2.0 * Negative particle crack length [m] * Negative electrode number of cracks per unit area [m-2] * Negative electrode initial crack width [m])) + yz-average(x-average(Negative outer SEI on cracks thickness [m] * 3.0 * Negative electrode active material volume fraction / Negative particle radius [m] / Outer SEI partial molar volume [m3.mol-1] * 2.0 * Negative particle crack length [m] * Negative electrode number of cracks per unit area [m-2] * Negative electrode initial crack width [m])) - ((Initial inner SEI on cracks thickness [m] * 3.0 * yz-average(x-average(Negative electrode active material volume fraction)) / Negative particle radius [m] / Inner SEI partial molar volume [m3.mol-1] + Initial outer SEI on cracks thickness [m] * 3.0 * yz-average(x-average(Negative electrode active material volume fraction)) / Negative particle radius [m] / Outer SEI partial molar volume [m3.mol-1]) * yz-average(x-average(2.0 * Negative particle crack length [m] * Negative electrode number of cracks per unit area [m-2] * Negative electrode initial crack width [m])))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] + x-average(Negative lithium plating concentration [mol.m-3]) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] + x-average(Negative dead lithium concentration [mol.m-3]) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m]) * Faraday constant [C.mol-1]'], domains={'primary': ['current collector']})}

# %%
cycles_df
# Out:
#              Mode  RelativeTime   Voltage          I        Q_dis     Q_cha  \
# Cycle Step
# 1     1       1.0  0.000000e+00  2.680430  1407.8055     0.000000  0.000078
#       2       1.0  8.400000e-03  2.690530  1574.4427     0.000000  0.003691
#       3       1.0  2.940000e-02  2.700598  1640.2499     0.000000  0.013108
#       4       1.0  6.340000e-02  2.710643  1664.4644     0.000000  0.028749
#       5       1.0  1.074000e-01  2.720645  1668.5892     0.000000  0.049123
# ...           ...           ...       ...        ...          ...       ...
# 105   14017   1.0  1.510170e+06  2.517027 -4997.5547  4461.105642  0.000000
#       14018   1.0  1.510171e+06  2.510488 -4997.8223  4462.493874  0.000000
#       14019   1.0  1.510172e+06  2.503801 -4997.8223  4463.882105  0.000000
#       14020   1.0  1.510173e+06  2.499954 -4997.1729  4464.662006  0.000000
#       14021   1.0  1.510173e+06  2.499981 -4997.4785  4464.662284  0.000000
#
#                      Cap         R    Pressure  Temperature
# Cycle Step
# 1     1         0.000078  1.903978  159.026607      25.3794
#       2         0.003691  1.708878  158.944819      25.3885
#       3         0.013108  1.646455  158.998347      25.4014
#       4         0.028749  1.628537  159.049016      25.4088
#       5         0.049123  1.630506  158.990980      25.4014
# ...                  ...       ...         ...          ...
# 105   14017  4461.105642  0.503652  278.040252      30.8711
#       14018  4462.493874  0.502316  277.965417      30.8656
#       14019  4463.882105  0.500978  277.965771      30.8428
#       14020  4464.662006  0.500274  277.854785      30.8390
#       14021  4464.662284  0.500248  277.859008      30.8190
#
# [1512250 rows x 10 columns]

# %%
# Compare model data to experiment

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(13, 4))

# plot the 1C results
t_sol = sol["Time [s]"].entries


ax1.plot(t_sol, sol["Current variable [A]"](t_sol))
ax1.plot(cycles_df.loc[1]["RelativeTime"],cycles_df.loc[1]["I"]/1000, "o")
ax1.set_xlabel("Time [s]")
ax1.set_ylabel("Voltage [V]")
ax1.set_title("Voltage")
ax1.legend(["Model", "Experiment"], loc="best")


ax2.plot(t_sol, sol["X-averaged cell temperature [C]"](t_sol))
ax2.plot(cycles_df.loc[1]["RelativeTime"],cycles_df.loc[1]["Temperature"], "o")
ax2.set_xlabel("Time [s]")
ax2.set_ylabel("Temperature [degC]")
ax2.set_title("Temperature")
ax2.legend(["Model", "Experiment"], loc="best")

plt.tight_layout()
plt.show()

# %% [markdown]
# 下面是处理源数据的方法

# %%
import os
import pandas as pd
# 读取 CSV 文件
cwd = os.getcwd()
csv_file_path = cwd + '/exp_LG/allData_C7_removefront.csv'
Cell_7 = pd.read_csv(csv_file_path)

# %%
# import os
# import pandas as pd
# # 读取 CSV 文件
# cwd = os.getcwd()
# csv_file_path = cwd + '/docs/source/examples/notebooks/models/exp_LG/allData_C7_removefront.csv'
# Cell_7 = pd.read_csv(csv_file_path)

# %%
# Cell_7['RelativeTime'] = Cell_7['RelativeTime'] - Cell_7['RelativeTime'][0]

# %%
# # 定义存储循环的列表
# cycles = []
# current_cycle = []
# charging = False

# # 遍历 DataFrame，识别循环
# for i, row in Cell_7.iterrows():
#     if row['Q_cha'] > 0 and not charging:
#         # 开始充电
#         charging = True
#         if current_cycle:
#             cycles.append(current_cycle)
#         current_cycle = [row]
#     elif row['Q_dis'] > 0 and charging:
#         # 结束充电，开始放电
#         charging = False
#         current_cycle.append(row)
#     else:
#         # 在当前循环中添加行
#         current_cycle.append(row)

# # 添加最后一个循环
# if current_cycle:
#     cycles.append(current_cycle)

# # 将循环数据转换为带有 MultiIndex 的 DataFrame
# cycle_data = []
# for cycle_num, cycle in enumerate(cycles):
#     for step_num, row in enumerate(cycle):
#         cycle_data.append((cycle_num + 1, step_num + 1, *row.values))

# # 定义多重索引
# multi_index = pd.MultiIndex.from_tuples(
#     [(cycle, step) for cycle, step, *rest in cycle_data],
#     names=['Cycle', 'Step']
# )

# # 定义 DataFrame 列名
# columns = ['Mode', 'RelativeTime', 'Voltage', 'I', 'Q_dis', 'Q_cha', 'Cap', 'R', 'Pressure', 'Temperature']

# # 创建最终的 DataFrame
# cycles_df = pd.DataFrame([rest for cycle, step, *rest in cycle_data], index=multi_index, columns=columns)

# # 打印前几行以验证
# print(cycles_df.head())

# # 示例：访问第一个循环的数据
# cycle_1_data = cycles_df.loc[1]
# print("\nCycle 1 Data:")
# print(cycle_1_data)

# # 示例：访问第一个循环的第一步数据
# cycle_1_step_1_data = cycles_df.loc[(1, 1)]
# print("\nCycle 1 Step 1 Data:")
# print(cycle_1_step_1_data)

# %%
# 将 DataFrame 存储为 pickle 文件
# pickle_file_path = cwd + '/exp_LG/processed_data.pkl'
# cycles_df.to_pickle(pickle_file_path)
# print(f"DataFrame saved to {pickle_file_path}")

# %%
# 将 DataFrame 存储为 pickle 文件
# pickle_file_path = cwd + '/docs/source/examples/notebooks/models/exp_LG/processed_data.pkl'
# cycles_df.to_pickle(pickle_file_path)
# print(f"DataFrame saved to {pickle_file_path}")
