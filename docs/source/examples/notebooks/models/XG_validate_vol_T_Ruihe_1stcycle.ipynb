# %% [markdown]
# To validate battery base model for LG M50, Use revised OKane2022 parameters with parameters used in Paper 1,2
# 1. To validate BoL voltage and thermal response

# %%
import pybamm
import matplotlib.pyplot as plt
import numpy as np
def Overwrite_Initial_L_SEI_0_Neg_Porosity(Para_0,cap_loss):
    """
    This is to overwrite the initial negative electrode porosity
    and initial SEI thickness (inner, outer) to be consistent
    with the initial capacity loss
    """
    delta_Q_SEI = cap_loss * 3600
    V_SEI = Para_0["Negative outer SEI partial molar volume [m3.mol-1]"]
    # do this when finish updating
    F = 96485.3
    A = Para_0["Electrode width [m]"] * Para_0["Electrode height [m]"]
    z_SEI = Para_0["Negative ratio of lithium moles to SEI moles"]
    L_neg = Para_0["Negative electrode thickness [m]"]
    eps_act_neg = Para_0["Negative electrode active material volume fraction"]
    R_neg =   Para_0["Negative particle radius [m]"]
    l_cr_init = Para_0["Negative electrode initial crack length [m]"]
    w_cr = Para_0["Negative electrode initial crack width [m]"]
    rho_cr = Para_0["Negative electrode number of cracks per unit area [m-2]"]
    a_neg = (3 * eps_act_neg / R_neg)
    roughness = 1 + 2 * l_cr_init * w_cr * rho_cr
    L_SEI_init = delta_Q_SEI  * V_SEI / (
        z_SEI * F * A * L_neg * a_neg * roughness)
 
    delta_epi = (L_SEI_init ) * roughness * a_neg
    L_inner_init = L_SEI_init / 2
    epi = 0.25 - delta_epi
    # print(L_inner_init,epi)
    # important: update here!
    Para_0["Negative electrode porosity"] = epi
    Para_0["Negative initial outer SEI thickness [m]"] = L_inner_init + 2.5e-9
    Para_0["Negative initial inner SEI thickness [m]"] = L_inner_init + 2.5e-9
    ## add Xinlei
    Para_0["Initial inner SEI thickness [m]"] = L_inner_init + 2.5e-9
    Para_0["Initial outer SEI thickness [m]"] = L_inner_init + 2.5e-9
    print(f"Has Overwritten Initial outer SEI thickness [m] to be {(L_inner_init+2.5e-9):.2e} and Negative electrode porosity to be {epi:.3f} to account for initial capacity loss of {cap_loss:.3f} Ah")
    print(f"Has Overwritten Initial outer SEI thickness [m] to be {(L_inner_init+2.5e-9):.2e} and Negative electrode porosity to be {epi:.3f} to account for initial capacity loss of {cap_loss:.3f} Ah")
 
    return Para_0

param = pybamm.ParameterValues("OKane2023_Xinlei")

Overwrite_Initial_L_SEI_0_Neg_Porosity(param,0.15)
# Out:
# Has Overwritten Initial outer SEI thickness [m] to be 1.62e-08 and Negative electrode porosity to be 0.219 to account for initial capacity loss of 0.150 Ah
# Has Overwritten Initial outer SEI thickness [m] to be 1.62e-08 and Negative electrode porosity to be 0.219 to account for initial capacity loss of 0.150 Ah
# {'Ambient temperature [K]': 298.15,
#  'Boltzmann constant [J.K-1]': 1.380649e-23,
#  'Bulk solvent concentration [mol.m-3]': 2636.0,
#  'Cation transference number': <function electrolyte_transference_number_EC_EMC_3_7_Landesfeind2019_Constant at 0x7fe7bd5db790>,
#  'Cell cooling surface area [m2]': 0.00531,
#  'Cell thermal expansion coefficient [m.K-1]': 1.1e-06,
#  'Cell volume [m3]': 2.42e-05,
#  'Contact resistance [Ohm]': 0.013,
#  'Current function [A]': 5.0,
#  'Dead lithium decay constant [s-1]': 1e-06,
#  'Dead lithium decay rate [s-1]': <function SEI_limited_dead_lithium_OKane2022 at 0x7fe7bd5cca60>,
#  'EC diffusivity [m2.s-1]': 2e-18,
#  'EC initial concentration in electrolyte [mol.m-3]': 4541.0,
#  'EC partial molar volume [m3.mol-1]': 6.667e-05,
#  'Electrode height [m]': 0.065,
#  'Electrode width [m]': 1.58,
#  'Electrolyte conductivity [S.m-1]': <function electrolyte_conductivity_EC_EMC_3_7_Landesfeind2019_Constant at 0x7fe7bd5db940>,
#  'Electrolyte diffusivity [m2.s-1]': <function electrolyte_diffusivity_EC_EMC_3_7_Landesfeind2019_Constant at 0x7fe7bd5db8b0>,
#  'Electron charge [C]': 1.602176634e-19,
#  'Exchange-current density for plating [A.m-2]': <function plating_exchange_current_density_OKane2020 at 0x7fe7bd5cc940>,
#  'Exchange-current density for stripping [A.m-2]': <function stripping_exchange_current_density_OKane2020 at 0x7fe7bd5cc9d0>,
#  'Faraday constant [C.mol-1]': 96485.33212,
#  'Ideal gas constant [J.K-1.mol-1]': 8.314462618,
#  'Initial concentration in electrolyte [mol.m-3]': 1000.0,
#  'Initial concentration in negative electrode [mol.m-3]': 28543,
#  'Initial concentration in positive electrode [mol.m-3]': 12729.0,
#  'Initial inner SEI on cracks thickness [m]': 0,
#  'Initial inner SEI thickness [m]': 1.6226992346364333e-08,
#  'Initial outer SEI on cracks thickness [m]': 5e-13,
#  'Initial outer SEI thickness [m]': 1.6226992346364333e-08,
#  'Initial plated lithium concentration [mol.m-3]': 0.0,
#  'Initial temperature [K]': 298.15,
#  'Inner SEI electron conductivity [S.m-1]': 8.95e-14,
#  'Inner SEI lithium interstitial diffusivity [m2.s-1]': 1e-20,
#  'Inner SEI open-circuit potential [V]': 0.1,
#  'Inner SEI partial molar volume [m3.mol-1]': 9.585e-05,
#  'Inner SEI reaction proportion': 0.0,
#  'Lithium interstitial reference concentration [mol.m-3]': 15.0,
#  'Lithium metal partial molar volume [m3.mol-1]': 1.3e-05,
#  'Lithium plating kinetic rate constant [m.s-1]': 1e-09,
#  'Lithium plating transfer coefficient': 0.65,
#  'Lower voltage cut-off [V]': 2.2,
#  'Maximum concentration in negative electrode [mol.m-3]': 32544.0,
#  'Maximum concentration in positive electrode [mol.m-3]': 52787.0,
#  'Minimum concentration in negative electrode [mol.m-3]': 0,
#  'Minimum concentration in positive electrode [mol.m-3]': 0,
#  'Negative EC diffusivity [m2.s-1]': 2e-18,
#  'Negative EC initial concentration in electrolyte [mol.m-3]': 4541.0,
#  'Negative SEI growth activation energy [J.mol-1]': 38000.0,
#  'Negative SEI kinetic rate constant [m.s-1]': 1e-12,
#  'Negative SEI open-circuit potential [V]': 0.4,
#  'Negative SEI reaction exchange current density [A.m-2]': 1.5e-07,
#  'Negative SEI resistivity [Ohm.m]': 200000.0,
#  'Negative bulk solvent concentration [mol.m-3]': 4541.0,
#  'Negative cracking growth activation energy [J.mol-1]': 0.0,
#  'Negative current collector conductivity [S.m-1]': 58411000.0,
#  'Negative current collector density [kg.m-3]': 8960.0,
#  'Negative current collector specific heat capacity [J.kg-1.K-1]': 385.0,
#  'Negative current collector thermal conductivity [W.m-1.K-1]': 401.0,
#  'Negative current collector thickness [m]': 1.2e-05,
#  'Negative electrode Bruggeman coefficient (electrode)': 0.0,
#  'Negative electrode Bruggeman coefficient (electrolyte)': 1.5,
#  'Negative electrode LAM constant exponential term': 2.0,
#  'Negative electrode LAM constant proportional term [s-1]': 2.7778e-07,
#  'Negative electrode OCP [V]': <function graphite_LGM50_delithiation_ocp_OKane2023 at 0x7fe7bd5dbdc0>,
#  'Negative electrode OCP entropic change [V.K-1]': <function graphite_LGM50_entropic_change_ORegan2022 at 0x7fe7bd5db1f0>,
#  "Negative electrode Paris' law constant b": 1.12,
#  "Negative electrode Paris' law constant m": 2.2,
#  "Negative electrode Poisson's ratio": 0.3,
#  "Negative electrode Young's modulus [Pa]": 15000000000.0,
#  'Negative electrode active material volume fraction': 0.75,
#  'Negative electrode cation signed stoichiometry': -1.0,
#  'Negative electrode charge transfer coefficient': 0.5,
#  'Negative electrode conductivity [S.m-1]': 215.0,
#  'Negative electrode cracking rate': <function graphite_cracking_rate_Ai2020 at 0x7fe7bd5dbc10>,
#  'Negative electrode critical stress [Pa]': 60000000.0,
#  'Negative electrode delithiation OCP [V]': <function graphite_LGM50_delithiation_ocp_OKane2023 at 0x7fe7bd5dbdc0>,
#  'Negative electrode density [kg.m-3]': 2060.0,
#  'Negative electrode diffusivity [m2.s-1]': <function graphite_LGM50_diffusivity_ORegan2022 at 0x7fe7bd5ccee0>,
#  'Negative electrode diffusivity activation energy [J.mol-1]': 30300.0,
#  'Negative electrode double-layer capacity [F.m-2]': 0.2,
#  'Negative electrode electrons in reaction': 1.0,
#  'Negative electrode exchange-current density [A.m-2]': <function graphite_LGM50_electrolyte_exchange_current_density_ORegan2022 at 0x7fe7bd5db040>,
#  'Negative electrode initial crack length [m]': 2e-08,
#  'Negative electrode initial crack width [m]': 1.5e-08,
#  'Negative electrode lithiation OCP [V]': <function graphite_LGM50_lithiation_ocp_OKane2023 at 0x7fe7bd5dbe50>,
#  'Negative electrode number of cracks per unit area [m-2]': 3180000000000000.0,
#  'Negative electrode partial molar volume [m3.mol-1]': 3.1e-06,
#  'Negative electrode porosity': 0.21934617374666832,
#  'Negative electrode reaction-driven LAM factor [m3.mol-1]': 0.0,
#  'Negative electrode reference concentration for free of deformation [mol.m-3]': 0.0,
#  'Negative electrode specific heat capacity [J.kg-1.K-1]': <function graphite_LGM50_heat_capacity_ORegan2022 at 0x7fe7bd5db0d0>,
#  'Negative electrode thermal conductivity [W.m-1.K-1]': <function graphite_LGM50_thermal_conductivity_ORegan2022 at 0x7fe7bd5db160>,
#  'Negative electrode thickness [m]': 8.52e-05,
#  'Negative electrode volume change': <function graphite_volume_change_Ai2020 at 0x7fe7bd5dbb80>,
#  'Negative initial inner SEI thickness [m]': 1.6226992346364333e-08,
#  'Negative initial outer SEI thickness [m]': 1.6226992346364333e-08,
#  'Negative inner SEI electron conductivity [S.m-1]': 8.95e-14,
#  'Negative inner SEI lithium interstitial diffusivity [m2.s-1]': 1e-20,
#  'Negative inner SEI open-circuit potential [V]': 0.1,
#  'Negative inner SEI partial molar volume [m3.mol-1]': 9.585e-05,
#  'Negative inner SEI reaction proportion': 0.5,
#  'Negative lithium interstitial reference concentration [mol.m-3]': 15.0,
#  'Negative outer SEI open-circuit potential [V]': 0.8,
#  'Negative outer SEI partial molar volume [m3.mol-1]': 9.585e-05,
#  'Negative outer SEI solvent diffusivity [m2.s-1]': 2.5000000000000002e-22,
#  'Negative particle diffusivity [m2.s-1]': <function graphite_LGM50_diffusivity_ORegan2022 at 0x7fe7bd5ccee0>,
#  'Negative particle diffusivity activation energy [J.mol-1]': 30300.0,
#  'Negative particle radius [m]': 5.86e-06,
#  'Negative ratio of lithium moles to SEI moles': 2.0,
#  'Nominal cell capacity [A.h]': 5.0,
#  'Number of cells connected in series to make a battery': 1.0,
#  'Number of electrodes connected in parallel to make a cell': 1.0,
#  'Open-circuit voltage at 0% SOC [V]': 2.5,
#  'Open-circuit voltage at 100% SOC [V]': 4.2,
#  'Outer SEI open-circuit potential [V]': 0.8,
#  'Outer SEI partial molar volume [m3.mol-1]': 9.585e-05,
#  'Outer SEI solvent diffusivity [m2.s-1]': 2.5000000000000002e-22,
#  'Positive EC diffusivity [m2.s-1]': 2e-18,
#  'Positive EC initial concentration in electrolyte [mol.m-3]': 4541.0,
#  'Positive SEI growth activation energy [J.mol-1]': 38000.0,
#  'Positive SEI kinetic rate constant [m.s-1]': 1e-12,
#  'Positive SEI open-circuit potential [V]': 0.4,
#  'Positive SEI reaction exchange current density [A.m-2]': 1.5e-07,
#  'Positive SEI resistivity [Ohm.m]': 200000.0,
#  'Positive bulk solvent concentration [mol.m-3]': 2636.0,
#  'Positive current collector conductivity [S.m-1]': 36914000.0,
#  'Positive current collector density [kg.m-3]': 2700.0,
#  'Positive current collector specific heat capacity [J.kg-1.K-1]': 897.0,
#  'Positive current collector thermal conductivity [W.m-1.K-1]': 237.0,
#  'Positive current collector thickness [m]': 1.6e-05,
#  'Positive electrode Bruggeman coefficient (electrode)': 0.0,
#  'Positive electrode Bruggeman coefficient (electrolyte)': 1.5,
#  'Positive electrode LAM constant exponential term': 2.0,
#  'Positive electrode LAM constant proportional term [s-1]': 2.7778e-07,
#  'Positive electrode OCP [V]': <function nmc_LGM50_lithiation_ocp_OKane2023 at 0x7fe7bd5dbee0>,
#  'Positive electrode OCP entropic change [V.K-1]': <function nmc_LGM50_entropic_change_ORegan2022 at 0x7fe7bd5dba60>,
#  "Positive electrode Paris' law constant b": 1.12,
#  "Positive electrode Paris' law constant m": 2.2,
#  "Positive electrode Poisson's ratio": 0.2,
#  "Positive electrode Young's modulus [Pa]": 375000000000.0,
#  'Positive electrode active material volume fraction': 0.665,
#  'Positive electrode cation signed stoichiometry': -1.0,
#  'Positive electrode charge transfer coefficient': 0.5,
#  'Positive electrode conductivity [S.m-1]': <function nmc_LGM50_electronic_conductivity_ORegan2022 at 0x7fe7bd5db280>,
#  'Positive electrode cracking rate': <function cracking_rate_Ai2020 at 0x7fe7bd5dbd30>,
#  'Positive electrode critical stress [Pa]': 375000000.0,
#  'Positive electrode delithiation OCP [V]': <function nmc_LGM50_delithiation_ocp_OKane2023 at 0x7fe7bd5dbf70>,
#  'Positive electrode density [kg.m-3]': 3699.0,
#  'Positive electrode diffusivity [m2.s-1]': <function nmc_LGM50_diffusivity_ORegan2022 at 0x7fe7bd5db310>,
#  'Positive electrode diffusivity activation energy [J.mol-1]': 25000.0,
#  'Positive electrode double-layer capacity [F.m-2]': 0.2,
#  'Positive electrode electrons in reaction': 1.0,
#  'Positive electrode exchange-current density [A.m-2]': <function nmc_LGM50_electrolyte_exchange_current_density_ORegan2022 at 0x7fe7bd5db430>,
#  'Positive electrode initial crack length [m]': 2e-08,
#  'Positive electrode initial crack width [m]': 1.5e-08,
#  'Positive electrode lithiation OCP [V]': <function nmc_LGM50_lithiation_ocp_OKane2023 at 0x7fe7bd5dbee0>,
#  'Positive electrode number of cracks per unit area [m-2]': 3180000000000000.0,
#  'Positive electrode partial molar volume [m3.mol-1]': 7.88e-07,
#  'Positive electrode porosity': 0.335,
#  'Positive electrode reaction-driven LAM factor [m3.mol-1]': 0.0,
#  'Positive electrode reference concentration for free of deformation [mol.m-3]': 0.0,
#  'Positive electrode specific heat capacity [J.kg-1.K-1]': <function nmc_LGM50_heat_capacity_ORegan2022 at 0x7fe7bd5db4c0>,
#  'Positive electrode thermal conductivity [W.m-1.K-1]': <function nmc_LGM50_thermal_conductivity_ORegan2022 at 0x7fe7bd5db9d0>,
#  'Positive electrode thickness [m]': 7.56e-05,
#  'Positive electrode volume change': <function volume_change_Ai2020 at 0x7fe7bd5dbca0>,
#  'Positive initial inner SEI thickness [m]': 0.0,
#  'Positive initial outer SEI thickness [m]': 5e-09,
#  'Positive inner SEI electron conductivity [S.m-1]': 8.95e-14,
#  'Positive inner SEI lithium interstitial diffusivity [m2.s-1]': 1e-20,
#  'Positive inner SEI open-circuit potential [V]': 0.1,
#  'Positive inner SEI partial molar volume [m3.mol-1]': 9.585e-05,
#  'Positive inner SEI reaction proportion': 0.0,
#  'Positive lithium interstitial reference concentration [mol.m-3]': 15.0,
#  'Positive outer SEI open-circuit potential [V]': 0.8,
#  'Positive outer SEI partial molar volume [m3.mol-1]': 9.585e-05,
#  'Positive outer SEI solvent diffusivity [m2.s-1]': 2.5000000000000002e-22,
#  'Positive particle diffusivity [m2.s-1]': <function nmc_LGM50_diffusivity_ORegan2022 at 0x7fe7bd5db310>,
#  'Positive particle diffusivity activation energy [J.mol-1]': 25000.0,
#  'Positive particle radius [m]': 5.22e-06,
#  'Positive ratio of lithium moles to SEI moles': 1.0,
#  'Ratio of lithium moles to SEI moles': 1.0,
#  'Reference temperature [K]': 298.15,
#  'SEI growth activation energy [J.mol-1]': 38000.0,
#  'SEI kinetic rate constant [m.s-1]': 1e-12,
#  'SEI open-circuit potential [V]': 0.4,
#  'SEI reaction exchange current density [A.m-2]': 1.5e-07,
#  'SEI resistivity [Ohm.m]': 200000.0,
#  'Separator Bruggeman coefficient (electrode)': 1.5,
#  'Separator Bruggeman coefficient (electrolyte)': 1.5,
#  'Separator density [kg.m-3]': 1548.0,
#  'Separator porosity': 0.47,
#  'Separator specific heat capacity [J.kg-1.K-1]': <function separator_LGM50_heat_capacity_ORegan2022 at 0x7fe7bd5dbaf0>,
#  'Separator thermal conductivity [W.m-1.K-1]': 0.3344,
#  'Separator thickness [m]': 1.2e-05,
#  'Thermodynamic factor': <function electrolyte_TDF_EC_EMC_3_7_Landesfeind2019_Constant at 0x7fe7bd5db820>,
#  'Total heat transfer coefficient [W.m-2.K-1]': 15.0,
#  'Typical current [A]': 5.0,
#  'Typical electrolyte concentration [mol.m-3]': 1000.0,
#  'Typical plated lithium concentration [mol.m-3]': 1000.0,
#  'Upper voltage cut-off [V]': 4.4,
#  'citations': ['OKane2022',
#                'OKane2020',
#                'Chen2020',
#                'ORegan2022']}

# %%
import pybamm
import matplotlib.pyplot as plt
import numpy as np


model = pybamm.lithium_ion.DFN(
    {
        #"particle phases": ("2", "1"),
        #"open-circuit potential": (("single", "current sigmoid"), "single"),
        "open-circuit potential": "current sigmoid",
        "SEI": "solvent-diffusion limited",
        #"SEI": "interstitial-diffusion limited",
        "SEI porosity change": "true",
        "lithium plating": "partially reversible",
        "lithium plating porosity change": "true",  # alias for "SEI porosity change"
        "particle mechanics": ("swelling and cracking", "swelling only"),
        "SEI on cracks": "true",
        "loss of active material": "stress-driven",
        "calculate discharge energy": "true",  # for compatibility with older PyBaMM versions

        "thermal": "lumped", 
    }
)

#param = pybamm.ParameterValues("OKane2023_Xinlei")

var_pts = {
    "x_n": 10,  # negative electrode
    "x_s": 10,  # separator
    "x_p": 10,  # positive electrode
    "r_n": 30,  # negative particle
    "r_p": 30,  # positive particle
}

cycle_number = 1
exp = pybamm.Experiment(
    # [
    #     "Hold at 4.2 V until C/100 (5 minute period)",
    #     "Rest for 4 hours (5 minute period)",
    #     "Discharge at 0.1C until 2.5 V (5 minute period)",  # initial capacity check
    #     "Charge at 1C until 4.2 V (5 minute period)",
    #     "Hold at 4.2 V until C/100 (5 minute period)",
    # ]
    # + 
    [
        (
            "Charge at C/3 until 4.2 V",
            "Hold at 4.2 V until C/20",
            "Discharge at 1C until 2.5 V",  # ageing cycles
            #"Discharge at 1C until 2.5 V"

        )
    ]
    * cycle_number
    #+ ["Discharge at 0.1C until 2.5 V (5 minute period)"],  # final capacity check
)

# exp = pybamm.Experiment(
#     [
#         "Hold at 4.2 V until C/100 (5 minute period)",
#         "Discharge at 0.1C until 2.5 V (5 minute period)",  # initial capacity check
#         "Charge at 0.1C until 4.2 V (5 minute period)",
#         "Hold at 4.2 V until C/100 (5 minute period)",
#     ]
# )


sim = pybamm.Simulation(model, parameter_values=param, experiment=exp, var_pts=var_pts )
#sim_thermal = pybamm.Simulation(model_thermal, parameter_values=param, experiment=exp, var_pts=var_pts)
sol = sim.solve(initial_soc=0)
#sol = sim.solve()
# Out:
# At t = 68.6514 and h = 1.44274e-12, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 68.6504 and h = 1.94073e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 68.6514 and h = 6.4504e-12, the corrector convergence failed repeatedly or with |h| = hmin.

# %%
model_nodeg = pybamm.lithium_ion.DFN(
    {
        #"particle phases": ("2", "1"),
        #"open-circuit potential": (("single", "current sigmoid"), "single"),
        "open-circuit potential": "current sigmoid",
        # "SEI": "solvent-diffusion limited",
        # "SEI porosity change": "true",
        # "lithium plating": "partially reversible",
        # "lithium plating porosity change": "true",  # alias for "SEI porosity change"
        # "particle mechanics": ("swelling and cracking", "swelling only"),
        # "SEI on cracks": "true",
        # "loss of active material": "stress-driven",
        # "calculate discharge energy": "true",  # for compatibility with older PyBaMM versions

        "thermal": "lumped", 
    }
)

#param = pybamm.ParameterValues("OKane2023_Xinlei")
var_pts = {
    "x_n": 10,  # negative electrode
    "x_s": 10,  # separator
    "x_p": 10,  # positive electrode
    "r_n": 30,  # negative particle
    "r_p": 30,  # positive particle
}

cycle_number = 2
exp_breakin = pybamm.Experiment(
    # [
    #     "Hold at 4.2 V until C/100 (5 minute period)",
    #     "Rest for 4 hours (5 minute period)",
    #     "Discharge at 0.1C until 2.5 V (5 minute period)",  # initial capacity check
    #     "Charge at 1C until 4.2 V (5 minute period)",
    #     "Hold at 4.2 V until C/100 (5 minute period)",
    # ]
    # + 
    [
        (
            "Charge at C/3 until 4.2 V",
            "Hold at 4.2 V until C/20",
            "Discharge at 1C until 2.5 V",  # ageing cycles
            #"Discharge at 1C until 2.5 V"

        )
    ]
    * cycle_number
    #+ ["Hold at 2.6V for 1 hours"],  # final capacity check
)

exp = pybamm.Experiment(
    # [
    #     "Hold at 4.2 V until C/100 (5 minute period)",
    #     "Rest for 4 hours (5 minute period)",
    #     "Discharge at 0.1C until 2.5 V (5 minute period)",  # initial capacity check
    #     "Charge at 1C until 4.2 V (5 minute period)",
    #     "Hold at 4.2 V until C/100 (5 minute period)",
    # ]
    # + 
    [
        (
            "Charge at C/3 until 4.2 V",
            "Hold at 4.2 V until C/20",
            "Discharge at 1C until 2.5 V",  # ageing cycles
            #"Discharge at 1C until 2.5 V"

        )
    ]
    * 1
    #+ ["Discharge at 0.1C until 2.5 V (5 minute period)"],  # final capacity check
)

# exp = pybamm.Experiment(
#     [
#         "Hold at 4.2 V until C/100 (5 minute period)",
#         "Discharge at 0.1C until 2.5 V (5 minute period)",  # initial capacity check
#         "Charge at 0.1C until 4.2 V (5 minute period)",
#         "Hold at 4.2 V until C/100 (5 minute period)",
#     ]
# )


sim_nodeg_breakin = pybamm.Simulation(model_nodeg, parameter_values=param, experiment=exp_breakin, var_pts=var_pts )
#sim_thermal = pybamm.Simulation(model_thermal, parameter_values=param, experiment=exp, var_pts=var_pts)
sol_nodeg_breakin = sim_nodeg_breakin.solve(initial_soc=0)
#sol = sim.solve()

# set end state as beginning
model_nodeg.set_initial_conditions_from(sol_nodeg_breakin, inplace=True)

sim_nodeg = pybamm.Simulation(model_nodeg, parameter_values=param, experiment=exp, var_pts=var_pts )
sol_nodeg = sim_nodeg.solve()
# Out:
# At t = 69.1117 and h = 1.16035e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 69.1117 and h = 1.12899e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 69.1117 and h = 4.13691e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 69.1147 and h = 1.61895e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 69.1147 and h = 1.16683e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 69.1147 and h = 2.40519e-14, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 69.1146 and h = 5.77315e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 69.1146 and h = 9.20544e-15, the corrector convergence failed repeatedly or with |h| = hmin.
# At t = 69.1146 and h = 7.35647e-15, the corrector convergence failed repeatedly or with |h| = hmin.

# %%
plt.plot(sol_nodeg["Time [s]"].entries,sol_nodeg["Average negative particle stoichiometry"].entries )

# %%
plt.plot(sol_nodeg["Time [s]"].entries,sol_nodeg["Discharge capacity [A.h]"].entries )

# %%
sol_nodeg["Discharge capacity [A.h]"].entries
# Out:
# array([-0.31849063, -0.34626841, -0.37404618, -0.40182396, -0.42960174,
#        -0.45737952, -0.48515729, -0.51293507, -0.54071285, -0.56849063,
#        -0.59626841, -0.62404618, -0.65182396, -0.67960174, -0.70737952,
#        -0.73515729, -0.76293507, -0.79071285, -0.81849063, -0.84626841,
#        -0.87404618, -0.90182396, -0.92960174, -0.95737952, -0.98515729,
#        -1.01293507, -1.04071285, -1.06849063, -1.09626841, -1.12404618,
#        -1.15182396, -1.17960174, -1.20737952, -1.23515729, -1.26293507,
#        -1.29071285, -1.31849063, -1.34626841, -1.37404618, -1.40182396,
#        -1.42960174, -1.45737952, -1.48515729, -1.51293507, -1.54071285,
#        -1.56849063, -1.59626841, -1.62404618, -1.65182396, -1.67960174,
#        -1.70737952, -1.73515729, -1.76293507, -1.79071285, -1.81849063,
#        -1.84626841, -1.87404618, -1.90182396, -1.92960174, -1.95737952,
#        -1.98515729, -2.01293507, -2.04071285, -2.06849063, -2.09626841,
#        -2.12404618, -2.15182396, -2.17960174, -2.20737952, -2.23515729,
#        -2.26293507, -2.29071285, -2.31849063, -2.34626841, -2.37404618,
#        -2.40182396, -2.42960174, -2.45737952, -2.48515729, -2.51293507,
#        -2.54071285, -2.56849063, -2.59626841, -2.62404618, -2.65182396,
#        -2.67960174, -2.70737952, -2.73515729, -2.76293507, -2.79071285,
#        -2.81849063, -2.84626841, -2.87404618, -2.90182396, -2.92960174,
#        -2.95737952, -2.98515729, -3.01293507, -3.04071285, -3.06849063,
#        -3.09626841, -3.12404618, -3.15182396, -3.17960174, -3.20737952,
#        -3.23515729, -3.26293507, -3.29071285, -3.31849063, -3.34626841,
#        -3.37404618, -3.40182396, -3.42960174, -3.45737952, -3.48515729,
#        -3.51293507, -3.54071285, -3.56849063, -3.59626841, -3.62404618,
#        -3.65182396, -3.67960174, -3.70737952, -3.73515729, -3.76293507,
#        -3.79071285, -3.81849063, -3.84626841, -3.87404618, -3.90182396,
#        -3.92960174, -3.95737952, -3.98515729, -4.01293507, -4.04071285,
#        -4.06849063, -4.09626841, -4.12404618, -4.15182396, -4.17960174,
#        -4.20737952, -4.23515729, -4.26293507, -4.29071285, -4.31849063,
#        -4.34626841, -4.37404618, -4.40182396, -4.42960174, -4.45737952,
#        -4.48515729, -4.51293507, -4.54071285, -4.56849063, -4.59626841,
#        -4.62404618, -4.65182396, -4.67960174, -4.70737952, -4.73515729,
#        -4.76293507, -4.77659659, -4.77659659, -4.80199228, -4.82407693,
#        -4.8434138 , -4.86019379, -4.87462467, -4.88693997, -4.89737167,
#        -4.90616061, -4.91351638, -4.91963167, -4.92469194, -4.9269087 ,
#        -4.9269087 , -4.84357537, -4.76024204, -4.6769087 , -4.59357537,
#        -4.51024204, -4.4269087 , -4.34357537, -4.26024204, -4.1769087 ,
#        -4.09357537, -4.01024204, -3.9269087 , -3.84357537, -3.76024204,
#        -3.6769087 , -3.59357537, -3.51024204, -3.4269087 , -3.34357537,
#        -3.26024204, -3.1769087 , -3.09357537, -3.01024204, -2.9269087 ,
#        -2.84357537, -2.76024204, -2.6769087 , -2.59357537, -2.51024204,
#        -2.4269087 , -2.34357537, -2.26024204, -2.1769087 , -2.09357537,
#        -2.01024204, -1.9269087 , -1.84357537, -1.76024204, -1.6769087 ,
#        -1.59357537, -1.51024204, -1.4269087 , -1.34357537, -1.26024204,
#        -1.1769087 , -1.09357537, -1.01024204, -0.9269087 , -0.84357537,
#        -0.76024204, -0.6769087 , -0.59357537, -0.51024204, -0.4269087 ,
#        -0.34357537, -0.31849103])

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
cwd = os.getcwd()


# 读取 pickle 文件
#pickle_file_path = cwd + '/docs/source/examples/notebooks/models/exp_LG/processed_data.pkl'
pickle_file_path = cwd + '/exp_LG/processed_data.pkl'
cycles_df = pd.read_pickle(pickle_file_path)
print("DataFrame loaded from pickle file")
print(cycles_df.head())
# Out:
# DataFrame loaded from pickle file
#             Mode  RelativeTime   Voltage          I  Q_dis     Q_cha  \
# Cycle Step
# 1     1      1.0        0.0000  2.680430  1407.8055    0.0  0.000078
#       2      1.0        0.0084  2.690530  1574.4427    0.0  0.003691
#       3      1.0        0.0294  2.700598  1640.2499    0.0  0.013108
#       4      1.0        0.0634  2.710643  1664.4644    0.0  0.028749
#       5      1.0        0.1074  2.720645  1668.5892    0.0  0.049123
#
#                  Cap         R    Pressure  Temperature
# Cycle Step
# 1     1     0.000078  1.903978  159.026607      25.3794
#       2     0.003691  1.708878  158.944819      25.3885
#       3     0.013108  1.646455  158.998347      25.4014
#       4     0.028749  1.628537  159.049016      25.4088
#       5     0.049123  1.630506  158.990980      25.4014

# %%
# Compare model data to experiment including degradation

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(13, 4))

# plot the 1C results
t_sol = sol["Time [s]"].entries


ax1.plot(t_sol, sol["Voltage [V]"](t_sol))
ax1.plot(cycles_df.loc[1]["RelativeTime"],cycles_df.loc[1]["Voltage"], "o")
ax1.set_xlabel("Time [s]")
ax1.set_ylabel("Voltage [V]")
ax1.set_title("Voltage")
ax1.legend(["Model", "Experiment"], loc="best")


ax2.plot(t_sol, sol["X-averaged cell temperature [C]"](t_sol))
ax2.plot(cycles_df.loc[1]["RelativeTime"],cycles_df.loc[1]["Temperature"], "o")
ax2.set_xlabel("Time [s]")
ax2.set_ylabel("Temperature [degC]")
ax2.set_title("Temperature")
ax2.legend(["Model", "Experiment"], loc="best")

plt.tight_layout()
plt.show()

# %%
# Compare model data to experiment without degradation
# breakin
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(13, 4))

# plot the 1C results
t_sol_nodeg = sol_nodeg_breakin["Time [s]"].entries


ax1.plot(t_sol_nodeg, sol_nodeg_breakin["Voltage [V]"](t_sol_nodeg))
ax1.plot(cycles_df.loc[1]["RelativeTime"]-cycles_df.loc[1]["RelativeTime"].iloc[1],cycles_df.loc[1]["Voltage"], "o")
#ax1.plot(cycles_df.loc[2]["RelativeTime"]-cycles_df.loc[2]["RelativeTime"].iloc[1],cycles_df.loc[2]["Voltage"], "o")
ax1.set_xlabel("Time [s]")
ax1.set_ylabel("Voltage [V]")
ax1.set_title("Voltage")
ax1.legend(["Model", "Experiment"], loc="best")


ax2.plot(t_sol_nodeg, sol_nodeg_breakin["X-averaged cell temperature [C]"](t_sol_nodeg))
ax2.plot(cycles_df.loc[1]["RelativeTime"]-cycles_df.loc[1]["RelativeTime"].iloc[1],cycles_df.loc[1]["Temperature"], "o")
#ax2.plot(cycles_df.loc[2]["RelativeTime"]-cycles_df.loc[2]["RelativeTime"].iloc[1],cycles_df.loc[2]["Temperature"], "o")
ax2.set_xlabel("Time [s]")
ax2.set_ylabel("Temperature [degC]")
ax2.set_title("Temperature")
ax2.legend(["Model", "Experiment"], loc="best")

plt.tight_layout()
plt.show()

# %%
# Compare model data to experiment without degradation
# 2nd cycle

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(13, 4))

# plot the 1C results
t_sol_nodeg = sol_nodeg["Time [s]"].entries


ax1.plot(t_sol_nodeg, sol_nodeg["Voltage [V]"](t_sol_nodeg))
#ax1.plot(cycles_df.loc[1]["RelativeTime"]-cycles_df.loc[1]["RelativeTime"].iloc[1],cycles_df.loc[1]["Voltage"], "o")
ax1.plot(cycles_df.loc[2]["RelativeTime"]-cycles_df.loc[2]["RelativeTime"].iloc[1],cycles_df.loc[2]["Voltage"], "o")
ax1.set_xlabel("Time [s]")
ax1.set_ylabel("Voltage [V]")
ax1.set_title("Voltage")
ax1.legend(["Model", "Experiment"], loc="best")


ax2.plot(t_sol_nodeg, sol_nodeg["X-averaged cell temperature [C]"](t_sol_nodeg))
#ax2.plot(cycles_df.loc[1]["RelativeTime"]-cycles_df.loc[1]["RelativeTime"].iloc[1],cycles_df.loc[1]["Temperature"], "o")
ax2.plot(cycles_df.loc[2]["RelativeTime"]-cycles_df.loc[2]["RelativeTime"].iloc[1],cycles_df.loc[2]["Temperature"], "o")
ax2.set_xlabel("Time [s]")
ax2.set_ylabel("Temperature [degC]")
ax2.set_title("Temperature")
ax2.legend(["Model", "Experiment"], loc="best")

plt.tight_layout()
plt.show()

# %%
model.variables
# Out:
# {'Time [s]': Time(-0x5d03a110888fbf74, time, children=[], domains={}),
#  'Time [min]': Multiplication(-0x44ddc193a91c63d7, *, children=['0.016666666666666666', 'time'], domains={}),
#  'Time [h]': Multiplication(-0x40ada24147c734b1, *, children=['0.0002777777777777778', 'time'], domains={}),
#  'x [m]': SpatialVariable(-0x176d7bf2a76c2611, x, children=[], domains={'primary': ['negative electrode', 'separator', 'positive electrode'], 'secondary': ['current collector']}),
#  'x_n [m]': SpatialVariable(0x43d6b5379e42d33a, x_n, children=[], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'x_s [m]': SpatialVariable(0x66a70d7f0a63f662, x_s, children=[], domains={'primary': ['separator'], 'secondary': ['current collector']}),
#  'x_p [m]': SpatialVariable(0x27e6fcc2d182c594, x_p, children=[], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'r_n [m]': SpatialVariable(-0x784c78a9d6edaa32, r_n, children=[], domains={'primary': ['negative particle'], 'secondary': ['negative electrode'], 'tertiary': ['current collector']}),
#  'r_p [m]': SpatialVariable(-0x53fbd84fd57fb56a, r_p, children=[], domains={'primary': ['positive particle'], 'secondary': ['positive electrode'], 'tertiary': ['current collector']}),
#  'Current variable [A]': FunctionParameter(0x2b4aa24d7d7d325c, Current function [A], children=['time'], domains={}),
#  'Total current density [A.m-2]': Division(0x3b80c5ab3e5261b5, /, children=['Current function [A]', 'Number of electrodes connected in parallel to make a cell * Electrode width [m] * Electrode height [m]'], domains={}),
#  'Current [A]': FunctionParameter(0x2b4aa24d7d7d325c, Current function [A], children=['time'], domains={}),
#  'C-rate': Division(0x303e960202f9c140, /, children=['Current function [A]', 'Nominal cell capacity [A.h]'], domains={}),
#  'Discharge capacity [A.h]': Variable(-0x28c77b60c0a89251, Discharge capacity [A.h], children=[], domains={}),
#  'Throughput capacity [A.h]': Variable(-0x108ac678ecd58ab1, Throughput capacity [A.h], children=[], domains={}),
#  'Discharge energy [W.h]': Variable(0x35e2f007ab443251, Discharge energy [W.h], children=[], domains={}),
#  'Throughput energy [W.h]': Variable(0x380c3f3b0928bad6, Throughput energy [W.h], children=[], domains={}),
#  'Negative electrode interface utilisation variable': FullBroadcast(0x73851177e5c51890, broadcast, children=['1.0'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrode interface utilisation variable': PrimaryBroadcast(-0x3d3dd1213ceba618, broadcast, children=['1.0'], domains={'primary': ['current collector']}),
#  'Negative electrode interface utilisation': FullBroadcast(0x73851177e5c51890, broadcast, children=['1.0'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrode interface utilisation': PrimaryBroadcast(-0x3d3dd1213ceba618, broadcast, children=['1.0'], domains={'primary': ['current collector']}),
#  'Positive electrode interface utilisation variable': FullBroadcast(-0x62449aa6777bfb26, broadcast, children=['1.0'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrode interface utilisation variable': PrimaryBroadcast(-0x3d3dd1213ceba618, broadcast, children=['1.0'], domains={'primary': ['current collector']}),
#  'Positive electrode interface utilisation': FullBroadcast(-0x62449aa6777bfb26, broadcast, children=['1.0'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrode interface utilisation': PrimaryBroadcast(-0x3d3dd1213ceba618, broadcast, children=['1.0'], domains={'primary': ['current collector']}),
#  'Negative particle crack length [m]': Variable(0x72b1b1dce6d8aa62, Negative particle crack length [m], children=[], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative particle crack length [m]': XAverage(0x6ab3a9e6bd4bdaa3, x-average, children=['Negative particle crack length [m]'], domains={'primary': ['current collector']}),
#  'Positive particle crack length [m]': FullBroadcast(-0x5480964e4a65cac7, broadcast, children=['0.0'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive particle crack length [m]': PrimaryBroadcast(0x1dec22bbb55b4e23, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'Positive particle cracking rate [m.s-1]': FullBroadcast(-0x5480964e4a65cac7, broadcast, children=['0.0'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive particle cracking rate [m.s-1]': PrimaryBroadcast(0x1dec22bbb55b4e23, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'Negative electrode active material volume fraction': Variable(-0x31322b2516213cf0, Negative electrode active material volume fraction, children=[], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrode active material volume fraction': XAverage(0x14496ba5a09f6c34, x-average, children=['Negative electrode active material volume fraction'], domains={'primary': ['current collector']}),
#  'Negative electrode capacity [A.h]': Multiplication(0x1fb03b1459d37e47, *, children=['0.0002777777777777778', 'yz-average(x-average(Negative electrode active material volume fraction)) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] * Maximum concentration in negative electrode [mol.m-3] * Faraday constant [C.mol-1]'], domains={}),
#  'Negative particle radius': Division(0x26364d56612aadcf, /, children=['Negative particle radius [m]', 'Negative particle radius [m]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Negative particle radius [m]': FunctionParameter(-0x604d99433e28c25a, Negative particle radius [m], children=['x_n'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative particle radius [m]': XAverage(0x47a1d2ab4bfb3fee, x-average, children=['Negative particle radius [m]'], domains={'primary': ['current collector']}),
#  'Negative electrode surface area to volume ratio [m-1]': Division(-0x152411b6beca5148, /, children=['3.0 * Negative electrode active material volume fraction', 'Negative particle radius [m]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrode surface area to volume ratio [m-1]': XAverage(0x5768a181147df1e7, x-average, children=['3.0 * Negative electrode active material volume fraction / Negative particle radius [m]'], domains={'primary': ['current collector']}),
#  'Loss of lithium due to loss of active material in negative electrode [mol]': Variable(0x3a703d21398495fc, Loss of lithium due to loss of active material in negative electrode [mol], children=[], domains={}),
#  'Positive electrode active material volume fraction': Variable(-0x3173da42f086fb2, Positive electrode active material volume fraction, children=[], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrode active material volume fraction': XAverage(-0x1af4371acfbe1aad, x-average, children=['Positive electrode active material volume fraction'], domains={'primary': ['current collector']}),
#  'Positive electrode capacity [A.h]': Multiplication(0x79bcfded10d60f5d, *, children=['0.0002777777777777778', 'yz-average(x-average(Positive electrode active material volume fraction)) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m] * Maximum concentration in positive electrode [mol.m-3] * Faraday constant [C.mol-1]'], domains={}),
#  'Positive particle radius': Division(0x7dd5799df2499023, /, children=['Positive particle radius [m]', 'Positive particle radius [m]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Positive particle radius [m]': FunctionParameter(-0x2d49bd43c3fa9c26, Positive particle radius [m], children=['x_p'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive particle radius [m]': XAverage(-0x39d37f00dfe96808, x-average, children=['Positive particle radius [m]'], domains={'primary': ['current collector']}),
#  'Positive electrode surface area to volume ratio [m-1]': Division(-0x452f57458239b5d3, /, children=['3.0 * Positive electrode active material volume fraction', 'Positive particle radius [m]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrode surface area to volume ratio [m-1]': XAverage(0x34afc3c9e5c586b4, x-average, children=['3.0 * Positive electrode active material volume fraction / Positive particle radius [m]'], domains={'primary': ['current collector']}),
#  'Loss of lithium due to loss of active material in positive electrode [mol]': Variable(0x36d9fa066a1fdf6, Loss of lithium due to loss of active material in positive electrode [mol], children=[], domains={}),
#  'Separator pressure [Pa]': PrimaryBroadcast(-0x4219593c7b43d77d, broadcast, children=['broadcast(0.0)'], domains={'primary': ['separator'], 'secondary': ['current collector']}),
#  'X-averaged separator pressure [Pa]': PrimaryBroadcast(0x1dec22bbb55b4e23, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'negative electrode transverse volume-averaged velocity [m.s-1]': PrimaryBroadcast(0xa7cd1c6bae1b5c7, broadcast, children=['broadcast(0.0)'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrode transverse volume-averaged velocity [m.s-1]': PrimaryBroadcast(0x1dec22bbb55b4e23, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'separator transverse volume-averaged velocity [m.s-1]': PrimaryBroadcast(-0x4219593c7b43d77d, broadcast, children=['broadcast(0.0)'], domains={'primary': ['separator'], 'secondary': ['current collector']}),
#  'X-averaged separator transverse volume-averaged velocity [m.s-1]': PrimaryBroadcast(0x1dec22bbb55b4e23, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'positive electrode transverse volume-averaged velocity [m.s-1]': PrimaryBroadcast(-0x1ad3f21f725f255d, broadcast, children=['broadcast(0.0)'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrode transverse volume-averaged velocity [m.s-1]': PrimaryBroadcast(0x1dec22bbb55b4e23, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'Transverse volume-averaged velocity [m.s-1]': PrimaryBroadcast(-0x6ec2fb2d3fe7b098, broadcast, children=['broadcast(0.0)'], domains={'primary': ['negative electrode', 'separator', 'positive electrode'], 'secondary': ['current collector']}),
#  'negative electrode transverse volume-averaged acceleration [m.s-2]': PrimaryBroadcast(0xa7cd1c6bae1b5c7, broadcast, children=['broadcast(0.0)'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrode transverse volume-averaged acceleration [m.s-2]': PrimaryBroadcast(0x1dec22bbb55b4e23, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'separator transverse volume-averaged acceleration [m.s-2]': PrimaryBroadcast(-0x4219593c7b43d77d, broadcast, children=['broadcast(0.0)'], domains={'primary': ['separator'], 'secondary': ['current collector']}),
#  'X-averaged separator transverse volume-averaged acceleration [m.s-2]': PrimaryBroadcast(0x1dec22bbb55b4e23, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'positive electrode transverse volume-averaged acceleration [m.s-2]': PrimaryBroadcast(-0x1ad3f21f725f255d, broadcast, children=['broadcast(0.0)'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrode transverse volume-averaged acceleration [m.s-2]': PrimaryBroadcast(0x1dec22bbb55b4e23, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'Transverse volume-averaged acceleration [m.s-2]': PrimaryBroadcast(-0x6ec2fb2d3fe7b098, broadcast, children=['broadcast(0.0)'], domains={'primary': ['negative electrode', 'separator', 'positive electrode'], 'secondary': ['current collector']}),
#  'Negative electrode volume-averaged velocity [m.s-1]': FullBroadcast(-0x7eb6ea2fed24b711, broadcast, children=['0.0'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Negative electrode volume-averaged acceleration [m.s-2]': FullBroadcast(-0x7eb6ea2fed24b711, broadcast, children=['0.0'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrode volume-averaged acceleration [m.s-2]': PrimaryBroadcast(0x1dec22bbb55b4e23, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'Negative electrode pressure [Pa]': FullBroadcast(-0x7eb6ea2fed24b711, broadcast, children=['0.0'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrode pressure [Pa]': PrimaryBroadcast(0x1dec22bbb55b4e23, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'Positive electrode volume-averaged velocity [m.s-1]': FullBroadcast(-0x5480964e4a65cac7, broadcast, children=['0.0'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Positive electrode volume-averaged acceleration [m.s-2]': FullBroadcast(-0x5480964e4a65cac7, broadcast, children=['0.0'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrode volume-averaged acceleration [m.s-2]': PrimaryBroadcast(0x1dec22bbb55b4e23, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'Positive electrode pressure [Pa]': FullBroadcast(-0x5480964e4a65cac7, broadcast, children=['0.0'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrode pressure [Pa]': PrimaryBroadcast(0x1dec22bbb55b4e23, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'Total negative electrode interfacial current density variable [A.m-2]': Variable(0x2b07fcfe816d3363, Total negative electrode interfacial current density variable [A.m-2], children=[], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged total negative electrode interfacial current density variable [A.m-2]': XAverage(-0x17e30d8931d44569, x-average, children=['Total negative electrode interfacial current density variable [A.m-2]'], domains={'primary': ['current collector']}),
#  'Total positive electrode interfacial current density variable [A.m-2]': Variable(-0x4f31d765719c2667, Total positive electrode interfacial current density variable [A.m-2], children=[], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged total positive electrode interfacial current density variable [A.m-2]': XAverage(-0x3ea6f95338870fac, x-average, children=['Total positive electrode interfacial current density variable [A.m-2]'], domains={'primary': ['current collector']}),
#  'Negative particle concentration [mol.m-3]': Variable(0x6be1ebe07340c4bd, Negative particle concentration [mol.m-3], children=[], domains={'primary': ['negative particle'], 'secondary': ['negative electrode'], 'tertiary': ['current collector']}),
#  'X-averaged negative particle concentration [mol.m-3]': XAverage(0x197d12c616de6887, x-average, children=['Negative particle concentration [mol.m-3]'], domains={'primary': ['negative particle'], 'secondary': ['current collector']}),
#  'R-averaged negative particle concentration [mol.m-3]': RAverage(-0x6ca95964825a216c, r-average, children=['Negative particle concentration [mol.m-3]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Average negative particle concentration [mol.m-3]': RAverage(0x33106fd07917a857, r-average, children=['x-average(Negative particle concentration [mol.m-3])'], domains={'primary': ['current collector']}),
#  'Negative particle surface concentration [mol.m-3]': BoundaryValue(0x108cb20faf916007, boundary value, children=['Negative particle concentration [mol.m-3]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative particle surface concentration [mol.m-3]': XAverage(-0x669dafa2d3f45d51, x-average, children=['boundary value(Negative particle concentration [mol.m-3])'], domains={'primary': ['current collector']}),
#  'Minimum negative particle concentration [mol.m-3]': Min(-0x41f555011b46dae0, function (min), children=['Negative particle concentration [mol.m-3]'], domains={'primary': ['negative particle'], 'secondary': ['negative electrode'], 'tertiary': ['current collector']}),
#  'Maximum negative particle concentration [mol.m-3]': Max(-0x542b8d8835be997c, function (max), children=['Negative particle concentration [mol.m-3]'], domains={'primary': ['negative particle'], 'secondary': ['negative electrode'], 'tertiary': ['current collector']}),
#  'Minimum negative particle Minimum negative particle surface concentration [mol.m-3]': Min(-0x9ec8396574d6e8b, function (min), children=['boundary value(Negative particle concentration [mol.m-3])'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Maximum negative particle surface concentration [mol.m-3]': Max(-0x791b7b1e5cd24815, function (max), children=['boundary value(Negative particle concentration [mol.m-3])'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Negative particle concentration': Division(-0x17051774c5537881, /, children=['Negative particle concentration [mol.m-3]', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative particle'], 'secondary': ['negative electrode'], 'tertiary': ['current collector']}),
#  'X-averaged negative particle concentration': Division(0x73fd61ee52e3e84e, /, children=['x-average(Negative particle concentration [mol.m-3])', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative particle'], 'secondary': ['current collector']}),
#  'R-averaged negative particle concentration': Division(0x4762d940178752f2, /, children=['r-average(Negative particle concentration [mol.m-3])', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Average negative particle concentration': Division(0x43959b7ffe7ee7d5, /, children=['r-average(x-average(Negative particle concentration [mol.m-3]))', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['current collector']}),
#  'Negative particle surface concentration': Division(0x27b9ce0038ca312, /, children=['boundary value(Negative particle concentration [mol.m-3])', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative particle surface concentration': Division(-0x1e571d1da520d2e4, /, children=['x-average(boundary value(Negative particle concentration [mol.m-3]))', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['current collector']}),
#  'Minimum negative particle concentration': Division(0x57de871d40fb491f, /, children=['min(Negative particle concentration [mol.m-3])', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative particle'], 'secondary': ['negative electrode'], 'tertiary': ['current collector']}),
#  'Maximum negative particle concentration': Division(0x349b0bc4b6a1b68c, /, children=['max(Negative particle concentration [mol.m-3])', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative particle'], 'secondary': ['negative electrode'], 'tertiary': ['current collector']}),
#  'Minimum negative particle surface concentration': Division(-0x5960ff29a40221ff, /, children=['min(boundary value(Negative particle concentration [mol.m-3]))', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Maximum negative particle surface concentration': Division(0x5c2e5be14db810e5, /, children=['max(boundary value(Negative particle concentration [mol.m-3]))', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Negative particle stoichiometry': Division(-0x17051774c5537881, /, children=['Negative particle concentration [mol.m-3]', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative particle'], 'secondary': ['negative electrode'], 'tertiary': ['current collector']}),
#  'X-averaged negative particle stoichiometry': Division(0x73fd61ee52e3e84e, /, children=['x-average(Negative particle concentration [mol.m-3])', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative particle'], 'secondary': ['current collector']}),
#  'R-averaged negative particle stoichiometry': Division(0x4762d940178752f2, /, children=['r-average(Negative particle concentration [mol.m-3])', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Average negative particle stoichiometry': Division(0x43959b7ffe7ee7d5, /, children=['r-average(x-average(Negative particle concentration [mol.m-3]))', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['current collector']}),
#  'Negative particle surface stoichiometry': Division(0x27b9ce0038ca312, /, children=['boundary value(Negative particle concentration [mol.m-3])', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative particle surface stoichiometry': Division(-0x1e571d1da520d2e4, /, children=['x-average(boundary value(Negative particle concentration [mol.m-3]))', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['current collector']}),
#  'Minimum negative particle stoichiometry': Division(0x57de871d40fb491f, /, children=['min(Negative particle concentration [mol.m-3])', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative particle'], 'secondary': ['negative electrode'], 'tertiary': ['current collector']}),
#  'Maximum negative particle stoichiometry': Division(0x349b0bc4b6a1b68c, /, children=['max(Negative particle concentration [mol.m-3])', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative particle'], 'secondary': ['negative electrode'], 'tertiary': ['current collector']}),
#  'Minimum negative particle surface stoichiometry': Division(-0x5960ff29a40221ff, /, children=['min(boundary value(Negative particle concentration [mol.m-3]))', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Maximum negative particle surface stoichiometry': Division(0x5c2e5be14db810e5, /, children=['max(boundary value(Negative particle concentration [mol.m-3]))', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Negative electrode extent of lithiation': Division(0x4762d940178752f2, /, children=['r-average(Negative particle concentration [mol.m-3])', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrode extent of lithiation': Division(0x43959b7ffe7ee7d5, /, children=['r-average(x-average(Negative particle concentration [mol.m-3]))', 'Maximum concentration in negative electrode [mol.m-3]'], domains={'primary': ['current collector']}),
#  'Positive particle concentration [mol.m-3]': Variable(-0x375633a583b2ea46, Positive particle concentration [mol.m-3], children=[], domains={'primary': ['positive particle'], 'secondary': ['positive electrode'], 'tertiary': ['current collector']}),
#  'X-averaged positive particle concentration [mol.m-3]': XAverage(0x7431ae9655da0299, x-average, children=['Positive particle concentration [mol.m-3]'], domains={'primary': ['positive particle'], 'secondary': ['current collector']}),
#  'R-averaged positive particle concentration [mol.m-3]': RAverage(0x268f6a3c1c1a9f4c, r-average, children=['Positive particle concentration [mol.m-3]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Average positive particle concentration [mol.m-3]': RAverage(0x603a94d2bdaa14df, r-average, children=['x-average(Positive particle concentration [mol.m-3])'], domains={'primary': ['current collector']}),
#  'Positive particle surface concentration [mol.m-3]': BoundaryValue(-0x6709282fea9e2dcb, boundary value, children=['Positive particle concentration [mol.m-3]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive particle surface concentration [mol.m-3]': XAverage(0xe5fa0a0f87bdf69, x-average, children=['boundary value(Positive particle concentration [mol.m-3])'], domains={'primary': ['current collector']}),
#  'Minimum positive particle concentration [mol.m-3]': Min(0x2b135f924e4385f5, function (min), children=['Positive particle concentration [mol.m-3]'], domains={'primary': ['positive particle'], 'secondary': ['positive electrode'], 'tertiary': ['current collector']}),
#  'Maximum positive particle concentration [mol.m-3]': Max(-0x3b23c400ff261327, function (max), children=['Positive particle concentration [mol.m-3]'], domains={'primary': ['positive particle'], 'secondary': ['positive electrode'], 'tertiary': ['current collector']}),
#  'Minimum positive particle Minimum positive particle surface concentration [mol.m-3]': Min(0x41c1d22acf4694da, function (min), children=['boundary value(Positive particle concentration [mol.m-3])'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Maximum positive particle surface concentration [mol.m-3]': Max(-0x3fae93e3e052b2bb, function (max), children=['boundary value(Positive particle concentration [mol.m-3])'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Positive particle concentration': Division(0x64e11192cb9e7f71, /, children=['Positive particle concentration [mol.m-3]', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive particle'], 'secondary': ['positive electrode'], 'tertiary': ['current collector']}),
#  'X-averaged positive particle concentration': Division(-0x2674ffdf2c9ab176, /, children=['x-average(Positive particle concentration [mol.m-3])', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive particle'], 'secondary': ['current collector']}),
#  'R-averaged positive particle concentration': Division(0x134e6194844a6412, /, children=['r-average(Positive particle concentration [mol.m-3])', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Average positive particle concentration': Division(0x3e1bf1a673bcfc5, /, children=['r-average(x-average(Positive particle concentration [mol.m-3]))', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['current collector']}),
#  'Positive particle surface concentration': Division(-0xa4e3bb0040efba0, /, children=['boundary value(Positive particle concentration [mol.m-3])', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive particle surface concentration': Division(0x6a6d454cea5a3be3, /, children=['x-average(boundary value(Positive particle concentration [mol.m-3]))', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['current collector']}),
#  'Minimum positive particle concentration': Division(-0x3a3342592525fdc6, /, children=['min(Positive particle concentration [mol.m-3])', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive particle'], 'secondary': ['positive electrode'], 'tertiary': ['current collector']}),
#  'Maximum positive particle concentration': Division(-0x1079ca77887df345, /, children=['max(Positive particle concentration [mol.m-3])', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive particle'], 'secondary': ['positive electrode'], 'tertiary': ['current collector']}),
#  'Minimum positive particle surface concentration': Division(-0x35b520972fded90c, /, children=['min(boundary value(Positive particle concentration [mol.m-3]))', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Maximum positive particle surface concentration': Division(-0x29c8603e275fdeb, /, children=['max(boundary value(Positive particle concentration [mol.m-3]))', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Positive particle stoichiometry': Division(0x64e11192cb9e7f71, /, children=['Positive particle concentration [mol.m-3]', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive particle'], 'secondary': ['positive electrode'], 'tertiary': ['current collector']}),
#  'X-averaged positive particle stoichiometry': Division(-0x2674ffdf2c9ab176, /, children=['x-average(Positive particle concentration [mol.m-3])', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive particle'], 'secondary': ['current collector']}),
#  'R-averaged positive particle stoichiometry': Division(0x134e6194844a6412, /, children=['r-average(Positive particle concentration [mol.m-3])', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Average positive particle stoichiometry': Division(0x3e1bf1a673bcfc5, /, children=['r-average(x-average(Positive particle concentration [mol.m-3]))', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['current collector']}),
#  'Positive particle surface stoichiometry': Division(-0xa4e3bb0040efba0, /, children=['boundary value(Positive particle concentration [mol.m-3])', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive particle surface stoichiometry': Division(0x6a6d454cea5a3be3, /, children=['x-average(boundary value(Positive particle concentration [mol.m-3]))', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['current collector']}),
#  'Minimum positive particle stoichiometry': Division(-0x3a3342592525fdc6, /, children=['min(Positive particle concentration [mol.m-3])', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive particle'], 'secondary': ['positive electrode'], 'tertiary': ['current collector']}),
#  'Maximum positive particle stoichiometry': Division(-0x1079ca77887df345, /, children=['max(Positive particle concentration [mol.m-3])', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive particle'], 'secondary': ['positive electrode'], 'tertiary': ['current collector']}),
#  'Minimum positive particle surface stoichiometry': Division(-0x35b520972fded90c, /, children=['min(boundary value(Positive particle concentration [mol.m-3]))', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Maximum positive particle surface stoichiometry': Division(-0x29c8603e275fdeb, /, children=['max(boundary value(Positive particle concentration [mol.m-3]))', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Positive electrode extent of lithiation': Division(0x134e6194844a6412, /, children=['r-average(Positive particle concentration [mol.m-3])', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrode extent of lithiation': Division(0x3e1bf1a673bcfc5, /, children=['r-average(x-average(Positive particle concentration [mol.m-3]))', 'Maximum concentration in positive electrode [mol.m-3]'], domains={'primary': ['current collector']}),
#  'Negative electrode potential [V]': Variable(-0x332d5b52049fc4dd, Negative electrode potential [V], children=[], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrode potential [V]': XAverage(-0x3c19e26aee2319ef, x-average, children=['Negative electrode potential [V]'], domains={'primary': ['current collector']}),
#  'Negative electrode ohmic losses [V]': Subtraction(0xed9c30389c5ede6, -, children=['broadcast(boundary value(Negative electrode potential [V]))', 'Negative electrode potential [V]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrode ohmic losses [V]': Subtraction(-0x6a22f18b95eaa227, -, children=['boundary value(Negative electrode potential [V])', 'x-average(Negative electrode potential [V])'], domains={'primary': ['current collector']}),
#  'Gradient of negative electrode potential [V.m-1]': Gradient(0x2a90a855a79c8c90, grad, children=['Negative electrode potential [V]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Positive electrode potential [V]': Variable(0x71608f04265575c6, Positive electrode potential [V], children=[], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrode potential [V]': XAverage(-0x553a9e3715cccce, x-average, children=['Positive electrode potential [V]'], domains={'primary': ['current collector']}),
#  'Positive electrode ohmic losses [V]': Subtraction(0x7784268f12f79798, -, children=['broadcast(boundary value(Positive electrode potential [V]))', 'Positive electrode potential [V]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrode ohmic losses [V]': Subtraction(-0xfecce251d869bbf, -, children=['boundary value(Positive electrode potential [V])', 'x-average(Positive electrode potential [V])'], domains={'primary': ['current collector']}),
#  'Gradient of positive electrode potential [V.m-1]': Gradient(-0x5237f5056db0b0e1, grad, children=['Positive electrode potential [V]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Porosity times concentration [mol.m-3]': ConcatenationVariable(-0x600ee59efff8d120, Porosity times concentration [mol.m-3], children=['Negative electrode porosity times concentration [mol.m-3]', 'Separator porosity times concentration [mol.m-3]', 'Positive electrode porosity times concentration [mol.m-3]'], domains={'primary': ['negative electrode', 'separator', 'positive electrode'], 'secondary': ['current collector']}),
#  'Negative electrode porosity times concentration [mol.m-3]': Variable(0x785dfacdaa8c5a56, Negative electrode porosity times concentration [mol.m-3], children=[], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Separator porosity times concentration [mol.m-3]': Variable(-0x327e940851eb6fa2, Separator porosity times concentration [mol.m-3], children=[], domains={'primary': ['separator'], 'secondary': ['current collector']}),
#  'Positive electrode porosity times concentration [mol.m-3]': Variable(0x4ba1a4ee02525470, Positive electrode porosity times concentration [mol.m-3], children=[], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Total lithium in electrolyte [mol]': Multiplication(0x25ecc2ee5ef4efbd, *, children=['(Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]) * Electrode width [m] * Electrode height [m]', 'yz-average(x-average(Porosity times concentration [mol.m-3](Negative electrode porosity times concentration [mol.m-3], Separator porosity times concentration [mol.m-3], Positive electrode porosity times concentration [mol.m-3])))'], domains={}),
#  'Electrolyte potential [V]': ConcatenationVariable(0x268d7765fff04872, Electrolyte potential [V], children=['Negative electrolyte potential [V]', 'Separator electrolyte potential [V]', 'Positive electrolyte potential [V]'], domains={'primary': ['negative electrode', 'separator', 'positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged electrolyte potential [V]': XAverage(0x5465e5f5efce06, x-average, children=['Electrolyte potential [V](Negative electrolyte potential [V], Separator electrolyte potential [V], Positive electrolyte potential [V])'], domains={'primary': ['current collector']}),
#  'X-averaged electrolyte overpotential [V]': Subtraction(-0x43527954f8e198ca, -, children=['x-average(Positive electrolyte potential [V])', 'x-average(Negative electrolyte potential [V])'], domains={'primary': ['current collector']}),
#  'Gradient of electrolyte potential [V.m-1]': Gradient(0x16ed728c7605df3f, grad, children=['Electrolyte potential [V](Negative electrolyte potential [V], Separator electrolyte potential [V], Positive electrolyte potential [V])'], domains={'primary': ['negative electrode', 'separator', 'positive electrode'], 'secondary': ['current collector']}),
#  'Negative electrolyte potential [V]': Variable(0x13fbeafd0fa7ece3, Negative electrolyte potential [V], children=[], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrolyte potential [V]': XAverage(-0x62a3164edae6be97, x-average, children=['Negative electrolyte potential [V]'], domains={'primary': ['current collector']}),
#  'Gradient of negative electrolyte potential [V.m-1]': Gradient(0x1da4408551d069f2, grad, children=['Negative electrolyte potential [V]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Separator electrolyte potential [V]': Variable(-0x1f3cb3468293738c, Separator electrolyte potential [V], children=[], domains={'primary': ['separator'], 'secondary': ['current collector']}),
#  'X-averaged separator electrolyte potential [V]': XAverage(0x6df401804523b237, x-average, children=['Separator electrolyte potential [V]'], domains={'primary': ['current collector']}),
#  'Gradient of separator electrolyte potential [V.m-1]': Gradient(0x4f4cf0da28f5b177, grad, children=['Separator electrolyte potential [V]'], domains={'primary': ['separator'], 'secondary': ['current collector']}),
#  'Positive electrolyte potential [V]': Variable(-0xbcc25e043932f4c, Positive electrolyte potential [V], children=[], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrolyte potential [V]': XAverage(-0x564b7371c0e9b7e9, x-average, children=['Positive electrolyte potential [V]'], domains={'primary': ['current collector']}),
#  'Gradient of positive electrolyte potential [V.m-1]': Gradient(-0x1c38e6109f389464, grad, children=['Positive electrolyte potential [V]'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Ambient temperature [K]': FunctionParameter(-0x57b2d51e9ee40aca, Ambient temperature [K], children=['y', 'z', 'time'], domains={'primary': ['current collector']}),
#  'Volume-averaged ambient temperature [K]': ZAverage(-0x1e2bb4e8142b5baa, z-average, children=['Ambient temperature [K]'], domains={}),
#  'Cell temperature [K]': PrimaryBroadcast(-0x5bcdcba7619c008b, broadcast, children=['broadcast(Volume-averaged cell temperature [K])'], domains={'primary': ['negative electrode', 'separator', 'positive electrode'], 'secondary': ['current collector']}),
#  'Negative current collector temperature [K]': PrimaryBroadcast(0x238553c156b25588, broadcast, children=['Volume-averaged cell temperature [K]'], domains={'primary': ['current collector']}),
#  'Positive current collector temperature [K]': PrimaryBroadcast(0x238553c156b25588, broadcast, children=['Volume-averaged cell temperature [K]'], domains={'primary': ['current collector']}),
#  'X-averaged cell temperature [K]': PrimaryBroadcast(0x238553c156b25588, broadcast, children=['Volume-averaged cell temperature [K]'], domains={'primary': ['current collector']}),
#  'Volume-averaged cell temperature [K]': Variable(-0x7029b50938ea6f14, Volume-averaged cell temperature [K], children=[], domains={}),
#  'Negative electrode temperature [K]': PrimaryBroadcast(-0x3215167b36d2619a, broadcast, children=['broadcast(Volume-averaged cell temperature [K])'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrode temperature [K]': PrimaryBroadcast(0x238553c156b25588, broadcast, children=['Volume-averaged cell temperature [K]'], domains={'primary': ['current collector']}),
#  'Separator temperature [K]': PrimaryBroadcast(-0x2371dd8bc9e32d58, broadcast, children=['broadcast(Volume-averaged cell temperature [K])'], domains={'primary': ['separator'], 'secondary': ['current collector']}),
#  'X-averaged separator temperature [K]': PrimaryBroadcast(0x238553c156b25588, broadcast, children=['Volume-averaged cell temperature [K]'], domains={'primary': ['current collector']}),
#  'Positive electrode temperature [K]': PrimaryBroadcast(-0x7dec29994137550, broadcast, children=['broadcast(Volume-averaged cell temperature [K])'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrode temperature [K]': PrimaryBroadcast(0x238553c156b25588, broadcast, children=['Volume-averaged cell temperature [K]'], domains={'primary': ['current collector']}),
#  'Ambient temperature [C]': Addition(0x18b764937f885714, +, children=['-273.15', 'Ambient temperature [K]'], domains={'primary': ['current collector']}),
#  'Volume-averaged ambient temperature [C]': Addition(-0x1d00ecccf6830934, +, children=['-273.15', 'z-average(Ambient temperature [K])'], domains={}),
#  'Cell temperature [C]': PrimaryBroadcast(-0x22d704a2d43acdd9, broadcast, children=['broadcast(-273.15 + Volume-averaged cell temperature [K])'], domains={'primary': ['negative electrode', 'separator', 'positive electrode'], 'secondary': ['current collector']}),
#  'Negative current collector temperature [C]': PrimaryBroadcast(0x7e1fa2b382fef1ba, broadcast, children=['-273.15 + Volume-averaged cell temperature [K]'], domains={'primary': ['current collector']}),
#  'Positive current collector temperature [C]': PrimaryBroadcast(0x7e1fa2b382fef1ba, broadcast, children=['-273.15 + Volume-averaged cell temperature [K]'], domains={'primary': ['current collector']}),
#  'X-averaged cell temperature [C]': PrimaryBroadcast(0x7e1fa2b382fef1ba, broadcast, children=['-273.15 + Volume-averaged cell temperature [K]'], domains={'primary': ['current collector']}),
#  'Volume-averaged cell temperature [C]': Addition(0x1e4cbdcda27c4a5c, +, children=['-273.15', 'Volume-averaged cell temperature [K]'], domains={}),
#  'Negative electrode temperature [C]': PrimaryBroadcast(0x5668c851268e9886, broadcast, children=['broadcast(-273.15 + Volume-averaged cell temperature [K])'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative electrode temperature [C]': PrimaryBroadcast(0x7e1fa2b382fef1ba, broadcast, children=['-273.15 + Volume-averaged cell temperature [K]'], domains={'primary': ['current collector']}),
#  'Separator temperature [C]': PrimaryBroadcast(0x9d29d4df0690b42, broadcast, children=['broadcast(-273.15 + Volume-averaged cell temperature [K])'], domains={'primary': ['separator'], 'secondary': ['current collector']}),
#  'X-averaged separator temperature [C]': PrimaryBroadcast(0x7e1fa2b382fef1ba, broadcast, children=['-273.15 + Volume-averaged cell temperature [K]'], domains={'primary': ['current collector']}),
#  'Positive electrode temperature [C]': PrimaryBroadcast(0x3118046af94dbd62, broadcast, children=['broadcast(-273.15 + Volume-averaged cell temperature [K])'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive electrode temperature [C]': PrimaryBroadcast(0x7e1fa2b382fef1ba, broadcast, children=['-273.15 + Volume-averaged cell temperature [K]'], domains={'primary': ['current collector']}),
#  'Negative current collector potential [V]': PrimaryBroadcast(0x1dec22bbb55b4e23, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'Negative inner SEI thickness [m]': Variable(0x1564decbddaddfd, Negative inner SEI thickness [m], children=[], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Negative outer SEI thickness [m]': Variable(0x7b0f11f6fc943c3a, Negative outer SEI thickness [m], children=[], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative inner SEI thickness [m]': XAverage(0x27021890f4d07430, x-average, children=['Negative inner SEI thickness [m]'], domains={'primary': ['current collector']}),
#  'X-averaged negative outer SEI thickness [m]': XAverage(-0x55c03c253ed50988, x-average, children=['Negative outer SEI thickness [m]'], domains={'primary': ['current collector']}),
#  'Negative SEI [m]': Addition(-0x7ae5f6db6e7084e, +, children=['Negative inner SEI thickness [m]', 'Negative outer SEI thickness [m]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'Negative total SEI thickness [m]': Addition(-0x7ae5f6db6e7084e, +, children=['Negative inner SEI thickness [m]', 'Negative outer SEI thickness [m]'], domains={'primary': ['negative electrode'], 'secondary': ['current collector']}),
#  'X-averaged negative SEI thickness [m]': Addition(0x1f1e2235b88948d8, +, children=['x-average(Negative inner SEI thickness [m])', 'x-average(Negative outer SEI thickness [m])'], domains={'primary': ['current collector']}),
#  'X-averaged negative total SEI thickness [m]': Addition(0x1f1e2235b88948d8, +, children=['x-average(Negative inner SEI thickness [m])', 'x-average(Negative outer SEI thickness [m])'], domains={'primary': ['current collector']}),
#  'X-averaged negative electrode resistance [Ohm.m2]': Multiplication(0x3e89f7a8263fd868, *, children=['x-average(Negative inner SEI thickness [m]) + x-average(Negative outer SEI thickness [m])', 'SEI resistivity [Ohm.m]'], domains={'primary': ['current collector']}),
#  'Positive inner SEI thickness [m]': FullBroadcast(-0x5480964e4a65cac7, broadcast, children=['0.0'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'Positive outer SEI thickness [m]': FullBroadcast(-0x5480964e4a65cac7, broadcast, children=['0.0'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
#  'X-averaged positive inner SEI thickness [m]': PrimaryBroadcast(0x1dec22bbb55b4e23, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'X-averaged positive outer SEI thickness [m]': PrimaryBroadcast(0x1dec22bbb55b4e23, broadcast, children=['0.0'], domains={'primary': ['current collector']}),
#  'Positive SEI [m]': FullBroadcast(-0x5480964e4a65cac7, broadcast, children=['0.0'], domains={'primary': ['positive electrode'], 'secondary': ['current collector']}),
# ...
#  'Loss of lithium inventory [%]': Subtraction(-0x1c5f7fa2e6ef3775, -, children=['100.0', '100.0 * (yz-average(x-average(Negative electrode active material volume fraction * r-average(Negative particle concentration [mol.m-3]))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] + yz-average(x-average(Positive electrode active material volume fraction * r-average(Positive particle concentration [mol.m-3]))) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m]) / (yz-average(x-average(Negative electrode active material volume fraction * r-average(Initial concentration in negative electrode [mol.m-3]))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] + yz-average(x-average(Positive electrode active material volume fraction * r-average(Initial concentration in positive electrode [mol.m-3]))) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m])'], domains={}),
#  'Loss of lithium inventory, including electrolyte [%]': Subtraction(-0x3744d4ddddf5f061, -, children=['100.0', '100.0 * (yz-average(x-average(Negative electrode active material volume fraction * r-average(Negative particle concentration [mol.m-3]))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] + yz-average(x-average(Positive electrode active material volume fraction * r-average(Positive particle concentration [mol.m-3]))) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m] + (Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]) * Electrode width [m] * Electrode height [m] * yz-average(x-average(Porosity times concentration [mol.m-3](Negative electrode porosity times concentration [mol.m-3], Separator porosity times concentration [mol.m-3], Positive electrode porosity times concentration [mol.m-3])))) / (yz-average(x-average(Negative electrode active material volume fraction * r-average(Initial concentration in negative electrode [mol.m-3]))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] + yz-average(x-average(Positive electrode active material volume fraction * r-average(Initial concentration in positive electrode [mol.m-3]))) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m] + yz-average((Negative electrode thickness [m] * x-average(Negative electrode porosity) + Separator thickness [m] * x-average(Separator porosity) + Positive electrode thickness [m] * x-average(Positive electrode porosity)) / (Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m])) * Initial concentration in electrolyte [mol.m-3] * (Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]) * Electrode width [m] * Electrode height [m])'], domains={}),
#  'Total lithium [mol]': Addition(-0x4d5d5ccac0d93495, +, children=['yz-average(x-average(Negative electrode active material volume fraction * r-average(Negative particle concentration [mol.m-3]))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] + yz-average(x-average(Positive electrode active material volume fraction * r-average(Positive particle concentration [mol.m-3]))) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m]', '(Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]) * Electrode width [m] * Electrode height [m] * yz-average(x-average(Porosity times concentration [mol.m-3](Negative electrode porosity times concentration [mol.m-3], Separator porosity times concentration [mol.m-3], Positive electrode porosity times concentration [mol.m-3])))'], domains={}),
#  'Total lithium in particles [mol]': Addition(0x36685a872daf457c, +, children=['yz-average(x-average(Negative electrode active material volume fraction * r-average(Negative particle concentration [mol.m-3]))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m]', 'yz-average(x-average(Positive electrode active material volume fraction * r-average(Positive particle concentration [mol.m-3]))) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m]'], domains={}),
#  'Total lithium capacity [A.h]': Multiplication(0x59b741a1e292167b, *, children=['0.0002777777777777778', '(yz-average(x-average(Negative electrode active material volume fraction * r-average(Negative particle concentration [mol.m-3]))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] + yz-average(x-average(Positive electrode active material volume fraction * r-average(Positive particle concentration [mol.m-3]))) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m] + (Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]) * Electrode width [m] * Electrode height [m] * yz-average(x-average(Porosity times concentration [mol.m-3](Negative electrode porosity times concentration [mol.m-3], Separator porosity times concentration [mol.m-3], Positive electrode porosity times concentration [mol.m-3])))) * Faraday constant [C.mol-1]'], domains={}),
#  'Total lithium capacity in particles [A.h]': Multiplication(0x579e6efa49179211, *, children=['0.0002777777777777778', '(yz-average(x-average(Negative electrode active material volume fraction * r-average(Negative particle concentration [mol.m-3]))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] + yz-average(x-average(Positive electrode active material volume fraction * r-average(Positive particle concentration [mol.m-3]))) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m]) * Faraday constant [C.mol-1]'], domains={}),
#  'Total lithium lost [mol]': Subtraction(0x71b1fb5816525706, -, children=['yz-average(x-average(Negative electrode active material volume fraction * r-average(Initial concentration in negative electrode [mol.m-3]))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] + yz-average(x-average(Positive electrode active material volume fraction * r-average(Initial concentration in positive electrode [mol.m-3]))) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m] + yz-average((Negative electrode thickness [m] * x-average(Negative electrode porosity) + Separator thickness [m] * x-average(Separator porosity) + Positive electrode thickness [m] * x-average(Positive electrode porosity)) / (Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m])) * Initial concentration in electrolyte [mol.m-3] * (Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]) * Electrode width [m] * Electrode height [m]', 'yz-average(x-average(Negative electrode active material volume fraction * r-average(Negative particle concentration [mol.m-3]))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] + yz-average(x-average(Positive electrode active material volume fraction * r-average(Positive particle concentration [mol.m-3]))) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m] + (Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]) * Electrode width [m] * Electrode height [m] * yz-average(x-average(Porosity times concentration [mol.m-3](Negative electrode porosity times concentration [mol.m-3], Separator porosity times concentration [mol.m-3], Positive electrode porosity times concentration [mol.m-3])))'], domains={}),
#  'Total lithium lost from particles [mol]': Subtraction(-0x7f6a98bede483d6, -, children=['yz-average(x-average(Negative electrode active material volume fraction * r-average(Initial concentration in negative electrode [mol.m-3]))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] + yz-average(x-average(Positive electrode active material volume fraction * r-average(Initial concentration in positive electrode [mol.m-3]))) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m]', 'yz-average(x-average(Negative electrode active material volume fraction * r-average(Negative particle concentration [mol.m-3]))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] + yz-average(x-average(Positive electrode active material volume fraction * r-average(Positive particle concentration [mol.m-3]))) * Positive electrode thickness [m] * Electrode width [m] * Electrode height [m]'], domains={}),
#  'Total lithium lost from electrolyte [mol]': Subtraction(-0x654b64df9c18913c, -, children=['yz-average((Negative electrode thickness [m] * x-average(Negative electrode porosity) + Separator thickness [m] * x-average(Separator porosity) + Positive electrode thickness [m] * x-average(Positive electrode porosity)) / (Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m])) * Initial concentration in electrolyte [mol.m-3] * (Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]) * Electrode width [m] * Electrode height [m]', '(Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]) * Electrode width [m] * Electrode height [m] * yz-average(x-average(Porosity times concentration [mol.m-3](Negative electrode porosity times concentration [mol.m-3], Separator porosity times concentration [mol.m-3], Positive electrode porosity times concentration [mol.m-3])))'], domains={}),
#  'Total lithium lost to side reactions [mol]': Addition(0x28a24daa9bbb9eed, +, children=['Ratio of lithium moles to SEI moles * (yz-average(x-average(Negative inner SEI thickness [m] * 3.0 * Negative electrode active material volume fraction / Negative particle radius [m] / Inner SEI partial molar volume [m3.mol-1])) + yz-average(x-average(Negative outer SEI thickness [m] * 3.0 * Negative electrode active material volume fraction / Negative particle radius [m] / Outer SEI partial molar volume [m3.mol-1])) - (Initial inner SEI thickness [m] * 3.0 * yz-average(x-average(Negative electrode active material volume fraction)) / Negative particle radius [m] / Inner SEI partial molar volume [m3.mol-1] + Initial outer SEI thickness [m] * 3.0 * yz-average(x-average(Negative electrode active material volume fraction)) / Negative particle radius [m] / Outer SEI partial molar volume [m3.mol-1])) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m]', 'Ratio of lithium moles to SEI moles * (yz-average(x-average(Negative inner SEI on cracks thickness [m] * 3.0 * Negative electrode active material volume fraction / Negative particle radius [m] / Inner SEI partial molar volume [m3.mol-1] * 2.0 * Negative particle crack length [m] * Negative electrode number of cracks per unit area [m-2] * Negative electrode initial crack width [m])) + yz-average(x-average(Negative outer SEI on cracks thickness [m] * 3.0 * Negative electrode active material volume fraction / Negative particle radius [m] / Outer SEI partial molar volume [m3.mol-1] * 2.0 * Negative particle crack length [m] * Negative electrode number of cracks per unit area [m-2] * Negative electrode initial crack width [m])) - ((Initial inner SEI on cracks thickness [m] * 3.0 * yz-average(x-average(Negative electrode active material volume fraction)) / Negative particle radius [m] / Inner SEI partial molar volume [m3.mol-1] + Initial outer SEI on cracks thickness [m] * 3.0 * yz-average(x-average(Negative electrode active material volume fraction)) / Negative particle radius [m] / Outer SEI partial molar volume [m3.mol-1]) * yz-average(x-average(2.0 * Negative particle crack length [m] * Negative electrode number of cracks per unit area [m-2] * Negative electrode initial crack width [m])))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] + x-average(Negative lithium plating concentration [mol.m-3]) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] + x-average(Negative dead lithium concentration [mol.m-3]) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m]'], domains={'primary': ['current collector']}),
#  'Total capacity lost to side reactions [A.h]': Multiplication(0x3debbfa6531c53aa, *, children=['0.0002777777777777778', '(Ratio of lithium moles to SEI moles * (yz-average(x-average(Negative inner SEI thickness [m] * 3.0 * Negative electrode active material volume fraction / Negative particle radius [m] / Inner SEI partial molar volume [m3.mol-1])) + yz-average(x-average(Negative outer SEI thickness [m] * 3.0 * Negative electrode active material volume fraction / Negative particle radius [m] / Outer SEI partial molar volume [m3.mol-1])) - (Initial inner SEI thickness [m] * 3.0 * yz-average(x-average(Negative electrode active material volume fraction)) / Negative particle radius [m] / Inner SEI partial molar volume [m3.mol-1] + Initial outer SEI thickness [m] * 3.0 * yz-average(x-average(Negative electrode active material volume fraction)) / Negative particle radius [m] / Outer SEI partial molar volume [m3.mol-1])) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] + Ratio of lithium moles to SEI moles * (yz-average(x-average(Negative inner SEI on cracks thickness [m] * 3.0 * Negative electrode active material volume fraction / Negative particle radius [m] / Inner SEI partial molar volume [m3.mol-1] * 2.0 * Negative particle crack length [m] * Negative electrode number of cracks per unit area [m-2] * Negative electrode initial crack width [m])) + yz-average(x-average(Negative outer SEI on cracks thickness [m] * 3.0 * Negative electrode active material volume fraction / Negative particle radius [m] / Outer SEI partial molar volume [m3.mol-1] * 2.0 * Negative particle crack length [m] * Negative electrode number of cracks per unit area [m-2] * Negative electrode initial crack width [m])) - ((Initial inner SEI on cracks thickness [m] * 3.0 * yz-average(x-average(Negative electrode active material volume fraction)) / Negative particle radius [m] / Inner SEI partial molar volume [m3.mol-1] + Initial outer SEI on cracks thickness [m] * 3.0 * yz-average(x-average(Negative electrode active material volume fraction)) / Negative particle radius [m] / Outer SEI partial molar volume [m3.mol-1]) * yz-average(x-average(2.0 * Negative particle crack length [m] * Negative electrode number of cracks per unit area [m-2] * Negative electrode initial crack width [m])))) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] + x-average(Negative lithium plating concentration [mol.m-3]) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m] + x-average(Negative dead lithium concentration [mol.m-3]) * Negative electrode thickness [m] * Electrode width [m] * Electrode height [m]) * Faraday constant [C.mol-1]'], domains={'primary': ['current collector']})}

# %%
cycles_df
# Out:
#              Mode  RelativeTime   Voltage          I        Q_dis     Q_cha  \
# Cycle Step
# 1     1       1.0  0.000000e+00  2.680430  1407.8055     0.000000  0.000078
#       2       1.0  8.400000e-03  2.690530  1574.4427     0.000000  0.003691
#       3       1.0  2.940000e-02  2.700598  1640.2499     0.000000  0.013108
#       4       1.0  6.340000e-02  2.710643  1664.4644     0.000000  0.028749
#       5       1.0  1.074000e-01  2.720645  1668.5892     0.000000  0.049123
# ...           ...           ...       ...        ...          ...       ...
# 105   14017   1.0  1.510170e+06  2.517027 -4997.5547  4461.105642  0.000000
#       14018   1.0  1.510171e+06  2.510488 -4997.8223  4462.493874  0.000000
#       14019   1.0  1.510172e+06  2.503801 -4997.8223  4463.882105  0.000000
#       14020   1.0  1.510173e+06  2.499954 -4997.1729  4464.662006  0.000000
#       14021   1.0  1.510173e+06  2.499981 -4997.4785  4464.662284  0.000000
#
#                      Cap         R    Pressure  Temperature
# Cycle Step
# 1     1         0.000078  1.903978  159.026607      25.3794
#       2         0.003691  1.708878  158.944819      25.3885
#       3         0.013108  1.646455  158.998347      25.4014
#       4         0.028749  1.628537  159.049016      25.4088
#       5         0.049123  1.630506  158.990980      25.4014
# ...                  ...       ...         ...          ...
# 105   14017  4461.105642  0.503652  278.040252      30.8711
#       14018  4462.493874  0.502316  277.965417      30.8656
#       14019  4463.882105  0.500978  277.965771      30.8428
#       14020  4464.662006  0.500274  277.854785      30.8390
#       14021  4464.662284  0.500248  277.859008      30.8190
#
# [1512250 rows x 10 columns]

# %%
# Compare model data to experiment

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(13, 4))

# plot the 1C results
t_sol = sol["Time [s]"].entries


ax1.plot(t_sol, (-1) * sol["Current variable [A]"](t_sol))
ax1.plot(cycles_df.loc[1]["RelativeTime"],cycles_df.loc[1]["I"]/1000, "o")
ax1.set_xlabel("Time [s]")
ax1.set_ylabel("Voltage [V]")
ax1.set_title("Voltage")
ax1.legend(["Model", "Experiment"], loc="best")


ax2.plot(t_sol, sol["X-averaged cell temperature [C]"](t_sol))
ax2.plot(cycles_df.loc[1]["RelativeTime"],cycles_df.loc[1]["Temperature"], "o")
ax2.set_xlabel("Time [s]")
ax2.set_ylabel("Temperature [degC]")
ax2.set_title("Temperature")
ax2.legend(["Model", "Experiment"], loc="best")

plt.tight_layout()
plt.show()

# %% [markdown]
# 下面是处理源数据的方法

# %%
import os
import pandas as pd
# 读取 CSV 文件
cwd = os.getcwd()
csv_file_path = cwd + '/exp_LG/allData_C7_removefront.csv'
Cell_7 = pd.read_csv(csv_file_path)

# %%
# import os
# import pandas as pd
# # 读取 CSV 文件
# cwd = os.getcwd()
# csv_file_path = cwd + '/docs/source/examples/notebooks/models/exp_LG/allData_C7_removefront.csv'
# Cell_7 = pd.read_csv(csv_file_path)

# %%
# Cell_7['RelativeTime'] = Cell_7['RelativeTime'] - Cell_7['RelativeTime'][0]

# %%
# # 定义存储循环的列表
# cycles = []
# current_cycle = []
# charging = False

# # 遍历 DataFrame，识别循环
# for i, row in Cell_7.iterrows():
#     if row['Q_cha'] > 0 and not charging:
#         # 开始充电
#         charging = True
#         if current_cycle:
#             cycles.append(current_cycle)
#         current_cycle = [row]
#     elif row['Q_dis'] > 0 and charging:
#         # 结束充电，开始放电
#         charging = False
#         current_cycle.append(row)
#     else:
#         # 在当前循环中添加行
#         current_cycle.append(row)

# # 添加最后一个循环
# if current_cycle:
#     cycles.append(current_cycle)

# # 将循环数据转换为带有 MultiIndex 的 DataFrame
# cycle_data = []
# for cycle_num, cycle in enumerate(cycles):
#     for step_num, row in enumerate(cycle):
#         cycle_data.append((cycle_num + 1, step_num + 1, *row.values))

# # 定义多重索引
# multi_index = pd.MultiIndex.from_tuples(
#     [(cycle, step) for cycle, step, *rest in cycle_data],
#     names=['Cycle', 'Step']
# )

# # 定义 DataFrame 列名
# columns = ['Mode', 'RelativeTime', 'Voltage', 'I', 'Q_dis', 'Q_cha', 'Cap', 'R', 'Pressure', 'Temperature']

# # 创建最终的 DataFrame
# cycles_df = pd.DataFrame([rest for cycle, step, *rest in cycle_data], index=multi_index, columns=columns)

# # 打印前几行以验证
# print(cycles_df.head())

# # 示例：访问第一个循环的数据
# cycle_1_data = cycles_df.loc[1]
# print("\nCycle 1 Data:")
# print(cycle_1_data)

# # 示例：访问第一个循环的第一步数据
# cycle_1_step_1_data = cycles_df.loc[(1, 1)]
# print("\nCycle 1 Step 1 Data:")
# print(cycle_1_step_1_data)

# %%
# 将 DataFrame 存储为 pickle 文件
# pickle_file_path = cwd + '/exp_LG/processed_data.pkl'
# cycles_df.to_pickle(pickle_file_path)
# print(f"DataFrame saved to {pickle_file_path}")

# %%
# 将 DataFrame 存储为 pickle 文件
# pickle_file_path = cwd + '/docs/source/examples/notebooks/models/exp_LG/processed_data.pkl'
# cycles_df.to_pickle(pickle_file_path)
# print(f"DataFrame saved to {pickle_file_path}")
