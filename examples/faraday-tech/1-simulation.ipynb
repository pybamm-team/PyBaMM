# %% [markdown]
# # Running a simulation

# %%
import pybamm

# %%
model = pybamm.lithium_ion.DFN()

# %%
sim = pybamm.Simulation(model)

# %%
sim.solve()

# %% [markdown]
# You can create a slider plot of the results. Note there is a new bug that means variables which depend of space do not update with the slider in notebooks. We are working to fix this!

# %%
sim.plot()
# Out:
# interactive(children=(FloatSlider(value=0.0, description='t', max=1.0, step=0.01), Output()), _dom_classes=('w…

# %% [markdown]
# You can pass a list of variables to the plot command. To see all the variables in a model, type

# %%
model.variables
# Out:
# {'Time': Time(0x73c189e5a355094a, time, children=[], domain=[], auxiliary_domains={}),
#  'Time [s]': Multiplication(0x674c74be3b18e7ee, *, children=['time', '96485.33212 * Maximum concentration in negative electrode [mol.m-3] * Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m] / function (absolute)'], domain=[], auxiliary_domains={}),
#  'Time [min]': Division(0x695bffe4e60a6abb, /, children=['time * 96485.33212 * Maximum concentration in negative electrode [mol.m-3] * Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m] / function (absolute)', '60.0'], domain=[], auxiliary_domains={}),
#  'Time [h]': Division(0x6cbbec9fe6975e77, /, children=['time * 96485.33212 * Maximum concentration in negative electrode [mol.m-3] * Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m] / function (absolute)', '3600.0'], domain=[], auxiliary_domains={}),
#  'x': SpatialVariable(-0x10ef8b2e36d1708a, x, children=[], domain=['negative electrode', 'separator', 'positive electrode'], auxiliary_domains={'secondary': "['current collector']"}),
#  'x [m]': Multiplication(-0x3d4f5718a05ce244, *, children=['x', 'Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]'], domain=['negative electrode', 'separator', 'positive electrode'], auxiliary_domains={'secondary': "['current collector']"}),
#  'x_n': SpatialVariable(-0x2f59c0b6daeebef1, x_n, children=[], domain=['negative electrode'], auxiliary_domains={'secondary': "['current collector']"}),
#  'x_n [m]': Multiplication(-0x7845f53431e15feb, *, children=['x_n', 'Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]'], domain=['negative electrode'], auxiliary_domains={'secondary': "['current collector']"}),
#  'x_s': SpatialVariable(0x45c184b3f69bd571, x_s, children=[], domain=['separator'], auxiliary_domains={'secondary': "['current collector']"}),
#  'x_s [m]': Multiplication(-0x7ac66dc7814a7b5a, *, children=['x_s', 'Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]'], domain=['separator'], auxiliary_domains={'secondary': "['current collector']"}),
#  'x_p': SpatialVariable(-0x8697df8ee635788, x_p, children=[], domain=['positive electrode'], auxiliary_domains={'secondary': "['current collector']"}),
#  'x_p [m]': Multiplication(-0x43bd94edddd7efa6, *, children=['x_p', 'Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]'], domain=['positive electrode'], auxiliary_domains={'secondary': "['current collector']"}),
#  'Sum of electrolyte reaction source terms': Addition(0x48b8323321b21e90, +, children=['0.0 + concatenation * concatenation + concatenation * concatenation', 'concatenation * concatenation'], domain=['negative electrode', 'separator', 'positive electrode'], auxiliary_domains={'secondary': "['current collector']"}),
#  'Sum of negative electrode electrolyte reaction source terms': Addition(0x1ebd71a7052e1365, +, children=['0.0 + 1.0 * broadcast(0.0) + broadcast(0.0) + 1.0 * 2.0 * 2e-05 * function (exp) * Negative electrolyte concentration * Typical electrolyte concentration [mol.m-3] ** 0.5 * boundary value(Negative particle concentration) * Maximum concentration in negative electrode [mol.m-3] ** 0.5 * Maximum concentration in negative electrode [mol.m-3] - boundary value(Negative particle concentration) * Maximum concentration in negative electrode [mol.m-3] ** 0.5 / 0.0706870030399418 * Maximum concentration in negative electrode [mol.m-3] - Maximum concentration in negative electrode [mol.m-3] / 2.0 ** 0.5 * 2.0 / 96485.33212 * Maximum concentration in negative electrode [mol.m-3] / 0.0706870030399418 * Maximum concentration in negative electrode [mol.m-3] - Maximum concentration in negative electrode [mol.m-3] / 2.0 ** 0.5 * 2.0 * Negative electrode surface area to volume ratio [m-1] / 96485.33212 * Maximum concentration in negative electrode [mol.m-3] * Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m] / function (absolute) * function (sinh)', '0.0 * broadcast(0.0)'], domain=['negative electrode'], auxiliary_domains={'secondary': "['current collector']"}),
#  'Sum of positive electrode electrolyte reaction source terms': Addition(-0x42d450ef85d7c4c1, +, children=['0.0 + 1.0 * broadcast(0.0) + broadcast(0.0) + 1.0 * 2.0 * Maximum concentration in positive electrode [mol.m-3] / Maximum concentration in negative electrode [mol.m-3] * 6e-07 * function (exp) * Positive electrolyte concentration * Typical electrolyte concentration [mol.m-3] ** 0.5 * boundary value(Positive particle concentration) * Maximum concentration in positive electrode [mol.m-3] ** 0.5 * Maximum concentration in positive electrode [mol.m-3] - boundary value(Positive particle concentration) * Maximum concentration in positive electrode [mol.m-3] ** 0.5 / 0.0030363179398025745 * Maximum concentration in positive electrode [mol.m-3] - Maximum concentration in positive electrode [mol.m-3] / 2.0 ** 0.5 * 2.0 / 96485.33212 * Maximum concentration in positive electrode [mol.m-3] / 0.0030363179398025745 * Maximum concentration in positive electrode [mol.m-3] - Maximum concentration in positive electrode [mol.m-3] / 2.0 ** 0.5 * 2.0 * Positive electrode surface area to volume ratio [m-1] / 96485.33212 * Maximum concentration in negative electrode [mol.m-3] * Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m] / function (absolute) * function (sinh)', '0.0 * broadcast(0.0)'], domain=['positive electrode'], auxiliary_domains={'secondary': "['current collector']"}),
#  'Sum of x-averaged negative electrode electrolyte reaction source terms': Addition(-0x40f676e056f21f72, +, children=["0.0 + 1.0 * integral dx_n ['negative electrode'](broadcast(0.0) + broadcast(0.0)) / Negative electrode thickness [m] / Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m] + 1.0 * integral dx_n ['negative electrode'](2.0 * 2e-05 * function (exp) * Negative electrolyte concentration * Typical electrolyte concentration [mol.m-3] ** 0.5 * boundary value(Negative particle concentration) * Maximum concentration in negative electrode [mol.m-3] ** 0.5 * Maximum concentration in negative electrode [mol.m-3] - boundary value(Negative particle concentration) * Maximum concentration in negative electrode [mol.m-3] ** 0.5 / 0.0706870030399418 * Maximum concentration in negative electrode [mol.m-3] - Maximum concentration in negative electrode [mol.m-3] / 2.0 ** 0.5 * 2.0 / 96485.33212 * Maximum concentration in negative electrode [mol.m-3] / 0.0706870030399418 * Maximum concentration in negative electrode [mol.m-3] - Maximum concentration in negative electrode [mol.m-3] / 2.0 ** 0.5 * 2.0 * Negative electrode surface area to volume ratio [m-1] / 96485.33212 * Maximum concentration in negative electrode [mol.m-3] * Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m] / function (absolute) * function (sinh)) / Negative electrode thickness [m] / Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]", '0.0'], domain=['current collector'], auxiliary_domains={}),
#  'Sum of x-averaged positive electrode electrolyte reaction source terms': Addition(0x3841e3ad809ab046, +, children=["0.0 + 1.0 * integral dx_p ['positive electrode'](broadcast(0.0) + broadcast(0.0)) / Positive electrode thickness [m] / Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m] + 1.0 * integral dx_p ['positive electrode'](2.0 * Maximum concentration in positive electrode [mol.m-3] / Maximum concentration in negative electrode [mol.m-3] * 6e-07 * function (exp) * Positive electrolyte concentration * Typical electrolyte concentration [mol.m-3] ** 0.5 * boundary value(Positive particle concentration) * Maximum concentration in positive electrode [mol.m-3] ** 0.5 * Maximum concentration in positive electrode [mol.m-3] - boundary value(Positive particle concentration) * Maximum concentration in positive electrode [mol.m-3] ** 0.5 / 0.0030363179398025745 * Maximum concentration in positive electrode [mol.m-3] - Maximum concentration in positive electrode [mol.m-3] / 2.0 ** 0.5 * 2.0 / 96485.33212 * Maximum concentration in positive electrode [mol.m-3] / 0.0030363179398025745 * Maximum concentration in positive electrode [mol.m-3] - Maximum concentration in positive electrode [mol.m-3] / 2.0 ** 0.5 * 2.0 * Positive electrode surface area to volume ratio [m-1] / 96485.33212 * Maximum concentration in negative electrode [mol.m-3] * Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m] / function (absolute) * function (sinh)) / Positive electrode thickness [m] / Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]", '0.0'], domain=['current collector'], auxiliary_domains={}),
#  'Sum of interfacial current densities': Addition(0x74d35ec43cb0d2fd, +, children=['0.0 + concatenation + concatenation', 'concatenation'], domain=['negative electrode', 'separator', 'positive electrode'], auxiliary_domains={'secondary': "['current collector']"}),
#  'Sum of negative electrode interfacial current densities': Addition(-0x3bcb448645b74a63, +, children=['0.0 + broadcast(0.0) + broadcast(0.0) + 2.0 * 2e-05 * function (exp) * Negative electrolyte concentration * Typical electrolyte concentration [mol.m-3] ** 0.5 * boundary value(Negative particle concentration) * Maximum concentration in negative electrode [mol.m-3] ** 0.5 * Maximum concentration in negative electrode [mol.m-3] - boundary value(Negative particle concentration) * Maximum concentration in negative electrode [mol.m-3] ** 0.5 / 0.0706870030399418 * Maximum concentration in negative electrode [mol.m-3] - Maximum concentration in negative electrode [mol.m-3] / 2.0 ** 0.5 * 2.0 / 96485.33212 * Maximum concentration in negative electrode [mol.m-3] / 0.0706870030399418 * Maximum concentration in negative electrode [mol.m-3] - Maximum concentration in negative electrode [mol.m-3] / 2.0 ** 0.5 * 2.0 * Negative electrode surface area to volume ratio [m-1] / 96485.33212 * Maximum concentration in negative electrode [mol.m-3] * Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m] / function (absolute) * function (sinh)', 'broadcast(0.0)'], domain=['negative electrode'], auxiliary_domains={'secondary': "['current collector']"}),
#  'Sum of positive electrode interfacial current densities': Addition(-0x4f740d31b8f9014e, +, children=['0.0 + broadcast(0.0) + broadcast(0.0) + 2.0 * Maximum concentration in positive electrode [mol.m-3] / Maximum concentration in negative electrode [mol.m-3] * 6e-07 * function (exp) * Positive electrolyte concentration * Typical electrolyte concentration [mol.m-3] ** 0.5 * boundary value(Positive particle concentration) * Maximum concentration in positive electrode [mol.m-3] ** 0.5 * Maximum concentration in positive electrode [mol.m-3] - boundary value(Positive particle concentration) * Maximum concentration in positive electrode [mol.m-3] ** 0.5 / 0.0030363179398025745 * Maximum concentration in positive electrode [mol.m-3] - Maximum concentration in positive electrode [mol.m-3] / 2.0 ** 0.5 * 2.0 / 96485.33212 * Maximum concentration in positive electrode [mol.m-3] / 0.0030363179398025745 * Maximum concentration in positive electrode [mol.m-3] - Maximum concentration in positive electrode [mol.m-3] / 2.0 ** 0.5 * 2.0 * Positive electrode surface area to volume ratio [m-1] / 96485.33212 * Maximum concentration in negative electrode [mol.m-3] * Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m] / function (absolute) * function (sinh)', 'broadcast(0.0)'], domain=['positive electrode'], auxiliary_domains={'secondary': "['current collector']"}),
#  'Sum of x-averaged negative electrode interfacial current densities': Addition(0x38b8583081c466f7, +, children=["0.0 + integral dx_n ['negative electrode'](broadcast(0.0) + broadcast(0.0)) / Negative electrode thickness [m] / Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m] + integral dx_n ['negative electrode'](2.0 * 2e-05 * function (exp) * Negative electrolyte concentration * Typical electrolyte concentration [mol.m-3] ** 0.5 * boundary value(Negative particle concentration) * Maximum concentration in negative electrode [mol.m-3] ** 0.5 * Maximum concentration in negative electrode [mol.m-3] - boundary value(Negative particle concentration) * Maximum concentration in negative electrode [mol.m-3] ** 0.5 / 0.0706870030399418 * Maximum concentration in negative electrode [mol.m-3] - Maximum concentration in negative electrode [mol.m-3] / 2.0 ** 0.5 * 2.0 / 96485.33212 * Maximum concentration in negative electrode [mol.m-3] / 0.0706870030399418 * Maximum concentration in negative electrode [mol.m-3] - Maximum concentration in negative electrode [mol.m-3] / 2.0 ** 0.5 * 2.0 * Negative electrode surface area to volume ratio [m-1] / 96485.33212 * Maximum concentration in negative electrode [mol.m-3] * Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m] / function (absolute) * function (sinh)) / Negative electrode thickness [m] / Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]", '0.0'], domain=['current collector'], auxiliary_domains={}),
#  'Sum of x-averaged positive electrode interfacial current densities': Addition(0x652a189911c3bc5c, +, children=["0.0 + integral dx_p ['positive electrode'](broadcast(0.0) + broadcast(0.0)) / Positive electrode thickness [m] / Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m] + integral dx_p ['positive electrode'](2.0 * Maximum concentration in positive electrode [mol.m-3] / Maximum concentration in negative electrode [mol.m-3] * 6e-07 * function (exp) * Positive electrolyte concentration * Typical electrolyte concentration [mol.m-3] ** 0.5 * boundary value(Positive particle concentration) * Maximum concentration in positive electrode [mol.m-3] ** 0.5 * Maximum concentration in positive electrode [mol.m-3] - boundary value(Positive particle concentration) * Maximum concentration in positive electrode [mol.m-3] ** 0.5 / 0.0030363179398025745 * Maximum concentration in positive electrode [mol.m-3] - Maximum concentration in positive electrode [mol.m-3] / 2.0 ** 0.5 * 2.0 / 96485.33212 * Maximum concentration in positive electrode [mol.m-3] / 0.0030363179398025745 * Maximum concentration in positive electrode [mol.m-3] - Maximum concentration in positive electrode [mol.m-3] / 2.0 ** 0.5 * 2.0 * Positive electrode surface area to volume ratio [m-1] / 96485.33212 * Maximum concentration in negative electrode [mol.m-3] * Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m] / function (absolute) * function (sinh)) / Positive electrode thickness [m] / Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]", '0.0'], domain=['current collector'], auxiliary_domains={}),
#  'r_n': SpatialVariable(-0x4ac2bc423e57f3cf, r_n, children=[], domain=['negative particle'], auxiliary_domains={'secondary': "['negative electrode']", 'tertiary': "['current collector']"}),
#  'r_n [m]': Multiplication(-0x36d3f356aa6bf0ab, *, children=['r_n', 'Negative particle radius [m]'], domain=['negative particle'], auxiliary_domains={'secondary': "['negative electrode']", 'tertiary': "['current collector']"}),
#  'r_p': SpatialVariable(0x4b44ed491d32efcc, r_p, children=[], domain=['positive particle'], auxiliary_domains={'secondary': "['positive electrode']", 'tertiary': "['current collector']"}),
#  'r_p [m]': Multiplication(0x55016c64c6f32c95, *, children=['r_p', 'Positive particle radius [m]'], domain=['positive particle'], auxiliary_domains={'secondary': "['positive electrode']", 'tertiary': "['current collector']"}),
#  'Total current density': Multiplication(0x5faf2c60c2f08da2, *, children=['0.680616 / Typical current [A]', 'function (sign)'], domain=[], auxiliary_domains={}),
#  'Total current density [A.m-2]': Division(-0x79a9787d01d7c0b3, /, children=['0.680616', 'Number of electrodes connected in parallel to make a cell * Electrode width [m] * Electrode height [m]'], domain=[], auxiliary_domains={}),
#  'Current [A]': Scalar(0x3bc86c1b895fbfac, 0.680616, children=[], domain=[], auxiliary_domains={}),
#  'C-rate': Division(0x42154e64d390a1be, /, children=['0.680616', 'Cell capacity [A.h]'], domain=[], auxiliary_domains={}),
#  'Discharge capacity [A.h]': Variable(0x457e2526c6f4a383, Discharge capacity [A.h], children=[], domain=[], auxiliary_domains={}),
#  'Porosity': Concatenation(0x639e59f88c33e148, concatenation, children=['Negative electrode porosity * broadcast(1.0)', 'Separator porosity * broadcast(1.0)', 'Positive electrode porosity * broadcast(1.0)'], domain=['negative electrode', 'separator', 'positive electrode'], auxiliary_domains={'secondary': "['current collector']"}),
#  'Negative electrode porosity': Multiplication(0x26d280879fff84b4, *, children=['Negative electrode porosity', 'broadcast(1.0)'], domain=['negative electrode'], auxiliary_domains={'secondary': "['current collector']"}),
#  'Separator porosity': Multiplication(0x32c1d19d12c4f524, *, children=['Separator porosity', 'broadcast(1.0)'], domain=['separator'], auxiliary_domains={'secondary': "['current collector']"}),
#  'Positive electrode porosity': Multiplication(0x46524ee3f34bc9f3, *, children=['Positive electrode porosity', 'broadcast(1.0)'], domain=['positive electrode'], auxiliary_domains={'secondary': "['current collector']"}),
#  'X-averaged negative electrode porosity': Division(-0x4413439779540f45, /, children=["integral dx_n ['negative electrode'](Negative electrode porosity * broadcast(1.0))", 'Negative electrode thickness [m] / Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]'], domain=['current collector'], auxiliary_domains={}),
#  'X-averaged separator porosity': Division(0x4c6f48f1a9668cd6, /, children=["integral dx_s ['separator'](Separator porosity * broadcast(1.0))", 'Separator thickness [m] / Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]'], domain=['current collector'], auxiliary_domains={}),
#  'X-averaged positive electrode porosity': Division(-0x7689e5f0b376d151, /, children=["integral dx_p ['positive electrode'](Positive electrode porosity * broadcast(1.0))", 'Positive electrode thickness [m] / Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]'], domain=['current collector'], auxiliary_domains={}),
#  'Active material volume fraction': Concatenation(0x4c6ce99df1e67019, concatenation, children=['1.0 - Negative electrode porosity * broadcast(1.0) - 1.0 - Negative electrode porosity * broadcast(1.0) - Negative electrode active material volume fraction', '1.0 - Separator porosity * broadcast(1.0) - 1.0 - Separator porosity * broadcast(1.0)', '1.0 - Positive electrode porosity * broadcast(1.0) - 1.0 - Positive electrode porosity * broadcast(1.0) - Positive electrode active material volume fraction'], domain=['negative electrode', 'separator', 'positive electrode'], auxiliary_domains={'secondary': "['current collector']"}),
#  'Negative electrode active material volume fraction': Subtraction(0x7c9b67e1bf4eeb5a, -, children=['1.0 - Negative electrode porosity * broadcast(1.0)', '1.0 - Negative electrode porosity * broadcast(1.0) - Negative electrode active material volume fraction'], domain=['negative electrode'], auxiliary_domains={'secondary': "['current collector']"}),
#  'Separator active material volume fraction': Concatenation(0x4c6ce99df1e67019, concatenation, children=['1.0 - Negative electrode porosity * broadcast(1.0) - 1.0 - Negative electrode porosity * broadcast(1.0) - Negative electrode active material volume fraction', '1.0 - Separator porosity * broadcast(1.0) - 1.0 - Separator porosity * broadcast(1.0)', '1.0 - Positive electrode porosity * broadcast(1.0) - 1.0 - Positive electrode porosity * broadcast(1.0) - Positive electrode active material volume fraction'], domain=['negative electrode', 'separator', 'positive electrode'], auxiliary_domains={'secondary': "['current collector']"}),
#  'Positive electrode active material volume fraction': Subtraction(-0x66f8b991ef63f39b, -, children=['1.0 - Positive electrode porosity * broadcast(1.0)', '1.0 - Positive electrode porosity * broadcast(1.0) - Positive electrode active material volume fraction'], domain=['positive electrode'], auxiliary_domains={'secondary': "['current collector']"}),
#  'X-averaged negative electrode active material volume fraction': Division(0x6fc4af9d6442e7c7, /, children=["integral dx_n ['negative electrode'](1.0 - Negative electrode porosity * broadcast(1.0) - 1.0 - Negative electrode porosity * broadcast(1.0) - Negative electrode active material volume fraction)", 'Negative electrode thickness [m] / Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]'], domain=['current collector'], auxiliary_domains={}),
#  'X-averaged separator active material volume fraction': Division(0x66bc9d72326b7068, /, children=["integral dx ['negative electrode', 'separator', 'positive electrode'](concatenation)", '1.0'], domain=['current collector'], auxiliary_domains={}),
#  'X-averaged positive electrode active material volume fraction': Division(-0x5eef7016123eb9c9, /, children=["integral dx_p ['positive electrode'](1.0 - Positive electrode porosity * broadcast(1.0) - 1.0 - Positive electrode porosity * broadcast(1.0) - Positive electrode active material volume fraction)", 'Positive electrode thickness [m] / Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]'], domain=['current collector'], auxiliary_domains={}),
#  'Leading-order porosity': Concatenation(0x639e59f88c33e148, concatenation, children=['Negative electrode porosity * broadcast(1.0)', 'Separator porosity * broadcast(1.0)', 'Positive electrode porosity * broadcast(1.0)'], domain=['negative electrode', 'separator', 'positive electrode'], auxiliary_domains={'secondary': "['current collector']"}),
#  'Leading-order negative electrode porosity': Multiplication(0x26d280879fff84b4, *, children=['Negative electrode porosity', 'broadcast(1.0)'], domain=['negative electrode'], auxiliary_domains={'secondary': "['current collector']"}),
#  'Leading-order separator porosity': Multiplication(0x32c1d19d12c4f524, *, children=['Separator porosity', 'broadcast(1.0)'], domain=['separator'], auxiliary_domains={'secondary': "['current collector']"}),
#  'Leading-order positive electrode porosity': Multiplication(0x46524ee3f34bc9f3, *, children=['Positive electrode porosity', 'broadcast(1.0)'], domain=['positive electrode'], auxiliary_domains={'secondary': "['current collector']"}),
#  'Leading-order x-averaged negative electrode porosity': Division(-0x4413439779540f45, /, children=["integral dx_n ['negative electrode'](Negative electrode porosity * broadcast(1.0))", 'Negative electrode thickness [m] / Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]'], domain=['current collector'], auxiliary_domains={}),
#  'Leading-order x-averaged separator porosity': Division(0x4c6f48f1a9668cd6, /, children=["integral dx_s ['separator'](Separator porosity * broadcast(1.0))", 'Separator thickness [m] / Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]'], domain=['current collector'], auxiliary_domains={}),
#  'Leading-order x-averaged positive electrode porosity': Division(-0x7689e5f0b376d151, /, children=["integral dx_p ['positive electrode'](Positive electrode porosity * broadcast(1.0))", 'Positive electrode thickness [m] / Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]'], domain=['current collector'], auxiliary_domains={}),
#  'Leading-order active material volume fraction': Concatenation(0x4c6ce99df1e67019, concatenation, children=['1.0 - Negative electrode porosity * broadcast(1.0) - 1.0 - Negative electrode porosity * broadcast(1.0) - Negative electrode active material volume fraction', '1.0 - Separator porosity * broadcast(1.0) - 1.0 - Separator porosity * broadcast(1.0)', '1.0 - Positive electrode porosity * broadcast(1.0) - 1.0 - Positive electrode porosity * broadcast(1.0) - Positive electrode active material volume fraction'], domain=['negative electrode', 'separator', 'positive electrode'], auxiliary_domains={'secondary': "['current collector']"}),
#  'Leading-order negative electrode active material volume fraction': Subtraction(0x7c9b67e1bf4eeb5a, -, children=['1.0 - Negative electrode porosity * broadcast(1.0)', '1.0 - Negative electrode porosity * broadcast(1.0) - Negative electrode active material volume fraction'], domain=['negative electrode'], auxiliary_domains={'secondary': "['current collector']"}),
#  'Leading-order separator active material volume fraction': Concatenation(0x4c6ce99df1e67019, concatenation, children=['1.0 - Negative electrode porosity * broadcast(1.0) - 1.0 - Negative electrode porosity * broadcast(1.0) - Negative electrode active material volume fraction', '1.0 - Separator porosity * broadcast(1.0) - 1.0 - Separator porosity * broadcast(1.0)', '1.0 - Positive electrode porosity * broadcast(1.0) - 1.0 - Positive electrode porosity * broadcast(1.0) - Positive electrode active material volume fraction'], domain=['negative electrode', 'separator', 'positive electrode'], auxiliary_domains={'secondary': "['current collector']"}),
#  'Leading-order positive electrode active material volume fraction': Subtraction(-0x66f8b991ef63f39b, -, children=['1.0 - Positive electrode porosity * broadcast(1.0)', '1.0 - Positive electrode porosity * broadcast(1.0) - Positive electrode active material volume fraction'], domain=['positive electrode'], auxiliary_domains={'secondary': "['current collector']"}),
#  'Leading-order x-averaged negative electrode active material volume fraction': Division(0x6fc4af9d6442e7c7, /, children=["integral dx_n ['negative electrode'](1.0 - Negative electrode porosity * broadcast(1.0) - 1.0 - Negative electrode porosity * broadcast(1.0) - Negative electrode active material volume fraction)", 'Negative electrode thickness [m] / Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]'], domain=['current collector'], auxiliary_domains={}),
#  'Leading-order x-averaged separator active material volume fraction': Division(0x66bc9d72326b7068, /, children=["integral dx ['negative electrode', 'separator', 'positive electrode'](concatenation)", '1.0'], domain=['current collector'], auxiliary_domains={}),
#  'Leading-order x-averaged positive electrode active material volume fraction': Division(-0x5eef7016123eb9c9, /, children=["integral dx_p ['positive electrode'](1.0 - Positive electrode porosity * broadcast(1.0) - 1.0 - Positive electrode porosity * broadcast(1.0) - Positive electrode active material volume fraction)", 'Positive electrode thickness [m] / Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]'], domain=['current collector'], auxiliary_domains={}),
#  'Porosity change': Concatenation(0x17c416163e584bd3, concatenation, children=['broadcast(0.0)', 'broadcast(0.0)', 'broadcast(0.0)'], domain=['negative electrode', 'separator', 'positive electrode'], auxiliary_domains={'secondary': "['current collector']"}),
#  'Negative electrode porosity change': FullBroadcast(-0xf67bd868643acfe, broadcast, children=['0.0'], domain=['negative electrode'], auxiliary_domains={'secondary': "['current collector']"}),
#  'Separator porosity change': FullBroadcast(-0xe6b060db4fc4c6e, broadcast, children=['0.0'], domain=['separator'], auxiliary_domains={'secondary': "['current collector']"}),
#  'Positive electrode porosity change': FullBroadcast(0x6b0650f8e2aad56b, broadcast, children=['0.0'], domain=['positive electrode'], auxiliary_domains={'secondary': "['current collector']"}),
#  'X-averaged negative electrode porosity change': Scalar(0x5898973d7d150646, 0.0, children=[], domain=[], auxiliary_domains={}),
#  'X-averaged separator porosity change': Scalar(0x5898973d7d150646, 0.0, children=[], domain=[], auxiliary_domains={}),
#  'X-averaged positive electrode porosity change': Scalar(0x5898973d7d150646, 0.0, children=[], domain=[], auxiliary_domains={}),
#  'Leading-order x-averaged negative electrode porosity change': Scalar(0x5898973d7d150646, 0.0, children=[], domain=[], auxiliary_domains={}),
#  'Leading-order x-averaged separator porosity change': Scalar(0x5898973d7d150646, 0.0, children=[], domain=[], auxiliary_domains={}),
#  'Leading-order x-averaged positive electrode porosity change': Scalar(0x5898973d7d150646, 0.0, children=[], domain=[], auxiliary_domains={}),
#  'Separator pressure': PrimaryBroadcast(-0x4ee06897ae4e3831, broadcast, children=['broadcast(0.0)'], domain=['separator'], auxiliary_domains={'secondary': "['current collector']"}),
#  'X-averaged separator pressure': PrimaryBroadcast(0x4524506437663457, broadcast, children=['0.0'], domain=['current collector'], auxiliary_domains={}),
#  'Negative electrode transverse volume-averaged velocity': PrimaryBroadcast(-0x32ec4e933e416ae1, broadcast, children=['broadcast(0.0)'], domain=['negative electrode'], auxiliary_domains={'secondary': "['current collector']"}),
#  'Separator transverse volume-averaged velocity': PrimaryBroadcast(-0x4ee06897ae4e3831, broadcast, children=['broadcast(0.0)'], domain=['separator'], auxiliary_domains={'secondary': "['current collector']"}),
#  'Positive electrode transverse volume-averaged velocity': PrimaryBroadcast(-0xa70ab4cecdc9ff2, broadcast, children=['broadcast(0.0)'], domain=['positive electrode'], auxiliary_domains={'secondary': "['current collector']"}),
#  'Negative electrode transverse volume-averaged velocity [m.s-2]': Multiplication(0x24668cc8eb7a0dfe, *, children=['1.0', 'broadcast(broadcast(0.0))'], domain=['negative electrode'], auxiliary_domains={'secondary': "['current collector']"}),
#  'Separator transverse volume-averaged velocity [m.s-2]': Multiplication(0x72d42094af9491df, *, children=['1.0', 'broadcast(broadcast(0.0))'], domain=['separator'], auxiliary_domains={'secondary': "['current collector']"}),
#  'Positive electrode transverse volume-averaged velocity [m.s-2]': Multiplication(-0x12ea562f76957831, *, children=['1.0', 'broadcast(broadcast(0.0))'], domain=['positive electrode'], auxiliary_domains={'secondary': "['current collector']"}),
#  'X-averaged negative electrode transverse volume-averaged velocity': PrimaryBroadcast(0x4524506437663457, broadcast, children=['0.0'], domain=['current collector'], auxiliary_domains={}),
#  'X-averaged separator transverse volume-averaged velocity': PrimaryBroadcast(0x4524506437663457, broadcast, children=['0.0'], domain=['current collector'], auxiliary_domains={}),
#  'X-averaged positive electrode transverse volume-averaged velocity': PrimaryBroadcast(0x4524506437663457, broadcast, children=['0.0'], domain=['current collector'], auxiliary_domains={}),
#  'X-averaged negative electrode transverse volume-averaged velocity [m.s-2]': Multiplication(0x7ba473292dce5fc2, *, children=['1.0', 'broadcast(0.0)'], domain=['current collector'], auxiliary_domains={}),
#  'X-averaged separator transverse volume-averaged velocity [m.s-2]': Multiplication(0x7ba473292dce5fc2, *, children=['1.0', 'broadcast(0.0)'], domain=['current collector'], auxiliary_domains={}),
#  'X-averaged positive electrode transverse volume-averaged velocity [m.s-2]': Multiplication(0x7ba473292dce5fc2, *, children=['1.0', 'broadcast(0.0)'], domain=['current collector'], auxiliary_domains={}),
#  'Transverse volume-averaged velocity': Concatenation(-0x29f8e387a2e05914, concatenation, children=['broadcast(broadcast(0.0))', 'broadcast(broadcast(0.0))', 'broadcast(broadcast(0.0))'], domain=['negative electrode', 'separator', 'positive electrode'], auxiliary_domains={'secondary': "['current collector']"}),
#  'Transverse volume-averaged velocity [m.s-2]': Multiplication(-0x42d7286308f43aa0, *, children=['1.0', 'concatenation'], domain=['negative electrode', 'separator', 'positive electrode'], auxiliary_domains={'secondary': "['current collector']"}),
#  'Negative electrode transverse volume-averaged acceleration': PrimaryBroadcast(-0x32ec4e933e416ae1, broadcast, children=['broadcast(0.0)'], domain=['negative electrode'], auxiliary_domains={'secondary': "['current collector']"}),
#  'Separator transverse volume-averaged acceleration': PrimaryBroadcast(-0x4ee06897ae4e3831, broadcast, children=['broadcast(0.0)'], domain=['separator'], auxiliary_domains={'secondary': "['current collector']"}),
#  'Positive electrode transverse volume-averaged acceleration': PrimaryBroadcast(-0xa70ab4cecdc9ff2, broadcast, children=['broadcast(0.0)'], domain=['positive electrode'], auxiliary_domains={'secondary': "['current collector']"}),
#  'Negative electrode transverse volume-averaged acceleration [m.s-2]': Multiplication(0xd073fd57f2a9f17, *, children=['1.0 / Electrode height [m]', 'broadcast(broadcast(0.0))'], domain=['negative electrode'], auxiliary_domains={'secondary': "['current collector']"}),
#  'Separator transverse volume-averaged acceleration [m.s-2]': Multiplication(0x1f58106ddad67cd6, *, children=['1.0 / Electrode height [m]', 'broadcast(broadcast(0.0))'], domain=['separator'], auxiliary_domains={'secondary': "['current collector']"}),
#  'Positive electrode transverse volume-averaged acceleration [m.s-2]': Multiplication(-0x17e7eebd51093b2a, *, children=['1.0 / Electrode height [m]', 'broadcast(broadcast(0.0))'], domain=['positive electrode'], auxiliary_domains={'secondary': "['current collector']"}),
#  'X-averaged negative electrode transverse volume-averaged acceleration': PrimaryBroadcast(0x4524506437663457, broadcast, children=['0.0'], domain=['current collector'], auxiliary_domains={}),
#  'X-averaged separator transverse volume-averaged acceleration': PrimaryBroadcast(0x4524506437663457, broadcast, children=['0.0'], domain=['current collector'], auxiliary_domains={}),
#  'X-averaged positive electrode transverse volume-averaged acceleration': PrimaryBroadcast(0x4524506437663457, broadcast, children=['0.0'], domain=['current collector'], auxiliary_domains={}),
#  'X-averaged negative electrode transverse volume-averaged acceleration [m.s-2]': Multiplication(0x1eb7bc4628bf6fc9, *, children=['1.0 / Electrode height [m]', 'broadcast(0.0)'], domain=['current collector'], auxiliary_domains={}),
#  'X-averaged separator transverse volume-averaged acceleration [m.s-2]': Multiplication(0x1eb7bc4628bf6fc9, *, children=['1.0 / Electrode height [m]', 'broadcast(0.0)'], domain=['current collector'], auxiliary_domains={}),
#  'X-averaged positive electrode transverse volume-averaged acceleration [m.s-2]': Multiplication(0x1eb7bc4628bf6fc9, *, children=['1.0 / Electrode height [m]', 'broadcast(0.0)'], domain=['current collector'], auxiliary_domains={}),
#  'Transverse volume-averaged acceleration': Concatenation(-0x29f8e387a2e05914, concatenation, children=['broadcast(broadcast(0.0))', 'broadcast(broadcast(0.0))', 'broadcast(broadcast(0.0))'], domain=['negative electrode', 'separator', 'positive electrode'], auxiliary_domains={'secondary': "['current collector']"}),
#  'Transverse volume-averaged acceleration [m.s-2]': Multiplication(-0x22a61663f38e9c2d, *, children=['1.0 / Electrode height [m]', 'concatenation'], domain=['negative electrode', 'separator', 'positive electrode'], auxiliary_domains={'secondary': "['current collector']"}),
#  'Negative electrode volume-averaged velocity': FullBroadcast(-0xf67bd868643acfe, broadcast, children=['0.0'], domain=['negative electrode'], auxiliary_domains={'secondary': "['current collector']"}),
#  'Positive electrode volume-averaged velocity': FullBroadcast(0x6b0650f8e2aad56b, broadcast, children=['0.0'], domain=['positive electrode'], auxiliary_domains={'secondary': "['current collector']"}),
#  'Negative electrode volume-averaged velocity [m.s-1]': Multiplication(-0x4583a04db4d1c136, *, children=['1.0', 'broadcast(0.0)'], domain=['negative electrode'], auxiliary_domains={'secondary': "['current collector']"}),
#  'Positive electrode volume-averaged velocity [m.s-1]': Multiplication(0x238245608137fc2f, *, children=['1.0', 'broadcast(0.0)'], domain=['positive electrode'], auxiliary_domains={'secondary': "['current collector']"}),
#  'Negative electrode volume-averaged acceleration': FullBroadcast(-0xf67bd868643acfe, broadcast, children=['0.0'], domain=['negative electrode'], auxiliary_domains={'secondary': "['current collector']"}),
#  'Positive electrode volume-averaged acceleration': FullBroadcast(0x6b0650f8e2aad56b, broadcast, children=['0.0'], domain=['positive electrode'], auxiliary_domains={'secondary': "['current collector']"}),
#  'Negative electrode volume-averaged acceleration [m.s-1]': Multiplication(-0x71a3cf8149de092c, *, children=['1.0 / Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]', 'broadcast(0.0)'], domain=['negative electrode'], auxiliary_domains={'secondary': "['current collector']"}),
#  'Positive electrode volume-averaged acceleration [m.s-1]': Multiplication(0x19a229e5c7dec791, *, children=['1.0 / Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]', 'broadcast(0.0)'], domain=['positive electrode'], auxiliary_domains={'secondary': "['current collector']"}),
#  'X-averaged negative electrode volume-averaged acceleration': Scalar(0x5898973d7d150646, 0.0, children=[], domain=[], auxiliary_domains={}),
#  'X-averaged positive electrode volume-averaged acceleration': Scalar(0x5898973d7d150646, 0.0, children=[], domain=[], auxiliary_domains={}),
#  'X-averaged negative electrode volume-averaged acceleration [m.s-1]': Multiplication(-0x406514ff0124f163, *, children=['1.0 / Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]', '0.0'], domain=[], auxiliary_domains={}),
#  'X-averaged positive electrode volume-averaged acceleration [m.s-1]': Multiplication(-0x406514ff0124f163, *, children=['1.0 / Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]', '0.0'], domain=[], auxiliary_domains={}),
#  'Negative electrode pressure': FullBroadcast(-0xf67bd868643acfe, broadcast, children=['0.0'], domain=['negative electrode'], auxiliary_domains={'secondary': "['current collector']"}),
#  'Positive electrode pressure': FullBroadcast(0x6b0650f8e2aad56b, broadcast, children=['0.0'], domain=['positive electrode'], auxiliary_domains={'secondary': "['current collector']"}),
#  'X-averaged negative electrode pressure': Scalar(0x5898973d7d150646, 0.0, children=[], domain=[], auxiliary_domains={}),
#  'X-averaged positive electrode pressure': Scalar(0x5898973d7d150646, 0.0, children=[], domain=[], auxiliary_domains={}),
#  'Negative particle concentration': Variable(-0x51d5541608d31aff, Negative particle concentration, children=[], domain=['negative particle'], auxiliary_domains={'secondary': "['negative electrode']", 'tertiary': "['current collector']"}),
#  'Negative particle concentration [mol.m-3]': Multiplication(0xa5253058b58bec2, *, children=['Negative particle concentration', 'Maximum concentration in negative electrode [mol.m-3]'], domain=['negative particle'], auxiliary_domains={'secondary': "['negative electrode']", 'tertiary': "['current collector']"}),
#  'X-averaged negative particle concentration': Variable(-0x51d5541608d31aff, Negative particle concentration, children=[], domain=['negative particle'], auxiliary_domains={'secondary': "['negative electrode']", 'tertiary': "['current collector']"}),
#  'X-averaged negative particle concentration [mol.m-3]': Multiplication(0xa5253058b58bec2, *, children=['Negative particle concentration', 'Maximum concentration in negative electrode [mol.m-3]'], domain=['negative particle'], auxiliary_domains={'secondary': "['negative electrode']", 'tertiary': "['current collector']"}),
#  'Negative particle surface concentration': BoundaryValue(0x315a1b08b809e7a5, boundary value, children=['Negative particle concentration'], domain=['negative electrode'], auxiliary_domains={'secondary': "['current collector']"}),
#  'Negative particle surface concentration [mol.m-3]': Multiplication(0x31ceadd2721cc4ea, *, children=['Maximum concentration in negative electrode [mol.m-3]', 'boundary value(Negative particle concentration)'], domain=['negative electrode'], auxiliary_domains={'secondary': "['current collector']"}),
#  'X-averaged negative particle surface concentration': Division(0x600e455a0a4a3b7a, /, children=["integral dx_n ['negative electrode'](boundary value(Negative particle concentration))", 'Negative electrode thickness [m] / Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]'], domain=['current collector'], auxiliary_domains={}),
#  'X-averaged negative particle surface concentration [mol.m-3]': Multiplication(-0x3c17a515d70fd68e, *, children=['Maximum concentration in negative electrode [mol.m-3]', "integral dx_n ['negative electrode'](boundary value(Negative particle concentration)) / Negative electrode thickness [m] / Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]"], domain=['current collector'], auxiliary_domains={}),
#  'Negative electrode active volume fraction': Division(-0x333d39a7e355644a, /, children=['Negative electrode surface area to volume ratio [m-1] * Negative particle radius [m]', '3.0'], domain=[], auxiliary_domains={}),
#  'Negative electrode volume-averaged concentration': Multiplication(0x755ab5a8430a5c22, *, children=['Negative electrode surface area to volume ratio [m-1] * Negative particle radius [m] / 3.0', "integral dr ['negative particle'](Negative particle concentration) / integral dr ['negative particle'](broadcast(1.0))"], domain=['negative electrode'], auxiliary_domains={'secondary': "['current collector']"}),
#  'Negative electrode volume-averaged concentration [mol.m-3]': Multiplication(0x7a26e6a2765518b3, *, children=["Negative electrode surface area to volume ratio [m-1] * Negative particle radius [m] / 3.0 * integral dr ['negative particle'](Negative particle concentration) / integral dr ['negative particle'](broadcast(1.0))", 'Maximum concentration in negative electrode [mol.m-3]'], domain=['negative electrode'], auxiliary_domains={'secondary': "['current collector']"}),
#  'Negative electrode average extent of lithiation': Division(-0x5cb0e51995c6607e, /, children=["integral dr ['negative particle'](Negative particle concentration)", "integral dr ['negative particle'](broadcast(1.0))"], domain=['negative electrode'], auxiliary_domains={'secondary': "['current collector']"}),
#  'Positive particle concentration': Variable(0x3359e59d5d5e636f, Positive particle concentration, children=[], domain=['positive particle'], auxiliary_domains={'secondary': "['positive electrode']", 'tertiary': "['current collector']"}),
#  'Positive particle concentration [mol.m-3]': Multiplication(0x69e27117d93b1204, *, children=['Positive particle concentration', 'Maximum concentration in positive electrode [mol.m-3]'], domain=['positive particle'], auxiliary_domains={'secondary': "['positive electrode']", 'tertiary': "['current collector']"}),
#  'X-averaged positive particle concentration': Variable(0x3359e59d5d5e636f, Positive particle concentration, children=[], domain=['positive particle'], auxiliary_domains={'secondary': "['positive electrode']", 'tertiary': "['current collector']"}),
#  'X-averaged positive particle concentration [mol.m-3]': Multiplication(0x69e27117d93b1204, *, children=['Positive particle concentration', 'Maximum concentration in positive electrode [mol.m-3]'], domain=['positive particle'], auxiliary_domains={'secondary': "['positive electrode']", 'tertiary': "['current collector']"}),
#  'Positive particle surface concentration': BoundaryValue(-0xc09eb8176e7c58b, boundary value, children=['Positive particle concentration'], domain=['positive electrode'], auxiliary_domains={'secondary': "['current collector']"}),
#  'Positive particle surface concentration [mol.m-3]': Multiplication(0x224d9f3278563f01, *, children=['Maximum concentration in positive electrode [mol.m-3]', 'boundary value(Positive particle concentration)'], domain=['positive electrode'], auxiliary_domains={'secondary': "['current collector']"}),
#  'X-averaged positive particle surface concentration': Division(0x467ab20b50961d2f, /, children=["integral dx_p ['positive electrode'](boundary value(Positive particle concentration))", 'Positive electrode thickness [m] / Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]'], domain=['current collector'], auxiliary_domains={}),
#  'X-averaged positive particle surface concentration [mol.m-3]': Multiplication(0x718e5a5b3b95dd03, *, children=['Maximum concentration in positive electrode [mol.m-3]', "integral dx_p ['positive electrode'](boundary value(Positive particle concentration)) / Positive electrode thickness [m] / Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]"], domain=['current collector'], auxiliary_domains={}),
#  'Positive electrode active volume fraction': Division(0x7e34237b99e3ed43, /, children=['Positive electrode surface area to volume ratio [m-1] * Positive particle radius [m]', '3.0'], domain=[], auxiliary_domains={}),
#  'Positive electrode volume-averaged concentration': Multiplication(-0x39593967452c0d03, *, children=['Positive electrode surface area to volume ratio [m-1] * Positive particle radius [m] / 3.0', "integral dr ['positive particle'](Positive particle concentration) / integral dr ['positive particle'](broadcast(1.0))"], domain=['positive electrode'], auxiliary_domains={'secondary': "['current collector']"}),
#  'Positive electrode volume-averaged concentration [mol.m-3]': Multiplication(-0x134c251cf1902b8a, *, children=["Positive electrode surface area to volume ratio [m-1] * Positive particle radius [m] / 3.0 * integral dr ['positive particle'](Positive particle concentration) / integral dr ['positive particle'](broadcast(1.0))", 'Maximum concentration in positive electrode [mol.m-3]'], domain=['positive electrode'], auxiliary_domains={'secondary': "['current collector']"}),
#  'Positive electrode average extent of lithiation': Division(0x425de86eb8d247bb, /, children=["integral dr ['positive particle'](Positive particle concentration)", "integral dr ['positive particle'](broadcast(1.0))"], domain=['positive electrode'], auxiliary_domains={'secondary': "['current collector']"}),
#  'Negative electrode potential': Variable(-0x4915d17aff58dbc7, Negative electrode potential, children=[], domain=['negative electrode'], auxiliary_domains={'secondary': "['current collector']"}),
#  'Negative electrode potential [V]': Multiplication(-0x1f8fdad2bd9720c7, *, children=['8.314462618 * Reference temperature [K] / 96485.33212', 'Negative electrode potential'], domain=['negative electrode'], auxiliary_domains={'secondary': "['current collector']"}),
#  'X-averaged negative electrode potential': Division(-0x74e3a9d7c42333c, /, children=["integral dx_n ['negative electrode'](Negative electrode potential)", 'Negative electrode thickness [m] / Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]'], domain=['current collector'], auxiliary_domains={}),
# ...
#  'X-averaged reaction overpotential [V]': Subtraction(-0x644cf319a49884df, -, children=["integral dx_p ['positive electrode'](Positive electrode potential - Positive electrolyte potential - 2.16216 + 0.07645 * function (tanh) + 2.1581 * function (tanh) - 0.14169 * function (tanh) + 0.2051 * function (tanh) + 0.2531 * function (tanh) - 0.02167 * function (tanh) + 1.0 * broadcast(broadcast(298.15 - Reference temperature [K] / 1.0)) + Reference temperature [K] - Reference temperature [K] * -8.132000292009045e-05 * 1.0 / function (cosh) ** 2.0 + -0.0021191697994606485 * function (cosh) ** -2.0 + 5.492438867553213e-05 * function (cosh) ** -2.0 - 2.1979665594310157e-05 * function (cosh) ** -2.0 - 3.755037425254259e-05 * function (cosh) ** -2.0 - 7.051567620368884e-05 * function (cosh) ** -2.0 - 4.027013847342062 + Reference temperature [K] - Reference temperature [K] * -2.0824519979857345e-05 / 8.314462618 * Reference temperature [K] / 96485.33212 + 0.0) / Positive electrode thickness [m] / Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m] * 8.314462618 * Reference temperature [K] / 96485.33212", "integral dx_n ['negative electrode'](Negative electrode potential - Negative electrolyte potential - 0.194 + 1.5 * function (exp) + 0.0351 * function (tanh) - 0.0045 * function (tanh) - 0.035 * function (tanh) - 0.0147 * function (tanh) - 0.102 * function (tanh) - 0.022 * function (tanh) - 0.011 * function (tanh) + 0.0155 * function (tanh) + 1.0 * broadcast(broadcast(298.15 - Reference temperature [K] / 1.0)) + Reference temperature [K] - Reference temperature [K] * -0.007204823775388301 * function (exp) + 1.6926995616876127e-05 * function (cosh) ** -2.0 - 1.5136184402076262e-06 * function (cosh) ** -2.0 - 2.801875912651006e-05 * function (cosh) ** -2.0 - 1.730570416637386e-05 * function (cosh) ** -2.0 - 2.8751644174084767e-05 * function (cosh) ** -2.0 - 5.3694486130942614e-05 * function (cosh) ** -2.0 - 1.9482070189103072e-05 * function (cosh) ** -2.0 + 2.139363381580817e-05 * function (cosh) ** -2.0 - 0.175193184028335 + Reference temperature [K] - Reference temperature [K] * -2.1035768663577916e-06 / 8.314462618 * Reference temperature [K] / 96485.33212 + 0.0) / Negative electrode thickness [m] / Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m] * 8.314462618 * Reference temperature [K] / 96485.33212"], domain=['current collector'], auxiliary_domains={}),
#  'X-averaged sei film overpotential': Scalar(0x5898973d7d150646, 0.0, children=[], domain=[], auxiliary_domains={}),
#  'X-averaged sei film overpotential [V]': Addition(0x50128292377057cb, +, children=['0.0 * 8.314462618 * Reference temperature [K] / 96485.33212', '0.0 * 8.314462618 * Reference temperature [K] / 96485.33212'], domain=[], auxiliary_domains={}),
#  'X-averaged solid phase ohmic losses': Subtraction(0x78e53d71c136e4e7, -, children=["integral dx_p ['positive electrode'](Positive electrode potential - broadcast(boundary value(Positive electrode potential))) / Positive electrode thickness [m] / Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]", "integral dx_n ['negative electrode'](Negative electrode potential) / Negative electrode thickness [m] / Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]"], domain=['current collector'], auxiliary_domains={}),
#  'X-averaged solid phase ohmic losses [V]': Subtraction(-0x5515db2e1a3c654b, -, children=["integral dx_p ['positive electrode'](Positive electrode potential - broadcast(boundary value(Positive electrode potential))) / Positive electrode thickness [m] / Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m] * 8.314462618 * Reference temperature [K] / 96485.33212", "integral dx_n ['negative electrode'](Negative electrode potential) / Negative electrode thickness [m] / Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m] * 8.314462618 * Reference temperature [K] / 96485.33212"], domain=['current collector'], auxiliary_domains={}),
#  'X-averaged battery open circuit voltage [V]': Multiplication(0x7dbb50c8a71d7d4a, *, children=["4.027013847342062 + Reference temperature [K] - Reference temperature [K] * -2.0824519979857345e-05 + 8.314462618 * Reference temperature [K] / 96485.33212 * integral dx_p ['positive electrode'](2.16216 + 0.07645 * function (tanh) + 2.1581 * function (tanh) - 0.14169 * function (tanh) + 0.2051 * function (tanh) + 0.2531 * function (tanh) - 0.02167 * function (tanh) + 1.0 * broadcast(broadcast(298.15 - Reference temperature [K] / 1.0)) + Reference temperature [K] - Reference temperature [K] * -8.132000292009045e-05 * 1.0 / function (cosh) ** 2.0 + -0.0021191697994606485 * function (cosh) ** -2.0 + 5.492438867553213e-05 * function (cosh) ** -2.0 - 2.1979665594310157e-05 * function (cosh) ** -2.0 - 3.755037425254259e-05 * function (cosh) ** -2.0 - 7.051567620368884e-05 * function (cosh) ** -2.0 - 4.027013847342062 + Reference temperature [K] - Reference temperature [K] * -2.0824519979857345e-05 / 8.314462618 * Reference temperature [K] / 96485.33212) / Positive electrode thickness [m] / Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m] - 0.175193184028335 + Reference temperature [K] - Reference temperature [K] * -2.1035768663577916e-06 + 8.314462618 * Reference temperature [K] / 96485.33212 * integral dx_n ['negative electrode'](0.194 + 1.5 * function (exp) + 0.0351 * function (tanh) - 0.0045 * function (tanh) - 0.035 * function (tanh) - 0.0147 * function (tanh) - 0.102 * function (tanh) - 0.022 * function (tanh) - 0.011 * function (tanh) + 0.0155 * function (tanh) + 1.0 * broadcast(broadcast(298.15 - Reference temperature [K] / 1.0)) + Reference temperature [K] - Reference temperature [K] * -0.007204823775388301 * function (exp) + 1.6926995616876127e-05 * function (cosh) ** -2.0 - 1.5136184402076262e-06 * function (cosh) ** -2.0 - 2.801875912651006e-05 * function (cosh) ** -2.0 - 1.730570416637386e-05 * function (cosh) ** -2.0 - 2.8751644174084767e-05 * function (cosh) ** -2.0 - 5.3694486130942614e-05 * function (cosh) ** -2.0 - 1.9482070189103072e-05 * function (cosh) ** -2.0 + 2.139363381580817e-05 * function (cosh) ** -2.0 - 0.175193184028335 + Reference temperature [K] - Reference temperature [K] * -2.1035768663577916e-06 / 8.314462618 * Reference temperature [K] / 96485.33212) / Negative electrode thickness [m] / Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m]", 'Number of cells connected in series to make a battery'], domain=['current collector'], auxiliary_domains={}),
#  'Measured battery open circuit voltage [V]': Multiplication(0x633d0357d2fea91f, *, children=['boundary value(4.027013847342062 + Reference temperature [K] - Reference temperature [K] * -2.0824519979857345e-05 + 8.314462618 * Reference temperature [K] / 96485.33212 * 2.16216 + 0.07645 * function (tanh) + 2.1581 * function (tanh) - 0.14169 * function (tanh) + 0.2051 * function (tanh) + 0.2531 * function (tanh) - 0.02167 * function (tanh) + 1.0 * broadcast(broadcast(298.15 - Reference temperature [K] / 1.0)) + Reference temperature [K] - Reference temperature [K] * -8.132000292009045e-05 * 1.0 / function (cosh) ** 2.0 + -0.0021191697994606485 * function (cosh) ** -2.0 + 5.492438867553213e-05 * function (cosh) ** -2.0 - 2.1979665594310157e-05 * function (cosh) ** -2.0 - 3.755037425254259e-05 * function (cosh) ** -2.0 - 7.051567620368884e-05 * function (cosh) ** -2.0 - 4.027013847342062 + Reference temperature [K] - Reference temperature [K] * -2.0824519979857345e-05 / 8.314462618 * Reference temperature [K] / 96485.33212) - boundary value(0.175193184028335 + Reference temperature [K] - Reference temperature [K] * -2.1035768663577916e-06 + 8.314462618 * Reference temperature [K] / 96485.33212 * 0.194 + 1.5 * function (exp) + 0.0351 * function (tanh) - 0.0045 * function (tanh) - 0.035 * function (tanh) - 0.0147 * function (tanh) - 0.102 * function (tanh) - 0.022 * function (tanh) - 0.011 * function (tanh) + 0.0155 * function (tanh) + 1.0 * broadcast(broadcast(298.15 - Reference temperature [K] / 1.0)) + Reference temperature [K] - Reference temperature [K] * -0.007204823775388301 * function (exp) + 1.6926995616876127e-05 * function (cosh) ** -2.0 - 1.5136184402076262e-06 * function (cosh) ** -2.0 - 2.801875912651006e-05 * function (cosh) ** -2.0 - 1.730570416637386e-05 * function (cosh) ** -2.0 - 2.8751644174084767e-05 * function (cosh) ** -2.0 - 5.3694486130942614e-05 * function (cosh) ** -2.0 - 1.9482070189103072e-05 * function (cosh) ** -2.0 + 2.139363381580817e-05 * function (cosh) ** -2.0 - 0.175193184028335 + Reference temperature [K] - Reference temperature [K] * -2.1035768663577916e-06 / 8.314462618 * Reference temperature [K] / 96485.33212)', 'Number of cells connected in series to make a battery'], domain=['current collector'], auxiliary_domains={}),
#  'X-averaged battery reaction overpotential [V]': Multiplication(0x74ebd5362f093fe6, *, children=["integral dx_p ['positive electrode'](Positive electrode potential - Positive electrolyte potential - 2.16216 + 0.07645 * function (tanh) + 2.1581 * function (tanh) - 0.14169 * function (tanh) + 0.2051 * function (tanh) + 0.2531 * function (tanh) - 0.02167 * function (tanh) + 1.0 * broadcast(broadcast(298.15 - Reference temperature [K] / 1.0)) + Reference temperature [K] - Reference temperature [K] * -8.132000292009045e-05 * 1.0 / function (cosh) ** 2.0 + -0.0021191697994606485 * function (cosh) ** -2.0 + 5.492438867553213e-05 * function (cosh) ** -2.0 - 2.1979665594310157e-05 * function (cosh) ** -2.0 - 3.755037425254259e-05 * function (cosh) ** -2.0 - 7.051567620368884e-05 * function (cosh) ** -2.0 - 4.027013847342062 + Reference temperature [K] - Reference temperature [K] * -2.0824519979857345e-05 / 8.314462618 * Reference temperature [K] / 96485.33212 + 0.0) / Positive electrode thickness [m] / Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m] * 8.314462618 * Reference temperature [K] / 96485.33212 - integral dx_n ['negative electrode'](Negative electrode potential - Negative electrolyte potential - 0.194 + 1.5 * function (exp) + 0.0351 * function (tanh) - 0.0045 * function (tanh) - 0.035 * function (tanh) - 0.0147 * function (tanh) - 0.102 * function (tanh) - 0.022 * function (tanh) - 0.011 * function (tanh) + 0.0155 * function (tanh) + 1.0 * broadcast(broadcast(298.15 - Reference temperature [K] / 1.0)) + Reference temperature [K] - Reference temperature [K] * -0.007204823775388301 * function (exp) + 1.6926995616876127e-05 * function (cosh) ** -2.0 - 1.5136184402076262e-06 * function (cosh) ** -2.0 - 2.801875912651006e-05 * function (cosh) ** -2.0 - 1.730570416637386e-05 * function (cosh) ** -2.0 - 2.8751644174084767e-05 * function (cosh) ** -2.0 - 5.3694486130942614e-05 * function (cosh) ** -2.0 - 1.9482070189103072e-05 * function (cosh) ** -2.0 + 2.139363381580817e-05 * function (cosh) ** -2.0 - 0.175193184028335 + Reference temperature [K] - Reference temperature [K] * -2.1035768663577916e-06 / 8.314462618 * Reference temperature [K] / 96485.33212 + 0.0) / Negative electrode thickness [m] / Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m] * 8.314462618 * Reference temperature [K] / 96485.33212", 'Number of cells connected in series to make a battery'], domain=['current collector'], auxiliary_domains={}),
#  'X-averaged battery solid phase ohmic losses [V]': Multiplication(-0x1b6ae81255ac0ab1, *, children=["integral dx_p ['positive electrode'](Positive electrode potential - broadcast(boundary value(Positive electrode potential))) / Positive electrode thickness [m] / Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m] * 8.314462618 * Reference temperature [K] / 96485.33212 - integral dx_n ['negative electrode'](Negative electrode potential) / Negative electrode thickness [m] / Negative electrode thickness [m] + Separator thickness [m] + Positive electrode thickness [m] * 8.314462618 * Reference temperature [K] / 96485.33212", 'Number of cells connected in series to make a battery'], domain=['current collector'], auxiliary_domains={}),
#  'X-averaged battery electrolyte ohmic losses [V]': Multiplication(-0x716d3cc5326c7ae8, *, children=['0.0', 'Number of cells connected in series to make a battery'], domain=[], auxiliary_domains={}),
#  'X-averaged battery concentration overpotential [V]': Multiplication(-0x716d3cc5326c7ae8, *, children=['0.0', 'Number of cells connected in series to make a battery'], domain=[], auxiliary_domains={}),
#  'Battery voltage [V]': Multiplication(-0x7880759efb8e2387, *, children=['boundary value(4.027013847342062 + Reference temperature [K] - Reference temperature [K] * -2.0824519979857345e-05 - 0.175193184028335 + Reference temperature [K] - Reference temperature [K] * -2.1035768663577916e-06 + boundary value(Positive electrode potential) * 8.314462618 * Reference temperature [K] / 96485.33212)', 'Number of cells connected in series to make a battery'], domain=[], auxiliary_domains={}),
#  'Terminal power [W]': Multiplication(-0x5ef4095f143667b8, *, children=['0.680616', 'boundary value(4.027013847342062 + Reference temperature [K] - Reference temperature [K] * -2.0824519979857345e-05 - 0.175193184028335 + Reference temperature [K] - Reference temperature [K] * -2.1035768663577916e-06 + boundary value(Positive electrode potential) * 8.314462618 * Reference temperature [K] / 96485.33212)'], domain=[], auxiliary_domains={})}

# %% [markdown]
# This is long! You can also search for variables

# %%
model.variables.search("electrolyte")
# Out:
# Electrolyte concentration
# Electrolyte concentration [Molar]
# Electrolyte concentration [mol.m-3]
# Electrolyte current density
# Electrolyte current density [A.m-2]
# Electrolyte flux
# Electrolyte flux [mol.m-2.s-1]
# Electrolyte potential
# Electrolyte potential [V]
# Electrolyte tortuosity
# Gradient of electrolyte potential
# Gradient of negative electrolyte potential
# Gradient of positive electrolyte potential
# Gradient of separator electrolyte potential
# Negative electrolyte concentration
# Negative electrolyte concentration [Molar]
# Negative electrolyte concentration [mol.m-3]
# Negative electrolyte potential
# Negative electrolyte potential [V]
# Negative electrolyte tortuosity
# Positive electrolyte concentration
# Positive electrolyte concentration [Molar]
# Positive electrolyte concentration [mol.m-3]
# Positive electrolyte potential
# Positive electrolyte potential [V]
# Positive electrolyte tortuosity
# Separator electrolyte concentration
# Separator electrolyte concentration [Molar]
# Separator electrolyte concentration [mol.m-3]
# Separator electrolyte potential
# Separator electrolyte potential [V]
# Sum of electrolyte reaction source terms
# Sum of negative electrode electrolyte reaction source terms
# Sum of positive electrode electrolyte reaction source terms
# Sum of x-averaged negative electrode electrolyte reaction source terms
# Sum of x-averaged positive electrode electrolyte reaction source terms
# X-averaged battery electrolyte ohmic losses [V]
# X-averaged electrolyte concentration
# X-averaged electrolyte concentration [Molar]
# X-averaged electrolyte concentration [mol.m-3]
# X-averaged electrolyte overpotential
# X-averaged electrolyte overpotential [V]
# X-averaged electrolyte potential
# X-averaged electrolyte potential [V]
# X-averaged negative electrolyte concentration
# X-averaged negative electrolyte concentration [mol.m-3]
# X-averaged negative electrolyte potential
# X-averaged negative electrolyte potential [V]
# X-averaged negative electrolyte tortuosity
# X-averaged positive electrolyte concentration
# X-averaged positive electrolyte concentration [mol.m-3]
# X-averaged positive electrolyte potential
# X-averaged positive electrolyte potential [V]
# X-averaged positive electrolyte tortuosity
# X-averaged separator electrolyte concentration
# X-averaged separator electrolyte concentration [mol.m-3]
# X-averaged separator electrolyte potential
# X-averaged separator electrolyte potential [V]

# %% [markdown]
# Here we plot the electrode current density and terminal voltage

# %%
sim.plot(["Electrode current density", "Terminal voltage [V]"])
# Out:
# interactive(children=(FloatSlider(value=0.0, description='t', max=1.0, step=0.01), Output()), _dom_classes=('w…

# %% [markdown]
# You can plot multiple variables on the same plot by nesting lists

# %%
sim.plot([["Electrode current density", "Electrolyte current density"], "Terminal voltage [V]"])
# Out:
# interactive(children=(FloatSlider(value=0.0, description='t', max=1.0, step=0.01), Output()), _dom_classes=('w…

# %% [markdown]
# ## Options
#
# You can pass options to each of the models. To see the available options look at the documentation for `BaseBatteryModel`. Here we set up a model in which the diffusion in the particles is assumed to be infinitely fast

# %%
model_fast = pybamm.lithium_ion.DFN({"particle": "fast diffusion"}, name="fast DFN")

# %%
sim_fast = pybamm.Simulation(model_fast)

# %%
sim_fast.solve()

# %%
sim_fast.plot()
# Out:
# interactive(children=(FloatSlider(value=0.0, description='t', max=1.0, step=0.01), Output()), _dom_classes=('w…

# %% [markdown]
# You can compare the output of two simulations

# %%
pybamm.dynamic_plot([sim, sim_fast])
# Out:
# interactive(children=(FloatSlider(value=0.0, description='t', max=1.0, step=0.01), Output()), _dom_classes=('w…

# %% [markdown]
# and also pass variables to compare

# %%
pybamm.dynamic_plot([sim, sim_fast], ["Terminal voltage [V]"])
# Out:
# interactive(children=(FloatSlider(value=0.0, description='t', max=1.0, step=0.01), Output()), _dom_classes=('w…

# %% [markdown]
# ## Accessing solution variables
#
# You can also access the solved variables directly so you can create your own plots

# %%
solution = sim.solution  # extract solution object

# %%
solution["Time [s]"]  # creates a post-processed variable

# %%
solution["Time [s]"].entries
# Out:
# array([   0.        ,   36.36363636,   72.72727273,  109.09090909,
#         145.45454545,  181.81818182,  218.18181818,  254.54545455,
#         290.90909091,  327.27272727,  363.63636364,  400.        ,
#         436.36363636,  472.72727273,  509.09090909,  545.45454545,
#         581.81818182,  618.18181818,  654.54545455,  690.90909091,
#         727.27272727,  763.63636364,  800.        ,  836.36363636,
#         872.72727273,  909.09090909,  945.45454545,  981.81818182,
#        1018.18181818, 1054.54545455, 1090.90909091, 1127.27272727,
#        1163.63636364, 1200.        , 1236.36363636, 1272.72727273,
#        1309.09090909, 1345.45454545, 1381.81818182, 1418.18181818,
#        1454.54545455, 1490.90909091, 1527.27272727, 1563.63636364,
#        1600.        , 1636.36363636, 1672.72727273, 1709.09090909,
#        1745.45454545, 1781.81818182, 1818.18181818, 1854.54545455,
#        1890.90909091, 1927.27272727, 1963.63636364, 2000.        ,
#        2036.36363636, 2072.72727273, 2109.09090909, 2145.45454545,
#        2181.81818182, 2218.18181818, 2254.54545455, 2290.90909091,
#        2327.27272727, 2363.63636364, 2400.        , 2436.36363636,
#        2472.72727273, 2509.09090909, 2545.45454545, 2581.81818182,
#        2618.18181818, 2654.54545455, 2690.90909091, 2727.27272727,
#        2763.63636364, 2800.        , 2836.36363636, 2872.72727273,
#        2909.09090909, 2945.45454545, 2981.81818182, 3018.18181818,
#        3054.54545455, 3090.90909091, 3127.27272727, 3163.63636364,
#        3200.        , 3236.36363636, 3272.72727273, 3309.09090909,
#        3345.45454545, 3381.81818182, 3418.18181818, 3454.54545455,
#        3490.90909091, 3527.27272727, 3563.63636364, 3600.        ])

# %% [markdown]
# Can create a post-processed V that can be called at any time (by interpolation)

# %%
V = solution["Terminal voltage [V]"]

# %%
V([200, 400, 780, 1236])  # times in seconds
# Out:
# array([3.73210958, 3.71116961, 3.67920812, 3.65043568])

# %% [markdown]
# ## Saving the simulation and data
#
# You can save the whole simulation

# %%
model = pybamm.lithium_ion.SPM()

# %%
sim = pybamm.Simulation(model)

# %%
sim.solve()

# %%
sim.save("SPM.pkl")

# %%
sim2 = pybamm.load("SPM.pkl")

# %%
sim2.plot()
# Out:
# interactive(children=(FloatSlider(value=0.0, description='t', max=1.0, step=0.01), Output()), _dom_classes=('w…

# %% [markdown]
# or just the solution

# %%
sol = sim.solution

# %%
sol.save("SPM_sol.pkl")

# %%
sol2 = pybamm.load("SPM_sol.pkl")

# %%
pybamm.dynamic_plot(sol2)
# Out:
# interactive(children=(FloatSlider(value=0.0, description='t', max=1.0, step=0.01), Output()), _dom_classes=('w…

# %% [markdown]
# or just the data for some variables

# %%
sol.save_data("sol_data.pkl", ["Current [A]", "Terminal voltage [V]"])

# %% [markdown]
# can also save to csv or mat

# %%
sol.save_data("sol_data.csv", ["Current [A]", "Terminal voltage [V]"], to_format="csv")

# %%
sol.save_data("sol_data.mat", ["Current [A]", "Terminal voltage [V]"], to_format="matlab")
