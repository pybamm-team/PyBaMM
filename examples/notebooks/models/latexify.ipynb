# %% [markdown]
# # Using latexify in PyBaMM
# In this notebook we show how to use `latexify` to print all the model equations.

# %% [markdown]
# First we import pybamm

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %pip install pybamm -q    # install PyBaMM if it is not installed
import pybamm
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Then we load a model

# %%
model = pybamm.lithium_ion.DFN()

# %% [markdown]
# Now that we have defined a model we can use latexify to get the latex of all the model equations

# %%
model.latexify()
# Out:
# \large{\underline{\textbf{Doyle-Fuller-Newman model Equations}}}\\\\\\ \textbf
# {Discharge capacity [A.h]}\\\\\frac{d}{d t} Q_{Ah} = \frac{I(t)}{3600}\\\\Q_{A
# h} = 0.0\quad \text{at}\; t=0\\\\\\ \textbf{Negative particle concentration [m
# ol.m-3]}\\\\\frac{\partial}{\partial t} c_{\mathrm{s,n}} = \frac{\left(R_{\mat
# hrm{n}}_{\mathrm{n}} \left(\nabla c_{\mathrm{s,n}}\right)\right)\right)}{R_{\m
# athrm{n}}_{\mathrm{n}}_{\mathrm{s,n}} = c_{\mathrm{n}}_{\mathrm{s,n}} = 0.0\qu
# ad  \text{at } r = 0\\\\\frac{\partial}{\partial r} c_{\mathrm{s,n}} = - \frac
# {R_{\mathrm{n}} j_{\mathrm{n}}}{D_{\mathrm{n}}_{\mathrm{n}}_{\mathrm{n}}_{\mat
# hrm{s,p}} = \frac{\left(R_{\mathrm{p}}_{\mathrm{p}} \left(\nabla c_{\mathrm{s,
# p}}\right)\right)\right)}{R_{\mathrm{p}}_{\mathrm{p}}_{\mathrm{s,p}} = c_{\mat
# hrm{p}}_{\mathrm{s,p}} = 0.0\quad  \text{at } r = 0\\\\\frac{\partial}{\partia
# l r} c_{\mathrm{s,p}} = - \frac{R_{\mathrm{p}} j_{\mathrm{p}}}{D_{\mathrm{p}}_
# {\mathrm{p}}_{\mathrm{p}}_{\mathrm{e}} = - \nabla\cdot \left(- D_{\mathrm{e}}
# \epsilon_e} \left(\nabla \left(\frac{(\epsilon c)_{\mathrm{e}}}{\begin{cases}\
# epsilon_{\mathrm{n}}_{\mathrm{s}}_{\mathrm{p}}_{\mathrm{+}} + aj}{F}\quad 0 <
# x < L_x\\\\\left[ (\epsilon c)_{\mathrm{e}} = \begin{cases}(\epsilon c)_{\math
# rm{e,n}}& 0 < \mathtt{\text{x\_n}} < L_{\mathrm{n}} \\ (\epsilon c)_{\mathrm{e
# ,s}}& L_{\mathrm{n}} < \mathtt{\text{x\_s}} < L_n + L_{\mathrm{s}} \\ (\epsilo
# n c)_{\mathrm{e,p}}& L_n + L_{\mathrm{s}} < \mathtt{\text{x\_p}} < L_x\end{cas
# es}, \  \epsilon_e} = \begin{cases}\left(\epsilon_{\mathrm{n}}_{\mathrm{e,n}}}
# & 0 < \mathtt{\text{x\_n}} < L_{\mathrm{n}} \\ \left(\epsilon_{\mathrm{s}}_{\m
# athrm{e,s}}}& L_{\mathrm{n}} < \mathtt{\text{x\_s}} < L_n + L_{\mathrm{s}} \\
# \left(\epsilon_{\mathrm{p}}_{\mathrm{e,p}}}& L_n + L_{\mathrm{s}} < \mathtt{\t
# ext{x\_p}} < L_x\end{cases}, \  aj = \begin{cases}a_{\mathrm{n}} j_{\mathrm{n}
# }& 0 < \mathtt{\text{x\_n}} < L_{\mathrm{n}} \\ 0.0& L_{\mathrm{n}} < \mathtt{
# \text{x\_s}} < L_n + L_{\mathrm{s}} \\ a_{\mathrm{p}} j_{\mathrm{p}}& L_n + L_
# {\mathrm{s}} < \mathtt{\text{x\_p}} < L_x\end{cases}\right]\\\\(\epsilon c)_{\
# mathrm{e}} = \epsilon_{\mathrm{e}}_{x}_{\mathrm{n}} j_{\mathrm{n}} - \nabla\cd
# ot \left(\epsilon_{\mathrm{s,n}}_{\mathrm{s,n}}} \sigma_{\mathrm{n}} \left(\na
# bla \phi_{\mathrm{s,n}}\right)\right)\right)\quad 0 < x < L_{\mathrm{n}}\\\\\f
# rac{\partial}{\partial r} \phi_{\mathrm{s,n}} = 0.0\quad  \text{at } x = 0\\\\
# \frac{\partial}{\partial r} \phi_{\mathrm{s,n}} = 0.0\quad \text{at } x = L_{\
# mathrm{n}}\\\\\\ \textbf{Positive electrode potential [V]}\\\\0 = L_{x}_{\math
# rm{p}} j_{\mathrm{p}} - \nabla\cdot \left(\epsilon_{\mathrm{s,p}}_{\mathrm{s,p
# }}} \sigma_{\mathrm{p}} \left(\nabla \phi_{\mathrm{s,p}}\right)\right)\right)\
# quad L_n + L_{\mathrm{s}} < x < L_x\\\\\frac{\partial}{\partial r} \phi_{\math
# rm{s,p}} = 0.0\quad  \text{at } x = L_n + L_{\mathrm{s}}\\\\\frac{\partial}{\p
# artial r} \phi_{\mathrm{s,p}} = \frac{i_{\mathrm{cell}}(t)}{- \epsilon_{\mathr
# m{s,p}}_{\mathrm{s,p}}} \sigma_{\mathrm{p}}_x\\\\\\ \textbf{Electrolyte potent
# ial [V](Negative electrolyte potential [V], Separator electrolyte potential [V
# ], Positive electrolyte potential [V])}\\\\0 = L_{x}_{\mathrm{e}}\right)\quad
# 0 < x < L_x\\\\\left[ aj = \begin{cases}a_{\mathrm{n}} j_{\mathrm{n}}& 0 < \ma
# thtt{\text{x\_n}} < L_{\mathrm{n}} \\ 0.0& L_{\mathrm{n}} < \mathtt{\text{x\_s
# }} < L_n + L_{\mathrm{s}} \\ a_{\mathrm{p}} j_{\mathrm{p}}& L_n + L_{\mathrm{s
# }} < \mathtt{\text{x\_p}} < L_x\end{cases}, \  (\epsilon c)_{\mathrm{e}} = \be
# gin{cases}(\epsilon c)_{\mathrm{e,n}}& 0 < \mathtt{\text{x\_n}} < L_{\mathrm{n
# }} \\ (\epsilon c)_{\mathrm{e,s}}& L_{\mathrm{n}} < \mathtt{\text{x\_s}} < L_n
#  + L_{\mathrm{s}} \\ (\epsilon c)_{\mathrm{e,p}}& L_n + L_{\mathrm{s}} < \math
# tt{\text{x\_p}} < L_x\end{cases}, \  \epsilon_e} = \begin{cases}\left(\epsilon
# _{\mathrm{n}}_{\mathrm{e,n}}}& 0 < \mathtt{\text{x\_n}} < L_{\mathrm{n}} \\ \l
# eft(\epsilon_{\mathrm{s}}_{\mathrm{e,s}}}& L_{\mathrm{n}} < \mathtt{\text{x\_s
# }} < L_n + L_{\mathrm{s}} \\ \left(\epsilon_{\mathrm{p}}_{\mathrm{e,p}}}& L_n
# + L_{\mathrm{s}} < \mathtt{\text{x\_p}} < L_x\end{cases}\right]\\\\\frac{\part
# ial}{\partial r} \phi_{\mathrm{e}} = 0.0\quad  \text{at } x = 0\\\\\frac{\part
# ial}{\partial r} \phi_{\mathrm{e}} = 0.0\quad \text{at } x = L_x\\\\\\ \textbf
# {Voltage [V]}\\\\V = \phi_{\mathrm{s,p}}_{\mathrm{s,n}} = \text{Negative parti
# cle concentration [mol.m-3]}\\\\D_{\mathrm{n}} = \text{Negative electrode diff
# usivity [m2.s-1]}\\\\T_{\mathrm{amb}} = \text{Ambient temperature [K]}\\\\c_{\
# mathrm{n}}_{\mathrm{n}}_{\mathrm{n}} = \text{Negative electrode thickness [m]}
# \\\\R_{\mathrm{n}} = \text{Negative particle radius [m]}\\\\c_{\mathrm{s,p}} =
#  \text{Positive particle concentration [mol.m-3]}\\\\D_{\mathrm{p}} = \text{Po
# sitive electrode diffusivity [m2.s-1]}\\\\c_{\mathrm{p}}_{\mathrm{p}}_{\mathrm
# {p}} = \text{Positive electrode thickness [m]}\\\\L_{\mathrm{s}} = \text{Separ
# ator thickness [m]}\\\\R_{\mathrm{p}} = \text{Positive particle radius [m]}\\\
# \\epsilon_{\mathrm{p}}_{\mathrm{s}}_{\mathrm{n}}_{\mathrm{e,p}} = \text{Positi
# ve electrode porosity times concentration [mol.m-3]}\\\\(\epsilon c)_{\mathrm{
# e,s}} = \text{Separator porosity times concentration [mol.m-3]}\\\\(\epsilon c
# )_{\mathrm{e,n}} = \text{Negative electrode porosity times concentration [mol.
# m-3]}\\\\D_{\mathrm{e}} = \text{Electrolyte diffusivity [m2.s-1]}\\\\b_{\mathr
# m{e,p}} = \text{Positive electrode Bruggeman coefficient (electrolyte)}\\\\b_{
# \mathrm{e,s}} = \text{Separator Bruggeman coefficient (electrolyte)}\\\\b_{\ma
# thrm{e,n}} = \text{Negative electrode Bruggeman coefficient (electrolyte)}\\\\
# F = \text{Faraday constant [C.mol-1]}\\\\R = \text{Ideal gas constant [J.kg-1.
# K-1]}\\\\dUdT_{\mathrm{p}} = \text{Positive electrode OCP entropic change [V.K
# -1]}\\\\T_{\mathrm{p}} = \text{Positive electrode OCP [V]}\\\\\phi_{\mathrm{e,
# p}} = \text{Positive electrolyte potential [V]}\\\\\phi_{\mathrm{s,p}} = \text
# {Positive electrode potential [V]}\\\\ne_{\mathrm{p}} = \text{Positive electro
# de electrons in reaction}\\\\j_{\mathrm{p}}_{\mathrm{s,p}} = \text{Positive el
# ectrode active material volume fraction}\\\\dUdT_{\mathrm{n}} = \text{Negative
#  electrode OCP entropic change [V.K-1]}\\\\U_{\mathrm{n}} = \text{Negative ele
# ctrode OCP [V]}\\\\\phi_{\mathrm{e,n}} = \text{Negative electrolyte potential
# [V]}\\\\\phi_{\mathrm{s,n}} = \text{Negative electrode potential [V]}\\\\ne_{\
# mathrm{n}} = \text{Negative electrode electrons in reaction}\\\\j_{\mathrm{n}}
# _{\mathrm{s,n}} = \text{Negative electrode active material volume fraction}\\\
# \t_{\mathrm{+}} = \text{Cation transference number}\\\\b_{\mathrm{s,n}} = \tex
# t{Negative electrode Bruggeman coefficient (electrode)}\\\\\sigma_{\mathrm{n}}
#  = \text{Negative electrode conductivity [S.m-1]}\\\\b_{\mathrm{s,p}} = \text{
# Positive electrode Bruggeman coefficient (electrode)}\\\\\sigma_{\mathrm{p}} =
#  \text{Positive electrode conductivity [S.m-1]}\\\\\phi_{\mathrm{e,s}} = \text
# {Separator electrolyte potential [V]}\\\\\left(1+\frac{dlnf}{dlnc}\right) = 1
# + dlnf/dlnc\\\\\kappa_{\mathrm{e}} = \text{Electrolyte conductivity [S.m-1]}\\
# \\\\ \textbf{Parameters}\\\\(\epsilon c)_{\mathrm{e}} = \begin{cases}(\epsilon
#  c)_{\mathrm{e,n}}\\(\epsilon c)_{\mathrm{e,s}}\\(\epsilon c)_{\mathrm{e,p}}\e
# nd{cases}\\\\\epsilon_e} = \begin{cases}\left(\epsilon_{\mathrm{n}}_{\mathrm{e
# ,n}}}\\\left(\epsilon_{\mathrm{s}}_{\mathrm{e,s}}}\\\left(\epsilon_{\mathrm{p}
# }_{\mathrm{e,p}}}\end{cases}\\\\aj = \begin{cases}a_{\mathrm{n}} j_{\mathrm{n}
# }\\0.0\\a_{\mathrm{p}} j_{\mathrm{p}}\end{cases}\\\\j_{\mathrm{p}} = 2.0 j_{\m
# athrm{p}}_{\mathrm{p}} \left(- U_\mathrm{p}(c_\mathrm{s,p}, T) - \phi_{\mathrm
# {e,p}} + \phi_{\mathrm{s,p}}\right)}{R T_{\mathrm{amb}}} \right)}\\\\U_\mathrm
# {p}(c_\mathrm{s,p}, T) = U_{\mathrm{p}} + dUdT_{\mathrm{p}} \left(- T_{\mathrm
# {amb}}\right) + \frac{1.0 \cdot 10_{\mathrm{s,p}}_{\mathrm{p}}_{\mathrm{s,p}}_
# {\mathrm{p}}_{\mathrm{p}} = \frac{3.0 \epsilon_{\mathrm{s,p}}}{R_{\mathrm{p}}}
# \\\\j_{\mathrm{n}} = 2.0 j_{\mathrm{n}}_{\mathrm{n}} \left(- U_\mathrm{n}(c_\m
# athrm{s,n}, T) - \phi_{\mathrm{e,n}} + \phi_{\mathrm{s,n}}\right)}{R T_{\mathr
# m{amb}}} \right)}\\\\U_\mathrm{n}(c_\mathrm{s,n}, T) = U_{\mathrm{n}} + dUdT_{
# \mathrm{n}} \left(- T_{\mathrm{amb}}\right) + \frac{1.0 \cdot 10_{\mathrm{s,n}
# }_{\mathrm{n}}_{\mathrm{s,n}}_{\mathrm{n}}_{\mathrm{n}} = \frac{3.0 \epsilon_{
# \mathrm{s,n}}}{R_{\mathrm{n}}}\\\\L_{x} = L_{\mathrm{n}} + L_{\mathrm{p}} + L_
# {\mathrm{s}}\\\\i_{\mathrm{e}} = \epsilon_e} \kappa_{\mathrm{e}} \left(- \nabl
# a \phi_{\mathrm{e}} + \frac{R T_{\mathrm{amb}} \left(1+\frac{dlnf}{dlnc}\right
# ) \left(2.0 - 2.0 t_{\mathrm{+}}\right) \left(\nabla \left(\frac{(\epsilon c)_
# {\mathrm{e}}}{\begin{cases}\epsilon_{\mathrm{n}}_{\mathrm{s}}_{\mathrm{p}}_{\m
# athrm{e}}}{\begin{cases}\epsilon_{\mathrm{n}}_{\mathrm{s}}_{\mathrm{p}}_{\math
# rm{e}} = \begin{cases}\phi_{\mathrm{e,n}}\\\phi_{\mathrm{e,s}}\\\phi_{\mathrm{
# e,p}}\end{cases}__{\mathrm{typ}}\right)__{2} \left(\nabla\cdot \left(D__{2}}\q
# uad 0 < r < R__{\mathrm{typ}}\\\\c__{\mathrm{init}}\quad \text{at}\; t=0\\\\\f
# rac{\partial}{\partial r} c__{surf} F R__{\mathrm{typ}}}\quad \text{at } r = R
# __{\mathrm{typ}}\\\\\\ \textbf{Positive particle concentration [mol.m-3]}\\\\\
# frac{\partial}{\partial t} c__{\mathrm{typ}}\right)__{2} \left(\nabla\cdot \le
# ft(D__{2}}\quad 0 < r < R__{\mathrm{typ}}\\\\c__{\mathrm{init}}\quad \text{at}
# \; t=0\\\\\frac{\partial}{\partial r} c__{surf} F R__{\mathrm{typ}}}\quad \tex
# t{at } r = R__{\mathrm{typ}}\\\\\\ \textbf{Porosity times concentration [mol.m
# -3](Negative electrode porosity times concentration [mol.m-3], Separator poros
# ity times concentration [mol.m-3], Positive electrode porosity times concentra
# tion [mol.m-3])}\\\\\frac{\partial}{\partial t} (\epsilon c)__{b__{\mathrm{ini
# t}}\\\epsilon__{\mathrm{init}}\\\epsilon__{\mathrm{init}}\end{cases}}\right)\r
# ight)\right) + \frac{- aj t__{b__{\mathrm{init}}\right)__{b__{\mathrm{init}}\r
# ight)__{b__{\mathrm{init}}\right)__{b__{\mathrm{init}} c__{\mathrm{init}}\quad
#  \text{at}\; t=0\\\\\\ \textbf{Negative electrode potential [V]}\\\\0 = L__{2}
#  \left(a__{b__{2} \left(a__{b__{b__{\mathtt{\text{right}}}}\quad \text{at } x
# = L__{2} \left(- aj + \nabla\cdot i__{b__{\mathrm{init}}\right)__{b__{\mathrm{
# init}}\right)__{b__{\mathrm{init}}\right)__{b__{\mathtt{\text{right}}}\\\\\\ \
# textbf{Variables}\\\\I(t) = \text{Current function [A]}\\\\c__{\mathrm{max}} =
#  \text{Maximum concentration in negative electrode [mol.m-3]}\\\\R__{\mathrm{t
# yp}} = \text{Negative particle radius [m]}\\\\L__{\mathrm{max}} = \text{Maximu
# m concentration in positive electrode [mol.m-3]}\\\\R__{\mathrm{typ}} = \text{
# Positive particle radius [m]}\\\\L__{\mathrm{init}} = \text{Positive electrode
#  porosity}\\\\\epsilon__{\mathrm{init}} = \text{Separator porosity}\\\\\epsilo
# n__{\mathrm{init}} = \text{Negative electrode porosity}\\\\(\epsilon c)__{\mat
# hrm{ref}} = \text{Reference temperature [K]}\\\\U__{\mathrm{0}} = \text{Positi
# ve electrode exchange-current density [A.m-2]}\\\\\epsilon__{\mathrm{0}} = \te
# xt{Negative electrode exchange-current density [A.m-2]}\\\\\epsilon__{b__{\mat
# hrm{init}}\right)__{b__{\mathrm{init}}\right)__{b__{\mathrm{init}}\right)__{b_
# _{\mathrm{0}} \sinh{\left(\frac{0.5 F ne__\mathrm{surf}__\mathrm{surf}__{\math
# rm{ref}} + T__{-6}}{\max\left(1.0 \cdot 10__{-10}, \min\left(0.9999999999, \fr
# ac{c__{surf}}{c__{\mathrm{max}}}\right)\right)} + \frac{1.0 \cdot 10__{-6}}{\m
# ax\left(1.0 \cdot 10__{-10}, \min\left(0.9999999999, \frac{c__{surf}}{c__{\mat
# hrm{max}}}\right)\right) - 1.0}\\\\a__{\mathrm{0}} \sinh{\left(\frac{0.5 F ne_
# _\mathrm{surf}__\mathrm{surf}__{\mathrm{ref}} + T__{-6}}{\max\left(1.0 \cdot 1
# 0__{-10}, \min\left(0.9999999999, \frac{c__{surf}}{c__{\mathrm{max}}}\right)\r
# ight)} + \frac{1.0 \cdot 10__{-6}}{\max\left(1.0 \cdot 10__{-10}, \min\left(0.
# 9999999999, \frac{c__{surf}}{c__{\mathrm{max}}}\right)\right) - 1.0}\\\\a__{b_
# _{\mathrm{init}}\\\epsilon__{\mathrm{init}}\\\epsilon__{\mathrm{init}}\end{cas
# es}}\right)\right)}{F \max\left(0.01, \frac{(\epsilon c)__{\mathrm{init}}\\\ep
# silon__{\mathrm{init}}\\\epsilon__{\mathrm{init}}\end{cases}}\right)}\right)\\
# \\\phi

# %% [markdown]
# We can also get a list of all the equations instead of a single line joined by newline

# %%
model.latexify(newline=False)
# Out:
# ⎡
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢\large{\underline{\textbf{Single Particle Model Equations}}}, \\ \textbf{Disc
# ⎣
#
#
#
#
#
#
#
#                        d           I
# harge capacity [A.h]}, ──(Q_Ah) = ────, Q_{Ah} = 0.0\quad \text{at}\; t=0, \\
#                        dt         3600
#
#
#
#
#
#
#
#                                                                d
# \textbf{X-averaged negative particle concentration [mol.m-3]}, ──(\overline{c}
#                                                                dt
#
#
#
#
#
#
#
#
# _{\mathrm{s,n}}) = \nabla\cdot \left(D_{\mathrm{n}} \left(\nabla \overline{c}_
#
#
#
#
#
#
#
#
#
# {\mathrm{s,n}}\right)\right)\quad 0 < r < R_{\mathrm{n}}__{\mathrm{typ}}, \ove
#
#
#
#
#
#
#
#
#
# rline{c}_{\mathrm{s,n}} = \int c_{\mathrm{n}}__{\mathrm{init}}\, dxn\quad \tex
#
#
#
#
#
#
#
#
#              d                                                             d
# t{at}\; t=0, ──(\overline{c}_{\mathrm{s,n}}) = 0.0\quad  \text{at } r = 0, ──(
#              dr                                                            dr
#
#
#
#
#
#
#
#
# \overline{c}_{\mathrm{s,n}}) = - \frac{i_{cell}}{D_{\mathrm{n}}_{\mathrm{n}} \
#
#
#
#
#
#
#
#
#
# int \frac{3.0 \epsilon_{\mathrm{s,n}}}{R_{\mathrm{n}}}\, dxn}\quad \text{at }
#
#
#
#
#
#
#
#
#
# r = R_{\mathrm{n}}__{surf} F L__{\mathrm{typ}}, \\ \textbf{X-averaged positive
#
#
#
#
#
#
#
#
#                                     d
#  particle concentration [mol.m-3]}, ──(\overline{c}_{\mathrm{s,p}}) = \nabla\c
#                                     dt
#
#
#
#
#
#
#
#
# dot \left(D_{\mathrm{p}} \left(\nabla \overline{c}_{\mathrm{s,p}}\right)\right
#
#
#
#
#
#
#
#
#
# )\quad 0 < r < R_{\mathrm{p}}__{\mathrm{typ}}, \overline{c}_{\mathrm{s,p}} = \
#
#
#
#
#
#
#
#
#                                                                 d
# int c_{\mathrm{p}}__{\mathrm{init}}\, dxn\quad \text{at}\; t=0, ──(\overline{c
#                                                                 dr
#
#
#
#
#
#
#
#                                                 d
# }_{\mathrm{s,p}}) = 0.0\quad  \text{at } r = 0, ──(\overline{c}_{\mathrm{s,p}}
#                                                 dr
#
#
#
#
#
#
#
#
# ) = \frac{i_{cell}}{D_{\mathrm{p}}_{\mathrm{p}} \int \frac{3.0 \epsilon_{\math
#
#
#
#
#
#
#
#
#
# rm{s,p}}}{R_{\mathrm{p}}}\, dxn}\quad \text{at } r = R_{\mathrm{p}}__{surf} F
#
#
#
#
#
#
#
#
#
# L__{\mathrm{typ}}, \\ \textbf{Voltage [V]}, V = -U_\mathrm{n}(c_\mathrm{s,n},
#
#
#
#                                                                      2.0⋅R⋅T_{
#
#
#
#
#
# T)__\mathrm{surf} + U_\mathrm{p}(c_\mathrm{s,p}, T)__\mathrm{surf} - ─────────
#
#
#                    ⎛                                  0.5⋅i_{cell}
# \mathrm{amb}}⋅asinh⎜──────────────────────────────────────────────────────────
#                    ⎜                                            ⌠
#                    ⎜                                            ⎮ 3.0⋅\epsilon
#                    ⎜L_{\mathrm{p}}⋅j_{\mathrm{p}}__{\mathrm{0}}⋅⎮ ────────────
#                    ⎜                                            ⎮        R_{\m
#                    ⎝                                            ⌡
# ──────────────────────────────────────────────────────────────────────────────
#                                      F⋅ne_{\mathrm{p}}
#
#                      ⎞                               ⎛
# ─────────────────────⎟   2.0⋅R⋅T_{\mathrm{amb}}⋅asinh⎜────────────────────────
#                      ⎟                               ⎜
# _{\mathrm{s,p}}      ⎟                               ⎜
# ─────────────── d(xn)⎟                               ⎜L_{\mathrm{n}}⋅j_{\mathr
# athrm{p}}            ⎟                               ⎜
#                      ⎠                               ⎝
# ────────────────────── - ─────────────────────────────────────────────────────
#                                                                        F⋅ne_{\
#
#           0.5⋅i_{cell}                                 ⎞
# ───────────────────────────────────────────────────────⎟
#                     ⌠                                  ⎟
#                     ⎮ 3.0⋅\epsilon_{\mathrm{s,n}}      ⎟
# m{n}}__{\mathrm{0}}⋅⎮ ─────────────────────────── d(xn)⎟
#                     ⎮        R_{\mathrm{n}}            ⎟
#                     ⌡                                  ⎠
# ────────────────────────────────────────────────────────, \\ \textbf{Parameter
# mathrm{n}}
#
#
#
#
#
#
#
#
# s and Variables}, I = \text{Current function [A]}, \overline{c}_{\mathrm{s,n}}
#
#
#
#
#
#
#
#
#
#  = \text{X-averaged negative particle concentration [mol.m-3]}, D_{\mathrm{n}}
#
#
#
#
#
#
#
#
#
#  = \text{Negative electrode diffusivity [m2.s-1]}, T_{\mathrm{amb}} = \text{Am
#
#
#
#
#
#
#
#
#
# bient temperature [K]}, c_{\mathrm{n}}__{\mathrm{max}} = \text{Maximum concent
#
#
#
#
#
#
#
#
#
# ration in negative electrode [mol.m-3]}, \overline{c}_{\mathrm{s,p}} = \text{X
#
#
#
#
#
#
#
#
#
# -averaged positive particle concentration [mol.m-3]}, D_{\mathrm{p}} = \text{P
#
#
#
#
#
#
#
#
#
# ositive electrode diffusivity [m2.s-1]}, c_{\mathrm{p}}__{\mathrm{max}} = \tex
#
#
#                                                         ⎤
#                                                         ⎥
#                                                         ⎥
#                                                         ⎥
#                                                         ⎥
#                                                         ⎥
#                                                         ⎥
# t{Maximum concentration in positive electrode [mol.m-3]}⎥
#                                                         ⎦

# %% [markdown]
# latexify can also be used to get the equations in a file format like png, jpg, pdf or tex.

# %%
model.latexify("spm_equations_.png")

# %% [markdown]
# It will create a png file like this in the directory

# %% [markdown]
# ![SPM Equations PNG](./spm_equations_.png)

# %% [markdown]
# Don't worry if you get something like this :)

# %%
model_spme = pybamm.lithium_ion.SPMe({"thermal": "lumped"})

# %%
model_spme.latexify()

# %% [markdown]
# jupyter notebook sometimes cannot render latex output that is too large

# %% [markdown]
# When `newline=False` it returns a list, so it inherits all the properties of a list and you can also do something like this

# %%
spme_latex = model_spme.latexify(newline=False)
for line in spme_latex:
    display(line)
# Out:
# \large{\underline{\textbf{Single Particle Model with electrolyte Equations}}}
# \\ \textbf{Discharge capacity [A.h]}
# d           I
# ──(Q_Ah) = ────
# dt         3600
# Q_{Ah} = 0.0\quad \text{at}\; t=0
# \\ \textbf{X-averaged negative particle concentration [mol.m-3]}
# d
# ──(\overline{c}_{\mathrm{s,n}}) = \nabla\cdot \left(D_{\mathrm{n}} \left(\nabl
# dt
#
#
# a \overline{c}_{\mathrm{s,n}}\right)\right)\quad 0 < r < R_{\mathrm{n}}__{\mat
#
#
#
# hrm{typ}}
# \overline{c}_{\mathrm{s,n}} = \int c_{\mathrm{n}}__{\mathrm{init}}\, dxn\quad
# \text{at}\; t=0
# d
# ──(\overline{c}_{\mathrm{s,n}}) = 0.0\quad  \text{at } r = 0
# dr
# d
# ──(\overline{c}_{\mathrm{s,n}}) = - \frac{i_{cell}}{D_{\mathrm{n}}_{\mathrm{n}
# dr
#
#
# } \int \frac{3.0 \epsilon_{\mathrm{s,n}}}{R_{\mathrm{n}}}\, dxn}\quad \text{at
#
#
#
#  } r = R_{\mathrm{n}}__{surf} F L__{\mathrm{typ}}
# \\ \textbf{X-averaged positive particle concentration [mol.m-3]}
# d
# ──(\overline{c}_{\mathrm{s,p}}) = \nabla\cdot \left(D_{\mathrm{p}} \left(\nabl
# dt
#
#
# a \overline{c}_{\mathrm{s,p}}\right)\right)\quad 0 < r < R_{\mathrm{p}}__{\mat
#
#
#
# hrm{typ}}
# \overline{c}_{\mathrm{s,p}} = \int c_{\mathrm{p}}__{\mathrm{init}}\, dxn\quad
# \text{at}\; t=0
# d
# ──(\overline{c}_{\mathrm{s,p}}) = 0.0\quad  \text{at } r = 0
# dr
# d
# ──(\overline{c}_{\mathrm{s,p}}) = \frac{i_{cell}}{D_{\mathrm{p}}_{\mathrm{p}}
# dr
#
#
# \int \frac{3.0 \epsilon_{\mathrm{s,p}}}{R_{\mathrm{p}}}\, dxn}\quad \text{at }
#
#
#
#  r = R_{\mathrm{p}}__{surf} F L__{\mathrm{typ}}
# \\ \textbf{Porosity times concentration [mol.m-3](Negative electrode porosity
# times concentration [mol.m-3], Separator porosity times concentration [mol.m-3
# ], Positive electrode porosity times concentration [mol.m-3])}
# d
# ──((\epsilon c)_{\mathrm{e}}) = - \nabla\cdot \left(- D_{\mathrm{e}} \epsilon_
# dt
#
#
# e} \left(\nabla \left(\frac{(\epsilon c)_{\mathrm{e}}}{\begin{cases}\epsilon_{
#
#
#
# \mathrm{n}}_{\mathrm{s}}_{\mathrm{p}}_{\mathrm{s,n}} i_{cell}}{L_{\mathrm{n}}
#
#
#
# R_{\mathrm{n}} \int \frac{3.0 \epsilon_{\mathrm{s,n}}}{R_{\mathrm{n}}}\, dxn}\
#
#
#
# \0.0\\- \frac{3.0 \epsilon_{\mathrm{s,p}} i_{cell}}{L_{\mathrm{p}} R_{\mathrm{
#
#
#
# p}} \int \frac{3.0 \epsilon_{\mathrm{s,p}}}{R_{\mathrm{p}}}\, dxn}\end{cases}
#
#
#
# t_{\mathrm{+}} + aj}{F}\quad 0 < x < L_x__{b__{\mathrm{init}}\\\epsilon__{\mat
#
#
#
# hrm{init}}\\\epsilon__{\mathrm{init}}\end{cases}}\right)\right)\right) + \frac
#
#
#
# {- \begin{cases}\frac{3.0 \epsilon
# [(\epsilon c)_{\mathrm{e}} = \begin{cases}(\epsilon c)_{\mathrm{e,n}}& 0 < \ma
# thtt{\text{x\_n}} < L_{\mathrm{n}} \\ (\epsilon c)_{\mathrm{e,s}}& L_{\mathrm{
# n}} < \mathtt{\text{x\_s}} < L_n + L_{\mathrm{s}} \\ (\epsilon c)_{\mathrm{e,p
# }}& L_n + L_{\mathrm{s}} < \mathtt{\text{x\_p}} < L_x\end{cases}, \epsilon_e}_
# _{b = \begin{cases}\left(\epsilon_{\mathrm{n}}_{\mathrm{e,n}}}& 0 < \mathtt{\t
# ext{x\_n}} < L_{\mathrm{n}} \\ \left(\epsilon_{\mathrm{s}}_{\mathrm{e,s}}}& L_
# {\mathrm{n}} < \mathtt{\text{x\_s}} < L_n + L_{\mathrm{s}} \\ \left(\epsilon_{
# \mathrm{p}}_{\mathrm{e,p}}}& L_n + L_{\mathrm{s}} < \mathtt{\text{x\_p}} < L_x
# \end{cases}__{\mathrm{init}}\right)__{b__{\mathrm{init}}\right)__{b__{\mathrm{
# init}}\right)__{b, aj = \begin{cases}\frac{3.0 \epsilon_{\mathrm{s,n}} i_{cell
# }}{L_{\mathrm{n}} R_{\mathrm{n}} \int \frac{3.0 \epsilon_{\mathrm{s,n}}}{R_{\m
# athrm{n}}}\, dxn}& 0 < \mathtt{\text{x\_n}} < L_{\mathrm{n}} \\ 0.0& L_{\mathr
# m{n}} < \mathtt{\text{x\_s}} < L_n + L_{\mathrm{s}} \\ - \frac{3.0 \epsilon_{\
# mathrm{s,p}} i_{cell}}{L_{\mathrm{p}} R_{\mathrm{p}} \int \frac{3.0 \epsilon_{
# \mathrm{s,p}}}{R_{\mathrm{p}}}\, dxn}& L_n + L_{\mathrm{s}} < \mathtt{\text{x\
# _p}} < L_x\end{cases}]
# (\epsilon c)_{\mathrm{e}} = \epsilon_{\mathrm{e}}__{\mathrm{init}} c__{\mathrm
# {init}}\quad \text{at}\; t=0
# \\ \textbf{Volume-averaged cell temperature [K]}
#                      ⎛
#                      ⎜
#                      ⎜
#                      ⎜
#                      ⎜
#                      ⎜
#                      ⎜
#                      ⎜
#                      ⎜
#                      ⎜
#                      ⎜
#                      ⎜
#                      ⎜
#                      ⎜
#                      ⎜
#                      ⎜
#                      ⎜
#                      ⎜
#                      ⎜
#                      ⎜
#                      ⎜
#                      ⎜
#                      ⎜  A_cooling⋅hₜₒₜₐₗ⋅(-T_{\mathrm{amb}} + \overline{T})
#                    L⋅⎜- ─────────────────────────────────────────────────── +
#                      ⎜                         V_cell
# d                    ⎝
# ──(\overline{T}) = ───────────────────────────────────────────────────────────
# dt
#
# ⌠
# ⎮                                                                            ⎛
# ⎮                                                                            ⎜
# ⎮                                                                            ⎜
# ⎮                                                                            ⎜
# ⎮                                                                            ⎜
# ⎮                                                                            ⎜
# ⎮                                                                            ⎜
# ⎮                                                                            ⎜
# ⎮                                                                            ⎜
# ⎮                                                                            ⎜
# ⎮                                                                            ⎜
# ⎮                                                                            ⎜
# ⎮                                                                            ⎜
# ⎮                           2                             2                  ⎜
# ⎮ L_cc_{\mathrm{n}}⋅i_{cell}    L_cc_{\mathrm{p}}⋅i_{cell}                   ⎜
# ⎮ ─────────────────────────── + ─────────────────────────── + L_{\mathrm{n}}⋅⎜
# ⎮      σ_cc_{\mathrm{n}}             σ_cc_{\mathrm{p}}                       ⎜
# ⎮                                                                            ⎜
# ⎮                                                                            ⎜
# ⎮                                                                            ⎜
# ⎮                                                                            ⎜
# ⎮                                                                            ⎝
# ⎮ ────────────────────────────────────────────────────────────────────────────
# ⎮
# ⌡
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#                                                                             ⌠
#                                                                             ⎮
#                                                                             ⎮
#                                                                             ⎮
#                                                                             ⎮
#                                                                             ⎮
# ⌠                                                                           ⎮
# ⎮ 3⋅\epsilon_{\mathrm{s,n}}⋅\overline{T}⋅dUdT_{\mathrm{n}}⋅i_{cell}         ⎮
# ⎮ ───────────────────────────────────────────────────────────────── d(xn) + ⎮
# ⎮                                ⌠                                          ⎮
# ⎮                                ⎮ 3⋅\epsilon_{\mathrm{s,n}}                ⎮
# ⎮  L_{\mathrm{n}}⋅R_{\mathrm{n}}⋅⎮ ───────────────────────── d(xn)          ⎮
# ⎮                                ⎮       R_{\mathrm{n}}                     ⎮
# ⎮                                ⌡                                          ⎮
# ⌡                                                                           ⌡
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#                                                        ⎛
# 6⋅R⋅\epsilon_{\mathrm{s,n}}⋅\overline{T}⋅i_{cell}⋅asinh⎜──────────────────────
#                                                        ⎜
#                                                        ⎜
#                                                        ⎜2⋅L_{\mathrm{n}}⋅j_{\m
#                                                        ⎜
#                                                        ⎝
# ──────────────────────────────────────────────────────────────────────────────
#                                                                            ⌠
#                                                                            ⎮ 3
#                            F⋅L_{\mathrm{n}}⋅R_{\mathrm{n}}⋅ne_{\mathrm{n}}⋅⎮ ─
#                                                                            ⎮
#                                                                            ⌡
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#               i_{cell}                                   ⎞
# ─────────────────────────────────────────────────────────⎟
#                         ⌠                                ⎟
#                         ⎮ 3⋅\epsilon_{\mathrm{s,n}}      ⎟
# athrm{n}}__{\mathrm{0}}⋅⎮ ───────────────────────── d(xn)⎟
#                         ⎮       R_{\mathrm{n}}           ⎟         ⌠
#                         ⌡                                ⎠         ⎮
# ────────────────────────────────────────────────────────── d(xn) + ⎮ -i_{cell}
#                                                                    ⎮
# ⋅\epsilon_{\mathrm{s,n}}                                           ⎮
# ──────────────────────── d(xn)                                     ⎮
#      R_{\mathrm{n}}                                                ⎮
#                                                                    ⌡
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ⎛          xₙ      ⎞                           i_{cell}⋅xₙ⋅(-2⋅L_{\mathrm{n}}
# ⋅⎜1 - ──────────────⎟⋅∇(──────────────────────────────────────────────────────
#  ⎝    L_{\mathrm{n}}⎠                                        ⌠
#                                                              ⎮
#                         2⋅L_{\mathrm{n}}⋅\sigma_{\mathrm{n}}⋅⎮ \epsilon_{\math
#                                                              ⌡
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                                         ⌠
#                                         ⎮
#                                         ⎮
#                                         ⎮
#                                         ⎮
#                                         ⎮
#                                         ⎮
#                                         ⎮
#                                         ⎮               1+\frac{dlnf}{dlnc}⋅R⋅
#                                         ⎮ i_{cell}⋅xₙ⋅∇(──────────────────────
#                                         ⎮
#                                         ⎮
#                                         ⎮
#                                         ⎮
#  + xₙ)                                  ⎮
# ──────────────────────────────) d(xn) - ⎮ ────────────────────────────────────
#                                         ⎮
#         b_{\mathrm{s,n}}                ⌡
# rm{s,n}}                 d(xn)
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
# \overline{T}⋅(2 - 2⋅t_{\mathrm{+}})⋅log(Max(1/1000000000000000, (\epsilon c)_{
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
# \mathrm{e,n}}/(\epsilon_{\mathrm{n}}^{\mathrm{init}}*Integral((\epsilon c)_{\m
# ──────────────────────────────────────────────────────────────────────────────
#                                                                    F
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
# athrm{e}}/\begin{cases}\epsilon_{\mathrm{n}}^{\mathrm{init}}\\\epsilon_{\mathr
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
# m{s}}^{\mathrm{init}}\\\epsilon_{\mathrm{p}}^{\mathrm{init}}\end{cases}, xn)))
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#                                                               ⌠
#     1+\frac{dlnf}{dlnc}⋅R⋅\overline{T}⋅(2 - 2⋅t_{\mathrm{+}})⋅⎮ log(Max(1/1000
# )                                                             ⌡
# ─ - ──────────────────────────────────────────────────────────────────────────
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
# 000000000000, (\epsilon c)_{\mathrm{e,n}}/(\epsilon_{\mathrm{n}}^{\mathrm{init
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
# }}*Integral((\epsilon c)_{\mathrm{e}}/\begin{cases}\epsilon_{\mathrm{n}}^{\mat
#
# ──────────────────────────────────────────────────────────────────────────────
#                    F
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
# hrm{init}}\\\epsilon_{\mathrm{s}}^{\mathrm{init}}\\\epsilon_{\mathrm{p}}^{\mat
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
# hrm{init}}\end{cases}, xn)))) d(xn)
#                                                               ⎛
# ─────────────────────────────────── - L_{\mathrm{n}}⋅i_{cell}⋅⎜- ─────────────
#                                                               ⎜
#                                                               ⎜
#                                                               ⎜  \kappa_{\math
#                                                               ⎝
#
# ──────────────────────────────────────────────────────────────────────────────
#     L_{\mathrm{n}}
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#                            1
# ───────────────────────────────────────────────────────────────────── + ──────
#        ⌠
#        ⎮                                       b_{\mathrm{e,s}}
# rm{e}}⋅⎮ \epsilon_{\mathrm{s}}__{\mathrm{init}}                 d(xn)   3⋅\kap
#        ⌡
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#                                    1
# ──────────────────────────────────────────────────────────────────────────────
#                 ⌠
#                 ⎮                                       b_{\mathrm{e,n}}
# pa_{\mathrm{e}}⋅⎮ \epsilon_{\mathrm{n}}__{\mathrm{init}}                 d(xn)
#                 ⌡
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
# ⎞                                L_{\mathrm{n}}⋅i_{cell}
# ⎟ - ──────────────────────────────────────────────────────────────────────────
# ⎟                       ⌠
# ⎟                       ⎮                                       b_{\mathrm{e,s
# ⎟   \kappa_{\mathrm{e}}⋅⎮ \epsilon_{\mathrm{s}}__{\mathrm{init}}
# ⎠                       ⌡
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
# ...
#                  i_{cell}                                   ⎞
# ────────────────────────────────────────────────────────────⎟
#                            ⌠                                ⎟
#                            ⎮ 3⋅\epsilon_{\mathrm{s,n}}      ⎟
# {\mathrm{n}}__{\mathrm{0}}⋅⎮ ───────────────────────── d(xn)⎟
#                            ⎮       R_{\mathrm{n}}           ⎟         ⌠
#                            ⌡                                ⎠         ⎮
# ───────────────────────────────────────────────────────────── d(xn) + ⎮ ──────
#  F⋅ne_{\mathrm{n}}                                                    ⎮
#                                                                       ⎮
#                                                                       ⎮ 2⋅L_{\
#                                                                       ⎮
#                                                                       ⌡
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                   i_{cell}⋅xₙ⋅(-2⋅L_{\mathrm{n}} + xₙ)
# ──────────────────────────────────────────────────────────────────────────────
#                                ⌠
#                                ⎮                        b_{\mathrm{s,n}}
# mathrm{n}}⋅\sigma_{\mathrm{n}}⋅⎮ \epsilon_{\mathrm{s,n}}                 d(xn)
#                                ⌡
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                             i_{cell}⋅xₛ
#  d(xn) - ─────────────────────────────────────────────────────────────────────
#                              ⌠
#                              ⎮                                       b_{\mathr
#          \kappa_{\mathrm{e}}⋅⎮ \epsilon_{\mathrm{s}}__{\mathrm{init}}
#                              ⌡
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                           ⎞
#                           ⎟
#                           ⎟
#                           ⎟
#                           ⎟
#                           ⎟
#                           ⎟
#                           ⎟
#                           ⎟
#                           ⎟
#                           ⎟
#                           ⎟
#                           ⎟
#                           ⎟
#                           ⎟
#                           ⎟
# ─────────────) d(xn)      ⎟
#                           ⎟
# m{e,s}}                   ⎟
#         d(xn)             ⎟
#                           ⎟
#                           ⎟
#                           ⎟
# ──────────────────── d(xn)⎟
#                           ⎟
#                           ⎠
# ───────────────────────────
# [(\epsilon c)_{\mathrm{e}} = \begin{cases}(\epsilon c)_{\mathrm{e,n}}& 0 < \ma
# thtt{\text{x\_n}} < L_{\mathrm{n}} \\ (\epsilon c)_{\mathrm{e,s}}& L_{\mathrm{
# n}} < \mathtt{\text{x\_s}} < L_n + L_{\mathrm{s}} \\ (\epsilon c)_{\mathrm{e,p
# }}& L_n + L_{\mathrm{s}} < \mathtt{\text{x\_p}} < L_x\end{cases}]
# \overline{T} = T__{\mathrm{init}}\quad \text{at}\; t=0
# \\ \textbf{Voltage [V]}
# V = - \frac{1+\frac{dlnf}{dlnc} R \overline{T} \left(2.0 - 2.0 t_{\mathrm{+}}\
# right) \int \log{\left(\max\left(1.0 \cdot 10_{\mathrm{e,n}}}{\epsilon_{\mathr
# m{n}}_{\mathrm{e}}}{\begin{cases}\epsilon_{\mathrm{n}}_{\mathrm{s}}_{\mathrm{p
# }}_{\mathrm{n}} i_{cell} \left(- \frac{1.0}{\kappa_{\mathrm{e}} \int \left(\ep
# silon_{\mathrm{s}}_{\mathrm{e,s}}}\, dxn} + \frac{0.333333333333333}{\kappa_{\
# mathrm{e}} \int \left(\epsilon_{\mathrm{n}}_{\mathrm{e,n}}}\, dxn}\right) - U_
# \mathrm{n}(c_\mathrm{s,n}, T) + U_\mathrm{p}(c_\mathrm{s,p}, T) - \int \frac{2
# .0 R \overline{T} \operatorname{asinh}{\left(\frac{0.5 i_{cell}}{L_{\mathrm{n}
# } j_{\mathrm{n}}_{\mathrm{s,n}}}{R_{\mathrm{n}}}\, dxn} \right)}}{F ne_{\mathr
# m{n}}}\, dxn + \int \left(- \frac{2.0 R \overline{T} \operatorname{asinh}{\lef
# t(\frac{0.5 i_{cell}}{L_{\mathrm{p}} j_{\mathrm{p}}_{\mathrm{s,p}}}{R_{\mathrm
# {p}}}\, dxn} \right)}}{F ne_{\mathrm{p}}}\right)\, dxn - \int \frac{0.5 i_{cel
# l} \left(- L_{x}_{\mathrm{p}}_{p} \left(2.0 L_{x} - x_{p}\right)\right)}{L_{\m
# athrm{p}} \kappa_{\mathrm{e}} \int \left(\epsilon_{\mathrm{p}}_{\mathrm{e,p}}}
# \, dxn}\, dxn + \int \frac{1+\frac{dlnf}{dlnc} R \overline{T} \left(2.0 - 2.0
# t_{\mathrm{+}}\right) \log{\left(\max\left(1.0 \cdot 10_{\mathrm{e,p}}}{\epsil
# on_{\mathrm{p}}_{\mathrm{e}}}{\begin{cases}\epsilon_{\mathrm{n}}_{\mathrm{s}}_
# {\mathrm{p}}_{cell} x_{n} \left(- 2.0 L_{\mathrm{n}} + x_{n}\right)}{L_{\mathr
# m{n}} \sigma_{\mathrm{n}} \int \epsilon_{\mathrm{s,n}}_{\mathrm{s,n}}}\, dxn}\
# , dxn + \frac{i_{cell} \left(L_{x} - 0.333333333333333 L_{\mathrm{p}}\right)}{
# \sigma_{\mathrm{p}} \int \epsilon_{\mathrm{s,p}}_{\mathrm{s,p}}}\, dxn} - \fra
# c{i_{cell} \left(x_{p} + \frac{0.5 \left(- L_{x} + x_{p}\right)_{\mathrm{p}}}\
# right)}{\sigma_{\mathrm{p}} \int \epsilon_{\mathrm{s,p}}_{\mathrm{s,p}}}\, dxn
# } - \frac{i_{cell} \left(L_{\mathrm{n}} + L_{\mathrm{s}}\right)}{\kappa_{\math
# rm{e}} \int \left(\epsilon_{\mathrm{s}}_{\mathrm{e,s}}}\, dxn}__{-15}, \frac{(
# \epsilon c)__{\mathrm{init}} \int \frac{(\epsilon c)__{\mathrm{init}}\\\epsilo
# n__{\mathrm{init}}\\\epsilon__{\mathrm{init}}\end{cases}}\, dxn}\right) \right
# )}\, dxn}{F} - L__{\mathrm{init}}\right)__{b__{\mathrm{init}}\right)__{b__\mat
# hrm{surf}__\mathrm{surf}__{\mathrm{0}} \int \frac{3.0 \epsilon__{\mathrm{0}} \
# int \frac{3.0 \epsilon__{2.0} + L__{2.0} + x__{\mathrm{init}}\right)__{b__{-15
# }, \frac{(\epsilon c)__{\mathrm{init}} \int \frac{(\epsilon c)__{\mathrm{init}
# }\\\epsilon__{\mathrm{init}}\\\epsilon__{\mathrm{init}}\end{cases}}\, dxn}\rig
# ht) \right)}}{F}\, dxn + \int \frac{0.5 i__{b__{b__{2.0}}{L__{b__{\mathrm{init
# }}\right)__{b__{\mathtt{\text{right}}}
# \\ \textbf{Parameters and Variables}
# (\epsilon c)_{\mathrm{e}} = \begin{cases}(\epsilon c)_{\mathrm{e,n}}\\(\epsilo
# n c)_{\mathrm{e,s}}\\(\epsilon c)_{\mathrm{e,p}}\end{cases}
# \epsilon_e}__{b = \begin{cases}\left(\epsilon_{\mathrm{n}}_{\mathrm{e,n}}}\\\l
# eft(\epsilon_{\mathrm{s}}_{\mathrm{e,s}}}\\\left(\epsilon_{\mathrm{p}}_{\mathr
# m{e,p}}}\end{cases}__{\mathrm{init}}\right)__{b__{\mathrm{init}}\right)__{b__{
# \mathrm{init}}\right)__{b
# i_{cell} = \frac{I}{A_{cc} n_{electrodes parallel}}
# A_cc = L_{y} L_{z}
# aj = \begin{cases}\frac{3.0 \epsilon_{\mathrm{s,n}} i_{cell}}{L_{\mathrm{n}} R
# _{\mathrm{n}} \int \frac{3.0 \epsilon_{\mathrm{s,n}}}{R_{\mathrm{n}}}\, dxn}\\
# 0.0\\- \frac{3.0 \epsilon_{\mathrm{s,p}} i_{cell}}{L_{\mathrm{p}} R_{\mathrm{p
# }} \int \frac{3.0 \epsilon_{\mathrm{s,p}}}{R_{\mathrm{p}}}\, dxn}\end{cases}
# L = L_cc_{\mathrm{n}} + L_cc_{\mathrm{p}} + L_{x}
# Lₓ = L_{\mathrm{n}} + L_{\mathrm{p}} + L_{\mathrm{s}}
# U_\mathrm{n}(c_\mathrm{s,n}, T)__\mathrm{surf} = U_{\mathrm{n}} + dUdT_{\mathr
# m{n}} \left(- T_{\mathrm{s,n}}_{\mathrm{n}}_{\mathrm{s,n}}_{\mathrm{n}}__{\mat
# hrm{ref}} + \overline{T}\right) + \frac{1.0 \cdot 10__{-6}}{\max\left(1.0 \cdo
# t 10__{-10}, \min\left(0.9999999999, \frac{\overline{c}__{surf}}{c__{\mathrm{m
# ax}}}\right)\right)} + \frac{1.0 \cdot 10__{-6}}{\max\left(1.0 \cdot 10__{-10}
# , \min\left(0.9999999999, \frac{\overline{c}__{surf}}{c__{\mathrm{max}}}\right
# )\right) - 1.0}
# U_\mathrm{p}(c_\mathrm{s,p}, T)__\mathrm{surf} = U_{\mathrm{p}} + dUdT_{\mathr
# m{p}} \left(- T_{\mathrm{s,p}}_{\mathrm{p}}_{\mathrm{s,p}}_{\mathrm{p}}__{\mat
# hrm{ref}} + \overline{T}\right) + \frac{1.0 \cdot 10__{-6}}{\max\left(1.0 \cdo
# t 10__{-10}, \min\left(0.9999999999, \frac{\overline{c}__{surf}}{c__{\mathrm{m
# ax}}}\right)\right)} + \frac{1.0 \cdot 10__{-6}}{\max\left(1.0 \cdot 10__{-10}
# , \min\left(0.9999999999, \frac{\overline{c}__{surf}}{c__{\mathrm{max}}}\right
# )\right) - 1.0}
# I = \text{Current function [A]}
# \overline{c}_{\mathrm{s,n}} = \text{X-averaged negative particle concentration
#  [mol.m-3]}
# D_{\mathrm{n}} = \text{Negative electrode diffusivity [m2.s-1]}
# \overline{T} = \text{Volume-averaged cell temperature [K]}
# c_{\mathrm{n}}__{\mathrm{max}} = \text{Maximum concentration in negative elect
# rode [mol.m-3]}
# \overline{c}_{\mathrm{s,p}} = \text{X-averaged positive particle concentration
#  [mol.m-3]}
# D_{\mathrm{p}} = \text{Positive electrode diffusivity [m2.s-1]}
# c_{\mathrm{p}}__{\mathrm{max}} = \text{Maximum concentration in positive elect
# rode [mol.m-3]}
# \epsilon_{\mathrm{p}}__{\mathrm{init}} = \text{Positive electrode porosity}
# \epsilon_{\mathrm{s}}__{\mathrm{init}} = \text{Separator porosity}
# \epsilon_{\mathrm{n}}__{\mathrm{init}} = \text{Negative electrode porosity}
# (\epsilon c)_{\mathrm{e,p}} = \text{Positive electrode porosity times concentr
# ation [mol.m-3]}
# (\epsilon c)_{\mathrm{e,s}} = \text{Separator porosity times concentration [mo
# l.m-3]}
# (\epsilon c)_{\mathrm{e,n}} = \text{Negative electrode porosity times concentr
# ation [mol.m-3]}
# D_{\mathrm{e}} = \text{Electrolyte diffusivity [m2.s-1]}
# b_{\mathrm{e,p}} = \text{Positive electrode Bruggeman coefficient (electrolyte
# )}
# b_{\mathrm{e,s}} = \text{Separator Bruggeman coefficient (electrolyte)}
# b_{\mathrm{e,n}} = \text{Negative electrode Bruggeman coefficient (electrolyte
# )}
# F = Faraday's constant [C.mol-1]
# R_{\mathrm{p}} = \text{Positive particle radius [m]}
# \epsilon_{\mathrm{s,p}} = \text{Positive electrode active material volume frac
# tion}
# L_{\mathrm{p}} = \text{Positive electrode thickness [m]}
# L_z = \text{Electrode height [m]}
# L_y = \text{Electrode width [m]}
# n_electrodes_parallel = \text{Number of electrodes connected in parallel to ma
# ke a cell}
# R_{\mathrm{n}} = \text{Negative particle radius [m]}
# \epsilon_{\mathrm{s,n}} = \text{Negative electrode active material volume frac
# tion}
# L_{\mathrm{n}} = \text{Negative electrode thickness [m]}
# t_{\mathrm{+}} = \text{Cation transference number}
# L_cc_{\mathrm{p}} = \text{Positive current collector thickness [m]}
# L_{\mathrm{s}} = \text{Separator thickness [m]}
# L_cc_{\mathrm{n}} = \text{Negative current collector thickness [m]}
# c_cc_{\mathrm{p}} = \text{Positive current collector specific heat capacity [J
# .kg-1.K-1]}
# ρ_cc_{\mathrm{p}} = \text{Positive current collector density [kg.m-3]}
# c_{\mathrm{p}} = \text{Positive electrode specific heat capacity [J.kg-1.K-1]}
# \rho_{\mathrm{p}} = \text{Positive electrode density [kg.m-3]}
# c_{\mathrm{s,p}} = \text{Separator specific heat capacity [J.kg-1.K-1]}
# \rho_{\mathrm{s}} = \text{Separator density [kg.m-3]}
# c_{\mathrm{n,p}} = \text{Negative electrode specific heat capacity [J.kg-1.K-1
# ]}
# \rho_{\mathrm{n}} = \text{Negative electrode density [kg.m-3]}
# c_cc_{\mathrm{n,p}} = \text{Negative current collector specific heat capacity
# [J.kg-1.K-1]}
# ρ_cc_{\mathrm{n}} = \text{Negative current collector density [kg.m-3]}
# T_{\mathrm{amb}} = \text{Ambient temperature [K]}
# V_cell = \text{Cell volume [m3]}
# A_cooling = \text{Cell cooling surface area [m2]}
# hₜₒₜₐₗ = \text{Total heat transfer coefficient [W.m-2.K-1]}
# σ_cc_{\mathrm{p}} = \text{Positive current collector conductivity [S.m-1]}
# dUdT_{\mathrm{p}} = \text{Positive electrode OCP entropic change [V.K-1]}
# j_{\mathrm{p}}__{\mathrm{0}} = \text{Positive electrode exchange-current densi
# ty [A.m-2]}
# ne_{\mathrm{p}} = \text{Positive electrode electrons in reaction}
# R = \text{Ideal gas constant [J.kg-1.K-1]}
# \kappa_{\mathrm{e}} = \text{Electrolyte conductivity [S.m-1]}
# 1+\frac{dlnf}{dlnc} = 1 + dlnf/dlnc
# dUdT_{\mathrm{n}} = \text{Negative electrode OCP entropic change [V.K-1]}
# T__{\mathrm{ref}} = \text{Reference temperature [K]}
# U_{\mathrm{n}} = \text{Negative electrode OCP [V]}
# j_{\mathrm{n}}__{\mathrm{0}} = \text{Negative electrode exchange-current densi
# ty [A.m-2]}
# ne_{\mathrm{n}} = \text{Negative electrode electrons in reaction}
# b_{\mathrm{s,n}} = \text{Negative electrode Bruggeman coefficient (electrode)}
# \sigma_{\mathrm{n}} = \text{Negative electrode conductivity [S.m-1]}
# b_{\mathrm{s,p}} = \text{Positive electrode Bruggeman coefficient (electrode)}
# \sigma_{\mathrm{p}} = \text{Positive electrode conductivity [S.m-1]}
# U_{\mathrm{p}} = \text{Positive electrode OCP [V]}
# σ_cc_{\mathrm{n}} = \text{Negative current collector conductivity [S.m-1]}

# %% [markdown]
# ## References
#
# The relevant papers for this notebook are:

# %%
pybamm.print_citations()
