# %% [markdown]
# # Using latexify in PyBaMM
# In this notebook we show how to use `latexify` to print all the model equations.

# %% [markdown]
# First we import pybamm

# %%
# %pip install pybamm -q    # install PyBaMM if it is not installed
import pybamm
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Then we load a model

# %%
model = pybamm.lithium_ion.SPM()

# %% [markdown]
# Now that we have defined a model we can use latexify to get the latex of all the model equations

# %%
model.latexify()
# Out:
# \large{\underline{\textbf{Single Particle Model Equations}}}\\\\\\ \textbf{Dis
# charge capacity [A.h]}\\\\\frac{d}{d t} Q_{Ah} = \frac{I}{3600}\\\\Q_{Ah} = 0.
# 0\quad at\; t=0\\\\\\ \textbf{X-averaged negative particle concentration [mol.
# m-3]}\\\\\frac{\partial}{\partial t} \bar{c}_{s\,n} = \nabla\cdot \left(D_{n}
# \left(\nabla \bar{c}_{s\,n}\right)\right)\quad 0 < r < R_{n}_{s\,n} = \int c_{
# n}_{s\,n} = 0.0\quad r = 0\\\\\frac{\partial}{\partial r} \bar{c}_{s\,n} = - \
# frac{1.03642696566177 \cdot 10_{density with time}}{D_{n}_{n} \int \frac{3.0 \
# epsilon_{s n}}{R_{n}}\, dxn}\quad r = R_{n}_{s\,p} = \nabla\cdot \left(D_{p} \
# left(\nabla \bar{c}_{s\,p}\right)\right)\quad 0 < r < R_{p}_{s\,p} = \int c_{p
# }_{s\,p} = 0.0\quad r = 0\\\\\frac{\partial}{\partial r} \bar{c}_{s\,p} = \fra
# c{1.03642696566177 \cdot 10_{density with time}}{D_{p}_{p} \int \frac{3.0 \eps
# ilon_{s p}}{R_{p}}\, dxn}\quad r = R_{p}_{amb} \operatorname{asinh}{\left(\fra
# c{0.5 current_{density with time}}{L_{p} j{p}_{s p}}{R_{p}}\, dxn} \right)}}{n
# e_{p}} - \frac{0.00017234666524564 T_{amb} \operatorname{asinh}{\left(\frac{0.
# 5 current_{density with time}}{L_{n} j{n}_{s n}}{R_{n}}\, dxn} \right)}}{ne_{n
# }} - U_{n} + U_{p} - \frac{dU_{n}}{dT} \left(T_{amb} - T{}_{p}}{dT} \left(T_{a
# mb} - T{}_{s\,p}_{p}_{s\,n}_{n}_{s\,p}_{p}_{s\,n}_{n}_{s\,n} = \text{X-average
# d negative particle concentration [mol.m-3]}\\\\D_{n} = \text{Negative electro
# de diffusivity [m2.s-1]}\\\\T_{amb} = \text{Ambient temperature [K]}\\\\c_{n}_
# {s\,p} = \text{X-averaged positive particle concentration [mol.m-3]}\\\\D_{p}
# = \text{Positive electrode diffusivity [m2.s-1]}\\\\c_{p}__{typ}\\\\\bar{c}__{
# init}\, dxn\quad at\; t=0\\\\\frac{\partial}{\partial r} \bar{c}__{-5} current
# __{surf} L__{typ}\\\\\\ \textbf{X-averaged positive particle concentration [mo
# l.m-3]}\\\\\frac{\partial}{\partial t} \bar{c}__{typ}\\\\\bar{c}__{init}\, dxn
# \quad at\; t=0\\\\\frac{\partial}{\partial r} \bar{c}__{-5} current__{surf} L_
# _{typ}\\\\\\ \textbf{Voltage [V]}\\\\V = - \frac{0.00017234666524564
# T__{0} \int \frac{3.0 \epsilon__{0} \int \frac{3.0 \epsilon__{ref}\right) + \f
# rac{dU__{ref}\right) + \frac{1.0 \cdot 10__{-6}}{\max\left(1.0 \cdot 10__{-10}
# , \min\left(0.9999999999, \frac{\bar{c}__{surf}}{c__{max}}\right)\right)} - \f
# rac{1.0 \cdot 10__{-6}}{\max\left(1.0 \cdot 10__{-10}, \min\left(0.9999999999,
#  \frac{\bar{c}__{surf}}{c__{max}}\right)\right)} + \frac{1.0 \cdot 10__{-6}}{\
# max\left(1.0 \cdot 10__{-10}, \min\left(0.9999999999, \frac{\bar{c}__{surf}}{c
# __{max}}\right)\right) - 1.0} - \frac{1.0 \cdot 10__{-6}}{\max\left(1.0 \cdot
# 10__{-10}, \min\left(0.9999999999, \frac{\bar{c}__{surf}}{c__{max}}\right)\rig
# ht) - 1.0}\\\\\\ \textbf{Parameters and Variables}\\\\I = \text{Current functi
# on [A]}\\\\\bar{c}__{max} = \text{Maximum concentration in negative electrode
# [mol.m-3]}\\\\\bar{c}__{max} = \text{Maximum concentration in positive electro
# de [mol.m-3]}

# %% [markdown]
# We can also get a list of all the equations instead of a single line joined by newline

# %%
model.latexify(newline=False)
# Out:
# ⎡
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢\large{\underline{\textbf{Single Particle Model Equations}}}, \\ \textbf{Disc
# ⎣
#
#
#
#
#
#
#
#                        d           I
# harge capacity [A.h]}, ──(Q_Ah) = ────, Q_{Ah} = 0.0\quad at\; t=0, \\ \textbf
#                        dt         3600
#
#
#
#
#
#
#
#                                                         d
# {X-averaged negative particle concentration [mol.m-3]}, ──(\bar{c}_{s\,n}) = \
#                                                         dt
#
#
#
#
#
#
#
#
# nabla\cdot \left(D_{n} \left(\nabla \bar{c}_{s\,n}\right)\right)\quad 0 < r <
#
#
#
#
#
#
#
#
#                                                                        d
# R_{n}__{typ}, \bar{c}_{s\,n} = \int c_{n}__{init}\, dxn\quad at\; t=0, ──(\bar
#                                                                        dr
#
#
#
#
#
#
#
#                               d
# {c}_{s\,n}) = 0.0\quad r = 0, ──(\bar{c}_{s\,n}) = - \frac{1.03642696566177 \c
#                               dr
#
#
#
#
#
#
#
#
# dot 10_{density with time}}{D_{n}_{n} \int \frac{3.0 \epsilon_{s n}}{R_{n}}\,
#
#
#
#
#
#
#
#
#
# dxn}\quad r = R_{n}__{-5} current__{surf} L__{typ}, \\ \textbf{X-averaged posi
#
#
#
#
#
#
#
#
#                                         d
# tive particle concentration [mol.m-3]}, ──(\bar{c}_{s\,p}) = \nabla\cdot \left
#                                         dt
#
#
#
#
#
#
#
#
# (D_{p} \left(\nabla \bar{c}_{s\,p}\right)\right)\quad 0 < r < R_{p}__{typ}, \b
#
#
#
#
#
#
#
#
#                                                        d
# ar{c}_{s\,p} = \int c_{p}__{init}\, dxn\quad at\; t=0, ──(\bar{c}_{s\,p}) = 0.
#                                                        dr
#
#
#
#
#
#
#
#               d
# 0\quad r = 0, ──(\bar{c}_{s\,p}) = \frac{1.03642696566177 \cdot 10_{density wi
#               dr
#
#
#
#
#
#
#
#
# th time}}{D_{p}_{p} \int \frac{3.0 \epsilon_{s p}}{R_{p}}\, dxn}\quad r = R_{p
#
#
#
#                                                                           0.00
#
#
#
#
#
# }__{-5} current__{surf} L__{typ}, \\ \textbf{Voltage [V]}, V = - ────
#
#
#                            ⎛   0.5⋅current_density_with_time    ⎞
# 017234666524564⋅T_amb⋅asinh⎜────────────────────────────────────⎟   0.00017234
#                            ⎜             ⌠                      ⎟
#                            ⎜             ⎮ 3.0⋅\epsilonₛ ₚ      ⎟
#                            ⎜Lₚ⋅j{p}__{0}⋅⎮ ─────────────── d(xn)⎟
#                            ⎜             ⎮        Rₚ            ⎟
#                            ⎝             ⌡                      ⎠
# ───────────────────────────────────────────────────────────────── - ──────────
#                              neₚ
#
#                      ⎛   0.5⋅current_density_with_time    ⎞
# 666524564⋅T_amb⋅asinh⎜────────────────────────────────────⎟
#                      ⎜             ⌠                      ⎟
#                      ⎜             ⎮ 3.0⋅\epsilonₛ ₙ      ⎟
#                      ⎜Lₙ⋅j{n}__{0}⋅⎮ ─────────────── d(xn)⎟
#                      ⎜             ⎮        Rₙ            ⎟
#                      ⎝             ⌡                      ⎠
# ─────────────────────────────────────────────────────────── - Uₙ + Uₚ - \frac{
#                        neₙ
#
#
#
#
#
#
#
#
# dU_{n}}{dT}⋅(T_amb - T{}__{ref}) + \frac{dU_{p}}{dT}⋅(T_amb - T{}__{ref}) + ──
#                                                                             Ma
#
#
#
#
#
#
#
#                             1.0e-6
# ──────────────────────────────────────────────────────────────── - ───────────
# x(1.0e-10, Min(0.9999999999, \bar{c}_{s\,p}^{surf}/c_{p}^{max}))   Max(1.0e-10
#
#
#
#
#
#
#
#                    1.0e-6
# ─────────────────────────────────────────────────────── + ────────────────────
# , Min(0.9999999999, \bar{c}_{s\,n}^{surf}/c_{n}^{max}))   Max(1.0e-10, Min(0.9
#
#
#
#
#
#
#
#              1.0e-6
# ──────────────────────────────────────────────────── - ───────────────────────
# 999999999, \bar{c}_{s\,p}^{surf}/c_{p}^{max})) - 1.0   Max(1.0e-10, Min(0.9999
#
#
#
#
#
#
#
#           1.0e-6
# ─────────────────────────────────────────────────, \\ \textbf{Parameters and V
# 999999, \bar{c}_{s\,n}^{surf}/c_{n}^{max})) - 1.0
#
#
#
#
#
#
#
#
# ariables}, I = \text{Current function [A]}, \bar{c}_{s\,n} = \text{X-averaged
#
#
#
#
#
#
#
#
#
# negative particle concentration [mol.m-3]}, Dₙ = \text{Negative electrode diff
#
#
#
#
#
#
#
#
#
# usivity [m2.s-1]}, T_amb = \text{Ambient temperature [K]}, c_{n}__{max} = \tex
#
#
#
#
#
#
#
#
#
# t{Maximum concentration in negative electrode [mol.m-3]}, \bar{c}_{s\,p} = \te
#
#
#
#
#
#
#
#
#
# xt{X-averaged positive particle concentration [mol.m-3]}, Dₚ = \text{Positive
#
#
#
#
#
#
#
#
#
# electrode diffusivity [m2.s-1]}, c_{p}__{max} = \text{Maximum concentration in
#
#
#                               ⎤
#                               ⎥
#                               ⎥
#                               ⎥
#                               ⎥
#                               ⎥
#                               ⎥
#  positive electrode [mol.m-3]}⎥
#                               ⎦

# %% [markdown]
# latexify can also be used to get the equations in a file format like png, jpg, pdf or tex.

# %%
model.latexify("spm_equations.png")
# Out:
# /Users/vsulzer/Code/PyBaMM/pybamm/expression_tree/operations/latexify.py:357: UserWarning: RuntimeError - Setting the output resolution to default
#   warnings.warn(
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File ~/Code/PyBaMM/pybamm/expression_tree/operations/latexify.py:347, in Latexify.latexify(self)
#     346 try:
# --> 347     return sympy.preview(
#     348         eqn_new_line,
#     349         viewer="file",
#     350         filename=self.filename,
#     351         dvioptions=["-D", "900"],
#     352         euler=False,
#     353     )
#     355 # When equations are too huge, set output resolution to default
#
# File ~/miniforge3/envs/pybamm/lib/python3.9/site-packages/sympy/printing/preview.py:308, in preview(expr, output, viewer, euler, packages, filename, outputbuffer, preamble, dvioptions, outputTexFile, extra_preamble, fontsize, **latex_settings)
#     307 if not shutil.which('latex'):
# --> 308     raise RuntimeError("latex program is not installed")
#     310 try:
#
# RuntimeError: latex program is not installed
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 model.latexify("spm_equations.png")
#
# File ~/Code/PyBaMM/pybamm/models/base_model.py:1048, in BaseModel.latexify(self, filename, newline)
#    1046 def latexify(self, filename=None, newline=True):
#    1047     # For docstring, see pybamm.expression_tree.operations.latexify.Latexify
# -> 1048     return Latexify(self, filename, newline).latexify()
#
# File ~/Code/PyBaMM/pybamm/expression_tree/operations/latexify.py:360, in Latexify.latexify(self)
#     356 except RuntimeError:  # pragma: no cover
#     357     warnings.warn(
#     358         "RuntimeError - Setting the output resolution to default"
#     359     )
# --> 360     return sympy.preview(
#     361         eqn_new_line,
#     362         viewer="file",
#     363         filename=self.filename,
#     364         euler=False,
#     365     )
#
# File ~/miniforge3/envs/pybamm/lib/python3.9/site-packages/sympy/printing/preview.py:308, in preview(expr, output, viewer, euler, packages, filename, outputbuffer, preamble, dvioptions, outputTexFile, extra_preamble, fontsize, **latex_settings)
#     305     shutil.copyfile(join(workdir, 'texput.tex'), outputTexFile)
#     307 if not shutil.which('latex'):
# --> 308     raise RuntimeError("latex program is not installed")
#     310 try:
#     311     _check_output_no_window(
#     312         ['latex', '-halt-on-error', '-interaction=nonstopmode',
#     313          'texput.tex'],
#     314         cwd=workdir,
#     315         stderr=STDOUT)
#
# RuntimeError: latex program is not installed

# %% [markdown]
# It will create a png file like this in the directory

# %% [markdown]
# ![SPM Equations PNG](./spm_equations.png)

# %% [markdown]
# Don't worry if you get something like this :)

# %%
model_spme = pybamm.lithium_ion.SPMe()

# %%
model_spme.latexify()
# Out:
# \large{\underline{\textbf{Single Particle Model with electrolyte Equations}}}\
# \\\\\ \textbf{Discharge capacity [A.h]}\\\\\frac{d}{d t} Q_{Ah} = \frac{I}{360
# 0}\\\\Q_{Ah} = 0.0\quad at\; t=0\\\\\\ \textbf{X-averaged negative particle co
# ncentration [mol.m-3]}\\\\\frac{\partial}{\partial t} \bar{c}_{s\,n} = \nabla\
# cdot \left(D_{n} \left(\nabla \bar{c}_{s\,n}\right)\right)\quad 0 < r < R_{n}_
# {s\,n} = \int c_{n}_{s\,n} = 0.0\quad r = 0\\\\\frac{\partial}{\partial r} \ba
# r{c}_{s\,n} = - \frac{1.03642696566177 \cdot 10_{density with time}}{D_{n}_{n}
#  \int \frac{3.0 \epsilon_{s n}}{R_{n}}\, dxn}\quad r = R_{n}_{s\,p} = \nabla\c
# dot \left(D_{p} \left(\nabla \bar{c}_{s\,p}\right)\right)\quad 0 < r < R_{p}_{
# s\,p} = \int c_{p}_{s\,p} = 0.0\quad r = 0\\\\\frac{\partial}{\partial r} \bar
# {c}_{s\,p} = \frac{1.03642696566177 \cdot 10_{density with time}}{D_{p}_{p} \i
# nt \frac{3.0 \epsilon_{s p}}{R_{p}}\, dxn}\quad r = R_{p}_e} = - \frac{1036426
# 96566177 \begin{cases}\frac{3.0 \epsilon_{s n} current_{density with time}}{L_
# {n} R_{n} \int \frac{3.0 \epsilon_{s n}}{R_{n}}\, dxn}\\0.0\\- \frac{3.0 \epsi
# lon_{s p} current_{density with time}}{L_{p} R_{p} \int \frac{3.0 \epsilon_{s
# p}}{R_{p}}\, dxn}\end{cases} t_{plus}}{10000000000000000000} + \frac{103642696
# 566177 aj}{10000000000000000000} - \nabla\cdot \left(- D_{e} \epsilon_e} \left
# (\nabla \left(\frac{\epsilon{c_e}}{\begin{cases}\epsilon_{n}_{s}_{p}_x\\\\\lef
# t[ \epsilon{c_e} = \begin{cases}\epsilon_{c e n}& 0 < \mathtt{\text{x\_n}} < L
# _n \\ \epsilon_{c e s}& L_n < \mathtt{\text{x\_s}} < L_n + L_s \\ \epsilon_{c
# e p}& L_n + L_s < \mathtt{\text{x\_p}} < L_x\end{cases}, \  \epsilon_e} = \beg
# in{cases}\left(\epsilon_{n}_{e n}}& 0 < \mathtt{\text{x\_n}} < L_n \\ \left(\e
# psilon_{s}_{e s}}& L_n < \mathtt{\text{x\_s}} < L_n + L_s \\ \left(\epsilon_{p
# }_{e p}}& L_n + L_s < \mathtt{\text{x\_p}} < L_x\end{cases}, \  aj = \begin{ca
# ses}\frac{3.0 \epsilon_{s n} current_{density with time}}{L_{n} R_{n} \int \fr
# ac{3.0 \epsilon_{s n}}{R_{n}}\, dxn}& 0 < \mathtt{\text{x\_n}} < L_n \\ 0.0& L
# _n < \mathtt{\text{x\_s}} < L_n + L_s \\ - \frac{3.0 \epsilon_{s p} current_{d
# ensity with time}}{L_{p} R_{p} \int \frac{3.0 \epsilon_{s p}}{R_{p}}\, dxn}& L
# _n + L_s < \mathtt{\text{x\_p}} < L_x\end{cases}\right]\\\\\epsilon{c_e} = \ep
# silon{}_{e}_{amb} \left(2.0 - 2.0 t_{plus}\right) \int \log{\left(\max\left(1.
# 0 \cdot 10_{c e n}}{\epsilon_{n}_e}}{\begin{cases}\epsilon_{n}_{s}_{p}_{n} cur
# rent_{density with time} \left(- \frac{1.0}{\kappa_{e} \int \left(\epsilon_{s}
# _{e s}}\, dxn} + \frac{0.333333333333333}{\kappa_{e} \int \left(\epsilon_{n}_{
# e n}}\, dxn}\right) - U_{n} + U_{p} - \frac{dU_{n}}{dT} \left(T_{amb} - T{}_{p
# }}{dT} \left(T_{amb} - T{}_{amb} \operatorname{asinh}{\left(\frac{0.5 current_
# {density with time}}{L_{n} j{n}_{s n}}{R_{n}}\, dxn} \right)}}{ne_{n}}\, dxn +
#  \int \left(- \frac{0.00017234666524564 T_{amb} \operatorname{asinh}{\left(\fr
# ac{0.5 current_{density with time}}{L_{p} j{p}_{s p}}{R_{p}}\, dxn} \right)}}{
# ne_{p}}\right)\, dxn + \int 8.61733326228198 \cdot 10_{amb} \left(2.0 - 2.0 t_
# {plus}\right) \log{\left(\max\left(1.0 \cdot 10_{c e p}}{\epsilon_{p}_e}}{\beg
# in{cases}\epsilon_{n}_{s}_{p}_{density with time} \left(L_{p}_{x}_{p} \left(2.
# 0 L_{x} - x_{p}\right)\right)}{L_{p} \kappa_{e} \int \left(\epsilon_{p}_{e p}}
# \, dxn}\, dxn + \int \frac{0.5 current_{density with time} x_{n} \left(- 2.0 L
# _{n} + x_{n}\right)}{L_{n} \sigma_{n} \int \epsilon_{s n}_{s n}}\, dxn}\, dxn
# + \frac{1.0 \cdot 10_{s\,p}_{p}_{s\,n}_{n}_{s\,p}_{p}_{s\,n}_{n}_{density with
#  time} \left(- 0.333333333333333 L_{p} + L_{x}\right)}{\sigma_{p} \int \epsilo
# n_{s p}_{s p}}\, dxn} - \frac{current_{density with time} \left(x_{p} + \frac{
# 0.5 \left(- L_{x} + x_{p}\right)_{p}}\right)}{\sigma_{p} \int \epsilon_{s p}_{
# s p}}\, dxn} - \frac{current_{density with time} \left(L_{n} + L_{s}\right)}{\
# kappa_{e} \int \left(\epsilon_{s}_{e s}}\, dxn}_e} = \begin{cases}\epsilon_{c
# e n}\\\epsilon_{c e s}\\\epsilon_{c e p}\end{cases}\\\\\epsilon_e} = \begin{ca
# ses}\left(\epsilon_{n}_{e n}}\\\left(\epsilon_{s}_{e s}}\\\left(\epsilon_{p}_{
# e p}}\end{cases}\\\\current_{density with time} = \frac{I}{A_{cc} n_{electrode
# s parallel}}\\\\A_{cc} = L_{y} L_{z}\\\\aj = \begin{cases}\frac{3.0 \epsilon_{
# s n} current_{density with time}}{L_{n} R_{n} \int \frac{3.0 \epsilon_{s n}}{R
# _{n}}\, dxn}\\0.0\\- \frac{3.0 \epsilon_{s p} current_{density with time}}{L_{
# p} R_{p} \int \frac{3.0 \epsilon_{s p}}{R_{p}}\, dxn}\end{cases}\\\\I = \text{
# Current function [A]}\\\\\bar{c}_{s\,n} = \text{X-averaged negative particle c
# oncentration [mol.m-3]}\\\\D_{n} = \text{Negative electrode diffusivity [m2.s-
# 1]}\\\\T_{amb} = \text{Ambient temperature [K]}\\\\c_{n}_{s\,p} = \text{X-aver
# aged positive particle concentration [mol.m-3]}\\\\D_{p} = \text{Positive elec
# trode diffusivity [m2.s-1]}\\\\c_{p}_{p}_{s}_{n}_{c e p} = \text{Positive elec
# trode porosity times concentration [mol.m-3]}\\\\\epsilon_{c e s} = \text{Sepa
# rator porosity times concentration [mol.m-3]}\\\\\epsilon_{c e n} = \text{Nega
# tive electrode porosity times concentration [mol.m-3]}\\\\D_{e} = \text{Electr
# olyte diffusivity [m2.s-1]}\\\\b_{e p} = \text{Positive electrode Bruggeman co
# efficient (electrolyte)}\\\\b_{e s} = \text{Separator Bruggeman coefficient (e
# lectrolyte)}\\\\b_{e n} = \text{Negative electrode Bruggeman coefficient (elec
# trolyte)}\\\\R_{p} = \text{Positive particle radius [m]}\\\\\epsilon_{s p} = \
# text{Positive electrode active material volume fraction}\\\\L_{p} = \text{Posi
# tive electrode thickness [m]}\\\\L_{z} = \text{Electrode height [m]}\\\\L_{y}
# = \text{Electrode width [m]}\\\\n_{electrodes parallel} = \text{Number of elec
# trodes connected in parallel to make a cell}\\\\R_{n} = \text{Negative particl
# e radius [m]}\\\\\epsilon_{s n} = \text{Negative electrode active material vol
# ume fraction}\\\\L_{n} = \text{Negative electrode thickness [m]}\\\\t_{plus} =
#  \text{Cation transference number}__{typ}\\\\\bar{c}__{init}\, dxn\quad at\; t
# =0\\\\\frac{\partial}{\partial r} \bar{c}__{-5} current__{surf} L__{typ}\\\\\\
#  \textbf{X-averaged positive particle concentration [mol.m-3]}\\\\\frac{\parti
# al}{\partial t} \bar{c}__{typ}\\\\\bar{c}__{init}\, dxn\quad at\; t=0\\\\\frac
# {\partial}{\partial r} \bar{c}__{-5} current__{surf} L__{typ}\\\\\\ \textbf{Po
# rosity times concentration [mol.m-3](Negative electrode porosity times concent
# ration [mol.m-3], Separator porosity times concentration [mol.m-3], Positive e
# lectrode porosity times concentration [mol.m-3])}\\\\\frac{\partial}{\partial
# t} \epsilon{c__{b__{init}\\\epsilon__{init}\\\epsilon__{init}\end{cases}}\righ
# t)\right)\right)\quad 0 < x < L__{b__{init}\right)__{b__{init}\right)__{b__{in
# it}\right)__{b__{init} c__{init}\quad at\; t=0\\\\\\ \textbf{Voltage
# [V]}\\\\V = - 8.61733326228198 \cdot 10__{-5} \cdot 1+\frac{dlnf}{dlnc} T__{-1
# 5}, \frac{\epsilon__{init} \int \frac{\epsilon{c__{init}\\\epsilon__{init}\\\e
# psilon__{init}\end{cases}}\, dxn}\right) \right)}\, dxn - L__{init}\right)__{b
# __{init}\right)__{b__{ref}\right) + \frac{dU__{ref}\right) - \int \frac{0.0001
# 7234666524564 T__{0} \int \frac{3.0 \epsilon__{0} \int \frac{3.0 \epsilon__{-5
# } \cdot 1+\frac{dlnf}{dlnc} T__{-15}, \frac{\epsilon__{init} \int \frac{\epsil
# on{c__{init}\\\epsilon__{init}\\\epsilon__{init}\end{cases}}\, dxn}\right) \ri
# ght)}\, dxn - \int \frac{0.5 current__{2.0} - L__{2.0} + x__{init}\right)__{b_
# _{b__{-6}}{\max\left(1.0 \cdot 10__{-10}, \min\left(0.9999999999, \frac{\bar{c
# }__{surf}}{c__{max}}\right)\right)} - \frac{1.0 \cdot 10__{-6}}{\max\left(1.0
# \cdot 10__{-10}, \min\left(0.9999999999, \frac{\bar{c}__{surf}}{c__{max}}\righ
# t)\right)} + \frac{1.0 \cdot 10__{-6}}{\max\left(1.0 \cdot 10__{-10}, \min\lef
# t(0.9999999999, \frac{\bar{c}__{surf}}{c__{max}}\right)\right) - 1.0} - \frac{
# 1.0 \cdot 10__{-6}}{\max\left(1.0 \cdot 10__{-10}, \min\left(0.9999999999, \fr
# ac{\bar{c}__{surf}}{c__{max}}\right)\right) - 1.0} + \frac{current__{b__{2.0}}
# {L__{b__{init}\right)__{b__{\mathtt{\text{right}}}\\\\\\ \textbf{Parameters an
# d Variables}\\\\\epsilon{c__{b__{init}\right)__{b__{init}\right)__{b__{init}\r
# ight)__{b__{max} = \text{Maximum concentration in negative electrode [mol.m-3]
# }\\\\\bar{c}__{max} = \text{Maximum concentration in positive electrode [mol.m
# -3]}\\\\\epsilon__{init} = \text{Positive electrode porosity}\\\\\epsilon__{in
# it} = \text{Separator porosity}\\\\\epsilon__{init} = \text{Negative electrode
#  porosity}\\\\\epsilon

# %% [markdown]
# jupyter notebook sometimes cannot render latex output that is too large

# %% [markdown]
# When `newline=False` it returns a list, so it inherits all the properties of a list and you can also do something like this

# %%
model_spme.latexify(newline=False)[15:18]
# Out:
# ⎡d
# ⎢──(\epsilon{c_e}) = - \frac{103642696566177 \begin{cases}\frac{3.0 \epsilon_{
# ⎣dt
#
#
# s n} current_{density with time}}{L_{n} R_{n} \int \frac{3.0 \epsilon_{s n}}{R
#
#
#
# _{n}}\, dxn}\\0.0\\- \frac{3.0 \epsilon_{s p} current_{density with time}}{L_{
#
#
#
# p} R_{p} \int \frac{3.0 \epsilon_{s p}}{R_{p}}\, dxn}\end{cases} t_{plus}}{100
#
#
#
# 00000000000000000} + \frac{103642696566177 aj}{10000000000000000000} - \nabla\
#
#
#
# cdot \left(- D_{e} \epsilon_e} \left(\nabla \left(\frac{\epsilon{c_e}}{\begin{
#
#
#
# cases}\epsilon_{n}_{s}_{p}_x__{b__{init}\\\epsilon__{init}\\\epsilon__{init}\e
#
#
#
# nd{cases}}\right)\right)\right)\quad 0 < x < L, [\epsilon{c_e} = \begin{cases}
#
#
#
# \epsilon_{c e n}& 0 < \mathtt{\text{x\_n}} < L_n \\ \epsilon_{c e s}& L_n < \m
#
#
#
# athtt{\text{x\_s}} < L_n + L_s \\ \epsilon_{c e p}& L_n + L_s < \mathtt{\text{
#
#
#
# x\_p}} < L_x\end{cases}, \epsilon_e}__{b = \begin{cases}\left(\epsilon_{n}_{e
#
#
#
# n}}& 0 < \mathtt{\text{x\_n}} < L_n \\ \left(\epsilon_{s}_{e s}}& L_n < \matht
#
#
#
# t{\text{x\_s}} < L_n + L_s \\ \left(\epsilon_{p}_{e p}}& L_n + L_s < \mathtt{\
#
#
#
# text{x\_p}} < L_x\end{cases}__{init}\right)__{b__{init}\right)__{b__{init}\rig
#
#
#
# ht)__{b, aj = \begin{cases}\frac{3.0 \epsilon_{s n} current_{density with time
#
#
#
# }}{L_{n} R_{n} \int \frac{3.0 \epsilon_{s n}}{R_{n}}\, dxn}& 0 < \mathtt{\text
#
#
#
# {x\_n}} < L_n \\ 0.0& L_n < \mathtt{\text{x\_s}} < L_n + L_s \\ - \frac{3.0 \e
#
#
#
# psilon_{s p} current_{density with time}}{L_{p} R_{p} \int \frac{3.0 \epsilon_
#
#
#
# {s p}}{R_{p}}\, dxn}& L_n + L_s < \mathtt{\text{x\_p}} < L_x\end{cases}], \eps
#
#
#                                                           ⎤
# ilon{c_e} = \epsilon{}_{e}__{init} c__{init}\quad at\; t=0⎥
#                                                           ⎦

# %% [markdown]
# ## References
#
# The relevant papers for this notebook are:

# %%
pybamm.print_citations()
# Out:
# [1] Weilong Ai, Ludwig Kraft, Johannes Sturm, Andreas Jossen, and Billy Wu. Electrochemical thermal-mechanical modelling of stress inhomogeneity in lithium-ion pouch cells. Journal of The Electrochemical Society, 167(1):013512, 2019. doi:10.1149/2.0122001JES.
# [2] Rutooj Deshpande, Mark Verbrugge, Yang-Tse Cheng, John Wang, and Ping Liu. Battery cycle life prediction with coupled chemical degradation and fatigue mechanics. Journal of the Electrochemical Society, 159(10):A1730, 2012. doi:10.1149/2.049210jes.
# [3] Charles R. Harris, K. Jarrod Millman, Stéfan J. van der Walt, Ralf Gommers, Pauli Virtanen, David Cournapeau, Eric Wieser, Julian Taylor, Sebastian Berg, Nathaniel J. Smith, and others. Array programming with NumPy. Nature, 585(7825):357–362, 2020. doi:10.1038/s41586-020-2649-2.
# [4] Scott G. Marquis, Valentin Sulzer, Robert Timms, Colin P. Please, and S. Jon Chapman. An asymptotic derivation of a single particle model with electrolyte. Journal of The Electrochemical Society, 166(15):A3693–A3706, 2019. doi:10.1149/2.0341915jes.
# [5] Valentin Sulzer, Scott G. Marquis, Robert Timms, Martin Robinson, and S. Jon Chapman. Python Battery Mathematical Modelling (PyBaMM). Journal of Open Research Software, 9(1):14, 2021. doi:10.5334/jors.309.
