# %% [markdown]
# # Using latexify in PyBaMM
# In this notebook we show how to use `latexify` to print all the model equations.

# %% [markdown]
# First we import pybamm

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %pip install pybamm -q    # install PyBaMM if it is not installed
import pybamm
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Then we load a model

# %%
model = pybamm.lithium_ion.SPM()

# %% [markdown]
# Now that we have defined a model we can use latexify to get the latex of all the model equations

# %%
model.latexify()
# Out:
# \large{\underline{\textbf{Single Particle Model Equations}}}\\\\\\ \textbf{Dis
# charge capacity [A.h]}\\\\\frac{d}{d t} Q_{Ah} = \frac{I}{3600}\\\\Q_{Ah} = 0.
# 0\quad \text{at}\; t=0\\\\\\ \textbf{X-averaged negative particle concentratio
# n [mol.m-3]}\\\\\frac{\partial}{\partial t} \overline{c}_{\mathrm{s,n}} = \nab
# la\cdot \left(D_{\mathrm{n}} \left(\nabla \overline{c}_{\mathrm{s,n}}\right)\r
# ight)\quad 0 < r < R_{\mathrm{n}}_{\mathrm{s,n}} = \int c_{\mathrm{n}}_{\mathr
# m{s,n}} = 0.0\quad  \text{at } r = 0\\\\\frac{\partial}{\partial r} \overline{
# c}_{\mathrm{s,n}} = - \frac{i_{cell}}{D_{\mathrm{n}}_{\mathrm{n}} \int \frac{3
# .0 \epsilon_{\mathrm{s,n}}}{R_{\mathrm{n}}}\, dxn}\quad \text{at } r = R_{\mat
# hrm{n}}_{\mathrm{s,p}} = \nabla\cdot \left(D_{\mathrm{p}} \left(\nabla \overli
# ne{c}_{\mathrm{s,p}}\right)\right)\quad 0 < r < R_{\mathrm{p}}_{\mathrm{s,p}}
# = \int c_{\mathrm{p}}_{\mathrm{s,p}} = 0.0\quad  \text{at } r = 0\\\\\frac{\pa
# rtial}{\partial r} \overline{c}_{\mathrm{s,p}} = \frac{i_{cell}}{D_{\mathrm{p}
# }_{\mathrm{p}} \int \frac{3.0 \epsilon_{\mathrm{s,p}}}{R_{\mathrm{p}}}\, dxn}\
# quad \text{at } r = R_{\mathrm{p}}_n(c_{s,n}, T) + U_p(c_{s,p}, T) - \frac{2.0
#  R T_{\mathrm{amb}} \operatorname{asinh}{\left(\frac{0.5 i_{cell}}{L_{\mathrm{
# p}} j0_{\mathrm{p}} \int \frac{3.0 \epsilon_{\mathrm{s,p}}}{R_{\mathrm{p}}}\,
# dxn} \right)}}{F ne_{\mathrm{p}}} - \frac{2.0 R T_{\mathrm{amb}} \operatorname
# {asinh}{\left(\frac{0.5 i_{cell}}{L_{\mathrm{n}} j0_{\mathrm{n}} \int \frac{3.
# 0 \epsilon_{\mathrm{s,n}}}{R_{\mathrm{n}}}\, dxn} \right)}}{F ne_{\mathrm{n}}}
# \\\\\\ \textbf{Parameters and Variables}\\\\I = \text{Current function [A]}\\\
# \\overline{c}_{\mathrm{s,n}} = \text{X-averaged negative particle concentratio
# n [mol.m-3]}\\\\D_{\mathrm{n}} = \text{Negative electrode diffusivity [m2.s-1]
# }\\\\T_{\mathrm{amb}} = \text{Ambient temperature [K]}\\\\c_{\mathrm{n}}_{\mat
# hrm{s,p}} = \text{X-averaged positive particle concentration [mol.m-3]}\\\\D_{
# \mathrm{p}} = \text{Positive electrode diffusivity [m2.s-1]}\\\\c_{\mathrm{p}}
# __{\mathrm{typ}}\\\\\overline{c}__{\mathrm{init}}\, dxn\quad \text{at}\; t=0\\
# \\\frac{\partial}{\partial r} \overline{c}__{surf} F L__{\mathrm{typ}}\\\\\\ \
# textbf{X-averaged positive particle concentration [mol.m-3]}\\\\\frac{\partial
# }{\partial t} \overline{c}__{\mathrm{typ}}\\\\\overline{c}__{\mathrm{init}}\,
# dxn\quad \text{at}\; t=0\\\\\frac{\partial}{\partial r} \overline{c}__{surf} F
#  L__{\mathrm{typ}}\\\\\\ \textbf{Voltage [V]}\\\\V = - U__{surf}__{surf}__{\ma
# thrm{max}} = \text{Maximum concentration in negative electrode [mol.m-3]}\\\\\
# overline{c}__{\mathrm{max}} = \text{Maximum concentration in positive electrod
# e [mol.m-3]}

# %% [markdown]
# We can also get a list of all the equations instead of a single line joined by newline

# %%
model.latexify(newline=False)

# %% [markdown]
# latexify can also be used to get the equations in a file format like png, jpg, pdf or tex.

# %%
model.latexify("spm_equations.png")

# %% [markdown]
# It will create a png file like this in the directory

# %% [markdown]
# ![SPM Equations PNG](./spm_equations.png)

# %% [markdown]
# Don't worry if you get something like this :)

# %%
model_spme = pybamm.lithium_ion.SPMe()

# %%
model_spme.latexify()

# %% [markdown]
# jupyter notebook sometimes cannot render latex output that is too large

# %% [markdown]
# When `newline=False` it returns a list, so it inherits all the properties of a list and you can also do something like this

# %%
model_spme.latexify(newline=False)[15:18]

# %% [markdown]
# ## References
#
# The relevant papers for this notebook are:

# %%
pybamm.print_citations()
